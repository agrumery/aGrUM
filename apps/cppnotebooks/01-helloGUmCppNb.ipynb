# %%
# %load_ext gum_cppnb

# %% [markdown]
# # aGrUM c++ in notebooks !

# %%
# %%cpp
# #include <agrum/bn.h>
# int main() {
#   auto net = gum::BayesNet<double>::fastPrototype("A->B->C");
#
#   std::cout << net.toString();
#   cppnb_add_dot(net.toDot());
#   net.addArc("A","C");
#   cppnb_add_dot(net.toDot());
#   net.eraseArc("B","C");
#   cppnb_add_dot(net.toDot());
# }
# Out:
# BN{nodes: 3, arcs: 2, domainSize: 8, dim: 5, mem: 80o}
# <table><tr><td style="padding:8px;vertical-align:top;text-align:center"><b>[0]</b><br><img src="data:image/png;base64,..."/></td><td style="padding:8px;vertical-align:top;text-align:center"><b>[1]</b><br><img src="data:image/png;base64,..."/></td><td style="padding:8px;vertical-align:top;text-align:center"><b>[2]</b><br><img src="data:image/png;base64,..."/></td></tr></table>

# %%
# %%cpp
# #include <agrum/bn2.h>
# int main() {
#   auto net = gum::BayesNet<double>::fastPrototype("A->B->C");
#
#   std::cout << net.toString();
# }
# Out:
# <blockquote style="background-color: lightblue; border-left: 5px solid #FFA500; padding: 10px;"><pre>/tmp/_nb.cpp:11:10: fatal error: 'agrum/bn2.h' file not found
#    11 | #include <agrum/bn2.h>
#       |          ^~~~~~~~~~~~~
# 1 error generated.
# </pre></blockquote>

# %%
# %%cpp
# #include <agrum/bn.h>
#
# int main() {
#   auto net = gum::BayesNet<double>::fastPrototype("A->B->C");
#   net.cpt("Z");
# }
# Out:
# <blockquote style="background-color: lightcoral; border-left: 5px solid #FFA500; padding: 10px;"><pre>libc++abi: terminating due to uncaught exception of type gum::NotFound: Object not found:
# /Users/phw/Documents/gits/agrum/aGrUM-dev/src/agrum/base/core/hashTable_tpl.h:576 in operator[]()
# --------------
# ! No element with the key <Z>
# --------------
#
# </pre></blockquote>
