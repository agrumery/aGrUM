# %%
# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
gnb.configuration()
# Out:
# <table width='100%'><tr><th>Library</th><th>Version</th></tr><tr><td>OS</td><td>posix [linux]</td></tr><tr><td>Python</td><td>3.5.0+ (default, Oct 11 2015, 09:05:38)
# [GCC 5.2.1 20151010]</td></tr><tr><td>IPython</td><td>4.0.0</td></tr><tr><td>MatPlotLib</td><td>1.5.0</td></tr><tr><td>Numpy</td><td>1.10.1</td></tr><tr><td>pyAgrum</td><td>0.9.2.9</td></tr></table><div align='right'><small>Fri Nov 06 11:44:30 2015 CET</small></div>

# %% [markdown]
# ## Static Credal Net

# %%
cn=gum.CredalNet("../resources/cn/2Umin.bif","../resources/cn/2Umax.bif")
cn.intervalToCredal()

# %%
gnb.showBN(cn.current_bn(),"3")

# %%
ie=gum.CNMonteCarloSampling(cn)
ie.insertEvidenceFile("../resources/cn/L2U.evi")

# %%
ie.setRepetitiveInd(False)

ie.setRepetitiveInd(False)
ie.setMaxTime(1)
ie.setMaxIter(1000)

ie.makeInference()

# %%
print(ie.marginalMax(0))
print(ie.marginalMin(0))
# Out:
# (0.6940476074385404, 0.5616124599175447)
# (0.4383875400824553, 0.3059523925614596)

# %% [markdown]
# ## Dynamical Credal Net

# %%
cn=gum.CredalNet("../resources/cn/bn_c_8.bif","../resources/cn/den_c_8.bif")
cn.bnToCredal(0.8,False)

# %%
ie=gum.CNMonteCarloSampling(cn)
ie.insertModalsFile("../resources/cn/modalities.modal")

ie.setRepetitiveInd(True)
ie.setMaxTime(30)
ie.setMaxIter(1000)

ie.makeInference()

# %%
print(ie.dynamicExpMax("temp"))
# Out:
# (14.20340463585978, 11.911090727297022, 12.190483111797988, 12.031555626094853, 12.004198563223472, 12.008870939724428, 12.007860681770776, 12.007688128877898, 12.007727248106775)

# %%
fig=figure()
ax=fig.add_subplot(111)
ax.fill_between(range(9),ie.dynamicExpMax("temp"),ie.dynamicExpMin("temp"))

# %%
ie=gum.CNMonteCarloSampling(cn)
ie.insertModalsFile("../resources/cn/modalities.modal")

ie.setRepetitiveInd(False)
ie.setMaxTime(30)
ie.setMaxIter(1000)

ie.makeInference()

# %%
fig=figure()
ax=fig.add_subplot(111)
ax.fill_between(range(9),ie.dynamicExpMax("temp"),ie.dynamicExpMin("temp"))

# %%
ie=gum.CNMonteCarloSampling(cn)
ie.insertModalsFile("../resources/cn/modalities.modal")

ie.setRepetitiveInd(False)
ie.setMaxTime(30)
ie.setMaxIter(1000)

gnb.animApproximationScheme(ie)
ie.makeInference()

fig=figure()
ax=fig.add_subplot(111)
ax.fill_between(range(9),ie.dynamicExpMax("temp"),ie.dynamicExpMin("temp"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-6458c3e220af> in <module>()
#       6 ie.setMaxIter(1000)
#       7
# ----> 8 gnb.animApproximationScheme(ie)
#       9 ie.makeInference()
#      10
#
# /home/phw/usr/lib/python3.5/site-packages/pyAgrum/lib/notebook.py in animApproximationScheme(apsc, scale)
#     134   f=plt.gcf()
#     135
# --> 136   h=gum.PythonApproximationListener(apsc)
#     137   apsc.setVerbosity(True)
#     138   apsc.listener=h
#
# /home/phw/usr/lib/python3.5/site-packages/pyAgrum/pyAgrum.py in __init__(self, algo)
#     252     def __init__(self, algo: 'IApproximationSchemeConfiguration'):
#     253         """__init__(PythonApproximationListener self, IApproximationSchemeConfiguration algo) -> PythonApproximationListener"""
# --> 254         this = _pyAgrum.new_PythonApproximationListener(algo)
#     255         try:
#     256             self.this.append(this)
#
# TypeError: in method 'new_PythonApproximationListener', argument 1 of type 'gum::IApproximationSchemeConfiguration &'
