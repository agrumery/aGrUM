# %%
import sys
import numpy as np
import pyAgrum as gum
# %matplotlib inline
from pyAgrum.lib.bn2roc import showROC

# %%
bn=gum.loadBN("../resources/alarm.dsl")

# %%
# generateCSV from a BN 
import pyAgrum.lib.bn2csv as bn2csv
bn2csv.generateCSV(bn,"learn.csv",10000,True)
bn2csv.generateCSV(bn,"train.csv",1000,True)
# Out:
#  learn.csv : [ ############################################################### ] 100%earn.csv : [ #################################################               ] 77%
# Log2-Likelihood : -150525.14118656336
#
#  train.csv : [ ############################################################### ] 100%
# Log2-Likelihood : -14932.722000777088
# -14932.722000777088

# %% [markdown]
# # Learning a BN from learn.csv

# %%
# Learning a BN from the database
learner=gum.BNLearner("train.csv")

# # Hill-Climbing
learner.useGreedyHillClimbing()
bn2=learner.learnBN()
bn2.setProperty("name","Learned_{0}s".format(learner.currentTime()))

# %%
import pyAgrum.lib.notebook as gnb
gnb.showBN(bn2,size="8",format="svg")
# Out:
# <svg height="576pt" viewBox="0.00 0.00 523.44 576.00" width="523pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.547529 0.547529) rotate(0) translate(4 1048)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-1048 952,-1048 952,4 -4,4" stroke="none"/>
# <!-- ANAPHYLAXIS -->
# <g class="node" id="node1"><title>ANAPHYLAXIS</title>
# <g id="a_node1"><a xlink:title="(0) ANAPHYLAXIS">
# <ellipse cx="380" cy="-522" fill="#444444" rx="76.0865" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="380" y="-518.3">ANAPHYLAXIS</text>
# </a>
# </g>
# </g>
# <!-- TPR -->
# <g class="node" id="node2"><title>TPR</title>
# <g id="a_node2"><a xlink:title="(1) TPR">
# <ellipse cx="377" cy="-450" fill="#444444" rx="27.8951" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="377" y="-446.3">TPR</text>
# </a>
# </g>
# </g>
# <!-- ANAPHYLAXIS&#45;&gt;TPR -->
# <g class="edge" id="edge17"><title>ANAPHYLAXIS-&gt;TPR</title>
# <g id="a_edge17"><a xlink:title="(0, 1) : ">
# <path d="M379.258,-503.697C378.928,-495.983 378.531,-486.712 378.162,-478.112" fill="none" stroke="black"/>
# <polygon fill="black" points="381.658,-477.945 377.733,-468.104 374.665,-478.245 381.658,-477.945" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- BP -->
# <g class="node" id="node33"><title>BP</title>
# <g id="a_node33"><a xlink:title="(32) BP">
# <ellipse cx="418" cy="-378" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="418" y="-374.3">BP</text>
# </a>
# </g>
# </g>
# <!-- TPR&#45;&gt;BP -->
# <g class="edge" id="edge18"><title>TPR-&gt;BP</title>
# <g id="a_edge18"><a xlink:title="(1, 32) : ">
# <path d="M386.509,-432.765C391.529,-424.195 397.796,-413.494 403.415,-403.9" fill="none" stroke="black"/>
# <polygon fill="black" points="406.508,-405.545 408.542,-395.147 400.468,-402.007 406.508,-405.545" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- DISCONNECT -->
# <g class="node" id="node3"><title>DISCONNECT</title>
# <g id="a_node3"><a xlink:title="(2) DISCONNECT">
# <ellipse cx="872" cy="-522" fill="#444444" rx="69.5877" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="872" y="-518.3">DISCONNECT</text>
# </a>
# </g>
# </g>
# <!-- LVFAILURE -->
# <g class="node" id="node4"><title>LVFAILURE</title>
# <g id="a_node4"><a xlink:title="(3) LVFAILURE">
# <ellipse cx="590" cy="-306" fill="#444444" rx="61.99" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="590" y="-302.3">LVFAILURE</text>
# </a>
# </g>
# </g>
# <!-- HISTORY -->
# <g class="node" id="node5"><title>HISTORY</title>
# <g id="a_node5"><a xlink:title="(4) HISTORY">
# <ellipse cx="668" cy="-234" fill="#444444" rx="50.0912" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="668" y="-230.3">HISTORY</text>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;HISTORY -->
# <g class="edge" id="edge2"><title>LVFAILURE-&gt;HISTORY</title>
# <g id="a_edge2"><a xlink:title="(3, 4) : ">
# <path d="M608.091,-288.765C618.402,-279.511 631.483,-267.772 642.788,-257.626" fill="none" stroke="black"/>
# <polygon fill="black" points="645.171,-260.19 650.276,-250.906 640.496,-254.98 645.171,-260.19" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- HYPOVOLEMIA -->
# <g class="node" id="node17"><title>HYPOVOLEMIA</title>
# <g id="a_node17"><a xlink:title="(16) HYPOVOLEMIA">
# <ellipse cx="483" cy="-234" fill="#444444" rx="78.7863" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="483" y="-230.3">HYPOVOLEMIA</text>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;HYPOVOLEMIA -->
# <g class="edge" id="edge36"><title>LVFAILURE-&gt;HYPOVOLEMIA</title>
# <g id="a_edge36"><a xlink:title="(3, 16) : ">
# <path d="M565.987,-289.291C551.326,-279.7 532.37,-267.298 516.276,-256.769" fill="none" stroke="black"/>
# <polygon fill="black" points="517.959,-253.688 507.675,-251.142 514.127,-259.546 517.959,-253.688" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- LVEDVOLUME -->
# <g class="node" id="node19"><title>LVEDVOLUME</title>
# <g id="a_node19"><a xlink:title="(18) LVEDVOLUME">
# <ellipse cx="483" cy="-162" fill="#444444" rx="74.187" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="483" y="-158.3">LVEDVOLUME</text>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;LVEDVOLUME -->
# <g class="edge" id="edge1"><title>LVFAILURE-&gt;LVEDVOLUME</title>
# <g id="a_edge1"><a xlink:title="(3, 18) : ">
# <path d="M590.263,-287.998C589.738,-268.811 586.32,-237.482 571,-216 560.881,-201.811 545.665,-190.732 530.717,-182.456" fill="none" stroke="black"/>
# <polygon fill="black" points="531.98,-179.168 521.493,-177.662 528.753,-185.379 531.98,-179.168" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- FIO2 -->
# <g class="node" id="node6"><title>FIO2</title>
# <g id="a_node6"><a xlink:title="(5) FIO2">
# <ellipse cx="106" cy="-738" fill="#444444" rx="30.5947" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="106" y="-734.3">FIO2</text>
# </a>
# </g>
# </g>
# <!-- PVSAT -->
# <g class="node" id="node28"><title>PVSAT</title>
# <g id="a_node28"><a xlink:title="(27) PVSAT">
# <ellipse cx="106" cy="-666" fill="#444444" rx="40.0939" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="106" y="-662.3">PVSAT</text>
# </a>
# </g>
# </g>
# <!-- FIO2&#45;&gt;PVSAT -->
# <g class="edge" id="edge44"><title>FIO2-&gt;PVSAT</title>
# <g id="a_edge44"><a xlink:title="(5, 27) : ">
# <path d="M106,-719.697C106,-711.983 106,-702.712 106,-694.112" fill="none" stroke="black"/>
# <polygon fill="black" points="109.5,-694.104 106,-684.104 102.5,-694.104 109.5,-694.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- ERRCAUTER -->
# <g class="node" id="node7"><title>ERRCAUTER</title>
# <g id="a_node7"><a xlink:title="(6) ERRCAUTER">
# <ellipse cx="687" cy="-738" fill="#444444" rx="65.7887" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="687" y="-734.3">ERRCAUTER</text>
# </a>
# </g>
# </g>
# <!-- HR -->
# <g class="node" id="node31"><title>HR</title>
# <g id="a_node31"><a xlink:title="(30) HR">
# <ellipse cx="590" cy="-522" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="590" y="-518.3">HR</text>
# </a>
# </g>
# </g>
# <!-- ERRCAUTER&#45;&gt;HR -->
# <g class="edge" id="edge45"><title>ERRCAUTER-&gt;HR</title>
# <g id="a_edge45"><a xlink:title="(6, 30) : ">
# <path d="M624.995,-732.088C592.533,-725.995 555.393,-712.707 535,-684 525.734,-670.956 528.981,-662.825 535,-648 543.394,-627.324 559.376,-631.624 570,-612 580.399,-592.791 585.398,-568.445 587.797,-550.074" fill="none" stroke="black"/>
# <polygon fill="black" points="591.287,-550.361 588.931,-540.032 584.331,-549.576 591.287,-550.361" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- HRSAT -->
# <g class="node" id="node34"><title>HRSAT</title>
# <g id="a_node34"><a xlink:title="(33) HRSAT">
# <ellipse cx="765" cy="-666" fill="#444444" rx="40.8928" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="765" y="-662.3">HRSAT</text>
# </a>
# </g>
# </g>
# <!-- ERRCAUTER&#45;&gt;HRSAT -->
# <g class="edge" id="edge24"><title>ERRCAUTER-&gt;HRSAT</title>
# <g id="a_edge24"><a xlink:title="(6, 33) : ">
# <path d="M705.485,-720.411C715.88,-711.082 728.994,-699.313 740.264,-689.199" fill="none" stroke="black"/>
# <polygon fill="black" points="742.612,-691.795 747.716,-682.511 737.936,-686.585 742.612,-691.795" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- ERRLOWOUTPUT -->
# <g class="node" id="node8"><title>ERRLOWOUTPUT</title>
# <g id="a_node8"><a xlink:title="(7) ERRLOWOUTPUT">
# <ellipse cx="760" cy="-450" fill="#444444" rx="87.1846" ry="18" stroke="black"/>
# <text fill="

# %%
print(bn2.names())
# Out:
# ['ANAPHYLAXIS', 'TPR', 'DISCONNECT', 'LVFAILURE', 'HISTORY', 'FIO2', 'ERRCAUTER', 'ERRLOWOUTPUT', 'INSUFFANESTH', 'PULMEMBOLUS', 'PAP', 'MINVOLSET', 'VENTMACH', 'VENTTUBE', 'INTUBATION', 'SHUNT', 'HYPOVOLEMIA', 'STROKEVOLUME', 'LVEDVOLUME', 'PCWP', 'CVP', 'KINKEDTUBE', 'VENTLUNG', 'MINVOL', 'VENTALV', 'ARTCO2', 'EXPCO2', 'PVSAT', 'SAO2', 'CATECHOL', 'HR', 'CO', 'BP', 'HRSAT', 'HREKG', 'HRBP', 'PRESS']

# %%
gnb.showInference(bn2,evs={},size="12")

# %% [markdown]
# # Two classifiers from the learned BN

# %%
print(bn2.variableFromName("HRSAT"))
print(bn2.variableFromName("INTUBATION"))
# Out:
# HRSAT<2,0,1>
# INTUBATION<0,1,2>

# %%
showROC(bn2,"train.csv",'HRSAT',"2",True,True)
# Out:
#  train.csv : [ ############################################################### ] 100%
#  result in roc_Learned_2.26666605s-train.csv-HRSAT-2.png

# %%
showROC(bn2,"train.csv",'INTUBATION',"0",True,True)
# Out:
#  train.csv : [ ############################################################### ] 100%
#  result in roc_Learned_2.26666605s-train.csv-INTUBATION-0.png
