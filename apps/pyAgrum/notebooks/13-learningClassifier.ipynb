# %%
import sys
import numpy as np
import pyAgrum as gum
# %matplotlib inline
from pyAgrum.lib.bn2roc import showROC

# %%
bn=gum.loadBN("../resources/alarm.dsl")

# %%
# generateCSV from a BN 
import pyAgrum.lib.bn2csv as bn2csv
bn2csv.generateCSV(bn,"learn.csv",10000,True)
bn2csv.generateCSV(bn,"train.csv",1000,True)
# Out:
#  learn.csv : [ ############################################################### ] 100%
# Log2-Likelihood : -151517.27045190416
#
#  train.csv : [ ############################################################### ] 100%
# Log2-Likelihood : -15352.214233277973
# -15352.214233277973

# %% [markdown]
# # Learning a BN from learn.csv

# %%
# Learning a BN from the database
learner=gum.BNLearner("train.csv")

# # Hill-Climbing
learner.useGreedyHillClimbing()
bn2=learner.learnBN()
bn2.setProperty("name","Learned_{0}s".format(learner.currentTime()))

# %%
import pyAgrum.lib.notebook as gnb
gnb.showBN(bn2,size="8",format="svg")
# Out:
# <svg height="351pt" viewBox="0.00 0.00 576.00 351.25" width="576pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.459753 0.459753) rotate(0) translate(4 760)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-760 1248.85,-760 1248.85,4 -4,4" stroke="none"/>
# <!-- ANAPHYLAXIS -->
# <g class="node" id="node1"><title>ANAPHYLAXIS</title>
# <g id="a_node1"><a xlink:title="(0) ANAPHYLAXIS">
# <ellipse cx="101" cy="-234" fill="#444444" rx="73.387" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="101" y="-230.3">ANAPHYLAXIS</text>
# </a>
# </g>
# </g>
# <!-- TPR -->
# <g class="node" id="node2"><title>TPR</title>
# <g id="a_node2"><a xlink:title="(1) TPR">
# <ellipse cx="107" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="107" y="-158.3">TPR</text>
# </a>
# </g>
# </g>
# <!-- ANAPHYLAXIS&#45;&gt;TPR -->
# <g class="edge" id="edge16"><title>ANAPHYLAXIS-&gt;TPR</title>
# <g id="a_edge16"><a xlink:title="(0, 1) : ">
# <path d="M102.483,-215.697C103.144,-207.983 103.939,-198.712 104.676,-190.112" fill="none" stroke="black"/>
# <polygon fill="black" points="108.167,-190.367 105.534,-180.104 101.193,-189.769 108.167,-190.367" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- BP -->
# <g class="node" id="node33"><title>BP</title>
# <g id="a_node33"><a xlink:title="(32) BP">
# <ellipse cx="119" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="119" y="-86.3">BP</text>
# </a>
# </g>
# </g>
# <!-- TPR&#45;&gt;BP -->
# <g class="edge" id="edge17"><title>TPR-&gt;BP</title>
# <g id="a_edge17"><a xlink:title="(1, 32) : ">
# <path d="M109.905,-144.055C111.226,-136.346 112.824,-127.027 114.309,-118.364" fill="none" stroke="black"/>
# <polygon fill="black" points="117.798,-118.723 116.039,-108.275 110.899,-117.54 117.798,-118.723" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- DISCONNECT -->
# <g class="node" id="node3"><title>DISCONNECT</title>
# <g id="a_node3"><a xlink:title="(2) DISCONNECT">
# <ellipse cx="751" cy="-234" fill="#444444" rx="66.0889" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="751" y="-230.3">DISCONNECT</text>
# </a>
# </g>
# </g>
# <!-- ERRLOWOUTPUT -->
# <g class="node" id="node8"><title>ERRLOWOUTPUT</title>
# <g id="a_node8"><a xlink:title="(7) ERRLOWOUTPUT">
# <ellipse cx="749" cy="-162" fill="#444444" rx="83.3857" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="749" y="-158.3">ERRLOWOUTPUT</text>
# </a>
# </g>
# </g>
# <!-- DISCONNECT&#45;&gt;ERRLOWOUTPUT -->
# <g class="edge" id="edge19"><title>DISCONNECT-&gt;ERRLOWOUTPUT</title>
# <g id="a_edge19"><a xlink:title="(2, 7) : ">
# <path d="M750.506,-215.697C750.285,-207.983 750.02,-198.712 749.775,-190.112" fill="none" stroke="black"/>
# <polygon fill="black" points="753.273,-190 749.489,-180.104 746.276,-190.2 753.273,-190" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- LVFAILURE -->
# <g class="node" id="node4"><title>LVFAILURE</title>
# <g id="a_node4"><a xlink:title="(3) LVFAILURE">
# <ellipse cx="231" cy="-90" fill="#444444" rx="59.5901" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="231" y="-86.3">LVFAILURE</text>
# </a>
# </g>
# </g>
# <!-- HISTORY -->
# <g class="node" id="node5"><title>HISTORY</title>
# <g id="a_node5"><a xlink:title="(4) HISTORY">
# <ellipse cx="231" cy="-18" fill="#444444" rx="48.9926" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="231" y="-14.3">HISTORY</text>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;HISTORY -->
# <g class="edge" id="edge1"><title>LVFAILURE-&gt;HISTORY</title>
# <g id="a_edge1"><a xlink:title="(3, 4) : ">
# <path d="M231,-71.6966C231,-63.9827 231,-54.7125 231,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="234.5,-46.1043 231,-36.1043 227.5,-46.1044 234.5,-46.1043" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- FIO2 -->
# <g class="node" id="node6"><title>FIO2</title>
# <g id="a_node6"><a xlink:title="(5) FIO2">
# <ellipse cx="909" cy="-666" fill="#444444" rx="29.4969" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="909" y="-662.3">FIO2</text>
# </a>
# </g>
# </g>
# <!-- VENTALV -->
# <g class="node" id="node25"><title>VENTALV</title>
# <g id="a_node25"><a xlink:title="(24) VENTALV">
# <ellipse cx="909" cy="-594" fill="#444444" rx="51.9908" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="909" y="-590.3">VENTALV</text>
# </a>
# </g>
# </g>
# <!-- FIO2&#45;&gt;VENTALV -->
# <g class="edge" id="edge3"><title>FIO2-&gt;VENTALV</title>
# <g id="a_edge3"><a xlink:title="(5, 24) : ">
# <path d="M909,-647.697C909,-639.983 909,-630.712 909,-622.112" fill="none" stroke="black"/>
# <polygon fill="black" points="912.5,-622.104 909,-612.104 905.5,-622.104 912.5,-622.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- ERRCAUTER -->
# <g class="node" id="node7"><title>ERRCAUTER</title>
# <g id="a_node7"><a xlink:title="(6) ERRCAUTER">
# <ellipse cx="474" cy="-18" fill="#444444" rx="63.0888" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="474" y="-14.3">ERRCAUTER</text>
# </a>
# </g>
# </g>
# <!-- HRBP -->
# <g class="node" id="node36"><title>HRBP</title>
# <g id="a_node36"><a xlink:title="(35) HRBP">
# <ellipse cx="695" cy="-90" fill="#444444" rx="33.5952" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="695" y="-86.3">HRBP</text>
# </a>
# </g>
# </g>
# <!-- ERRLOWOUTPUT&#45;&gt;HRBP -->
# <g class="edge" id="edge12"><title>ERRLOWOUTPUT-&gt;HRBP</title>
# <g id="a_edge12"><a xlink:title="(7, 35) : ">
# <path d="M735.928,-144.055C729.168,-135.292 720.805,-124.451 713.403,-114.856" fill="none" stroke="black"/>
# <polygon fill="black" points="716.091,-112.609 707.211,-106.829 710.548,-116.885 716.091,-112.609" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- INSUFFANESTH -->
# <g class="node" id="node9"><title>INSUFFANESTH</title>
# <g id="a_node9"><a xlink:title="(8) INSUFFANESTH">
# <ellipse cx="554" cy="-378" fill="#444444" rx="75.2868" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="554" y="-374.3">INSUFFANESTH</text>
# </a>
# </g>
# </g>
# <!-- MINVOLSET -->
# <g class="node" id="node12"><title>MINVOLSET</title>
# <g id="a_node12"><a xlink:title="(11) MINVOLSET">
# <ellipse cx="598" cy="-234" fill="#444444" rx="61.99" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="598" y="-230.3">MINVOLSET</text>
# </a>
# </g>
# </g>
# <!-- INSUFFANESTH&#45;&gt;MINVOLSET -->
# <g class="edge" id="edge28"><title>INSUFFANESTH-&gt;MINVOLSET</title>
# <g id="a_edge28"><a xlink:title="(8, 11) : ">
# <path d="M559.307,-359.871C566.839,-335.564 580.704,-290.819 589.63,-262.013" fill="none" stroke="black"/>
# <polygon fill="black" points="593.057,-262.777 592.674,-252.189 586.371,-260.705 593.057,-262.777" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- KINKEDTUBE -->
# <g class="node" id="node22"><title>KINKEDTUBE</title>
# <g id="a_node22"><a xlink:title="(21) KINKEDTUBE">
# <ellipse cx="727" cy="-306" fill="#444444" rx="67.6881" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="727" y="-302.3">KINKEDTUBE</text>
# </a>
# </g>
# </g>
# <!-- INSUFFANESTH&#45;&gt;KINKEDTUBE -->
# <g class="edge" id="edge35"><title>INSUFFANESTH-&gt;KINKEDTUBE</title>
# <g id="a_edge35"><a xlink:title="(8, 21) : ">
# <path d="M590.689,-362.155C617.422,-351.338 653.785,-336.625 682.23,-325.115" fill="none" stroke="black"/>
# <polygon fill="black" points="683.59,-328.34 691.547,-321.345 680.965,-321.851 683.59,-328.34" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- CATECH

# %%
print(bn2.names())
# Out:
# ['ANAPHYLAXIS', 'TPR', 'DISCONNECT', 'LVFAILURE', 'HISTORY', 'FIO2', 'ERRCAUTER', 'ERRLOWOUTPUT', 'INSUFFANESTH', 'PULMEMBOLUS', 'PAP', 'MINVOLSET', 'VENTMACH', 'VENTTUBE', 'INTUBATION', 'SHUNT', 'HYPOVOLEMIA', 'STROKEVOLUME', 'LVEDVOLUME', 'PCWP', 'CVP', 'KINKEDTUBE', 'VENTLUNG', 'MINVOL', 'VENTALV', 'ARTCO2', 'EXPCO2', 'PVSAT', 'SAO2', 'CATECHOL', 'HR', 'CO', 'BP', 'HRSAT', 'HREKG', 'HRBP', 'PRESS']

# %%
gnb.showInference(bn2,evs={},size="12")

# %% [markdown]
# # Two classifiers from the learned BN

# %%
print(bn2.variableFromName("HRSAT"))
print(bn2.variableFromName("INTUBATION"))
# Out:
# HRSAT<2,0,1>
# INTUBATION<0,1,2>

# %%
showROC(bn2,"train.csv",'HRSAT',"2",True,True)
# Out:
#  train.csv : [ ############################################################### ] 100%
#  result in roc_Learned_1.219987873s-train.csv-HRSAT-2.png

# %%
showROC(bn2,"train.csv",'INTUBATION',"0",True,True)
# Out:
#  train.csv : [ ############################################################### ] 100%
#  result in roc_Learned_1.219987873s-train.csv-INTUBATION-0.png
