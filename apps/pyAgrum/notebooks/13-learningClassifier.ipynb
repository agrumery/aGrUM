# %%
import sys
import numpy as np
import pyAgrum as gum
# %matplotlib inline
from pyAgrum.lib.bn2roc import showROC

# %%
bn=gum.loadBN("../resources/alarm.dsl")

# %%
# generateCSV from a BN 
import pyAgrum.lib.bn2csv as bn2csv
bn2csv.generateCSV(bn,"learn.csv",10000,True)
bn2csv.generateCSV(bn,"train.csv",1000,True)
# Out:
#  learn.csv : [ ############################################################### ] 100%
# Log2-Likelihood : -151782.0674314763
#
#  train.csv : [ ############################################################### ] 100%
# Log2-Likelihood : -15595.418341440227
# -15595.418341440227

# %% [markdown]
# # Learning a BN from learn.csv

# %%
# Learning a BN from the database
learner=gum.BNLearner("train.csv")

# # Hill-Climbing
learner.useGreedyHillClimbing()
bn2=learner.learnBN()
bn2.setProperty("name","Learned_{0}s".format(learner.currentTime()))

# %%
import pyAgrum.lib.notebook as gnb
gnb.showBN(bn2,size="8",format="svg")
# Out:
# <svg height="576pt" viewBox="0.00 0.00 441.26 576.00" width="441pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.454259 0.454259) rotate(0) translate(4 1264)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-1264 967.393,-1264 967.393,4 -4,4" stroke="none"/>
# <!-- ANAPHYLAXIS -->
# <g class="node" id="node1"><title>ANAPHYLAXIS</title>
# <g id="a_node1"><a xlink:title="(0) ANAPHYLAXIS">
# <ellipse cx="653" cy="-378" fill="#444444" rx="73.387" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="653" y="-374.3">ANAPHYLAXIS</text>
# </a>
# </g>
# </g>
# <!-- HYPOVOLEMIA -->
# <g class="node" id="node17"><title>HYPOVOLEMIA</title>
# <g id="a_node17"><a xlink:title="(16) HYPOVOLEMIA">
# <ellipse cx="761" cy="-306" fill="#444444" rx="75.2868" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="761" y="-302.3">HYPOVOLEMIA</text>
# </a>
# </g>
# </g>
# <!-- ANAPHYLAXIS&#45;&gt;HYPOVOLEMIA -->
# <g class="edge" id="edge22"><title>ANAPHYLAXIS-&gt;HYPOVOLEMIA</title>
# <g id="a_edge22"><a xlink:title="(0, 16) : ">
# <path d="M677.777,-360.941C692.49,-351.405 711.344,-339.184 727.386,-328.787" fill="none" stroke="black"/>
# <polygon fill="black" points="729.476,-331.603 735.964,-323.227 725.669,-325.729 729.476,-331.603" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- TPR -->
# <g class="node" id="node2"><title>TPR</title>
# <g id="a_node2"><a xlink:title="(1) TPR">
# <ellipse cx="653" cy="-450" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="653" y="-446.3">TPR</text>
# </a>
# </g>
# </g>
# <!-- TPR&#45;&gt;ANAPHYLAXIS -->
# <g class="edge" id="edge21"><title>TPR-&gt;ANAPHYLAXIS</title>
# <g id="a_edge21"><a xlink:title="(1, 0) : ">
# <path d="M653,-431.697C653,-423.983 653,-414.712 653,-406.112" fill="none" stroke="black"/>
# <polygon fill="black" points="656.5,-406.104 653,-396.104 649.5,-406.104 656.5,-406.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- BP -->
# <g class="node" id="node33"><title>BP</title>
# <g id="a_node33"><a xlink:title="(32) BP">
# <ellipse cx="771" cy="-378" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="771" y="-374.3">BP</text>
# </a>
# </g>
# </g>
# <!-- TPR&#45;&gt;BP -->
# <g class="edge" id="edge12"><title>TPR-&gt;BP</title>
# <g id="a_edge12"><a xlink:title="(1, 32) : ">
# <path d="M672.485,-437.441C691.616,-426.092 721.004,-408.658 742.707,-395.784" fill="none" stroke="black"/>
# <polygon fill="black" points="744.671,-398.689 751.486,-390.576 741.099,-392.668 744.671,-398.689" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- DISCONNECT -->
# <g class="node" id="node3"><title>DISCONNECT</title>
# <g id="a_node3"><a xlink:title="(2) DISCONNECT">
# <ellipse cx="281" cy="-1170" fill="#444444" rx="66.0889" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="281" y="-1166.3">DISCONNECT</text>
# </a>
# </g>
# </g>
# <!-- VENTTUBE -->
# <g class="node" id="node14"><title>VENTTUBE</title>
# <g id="a_node14"><a xlink:title="(13) VENTTUBE">
# <ellipse cx="239" cy="-1098" fill="#444444" rx="57.3905" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="239" y="-1094.3">VENTTUBE</text>
# </a>
# </g>
# </g>
# <!-- DISCONNECT&#45;&gt;VENTTUBE -->
# <g class="edge" id="edge30"><title>DISCONNECT-&gt;VENTTUBE</title>
# <g id="a_edge30"><a xlink:title="(2, 13) : ">
# <path d="M270.833,-1152.05C265.88,-1143.8 259.821,-1133.7 254.323,-1124.54" fill="none" stroke="black"/>
# <polygon fill="black" points="257.22,-1122.56 249.073,-1115.79 251.217,-1126.16 257.22,-1122.56" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- VENTLUNG -->
# <g class="node" id="node23"><title>VENTLUNG</title>
# <g id="a_node23"><a xlink:title="(22) VENTLUNG">
# <ellipse cx="239" cy="-1026" fill="#444444" rx="58.4896" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="239" y="-1022.3">VENTLUNG</text>
# </a>
# </g>
# </g>
# <!-- DISCONNECT&#45;&gt;VENTLUNG -->
# <g class="edge" id="edge24"><title>DISCONNECT-&gt;VENTLUNG</title>
# <g id="a_edge24"><a xlink:title="(2, 22) : ">
# <path d="M292.468,-1151.95C303.306,-1133.54 316.347,-1103.67 305,-1080 298.711,-1066.88 287.42,-1055.99 275.934,-1047.56" fill="none" stroke="black"/>
# <polygon fill="black" points="277.833,-1044.61 267.604,-1041.85 273.879,-1050.39 277.833,-1044.61" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- LVFAILURE -->
# <g class="node" id="node4"><title>LVFAILURE</title>
# <g id="a_node4"><a xlink:title="(3) LVFAILURE">
# <ellipse cx="888" cy="-162" fill="#444444" rx="59.5901" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="888" y="-158.3">LVFAILURE</text>
# </a>
# </g>
# </g>
# <!-- HISTORY -->
# <g class="node" id="node5"><title>HISTORY</title>
# <g id="a_node5"><a xlink:title="(4) HISTORY">
# <ellipse cx="888" cy="-90" fill="#444444" rx="48.9926" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="888" y="-86.3">HISTORY</text>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;HISTORY -->
# <g class="edge" id="edge1"><title>LVFAILURE-&gt;HISTORY</title>
# <g id="a_edge1"><a xlink:title="(3, 4) : ">
# <path d="M888,-143.697C888,-135.983 888,-126.712 888,-118.112" fill="none" stroke="black"/>
# <polygon fill="black" points="891.5,-118.104 888,-108.104 884.5,-118.104 891.5,-118.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- PRESS -->
# <g class="node" id="node37"><title>PRESS</title>
# <g id="a_node37"><a xlink:title="(36) PRESS">
# <ellipse cx="330" cy="-90" fill="#444444" rx="36.2938" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="330" y="-86.3">PRESS</text>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;PRESS -->
# <g class="edge" id="edge47"><title>LVFAILURE-&gt;PRESS</title>
# <g id="a_edge47"><a xlink:title="(3, 36) : ">
# <path d="M844.755,-149.409C836.26,-147.397 827.383,-145.48 819,-144 657.385,-115.464 462.829,-99.9032 375.878,-93.9185" fill="none" stroke="black"/>
# <polygon fill="black" points="376.031,-90.4209 365.817,-93.2359 375.557,-97.4049 376.031,-90.4209" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- INSUFFANESTH -->
# <g class="node" id="node9"><title>INSUFFANESTH</title>
# <g id="a_node9"><a xlink:title="(8) INSUFFANESTH">
# <ellipse cx="888" cy="-18" fill="#444444" rx="75.2868" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="888" y="-14.3">INSUFFANESTH</text>
# </a>
# </g>
# </g>
# <!-- HISTORY&#45;&gt;INSUFFANESTH -->
# <g class="edge" id="edge13"><title>HISTORY-&gt;INSUFFANESTH</title>
# <g id="a_edge13"><a xlink:title="(4, 8) : ">
# <path d="M888,-71.6966C888,-63.9827 888,-54.7125 888,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="891.5,-46.1043 888,-36.1043 884.5,-46.1044 891.5,-46.1043" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- FIO2 -->
# <g class="node" id="node6"><title>FIO2</title>
# <g id="a_node6"><a xlink:title="(5) FIO2">
# <ellipse cx="447" cy="-954" fill="#444444" rx="29.4969" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="447" y="-950.3">FIO2</text>
# </a>
# </g>
# </g>
# <!-- PVSAT -->
# <g class="node" id="node28"><title>PVSAT</title>
# <g id="a_node28"><a xlink:title="(27) PVSAT">
# <ellipse cx="427" cy="-882" fill="#444444" rx="38.1938" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="427" y="-878.3">PVSAT</text>
# </a>
# </g>
# </g>
# <!-- FIO2&#45;&gt;PVSAT -->
# <g class="edge" id="edge38"><title>FIO2-&gt;PVSAT</title>
# <g id="a_edge38"><a xlink:title="(5, 27) : ">
# <path d="M442.159,-936.055C439.932,-928.261 437.235,-918.822 434.737,-910.079" fill="none" stroke="black"/>
# <polygon fill="black" points="438.048,-9

# %%
print(bn2.names())
# Out:
# ['ANAPHYLAXIS', 'TPR', 'DISCONNECT', 'LVFAILURE', 'HISTORY', 'FIO2', 'ERRCAUTER', 'ERRLOWOUTPUT', 'INSUFFANESTH', 'PULMEMBOLUS', 'PAP', 'MINVOLSET', 'VENTMACH', 'VENTTUBE', 'INTUBATION', 'SHUNT', 'HYPOVOLEMIA', 'STROKEVOLUME', 'LVEDVOLUME', 'PCWP', 'CVP', 'KINKEDTUBE', 'VENTLUNG', 'MINVOL', 'VENTALV', 'ARTCO2', 'EXPCO2', 'PVSAT', 'SAO2', 'CATECHOL', 'HR', 'CO', 'BP', 'HRSAT', 'HREKG', 'HRBP', 'PRESS']

# %%
gnb.showInference(bn2,evs={},size="12")

# %% [markdown]
# # Two classifiers from the learned BN

# %%
print(bn2.variableFromName("HRSAT"))
print(bn2.variableFromName("INTUBATION"))
# Out:
# HRSAT<2,1,0>
# INTUBATION<0,2,1>

# %%
showROC(bn2,"train.csv",'HRSAT',"2",True,True)
# Out:
#  train.csv : [ ############################################################### ] 100%
#  result in roc_Learned_1.415903144s-train.csv-HRSAT-2.png

# %%
showROC(bn2,"train.csv",'INTUBATION',"0",True,True)
# Out:
#  train.csv : [ ############################################################### ] 100%
#  result in roc_Learned_1.415903144s-train.csv-INTUBATION-0.png
