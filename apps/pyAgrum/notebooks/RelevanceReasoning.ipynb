# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %%
bn=gum.fastBN("Y->X->T1;Z2->X;Z1->X;Z1->T1;Z1->Z3->T2")
ie=gum.LazyPropagation(bn)

gnb.sideBySide(bn,
               bn.cpt("X"),
               gnb.getJunctionTree(bn),
               captions=["BN","potential","Junction Tree"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="#ffffff" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="transparent"/>
# <!-- Y -->
# <g class="node" id="node1">
# <title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-157.8">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2">
# <title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-85.8">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1">
# <title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M42.2693,-146.7307C52.197,-136.803 65.3153,-123.6847 76.4363,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="79.1564,-114.7933 83.7527,-105.2473 74.2067,-109.8436 79.1564,-114.7933" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3">
# <title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-13.8">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6">
# <title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.6966,-72.2022C105.7976,-64.2406 108.324,-54.6671 110.665,-45.7957" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="114.1241,-46.4046 113.2916,-35.8425 107.3558,-44.6185 114.1241,-46.4046" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4">
# <title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-157.8">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3">
# <title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.8314C99,-136.131 99,-126.9743 99,-118.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="102.5001,-118.4132 99,-108.4133 95.5001,-118.4133 102.5001,-118.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5">
# <title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-157.8">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4">
# <title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M155.7307,-146.7307C145.803,-136.803 132.6847,-123.6847 121.5637,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="123.7933,-109.8436 114.2473,-105.2473 118.8436,-114.7933 123.7933,-109.8436" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7">
# <title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.5012,-144.3428C155.4019,-119.6202 138.7807,-74.4608 128.0714,-45.3639" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="131.2907,-43.9773 124.552,-35.8017 124.7215,-46.3951 131.2907,-43.9773" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6">
# <title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-85.8">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5">
# <title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M180.0055,-144.937C184.4828,-136.4537 189.9952,-126.0092 195.007,-116.513" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="198.2229,-117.9182 199.7952,-107.4407 192.0322,-114.6509 198.2229,-117.9182" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7">
# <title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-13.8">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2">
# <title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.8314C209,-64.131 209,-54.9743 209,-46.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="212.5001,-46.4132 209,-36.4133 205.5001,-46.4133 212.5001,-46.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table>
# <tr><th colspan='3'></th><th colspan='2' style='background-color:#AAAAAA'><center>X</center></th></tr>
# <tr><th style='background-color:#AAAAAA'><center>Y</center></th><th style='background-color:#AAAAAA'><center>Z2</center></th><th style='background-color:#AAAAAA'><center>Z1</center></th><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='background-color:#BBBBBB'>0</th><th style='background-color:#BBBBBB;' rowspan = '2'>0</th><th style='background-color:#BBBBBB;' rowspan = '4'>0</th><td style='background-color:#e89564;text-align:right;'>0.1777</td><td style='background-color:#95e864;text-align:right;'>0.8223</td></tr>
# <tr><th style='background-color:#BBBBBB'>1</th><td style='background-color:#c1bc64;text-align:right;'>0.4801</td><td style='background-color:#bcc164;text-align:right;'>0.5199</td></tr>
# <tr><th style='background-color:#BBBBBB'>0</th><th style='background-color:#BBBBBB;' rowspan = '2'>1</th><td style='background-color:#d4a964;text-align:right;'>0.3358</td><td style='background-color:#a9d464;text-align:right;'>0.6642</td></tr>
# <tr><th style='background-color:#BBBBBB'>1</th><td style='background-color:#fd8064;text-align:right;'>0.0089</td><td style='background-color:#80fd64;text-align:right;'>0.9911</td></tr>
# <tr><th style='background-color:#BBBBBB'>0</th><th style='background-color:#BBBBBB;' rowspan = '2'>0</th><th style='background-color:#BBBBBB;' rowspan = '4'>1</th><td style='background-color:#85f864;text-align:right;'>0.9492</td><td style='background-color:#f88564;text-align:right;'>0.0508</td></tr>
# <tr><th style='background-color:#BBBBBB'>1</th><td style='background-color:#c8b564;text-align:right;'>0.4220</td><td style='background-color:#b5c864;text-align:right;'>0.5780</td></tr>
# <tr><th style='background-color:#BBBBBB'>0</th><th style='background-color:#BBBBBB;' rowspan = '2'>1</th><td style='background-color:#df9e64;text-align:right;'>0.2460</td><td style='background-color:#9edf64;text-align:right;'>0.7540</td></tr>
# <tr><th style='background-color:#BBBBBB'>1</th><td style='background-color:#bbc264;text-align:right;'>0.5296</td><td style='background-color:#c2bb64;text-align:right;'>0.4704</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="...

# %% [markdown]
# <h3>aGrUM/pyAgrum use as much as possible techniques of relevance reasonning to reduce the complexity of the inference.</h3>

# %%
ie.setEvidence({"X":0})
gnb.sideBySide(ie,gnb.getDot(ie.joinTree().toDotWithNames(bn)),
               captions=["","Join tree optimized for hard evidence on X"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="#ffffff" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="transparent"/>
# <!-- Y -->
# <g class="node" id="node1">
# <title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-157.8">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2">
# <title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-85.8">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1">
# <title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M42.2693,-146.7307C52.197,-136.803 65.3153,-123.6847 76.4363,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="79.1564,-114.7933 83.7527,-105.2473 74.2067,-109.8436 79.1564,-114.7933" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3">
# <title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-13.8">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6">
# <title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.6966,-72.2022C105.7976,-64.2406 108.324,-54.6671 110.665,-45.7957" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="114.1241,-46.4046 113.2916,-35.8425 107.3558,-44.6185 114.1241,-46.4046" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4">
# <title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-157.8">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3">
# <title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.8314C99,-136.131 99,-126.9743 99,-118.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="102.5001,-118.4132 99,-108.4133 95.5001,-118.4133 102.5001,-118.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5">
# <title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-157.8">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4">
# <title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M155.7307,-146.7307C145.803,-136.803 132.6847,-123.6847 121.5637,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="123.7933,-109.8436 114.2473,-105.2473 118.8436,-114.7933 123.7933,-109.8436" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7">
# <title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.5012,-144.3428C155.4019,-119.6202 138.7807,-74.4608 128.0714,-45.3639" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="131.2907,-43.9773 124.552,-35.8017 124.7215,-46.3951 131.2907,-43.9773" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6">
# <title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-85.8">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5">
# <title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M180.0055,-144.937C184.4828,-136.4537 189.9952,-126.0092 195.007,-116.513" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="198.2229,-117.9182 199.7952,-107.4407 192.0322,-114.6509 198.2229,-117.9182" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7">
# <title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-13.8">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2">
# <title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.8314C209,-64.131 209,-54.9743 209,-46.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="212.5001,-46.4132 209,-36.4133 205.5001,-46.4133 212.5001,-46.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><div align="left"><ul><li><b>hard evidence</b><br/>X</li><li><b>target(s)</b><br/> all</li></ul></div></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Lazy Propagation on this BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Evidence and targets</small></div></td></tr></table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small></small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Join tree optimized for hard evidence on X</small></div></td></tr></table>

# %%
ie.updateEvidence({"X":[0.1,0.9]})
gnb.sideBySide(ie,gnb.getDot(ie.joinTree().toDotWithNames(bn)),
               captions=["","Join tree optimized for soft evidence on X"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="#ffffff" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="transparent"/>
# <!-- Y -->
# <g class="node" id="node1">
# <title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-157.8">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2">
# <title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-85.8">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1">
# <title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M42.2693,-146.7307C52.197,-136.803 65.3153,-123.6847 76.4363,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="79.1564,-114.7933 83.7527,-105.2473 74.2067,-109.8436 79.1564,-114.7933" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3">
# <title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-13.8">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6">
# <title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.6966,-72.2022C105.7976,-64.2406 108.324,-54.6671 110.665,-45.7957" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="114.1241,-46.4046 113.2916,-35.8425 107.3558,-44.6185 114.1241,-46.4046" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4">
# <title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-157.8">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3">
# <title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.8314C99,-136.131 99,-126.9743 99,-118.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="102.5001,-118.4132 99,-108.4133 95.5001,-118.4133 102.5001,-118.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5">
# <title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-157.8">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4">
# <title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M155.7307,-146.7307C145.803,-136.803 132.6847,-123.6847 121.5637,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="123.7933,-109.8436 114.2473,-105.2473 118.8436,-114.7933 123.7933,-109.8436" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7">
# <title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.5012,-144.3428C155.4019,-119.6202 138.7807,-74.4608 128.0714,-45.3639" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="131.2907,-43.9773 124.552,-35.8017 124.7215,-46.3951 131.2907,-43.9773" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6">
# <title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-85.8">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5">
# <title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M180.0055,-144.937C184.4828,-136.4537 189.9952,-126.0092 195.007,-116.513" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="198.2229,-117.9182 199.7952,-107.4407 192.0322,-114.6509 198.2229,-117.9182" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7">
# <title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-13.8">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2">
# <title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.8314C209,-64.131 209,-54.9743 209,-46.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="212.5001,-46.4132 209,-36.4133 205.5001,-46.4133 212.5001,-46.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><div align="left"><ul><li><b>soft evidence</b><br/>X</li><li><b>target(s)</b><br/> all</li></ul></div></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Lazy Propagation on this BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Evidence and targets</small></div></td></tr></table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small></small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Join tree optimized for soft evidence on X</small></div></td></tr></table>

# %%
ie.updateEvidence({"Y":0,"X":0,3:[0.1,0.9],"Z1":[0.4,0.6]})
gnb.sideBySide(ie,gnb.getDot(ie.joinTree().toDotWithNames(bn)),
               captions=["","Join tree optimized for hard evidence on X and Y, soft on Z2 and Z1"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="#ffffff" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="transparent"/>
# <!-- Y -->
# <g class="node" id="node1">
# <title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-157.8">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2">
# <title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-85.8">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1">
# <title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M42.2693,-146.7307C52.197,-136.803 65.3153,-123.6847 76.4363,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="79.1564,-114.7933 83.7527,-105.2473 74.2067,-109.8436 79.1564,-114.7933" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3">
# <title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-13.8">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6">
# <title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.6966,-72.2022C105.7976,-64.2406 108.324,-54.6671 110.665,-45.7957" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="114.1241,-46.4046 113.2916,-35.8425 107.3558,-44.6185 114.1241,-46.4046" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4">
# <title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-157.8">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3">
# <title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.8314C99,-136.131 99,-126.9743 99,-118.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="102.5001,-118.4132 99,-108.4133 95.5001,-118.4133 102.5001,-118.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5">
# <title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-157.8">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4">
# <title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M155.7307,-146.7307C145.803,-136.803 132.6847,-123.6847 121.5637,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="123.7933,-109.8436 114.2473,-105.2473 118.8436,-114.7933 123.7933,-109.8436" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7">
# <title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.5012,-144.3428C155.4019,-119.6202 138.7807,-74.4608 128.0714,-45.3639" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="131.2907,-43.9773 124.552,-35.8017 124.7215,-46.3951 131.2907,-43.9773" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6">
# <title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-85.8">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5">
# <title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M180.0055,-144.937C184.4828,-136.4537 189.9952,-126.0092 195.007,-116.513" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="198.2229,-117.9182 199.7952,-107.4407 192.0322,-114.6509 198.2229,-117.9182" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7">
# <title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-13.8">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2">
# <title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.8314C209,-64.131 209,-54.9743 209,-46.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="212.5001,-46.4132 209,-36.4133 205.5001,-46.4133 212.5001,-46.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><div align="left"><ul><li><b>hard evidence</b><br/>X, Y</li><li><b>soft evidence</b><br/>Z2, Z1</li><li><b>target(s)</b><br/> all</li></ul></div></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Lazy Propagation on this BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Evidence and targets</small></div></td></tr></table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="...

# %%
ie.setEvidence({"X":0})
ie.setTargets({"T1","Z1"})
gnb.sideBySide(ie,gnb.getDot(ie.joinTree().toDotWithNames(bn)),
               captions=["","Join tree optimized for hard evidence on X and targets T1,Z1"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="#ffffff" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="transparent"/>
# <!-- Y -->
# <g class="node" id="node1">
# <title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-157.8">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2">
# <title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-85.8">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1">
# <title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M42.2693,-146.7307C52.197,-136.803 65.3153,-123.6847 76.4363,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="79.1564,-114.7933 83.7527,-105.2473 74.2067,-109.8436 79.1564,-114.7933" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3">
# <title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-13.8">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6">
# <title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.6966,-72.2022C105.7976,-64.2406 108.324,-54.6671 110.665,-45.7957" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="114.1241,-46.4046 113.2916,-35.8425 107.3558,-44.6185 114.1241,-46.4046" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4">
# <title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-157.8">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3">
# <title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.8314C99,-136.131 99,-126.9743 99,-118.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="102.5001,-118.4132 99,-108.4133 95.5001,-118.4133 102.5001,-118.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5">
# <title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-157.8">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4">
# <title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M155.7307,-146.7307C145.803,-136.803 132.6847,-123.6847 121.5637,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="123.7933,-109.8436 114.2473,-105.2473 118.8436,-114.7933 123.7933,-109.8436" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7">
# <title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.5012,-144.3428C155.4019,-119.6202 138.7807,-74.4608 128.0714,-45.3639" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="131.2907,-43.9773 124.552,-35.8017 124.7215,-46.3951 131.2907,-43.9773" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6">
# <title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-85.8">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5">
# <title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M180.0055,-144.937C184.4828,-136.4537 189.9952,-126.0092 195.007,-116.513" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="198.2229,-117.9182 199.7952,-107.4407 192.0322,-114.6509 198.2229,-117.9182" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7">
# <title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-13.8">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2">
# <title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.8314C209,-64.131 209,-54.9743 209,-46.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="212.5001,-46.4132 209,-36.4133 205.5001,-46.4133 212.5001,-46.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><div align="left"><ul><li><b>hard evidence</b><br/>X</li><li><b>target(s)</b><br/>Z1, T1</li></ul></div></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Lazy Propagation on this BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Evidence and targets</small></div></td></tr></table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small></small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Join tree optimized for hard evidence on X and targets T1,Z1</small></div></td></tr></table>

# %%
ie.updateEvidence({"Y":0,"X":0,3:[0.1,0.9],"Z1":[0.4,0.6]})
ie.addJointTarget(["Z2","Z1","T1"])

gnb.sideBySide(ie,
               gnb.getDot(ie.joinTree().toDotWithNames(bn)),
               captions=["","Join tree optimized for hard evidence on X and targets T1,Z1"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="#ffffff" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="transparent"/>
# <!-- Y -->
# <g class="node" id="node1">
# <title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-157.8">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2">
# <title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-85.8">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1">
# <title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M42.2693,-146.7307C52.197,-136.803 65.3153,-123.6847 76.4363,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="79.1564,-114.7933 83.7527,-105.2473 74.2067,-109.8436 79.1564,-114.7933" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3">
# <title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-13.8">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6">
# <title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.6966,-72.2022C105.7976,-64.2406 108.324,-54.6671 110.665,-45.7957" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="114.1241,-46.4046 113.2916,-35.8425 107.3558,-44.6185 114.1241,-46.4046" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4">
# <title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-157.8">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3">
# <title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.8314C99,-136.131 99,-126.9743 99,-118.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="102.5001,-118.4132 99,-108.4133 95.5001,-118.4133 102.5001,-118.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5">
# <title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-157.8">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4">
# <title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M155.7307,-146.7307C145.803,-136.803 132.6847,-123.6847 121.5637,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="123.7933,-109.8436 114.2473,-105.2473 118.8436,-114.7933 123.7933,-109.8436" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7">
# <title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.5012,-144.3428C155.4019,-119.6202 138.7807,-74.4608 128.0714,-45.3639" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="131.2907,-43.9773 124.552,-35.8017 124.7215,-46.3951 131.2907,-43.9773" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6">
# <title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-85.8">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5">
# <title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M180.0055,-144.937C184.4828,-136.4537 189.9952,-126.0092 195.007,-116.513" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="198.2229,-117.9182 199.7952,-107.4407 192.0322,-114.6509 198.2229,-117.9182" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7">
# <title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-13.8">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2">
# <title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.8314C209,-64.131 209,-54.9743 209,-46.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="212.5001,-46.4132 209,-36.4133 205.5001,-46.4133 212.5001,-46.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><div align="left"><ul><li><b>hard evidence</b><br/>X, Y</li><li><b>soft evidence</b><br/>Z2, Z1</li><li><b>target(s)</b><br/>Z1, T1</li><li><b>Joint target(s)</b><br/>[Z2, Z1, T1]</li></ul></div></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Lazy Propagation on this BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Evidence and targets</small></div></td></tr></table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small></small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Join tree optimized for hard evidence on X and targets T1,Z1</small></div></td></tr></table>

# %%
ie.makeInference()
ie.jointPosterior(["Z2","Z1","T1"])
# Out:
# <pyAgrum.pyAgrum.Potential_double; proxy of <Swig Object of type 'gum::Potential< double > *' at 0x10f643b70> >

# %%
ie.jointPosterior(["Z2","Z1"])
# Out:
# <pyAgrum.pyAgrum.Potential_double; proxy of <Swig Object of type 'gum::Potential< double > *' at 0x10f643ab0> >

# %%
# this will not work 
# ie.jointPosterior(["Z3","Z1"])
# UndefinedElement:  no joint target containing {4,5}could be found

# %%
ie.addJointTarget(["Z2","Z1"])
gnb.sideBySide(ie,
               gnb.getDot(ie.joinTree().toDotWithNames(bn)),
              captions=['','JoinTree'])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="#ffffff" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="transparent"/>
# <!-- Y -->
# <g class="node" id="node1">
# <title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-157.8">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2">
# <title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-85.8">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1">
# <title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M42.2693,-146.7307C52.197,-136.803 65.3153,-123.6847 76.4363,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="79.1564,-114.7933 83.7527,-105.2473 74.2067,-109.8436 79.1564,-114.7933" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3">
# <title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-13.8">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6">
# <title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.6966,-72.2022C105.7976,-64.2406 108.324,-54.6671 110.665,-45.7957" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="114.1241,-46.4046 113.2916,-35.8425 107.3558,-44.6185 114.1241,-46.4046" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4">
# <title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-157.8">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3">
# <title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.8314C99,-136.131 99,-126.9743 99,-118.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="102.5001,-118.4132 99,-108.4133 95.5001,-118.4133 102.5001,-118.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5">
# <title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-157.8">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4">
# <title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M155.7307,-146.7307C145.803,-136.803 132.6847,-123.6847 121.5637,-112.5637" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="123.7933,-109.8436 114.2473,-105.2473 118.8436,-114.7933 123.7933,-109.8436" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7">
# <title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.5012,-144.3428C155.4019,-119.6202 138.7807,-74.4608 128.0714,-45.3639" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="131.2907,-43.9773 124.552,-35.8017 124.7215,-46.3951 131.2907,-43.9773" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6">
# <title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-85.8">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5">
# <title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M180.0055,-144.937C184.4828,-136.4537 189.9952,-126.0092 195.007,-116.513" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="198.2229,-117.9182 199.7952,-107.4407 192.0322,-114.6509 198.2229,-117.9182" stroke="#000000"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7">
# <title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-13.8">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2">
# <title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.8314C209,-64.131 209,-54.9743 209,-46.4166" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="212.5001,-46.4132 209,-36.4133 205.5001,-46.4133 212.5001,-46.4132" stroke="#000000"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><div align="left"><ul><li><b>hard evidence</b><br/>X, Y</li><li><b>soft evidence</b><br/>Z2, Z1</li><li><b>target(s)</b><br/>Z1, T1</li><li><b>Joint target(s)</b><br/>[Z2, Z1, T1]</li></ul></div></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Lazy Propagation on this BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Evidence and targets</small></div></td></tr></table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small></small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>JoinTree</small></div></td></tr></table>
