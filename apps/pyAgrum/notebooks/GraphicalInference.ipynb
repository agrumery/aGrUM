# %%
# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt

# %% [markdown]
# This notebook to show how to display some results about inference in BN with pyAgrum

# %%
import pyAgrum as gum
import gumLib.notebook as gnb
bn=gum.loadBN("../resources/alarm.dsl")
gnb.showBN(bn,size="10")
# Out:
# <div align='center'><svg height="443pt" viewBox="0.00 0.00 720.00 442.54" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.579244 0.579244) rotate(0) translate(4 760)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-760 1239,-760 1239,4 -4,4" stroke="none"/>
# <!-- KINKEDTUBE -->
# <g class="node" id="node1"><title>KINKEDTUBE</title>
# <g id="a_node1"><a xlink:title="(0) KINKEDTUBE">
# <ellipse cx="281" cy="-594" fill="#444444" rx="67.3907" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="281" y="-590.3">KINKEDTUBE</text>
# </a>
# </g>
# </g>
# <!-- VENTLUNG -->
# <g class="node" id="node23"><title>VENTLUNG</title>
# <g id="a_node23"><a xlink:title="(22) VENTLUNG">
# <ellipse cx="308" cy="-522" fill="#444444" rx="58.2422" ry="18" stroke="black"/>
# ...

# %% [markdown]
# It is well known that Lazy Propagation uses a junction tree to propagte information. How does it look for this BN ?

# %%
gnb.getJunctionTree(bn,size="8")

# %% [markdown]
# It is easy to get a posterior from an inference engine :

# %%
ie=gum.LazyPropagation(bn)
ie.makeInference()
print(ie.posterior(bn.idFromName("CATECHOL")))
# Out:
# <CATECHOL:NORMAL> :: 0.0511754 /<CATECHOL:HIGH> :: 0.948825

# %% [markdown]
# A graphical visualisation of the distribution is easy as well :

# %%
gnb.showPosterior(bn,{},'CATECHOL')

# %% [markdown]
# To have a <em>global</em> view of the knowledge brought by the inference, one can for instance draw the entropy of all nodes.

# %%
gnb.showInference(bn,ie,size="9")
# Out:
# <div align='center'><svg height="398pt" viewBox="0.00 0.00 648.00 398.29" width="648pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.521319 0.521319) rotate(0) translate(4 760)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-760 1239,-760 1239,4 -4,4" stroke="none"/>
# <!-- KINKEDTUBE -->
# <g class="node" id="node1"><title>KINKEDTUBE</title>
# <g id="a_node1"><a xlink:title="(0) KINKEDTUBE : 0.10725">
# <ellipse cx="281" cy="-594" fill="#54101b" rx="67.3907" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="281" y="-590.3">KINKEDTUBE</text>
# </a>
# </g>
# </g>
# <!-- VENTLUNG -->
# <g class="node" id="node23"><title>VENTLUNG</title>
# <g id="a_node23"><a xlink:title="(22) VENTLUNG : 0.42035">
# <ellipse cx="308" cy="-522" fill="#6d406b" rx="58.2422" ry="18" stroke="black"/>
# ...

# %% [markdown]
# .. and then observe the impact of an evidence on the whole bayes network :

# %%
ie.eraseAllEvidence()
ie.addHardEvidence(bn.idFromName("CO"),0)
gnb.showInference(bn,ie,size="9")
# Out:
# <div align='center'><svg height="398pt" viewBox="0.00 0.00 648.00 398.29" width="648pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.521319 0.521319) rotate(0) translate(4 760)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-760 1239,-760 1239,4 -4,4" stroke="none"/>
# <!-- KINKEDTUBE -->
# <g class="node" id="node1"><title>KINKEDTUBE</title>
# <g id="a_node1"><a xlink:title="(0) KINKEDTUBE : 0.14972">
# <ellipse cx="281" cy="-594" fill="#581626" rx="67.3907" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="281" y="-590.3">KINKEDTUBE</text>
# </a>
# </g>
# </g>
# <!-- VENTLUNG -->
# <g class="node" id="node23"><title>VENTLUNG</title>
# <g id="a_node23"><a xlink:title="(22) VENTLUNG : 0.45119">
# <ellipse cx="308" cy="-522" fill="#6f4573" rx="58.2422" ry="18" stroke="black"/>
# ...
