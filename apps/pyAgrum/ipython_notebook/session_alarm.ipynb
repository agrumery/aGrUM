# %%
import pyAgrum as gumimport gumLib.notebook as gnb

# %%
bn=gum.loadBN("../resources/alarm.dsl")gnb.showBN(bn)

# %%
var='TPR'gnb.showPosterior(bn,{'HRSAT':[0.2,0,0]},"VENTMACH")

# %%
gnb.getPosterior(bn,{'HRSAT':[0.2,0.8,0.8]},"VENTMACH").tolist()
# Out:
# [0.05009339787658059, 0.05610460664813877, 0.8389776493300735, 0.054824346145207106]

# %%
x=[p/100.0 for p in xrange(0,100)]y=[gnb.getPosterior(bn,{'HRBP':[1.0-p/100.0,1.0-p/100.0,p/100.0]},var).toarray() for p in xrange(0,100)]p=plot(x,y)title(bn.property('name'));bn.variableFromName(var);legend([v.label(i) for i in range(len(v))],loc='best');np1=(transpose(y)[0]>transpose(y)[2]).argmin()text(x[np1]-0.05,y[np1][0]+0.005,str(x[np1]),bbox=dict(facecolor='red', alpha=0.1));
