# %%
import pyAgrum as gumimport gumLib.notebook as gnb

# %%
bn=gum.loadBN("../resources/alarm.dsl")gnb.showBN(bn)

# %%
var='TPR'gnb.showPosterior(bn,{'HRSAT':[0.2,0,0]},"VENTMACH")

# %%
gnb.getPosterior(bn,{'HRSAT':[0.2,0.8,0.8]},"VENTMACH").tolist()
# Out:
# [0.0500933978765806, 0.05610460664813877, 0.8389776493300736, 0.054824346145207106]

# %%
x=[p/100.0 for p in xrange(0,100)]y=[gnb.getPosterior(bn,{'HRBP':[1.0-p/100.0,1.0-p/100.0,p/100.0]},var).toarray() for p in xrange(0,100)]p=plot(x,y)t=title(bn.property('name'))v=bn.variableFromName(var)l=legend([v.label(i) for i in range(len(v))],loc='best')np1=(transpose(y)[0]>transpose(y)[2]).argmin()np2=(transpose(y)[1]>transpose(y)[2]).argmin()s1=text(x[np1]-0.05,y[np1][0]+0.005,str(x[np1]),bbox=dict(facecolor='red', alpha=0.1))s2=text(x[np2]-0.05,y[np2][1]+0.005,str(x[np2]),bbox=dict(facecolor='red', alpha=0.1))
