# %% [markdown]
# # Learning classifiers

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
import pyAgrum.skbn as skbn
import pyAgrum.lib.notebook as gnb

import os
import pandas

# %% [markdown]
# skbn is a pyAgrum's module that allows to use bayesian networks as classifier in the scikit-learn environment.
# ## Initialization of parameters

# %% [markdown]
# First, we initialize the parameters to indicate properties we want our classifier to have.

# %%
BNTest= skbn.BNClassifier(learningMethod = 'Chow-Liu', prior= 'Smoothing', priorWeight = 0.5, 
                          discretizationStrategy = 'quantile', usePR = True, significant_digit = 13)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %% [markdown]
# Then, we train the classifier thanks to two types of objects.

# %% [markdown]
# ## Learn from csv file

# %%
BNTest.fit(data = 'res/creditCardTest.csv', targetName = 'Class')

# %%
for i in BNTest.bn.nodes():
    print(BNTest.bn.variable(i))
# Out:
# Class:Labelized({0.0|1.0})
# Time:Discretized(<(0;1578[,[1578;3733[,[3733;6982[,[6982;11033[,[11033;170348)>)
# V1:Discretized(<(-30.5524;-1.33295[,[-1.33295;-0.654664[,[-0.654664;0.305375[,[0.305375;1.18346[,[1.18346;2.13239)>)
# V2:Discretized(<(-25.6405;-0.362408[,[-0.362408;0.104022[,[0.104022;0.582468[,[0.582468;1.12626[,[1.12626;22.0577)>)
# V3:Discretized(<(-31.1037;0.107723[,[0.107723;0.675277[,[0.675277;1.14525[,[1.14525;1.73106[,[1.73106;4.10172)>)
# V4:Discretized(<(-4.65755;-0.835683[,[-0.835683;0.0334235[,[0.0334235;0.648386[,[0.648386;1.44563[,[1.44563;12.1147)>)
# V5:Discretized(<(-22.1055;-0.813666[,[-0.813666;-0.355923[,[-0.355923;0.0329468[,[0.0329468;0.534605[,[0.534605;11.9743)>)
# V6:Discretized(<(-7.5748;-0.789778[,[-0.789778;-0.370597[,[-0.370597;0.0353554[,[0.0353554;0.711815[,[0.711815;10.0339)>)
# V7:Discretized(<(-43.5572;-0.691953[,[-0.691953;-0.264738[,[-0.264738;0.111993[,[0.111993;0.57616[,[0.57616;12.2192)>)
# V8:Discretized(<(-41.0443;-0.248778[,[-0.248778;-0.0618973[,[-0.0618973;0.101159[,[0.101159;0.417327[,[0.417327;20.0072)>)
# V9:Discretized(<(-13.4341;-0.258886[,[-0.258886;0.432783[,[0.432783;1.00315[,[1.00315;1.60675[,[1.60675;10.3929)>)
# V10:Discretized(<(-24.5883;-0.887242[,[-0.887242;-0.486914[,[-0.486914;-0.17427[,[-0.17427;0.281998[,[0.281998;12.2599)>)
# V11:Discretized(<(-2.59533;-0.21685[,[-0.21685;0.467606[,[0.467606;1.06928[,[1.06928;1.89436[,[1.89436;12.0189)>)
# V12:Discretized(<(-18.6837;-2.60336[,[-2.60336;-1.98917[,[-1.98917;-1.01028[,[-1.01028;0.297745[,[0.297745;3.77484)>)
# V13:Discretized(<(-3.38951;-0.277526[,[-0.277526;0.487335[,[0.487335;1.192[,[1.192;1.87168[,[1.87168;4.46541)>)

# <ellipse fill="#404040" stroke="#4a4a4a" cx="603" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="603" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">V6</text>
# </a>
# </g>
# </g>
# <!-- V8&#45;&gt;V6 -->
# <g id="edge13" class="edge">
# <title>V8-&gt;V6</title>
# <g id="a_edge13"><a xlink:title="9 → 7">
# <path fill="none" stroke="#4a4a4a" d="M603,-143.7C603,-136.41 603,-127.73 603,-119.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="606.5,-119.62 603,-109.62 599.5,-119.62 606.5,-119.62"/>
# </a>
# </g>
# </g>
# <!-- V23 -->
# <g id="node2" class="node">
# <title>V23</title>
# <g id="a_node2"><a xlink:title="(24) V23">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="99" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">V23</text>
# </a>
# </g>
# </g>
# <!-- Class -->
# <g id="node3" class="node">
# <title>Class</title>
# <g id="a_node3"><a xlink:title="(0) Class">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="445" cy="-522" rx="30.88" ry="18"/>
# <text text-anchor="middle" x="445" y="-516.95" font-family="Times,serif" font-size="14.00" fill="white">Class</text>
# </a>
# </g>
# </g>
# <!-- Time -->
# <g id="node10" class="node">
# <title>Time</title>
# <g id="a_node10"><a xlink:title="(1) Time">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="445" cy="-450" rx="30.88" ry="18"/>
# <text text-anchor="middle" x="445" y="-444.95" font-family="Times,serif" font-size="14.00" fill="white">Time</text>
# </a>
# </g>
# </g>
# <!-- Class&#45;&gt;Time -->
# <g id="edge14" class="edge">
# <title>Class-&gt;Time</title>
# <g id="a_edge14"><a xlink:title="0 → 1">
# <path fill="none" stroke="#4a4a4a" d="M445,-503.7C445,-496.41 445,-487.73 445,-479.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="448.5,-479.62 445,-469.62 441.5,-479.62 448.5,-479.62"/>
# </a>
# </g>
# </g>
# <!-- V26 -->
# <g id="node4" class="node">
# <title>V26</title>
# <g id="a_node4"><a xlink:title="(27) V26">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">V26</text>
# </a>
# </g>
# </g>
# <!-- V11 -->
# <g id="node5" class="node">
# <title>V11</title>
# <g id="a_node5"><a xlink:title="(12) V11">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="243" cy="-306" rx="27" ry="18"/>
# <text text-anchor="middle" x="243" y="-300.95" font-family="Times,serif" font-size="14.00" fill="white">V11</text>
# </a>
# </g>
# </g>
# <!-- V19 -->
# <g id="node6" class="node">
# <title>V19</title>
# <g id="a_node6"><a xlink:title="(20) V19">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="315" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="315" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">V19</text>
# </a>
# </g>
# </g>
# <!-- V5 -->
# <g id="node7" class="node">
# <title>V5</title>
# <g id="a_node7"><a xlink:title="(6) V5">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="675" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="675" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">V5</text>
# </a>
# </g>
# </g>
# <!-- V22 -->
# <g id="node8" class="node">
# <title>V22</title>
# <g id="a_node8"><a xlink:title="(23) V22">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="459" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="459" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">V22</text>
# </a>
# </g>
# </g>
# <!-- V12 -->
# <g id="node9" class="node">
# <title>V12</title>
# <g id="a_node9"><a xlink:title="(13) V12">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="337" cy="-378" rx="27" ry="18"/>
# <text text-anchor="middle" x="337" y="-372.95" font-family="Times,serif" font-size="14.00" fill="white">V12</text>
# </a>
# </g>
# </g>
# <!-- V12&#45;&gt;V11 -->
# <g id="edge27" class="edge">
# <title>V12-&gt;V11</title>
# <g id="a_edge27"><a xlink:title="13 → 12">
# <path fill="none" stroke="#4a4a4a" d="M319.32,-363.83C305.27,-353.37 285.4,-338.58 269.46,-326.7"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="271.93,-324.18 261.82,-321.01 267.75,-329.79 271.93,-324.18"/>
# </a>
# </g>
# </g>
# <!-- V15 -->
# <g id="node18" class="node">
# <title>V15</title>
# <g id="a_node18"><a xlink:title="(16) V15">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="315" cy="-306" rx="27" ry="18"/>
# <text text-anchor="middle" x="315" y="-300.95" font-family="Times,serif" font-size="14.00" fill="white">V15</text>
# </a>
# </g>
# </g>
# <!-- V12&#45;&gt;V15 -->
# <g id="edge19" class="edge">
# <title>V12-&gt;V15</title>
# <g id="a_edge19"><a xlink:title="13 → 16">
# <path fill="none" stroke="#4a4a4a" d="M331.67,-360.05C329.27,-352.4 326.37,-343.16 323.66,-334.56"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="327.07,-333.72 320.73,-325.23 320.39,-335.82 327.07,-333.72"/>
# </a>
# </g>
# </g>
# <!-- V13 -->
# <g id="node19" class="node">
# <title>V13</title>
# <g id="a_node19"><a xlink:title="(14) V13">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="387" cy="-306" rx="27" ry="18"/>
# <text text-anchor="middle" x="387" y="-300.95" font-family="Times,serif" font-size="14.00" fill="white">V13</text>
# </a>
# </g>
# </g>
# <!-- V12&#45;&gt;V13 -->
# <g id="edge7" class="edge">
# <title>V12-&gt;V13</title>
# <g id="a_edge7"><a xlink:title="13 → 14">
# <path fill="none" stroke="#4a4a4a" d="M348.1,-361.46C354.31,-352.76 362.21,-341.71 369.26,-331.84"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="372.09,-333.9 375.05,-323.72 366.39,-329.83 372.09,-333.9"/>
# </a>
# </g>
# </g>
# <!-- Time&#45;&gt;V12 -->
# <g id="edge26" class="edge">
# <title>Time-&gt;V12</title>
# <g id="a_edge26"><a xlink:title="1 → 13">
# <path fill="none" stroke="#4a4a4a" d="M424.94,-436C408.19,-425.14 384.1,-409.53 365.37,-397.39"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="367.43,-394.55 357.14,-392.05 363.63,-400.43 367.43,-394.55"/>
# </a>
# </g>
# </g>
# <!-- V14 -->
# <g id="node17" class="node">
# <title>V14</title>
# <g id="a_node17"><a xlink:title="(15) V14">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="409" cy="-378" rx="27" ry="18"/>
# <text text-anchor="middle" x="409" y="-372.95" font-family="Times,serif" font-size="14.00" fill="white">V14</text>
# </a>
# </g>
# </g>
# <!-- Time&#45;&gt;V14 -->
# <g id="edge9" class="edge">
# <title>Time-&gt;V14</title>
# <g id="a_edge9"><a xlink:title="1 → 15">
# <path fill="none" stroke="#4a4a4a" d="M436.47,-432.41C432.34,-424.39 427.29,-414.57 422.65,-405.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="425.85,-404.11 418.16,-396.82 419.62,-407.31 425.85,-404.11"/>
# </a>
# </g>
# </g>
# <!-- V9 -->
# <g id="node27" class="node">
# <title>V9</title>
# <g id="a_node27"><a xlink:title="(10) V9">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="481" cy="-378" rx="27" ry="18"/>
# <text text-anchor="middle" x="481" y="-372.95" font-family="Times,serif" font-size="14.00" fill="white">V9</text>
# </a>
# </g>
# </g>
# <!-- Time&#45;&gt;V9 -->
# <g id="edge28" class="edge">
# <title>Time-&gt;V9</title>
# <g id="a_edge28"><a xlink:title="1 → 10">
# <path fill="none" stroke="#4a4a4a" d="M453.53,-432.41C457.66,-424.39 462.71,-414.57 467.35,-405.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="470.38,-407.31 471.84,-396.82 464.15,-404.11 470.38,-407.31"/>
# </a>
# </g>
# </g>
# <!-- V17 -->
# <g id="node30" class="node">
# <title>V17</title>
# <g id="a_node30"><a xlink:title="(18) V1

# %%
gnb.showBN(BNTest.MarkovBlanket)

# %% [markdown]
# ## Learn from array-likes

# %% [markdown]
# We use a method to transform the csv file in two array-likes in order to train from the same database.

# %%
#we use now another method to learn the BN (MIIC)
BNTest= skbn.BNClassifier(learningMethod = 'MIIC', prior= 'Smoothing', priorWeight = 0.5, 
                          discretizationStrategy = 'quantile', usePR = True, significant_digit = 13)

xTrain, yTrain = BNTest.XYfromCSV(filename = 'res/creditCardTest.csv', target = 'Class')

# %%
BNTest.fit(xTrain, yTrain)

# %%
gnb.showBN(BNTest.bn)

# %%
gnb.showBN(BNTest.MarkovBlanket)

# %% [markdown]
# ## Create a classifier from a Bayesian network

# %% [markdown]
# If we already have a Bayesian network with learned parameters, we can create a classifier that uses it. In this case we do not have to train the classifier on data since it the Bayesian network is already trained.

# %%
ClassfromBN = skbn.BNClassifier(significant_digit = 7)

# %%
ClassfromBN.fromTrainedModel(bn = BNTest.bn, targetAttribute = 'Class', targetModality = '1.0', 
                             threshold = BNTest.threshold, variableList = xTrain.columns.tolist())

# %%
gnb.showBN(ClassfromBN.bn)

# %%
gnb.showBN(ClassfromBN.MarkovBlanket)

# %% [markdown]
# Then, we work with functions from scikit-learn like score.
# We can also call it with a csv file or two array-likes.

# %%
xTest, yTest = ClassfromBN.XYfromCSV(filename = 'res/creditCardTest.csv', target = 'Class')

# %% [markdown]
# ## Prediction for classifier
#
# ### Prediction with csv file

# %%
scoreCSV1 = BNTest.score('res/creditCardTest.csv', y = yTest)
print("{0:.2f}% good predictions".format(100*scoreCSV1))
# Out:
# 99.77% good predictions

# %%
scoreCSV2 = ClassfromBN.score('res/creditCardTest.csv', y = yTest)
print("{0:.2f}% good predictions".format(100*scoreCSV2))
# Out:
# 99.77% good predictions

# %% [markdown]
# ### Prediction with array-like

# %%
scoreAR1 = BNTest.score(xTest, yTest)
print("{0:.2f}% good predictions".format(100*scoreAR1))
# Out:
# 99.77% good predictions

# %%
scoreAR2 = ClassfromBN.score(xTest, yTest)
print("{0:.2f}% good predictions".format(100*scoreAR2))
# Out:
# 99.77% good predictions

# %% [markdown]
# ## ROC and Precision-Recall curves with all methods

# %% [markdown]
# In addition (and of  course), we can work with functions from pyAgrum (from  `pyAgrum.lib.bn2roc`).

# %%
BNTest.showROC_PR('res/creditCardTest.csv')
