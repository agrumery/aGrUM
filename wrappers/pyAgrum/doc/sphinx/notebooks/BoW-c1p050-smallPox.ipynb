# %% [markdown]
# <a href="http://agrum.org" target="blank"><img src="http://agrum.gitlab.io/theme/img/logoAgrum.png" align="left" style="height:100px"/></a><a href="https://agrum.gitlab.io/pages/pyagrum.html" target="blank"><img src="https://agrum.gitlab.io/images/pyAgrum.png" align="right" style="height:75px"/></a><a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This pyAgrum's notebook is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a><br/>
# Author: <b>Aymen Merrouche</b> and Pierre-Henri Wuillemin.

# %% [markdown]
# <font size="+3" color="GREEN">**Smallpox Paradox**</font>
#
# #### This notebook follows the example from "The Book Of Why" (Pearl, 2018) chapter 1 page 050.

# %%
from IPython.display import display, Math, Latex,HTML

import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import pyAgrum.causal as csl
import pyAgrum.causal.notebook as cslnb
import os

# %% [markdown]
# >"When the smallpox vaccine was first introduced. Unexpectedly, data showed that more people died from
# smallpox inoculations than from smallpox itself. Naturally, some people used
# this information to argue that inoculation should be banned, when in fact it
# was saving lives by eradicating smallpox. Let’s look at some fictitious data to
# illustrate the effect and settle the dispute. We have a population of one million children." chapter1, page 50.

# %% [markdown]
# ### derived causal diagram:
# * The vaccination rate is set to 0.99.
#     * You have a 0.01 probability of developing a reaction to the vaccine.
#     * You have a 0.02 probability of contracting smallpox if you don't get vaccinated.
#         * You have a 0.01 probability of dying from a reaction to the vaccine.
#         * You have a 0.2 probability of dying from smallpox.
#
# The corresponding causal diagram is the following:

# %%
sp = gum.fastBN("vaccination->reaction->death<-smallPox<-vaccination")
sp
# Out:
# (pyAgrum.BayesNet<double>@0x11d960200) BN{nodes: 4, arcs: 4, domainSize: 16, dim: 9, mem: 144o}

# %%
# filling the CPTs

# This function adds a uniform noise to a CPT
def smallPertubation(cpt,epsilon=0.0001):
    cpt.fillWith(cpt.translate(epsilon).normalizeAsCPT())


# Fictitious data
sp.cpt("vaccination")[:] = [0.01, 0.99]
sp.cpt("reaction")[{"vaccination":0}] = [1,0] 
sp.cpt("reaction")[{"vaccination":1}] = [0.99, 0.01] 
sp.cpt("smallPox")[{"vaccination":0}] = [0.98, 0.02] 
sp.cpt("smallPox")[{"vaccination":1}] = [1, 0] 

sp.cpt("death")[{"reaction":0,"smallPox":0}] = [1, 0]
sp.cpt("death")[{"reaction":0,"smallPox":1}] = [0.8, 0.2]
sp.cpt("death")[{"reaction":1,"smallPox":0}] = [0.99, 0.01]
# This case is not possible
sp.cpt("death")[{"reaction":1,"smallPox":1}] = [0.5, 0.5] 


# We add a uniform noise to the CPTs
epsilon=0.000000001
smallPertubation(sp.cpt("reaction"), epsilon)
smallPertubation(sp.cpt("smallPox"), epsilon)
smallPertubation(sp.cpt("death"), epsilon)

# %%
gnb.sideBySide(sp,sp.cpt("vaccination"),
               sp.cpt("reaction"),
               sp.cpt("smallPox"),
               sp.cpt("death"),
               captions=["the BN","the marginal for $vaccination$","the CPT for $reaction$","the CPT for $smallPox$","the CPT for $death$"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="198pt" height="188pt" viewBox="0.00 0.00 198.32 188.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- vaccination -->
# <g id="node1" class="node">
# <title>vaccination</title>
# <g id="a_node1"><a xlink:title="(0) vaccination">
# <ellipse fill="#404040" stroke="black" cx="97.72" cy="-162" rx="53.4" ry="18"/>
# <text text-anchor="middle" x="97.72" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">vaccination</text>
# </a>
# </g>
# </g>
# <!-- smallPox -->
# <g id="node2" class="node">
# <title>smallPox</title>
# <g id="a_node2"><a xlink:title="(3) smallPox">
# <ellipse fill="#404040" stroke="black" cx="45.72" cy="-90" rx="45.72" ry="18"/>
# <text text-anchor="middle" x="45.72" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">smallPox</text>
# </a>
# </g>
# </g>
# <!-- vaccination&#45;&gt;smallPox -->
# <g id="edge3" class="edge">
# <title>vaccination-&gt;smallPox</title>
# <g id="a_edge3"><a xlink:title="0 → 3">
# <path fill="none" stroke="#4a4a4a" d="M85.13,-144.05C79.07,-135.89 71.66,-125.91 64.91,-116.82"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="67.87,-114.94 59.1,-109 62.25,-119.12 67.87,-114.94"/>
# </a>
# </g>
# </g>
# <!-- reaction -->
# <g id="node3" class="node">
# <title>reaction</title>
# <g id="a_node3"><a xlink:title="(1) reaction">
# <ellipse fill="#404040" stroke="black" cx="149.72" cy="-90" rx="40.6" ry="18"/>
# <text text-anchor="middle" x="149.72" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">reaction</text>
# </a>
# </g>
# </g>
# <!-- vaccination&#45;&gt;reaction -->
# <g id="edge1" class="edge">
# <title>vaccination-&gt;reaction</title>
# <g id="a_edge1"><a xlink:title="0 → 1">
# <path fill="none" stroke="#4a4a4a" d="M110.31,-144.05C116.47,-135.77 124.01,-125.62 130.84,-116.42"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="133.55,-118.64 136.71,-108.52 127.93,-114.46 133.55,-118.64"/>
# </a>
# </g>
# </g>
# <!-- death -->
# <g id="node4" class="node">
# <title>death</title>
# <g id="a_node4"><a xlink:title="(2) death">
# <ellipse fill="#404040" stroke="black" cx="97.72" cy="-18" rx="30.88" ry="18"/>
# <text text-anchor="middle" x="97.72" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">death</text>
# </a>
# </g>
# </g>
# <!-- smallPox&#45;&gt;death -->
# <g id="edge4" class="edge">
# <title>smallPox-&gt;death</title>
# <g id="a_edge4"><a xlink:title="3 → 2">
# <path fill="none" stroke="#4a4a4a" d="M58.04,-72.41C64.35,-63.92 72.16,-53.41 79.18,-43.96"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="81.79,-46.32 84.94,-36.2 76.17,-42.14 81.79,-46.32"/>
# </a>
# </g>
# </g>
# <!-- reaction&#45;&gt;death -->
# <g id="edge2" class="edge">
# <title>reaction-&gt;death</title>
# <g id="a_edge2"><a xlink:title="1 → 2">
# <path fill="none" stroke="#4a4a4a" d="M137.4,-72.41C131.09,-63.92 123.28,-53.41 116.27,-43.96"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="119.27,-42.14 110.5,-36.2 113.65,-46.32 119.27,-42.14"/>
# </a>
# </g>
# </g>
# </g>
# </svg><br><small><i>the BN</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>vaccination</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td></tr>
# </table><br><small><i>the marginal for $vaccination$</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>reaction</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>vaccination</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>1.0000</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# </table><br><small><i>the CPT for $reaction$</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>smallPox</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>vaccination</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#81fc64;text-align:right;'>0.9800</td><td style='color:black;background-color:#fc8164;text-align:right;'>0.0200</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>1.0000</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0000</td></tr>
# </table><br><small><i>the CPT for $smallPox$</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>death</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>smallPox</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>reaction</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>1.0000</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#80fd64;text-align:

# %%
#gum.saveBN(sp,os.path.join("out","smallPox.o3prm"))

# %% [markdown]
# ### We have that :
# $$P(reaction = 1 \mid vaccination = 1 ) < P(smallPox = 1 \mid vaccination = 0 )$$
# $$P(death = 1 \mid reaction = 1) < P(death = 1 \mid smallPox = 1)$$
# > We know that the probability of developing a reaction to the vaccine is lower than the probability of contracting smallpox if one does not vaccinate. We also know that the probability of dying from smallpox is greater than the probability of dying from a reaction to the vaccine. (smallpox is more threatening to one's life than a reaction to the vaccine)

# %%
def getAliveObservedProba(sp,evs):
    evs0=dict(evs)
    evs1=dict(evs)
    evs0["vaccination"]=0
    evs1["vaccination"]=1
    
    return gum.Potential().add(sp["vaccination"]).fillWith([
      gum.getPosterior(sp,target="death",evs=evs0)[1],
      gum.getPosterior(sp,target="death",evs=evs1)[1]
    ])

gnb.sideBySide(getAliveObservedProba(sp,{}),
               captions=["$P(death = 1 \mid vaccination )$<br/>$P(death = 1 \mid vaacination = 0) > P(death = 1 \mid vaacination = 1)$"])
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\m'
# <>:13: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/r1/pj4vdx_n4_d_xpsb04kzf97r0000gp/T/ipykernel_21366/2772643658.py:13: SyntaxWarning: invalid escape sequence '\m'
#   captions=["$P(death = 1 \mid vaccination )$<br/>$P(death = 1 \mid vaacination = 0) > P(death = 1 \mid vaacination = 1)$"])
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>vaccination</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='text-align:right;'>0.0040</td><td style='text-align:right;'>0.0001</td></tr>
# </table><br><small><i>$P(death = 1 \mid vaccination )$<br/>$P(death = 1 \mid vaacination = 0) > P(death = 1 \mid vaacination = 1)$</i></small></div></td></tr></table>

# %% [markdown]
# Based on this information, we can say that vaccination is a good choice. However, more children die from vaccination than from smallpox itself according to the data:
# * Number of people dying from a reaction:
# $$P(vaccination = 1) \times P(reaction = 1 \mid vaccination = 1) \times P(death = 1 \mid reaction = 1) \times 1000000 = 99$$
# * Number of people dying from smallpox:
# $$P(vaccination = 0) \times P(smallPox = 1 \mid vaccination = 0) \times P(death = 1 \mid smallPox = 1) \times 1000000 = 40$$
# <b>In total if the vaccination rate is set to 99% we have 139 deaths. </b>

# %% [markdown]
# ### When we began, the vaccination rate was 99 percent. We now ask the counterfactual question “What if we had set the vaccination rate to zero?”

# %%
# Counterfactual world where the vaccination rate is set to 0
spCounterfactual = gum.BayesNet(sp)
spCounterfactual.cpt("vaccination")[:] = [1, 0]

# %%
gnb.sideBySide(gnb.getInference(sp),
               gnb.getInference(spCounterfactual),
               captions=["<b>factual world:</b> the vaccination rate is set to 0.99 <br> lower risk of contracting smallpox, higher risk of developing a reaction, lower probability of death","<b>counterfactual world:</b> the vaccination rate is set to 0 <br> higher risk of contracting smallpox, lower risk of developing a reaction, higher probability of death"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="228pt" height="261pt" viewBox="0.00 0.00 228.00 260.50">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 256.5)">
# <title>structs</title>
# <text text-anchor="middle" x="110" y="-7.2" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.30ms</text>
# <!-- vaccination -->
# <g id="node1" class="node">
# <title>vaccination</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="160,-252.5 59,-252.5 59,-200.5 160,-200.5 160,-252.5"/>
# <svg viewBox="0 0 132.1625 66.9755" width="101px" height="52px" preserveAspectRatio="xMinYMin meet" x="59" y="-252.5"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-02-14T15:24:15.596114</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.8.2, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.9755  L 132.1625 66.9755  L 132.1625 0  L 0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 59.8755  L 128.5625 59.8755  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill: #ffffff"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 16.9625 59.8755  L 127.4465 59.8755  L 127.4465 47.5555  L 16.9625 47.5555  z " clip-path="url(#pa5afe49de8)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="patch_4">
#     <path d="M 16.9625 44.4755  L 18.0785 44.4755  L 18.0785 32.1555  L 16.9625 32.1555  z " clip-path="url(#pa5afe49de8)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path d="M 16.9625 59.8755  L 16.9625 32.1555  " clip-path="url(#pa5afe49de8)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path id="m9ebc633d74" d="M 0 0  L 0 3.5  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#m9ebc633d74" x="16.9625" y="59.8755" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path d="M 72.7625 59.8755  L 72.7625 32.1555  " clip-path="url(#pa5afe49de8)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use xlink:href="#m9ebc633d74" x="72.7625" y="59.8755" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path d="M 128.5625 59.8755  L 128.5625 32.1555  " clip-path="url(#pa5afe49de8)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use xlink:href="#m9ebc633d74" x="128.5625" y="59.8755" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path id="m5185985f86" d="M 0 0  L -3.5 0  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#m5185985f86" x="16.9625" y="53.7155" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 1 -->
#       <g transform="translate(3.6 57.514719) scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-31" d="M 794 531  L 1825 531  L 1825 4091  L 703 3866  L 703 4441  L 1819 4666  L 2450 4666  L 2450 531  L 3481 531  L 3481 0  L 794 0  L 794 531  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-31"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_2">
#      <g id="line2d_8">
#       <g>
#        <use xlink:href="#m5185985f86" x="16.9625" y="38.3155" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 0 -->
#       <g transform="translate(3.6 42.114719) scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-30" d="M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="patch_5">
#     <path d="M 16.9625 59.8755  L 16.9625 32.1555  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="patch_6">
#     <path d="M 128.5625 59.8755  L 128.5625 32.1555  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="patch_7">
#     <path d="M 16.9625 59.8755  L 128.5625 59.8755  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="patch_8">
#     <path d="M 16.9625 32.1555  L 128.5625 32.1555  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="text_3">
#     <!-- 99.00% -->
#     <g transform="translate(90.432812 57.795812) scale(0.1 -0.1)">
#      <defs>
#       <path id="DejaVuSans-39" d="M 703 97  L 703 672  Q 941 559 1184 500  Q 1428 441 1663 441  Q 2288 441 2617 861  Q 2947 1281 2994 2138  Q 2813 1869 2534 1725  Q 2256 1581 1919 1581  Q 1219 1581 811 2004  Q 403 2428 403 3163  Q 403 3881 828 4315  Q 1253 4750 1959 4750  Q 2769 4750 3195 4129  Q 3622 3509 3622 2328  Q 3622 1225 3098 567  Q 2575 -91 1691 -91  Q 1453 -91 1209 -44  Q 966 3 703 97  z M 1959 2075  Q 2384 2075 2632 2365  Q 2881 2656 2881 3163  Q 2881 3666 2632 3958  Q 2384 4250 1959 4250  Q 1534 4250 1286 3958  Q 1038 3666 1038 3163  Q 1038 2656 1286 2365  Q 1534 2075 1959 2075  z " transform="scale(0.015625)"/>
#       <path id="DejaVuSans-2e" d="M 684 794  L 1344 794  L 1344 0  L 684 0  L 684 794  z " transform="scale(0.015625)"/>
#       <path id="DejaVuSans-25" d="M 4653 2053  Q 4381 2053 4226 1822  Q 4072 1591 4072 1178  Q 4072 772 4226 539  Q 4381 306 4653 306  Q 4919 306 5073 539  Q 5228 772 5228 1178  Q 5228 1588 5073 1820  Q 4919 2053 4653 2053  z M 4653 2450  Q 5147 2450 5437 2106  Q 5728 1763 5728 1178  Q 5728 594 5436 251  Q 5144 -91 4653 -91  Q 4153 -91 3862 251  Q 3572 594 3572 1178  Q 3572 1766 3864 2108  Q 4156 2450 4653 2450  z M 1428 4353  Q 1159 4353 1004 4120  Q 850 3888 850 3481  Q 850 3069 1003 2837  Q 1156 2606 1428 2606  Q 1700 2606 1854 2837  Q 2009 3069 2009 3481  Q 2009 3884 1853 4118  Q 1697 4353 1428 4353  z M 4250 4750  L 4750 4750  L 1831 -91  L 1331 -91  L 4250 4750  z M 1428 4750  Q 1922 4750 2215 4408  Q 2509 4066 2509 3481  Q 2509 2891 2217 2550  Q 1925 2209 1428 2209  Q 931 2209 642 2551  Q 353 2894 353 3481  Q 353 4063 643 4406  Q 934 4750 1428 4750  z " transform="scale(0.015625)"/>
#      </defs>
#      <use xlink:href="#DejaVuSans-39"/>
#      <use xlink:href="#DejaVuSans-39" x="63.623047"/>
#      <use xlink:href="#DejaVuSans-2e" x="127.246094"/>
#      <use xlink:href="#DejaVuSans-30" x="159.033203"/>
#      <use xlink:href="#DejaVuSans-30" x="222.65625"/>
#      <use xlink:href="#DejaVuSans-25" x="286.279297"/>
#     </g>
#    </g>
#    <g id="text_4">
#     <!-- 1.00% -->
#     <g trans

# %% [markdown]
# The probability of death in the counterfactual world is higher.<br>
# * Number of deaths in this case:
# $$P(vaccination = 0) \times P(smallPox = 1 \mid vaccination = 0) \times P(death = 1 \mid smallPox = 1) \times 1000000 = 4000$$

# %% [markdown]
# ## In total, if the vaccination rate is set to 0%, we have 4000 deaths, compared to 139 deaths if the vaccination rate is set to 99%. Vaccination is definitely a good choice !
# > More people died from a reaction than from smallpox itself because with a vaccination rate of 0.99% the probability of developing a reaction was much higher than the probability of contracting smallpox (almost null) (since 99% of the population got vaccinated $\implies$ 99% of the population had a 0.001 probability of developing a reaction, while only 1% of the population had a 0.2 percent probability of contracting smallpox) that's why we saw that the effect of a reaction on death was greater than the effect of smallpox.(we recorded the effect of a reaction to the vaccine on a much greater population)

# %% [markdown]
# ### Causal impact of reaction/vaccination on death :
# Corresponds to the former results

# %%
spModele = csl.CausalModel(sp)
cslnb.showCausalImpact(spModele,on="death",doing="reaction", values={"reaction":1})
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="180pt" height="171pt" viewBox="0.00 0.00 180.00 170.63">
# <g id="graph0" class="graph" transform="scale(0.907601 0.907601) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- vaccination -->
# <g id="node1" class="node">
# <title>vaccination</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="92.6" cy="-162" rx="53.4" ry="18"/>
# <text text-anchor="middle" x="92.6" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">vaccination</text>
# </g>
# <!-- reaction -->
# <g id="node2" class="node">
# <title>reaction</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="40.6" cy="-90" rx="40.6" ry="18"/>
# <text text-anchor="middle" x="40.6" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">reaction</text>
# </g>
# <!-- vaccination&#45;&gt;reaction -->
# <g id="edge1" class="edge">
# <title>vaccination-&gt;reaction</title>
# <path fill="none" stroke="#4a4a4a" d="M79.21,-144.65C73.06,-136.36 65.52,-126.21 58.69,-117.02"/>
# <path fill="none" stroke="#4a4a4a" d="M80.82,-143.46C74.66,-135.17 67.12,-125.02 60.29,-115.83"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="62.39,-114.46 53.62,-108.52 56.77,-118.64 62.39,-114.46"/>
# </g>
# <!-- smallPox -->
# <g id="node4" class="node">
# <title>smallPox</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="144.6" cy="-90" rx="45.72" ry="18"/>
# <text text-anchor="middle" x="144.6" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">smallPox</text>
# </g>
# <!-- vaccination&#45;&gt;smallPox -->
# <g id="edge3" class="edge">
# <title>vaccination-&gt;smallPox</title>
# <path fill="none" stroke="#4a4a4a" d="M104.39,-143.46C110.46,-135.29 117.87,-125.32 124.62,-116.23"/>
# <path fill="none" stroke="#4a4a4a" d="M105.99,-144.65C112.06,-136.48 119.47,-126.51 126.22,-117.42"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="128.08,-119.12 131.23,-109 122.46,-114.94 128.08,-119.12"/>
# </g>
# <!-- death -->
# <g id="node3" class="node">
# <title>death</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="92.6" cy="-18" rx="30.88" ry="18"/>
# <text text-anchor="middle" x="92.6" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">death</text>
# </g>
# <!-- reaction&#45;&gt;death -->
# <g id="edge2" class="edge">
# <title>reaction-&gt;death</title>
# <path fill="none" stroke="#4a4a4a" d="M52.12,-71.81C58.43,-63.32 66.24,-52.81 73.26,-43.37"/>
# <path fill="none" stroke="#4a4a4a" d="M53.73,-73.01C60.04,-64.52 67.84,-54.01 74.86,-44.56"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="76.67,-46.32 79.82,-36.2 71.05,-42.14 76.67,-46.32"/>
# </g>
# <!-- smallPox&#45;&gt;death -->
# <g id="edge4" class="edge">
# <title>smallPox-&gt;death</title>
# <path fill="none" stroke="#4a4a4a" d="M131.48,-73.01C125.17,-64.52 117.36,-54.01 110.35,-44.56"/>
# <path fill="none" stroke="#4a4a4a" d="M133.08,-71.81C126.78,-63.32 118.97,-52.81 111.95,-43.37"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="114.16,-42.14 105.38,-36.2 108.54,-46.32 114.16,-42.14"/>
# </g>
# </g>
# </svg><br><center><small><em>Causal Model</em></small></center></div><div class="floating-box">$$\begin{equation*}P( death \mid \text{do}(reaction)) = \sum_{vaccination}{P\left(death\mid reaction,vaccination\right) \cdot P\left(vaccination\right)}\end{equation*}$$<br><center><small><em>Explanation : backdoor ['vaccination'] found.</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>death</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#80fd64;text-align:right;'>0.9899</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0101</td></tr>
# </table><br><center><small><em>Impact</em></small></center></div>

# %%
spModele = csl.CausalModel(sp)
cslnb.showCausalImpact(spModele,on="death",doing="smallPox", values={"smallPox":1})
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="180pt" height="171pt" viewBox="0.00 0.00 180.00 170.63">
# <g id="graph0" class="graph" transform="scale(0.907601 0.907601) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- vaccination -->
# <g id="node1" class="node">
# <title>vaccination</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="92.6" cy="-162" rx="53.4" ry="18"/>
# <text text-anchor="middle" x="92.6" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">vaccination</text>
# </g>
# <!-- reaction -->
# <g id="node2" class="node">
# <title>reaction</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="40.6" cy="-90" rx="40.6" ry="18"/>
# <text text-anchor="middle" x="40.6" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">reaction</text>
# </g>
# <!-- vaccination&#45;&gt;reaction -->
# <g id="edge1" class="edge">
# <title>vaccination-&gt;reaction</title>
# <path fill="none" stroke="#4a4a4a" d="M79.21,-144.65C73.06,-136.36 65.52,-126.21 58.69,-117.02"/>
# <path fill="none" stroke="#4a4a4a" d="M80.82,-143.46C74.66,-135.17 67.12,-125.02 60.29,-115.83"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="62.39,-114.46 53.62,-108.52 56.77,-118.64 62.39,-114.46"/>
# </g>
# <!-- smallPox -->
# <g id="node4" class="node">
# <title>smallPox</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="144.6" cy="-90" rx="45.72" ry="18"/>
# <text text-anchor="middle" x="144.6" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">smallPox</text>
# </g>
# <!-- vaccination&#45;&gt;smallPox -->
# <g id="edge3" class="edge">
# <title>vaccination-&gt;smallPox</title>
# <path fill="none" stroke="#4a4a4a" d="M104.39,-143.46C110.46,-135.29 117.87,-125.32 124.62,-116.23"/>
# <path fill="none" stroke="#4a4a4a" d="M105.99,-144.65C112.06,-136.48 119.47,-126.51 126.22,-117.42"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="128.08,-119.12 131.23,-109 122.46,-114.94 128.08,-119.12"/>
# </g>
# <!-- death -->
# <g id="node3" class="node">
# <title>death</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="92.6" cy="-18" rx="30.88" ry="18"/>
# <text text-anchor="middle" x="92.6" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">death</text>
# </g>
# <!-- reaction&#45;&gt;death -->
# <g id="edge2" class="edge">
# <title>reaction-&gt;death</title>
# <path fill="none" stroke="#4a4a4a" d="M52.12,-71.81C58.43,-63.32 66.24,-52.81 73.26,-43.37"/>
# <path fill="none" stroke="#4a4a4a" d="M53.73,-73.01C60.04,-64.52 67.84,-54.01 74.86,-44.56"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="76.67,-46.32 79.82,-36.2 71.05,-42.14 76.67,-46.32"/>
# </g>
# <!-- smallPox&#45;&gt;death -->
# <g id="edge4" class="edge">
# <title>smallPox-&gt;death</title>
# <path fill="none" stroke="#4a4a4a" d="M131.48,-73.01C125.17,-64.52 117.36,-54.01 110.35,-44.56"/>
# <path fill="none" stroke="#4a4a4a" d="M133.08,-71.81C126.78,-63.32 118.97,-52.81 111.95,-43.37"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="114.16,-42.14 105.38,-36.2 108.54,-46.32 114.16,-42.14"/>
# </g>
# </g>
# </svg><br><center><small><em>Causal Model</em></small></center></div><div class="floating-box">$$\begin{equation*}P( death \mid \text{do}(smallPox)) = \sum_{vaccination}{P\left(death\mid smallPox,vaccination\right) \cdot P\left(vaccination\right)}\end{equation*}$$<br><center><small><em>Explanation : backdoor ['vaccination'] found.</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>death</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#98e564;text-align:right;'>0.7970</td><td style='color:black;background-color:#e59864;text-align:right;'>0.2030</td></tr>
# </table><br><center><small><em>Impact</em></small></center></div>
