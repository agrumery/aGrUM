# %% [markdown]
# # Kullback-Leibler for Bayesian networks

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
import os

# %matplotlib inline

from pylab import *
import matplotlib.pyplot as plt

# %% [markdown]
# ## Initialisation
#
# * importing pyAgrum
# * importing pyAgrum.lib tools
# * loading a BN

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %% [markdown]
# ## Create a first BN : bn

# %%
bn=gum.loadBN("res/asia.bif")
# randomly re-generate parameters for every Conditional Probability Table
bn.generateCPTs() 
bn
# Out:
# (pyAgrum.BayesNet<double>@0x55826ebdbe60) BN{nodes: 8, arcs: 8, domainSize: 256, dim: 18, mem: 288o}

# %% [markdown]
# ## Create a second BN : bn2

# %%
bn2=gum.loadBN("res/asia.bif")
bn2.generateCPTs()
bn2
# Out:
# (pyAgrum.BayesNet<double>@0x55826ec36de0) BN{nodes: 8, arcs: 8, domainSize: 256, dim: 18, mem: 288o}

# %% [markdown]
# ## bn vs bn2 : different parameters

# %%
gnb.flow.row(bn.cpt(3),bn2.cpt(3),
              captions=["a CPT in bn","same CPT in bn2 (with different parameters)"])
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>positive_XraY</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>tuberculos_or_cancer</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#f18c64;text-align:right;'>0.1046</td><td style='color:black;background-color:#8cf164;text-align:right;'>0.8954</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#d9a464;text-align:right;'>0.2958</td><td style='color:black;background-color:#a4d964;text-align:right;'>0.7042</td></tr>
# </table><br><center><small><em>a CPT in bn</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>positive_XraY</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>tuberculos_or_cancer</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#afce64;text-align:right;'>0.6247</td><td style='color:black;background-color:#ceaf64;text-align:right;'>0.3753</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#d7a664;text-align:right;'>0.3076</td><td style='color:black;background-color:#a6d764;text-align:right;'>0.6924</td></tr>
# </table><br><center><small><em>same CPT in bn2 (with different parameters)</em></small></center></div>

# %% [markdown]
# ## Exact and (Gibbs) approximated KL-divergence

# %% [markdown]
# In order to compute KL-divergence, we just need to be sure that the 2 distributions are defined on the same domain (same variables, etc.)

# %% [markdown]
# <h3>Exact KL</h3>

# %%
g1=gum.ExactBNdistance(bn,bn2)
print(g1.compute())
# Out:
# {'klPQ': 2.693885010280355, 'errorPQ': 0, 'klQP': 5.322118996448689, 'errorQP': 0, 'hellinger': 0.9795669288987562, 'bhattacharya': 0.6534951836845349, 'jensen-shannon': 0.5757571920278003}

# %% [markdown]
# If the models are not on the same domain :

# %%
bn_different_domain=gum.loadBN("res/alarm.dsl")

# g=gum.BruteForceKL(bn,bn_different_domain) # a KL-divergence between asia and alarm ... :(
#
# would cause
#---------------------------------------------------------------------------
#OperationNotAllowed                       Traceback (most recent call last)
#
#OperationNotAllowed: this operation is not allowed : KL : the 2 BNs are not compatible (not the same vars : visit_to_Asia?)

# %% [markdown]
# <h3>Gibbs-approximated KL</h3>

# %%
g=gum.GibbsBNdistance(bn,bn2)
g.setVerbosity(True)
g.setMaxTime(120)
g.setBurnIn(5000)
g.setEpsilon(1e-7)
g.setPeriodSize(500)

# %%
print(g.compute())
print("Computed in {0} s".format(g.currentTime()))
# Out:
# {'klPQ': 2.693569456053914, 'errorPQ': 0, 'klQP': 4.170450481408639, 'errorQP': 0, 'hellinger': 0.9354607479362501, 'bhattacharya': 0.6557049176527434, 'jensen-shannon': 0.532485604630078}
# Computed in 6.798801791 s

# %%
print("--")

print(g.messageApproximationScheme())
print("--")

print("Temps de calcul : {0}".format(g.currentTime()))
print("Nombre d'itérations : {0}".format(g.nbrIterations()))
# Out:
# --
# stopped with epsilon=1e-07
# --
# Temps de calcul : 6.798801791
# Nombre d'itérations : 1284500

# %%
p=plot(g.history(), 'g')

# %% [markdown]
# ### Animation of Gibbs KL

# %% [markdown]
# Since it may be difficult to know what happens during approximation algorithm, pyAgrum allows to follow the iteration using animated matplotlib figure

# %%
g=gum.GibbsBNdistance(bn,bn2)
g.setMaxTime(60)
g.setBurnIn(500)
g.setEpsilon(1e-7)
g.setPeriodSize(5000)

# %%
gnb.animApproximationScheme(g) # logarithmique scale for Y
g.compute()
# Out:
# {'klPQ': 2.6980953717263163,
#  'errorPQ': 0,
#  'klQP': 4.294954692336129,
#  'errorQP': 0,
#  'hellinger': 0.9421255936192727,
#  'bhattacharya': 0.6566737627926815,
#  'jensen-shannon': 0.5390719372945214}
