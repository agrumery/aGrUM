# %% [markdown]
# # Kullback-Leibler for Bayesian networks

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
import os

# %matplotlib inline

from pylab import *
import matplotlib.pyplot as plt

# %% [markdown]
# ## import pyAgrum and pyAgrum.lib.notebook (for ... notebooks :-) )

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %% [markdown]
# ## Create a first BN : bn

# %%
bn=gum.loadBN("res/asia.bif")
# randomly re-generate parameters for every Conditional Probability Table
bn.generateCPTs() 
bn
# Out:
# (pyAgrum.BayesNet@0x1199e9000) BN{nodes: 8, arcs: 8, domainSize: 256, dim: 18, mem: 288o}

# %% [markdown]
# ## Create a second BN : bn2

# %%
bn2=gum.loadBN("res/asia.bif")
bn2.generateCPTs()
bn2
# Out:
# (pyAgrum.BayesNet@0x11a878200) BN{nodes: 8, arcs: 8, domainSize: 256, dim: 18, mem: 288o}

# %% [markdown]
# ## bn vs bn2 : different parameters

# %%
gnb.flow.row(bn.cpt(3),bn2.cpt(3),
              captions=["a CPT in bn","same CPT in bn2 (with different parameters)"])
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>positive_XraY</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>tuberculos_or_cancer</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#98e564;text-align:right;padding: 3px;'>0.8010</td><td style='color:black;background-color:#e59864;text-align:right;padding: 3px;'>0.1990</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#d1ac64;text-align:right;padding: 3px;'>0.3551</td><td style='color:black;background-color:#acd164;text-align:right;padding: 3px;'>0.6449</td></tr>
# </table><br><center><small><em>a CPT in bn</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>positive_XraY</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>tuberculos_or_cancer</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#eb9264;text-align:right;padding: 3px;'>0.1544</td><td style='color:black;background-color:#92eb64;text-align:right;padding: 3px;'>0.8456</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#bcc164;text-align:right;padding: 3px;'>0.5195</td><td style='color:black;background-color:#c1bc64;text-align:right;padding: 3px;'>0.4805</td></tr>
# </table><br><center><small><em>same CPT in bn2 (with different parameters)</em></small></center></div>

# %% [markdown]
# ## Exact and (Gibbs) approximated KL-divergence

# %% [markdown]
# In order to compute KL-divergence, we just need to be sure that the 2 distributions are defined on the same domain (same variables, etc.)

# %% [markdown]
# <h3>Exact KL</h3>

# %%
g1=gum.ExactBNdistance(bn,bn2)
print(g1.compute())
# Out:
# {'klPQ': 3.1041814248096937, 'errorPQ': 0, 'klQP': 4.2783118338701644, 'errorQP': 0, 'hellinger': 0.9574545313716569, 'bhattacharya': 0.6131529475789365, 'jensen-shannon': 0.5483763133874818}

# %% [markdown]
# If the models are not on the same domain :

# %%
bn_different_domain=gum.loadBN("res/alarm.dsl")

# g=gum.BruteForceKL(bn,bn_different_domain) # a KL-divergence between asia and alarm ... :(
#
# would cause
#---------------------------------------------------------------------------
#OperationNotAllowed                       Traceback (most recent call last)
#
#OperationNotAllowed: this operation is not allowed : KL : the 2 BNs are not compatible (not the same vars : visit_to_Asia?)

# %% [markdown]
# <h3>Gibbs-approximated KL</h3>

# %%
g=gum.GibbsBNdistance(bn,bn2)
g.setVerbosity(True)
g.setMaxTime(120)
g.setBurnIn(5000)
g.setEpsilon(1e-7)
g.setPeriodSize(500)

# %%
print(g.compute())
print("Computed in {0} s".format(g.currentTime()))
# Out:
# {'klPQ': 3.1035434604786545, 'errorPQ': 0, 'klQP': 4.186130989058809, 'errorQP': 0, 'hellinger': 0.9562154738730229, 'bhattacharya': 0.6066764757250871, 'jensen-shannon': 0.5484257151851746}
# Computed in 1.0305 s

# %%
print("--")

print(g.messageApproximationScheme())
print("--")

print("Temps de calcul : {0}".format(g.currentTime()))
print("Nombre d'itérations : {0}".format(g.nbrIterations()))
# Out:
# --
# stopped with epsilon=1e-07
# --
# Temps de calcul : 1.0305
# Nombre d'itérations : 295000

# %%
p=plot(g.history(), 'g')

# %% [markdown]
# ### Animation of Gibbs KL

# %% [markdown]
# Since it may be difficult to know what happens during approximation algorithm, pyAgrum allows to follow the iteration using animated matplotlib figure

# %%
g=gum.GibbsBNdistance(bn,bn2)
g.setMaxTime(60)
g.setBurnIn(500)
g.setEpsilon(1e-7)
g.setPeriodSize(5000)

# %%
gnb.animApproximationScheme(g) # logarithmique scale for Y
g.compute()
# Out:
# {'klPQ': 3.131136771971031,
#  'errorPQ': 0,
#  'klQP': 4.377976493770096,
#  'errorQP': 0,
#  'hellinger': 0.9608562434284481,
#  'bhattacharya': 0.6263971196046259,
#  'jensen-shannon': 0.5499644854474918}
