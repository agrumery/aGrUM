# %% [markdown]
# # Learning essential graphs

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
from pylab import *
import matplotlib.pyplot as plt

import os

import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %% [markdown]
# ### Compare learning algorithms
# Essentially MIIC and 3off2 computes the essential graph (CPDAG) from data. Essential graphs are PDAGs (Partially Directed Acyclic Graphs).

# %%
learner=gum.BNLearner("res/sample_asia.csv")
learner.use3off2()
learner.useNMLCorrection()
print(learner)
# Out:
# Filename       : res/sample_asia.csv
# Size           : (50000,8)
# Variables      : visit_to_Asia[2], lung_cancer[2], tuberculosis[2], bronchitis[2], positive_XraY[2], smoking[2], tuberculos_or_cancer[2], dyspnoea[2]
# Induced types  : True
# Missing values : False
# Algorithm      : 3off2
# Score          : BDeu
# Correction     : NML  (Not used for score-based algorithms)
# Prior          : -

# %%
ge3off2=learner.learnEssentialGraph()
# Out:
# ---------------------------------------------------------------------------
# OperationNotAllowed                       Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 ge3off2=learner.learnEssentialGraph()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyAgrum\pyAgrum.py:26296, in BNLearner.learnEssentialGraph(self)
#   26294 for i in range(len(self.names())):
#   26295   bn.add(self.nameFromId(i),2)
# > 26296 ge=EssentialGraph(bn,self.learnPDAG())
#   26297 ge._bn=bn
#   26298 return ge
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyAgrum\pyAgrum.py:26525, in BNLearner.learnPDAG(self)
#   26524 def learnPDAG(self) -> "pyAgrum.PDAG":
# > 26525     return _pyAgrum.BNLearner_learnPDAG(self)
#
# OperationNotAllowed: [pyAgrum] Operation not allowed: Must be using the miic/3off2 algorithm

# %%
gnb.show(ge3off2)

# %%
learner=gum.BNLearner("res/sample_asia.csv")
learner.useMIIC()
learner.useNMLCorrection()
print(learner)
gemiic=learner.learnEssentialGraph()
gemiic
# Out:
# Filename       : res/sample_asia.csv
# Size           : (50000,8)
# Variables      : visit_to_Asia[2], lung_cancer[2], tuberculosis[2], bronchitis[2], positive_XraY[2], smoking[2], tuberculos_or_cancer[2], dyspnoea[2]
# Induced types  : True
# Missing values : False
# Algorithm      : MIIC
# Score          : BDeu
# Correction     : NML  (Not used for score-based algorithms)
# Prior          : -
# <pyAgrum.pyAgrum.EssentialGraph; proxy of <Swig Object of type 'gum::EssentialGraph *' at 0x000001BE14BC04E0> >

# %% [markdown]
# For the others methods, it is possible to obtain the essential graph from the learned BN.

# %%
learner=gum.BNLearner("res/sample_asia.csv")
learner.useGreedyHillClimbing()
bnHC=learner.learnBN()
print(learner)
geHC=gum.EssentialGraph(bnHC)
geHC
gnb.sideBySide(bnHC,geHC)
# Out:
# Filename       : res/sample_asia.csv
# Size           : (50000,8)
# Variables      : visit_to_Asia[2], lung_cancer[2], tuberculosis[2], bronchitis[2], positive_XraY[2], smoking[2], tuberculos_or_cancer[2], dyspnoea[2]
# Induced types  : True
# Missing values : False
# Algorithm      : Greedy Hill Climbing
# Score          : BDeu
# Correction     : MDL  (Not used for score-based algorithms)
# Prior          : -
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="360pt" height="134pt" viewBox="0.00 0.00 360.00 134.00">
# <g id="graph0" class="graph" transform="scale(0.712743 0.712743) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- positive_XraY -->
# <g id="node1" class="node">
# <title>positive_XraY</title>
# <g id="a_node1"><a xlink:title="(4) positive_XraY">
# <ellipse fill="#404040" stroke="black" cx="275.6" cy="-18" rx="63.89" ry="18"/>
# <text text-anchor="middle" x="275.6" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">positive_XraY</text>
# </a>
# </g>
# </g>
# <!-- bronchitis -->
# <g id="node2" class="node">
# <title>bronchitis</title>
# <g id="a_node2"><a xlink:title="(3) bronchitis">
# <ellipse fill="#404040" stroke="black" cx="116.6" cy="-90" rx="46.59" ry="18"/>
# <text text-anchor="middle" x="116.6" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">bronchitis</text>
# </a>
# </g>
# </g>
# <!-- smoking -->
# <g id="node5" class="node">
# <title>smoking</title>
# <g id="a_node5"><a xlink:title="(5) smoking">
# <ellipse fill="#404040" stroke="black" cx="41.6" cy="-18" rx="41.69" ry="18"/>
# <text text-anchor="middle" x="41.6" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">smoking</text>
# </a>
# </g>
# </g>
# <!-- bronchitis&#45;&gt;smoking -->
# <g id="edge9" class="edge">
# <title>bronchitis-&gt;smoking</title>
# <g id="a_edge9"><a xlink:title="3 → 5">
# <path fill="none" stroke="#4a4a4a" d="M99.58,-73.12C89.53,-63.74 76.66,-51.73 65.6,-41.41"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="67.99,-38.84 58.29,-34.58 63.21,-43.96 67.99,-38.84"/>
# </a>
# </g>
# </g>
# <!-- dyspnoea -->
# <g id="node6" class="node">
# <title>dyspnoea</title>
# <g id="a_node6"><a xlink:title="(7) dyspnoea">
# <ellipse fill="#404040" stroke="black" cx="147.6" cy="-18" rx="46.29" ry="18"/>
# <text text-anchor="middle" x="147.6" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">dyspnoea</text>
# </a>
# </g>
# </g>
# <!-- bronchitis&#45;&gt;dyspnoea -->
# <g id="edge2" class="edge">
# <title>bronchitis-&gt;dyspnoea</title>
# <g id="a_edge2"><a xlink:title="3 → 7">
# <path fill="none" stroke="#4a4a4a" d="M124.1,-72.05C127.68,-63.97 132.04,-54.12 136.03,-45.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="139.31,-46.35 140.16,-35.79 132.91,-43.52 139.31,-46.35"/>
# </a>
# </g>
# </g>
# <!-- visit_to_Asia -->
# <g id="node3" class="node">
# <title>visit_to_Asia</title>
# <g id="a_node3"><a xlink:title="(0) visit_to_Asia">
# <ellipse fill="#404040" stroke="black" cx="438.6" cy="-90" rx="58.49" ry="18"/>
# <text text-anchor="middle" x="438.6" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">visit_to_Asia</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer -->
# <g id="node4" class="node">
# <title>tuberculos_or_cancer</title>
# <g id="a_node4"><a xlink:title="(6) tuberculos_or_cancer">
# <ellipse fill="#404040" stroke="black" cx="271.6" cy="-90" rx="90.18" ry="18"/>
# <text text-anchor="middle" x="271.6" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">tuberculos_or_cancer</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer&#45;&gt;positive_XraY -->
# <g id="edge4" class="edge">
# <title>tuberculos_or_cancer-&gt;positive_XraY</title>
# <g id="a_edge4"><a xlink:title="6 → 4">
# <path fill="none" stroke="#4a4a4a" d="M272.59,-71.7C273.03,-63.98 273.56,-54.71 274.05,-46.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="277.54,-46.29 274.62,-36.1 270.55,-45.89 277.54,-46.29"/>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer&#45;&gt;dyspnoea -->
# <g id="edge5" class="edge">
# <title>tuberculos_or_cancer-&gt;dyspnoea</title>
# <g id="a_edge5"><a xlink:title="6 → 7">
# <path fill="none" stroke="#4a4a4a" d="M242.84,-72.76C224.55,-62.44 200.8,-49.03 181.59,-38.19"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="183.27,-35.12 172.84,-33.25 179.83,-41.21 183.27,-35.12"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer -->
# <g id="node7" class="node">
# <title>lung_cancer</title>
# <g id="a_node7"><a xlink:title="(1) lung_cancer">
# <ellipse fill="#404040" stroke="black" cx="116.6" cy="-162" rx="54.69" ry="18"/>
# <text text-anchor="middle" x="116.6" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">lung_cancer</text>
# </a>
# </g>
# </g>
# <!-- lung_cancer&#45;&gt;bronchitis -->
# <g id="edge8" class="edge">
# <title>lung_cancer-&gt;bronchitis</title>
# <g id="a_edge8"><a xlink:title="1 → 3">
# <path fill="none" stroke="#4a4a4a" d="M116.6,-143.7C116.6,-135.98 116.6,-126.71 116.6,-118.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="120.1,-118.1 116.6,-108.1 113.1,-118.1 120.1,-118.1"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer&#45;&gt;tuberculos_or_cancer -->
# <g id="edge7" class="edge">
# <title>lung_cancer-&gt;tuberculos_or_cancer</title>
# <g id="a_edge7"><a xlink:title="1 → 6">
# <path fill="none" stroke="#4a4a4a" d="M147.59,-147C170.57,-136.63 202.19,-122.34 227.76,-110.8"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="229.2,-113.99 236.87,-106.68 226.32,-107.61 229.2,-113.99"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer&#45;&gt;smoking -->
# <g id="edge1" class="edge">
# <title>lung_cancer-&gt;smoking</title>
# <g id="a_edge1"><a xlink:title="1 → 5">
# <path fill="none" stroke="#4a4a4a" d="M94.61,-145.48C82.77,-135.98 68.92,-122.82 60.6,-108 49.93,-89 45.24,-64.64 43.18,-46.21"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="46.66,-45.76 42.25,-36.13 39.69,-46.41 46.66,-45.76"/>
# </a>
# </g>
# </g>
# <!-- tuberculosis -->
# <g id="node8" class="node">
# <title>tuberculosis</title>
# <g id="a_node8"><a xlink:title="(2) tuberculosis">
# <ellipse fill="#404040" stroke="black" cx="354.6" cy="-162" rx="54.69" ry="18"/>
# <text text-anchor="middle" x="354.6" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">tuberculosis</text>
# </a>
# </g>
# </g>
# <!-- tuberculosis&#45;&gt;visit_to_Asia -->
# <g id="edge3" class="edge">
# <title>tuberculosis-&gt;visit_to_Asia</title>
# <g id="a_edge3"><a xlink:title="2 → 0">
# <path fill="none" stroke="#4a4a4a" d="M373.66,-145.12C384.85,-135.78 399.19,-123.84 411.54,-113.55"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="413.88,-116.15 419.32,-107.06 409.4,-110.78 413.88,-116.15"/>
# </a>
# </g>
# </g>
# <!-- tuberculosis&#45;&gt;tuberculos_or_cancer -->
# <g id="edge6" class="edge">
# <title>tuberculosis-&gt;tuberculos_or_cancer</title>
# <g id="a_edge6"><a xlink:title="2 → 6">
# <path fill="none" stroke="#4a4a4a" d="M335.35,-144.76C324.61,-135.71 311.05,-124.27 299.19,-114.28"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="301.22,-111.4 291.32,-107.63 296.71,-116.76 301.22,-111.4"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="360pt" height="253pt" viewBox="0.00 0.00 360.00 253.02">
# <g id="graph0" class="graph" transform="scale(0.973135 0.973135) rotate(0) translate(4 256)">
# <title>no_name</title>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="90.34" cy="-234" rx="58.49" ry="18"/>
# <text text-anchor="middle" x="90.34" y="-230.3" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">visit_to_Asia</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="90.34" cy="-162" rx="54.69" ry="18"/>
# <text text-anchor="middle" x="90.34" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">tuberculosis</text>
# </g>
# <!-- 0&#45;&gt;2 -->
# <g id="edge1" class="edge">
# <title>0-&gt;2</title>
# <path fill="none" stroke="#4a4a4a" d="M90.34,-215.7C90.34,-204.85 90.34,-190.92 90.34,-180.1"/>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="245.34"

# %%
learner=gum.BNLearner("res/sample_asia.csv")
learner.useLocalSearchWithTabuList()
print(learner)
bnTL=learner.learnBN()
geTL=gum.EssentialGraph(bnTL)
geTL
gnb.sideBySide(bnTL,geTL)
# Out:
# Filename       : res/sample_asia.csv
# Size           : (50000,8)
# Variables      : visit_to_Asia[2], lung_cancer[2], tuberculosis[2], bronchitis[2], positive_XraY[2], smoking[2], tuberculos_or_cancer[2], dyspnoea[2]
# Induced types  : True
# Missing values : False
# Algorithm      : Local Search with Tabu List
# Tabu list size : 2
# Score          : BDeu
# Correction     : MDL  (Not used for score-based algorithms)
# Prior          : -
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="235pt" height="360pt" viewBox="0.00 0.00 235.09 360.00">
# <g id="graph0" class="graph" transform="scale(0.756303 0.756303) rotate(0) translate(4 472)">
# <title>G</title>
# <!-- positive_XraY -->
# <g id="node1" class="node">
# <title>positive_XraY</title>
# <g id="a_node1"><a xlink:title="(4) positive_XraY">
# <ellipse fill="#404040" stroke="black" cx="90.34" cy="-450" rx="63.89" ry="18"/>
# <text text-anchor="middle" x="90.34" y="-446.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">positive_XraY</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer -->
# <g id="node4" class="node">
# <title>tuberculos_or_cancer</title>
# <g id="a_node4"><a xlink:title="(6) tuberculos_or_cancer">
# <ellipse fill="#404040" stroke="black" cx="90.34" cy="-378" rx="90.18" ry="18"/>
# <text text-anchor="middle" x="90.34" y="-374.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">tuberculos_or_cancer</text>
# </a>
# </g>
# </g>
# <!-- positive_XraY&#45;&gt;tuberculos_or_cancer -->
# <g id="edge6" class="edge">
# <title>positive_XraY-&gt;tuberculos_or_cancer</title>
# <g id="a_edge6"><a xlink:title="4 → 6">
# <path fill="none" stroke="#4a4a4a" d="M90.34,-431.7C90.34,-423.98 90.34,-414.71 90.34,-406.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="93.84,-406.1 90.34,-396.1 86.84,-406.1 93.84,-406.1"/>
# </a>
# </g>
# </g>
# <!-- bronchitis -->
# <g id="node2" class="node">
# <title>bronchitis</title>
# <g id="a_node2"><a xlink:title="(3) bronchitis">
# <ellipse fill="#404040" stroke="black" cx="109.34" cy="-90" rx="46.59" ry="18"/>
# <text text-anchor="middle" x="109.34" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">bronchitis</text>
# </a>
# </g>
# </g>
# <!-- dyspnoea -->
# <g id="node6" class="node">
# <title>dyspnoea</title>
# <g id="a_node6"><a xlink:title="(7) dyspnoea">
# <ellipse fill="#404040" stroke="black" cx="67.34" cy="-18" rx="46.29" ry="18"/>
# <text text-anchor="middle" x="67.34" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">dyspnoea</text>
# </a>
# </g>
# </g>
# <!-- bronchitis&#45;&gt;dyspnoea -->
# <g id="edge4" class="edge">
# <title>bronchitis-&gt;dyspnoea</title>
# <g id="a_edge4"><a xlink:title="3 → 7">
# <path fill="none" stroke="#4a4a4a" d="M99.39,-72.41C94.44,-64.16 88.35,-54.01 82.81,-44.78"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="85.66,-42.73 77.52,-35.96 79.66,-46.33 85.66,-42.73"/>
# </a>
# </g>
# </g>
# <!-- visit_to_Asia -->
# <g id="node3" class="node">
# <title>visit_to_Asia</title>
# <g id="a_node3"><a xlink:title="(0) visit_to_Asia">
# <ellipse fill="#404040" stroke="black" cx="244.34" cy="-234" rx="58.49" ry="18"/>
# <text text-anchor="middle" x="244.34" y="-230.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">visit_to_Asia</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer&#45;&gt;dyspnoea -->
# <g id="edge8" class="edge">
# <title>tuberculos_or_cancer-&gt;dyspnoea</title>
# <g id="a_edge8"><a xlink:title="6 → 7">
# <path fill="none" stroke="#4a4a4a" d="M77.91,-360.05C60.34,-334.37 30.34,-283.44 30.34,-235 30.34,-235 30.34,-235 30.34,-161 30.34,-119.71 45.18,-73.77 56.06,-45.63"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="59.4,-46.7 59.85,-36.11 52.9,-44.11 59.4,-46.7"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer -->
# <g id="node7" class="node">
# <title>lung_cancer</title>
# <g id="a_node7"><a xlink:title="(1) lung_cancer">
# <ellipse fill="#404040" stroke="black" cx="113.34" cy="-234" rx="54.69" ry="18"/>
# <text text-anchor="middle" x="113.34" y="-230.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">lung_cancer</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer&#45;&gt;lung_cancer -->
# <g id="edge5" class="edge">
# <title>tuberculos_or_cancer-&gt;lung_cancer</title>
# <g id="a_edge5"><a xlink:title="6 → 1">
# <path fill="none" stroke="#4a4a4a" d="M93.12,-359.87C97.04,-335.67 104.24,-291.21 108.91,-262.39"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="112.41,-262.62 110.56,-252.19 105.5,-261.5 112.41,-262.62"/>
# </a>
# </g>
# </g>
# <!-- tuberculosis -->
# <g id="node8" class="node">
# <title>tuberculosis</title>
# <g id="a_node8"><a xlink:title="(2) tuberculosis">
# <ellipse fill="#404040" stroke="black" cx="173.34" cy="-306" rx="54.69" ry="18"/>
# <text text-anchor="middle" x="173.34" y="-302.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">tuberculosis</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer&#45;&gt;tuberculosis -->
# <g id="edge1" class="edge">
# <title>tuberculos_or_cancer-&gt;tuberculosis</title>
# <g id="a_edge1"><a xlink:title="6 → 2">
# <path fill="none" stroke="#4a4a4a" d="M110.01,-360.41C120.92,-351.21 134.64,-339.64 146.51,-329.63"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="149,-332.11 154.38,-322.99 144.48,-326.76 149,-332.11"/>
# </a>
# </g>
# </g>
# <!-- smoking -->
# <g id="node5" class="node">
# <title>smoking</title>
# <g id="a_node5"><a xlink:title="(5) smoking">
# <ellipse fill="#404040" stroke="black" cx="111.34" cy="-162" rx="41.69" ry="18"/>
# <text text-anchor="middle" x="111.34" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">smoking</text>
# </a>
# </g>
# </g>
# <!-- smoking&#45;&gt;bronchitis -->
# <g id="edge9" class="edge">
# <title>smoking-&gt;bronchitis</title>
# <g id="a_edge9"><a xlink:title="5 → 3">
# <path fill="none" stroke="#4a4a4a" d="M110.85,-143.7C110.63,-135.98 110.36,-126.71 110.12,-118.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="113.61,-118 109.83,-108.1 106.62,-118.2 113.61,-118"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer&#45;&gt;smoking -->
# <g id="edge3" class="edge">
# <title>lung_cancer-&gt;smoking</title>
# <g id="a_edge3"><a xlink:title="1 → 5">
# <path fill="none" stroke="#4a4a4a" d="M112.85,-215.7C112.63,-207.98 112.36,-198.71 112.12,-190.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="115.61,-190 111.83,-180.1 108.62,-190.2 115.61,-190"/>
# </a>
# </g>
# </g>
# <!-- tuberculosis&#45;&gt;visit_to_Asia -->
# <g id="edge7" class="edge">
# <title>tuberculosis-&gt;visit_to_Asia</title>
# <g id="a_edge7"><a xlink:title="2 → 0">
# <path fill="none" stroke="#4a4a4a" d="M189.81,-288.76C198.82,-279.88 210.15,-268.71 220.15,-258.85"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="222.81,-261.15 227.47,-251.63 217.89,-256.16 222.81,-261.15"/>
# </a>
# </g>
# </g>
# <!-- tuberculosis&#45;&gt;lung_cancer -->
# <g id="edge2" class="edge">
# <title>tuberculosis-&gt;lung_cancer</title>
# <g id="a_ed