# %% [markdown]
# # Learning essential graphs

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
from pylab import *
import matplotlib.pyplot as plt

import os

import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %% [markdown]
# ### Compare learning algorithms
# Essentially MIIC computes the essential graph (CPDAG) from data. Essential graphs are PDAGs (Partially Directed Acyclic Graphs).

# %%
learner=gum.BNLearner("res/sample_asia.csv")
learner.useMIIC()
learner.useNMLCorrection()
print(learner)
# Out:
# Filename       : res/sample_asia.csv
# Size           : (50000,8)
# Variables      : visit_to_Asia[2], lung_cancer[2], tuberculosis[2], bronchitis[2], positive_XraY[2], smoking[2], tuberculos_or_cancer[2], dyspnoea[2]
# Induced types  : True
# Missing values : False
# Algorithm      : MIIC
# Correction     : NML
# Prior          : -

# %%
gemiic=learner.learnEssentialGraph()
gnb.show(gemiic)

# %% [markdown]
# For the others methods, it is possible to obtain the essential graph from the learned BN.

# %%
learner=gum.BNLearner("res/sample_asia.csv")
learner.useGreedyHillClimbing()
bnHC=learner.learnBN()
print(learner)
geHC=gum.EssentialGraph(bnHC)
geHC
gnb.sideBySide(bnHC,geHC)
# Out:
# Filename       : res/sample_asia.csv
# Size           : (50000,8)
# Variables      : visit_to_Asia[2], lung_cancer[2], tuberculosis[2], bronchitis[2], positive_XraY[2], smoking[2], tuberculos_or_cancer[2], dyspnoea[2]
# Induced types  : True
# Missing values : False
# Algorithm      : Greedy Hill Climbing
# Score          : BDeu
# Prior          : -
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="360pt" height="132pt" viewBox="0.00 0.00 360.00 132.39">
# <g id="graph0" class="graph" transform="scale(0.704205 0.704205) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- visit_to_Asia -->
# <g id="node1" class="node">
# <title>visit_to_Asia</title>
# <g id="a_node1"><a xlink:title="(0) visit_to_Asia">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="60.05" cy="-90" rx="60.05" ry="18"/>
# <text text-anchor="middle" x="60.05" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">visit_to_Asia</text>
# </a>
# </g>
# </g>
# <!-- bronchitis -->
# <g id="node2" class="node">
# <title>bronchitis</title>
# <g id="a_node2"><a xlink:title="(3) bronchitis">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="384.05" cy="-90" rx="47.77" ry="18"/>
# <text text-anchor="middle" x="384.05" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">bronchitis</text>
# </a>
# </g>
# </g>
# <!-- dyspnoea -->
# <g id="node6" class="node">
# <title>dyspnoea</title>
# <g id="a_node6"><a xlink:title="(7) dyspnoea">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="353.05" cy="-18" rx="45.72" ry="18"/>
# <text text-anchor="middle" x="353.05" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">dyspnoea</text>
# </a>
# </g>
# </g>
# <!-- bronchitis&#45;&gt;dyspnoea -->
# <g id="edge2" class="edge">
# <title>bronchitis-&gt;dyspnoea</title>
# <g id="a_edge2"><a xlink:title="3 → 7">
# <path fill="none" stroke="#4a4a4a" d="M376.55,-72.05C373.12,-64.32 368.98,-54.96 365.13,-46.27"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="368.35,-44.9 361.1,-37.17 361.95,-47.73 368.35,-44.9"/>
# </a>
# </g>
# </g>
# <!-- smoking -->
# <g id="node7" class="node">
# <title>smoking</title>
# <g id="a_node7"><a xlink:title="(5) smoking">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="460.05" cy="-18" rx="43.16" ry="18"/>
# <text text-anchor="middle" x="460.05" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">smoking</text>
# </a>
# </g>
# </g>
# <!-- bronchitis&#45;&gt;smoking -->
# <g id="edge9" class="edge">
# <title>bronchitis-&gt;smoking</title>
# <g id="a_edge9"><a xlink:title="3 → 5">
# <path fill="none" stroke="#4a4a4a" d="M401.3,-73.12C411.11,-64.08 423.59,-52.58 434.52,-42.52"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="436.78,-45.2 441.76,-35.85 432.03,-40.05 436.78,-45.2"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer -->
# <g id="node3" class="node">
# <title>lung_cancer</title>
# <g id="a_node3"><a xlink:title="(1) lung_cancer">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="384.05" cy="-162" rx="55.96" ry="18"/>
# <text text-anchor="middle" x="384.05" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">lung_cancer</text>
# </a>
# </g>
# </g>
# <!-- lung_cancer&#45;&gt;bronchitis -->
# <g id="edge8" class="edge">
# <title>lung_cancer-&gt;bronchitis</title>
# <g id="a_edge8"><a xlink:title="1 → 3">
# <path fill="none" stroke="#4a4a4a" d="M384.05,-143.7C384.05,-136.41 384.05,-127.73 384.05,-119.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="387.55,-119.62 384.05,-109.62 380.55,-119.62 387.55,-119.62"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer&#45;&gt;smoking -->
# <g id="edge1" class="edge">
# <title>lung_cancer-&gt;smoking</title>
# <g id="a_edge1"><a xlink:title="1 → 5">
# <path fill="none" stroke="#4a4a4a" d="M407.01,-145.11C418.93,-135.67 432.72,-122.69 441.05,-108 451.49,-89.6 456.21,-66.1 458.33,-47.87"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="461.81,-48.28 459.27,-38 454.84,-47.62 461.81,-48.28"/>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer -->
# <g id="node8" class="node">
# <title>tuberculos_or_cancer</title>
# <g id="a_node8"><a xlink:title="(6) tuberculos_or_cancer">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="228.05" cy="-90" rx="90.25" ry="18"/>
# <text text-anchor="middle" x="228.05" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">tuberculos_or_cancer</text>
# </a>
# </g>
# </g>
# <!-- lung_cancer&#45;&gt;tuberculos_or_cancer -->
# <g id="edge7" class="edge">
# <title>lung_cancer-&gt;tuberculos_or_cancer</title>
# <g id="a_edge7"><a xlink:title="1 → 6">
# <path fill="none" stroke="#4a4a4a" d="M352.48,-146.83C329.97,-136.73 299.34,-122.99 274.11,-111.67"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="275.6,-108.5 265.04,-107.6 272.73,-114.89 275.6,-108.5"/>
# </a>
# </g>
# </g>
# <!-- tuberculosis -->
# <g id="node4" class="node">
# <title>tuberculosis</title>
# <g id="a_node4"><a xlink:title="(2) tuberculosis">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="144.05" cy="-162" rx="55.45" ry="18"/>
# <text text-anchor="middle" x="144.05" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">tuberculosis</text>
# </a>
# </g>
# </g>
# <!-- tuberculosis&#45;&gt;visit_to_Asia -->
# <g id="edge3" class="edge">
# <title>tuberculosis-&gt;visit_to_Asia</title>
# <g id="a_edge3"><a xlink:title="2 → 0">
# <path fill="none" stroke="#4a4a4a" d="M124.57,-144.76C113.83,-135.82 100.31,-124.55 88.42,-114.64"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="90.81,-112.07 80.88,-108.36 86.32,-117.45 90.81,-112.07"/>
# </a>
# </g>
# </g>
# <!-- tuberculosis&#45;&gt;tuberculos_or_cancer -->
# <g id="edge6" class="edge">
# <title>tuberculosis-&gt;tuberculos_or_cancer</title>
# <g id="a_edge6"><a xlink:title="2 → 6">
# <path fill="none" stroke="#4a4a4a" d="M163.53,-144.76C174.12,-135.95 187.41,-124.87 199.17,-115.07"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="201.19,-117.94 206.64,-108.85 196.71,-112.56 201.19,-117.94"/>
# </a>
# </g>
# </g>
# <!-- positive_XraY -->
# <g id="node5" class="node">
# <title>positive_XraY</title>
# <g id="a_node5"><a xlink:title="(4) positive_XraY">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="224.05" cy="-18" rx="65.17" ry="18"/>
# <text text-anchor="middle" x="224.05" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">positive_XraY</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer&#45;&gt;positive_XraY -->
# <g id="edge4" class="edge">
# <title>tuberculos_or_cancer-&gt;positive_XraY</title>
# <g id="a_edge4"><a xlink:title="6 → 4">
# <path fill="none" stroke="#4a4a4a" d="M227.06,-71.7C226.65,-64.41 226.15,-55.73 225.68,-47.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="229.18,-47.4 225.12,-37.62 222.19,-47.8 229.18,-47.4"/>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer&#45;&gt;dyspnoea -->
# <g id="edge5" class="edge">
# <title>tuberculos_or_cancer-&gt;dyspnoea</title>
# <g id="a_edge5"><a xlink:title="6 → 7">
# <path fill="none" stroke="#4a4a4a" d="M257.36,-72.59C275.46,-62.45 298.81,-49.38 317.9,-38.68"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="319.4,-41.86 326.41,-33.92 315.98,-35.75 319.4,-41.86"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="360pt" height="251pt" viewBox="0.00 0.00 360.00 250.66">
# <g id="graph0" class="graph" transform="scale(0.964084 0.964084) rotate(0) translate(4 256)">
# <title>no_name</title>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="90.25" cy="-234" rx="60.05" ry="18"/>
# <text text-anchor="middle" x="90.25" y="-228.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">visit_to_Asia</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="90.25" cy="-162" rx="55.45" ry="18"/>
# <text text-anchor="middle" x="90.25" y="-156.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">tuberculosis</text>
# </g>
# <!-- 0&#45;&gt;2 -->
# <g id="edge1" class="edge">
# <title>0-&gt;2</title>
# <path fill="none" stroke="#4a4a4a" d="M90.25,-215.7C90.25,-204.85 90.25,-190.92 90.25,-180.1"/>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="246.25" cy="-162" rx="55.96" ry="18"/>
# <text

# %%
learner=gum.BNLearner("res/sample_asia.csv")
learner.useLocalSearchWithTabuList()
print(learner)
bnTL=learner.learnBN()
geTL=gum.EssentialGraph(bnTL)
geTL
gnb.sideBySide(bnTL,geTL)
# Out:
# Filename       : res/sample_asia.csv
# Size           : (50000,8)
# Variables      : visit_to_Asia[2], lung_cancer[2], tuberculosis[2], bronchitis[2], positive_XraY[2], smoking[2], tuberculos_or_cancer[2], dyspnoea[2]
# Induced types  : True
# Missing values : False
# Algorithm      : Local Search with Tabu List
# Tabu list size : 2
# Score          : BDeu
# Prior          : -
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="276pt" height="360pt" viewBox="0.00 0.00 275.52 360.00">
# <g id="graph0" class="graph" transform="scale(0.756303 0.756303) rotate(0) translate(4 472)">
# <title>G</title>
# <!-- visit_to_Asia -->
# <g id="node1" class="node">
# <title>visit_to_Asia</title>
# <g id="a_node1"><a xlink:title="(0) visit_to_Asia">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="60.05" cy="-306" rx="60.05" ry="18"/>
# <text text-anchor="middle" x="60.05" y="-300.95" font-family="Times,serif" font-size="14.00" fill="white">visit_to_Asia</text>
# </a>
# </g>
# </g>
# <!-- bronchitis -->
# <g id="node2" class="node">
# <title>bronchitis</title>
# <g id="a_node2"><a xlink:title="(3) bronchitis">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="188.05" cy="-90" rx="47.77" ry="18"/>
# <text text-anchor="middle" x="188.05" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">bronchitis</text>
# </a>
# </g>
# </g>
# <!-- dyspnoea -->
# <g id="node6" class="node">
# <title>dyspnoea</title>
# <g id="a_node6"><a xlink:title="(7) dyspnoea">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="226.05" cy="-18" rx="45.72" ry="18"/>
# <text text-anchor="middle" x="226.05" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">dyspnoea</text>
# </a>
# </g>
# </g>
# <!-- bronchitis&#45;&gt;dyspnoea -->
# <g id="edge3" class="edge">
# <title>bronchitis-&gt;dyspnoea</title>
# <g id="a_edge3"><a xlink:title="3 → 7">
# <path fill="none" stroke="#4a4a4a" d="M197.25,-72.05C201.55,-64.14 206.76,-54.54 211.56,-45.69"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="214.52,-47.58 216.22,-37.12 208.37,-44.24 214.52,-47.58"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer -->
# <g id="node3" class="node">
# <title>lung_cancer</title>
# <g id="a_node3"><a xlink:title="(1) lung_cancer">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="182.05" cy="-234" rx="55.96" ry="18"/>
# <text text-anchor="middle" x="182.05" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">lung_cancer</text>
# </a>
# </g>
# </g>
# <!-- smoking -->
# <g id="node7" class="node">
# <title>smoking</title>
# <g id="a_node7"><a xlink:title="(5) smoking">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="184.05" cy="-162" rx="43.16" ry="18"/>
# <text text-anchor="middle" x="184.05" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">smoking</text>
# </a>
# </g>
# </g>
# <!-- lung_cancer&#45;&gt;smoking -->
# <g id="edge2" class="edge">
# <title>lung_cancer-&gt;smoking</title>
# <g id="a_edge2"><a xlink:title="1 → 5">
# <path fill="none" stroke="#4a4a4a" d="M182.55,-215.7C182.75,-208.41 183,-199.73 183.24,-191.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="186.73,-191.71 183.52,-181.62 179.74,-191.51 186.73,-191.71"/>
# </a>
# </g>
# </g>
# <!-- tuberculosis -->
# <g id="node4" class="node">
# <title>tuberculosis</title>
# <g id="a_node4"><a xlink:title="(2) tuberculosis">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="165.05" cy="-378" rx="55.45" ry="18"/>
# <text text-anchor="middle" x="165.05" y="-372.95" font-family="Times,serif" font-size="14.00" fill="white">tuberculosis</text>
# </a>
# </g>
# </g>
# <!-- tuberculosis&#45;&gt;visit_to_Asia -->
# <g id="edge6" class="edge">
# <title>tuberculosis-&gt;visit_to_Asia</title>
# <g id="a_edge6"><a xlink:title="2 → 0">
# <path fill="none" stroke="#4a4a4a" d="M141.49,-361.29C127.27,-351.81 108.93,-339.58 93.25,-329.14"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="95.42,-326.37 85.16,-323.74 91.54,-332.2 95.42,-326.37"/>
# </a>
# </g>
# </g>
# <!-- tuberculosis&#45;&gt;lung_cancer -->
# <g id="edge1" class="edge">
# <title>tuberculosis-&gt;lung_cancer</title>
# <g id="a_edge1"><a xlink:title="2 → 1">
# <path fill="none" stroke="#4a4a4a" d="M164.16,-359.83C163.52,-341.82 163.33,-312.76 167.05,-288 168.29,-279.74 170.43,-270.95 172.72,-262.95"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="176.06,-263.98 175.63,-253.39 169.36,-261.94 176.06,-263.98"/>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer -->
# <g id="node8" class="node">
# <title>tuberculos_or_cancer</title>
# <g id="a_node8"><a xlink:title="(6) tuberculos_or_cancer">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="266.05" cy="-306" rx="90.25" ry="18"/>
# <text text-anchor="middle" x="266.05" y="-300.95" font-family="Times,serif" font-size="14.00" fill="white">tuberculos_or_cancer</text>
# </a>
# </g>
# </g>
# <!-- tuberculosis&#45;&gt;tuberculos_or_cancer -->
# <g id="edge9" class="edge">
# <title>tuberculosis-&gt;tuberculos_or_cancer</title>
# <g id="a_edge9"><a xlink:title="2 → 6">
# <path fill="none" stroke="#4a4a4a" d="M187.72,-361.29C200.98,-352.1 217.97,-340.32 232.73,-330.09"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="234.58,-333.07 240.81,-324.49 230.6,-327.31 234.58,-333.07"/>
# </a>
# </g>
# </g>
# <!-- positive_XraY -->
# <g id="node5" class="node">
# <title>positive_XraY</title>
# <g id="a_node5"><a xlink:title="(4) positive_XraY">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="206.05" cy="-450" rx="65.17" ry="18"/>
# <text text-anchor="middle" x="206.05" y="-444.95" font-family="Times,serif" font-size="14.00" fill="white">positive_XraY</text>
# </a>
# </g>
# </g>
# <!-- positive_XraY&#45;&gt;tuberculosis -->
# <g id="edge7" class="edge">
# <title>positive_XraY-&gt;tuberculosis</title>
# <g id="a_edge7"><a xlink:title="4 → 2">
# <path fill="none" stroke="#4a4a4a" d="M196.13,-432.05C191.49,-424.14 185.87,-414.54 180.68,-405.69"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="183.72,-403.95 175.65,-397.1 177.68,-407.49 183.72,-403.95"/>
# </a>
# </g>
# </g>
# <!-- positive_XraY&#45;&gt;tuberculos_or_cancer -->
# <g id="edge5" class="edge">
# <title>positive_XraY-&gt;tuberculos_or_cancer</title>
# <g id="a_edge5"><a xlink:title="4 → 6">
# <path fill="none" stroke="#4a4a4a" d="M213.58,-431.84C218.1,-421.48 223.95,-408 229.05,-396 237.78,-375.47 247.45,-352.18 254.72,-334.58"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="257.75,-336.41 258.32,-325.83 251.28,-333.74 257.75,-336.41"/>
# </a>
# </g>
# </g>
# <!-- smoking&#45;&gt;bronchitis -->
# <g id="edge10" class="edge">
# <title>smoking-&gt;bronchitis</title>
# <g id="a_edge10"><a xlink:title="5 → 3">
# <path fill="none" stroke="#4a4a4a" d="M185.04,-143.7C185.46,-136.41 185.95,-127.73 186.42,-119.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="189.91,-119.8 186.99,-109.62 182.92,-119.4 189.91,-119.8"/>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer&#45;&gt;lung_cancer -->
# <g id="edge4" class="edge">
# <title>tuberculos_or_cancer-&gt;lung_cancer</title>
# <g id="a_edge4"><a xlink:title="6 → 1">
# <path fill="none" stroke="#4a4a4a" d="M245.72,-288.05C235.04,-279.16 221.79,-268.11 210.14,-258.41"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="212.71,-255.99 202.78,-252.28 208.22,-261.37 212.71,-255.99"/>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer&#45;&gt;dyspnoea -->
# <g id="edge8" class="edge">
# <title>tuberculos_or_cancer-&gt;dyspnoea</title>
# <g id="a_edge8"><a xlink:title="6 → 7">
# <path fill="none" stroke="#4a4a4a" d="M265.98,-287.52C265.51,-248.43 262.5,-151.13 245.05,-72 243.19,-63.57 240.35,-54.64 237.43,-46.57"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="240.72,-45.37 233.88,-37.27 234.18,-47.87 240.72,-45.37"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="360pt" height="307pt" viewBox="0.00 0.00 360.00 307.30">
# <g id="graph0" class="graph" transform="scale(0.925595 0.925595) rotate(0) translate(4 328)">
# <title>no_name</title>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="67.17" cy="-306" rx="60.05" ry="18"/>
# <text text-anchor="middle" x="67.17" y="-300.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">visit_to_Asia</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill

# %% [markdown]
# Hence we can compare the 4 algorithms.

# %%
(
  gnb.flow.clear()
  .add(gemiic,"Essential graph from miic")
  .add(bnHC,"BayesNet from GHC")
  .add(geHC,"Essential graph from GHC")
  .add(bnTL,"BayesNet from TabuList")
  .add(geTL,"Essential graph from TabuList")
  .display()
)
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="360pt" height="254pt" viewBox="0.00 0.00 360.00 254.34">
# <g id="graph0" class="graph" transform="scale(0.978214 0.978214) rotate(0) translate(4 256)">
# <title>no_name</title>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="61.25" cy="-234" rx="60.05" ry="18"/>
# <text text-anchor="middle" x="61.25" y="-228.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">visit_to_Asia</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="61.25" cy="-162" rx="55.45" ry="18"/>
# <text text-anchor="middle" x="61.25" y="-156.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">tuberculosis</text>
# </g>
# <!-- 0&#45;&gt;2 -->
# <g id="edge1" class="edge">
# <title>0-&gt;2</title>
# <path fill="none" stroke="#4a4a4a" d="M61.25,-215.7C61.25,-204.85 61.25,-190.92 61.25,-180.1"/>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="190.25" cy="-162" rx="55.96" ry="18"/>
# <text text-anchor="middle" x="190.25" y="-156.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">lung_cancer</text>
# </g>
# <!-- 5 -->
# <g id="node6" class="node">
# <title>5</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="241.25" cy="-90" rx="43.16" ry="18"/>
# <text text-anchor="middle" x="241.25" y="-84.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">smoking</text>
# </g>
# <!-- 1&#45;&gt;5 -->
# <g id="edge2" class="edge">
# <title>1-&gt;5</title>
# <path fill="none" stroke="#4a4a4a" d="M202.59,-144.05C210.73,-132.89 221.33,-118.34 229.37,-107.31"/>
# </g>
# <!-- 6 -->
# <g id="node7" class="node">
# <title>6</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="90.25" cy="-90" rx="90.25" ry="18"/>
# <text text-anchor="middle" x="90.25" y="-84.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">tuberculos_or_cancer</text>
# </g>
# <!-- 1&#45;&gt;6 -->
# <g id="edge3" class="edge">
# <title>1-&gt;6</title>
# <path fill="none" stroke="red" d="M167.56,-145.12C154.51,-135.98 137.89,-124.35 123.4,-114.2"/>
# <polygon fill="red" stroke="red" points="125.68,-111.53 115.48,-108.67 121.67,-117.27 125.68,-111.53"/>
# </g>
# <!-- 2&#45;&gt;6 -->
# <g id="edge4" class="edge">
# <title>2-&gt;6</title>
# <path fill="none" stroke="red" d="M68.42,-143.7C71.54,-136.15 75.29,-127.12 78.78,-118.68"/>
# <polygon fill="red" stroke="red" points="81.99,-120.08 82.58,-109.5 75.52,-117.4 81.99,-120.08"/>
# </g>
# <!-- 3 -->
# <g id="node4" class="node">
# <title>3</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="312.25" cy="-162" rx="47.77" ry="18"/>
# <text text-anchor="middle" x="312.25" y="-156.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">bronchitis</text>
# </g>
# <!-- 3&#45;&gt;5 -->
# <g id="edge5" class="edge">
# <title>3-&gt;5</title>
# <path fill="none" stroke="#4a4a4a" d="M295.78,-144.76C284.31,-133.46 269.08,-118.44 257.63,-107.15"/>
# </g>
# <!-- 7 -->
# <g id="node8" class="node">
# <title>7</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="265.25" cy="-18" rx="45.72" ry="18"/>
# <text text-anchor="middle" x="265.25" y="-12.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">dyspnoea</text>
# </g>
# <!-- 3&#45;&gt;7 -->
# <g id="edge6" class="edge">
# <title>3-&gt;7</title>
# <path fill="none" stroke="red" d="M309.98,-143.55C307.27,-125.31 301.98,-96.06 293.25,-72 290,-63.06 285.51,-53.75 281.06,-45.47"/>
# <polygon fill="red" stroke="red" points="284.24,-43.98 276.31,-36.96 278.13,-47.39 284.24,-43.98"/>
# </g>
# <!-- 4 -->
# <g id="node5" class="node">
# <title>4</title>
# <ellipse fill="none" stroke="#4a4a4a" cx="90.25" cy="-18" rx="65.17" ry="18"/>
# <text text-anchor="middle" x="90.25" y="-12.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">positive_XraY</text>
# </g>
# <!-- 6&#45;&gt;4 -->
# <g id="edge8" class="edge">
# <title>6-&gt;4</title>
# <path fill="none" stroke="red" d="M90.25,-71.7C90.25,-64.41 90.25,-55.73 90.25,-47.54"/>
# <polygon fill="red" stroke="red" points="93.75,-47.62 90.25,-37.62 86.75,-47.62 93.75,-47.62"/>
# </g>
# <!-- 6&#45;&gt;7 -->
# <g id="edge7" class="edge">
# <title>6-&gt;7</title>
# <path fill="none" stroke="red" d="M129.09,-73.46C157.12,-62.25 194.93,-47.13 223.6,-35.66"/>
# <polygon fill="red" stroke="red" points="224.7,-38.99 232.69,-32.02 222.1,-32.49 224.7,-38.99"/>
# </g>
# </g>
# </svg><br><center><small><em>Essential graph from miic</em></small></center></div><div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="360pt" height="132pt" viewBox="0.00 0.00 360.00 132.39">
# <g id="graph0" class="graph" transform="scale(0.704205 0.704205) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- visit_to_Asia -->
# <g id="node1" class="node">
# <title>visit_to_Asia</title>
# <g id="a_node1"><a xlink:title="(0) visit_to_Asia">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="60.05" cy="-90" rx="60.05" ry="18"/>
# <text text-anchor="middle" x="60.05" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">visit_to_Asia</text>
# </a>
# </g>
# </g>
# <!-- bronchitis -->
# <g id="node2" class="node">
# <title>bronchitis</title>
# <g id="a_node2"><a xlink:title="(3) bronchitis">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="384.05" cy="-90" rx="47.77" ry="18"/>
# <text text-anchor="middle" x="384.05" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">bronchitis</text>
# </a>
# </g>
# </g>
# <!-- dyspnoea -->
# <g id="node6" class="node">
# <title>dyspnoea</title>
# <g id="a_node6"><a xlink:title="(7) dyspnoea">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="353.05" cy="-18" rx="45.72" ry="18"/>
# <text text-anchor="middle" x="353.05" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">dyspnoea</text>
# </a>
# </g>
# </g>
# <!-- bronchitis&#45;&gt;dyspnoea -->
# <g id="edge2" class="edge">
# <title>bronchitis-&gt;dyspnoea</title>
# <g id="a_edge2"><a xlink:title="3 → 7">
# <path fill="none" stroke="#4a4a4a" d="M376.55,-72.05C373.12,-64.32 368.98,-54.96 365.13,-46.27"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="368.35,-44.9 361.1,-37.17 361.95,-47.73 368.35,-44.9"/>
# </a>
# </g>
# </g>
# <!-- smoking -->
# <g id="node7" class="node">
# <title>smoking</title>
# <g id="a_node7"><a xlink:title="(5) smoking">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="460.05" cy="-18" rx="43.16" ry="18"/>
# <text text-anchor="middle" x="460.05" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">smoking</text>
# </a>
# </g>
# </g>
# <!-- bronchitis&#45;&gt;smoking -->
# <g id="edge9" class="edge">
# <title>bronchitis-&gt;smoking</title>
# <g id="a_edge9"><a xlink:title="3 → 5">
# <path fill="none" stroke="#4a4a4a" d="M401.3,-73.12C411.11,-64.08 423.59,-52.58 434.52,-42.52"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="436.78,-45.2 441.76,-35.85 432.03,-40.05 436.78,-45.2"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer -->
# <g id="node3" class="node">
# <title>lung_cancer</title>
# <g id="a_node3"><a xlink:title="(1) lung_cancer">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="384.05" cy="-162" rx="55.96" ry="18"/>
# <text text-anchor="middle" x="384.05" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">lung_cancer</text>
# </a>
# </g>
# </g>
# <!-- lung_cancer&#45;&gt;bronchitis -->
# <g id="edge8" class="edge">
# <title>lung_cancer-&gt;bronchitis</title>
# <g id="a_edge8"><a xlink:title="1 → 3">
# <path fill="none" stroke="#4a4a4a" d="M384.05,-143.7C384.05,-136.41 384.05,-127.73 384.05,-119.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="387.55,-119.62 384.05,-109.62 380.55,-119.62 387.55,-119.62"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer&#45;&gt;smoking -->
# <g id="edge1" class="edge">
# <title>lung_cancer-&gt;smoking</title>
# <g id="a_edge1"><a xlink:title="1 → 5">
# <path fill="none" stroke="#4a4a4a" d="M407.01,-145.11C418.93,-135.67 432.72,-1
