# %% [markdown]
# # Influence diagram

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
import os

# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt
from IPython.display import display,HTML

import math

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %% [markdown]
# ## Build a influencediagram
#
# ### fast build with string

# %%
gum.fastID("A->*B->$C<-D<-*E->*G->H->*I<-D")
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x11d0a5e00) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 4,
#   arcs: 8,
#   domainSize: 128
# }

# %% [markdown]
# ### bifxml format file

# %%
diag=gum.loadID("res/diag.bifxml")
gnb.showInfluenceDiagram(diag)

# %%
diag
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x11d101200) Influence Diagram{
#   chance: 5,
#   utility: 2,
#   decision: 4,
#   arcs: 12,
#   domainSize: 512
# }

# %% [markdown]
# ### the hard way :-)

# %%
F=diag.addChanceNode(gum.LabelizedVariable("F","F",2))
diag.addArc(diag.idFromName("decisionVar1"),F)

U=diag.addUtilityNode(gum.LabelizedVariable("U","U",1))
diag.addArc(diag.idFromName("decisionVar3"),U)
diag.addArc(diag.idFromName("F"),U)
gnb.showInfluenceDiagram(diag)

# %%
diag.cpt(F)[{'decisionVar1':0}]=[0.9,0.1]
diag.cpt(F)[{'decisionVar1':1}]=[0.3,0.7]

diag.utility(U)[{'F':0,'decisionVar3':0}]=2
diag.utility(U)[{'F':0,'decisionVar3':1}]=4
diag.utility(U)[{'F':1}]=[[0],[5]]

# %% [markdown]
# ## Optimization in an influence diagram (actually LIMID)

# %%
oil=gum.loadID("res/OilWildcatter.bifxml")
gnb.flow.row(oil,gnb.getInference(oil))
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="286pt" height="281pt" viewBox="0.00 0.00 286.41 280.73">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 276.73)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="black" cx="107.57" cy="-172.04" rx="50.82" ry="20.51"/>
# <text text-anchor="middle" x="107.57" y="-168.34" font-family="Times,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="black" points="136.07,-112.36 79.07,-112.36 79.07,-83.36 136.07,-83.36 136.07,-112.36"/>
# <text text-anchor="middle" x="107.57" y="-94.16" font-family="Times,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="108.57,-151.31 108.52,-150.04 108.47,-148.76 108.43,-147.45 108.38,-146.13 108.33,-144.79 108.28,-143.43 108.23,-142.07 108.18,-140.7 108.13,-139.32 108.08,-137.93 108.02,-136.54 107.97,-135.15 107.92,-133.76 107.87,-132.36 107.82,-130.98 107.77,-129.59 107.72,-128.22 107.67,-126.85 107.62,-125.5 107.57,-124.15 107.57,-124.15 107.52,-125.5 107.47,-126.85 107.42,-128.22 107.37,-129.59 107.32,-130.98 107.27,-132.36 107.22,-133.76 107.16,-135.15 107.11,-136.54 107.06,-137.93 107.01,-139.32 106.96,-140.7 106.91,-142.07 106.86,-143.43 106.81,-144.79 106.76,-146.13 106.71,-147.45 106.66,-148.76 106.62,-150.04 106.57,-151.31 108.57,-151.31"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="111.07,-125.86 107.57,-115.86 104.07,-125.86 111.07,-125.86"/>
# </g>
# <!-- OilContents -->
# <g id="node2" class="node">
# <title>OilContents</title>
# <ellipse fill="#808080" stroke="black" cx="56.57" cy="-252.22" rx="56.64" ry="20.51"/>
# <text text-anchor="middle" x="56.57" y="-248.52" font-family="Times,serif" font-size="14.00" fill="white">OilContents</text>
# </g>
# <!-- OilContents&#45;&gt;TestResult -->
# <g id="edge6" class="edge">
# <title>OilContents-&gt;TestResult</title>
# <path fill="none" stroke="black" d="M69.18,-231.89C75.1,-222.8 82.3,-211.78 88.84,-201.74"/>
# <polygon fill="black" stroke="black" points="91.75,-203.69 94.28,-193.41 85.88,-199.87 91.75,-203.69"/>
# </g>
# <!-- Reward -->
# <g id="node6" class="node">
# <title>Reward</title>
# <polygon fill="#50508a" stroke

# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 336.82)">
# <title>structs</title>
# <text text-anchor="middle" x="210.42" y="-22.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">MEU 22.50 (stdev=87.46)</text>
# <text text-anchor="middle" x="210.42" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.20ms</text>
# <!-- Testing -->
# <g id="node1" class="node">
# <title>Testing</title>
# <polygon fill="none" stroke="#000000" points="168.75,-327.82 30.75,-327.82 30.75,-285.82 168.75,-285.82 168.75,-327.82"/>
# <svg viewBox="0 0 181.554687 53.538125" width="138px" height="42px" preserveAspectRatio="xMinYMin meet" x="30.7542" y="-327.825"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2023-02-14T00:13:25.648644</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.6.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; strok

# %%
# a function to show results on decision nodes T and D
def show_decisions(ie):
    gnb.flow.row(ie.optimalDecision("Testing"),
                   ie.optimalDecision("Drilling"),
                   f"$${ie.MEU()['mean']:5.3f}\\ (stdev : {math.sqrt(ie.MEU()['variance']):5.3f})$$",
                   captions=["Strategy for T",
                             "Strategy for D",
                             "MEU and its standard deviation>"])
    gnb.flow.row(ie.posterior("Testing"),ie.posteriorUtility("Testing"),
                   ie.posterior("Drilling"),ie.posteriorUtility("Drilling"),
                  captions=["Final decision for Testing","Final reward for Testing",
                            "Final decision for Drilling","Final reward for Drilling"])

ie=gum.ShaferShenoyLIMIDInference(oil) 

display(HTML("<h2>Inference in the LIMID optimizing the decisions nodes</h2>"))
ie.makeInference()
show_decisions(ie)
# Out:
# <h2>Inference in the LIMID optimizing the decisions nodes</h2>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# </table><br><center><small><em>Strategy for T</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>Drilling</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>TestResult</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>closed</center></th><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>open</center></th><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>diffuse</center></th><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td></tr>
# </table><br><center><small><em>Strategy for D</em></small></center></div><div class="floating-box">$$22.500\ (stdev : 87.457)$$<br><center><small><em>MEU and its standard deviation></em></small></center></div>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# </table><br><center><small><em>Final decision for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;'>22.5000</td><td style='text-align:right;'>20.0000</td></tr>
# </table><br><center><small><em>Final reward for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#b3ca64;text-align:right;'>0.5900</td><td style='color:black;background-color:#cab364;text-align:right;'>0.4100</td></tr>
# </table><br><center><small><em>Final decision for Drilling</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;'>45.0847</td><td style='text-align:right;'>-10.0000</td></tr>
# </table><br><center><small><em>Final reward for Drilling</em></small></center></div>

# %% [markdown]
# ## Graphical inference with evidence and targets (developped nodes)

# %%
gnb.sideBySide(oil,
               gnb.getInference(oil,evs={'TestResult':'closed'}),
               gnb.getInference(oil,evs={'TestResult':'open'}),
               gnb.getInference(oil,evs={'TestResult':'diffuse'}),
               oil,
               gnb.getInference(oil,evs={'OilContents':'Dry'}),
               gnb.getInference(oil,evs={'OilContents':'Wet'}),
               gnb.getInference(oil,evs={'OilContents':'Soaking'}),
               ncols=4)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="286pt" height="281pt" viewBox="0.00 0.00 286.41 280.73">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 276.73)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="black" cx="107.57" cy="-172.04" rx="50.82" ry="20.51"/>
# <text text-anchor="middle" x="107.57" y="-168.34" font-family="Times,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="black" points="136.07,-112.36 79.07,-112.36 79.07,-83.36 136.07,-83.36 136.07,-112.36"/>
# <text text-anchor="middle" x="107.57" y="-94.16" font-family="Times,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points
/>
# <polygon fill="black" stroke="black" stroke-width="2" points="144.19,-117.67 134.04,-114.62 140.07,-123.33 144.19,-117.67"/>
# </g>
# <!-- Cost -->
# <g id="node5" class="node">
# <title>Cost</title>
# <polygon fill="#50508a" stroke="black" points="278.26,-172.04 262.41,-195.89 230.72,-195.89 214.88,-172.04 230.72,-148.18 262.41,-148.18 278.26,-172.04"/>
# <text text-anchor="middle" x="246.57" y="-168.34" font-family="Times,serif" font-size="14.00" fill="white">Cost</text>
# </g>
# <!-- Testing&#45;&gt;Cost -->
# <g id="edge3" class="edge">
# <title>Testing-&gt;Cost</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M197.3,-237.24C204.42,-227.95 214.07,-215.38 222.94,-203.83"/>
# <polygon fill="black" stroke="black" points="225.58,-206.13 228.9,-196.06 220.03,-201.87 225.58,-206.13"/>
# </g>
# <!-- Drilling&#45;&gt;Reward -->
# <g id="edge4" class="edge">
# <title>Drilling-&gt;Reward</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M99.86,-82.94C95.86,-75.74 90.81,-66.61 85.89,-57.73"/>
# <polygon fill="black" stroke="black" points="89.09,-56.3 81.19,-49.25 82.97,-59.69 89.09,-56.3"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="431pt" height="341pt" viewBox="0.00 0.00 430.73 340.82">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 336.82)">
# <title>structs</title>
# <text text-anchor="middle" x="211.36" y="-22.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">MEU 77.50 (stdev=104.73)</text>
# <text text-anchor="middle" x="211.36" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.16ms</text>
# <!-- Testing -->
# <g id="node1" class="node">
# <title>Testing</title>
# <polygon fill="none" stroke="#000000" points="168.75,-327.82 30.75,-327.82 30.75,-285.82 168.75,-285.82 168.75,-327.82"/>
# <svg viewBox="0 0 181.554687 53.538125" width="138px" height="42px" preserveAspectRatio="xMinYMin meet" x="30.7482" y="-327.825"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2023-02-14T00:13:26.152296</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.6.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <

# %% [markdown]
# ## Soft evidence on chance node

# %%
gnb.showInference(oil,evs={'OilContents':[0.7,0.5,0.8]})

# %% [markdown]
# ## Forced decision

# %%
gnb.showInference(oil,evs={'Drilling':'Yes'})

# %% [markdown]
# ## LIMID versus Influence Diagram
#
# The default inference for influence diagram actually an inference for LIMIDs. In order to use it for classical (and solvable) influence diagram, do not forget to add the sequence of decision nodes using `addNoForgettingAssumption`.

# %%
infdiag=gum.fastID("Chance->*Decision1->Chance2->$Utility<-Chance3<-*Decision2<-Chance->Utility")
infdiag
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x11d13c000) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 2,
#   arcs: 7,
#   domainSize: 32
# }

# %%
ie=gum.ShaferShenoyLIMIDInference(infdiag)
try:
    ie.makeInference()
except gum.GumException as e:
    print(e)
# Out:
# [pyAgrum] Fatal error: This LIMID/Influence Diagram is not solvable.

# %%
ie.addNoForgettingAssumption(["Decision1","Decision2"])
gnb.sideBySide(ie.reducedLIMID(),ie.junctionTree(),gnb.getInference(infdiag,engine=ie))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="221pt" height="339pt" viewBox="0.00 0.00 221.27 339.38">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 335.38)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <ellipse fill="#808080" stroke="black" cx="166.84" cy="-310.88" rx="38.78" ry="20.51"/>
# <text text-anchor="middle" x="166.84" y="-307.18" font-family="Times,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="#9a5050" stroke="black" points="138.34,-254.37 69.34,-254.37 69.34,-225.37 138.34,-225.37 138.34,-254.37"/>
# <text text-anchor="middle" x="103.84" y="-236.17" font-family="Times,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="151.36,-291.43 150.1,-290.12 148.82,-288.79 147.51,-287.43 146.19,-286.05 144.84,-284.65 143.49,-283.24 142.12,-281.81 140.73,-280.37 139.34,-278.93 137.95,-277.47 136.55,-276.02 135.14,-274.56 133.74,-273.1 132.34,-271.64 130.95,-270.19 129.57,-268.75 128.19,-267.32 126.83,-265.91 125.48,-264.5 124.15,-263.12 124.15,-263.12 125.41,-264.57 126.69,-266.04 127.97,-267.52 129.27,-269.02 130.58,-270.53 131.9,-272.05 133.22,-273.57 134.55,-275.1 135.87,-276.63 137.2,-278.16 138.52,-279.68 139.83,-281.2 141.14,-282.7 142.44,-284.2 143.72,-285.68 144.99,-287.14 146.24,-288.59 147.48,-290.01 148.69,-291.41 149.88,-292.78 151.36,-291.43"/>
# <polygon fill="black" stroke="black" stroke-width="2" points
&gt;Decision2</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="114.86,-225.48 115.66,-224.3 116.49,-223.09 117.33,-221.86 118.19,-220.6 119.06,-219.32 119.95,-218.03 120.85,-216.71 121.76,-215.38 122.67,-214.04 123.6,-212.68 124.53,-211.32 125.46,-209.95 126.4,-208.58 127.34,-207.21 128.28,-205.84 129.21,-204.47 130.15,-203.1 131.07,-201.75 131.99,-200.4 132.91,-199.06 132.91,-199.06 131.91,-200.34 130.91,-201.63 129.9,-202.92 128.88,-204.23 127.86,-205.54 126.84,-206.85 125.82,-208.16 124.8,-209.47 123.78,-210.78 122.77,-212.08 121.76,-213.37 120.76,-214.65 119.77,-215.92 118.79,-217.18 117.82,-218.42 116.87,-219.64 115.94,-220.84 115.02,-222.02 114.12,-223.17 113.24,-224.3 114.86,-225.48"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="134.8,-202.4 137.88,-192.26 129.15,-198.27 134.8,-202.4"/>
# </g>
# <!-- Decision2&#45;&gt;Chance3 -->
# <g id="edge8" class="edge">
# <title>Decision2-&gt;Chance3</title>
# <path fill="none" stroke="black" d="M149.84,-159.9C149.84,-153.05 149.84,-144.5 149.84,-136.2"/>
# <polygon fill="black" stroke="black" points="153.34,-136.34 149.84,-126.34 146.34,-136.34 153.34,-136.34"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="229pt" height="163pt" viewBox="0.00 0.00 229.34 163.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 159)">
# <title>InfluenceDiagram</title>
# <!-- Chance&#45;Chance2&#45;Decision1&#45;Decision2 -->
# <g id="node1" class="node">
# <title>Chance-Chance2-Decision1-Decision2</title>
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="110.67" cy="-137" rx="110.84" ry="18"/>
# <text text-anchor="middle" x="110.67" y="-134.5" font-family="Times,serif" font-size="10.00">(0):Chance,Chance2,Decision1,Decision2</text>
# </g>
# <!-- Chance&#45;Chance2&#45;Decision1&#45;Decision2+Chance&#45;Chance2&#45;Chance3&#45;Decision2 -->
# <g id="node3" class="node">
# <title>Chance-Chance2-Decision1-Decision2+Chance-Chance2-Chance3-Decision2</title>
# <polygon fill="palegreen" stroke="#4a4a4a" points="156.17,-83 65.17,-83 65.17,-72 156.17,-72 156.17,-83"/>
# <text text-anchor="middle" x="110.67" y="-75.6" font-family="Times,serif" font-size="8.00">Chance,Chance2,Decision2</text>
# </g>
# <!-- Chance&#45;Ch

# %% [markdown]
# ## Customizing visualization of the results
#
# Using `pyAgrum.config`, it is possible to adapt the graphical representations for Influence Diagram (see [99-Tools_configForPyAgrum.ipynb](configForPyAgrum.ipynb.html) ).

# %%
gum.config.reset()
gnb.showInference(infdiag,engine=ie,size="7!")

# %% [markdown]
# Many visual options can be changed when displaing an inference (especially for influence diagrams)

# %%
# do not show inference time
gum.config["notebook","show_inference_time"]=False
# more digits for probabilities
gum.config["notebook","histogram_horizontal_visible_digits"]=3

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# specificic for influence diagram :
# more digits for utilities
gum.config["influenceDiagram","utility_visible_digits"]=5
# disabling stdev for utility and MEU
gum.config["influenceDiagram","utility_show_stdev"]=False
# showing loss (=-utility) and mEL (minimum Expected Loss) instead of MEU
gum.config["influenceDiagram","utility_show_loss"]=True

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# more visual changes for influence diagram and inference
gum.config.reset()

#shape (https://graphviz.org/doc/info/shapes.html)
gum.config["influenceDiagram","chance_shape"] = "cylinder"
gum.config["influenceDiagram","utility_shape"] = "star"
gum.config["influenceDiagram","decision_shape"] = "box3d"

#colors
gum.config["influenceDiagram","default_chance_bgcolor"] = "green"
gum.config["influenceDiagram","default_utility_bgcolor"] = "MediumVioletRed"
gum.config["influenceDiagram","default_decision_bgcolor"] = "DarkSalmon"

gum.config["influenceDiagram","utility_show_stdev"]=False

gnb.sideBySide(infdiag,gnb.getInference(infdiag,engine=ie,targets=["Decision1","Chance3"]))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width