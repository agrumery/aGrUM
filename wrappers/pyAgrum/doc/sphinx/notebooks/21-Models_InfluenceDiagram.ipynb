# %% [markdown]
# # Influence diagram

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
import os

# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt
from IPython.display import display,HTML

import math

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %% [markdown]
# ## Build a Influence Diagram
#
# ### fast build with string

# %%
gum.fastID("A->*B->$C<-D<-*E->*G->H->*I<-D")
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x55c699b1e760) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 4,
#   arcs: 8,
#   domainSize: 128
# }

# %% [markdown]
# ### bifxml format file

# %%
diag=gum.loadID("res/diag.bifxml")
gnb.showInfluenceDiagram(diag)

# %%
diag
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x55c69a07f810) Influence Diagram{
#   chance: 5,
#   utility: 2,
#   decision: 4,
#   arcs: 12,
#   domainSize: 512
# }

# %% [markdown]
# ### the hard way :-)

# %%
F=diag.addChanceNode(gum.LabelizedVariable("F","F",2))
diag.addArc(diag.idFromName("decisionVar1"),F)

U=diag.addUtilityNode(gum.LabelizedVariable("U","U",1))
diag.addArc(diag.idFromName("decisionVar3"),U)
diag.addArc(diag.idFromName("F"),U)
gnb.showInfluenceDiagram(diag)

# %%
diag.cpt(F)[{'decisionVar1':0}]=[0.9,0.1]
diag.cpt(F)[{'decisionVar1':1}]=[0.3,0.7]

diag.utility(U)[{'F':0,'decisionVar3':0}]=2
diag.utility(U)[{'F':0,'decisionVar3':1}]=4
diag.utility(U)[{'F':1}]=[[0],[5]]

# %% [markdown]
# ## Optimization in an influence diagram (actually LIMID)

# %%
oil=gum.loadID("res/OilWildcatter.bifxml")
gnb.flow.row(oil,gnb.getInference(oil))
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="335pt" height="296pt" viewBox="0.00 0.00 335.20 295.78">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 291.78)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="#4a4a4a" cx="131.11" cy="-181.18" rx="63.75" ry="22.38"/>
# <text text-anchor="middle" x="131.11" y="-176.5" font-family="Times,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="#4a4a4a" points="165.31,-119.33 96.91,-119.33 96.91,-87.68 165.31,-87.68 165.31,-119.33"/>
# <text text-anchor="middle" x="131.11" y="-98.83" font-family="Times,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="132.11,-158.7 132.06,-157.41 132.01,-156.1 131.97,-154.77 131.92,-153.43 131.87,-152.08 131.82,-150.71 131.77,-149.33 131.72,-147.95 131.67,-146.55 131.62,-145.16 131.56,-143.75 131.51,-142.35 131.46,-140.95 131.41,-139.55 131.36,-138.15 131.31,-136.76 131.26,-135.37 131.21,-133.99 131.16,-132.63 131.11,-131.27 131.11,-131.27 131.06,-132.63 131.01,-133.99 130.96,-135.37 130.91,-136.76 130.86,-138.15 130.81,-139.55 130.76,-140.95 130.71,-142.35 130.65,-143.75 130.6,-145.16 130.55,-146.55 130.5,-147.95 130.45,-149.33 130.4,-150.71 130.35,-152.08 130.3,-153.43 130.25,-154.77 130.2,-156.1 130.16,-157.41 130.11,-158.7 132.11,-158.7"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" stroke-width="2" points="134.61,-132.82 131.11,-122.82 127.61,-132.82 134.61,-132.82"/>
# </g>
# <!-- OilContents -->
# <g id="node2" class="node">
# <title>OilContents</title>
# <ellipse fill="#808080" stroke="#4a4a4a" cx="70.11" cy="-265.4" rx="70.11" ry="22.38"/>
# <text text-anchor="middle" x="70.11" y="-260.72" font-family="Times,serif" font-size="14.00" fill="white">OilContents</text>
# </g>
# <!-- OilContents&#45;&gt;TestResult -->
# <g id="edge6" class="edge">
# <title>OilContents-&gt;TestResult</title>
# <path fill="none" stroke="#4a4a4a" d="M85.82,-243.22C92.79,-233.83 101.13,-222.59 108.73,-212.34"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="111.4,-214.61 114.55,-204.49 105.78,-210.44 111.4,-214.61"/>
# </g>
# <!-- Reward -->
# <g id="node6" class="node">
# <title>Reward</title>
# <polygon fill="#50508a" stroke="#4a4a4a" points="141.57,-25.84 113.34,-51.68 56.88,-51.68 28.65,-25.84 56.88,0 113.34,0 141.57,-25.84"/>
# <text text-anchor="middle" x="85.11" y="-21.17" font-family="Times,serif" font-size="14.00" fill="white">Reward</text>
# </g>
# <!-- OilContents&#45;&gt;Reward -->
# <g id="edge7" class="edge">
# <title>OilContents-&gt;Reward</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="
3, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <styl

# %%
# a function to show results on decision nodes T and D
def show_decisions(ie):
    gnb.flow.row(ie.optimalDecision("Testing"),
                   ie.optimalDecision("Drilling"),
                   f"$${ie.MEU()['mean']:5.3f}\\ (stdev : {math.sqrt(ie.MEU()['variance']):5.3f})$$",
                   captions=["Strategy for T",
                             "Strategy for D",
                             "MEU and its standard deviation"])
    gnb.flow.row(ie.posterior("Testing"),ie.posteriorUtility("Testing"),
                   ie.posterior("Drilling"),ie.posteriorUtility("Drilling"),
                  captions=["Final decision for Testing","Final reward for Testing",
                            "Final decision for Drilling","Final reward for Drilling"])

ie=gum.ShaferShenoyLIMIDInference(oil) 

display(HTML("<h2>Inference in the LIMID optimizing the decisions nodes</h2>"))
ie.makeInference()
show_decisions(ie)
# Out:
# <h2>Inference in the LIMID optimizing the decisions nodes</h2>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td></tr>
# </table><br><center><small><em>Strategy for T</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>Drilling</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>TestResult</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>closed</center></th><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>open</center></th><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>diffuse</center></th><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td></tr>
# </table><br><center><small><em>Strategy for D</em></small></center></div><div class="floating-box">$$22.500\ (stdev : 87.457)$$<br><center><small><em>MEU and its standard deviation</em></small></center></div>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td></tr>
# </table><br><center><small><em>Final decision for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;padding: 3px;'>22.5000</td><td style='text-align:right;padding: 3px;'>20.0000</td></tr>
# </table><br><center><small><em>Final reward for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#b3ca64;text-align:right;padding: 3px;'>0.5900</td><td style='color:black;background-color:#cab364;text-align:right;padding: 3px;'>0.4100</td></tr>
# </table><br><center><small><em>Final decision for Drilling</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;padding: 3px;'>45.0847</td><td style='text-align:right;padding: 3px;'>-10.0000</td></tr>
# </table><br><center><small><em>Final reward for Drilling</em></small></center></div>

# %% [markdown]
# ## Graphical inference with evidence and targets (developped nodes)

# %%
gnb.sideBySide(oil,
               gnb.getInference(oil,evs={'TestResult':'closed'}),
               gnb.getInference(oil,evs={'TestResult':'open'}),
               gnb.getInference(oil,evs={'TestResult':'diffuse'}),
               oil,
               gnb.getInference(oil,evs={'OilContents':'Dry'}),
               gnb.getInference(oil,evs={'OilContents':'Wet'}),
               gnb.getInference(oil,evs={'OilContents':'Soaking'}),
               ncols=4)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="335pt" height="296pt" viewBox="0.00 0.00 335.20 295.78">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 291.78)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="#4a4a4a" cx="131.11" cy="-181.18" rx="63.75" ry="22.38"/>
# <text text-anchor="middle" x="131.11" y="-176.5" font-family="Times,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="#4a4a4a" points="165.31,-119.33 96.91,-119.33 96.91,-87.68 165.31,-87.68 165.31,-119.33"/>
# <text text-anchor="middle" x="131.11" y="-98.83" font-family="Times,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="132.11,-158.7 132.06,-157.41 132.01,-156.1 131.97,-154.77 131.92,-153.43 131.87,-152.08 131.82,-150.71 131.77,-149.33 131.72,-147.95 131.67,-146.55 131.62,-145.16 131.56,-143.75 131.51,-142.35 131.46,-140.95 131.41,-139.55 131.36,-138.15 131.31,-136.76 131.26,-135.37 131.21,-133.99 131.16,-132.63 131.11,-131.27 131.11,-131.27 131.06,-132.63 131.01,-133.99 130.96,-135.37 130.91,-136.76 130.86,-138.15 130.81,-139.55 130.76,-140.95 130.71,-142.35 130.65,-143.75 130.6,-145.16 130.55,-146.55 130.5,-147.95 130.45,-149.33 130.4,-150.71 130.35,-152.08 130.3,-153.43 130.25,-154.77 130.2,-156.1 130.16,-157.41 130.11,-158.7 132.11,-158.7"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" stroke-width="2" points
54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="109.35,-59.98 101.17,-53.26 103.37,-63.62 109.35,-59.98"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="454pt" height="349pt" viewBox="0.00 0.00 453.57 348.84">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 344.84)">
# <title>structs</title>
# <text text-anchor="middle" x="222.79" y="-25.2" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">MEU 77.50 (stdev=104.73)</text>
# <text text-anchor="middle" x="222.79" y="-7.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.56ms</text>
# <!-- Testing -->
# <g id="node1" class="node">
# <title>Testing</title>
# <polygon fill="none" stroke="#000000" points="175.9,-335.84 37.9,-335.84 37.9,-293.84 175.9,-293.84 175.9,-335.84"/>
# <svg viewBox="0 0 181.554687 53.538125" width="138px" height="42px" preserveAspectRatio="xMinYMin meet" x="37.8973" y="-335.836"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-03-27T15:55:19.820034</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.8.3, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>

# %% [markdown]
# ## Soft evidence on chance node

# %%
gnb.showInference(oil,evs={'OilContents':[0.7,0.5,0.8]})

# %% [markdown]
# ## Forced decision

# %%
gnb.showInference(oil,evs={'Drilling':'Yes'})

# %% [markdown]
# ## LIMID versus Influence Diagram
#
# The default inference for influence diagram actually an inference for LIMIDs. In order to use it for classical (and solvable) influence diagram, do not forget to add the sequence of decision nodes using `addNoForgettingAssumption`.

# %%
infdiag=gum.fastID("Chance->*Decision1->Chance2->$Utility<-Chance3<-*Decision2<-Chance->Utility")
infdiag
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x55c69a56e090) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 2,
#   arcs: 7,
#   domainSize: 32
# }

# %%
ie=gum.ShaferShenoyLIMIDInference(infdiag)
try:
    ie.makeInference()
except gum.GumException as e:
    print(e)
# Out:
# [pyAgrum] Fatal error: This LIMID/Influence Diagram is not solvable.

# %%
ie.addNoForgettingAssumption(["Decision1","Decision2"])
gnb.sideBySide(ie.reducedLIMID(),ie.junctionTree(),gnb.getInference(infdiag,engine=ie))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="262pt" height="357pt" viewBox="0.00 0.00 261.62 356.50">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 352.5)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <ellipse fill="#808080" stroke="#4a4a4a" cx="200.67" cy="-326.12" rx="47.31" ry="22.38"/>
# <text text-anchor="middle" x="200.67" y="-321.45" font-family="Times,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="#9a5050" stroke="#4a4a4a" points="172.74,-267.74 88.59,-267.74 88.59,-236.09 172.74,-236.09 172.74,-267.74"/>
# <text text-anchor="middle" x="130.67" y="-247.24" font-family="Times,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="182.26,-304.7 180.89,-303.36 179.5,-301.99 178.09,-300.6 176.66,-299.2 175.21,-297.78 173.75,-296.34 172.28,-294.89 170.79,-293.43 169.3,-291.97 167.81,-290.5 166.31,-289.03 164.81,-287.55 163.31,-286.08 161.81,-284.61 160.33,-283.15 158.85,-281.7 157.38,-280.26 155.93,-278.83 154.49,-277.42 153.07,-276.02 153.07,-276.02 154.42,-277.49 155.79,-278.97 157.17,-280.47 158.56,-281.98 159.97,-283.5 161.38,-285.03 162.8,-286.57 164.23,-288.11 165.66,-289.66 167.08,-291.2 168.5,-292.74 169.92,-294.28 171.33,-295.81 172.73,-297.33 174.12,-298.83 175.5,-300.32 176.86,-301.8 178.2,-303.25 179.52,-304.68 180.82,-306.09 182.26,-304.7"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" stroke-width="2" points="156.69,-274.73 147.22,-269.99 151.66,-279.6 156.69,-274.73"/>
# </g>
# <!-- Decision2 -->
# <g id="node5" class="node">
# <title>Decision2</title>
# <polygon fill="#9a5050" stroke="#4a4a4a" points="220.74,-200.09 136.59,-200.09 136.59,-168.44 220.74,-168.44 220.74,-200.09"/>
# <text text-anchor="middle" x="178.67" y="-179.59" font-family="Times,serif" font-size="14.00" fill="white">Decision2</text>
# </g>
# <!-- Chance&#45;&gt;Decision2 -->
# <g id="edge3" class="edge">
# <title>Chance-&gt;Decision2</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points

# <!-- Chance&#45;Chance2&#45;Decision1&#45;Decision2+Chance&#45;Chance2&#45;Chance3&#45;Decision2 -->
# <g id="node3" class="node">
# <title>Chance-Chance2-Decision1-Decision2+Chance-Chance2-Chance3-Decision2</title>
# <polygon fill="palegreen" stroke="#4a4a4a" points="192.26,-84.63 80.63,-84.63 80.63,-72 192.26,-72 192.26,-84.63"/>
# <text text-anchor="middle" x="136.45" y="-75.59" font-family="Times,serif" font-size="8.

# %% [markdown]
# ## Customizing visualization of the results
#
# Using `pyAgrum.config`, it is possible to adapt the graphical representations for Influence Diagram (see the notebook 99-Tools_configForPyAgrum.ipynb).

# %%
gum.config.reset()
gnb.showInference(infdiag,engine=ie,size="7!")

# %% [markdown]
# Many visual options can be changed when displaing an inference (especially for influence diagrams)

# %%
# do not show inference time
gum.config["notebook","show_inference_time"]=False
# more digits for probabilities
gum.config["notebook","histogram_horizontal_visible_digits"]=3

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# specificic for influence diagram :
# more digits for utilities
gum.config["influenceDiagram","utility_visible_digits"]=5
# disabling stdev for utility and MEU
gum.config["influenceDiagram","utility_show_stdev"]=False
# showing loss (=-utility) and mEL (minimum Expected Loss) instead of MEU
gum.config["influenceDiagram","utility_show_loss"]=True

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# visual changes for influence diagram and inference
gum.config.reset()
gum.config.push() # keep the current state
gum.config['notebook','graph_rankdir']='LR'
gnb.sideBySide(infdiag,gnb.getInference(infdiag,engine=ie,targets=["Decision1","Chance3"]))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="432pt" height="117pt" viewBox="0.00 0.00 432.00 116.84">
# <g id="graph0" class="graph" transform="scale(0.86344 0.86344) rotate(0) translate(4 131.32)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <ellipse fill="#808080" stroke="#4a4a4a" cx="47.31" cy="-41.94" rx="47.31" ry="22.38"/>
# <text text-anchor="middle" x="47.31" y="-37.27" font-family="Times,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="#9a5050" stroke="#4a4a4a" points="214.76,-113.77 130.61,-113.77 130.61,-82.12 214.76,-82.12 214.76,-113.77"/>
# <text text-anchor="middle" x="172.69" y="-93.27" font-family="Times,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="81.93,-58.3 83.98,-59.18 86.06,-60.08 88.17,-60.98 90.31,-61.9 92.46,-62.82 94.64,-63.76 96.84,-64.7 99.05,-65.65 101.27,-66.6 103.51,-67.56 105.75,-68.52 107.99,-69.48 110.24,-70.44 112.49,-71.41 114.73,-72.37 116.97,-73.33 119.2,-74.29 121.42,-75.24 123.62,-76.18 125.81,-77.12 125.81,-77.12 123.67,-76.09 121.5,-75.06 119.32,-74.01 117.14,-72.96 114.94,-71.91 112.74,-70.85 110.53,-69.8 108.33,-68.74 106.12,-67.68 103.93,-66.63 101.74,-65.58 99.55,-64.53 97.38,-63.49 95.23,-62.46 93.09,-61.44 90.98,-60.42 88.88,-59.42 86.81,-58.43 84.77,-57.45 82.76,-56.48 81.93,-58.3"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" stroke-width="2" points="122.73,-79.56 133.28,-80.51 125.62,-73.19 122.73,-79.56"/>
# </g>
# <!-- Decision2 -->
# <g id="node5" class="node">
# <title>Decision2</title>
# <polygon fill="#9a5050" stroke="#4a4a4a" points="214.76,-57.77 130.61,-57.77 130.61,-26.12 214.76,-26.12 214.76,-57.77"/>
# <text text-anchor="middle" x="172.69" y="-37.27" font-family="Times,serif" font-size="14.00" fill="white">Decision2</text>
# </g>
# <!-- Chance&#45;&gt;Decision2 -->
# <g id="edge3" class="edge">
# <title>Chance-&gt;Decision2</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="94.95,-42.94 96.12,-42.89 97.3,-42.85 98.48,-42.8 99.66,-42.75 100.85,-42.7 102.04,-42.65 103.24,-42.6 104.43,-42.55 105.63,-42.5 106.83,-42.45 108.03,-42.4 109.23,-42.35 110.43,-42.29 111.63,-42.24 112.84,-42.19 114.04,-42.14 115.23,-42.09 116.43,-42.04 117.63,-41.99 118.82,-41.94 118.82,-41.94 117.63,-41.89 116.43,-41.84 115.23,-41.79 114.04,-41.74 112.84,-41.69 111.63,-41.64 110.43,-41.59 109.23,-41.54 108.03,-41.49 106.83,-41.44 105.63,-41.39 104.43,-41.34 103.24,-41.29 102.04,-41.24 100.85,-41.19 99.66,-41.14 98.48,-41.09 97.3,-41.04 96.12,-40.99 94.95,-40.94 94.95,-42.94"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" stroke-width="2" points
18.718125  z " style="fill: #ffffff"/>
#    </g>
#    <g id="p

# %%
# more visual changes for influence diagram and inference
gum.config.pop() # back to the last state

#shape (https://graphviz.org/doc/info/shapes.html)
gum.config["influenceDiagram","chance_shape"] = "cylinder"
gum.config["influenceDiagram","utility_shape"] = "star"
gum.config["influenceDiagram","decision_shape"] = "box3d"

#colors
gum.config["influenceDiagram","default_chance_bgcolor"] = "green"
gum.config["influenceDiagram","default_utility_bgcolor"] = "MediumVioletRed"
gum.config["influenceDiagram","default_decision_bgcolor"] = "DarkSalmon"

gum.config["influenceDiagram","utility_show_stdev"]=False

gnb.sideBySide(infdiag,gnb.getInference(infdiag,engine=ie,targets=["Decision1","Chance3"]))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="198pt" height="363pt" viewBox="0.00 0.00 198.39 362.77">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 358.77)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <path fill="green" stroke="#4a4a4a" d="M149.03,-350.91C149.03,-353.04 136.72,-354.77 121.58,-354.77 106.43,-354.77 94.12,-353.04 94.12,-350.91 94.12,-350.91 94.12,-316.14 94.12,-316.14 94.12,-314.01 106.43,-312.28 121.58,-312.28 136.72,-312.28 149.03,-314.01 149.03,-316.14 149.03,-316.14 149.03,-350.91 149.03,-350.91"/>
# <path fill="none" stroke="#4a4a4a" d="M149.03,-350.91C149.03,-348.78 136.72,-347.04 121.58,-347.04 106.43,-347.04 94.12,-348.78 94.12,-350.91"/>
# <text text-anchor="middle" x="121.58" y="-328.48" font-family="Times,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="DarkSalmon" stroke="#4a4a4a" points="69.15,-276.28 3.43,-276.28 0,-272.85 0,-245.38 65.72,-245.38 69.15,-248.82 69.15,-276.28"/>
# <polyline fill="none" stroke="#4a4a4a" points="65.72,-272.85 0,-272.85"/>
# <polyline fill="none" stroke="#4a4a4a" points="65.72,-272.85 65.72,-245.38"/>
# <polyline fill="none" stroke="#4a4a4a" points="65.72,-272.85 69.15,-276.28"/>
# <text text-anchor="middle" x="34.58" y="-255.78" font-family="Times,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="97.04,-311.3 95.36,-310 93.66,-308.68 91.93,-307.34 90.18,-305.98 88.42,-304.61 86.64,-303.22 84.84,-301.83 83.04,-300.43 81.23,-299.03 79.41,-297.62 77.6,-296.21 75.78,-294.8 73.97,-293.39 72.17,-291.99 70.37,-290.6 68.59,-289.22 66.82,-287.84 65.07,-286.48 63.34,-285.14 61.63,-283.82 61.63,-283.82 63.28,-285.22 64.95,-286.64 66.63,-288.07 68.34,-289.52 70.06,-290.98 71.79,-292.46 73.53,-293.94 75.28,-295.42 77.03,-296.91 78.78,-298.4 80.53,-299.89 82.28,-301.37 84.01,-302.85 85.74,-304.32 87.46,-305.78 89.17,-307.23 90.85,-308.66 92.52,-310.08 94.16,-311.48 95.78,-312.85 97.04,-311.3"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" stroke-width="2" points="65.09,-282.12 55.12,-278.53 60.68,-287.55 65.09,-282.12"/>
# </g>
# <!-- Decision2 -->
# <g id="node5" class="node">
# <title>Decision2</title>
# <polygon fill="DarkSalmon" stroke="#4a4a4a" points="156.15,-276.28 90.43,-276.28 87,-272.85 87,-245.38 152.72,-245.38 156.15,-248.82 156.15,-276.28"/>
# <polyline fill="none" stroke="#4a4a4a" points="152.72,-272.85 87,-272.85"/>
# <polyline fill="none" stroke="#4a4a4a" points="152.72,-272.85 152.72,-245.38"/>
# <polyline fill="none" stroke="#4a4a4a" points="152.72,-272.85 156.15,-276.28"/>
# <text text-anchor="middle" x="121.58" y="-255.78" font-family="Times,serif" font-size="14.00" fill="white">Decision2</text>
# </g>
# <!-- Chance&#45;&gt;Decision2 -->
# <g id="edge3" class="edge">
# <title>Chance-&gt;Decision2</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points