# %% [markdown]
# # Influence diagram

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
import os

# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt
from IPython.display import display,HTML

import math

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %% [markdown]
# ## Build a Influence Diagram
#
# ### fast build with string

# %%
gum.fastID("A->*B->$C<-D<-*E->*G->H->*I<-D")
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x11ca9a600) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 4,
#   arcs: 8,
#   domainSize: 128
# }

# %% [markdown]
# ### bifxml format file

# %%
diag=gum.loadID("res/diag.bifxml")
gnb.showInfluenceDiagram(diag)

# %%
diag
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x11caace00) Influence Diagram{
#   chance: 5,
#   utility: 2,
#   decision: 4,
#   arcs: 12,
#   domainSize: 512
# }

# %% [markdown]
# ### the hard way :-)

# %%
F=diag.addChanceNode(gum.LabelizedVariable("F","F",2))
diag.addArc(diag.idFromName("decisionVar1"),F)

U=diag.addUtilityNode(gum.LabelizedVariable("U","U",1))
diag.addArc(diag.idFromName("decisionVar3"),U)
diag.addArc(diag.idFromName("F"),U)
gnb.showInfluenceDiagram(diag)

# %%
diag.cpt(F)[{'decisionVar1':0}]=[0.9,0.1]
diag.cpt(F)[{'decisionVar1':1}]=[0.3,0.7]

diag.utility(U)[{'F':0,'decisionVar3':0}]=2
diag.utility(U)[{'F':0,'decisionVar3':1}]=4
diag.utility(U)[{'F':1}]=[[0],[5]]

# %% [markdown]
# ## Optimization in an influence diagram (actually LIMID)

# %%
oil=gum.loadID("res/OilWildcatter.bifxml")
gnb.flow.row(oil,gnb.getInference(oil))
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="286pt" height="292pt" viewBox="0.00 0.00 286.29 291.52">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 287.52)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="#4a4a4a" cx="107.32" cy="-178.59" rx="51.02" ry="21.85"/>
# <text text-anchor="middle" x="107.32" y="-173.54" font-family="Times,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="#4a4a4a" points="135.9,-117.36 78.75,-117.36 78.75,-86.46 135.9,-86.46 135.9,-117.36"/>
# <text text-anchor="middle" x="107.32" y="-96.86" font-family="Times,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="108.32,-156.39 108.27,-155.1 108.23,-153.79 108.18,-152.46 108.13,-151.12 108.08,-149.76 108.03,-148.39 107.98,-147.01 107.93,-145.62 107.88,-144.23 107.83,-142.83 107.78,-141.43 107.72,-140.02 107.67,-138.62 107.62,-137.22 107.57,-135.82 107.52,-134.43 107.47,-133.04 107.42,-131.66 107.37,-130.3 107.32,-128.95 107.32,-128.95 107.27,-130.3 107.22,-131.66 107.17,-133.04 107.12,-134.43 107.07,-135.82 107.02,-137.22 106.97,-138.62 106.92,-140.02 106.87,-141.43 106.82,-142.83 106.76,-144.23 106.71,-145.62 106.66,-147.01 106.61,-148.39 106.56,-149.76 106.51,-151.12 106.46,-152.46 106.42,-153.79 106.37,-155.1 106.32,-156.39 108.32,-156.39"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" stroke-width="2" points="110.82,-130.56 107.32,-120.56 103.82,-130.56 110.82,-130.56"/>
# </g>
# <!-- OilContents -->
# <g id="node2" class="node">
# <title>OilContents</title>
# <ellipse fill="#808080" stroke="#4a4a4a" cx="56.32" cy="-261.67" rx="56.32" ry="21.85"/>
# <text text-anchor="middle" x="56.32" y="-256.62" font-family="Times,serif" font-size="14.00" fill="white">OilContents</text>
# </g>
# <!-- OilContents&#45;&gt;TestResult -->
# <g id="edge6" class="edge">
# <title>OilContents-&gt;TestResult</title>
# <path fill="none" stroke="#4a4a4a" d="M69.19,-240.21C74.99,-230.99 81.95,-219.92 88.33,-209.77"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="91.29,-211.65 93.65,-201.32 85.36,-207.92 91.29,-211.65"/>
# </g>
# <!-- Reward -->
# <g id="node6" class="node">
# <title>Reward</title>
# <polygon fill="#50508a" stroke="#4a4a4a" points="113.37,-25.23 90.35,-50.46 44.3,-50.46 21.27,-25.23 44.3,0 90.35,0 113.37,-25.23"/>
# <text text-anchor="middle" x="67.32" y="-20.18" font-family="Times,serif" font-size="14.00" fill="white">Reward</text>
# </g>
# <!-- OilContents&#45;&gt;Reward -->
# <g id="edge7" class="edge">
# <title>OilContents-&gt;Reward</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="
3, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css"

# %%
# a function to show results on decision nodes T and D
def show_decisions(ie):
    gnb.flow.row(ie.optimalDecision("Testing"),
                   ie.optimalDecision("Drilling"),
                   f"$${ie.MEU()['mean']:5.3f}\\ (stdev : {math.sqrt(ie.MEU()['variance']):5.3f})$$",
                   captions=["Strategy for T",
                             "Strategy for D",
                             "MEU and its standard deviation"])
    gnb.flow.row(ie.posterior("Testing"),ie.posteriorUtility("Testing"),
                   ie.posterior("Drilling"),ie.posteriorUtility("Drilling"),
                  captions=["Final decision for Testing","Final reward for Testing",
                            "Final decision for Drilling","Final reward for Drilling"])

ie=gum.ShaferShenoyLIMIDInference(oil) 

display(HTML("<h2>Inference in the LIMID optimizing the decisions nodes</h2>"))
ie.makeInference()
show_decisions(ie)
# Out:
# <h2>Inference in the LIMID optimizing the decisions nodes</h2>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td></tr>
# </table><br><center><small><em>Strategy for T</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>Drilling</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>TestResult</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>closed</center></th><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>open</center></th><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>diffuse</center></th><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td></tr>
# </table><br><center><small><em>Strategy for D</em></small></center></div><div class="floating-box">$$22.500\ (stdev : 87.457)$$<br><center><small><em>MEU and its standard deviation</em></small></center></div>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td></tr>
# </table><br><center><small><em>Final decision for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;padding: 3px;'>22.5000</td><td style='text-align:right;padding: 3px;'>20.0000</td></tr>
# </table><br><center><small><em>Final reward for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#b3ca64;text-align:right;padding: 3px;'>0.5900</td><td style='color:black;background-color:#cab364;text-align:right;padding: 3px;'>0.4100</td></tr>
# </table><br><center><small><em>Final decision for Drilling</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;padding: 3px;'>45.0847</td><td style='text-align:right;padding: 3px;'>-10.0000</td></tr>
# </table><br><center><small><em>Final reward for Drilling</em></small></center></div>

# %% [markdown]
# ## Graphical inference with evidence and targets (developped nodes)

# %%
gnb.sideBySide(oil,
               gnb.getInference(oil,evs={'TestResult':'closed'}),
               gnb.getInference(oil,evs={'TestResult':'open'}),
               gnb.getInference(oil,evs={'TestResult':'diffuse'}),
               oil,
               gnb.getInference(oil,evs={'OilContents':'Dry'}),
               gnb.getInference(oil,evs={'OilContents':'Wet'}),
               gnb.getInference(oil,evs={'OilContents':'Soaking'}),
               ncols=4)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="286pt" height="292pt" viewBox="0.00 0.00 286.29 291.52">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 287.52)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="#4a4a4a" cx="107.32" cy="-178.59" rx="51.02" ry="21.85"/>
# <text text-anchor="middle" x="107.32" y="-173.54" font-family="Times,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="#4a4a4a" points="135.9,-117.36 78.75,-117.36 78.75,-86.46 135.9,-86.46 135.9,-117.36"/>
# <text text-anchor="middle" x="107.32" y="-96.86" font-family="Times,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="108.32,-156.39 108.27,-155.1 108.23,-153.79 108.18,-152.46 108.13,-151.12 108.08,-149.76 108.03,-148.39 107.98,-147.01 107.93,-145.62 107.88,-144.23 107.83,-142.83 107.78,-141.43 107.72,-140.02 107.67,-138.62 107.62,-137.22 107.57,-135.82 107.52,-134.43 107.47,-133.04 107.42,-131.66 107.37,-130.3 107.32,-128.95 107.32,-128.95 107.27,-130.3 107.22,-131.66 107.17,-133.04 107.12,-134.43 107.07,-135.82 107.02,-137.22 106.97,-138.62 106.92,-140.02 106.87,-141.43 106.82,-142.83 106.76,-144.23 106.71,-145.62 106.66,-147.01 106.61,-148.39 106.56,-149.76 106.51,-151.12 106.46,-152.46 106.42,-153.79 106.37,-155.1 106.32,-156.39 108.32,-156.39"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" stroke-width="2" points
82"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="89.08,-59.45 81.28,-52.29 82.91,-62.75 89.08,-59.45"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="430pt" height="345pt" viewBox="0.00 0.00 430.24 344.89">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 340.89)">
# <title>structs</title>
# <text text-anchor="middle" x="211.12" y="-23.7" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">MEU 77.50 (stdev=104.73)</text>
# <text text-anchor="middle" x="211.12" y="-7.2" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.18ms</text>
# <!-- Testing -->
# <g id="node1" class="node">
# <title>Testing</title>
# <polygon fill="none" stroke="#000000" points="168.75,-331.89 30.75,-331.89 30.75,-289.89 168.75,-289.89 168.75,-331.89"/>
# <svg viewBox="0 0 181.554687 53.538125" width="138px" height="42px" preserveAspectRatio="xMinYMin meet" x="30.7482" y="-331.886"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-03-20T17:43:43.305633</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.8.3, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </r

# %% [markdown]
# ## Soft evidence on chance node

# %%
gnb.showInference(oil,evs={'OilContents':[0.7,0.5,0.8]})

# %% [markdown]
# ## Forced decision

# %%
gnb.showInference(oil,evs={'Drilling':'Yes'})

# %% [markdown]
# ## LIMID versus Influence Diagram
#
# The default inference for influence diagram actually an inference for LIMIDs. In order to use it for classical (and solvable) influence diagram, do not forget to add the sequence of decision nodes using `addNoForgettingAssumption`.

# %%
infdiag=gum.fastID("Chance->*Decision1->Chance2->$Utility<-Chance3<-*Decision2<-Chance->Utility")
infdiag
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x107010a00) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 2,
#   arcs: 7,
#   domainSize: 32
# }

# %%
ie=gum.ShaferShenoyLIMIDInference(infdiag)
try:
    ie.makeInference()
except gum.GumException as e:
    print(e)
# Out:
# [pyAgrum] Fatal error: This LIMID/Influence Diagram is not solvable.

# %%
ie.addNoForgettingAssumption(["Decision1","Decision2"])
gnb.sideBySide(ie.reducedLIMID(),ie.junctionTree(),gnb.getInference(infdiag,engine=ie))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="220pt" height="352pt" viewBox="0.00 0.00 220.27 351.66">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 347.66)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <ellipse fill="#808080" stroke="#4a4a4a" cx="165.59" cy="-321.81" rx="38.82" ry="21.85"/>
# <text text-anchor="middle" x="165.59" y="-316.76" font-family="Times,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="#9a5050" stroke="#4a4a4a" points="137.17,-263.96 68.02,-263.96 68.02,-233.06 137.17,-233.06 137.17,-263.96"/>
# <text text-anchor="middle" x="102.59" y="-243.46" font-family="Times,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="149.46,-301.04 148.24,-299.73 146.99,-298.39 145.73,-297.03 144.45,-295.65 143.15,-294.26 141.84,-292.85 140.51,-291.43 139.18,-290 137.84,-288.56 136.49,-287.11 135.15,-285.66 133.8,-284.21 132.45,-282.76 131.1,-281.32 129.76,-279.88 128.43,-278.45 127.1,-277.02 125.79,-275.61 124.49,-274.22 123.21,-272.84 123.21,-272.84 124.42,-274.28 125.64,-275.74 126.88,-277.22 128.13,-278.71 129.39,-280.21 130.65,-281.72 131.92,-283.23 133.19,-284.75 134.46,-286.27 135.74,-287.78 137,-289.29 138.27,-290.8 139.52,-292.3 140.77,-293.79 142.01,-295.26 143.23,-296.72 144.44,-298.17 145.63,-299.59 146.81,-300.99 147.96,-302.36 149.46,-301.04"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" stroke-width="2" points="126.97,-271.82 117.73,-266.64 121.73,-276.45 126.97,-271.82"/>
# </g>
# <!-- Decision2 -->
# <g id="node5" class="node">
# <title>Decision2</title>
# <polygon fill="#9a5050" stroke="#4a4a4a" points="183.17,-197.06 114.02,-197.06 114.02,-166.16 183.17,-166.16 183.17,-197.06"/>
# <text text-anchor="middle" x="148.59" y="-176.56" font-family="Times,serif" font-size="14.00" fill="white">Decision2</text>
# </g>
# <!-- Chance&#45;&gt;Decision2 -->
# <g id="edge3" class="edge">
# <title>Chance-&gt;Decision2</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points

# <!-- Chance&#45;Chance2&#45;Decision1&#45;Decision2+Chance&#45;Chance2&#45;Chance3&#45;Decision2 -->
# <g id="node3" class="node">
# <title>Chance-Chance2-Decision1-Decision2+Chance-Chance2-Chance3-Decision2</title>
# <polygon fill="palegreen" stroke="#4a4a4a" points="156.78,-84.63 65.4,-84.63 65.4,-72 156.78,-72 156.78,-84.63"/>
# <text text-anchor="middle" x="111.09" y="-75.59" font-family="Times,serif" font-size="8.0

# %% [markdown]
# ## Customizing visualization of the results
#
# Using `pyAgrum.config`, it is possible to adapt the graphical representations for Influence Diagram (see the notebook 99-Tools_configForPyAgrum.ipynb).

# %%
gum.config.reset()
gnb.showInference(infdiag,engine=ie,size="7!")

# %% [markdown]
# Many visual options can be changed when displaing an inference (especially for influence diagrams)

# %%
# do not show inference time
gum.config["notebook","show_inference_time"]=False
# more digits for probabilities
gum.config["notebook","histogram_horizontal_visible_digits"]=3

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# specificic for influence diagram :
# more digits for utilities
gum.config["influenceDiagram","utility_visible_digits"]=5
# disabling stdev for utility and MEU
gum.config["influenceDiagram","utility_show_stdev"]=False
# showing loss (=-utility) and mEL (minimum Expected Loss) instead of MEU
gum.config["influenceDiagram","utility_show_loss"]=True

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# visual changes for influence diagram and inference
gum.config.reset()
gum.config.push() # keep the current state
gum.config['notebook','graph_rankdir']='LR'
gnb.sideBySide(infdiag,gnb.getInference(infdiag,engine=ie,targets=["Decision1","Chance3"]))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="431pt" height="133pt" viewBox="0.00 0.00 431.05 132.52">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 128.52)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <ellipse fill="#808080" stroke="#4a4a4a" cx="38.82" cy="-40.67" rx="38.82" ry="21.85"/>
# <text text-anchor="middle" x="38.82" y="-35.62" font-family="Times,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="#9a5050" stroke="#4a4a4a" points="182.79,-111.12 113.64,-111.12 113.64,-80.22 182.79,-80.22 182.79,-111.12"/>
# <text text-anchor="middle" x="148.22" y="-90.62" font-family="Times,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="67.86,-56.16 69.65,-57.02 71.46,-57.9 73.31,-58.79 75.17,-59.69 77.06,-60.6 78.97,-61.52 80.89,-62.45 82.83,-63.39 84.78,-64.33 86.75,-65.28 88.72,-66.23 90.69,-67.19 92.67,-68.14 94.65,-69.1 96.63,-70.05 98.6,-71.01 100.57,-71.96 102.53,-72.9 104.48,-73.84 106.41,-74.78 106.41,-74.78 104.52,-73.75 102.62,-72.72 100.71,-71.69 98.79,-70.65 96.86,-69.6 94.93,-68.55 93,-67.51 91.06,-66.46 89.13,-65.41 87.21,-64.37 85.3,-63.33 83.39,-62.3 81.5,-61.27 79.62,-60.26 77.75,-59.25 75.91,-58.25 74.09,-57.26 72.29,-56.29 70.52,-55.32 68.77,-54.38 67.86,-56.16"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" stroke-width="2" points="103.13,-77.03 113.63,-78.47 106.32,-70.8 103.13,-77.03"/>
# </g>
# <!-- Decision2 -->
# <g id="node5" class="node">
# <title>Decision2</title>
# <polygon fill="#9a5050" stroke="#4a4a4a" points="182.79,-56.12 113.64,-56.12 113.64,-25.22 182.79,-25.22 182.79,-56.12"/>
# <text text-anchor="middle" x="148.22" y="-35.62" font-family="Times,serif" font-size="14.00" fill="white">Decision2</text>
# </g>
# <!-- Chance&#45;&gt;Decision2 -->
# <g id="edge3" class="edge">
# <title>Chance-&gt;Decision2</title>
# <polygon fill="#4a4a4a" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="77.99,-41.67 79.16,-41.63 80.33,-41.58 81.52,-41.53 82.7,-41.48 83.9,-41.43 85.09,-41.38 86.3,-41.33 87.5,-41.28 88.71,-41.23 89.92,-41.18 91.13,-41.13 92.34,-41.08 93.55,-41.03 94.77,-40.98 95.98,-40.93 97.19,-40.88 98.4,-40.83 99.61,-40.78 100.81,-40.72 102.01,-40.67 102.01,-40.67 100.81,-40.62 99.61,-40.57 98.4,-40.52 97.19,-40.47 95.98,-40.42 94.77,-40.37 93.55,-40.32 92.34,-40.27 91.13,-40.22 89.92,-40.17 88.71,-40.12 87.5,-40.07 86.3,-40.02 85.09,-39.97 83.9,-39.92 82.7,-39.87 81.52,-39.82 80.33,-39.77 79.16,-39.72 77.99,-39.67 77.99,-41.67"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" stroke-width="2" points="100.43,-44.18 110.43,-40.67 100.43,-37.18 100.43,-44.18"/>
# </g>
# <!-- Utility -->
# <g id="node6" class="node">
# <title>Utility</title>
# <polygon fill="#50508a" stroke="#4a4a4a" points="423.05,-40.67 402.79,-65.9 362.25,-65.9 341.98,-40.67 362.25,-15.45 402.79,-15.45 423.05,-40.67"/>
# <text text-anchor="middle" x="382.52" y="-35.62" font-family="Times,serif" font-size="14.00" fill="white">Utility</text>
# </g>
# <!-- Chance&#45;&gt;Utility -->
# <g id="edge2" class="edge">
# <title>Chance-&gt;Utility</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="M71.34,-28.52C84.26,-24.04 99.48,-19.4 113.64,-16.67 197.63,-0.49 222.05,6.88 305.98,-9.67 318.44,-12.13 331.42,-16.66 343.05,-21.52"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="341.33,-24.59 351.9,-25.41 344.15,-18.18 341.33,-24.59"/>
# </g>
# <!-- Chance2 -->
# <g id="node2" class="node">
# <title>Chance2</title>
# <ellipse fill="#808080" stroke="#4a4a4a" cx="262.38" cy="-102.67" rx="43.59" ry="21.85"/>
# <text text-anchor="middle" x="262.38" y="-97.62" font-family="Times,serif" font-size="14.00" fill="white">Chance2</text>
# </g>
# <!-- Chance2&#45;&gt;Utility -->
# <g id="edge5" class="edge">
# <title>Chance2-&gt;Utility</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="M293.5,-86.87C308.78,-78.85 327.5,-69.02 343.74,-60.5"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="344.92,-63.84 352.14,-56.09 341.66,-57.64 344.92,-63.84"/>
# </g>
# <!-- Chance3 -->
# <g id="node3" class="node">
# <title>Chance3</title>
# <ellipse fill="#808080" stroke="#4a4a4a" cx="262.38" cy="-40.67" rx="43.59" ry="21.85"/>
# <text text-anchor="middle" x="262.38" y="-35.62" font-family="Times,serif" font-size="14.00" fill="white">Chance3</text>
# </g>
# <!-- Chance3&#45;&gt;Utility -->
# <g id="edge6" class="edge">
# <title>Chance3-&gt;Utility</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="M306.37,-40.67C314.08,-40.67 322.19,-40.67 330.11,-40.67"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="330,-44.17 340,-40.67 330,-37.17 330,-44.17"/>
# </g>
# <!-- Decision1&#45;&gt;Chance2 -->
# <g id="edge4" class="edge">
# <title>Decision1-&gt;Chance2</title>
# <path fill="none" stroke="#4a4a4a" d="M183.17,-97.79C190.89,-98.28 199.27,-98.8 207.58,-99.32"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="207.09,-102.79 217.29,-99.92 207.53,-95.81 207.09,-102.79"/>
# </g>
# <!-- Decision2&#45;&gt;Chance3 -->
# <g id="edge7" class="edge">
# <title>Decision2-&gt;Chance3</title>
# <path fill="none" stroke="#4a4a4a" d="M183.17,-40.67C190.71,-40.67 198.89,-40.67 207.01,-40.67"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="206.88,-44.17 216.88,-40.67 206.88,-37.17 206.88,-44.17"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="576pt" height="194pt" viewBox="0.00 0.00 576.00 194.47">
# <g id="graph0" class="graph" transform="scale(0.93049 0.93049) rotate(0) translate(4 205)">
# <title>structs</title>
# <text text-anchor="middle" x="305.51" y="-23.7" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">MEU 21.60 (stdev=10.97)</text>
# <text text-anchor="middle" x="305.51" y="-7.2" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.23ms</text>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <ellipse fill="#808080" stroke="#000000" cx="34.05" cy="-121" rx="34.05" ry="18.14"/>
# <text text-anchor="middle" x="34.05" y="-117.12" font-family="DejaVu Sans" font-size="10.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node2" class="node">
# <title>Decision1</title>
# <polygon fill="none" stroke="#000000" points="235.09,-201 104.09,-201 104.09,-149 235.09,-149 235.09,-201"/>
# <svg viewBox="0 0 171.771875 66.9755" width="131px" height="52px" preserveAspectRatio="xMinYMin meet" x="104.094" y="-201"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-03-20T17:43:48.817800</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.8.3, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.9755  L 171.771875 66.9755  L 171.771875 0  L 0 0  z " style="fill: #9a5050"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 56.571875 59.8755  L 168.171875 59.8755  L 168.171875 32.1555  L 56.571875 32.1555  z " style="fill: #ffffff"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 56.571875 59.8755  L 138.796383 59.8755  L 138.796383 47.5555  L 56.5718

# %%
# more visual changes for influence diagram and inference
gum.config.pop() # back to the last state

#shape (https://graphviz.org/doc/info/shapes.html)
gum.config["influenceDiagram","chance_shape"] = "cylinder"
gum.config["influenceDiagram","utility_shape"] = "star"
gum.config["influenceDiagram","decision_shape"] = "box3d"

#colors
gum.config["influenceDiagram","default_chance_bgcolor"] = "green"
gum.config["influenceDiagram","default_utility_bgcolor"] = "MediumVioletRed"
gum.config["influenceDiagram","default_decision_bgcolor"] = "DarkSalmon"

gum.config["influenceDiagram","utility_show_stdev"]=False

gnb.sideBySide(infdiag,gnb.getInference(infdiag,engine=ie,targets=["Decision1","Chance3"]))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width