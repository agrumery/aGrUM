# %% [markdown]
# # Influence diagram

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
import os

# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt
from IPython.display import display,HTML

import math

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %% [markdown]
# ## Build a Influence Diagram
#
# ### fast build with string

# %%
gum.fastID("A->*B->$C<-D<-*E->*G->H->*I<-D")
# Out:
# (pyAgrum.InfluenceDiagram<double>@000001F8A04E0FE0) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 4,
#   arcs: 8,
#   domainSize: 128
# }

# %% [markdown]
# ### bifxml format file

# %%
diag=gum.loadID("res/diag.bifxml")
gnb.showInfluenceDiagram(diag)

# %%
diag
# Out:
# (pyAgrum.InfluenceDiagram<double>@000001F8A04E35C0) Influence Diagram{
#   chance: 5,
#   utility: 2,
#   decision: 4,
#   arcs: 12,
#   domainSize: 512
# }

# %% [markdown]
# ### the hard way :-)

# %%
F=diag.addChanceNode(gum.LabelizedVariable("F","F",2))
diag.addArc(diag.idFromName("decisionVar1"),F)

U=diag.addUtilityNode(gum.LabelizedVariable("U","U",1))
diag.addArc(diag.idFromName("decisionVar3"),U)
diag.addArc(diag.idFromName("F"),U)
gnb.showInfluenceDiagram(diag)

# %%
diag.cpt(F)[{'decisionVar1':0}]=[0.9,0.1]
diag.cpt(F)[{'decisionVar1':1}]=[0.3,0.7]

diag.utility(U)[{'F':0,'decisionVar3':0}]=2
diag.utility(U)[{'F':0,'decisionVar3':1}]=4
diag.utility(U)[{'F':1}]=[[0],[5]]

# %% [markdown]
# ## Optimization in an influence diagram (actually LIMID)

# %%
oil=gum.loadID("res/OilWildcatter.bifxml")
gnb.flow.row(oil,gnb.getInference(oil))
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="293pt" height="287pt" viewBox="0.00 0.00 293.18 287.26">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 283.26)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="black" cx="108.38" cy="-176" rx="52.61" ry="21.32"/>
# <text text-anchor="middle" x="108.38" y="-170.58" font-family="Times New Roman,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="black" points="135.46,-115.38 81.31,-115.38 81.31,-85.23 135.46,-85.23 135.46,-115.38"/>
# <text text-anchor="middle" x="108.38" y="-94.88" font-family="Times New Roman,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="109.38,-154.47 109.33,-153.15 109.29,-151.81 109.24,-150.45 109.19,-149.07 109.14,-147.67 109.09,-146.26 109.04,-144.84 108.99,-143.41 108.94,-141.98 108.89,-140.54 108.84,-139.09 108.79,-137.65 108.73,-136.2 108.68,-134.76 108.63,-133.32 108.58,-131.89 108.53,-130.47 108.48,-129.06 108.43,-127.66 108.38,-126.27 108.38,-126.27 108.33,-127.66 108.28,-129.06 108.23,-130.47 108.18,-131.89 108.13,-133.32 108.08,-134.76 108.03,-136.2 107.98,-137.65 107.93,-139.09 107.88,-140.54 107.82,-141.98 107.77,-143.41 107.72,-144.84 107.67,-146.26 107.62,-147.67 107.57,-149.07 107.52,-150.45 107.48,-151.81 107.43,-153.15 107.38,-154.47 109.38,-154.47"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="111.88,-128.43 108.38,-118.43 104.88,-128.43 111.88,-128.43"/>
# </g>
# <!-- OilContents -->
# <g id="node2" class="node">
# <title>OilContents</title>
# <ellipse fill="#808080" stroke="black" cx="57.38" cy="-257.94" rx="57.38" ry="21.32"/>
# <text text-anchor="middle" x="57.38" y="-252.51" font-family="Times New Roman,serif" font-size="14.00" fill="white">OilContents</text>
# </g>
# <!-- OilContents&#45;&gt;TestResult -->
# <g id="edge6" class="edge">
# <title>OilContents-&gt;TestResult</title>
# <path fill="none" stroke="black" d="M70.25,-236.77C76.17,-227.49 83.3,-216.31 89.79,-206.14"/>
# <polygon fill="black" stroke="black" points="93.09,-208.48 95.52,-198.17 87.19,-204.71 93.09,-208.48"/>
# </g>
# <!-- Reward -->
# <g id="node6" class="node">
# <title>Reward</title>
# <polygon fill="#50508a" stroke="black" points="114.66,-24.62 91.02,-49.23 43.74,-49.23 20.11,-24.62 43.74,0 91.02,0 114.66,-24.62"/>
# <text text-anchor="middle" x="67.38" y="-19.19" font-family="Times New Roman,serif" font-size="14.00" fill="white">Reward</text>
# </g>
# <!-- OilContents&#45;&gt;Reward -->
# <g id="edge7" class="edge">
# <title>OilContents-&gt;Reward</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M52.34,-236.22C50.02,-225.64 47.53,-212.52 46.38,-200.62 41.66,-151.84 51.07,-95.59 58.77,-60.32"/>
# <polygon fill="black" stroke="black" points="62.4,-61.17 61.19,-50.64 55.57,-59.62 62.4,-61.17"/>
# </g>
# <!-- Testing -->
# <g id="node3" class="node">
# <title>Testing</title>
# <polygon fill="#9a5050" stroke="black" points="217.21,-273.01 161.56,-273.01 161.56,-242.86 217.21,-242.86 217.21,-273.01"/>
# <text text-anchor="middle" x="189.38" y="-252.51" font-family="Times New Roman,serif" font-size="14.00" fill="white">Testing</text>
# </g>
# <!-- Testing&#45;&gt;TestResult -->
# <g id="edge2" class="edge">
# <title>Testing-&gt;TestResult</title>
# <path fill="none" stroke="black" d="M174.9,-242.65C163.95,-231.84 148.59,-216.68 135.38,-203.65"/>
# <polygon fill="black" stroke="black" points="138.49,-201.81 128.91,-197.28 133.57,-206.79 138.49,-201.81"/>
# </g>
# <!-- Testing&#45;&gt;Drilling -->
# <g id="edge1" class="edge">
# <title>Testing-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="190.87,-242.53 190.83,-239.18 190.75,-235.55 190.61,-231.67 190.41,-227.58 190.13,-223.29 189.76,-218.82 189.3,-214.21 188.74,-209.47 188.06,-204.62 187.27,-199.7 186.34,-194.72 185.28,-189.7 184.06,-184.68 182.69,-179.67 181.15,-174.7 179.44,-169.79 177.54,-164.96 175.45,-160.25 173.15,-155.66 170.64,-151.23 169.57,-149.51 168.45,-147.82 167.28,-146.15 166.06,-144.51 164.8,-142.89 163.5,-141.3 162.16,-139.74 160.78,-138.2 159.37,-136.69 157.93,-135.21 156.47,-133.75 154.98,-132.32 153.47,-130.92 151.94,-129.55 150.4,-128.21 148.84,-126.89 147.28,-125.61 145.7,-124.35 144.13,-123.13 142.55,-121.93 142.55,-121.93 144.11,-123.15 145.67,-124.4 147.22,-125.68 148.77,-126.98 150.3,-128.32 151.82,-129.68 153.33,-131.08 154.82,-132.5 156.28,-133.94 157.72,-135.42 159.13,-136.92 160.51,-138.44 161.86,-140 163.17,-141.57 164.44,-143.18 165.67,-144.8 166.86,-146.45 168,-148.12 169.09,-149.82 170.12,-151.54 172.55,-155.98 174.76,-160.56 176.77,-165.28 178.58,-170.1 180.21,-175 181.67,-179.96 182.96,-184.96 184.09,-189.96 185.07,-194.96 185.92,-199.92 186.64,-204.83 187.24,-209.65 187.73,-214.37 188.12,-218.96 188.41,-223.4 188.63,-227.67 188.77,-231.74 188.86,-235.59 188.88,-239.19 188.87,-242.54 190.87,-242.53"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="146.04,-119.7 135.86,-116.75 141.98,-125.4 146.04,-119.7"/>
# </g>
# <!-- Cost -->
# <g id="node5" class="node">
# <title>Cost</title>
# <polygon fill="#50508a" stroke="black" points="285.18,-176 268.28,-200.62 234.48,-200.62 217.58,-176 234.48,-151.38 268.28,-151.38 285.18,-176"/>
# <text text-anchor="middle" x="251.38" y="-170.58" font-family="Times New Roman,serif" font-size="14.00" fill="white">Cost</text>
# </g>
# <!-- Testing&#45;&gt;Cost -->
# <g id="edge3" class="edge">
# <title>Testing-&gt;Cost</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M200.47,-242.65C207.87,-233.11 217.89,-220.18 227.09,-208.32"/>
# <polygon fill="black" stroke="black" points="230.23,-210.99 233.59,-200.94 224.69,-206.7 230.23,-210.99"/>
# </g>
# <!-- Drilling&#45;&gt;Reward -->
# <g id="edge4" class="edge">
# <title>Drilling-&gt;Reward</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M100.28,-84.75C96.2,-77.42 91.07,-68.2 86.09,-59.24"/>
# <polygon fill="black" stroke="black" points="88.71,-57.76 80.79,-50.72 82.59,-61.16 88.71,-57.76"/>
# </g>
# </g>
# </svg></div><div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="450pt" height="343pt" viewBox="0.00 0.00 449.84 343.39">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 339.39)">
# <title>structs</title>
# <text text-anchor="middle" x="220.92" y="-22.2" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">MEU 22.50 (stdev=87.46)</text>
# <text text-anchor="middle" x="220.92" y="-6.45" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.00ms</text>
# <!-- Testing -->
# <g id="node1" class="node">
# <title>Testing</title>
# <polygon fill="none" stroke="#000000" points="175.9,-330.39 37.9,-330.39 37.9,-288.39 175.9,-288.39 175.9,-330.39"/>
# <svg viewBox="0 0 181.554687 53.538125" width="138px" height="42px" preserveAspectRatio="xMinYMin meet" x="37.9027" y="-330.386"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2023-07-15T19:01:00.750550</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.7.2, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <

# %%
# a function to show results on decision nodes T and D
def show_decisions(ie):
    gnb.flow.row(ie.optimalDecision("Testing"),
                   ie.optimalDecision("Drilling"),
                   f"$${ie.MEU()['mean']:5.3f}\\ (stdev : {math.sqrt(ie.MEU()['variance']):5.3f})$$",
                   captions=["Strategy for T",
                             "Strategy for D",
                             "MEU and its standard deviation"])
    gnb.flow.row(ie.posterior("Testing"),ie.posteriorUtility("Testing"),
                   ie.posterior("Drilling"),ie.posteriorUtility("Drilling"),
                  captions=["Final decision for Testing","Final reward for Testing",
                            "Final decision for Drilling","Final reward for Drilling"])

ie=gum.ShaferShenoyLIMIDInference(oil) 

display(HTML("<h2>Inference in the LIMID optimizing the decisions nodes</h2>"))
ie.makeInference()
show_decisions(ie)
# Out:
# <h2>Inference in the LIMID optimizing the decisions nodes</h2>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# </table><br><center><small><em>Strategy for T</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>Drilling</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>TestResult</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>closed</center></th><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>open</center></th><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>diffuse</center></th><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td></tr>
# </table><br><center><small><em>Strategy for D</em></small></center></div><div class="floating-box">$$22.500\ (stdev : 87.457)$$<br><center><small><em>MEU and its standard deviation</em></small></center></div>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# </table><br><center><small><em>Final decision for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;'>22.5000</td><td style='text-align:right;'>20.0000</td></tr>
# </table><br><center><small><em>Final reward for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#b3ca64;text-align:right;'>0.5900</td><td style='color:black;background-color:#cab364;text-align:right;'>0.4100</td></tr>
# </table><br><center><small><em>Final decision for Drilling</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;'>45.0847</td><td style='text-align:right;'>-10.0000</td></tr>
# </table><br><center><small><em>Final reward for Drilling</em></small></center></div>

# %% [markdown]
# ## Graphical inference with evidence and targets (developped nodes)

# %%
gnb.sideBySide(oil,
               gnb.getInference(oil,evs={'TestResult':'closed'}),
               gnb.getInference(oil,evs={'TestResult':'open'}),
               gnb.getInference(oil,evs={'TestResult':'diffuse'}),
               oil,
               gnb.getInference(oil,evs={'OilContents':'Dry'}),
               gnb.getInference(oil,evs={'OilContents':'Wet'}),
               gnb.getInference(oil,evs={'OilContents':'Soaking'}),
               ncols=4)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="293pt" height="287pt" viewBox="0.00 0.00 293.18 287.26">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 283.26)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="black" cx="108.38" cy="-176" rx="52.61" ry="21.32"/>
# <text text-anchor="middle" x="108.38" y="-170.58" font-family="Times New Roman,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="black" points="135.46,-115.38 81.31,-115.38 81.31,-85.23 135.46,-85.23 135.46,-115.38"/>
# <text text-anchor="middle" x="108.38" y="-94.88" font-family="Times New Roman,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="109.38,-154.47 109.33,-153.15 109.29,-151.81 109.24,-150.45 109.19,-149.07 109.14,-147.67 109.09,-146.26 109.04,-144.84 108.99,-143.41 108.94,-141.98 108.89,-140.54 108.84,-139.09 108.79,-137.65 108.73,-136.2 108.68,-134.76 108.63,-133.32 108.58,-131.89 108.53,-130.47 108.48,-129.06 108.43,-127.66 108.38,-126.27 108.38,-126.27 108.33,-127.66 108.28,-129.06 108.23,-130.47 108.18,-131.89 108.13,-133.32 108.08,-134.76 108.03,-136.2 107.98,-137.65 107.93,-139.09 107.88,-140.54 107.82,-141.98 107.77,-143.41 107.72,-144.84 107.67,-146.26 107.62,-147.67 107.57,-149.07 107.52,-150.45 107.48,-151.81 107.43,-153.15 107.38,-154.47 109.38,-154.47"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="111.88,-128.43 108.38,-118.43 104.88,-128.43 111.88,-128.43"/>
# </g>
# <!-- OilContents -->
# <g id="node2" class="node">
# <title>OilContents</title>
# <ellipse fill="#808080" stroke="black" cx="57.38" cy="-257.94" rx="57.38" ry="21.32"/>
# <text text-anchor="middle" x="57.38" y="-252.51" font-family="Times New Roman,serif" font-size="14.00" fill="white">OilContents</text>
# </g>
# <!-- OilContents&#45;&gt;TestResult -->
# <g id="edge6" class="edge">
# <title>OilContents-&gt;TestResult</title>
# <path fill="none" stroke="black" d="M70.25,-236.77C76.17,-227.49 83.3,-216.31 89.79,-206.14"/>
# <polygon fill="black" stroke="black" points="93.09,-208.48 95.52,-198.17 87.19,-204.71 93.09,-208.48"/>
# </g>
# <!-- Reward -->
# <g id="node6" class="node">
# <title>Reward</title>
# <polygon fill="#50508a" stroke="black" points="114.66,-24.62 91.02,-49.23 43.74,-49.23 20.11,-24.62 43.74,0 91.02,0 114.66,-24.62"/>
# <text text-anchor="middle" x="67.38" y="-19.19" font-family="Times New Roman,serif" font-size="14.00" fill="white">Reward</text>
# </g>
# <!-- OilContents&#45;&gt;Reward -->
# <g id="edge7" class="edge">
# <title>OilContents-&gt;Reward</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M52.34,-236.22C50.02,-225.64 47.53,-212.52 46.38,-200.62 41.66,-151.84 51.07,-95.59 58.77,-60.32"/>
# <polygon fill="black" stroke="black" points="62.4,-61.17 61.19,-50.64 55.57,-59.62 62.4,-61.17"/>
# </g>
# <!-- Testing -->
# <g id="node3" class="node">
# <title>Testing</title>
# <polygon fill="#9a5050" stroke="black" points="217.21,-273.01 161.56,-273.01 161.56,-242.86 217.21,-242.86 217.21,-273.01"/>
# <text text-anchor="middle" x="189.38" y="-252.51" font-family="Times New Roman,serif" font-size="14.00" fill="white">Testing</text>
# </g>
# <!-- Testing&#45;&gt;TestResult -->
# <g id="edge2" class="edge">
# <title>Testing-&gt;TestResult</title>
# <path fill="none" stroke="black" d="M174.9,-242.65C163.95,-231.84 148.59,-216.68 135.38,-203.65"/>
# <polygon fill="black" stroke="black" points="138.49,-201.81 128.91,-197.28 133.57,-206.79 138.49,-201.81"/>
# </g>
# <!-- Testing&#45;&gt;Drilling -->
# <g id="edge1" class="edge">
# <title>Testing-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="190.87,-242.53 190.83,-239.18 190.75,-235.55 190.61,-231.67 190.41,-227.58 190.13,-223.29 189.76,-218.82 189.3,-214.21 188.74,-209.47 188.06,-204.62 187.27,-199.7 186.34,-194.72 185.28,-189.7 184.06,-184.68 182.69,-179.67 181.15,-174.7 179.44,-169.79 177.54,-164.96 175.45,-160.25 173.15,-155.66 170.64,-151.23 169.57,-149.51 168.45,-147.82 167.28,-146.15 166.06,-144.51 164.8,-142.89 163.5,-141.3 162.16,-139.74 160.78,-138.2 159.37,-136.69 157.93,-135.21 156.47,-133.75 154.98,-132.32 153.47,-130.92 151.94,-129.55 150.4,-128.21 148.84,-126.89 147.28,-125.61 145.7,-124.35 144.13,-123.13 142.55,-121.93 142.55,-121.93 144.11,-123.15 145.67,-124.4 147.22,-125.68 148.77,-126.98 150.3,-128.32 151.82,-129.68 153.33,-131.08 154.82,-132.5 156.28,-133.94 157.72,-135.42 159.13,-136.92 160.51,-138.44 161.86,-140 163.17,-141.57 164.44,-143.18 165.67,-144.8 166.86,-146.45 168,-148.12 169.09,-149.82 170.12,-151.54 172.55,-155.98 174.76,-160.56 176.77,-165.28 178.58,-170.1 180.21,-175 181.67,-179.96 182.96,-184.96 184.09,-189.96 185.07,-194.96 185.92,-199.92 186.64,-204.83 187.24,-209.65 187.73,-214.37 188.12,-218.96 188.41,-223.4 188.63,-227.67 188.77,-231.74 188.86,-235.59 188.88,-239.19 188.87,-242.54 190.87,-242.53"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="146.04,-119.7 135.86,-116.75 141.98,-125.4 146.04,-119.7"/>
# </g>
# <!-- Cost -->
# <g id="node5" class="node">
# <title>Cost</title>
# <polygon fill="#50508a" stroke="black" points="285.18,-176 268.28,-200.62 234.48,-200.62 217.58,-176 234.48,-151.38 268.28,-151.38 285.18,-176"/>
# <text text-anchor="middle" x="251.38" y="-170.58" font-family="Times New Roman,serif" font-size="14.00" fill="white">Cost</text>
# </g>
# <!-- Testing&#45;&gt;Cost -->
# <g id="edge3" class="edge">
# <title>Testing-&gt;Cost</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M200.47,-242.65C207.87,-233.11 217.89,-220.18 227.09,-208.32"/>
# <polygon fill="black" stroke="black" points="230.23,-210.99 233.59,-200.94 224.69,-206.7 230.23,-210.99"/>
# </g>
# <!-- Drilling&#45;&gt;Reward -->
# <g id="edge4" class="edge">
# <title>Drilling-&gt;Reward</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M100.28,-84.75C96.2,-77.42 91.07,-68.2 86.09,-59.24"/>
# <polygon fill="black" stroke="black" points="88.71,-57.76 80.79,-50.72 82.59,-61.16 88.71,-57.76"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="452pt" height="343pt" viewBox="0.00 0.00 451.74 343.39">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 339.39)">
# <title>structs</title>
# <text text-anchor="middle" x="221.87" y="-22.2" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">MEU 77.50 (stdev=104.73)</text>
# <text text-anchor="middle" x="221.87" y="-6.45" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">Inference in   5.05ms</text>
# <!-- Testing -->
# <g id="node1" class="node">
# <title>Testing</title>
# <polygon fill="none" stroke="#000000" points="175.9,-330.39 37.9,-330.39 37.9,-288.39 175.9,-288.39 175.9,-330.39"/>
# <svg viewBox="0 0 181.554687 53.538125" width="138px" height="42px" preserveAspectRatio="xMinYMin meet" x="37.8973" y="-330.386"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2023-07-15T19:01:01.360481</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.7.2, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator

# %% [markdown]
# ## Soft evidence on chance node

# %%
gnb.showInference(oil,evs={'OilContents':[0.7,0.5,0.8]})

# %% [markdown]
# ## Forced decision

# %%
gnb.showInference(oil,evs={'Drilling':'Yes'})

# %% [markdown]
# ## LIMID versus Influence Diagram
#
# The default inference for influence diagram actually an inference for LIMIDs. In order to use it for classical (and solvable) influence diagram, do not forget to add the sequence of decision nodes using `addNoForgettingAssumption`.

# %%
infdiag=gum.fastID("Chance->*Decision1->Chance2->$Utility<-Chance3<-*Decision2<-Chance->Utility")
infdiag
# Out:
# (pyAgrum.InfluenceDiagram<double>@000001F8A04E2F70) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 2,
#   arcs: 7,
#   domainSize: 32
# }

# %%
ie=gum.ShaferShenoyLIMIDInference(infdiag)
try:
    ie.makeInference()
except gum.GumException as e:
    print(e)
# Out:
# [pyAgrum] Fatal error: This LIMID/Influence Diagram is not solvable.

# %%
ie.addNoForgettingAssumption(["Decision1","Decision2"])
gnb.sideBySide(ie.reducedLIMID(),ie.junctionTree(),gnb.getInference(infdiag,engine=ie))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="224pt" height="347pt" viewBox="0.00 0.00 224.30 346.81">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 342.81)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <ellipse fill="#808080" stroke="black" cx="168.65" cy="-317.49" rx="39.88" ry="21.32"/>
# <text text-anchor="middle" x="168.65" y="-312.07" font-family="Times New Roman,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="#9a5050" stroke="black" points="140.6,-260.17 70.7,-260.17 70.7,-230.02 140.6,-230.02 140.6,-260.17"/>
# <text text-anchor="middle" x="105.65" y="-239.67" font-family="Times New Roman,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="152.85,-297.33 151.58,-295.99 150.29,-294.62 148.98,-293.22 147.65,-291.81 146.3,-290.38 144.94,-288.93 143.56,-287.47 142.18,-285.99 140.78,-284.51 139.38,-283.03 137.98,-281.54 136.58,-280.05 135.18,-278.56 133.78,-277.07 132.39,-275.59 131,-274.12 129.63,-272.67 128.27,-271.22 126.93,-269.8 125.6,-268.39 125.6,-268.39 126.85,-269.86 128.12,-271.35 129.41,-272.86 130.71,-274.39 132.01,-275.93 133.33,-277.47 134.65,-279.03 135.98,-280.58 137.3,-282.14 138.63,-283.7 139.95,-285.26 141.27,-286.81 142.58,-288.35 143.88,-289.88 145.17,-291.39 146.44,-292.89 147.7,-294.37 148.94,-295.83 150.16,-297.26 151.36,-298.66 152.85,-297.33"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="129.79,-267.59 120.52,-262.47 124.58,-272.26 129.79,-267.59"/>
# </g>
# <!-- Decision2 -->
# <g id="node5" class="node">
# <title>Decision2</title>
# <polygon fill="#9a5050" stroke="black" points="186.6,-194.02 116.7,-194.02 116.7,-163.87 186.6,-163.87 186.6,-194.02"/>
# <text text-anchor="middle" x="151.65" y="-173.52" font-family="Times New Roman,serif" font-size="14.00" fill="white">Decision2</text>
# </g>
# <!-- Chance&#45;&gt;Decision2 -->
# <g id="edge3" class="edge">
# <title>Chance-&gt;Decision2</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="167.06,-295.63 166.55,-291.87 166.01,-287.89 165.45,-283.72 164.86,-279.38 164.25,-274.89 163.62,-270.27 162.98,-265.55 162.33,-260.75 161.67,-255.89 161.01,-250.99 160.34,-246.08 159.68,-241.18 159.02,-236.32 158.37,-231.5 157.72,-226.77 157.1,-222.13 156.48,-217.62 155.89,-213.26 155.32,-209.06 154.78,-205.05 154.78,-205.05 155.23,-209.07 155.71,-213.28 156.21,-217.66 156.72,-222.18 157.25,-226.83 157.79,-231.58 158.33,-236.4 158.89,-241.28 159.45,-246.2 160,-251.12 160.56,-256.03 161.11,-260.9 161.66,-265.72 162.2,-270.45 162.72,-275.08 163.23,-279.58 163.73,-283.94 164.2,-288.12 164.65,-292.11 165.08,-295.88 167.06,-295.63"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="158.13,-206.67 153.43,-197.18 151.19,-207.54 158.13,-206.67"/>
# </g>
# <!-- Utility -->
# <g id="node6" class="node">
# <title>Utility</title>
# <polygon fill="#50508a" stroke="black" points="190.36,-24.62 171,-49.23 132.3,-49.23 112.95,-24.62 132.3,0 171,0 190.36,-24.62"/>
# <text text-anchor="middle" x="151.65" y="-19.19" font-family="Times New Roman,serif" font-size="14.00" fill="white">Utility</text>
# </g>
# <!-- Chance&#45;&gt;Utility -->
# <g id="edge2" class="edge">
# <title>Chance-&gt;Utility</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M178.52,-296.59C197.4,-255.65 234.32,-159.59 205.65,-85.23 200.83,-72.71 192.01,-61.19 182.89,-51.68"/>
# <polygon fill="black" stroke="black" points="185.83,-49.68 176.23,-45.19 180.93,-54.69 185.83,-49.68"/>
# </g>
# <!-- Chance2 -->
# <g id="node2" class="node">
# <title>Chance2</title>
# <ellipse fill="#808080" stroke="black" cx="44.65" cy="-106.55" rx="44.65" ry="21.32"/>
# <text text-anchor="middle" x="44.65" y="-101.13" font-family="Times New Roman,serif" font-size="14.00" fill="white">Chance2</text>
# </g>
# <!-- Chance2&#45;&gt;Utility -->
# <g id="edge6" class="edge">
# <title>Chance2-&gt;Utility</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M68.14,-88.01C82.98,-76.92 102.38,-62.42 118.75,-50.2"/>
# <polygon fill="black" stroke="black" points="120.57,-52.46 126.49,-43.67 116.38,-46.85 120.57,-52.46"/>
# </g>
# <!-- Chance3 -->
# <g id="node3" class="node">
# <title>Chance3</title>
# <ellipse fill="#808080" stroke="black" cx="151.65" cy="-106.55" rx="44.65" ry="21.32"/>
# <text text-anchor="middle" x="151.65" y="-101.13" font-family="Times New Roman,serif" font-size="14.00" fill="white">Chance3</text>
# </g>
# <!-- Chance3&#45;&gt;Utility -->
# <g id="edge7" class="edge">
# <title>Chance3-&gt;Utility</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M151.65,-84.97C151.65,-77.44 151.65,-68.71 151.65,-60.29"/>
# <polygon fill="black" stroke="black" points="155.15,-60.53 151.65,-50.54 148.15,-60.54 155.15,-60.53"/>
# </g>
# <!-- Decision1&#45;&gt;Chance2 -->
# <g id="edge4" class="edge">
# <title>Decision1-&gt;Chance2</title>
# <path fill="none" stroke="black" d="M99.24,-229.74C89.54,-208.03 70.92,-166.35 58.15,-137.76"/>
# <polygon fill="black" stroke="black" points="61.01,-136.59 53.74,-128.88 54.62,-139.44 61.01,-136.59"/>
# </g>
# <!-- Decision1&#45;&gt;Decision2 -->
# <g id="edge5" class="edge">
# <title>Decision1-&gt;Decision2</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="116.9,-230.12 117.72,-228.91 118.55,-227.68 119.4,-226.41 120.26,-225.13 121.14,-223.82 122.03,-222.49 122.93,-221.14 123.85,-219.79 124.77,-218.41 125.7,-217.03 126.63,-215.64 127.57,-214.25 128.5,-212.85 129.44,-211.45 130.38,-210.05 131.32,-208.65 132.25,-207.27 133.18,-205.88 134.1,-204.51 135.01,-203.16 135.01,-203.16 134.02,-204.46 133.02,-205.77 132.01,-207.09 130.99,-208.42 129.97,-209.75 128.94,-211.09 127.92,-212.43 126.9,-213.77 125.88,-215.1 124.86,-216.43 123.85,-217.75 122.84,-219.07 121.85,-220.37 120.87,-221.65 119.89,-222.92 118.94,-224.18 117.99,-225.41 117.07,-226.62 116.16,-227.8 115.28,-228.96 116.9,-230.12"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="137.27,-206.61 140.26,-196.45 131.59,-202.53 137.27,-206.61"/>
# </g>
# <!-- Decision2&#45;&gt;Chance3 -->
# <g id="edge8" class="edge">
# <title>Decision2-&gt;Chance3</title>
# <path fill="none" stroke="black" d="M151.65,-163.7C151.65,-156.61 151.65,-147.73 151.65,-139.14"/>
# <polygon fill="black" stroke="black" points="155.15,-139.18 151.65,-129.18 148.15,-139.18 155.15,-139.18"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="220pt" height="165pt" viewBox="0.00 0.00 220.42 165.38">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 161.38)">
# <title>InfluenceDiagram</title>
# <!-- Chance&#45;Chance2&#45;Decision1&#45;Decision2 -->
# <g id="node1" class="node">
# <title>Chance-Chance2-Decision1-Decision2</title>
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="106.21" cy="-139.38" rx="106.21" ry="18"/>
# <text text-anchor="middle" x="106.21" y="-135.5" font-family="Times New Roman,serif" font-size="10.00">(0):Chance,Chance2,Decision1,Decision2</text>
# </g>
# <!-- Chance&#45;Chance2&#45;Decision1&#45;Decision2+Chance&#45;Chance2&#45;Chance3&#45;Decision2 -->
# <g id="node3" class="node">
# <title>Chance-Chance2-Decision1-Decision2+Chance-Chance2-Chance3-Decision2</title>
# <polygon fill="palegreen" stroke="#4a4a4a" points="154.9,-85.38 57.52,-85.38 57.52,-72 154.9,-72 154.9,-85.38"/>
# <text text-anchor="middle" x="106.21" y="-76.34" font-family="Times New Roman,seri

# %% [markdown]
# ## Customizing visualization of the results
#
# Using `pyAgrum.config`, it is possible to adapt the graphical representations for Influence Diagram (see the notebook 99-Tools_configForPyAgrum.ipynb).

# %%
gum.config.reset()
gnb.showInference(infdiag,engine=ie,size="7!")

# %% [markdown]
# Many visual options can be changed when displaing an inference (especially for influence diagrams)

# %%
# do not show inference time
gum.config["notebook","show_inference_time"]=False
# more digits for probabilities
gum.config["notebook","histogram_horizontal_visible_digits"]=3

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# specificic for influence diagram :
# more digits for utilities
gum.config["influenceDiagram","utility_visible_digits"]=5
# disabling stdev for utility and MEU
gum.config["influenceDiagram","utility_show_stdev"]=False
# showing loss (=-utility) and mEL (minimum Expected Loss) instead of MEU
gum.config["influenceDiagram","utility_show_loss"]=True

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# more visual changes for influence diagram and inference
gum.config.reset()

#shape (https://graphviz.org/doc/info/shapes.html)
gum.config["influenceDiagram","chance_shape"] = "cylinder"
gum.config["influenceDiagram","utility_shape"] = "star"
gum.config["influenceDiagram","decision_shape"] = "box3d"

#colors
gum.config["influenceDiagram","default_chance_bgcolor"] = "green"
gum.config["influenceDiagram","default_utility_bgcolor"] = "MediumVioletRed"
gum.config["influenceDiagram","default_decision_bgcolor"] = "DarkSalmon"

gum.config["influenceDiagram","utility_show_stdev"]=False

gnb.sideBySide(infdiag,gnb.getInference(infdiag,engine=ie,targets=["Decision1","Chance3"]))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="198pt" height="357pt" viewBox="0.00 0.00 198.10 356.78">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 352.78)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <path fill="green" stroke="black" d="M151.15,-345.01C151.15,-347.09 138.51,-348.78 122.95,-348.78 107.39,-348.78 94.75,-347.09 94.75,-345.01 94.75,-345.01 94.75,-311.09 94.75,-311.09 94.75,-309.01 107.39,-307.32 122.95,-307.32 138.51,-307.32 151.15,-309.01 151.15,-311.09 151.15,-311.09 151.15,-345.01 151.15,-345.01"/>
# <path fill="none" stroke="black" d="M151.15,-345.01C151.15,-342.93 138.51,-341.24 122.95,-341.24 107.39,-341.24 94.75,-342.93 94.75,-345.01"/>
# <text text-anchor="middle" x="122.95" y="-322.63" font-family="Times New Roman,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="DarkSalmon" stroke="black" points="69.9,-271.32 3.35,-271.32 0,-267.97 0,-241.17 66.55,-241.17 69.9,-244.52 69.9,-271.32"/>
# <polyline fill="none" stroke="black" points="66.55,-267.97 0,-267.97"/>
# <polyline fill="none" stroke="black" points="66.55,-267.97 66.55,-241.17"/>
# <polyline fill="none" stroke="black" points="66.55,-267.97 69.9,-271.32"/>
# <text text-anchor="middle" x="34.95" y="-250.82" font-family="Times New Roman,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="99.53,-307.19 97.75,-305.85 95.95,-304.48 94.11,-303.08 92.25,-301.67 90.37,-300.24 88.47,-298.8 86.55,-297.34 84.62,-295.88 82.69,-294.41 80.74,-292.93 78.8,-291.45 76.85,-289.97 74.91,-288.5 72.98,-287.03 71.05,-285.57 69.14,-284.12 67.25,-282.68 65.38,-281.26 63.53,-279.86 61.71,-278.47 61.71,-278.47 63.47,-279.93 65.26,-281.41 67.07,-282.91 68.9,-284.43 70.74,-285.96 72.61,-287.5 74.48,-289.05 76.35,-290.6 78.23,-292.16 80.12,-293.72 82,-295.28 83.87,-296.83 85.74,-298.37 87.59,-299.91 89.43,-301.43 91.25,-302.94 93.05,-304.43 94.82,-305.89 96.57,-307.34 98.28,-308.76 99.53,-307.19"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="65.11,-276.12 55.1,-272.65 60.76,-281.61 65.11,-276.12"/>
# </g>
# <!-- Decision2 -->
# <g id="node5" class="node">
# <title>Decision2</title>
# <polygon fill="DarkSalmon" stroke="black" points="157.9,-271.32 91.35,-271.32 88,-267.97 88,-241.17 154.55,-241.17 157.9,-244.52 157.9,-271.32"/>
# <polyline fill="none" stroke="black" points="154.55,-267.97 88,-267.97"/>
# <polyline fill="none" stroke="black" points="154.55,-267.97 154.55,-241.17"/>
# <polyline fill="none" stroke="black" points="154.55,-267.97 157.9,-271.32"/>
# <text text-anchor="middle" x="122.95" y="-250.82" font-family="Times New Roman,serif" font-size="14.00" fill="white">Decision2</text>
# </g>
# <!-- Chance&#45;&gt;Decision2 -->
# <g id="edge3" class="edge">
# <title>Chance-&gt;Decision2</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="123.95,-306.86 123.9,-305.72 123.86,-304.56 123.81,-303.38 123.76,-302.2 123.71,-301 123.66,-299.79 123.61,-298.57 123.56,-297.35 123.51,-296.12 123.46,-294.88 123.41,-293.64 123.35,-292.41 123.3,-291.17 123.25,-289.93 123.2,-288.69 123.15,-287.46 123.1,-286.23 123.05,-285.01 123,-283.8 122.95,-282.6 122.95,-282.6 122.9,-283.8 122.85,-285.01 122.8,-286.23 122.75,-287.46 122.7,-288.69 122.65,-289.93 122.6,-291.17 122.55,-292.41 122.49,-293.64 122.44,-294.88 122.39,-296.12 122.34,-297.35 122.29,-298.57 122.24,-299.79 122.19,-301 122.14,-302.2 122.09,-303.38 122.04,-304.56 122,-305.72 121.95,-306.86 123.95,-306.86"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="126.45,-284.63 122.95,-274.63 119.45,-284.63 126.45,-284.63"/>
# </g>
# <!-- Utility -->
# <g id="node6" class="node">
# <title>Utility</title>
# <polygon fill="MediumVioletRed" stroke="black" points="190.1,-78.93 138.8,-78.93 122.95,-127.72 107.1,-78.93 55.8,-78.93 97.3,-48.78 81.45,0 122.95,-30.15 164.45,0 148.6,-48.78 190.1,-78.93"/>
# <text text-anchor="middle" x="122.95" y="-58.43" font-family="Times New Roman,serif" font-size="14.00" fill="white">Utility</text>
# </g>
# <!-- Chance&#45;&gt;Utility -->
# <g id="edge2" class="edge">
# <title>Chance-&gt;Utility</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M143.6,-307.66C152.62,-297.76 162.22,-284.95 166.95,-271.32 187.56,-211.96 160.82,-139.49 140.92,-98.11"/>
# <polygon fill="black" stroke="black" points="143.62,-96.68 136.04,-89.28 137.35,-99.8 143.62,-96.68"/>
# </g>
# <!-- Chance2 -->
# <g id="node2" class="node">
# <title>Chance2</title>
# <path fill="green" stroke="black" d="M70.53,-201.4C70.53,-203.48 56.37,-205.17 38.95,-205.17 21.53,-205.17 7.38,-203.48 7.38,-201.4 7.38,-201.4 7.38,-167.49 7.38,-167.49 7.38,-165.41 21.53,-163.72 38.95,-163.72 56.37,-163.72 70.53,-165.41 70.53,-167.49 70.53,-167.49 70.53,-201.4 70.53,-201.4"/>
# <path fill="none" stroke="black" d="M70.53,-201.4C70.53,-199.33 56.37,-197.64 38.95,-197.64 21.53,-197.64 7.38,-199.33 7.38,-201.4"/>
# <text text-anchor="middle" x="38.95" y="-179.02" font-family="Times New Roman,serif" font-size="14.00" fill="white">Chance2</text>
# </g>
# <!-- Chance2&#45;&gt;Utility -->
# <g id="edge5" class="edge">
# <title>Chance2-&gt;Utility</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M53.2,-163.33C66.72,-144.25 87.17,-115.37 102.44,-93.81"/>
# <polygon fill="black" stroke="black" points="105.71,-96.26 108.63,-86.07 99.99,-92.21 105.71,-96.26"/>
# </g>
# <!-- Chance3 -->
# <g id="node3" class="node">
# <title>Chance3</title>
# <path fill="green" stroke="black" d="M154.53,-201.4C154.53,-203.48 140.37,-205.17 122.95,-205.17 105.53,-205.17 91.38,-203.48 91.38,-201.4 91.38,-201.4 91.38,-167.49 91.38,-167.49 91.38,-165.41 105.53,-163.72 122.95,-163.72 140.37,-163.72 154.53,-165.41 154.53,-167.49 154.53,-167.49 154.53,-201.4 154.53,-201.4"/>
# <path fill="none" stroke="black" d="M154.53,-201.4C154.53,-199.33 140.37,-197.64 122.95,-197.64 105.53,-197.64 91.38,-199.33 91.38,-201.4"/>
# <text text-anchor="middle" x="122.95" y="-179.02" font-family="Times New Roman,serif" font-size="14.00" fill="white">Chance3</text>
# </g>
# <!-- Chance3&#45;&gt;Utility -->
# <g id="edge6" class="edge">
# <title>Chance3-&gt;Utility</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M122.95,-163.33C122.95,-156.55 122.95,-148.52 122.95,-140.03"/>
# <polygon fill="black" stroke="black" points="126.45,-140.08 122.95,-130.08 119.45,-140.08 126.45,-140.08"/>
# </g>
# <!-- Decision1&#45;&gt;Chance2 -->
# <g id="edge4" class="edge">
# <title>Decision1-&gt;Chance2</title>
# <path fill="none" stroke="black" d="M35.78,-240.79C36.19,-233.68 36.69,-224.82 37.18,-216.3"/>
# <polygon fill="black" stroke="black" points="40.73,-216.63 37.8,-206.45 33.74,-216.23 40.73,-216.63"/>
# </g>
# <!-- Decision2&#45;&gt;Chance3 -->
# <g id="edge7" class="edge">
# <title>Decision2-&gt;Chance3</title>
# <path fill="none" stroke="black" d="M122.95,-240.79C122.95,-233.68 122.95,-224.82 122.95,-216.3"/>
# <polygon fill="black" stroke="black" points="126.45,-216.45 122.95,-206.45 119.45,-216.45 126.45,-216.45"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="327pt" height="487pt" viewBox="0.00 0.00 327.00 487.49">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 483.49)">
# <title>structs</title>
# <text text-anchor="middle" x="159.5" y="-22.2" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">MEU 16.04</text>
# <text text-anchor="middle
