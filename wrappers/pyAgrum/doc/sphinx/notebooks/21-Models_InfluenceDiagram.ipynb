# %% [markdown]
# # Influence diagram

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
import os

# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt
from IPython.display import display,HTML

import math

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %% [markdown]
# ## Build a Influence Diagram
#
# ### fast build with string

# %%
gum.fastID("A->*B->$C<-D<-*E->*G->H->*I<-D")
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x564d7008dae0) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 4,
#   arcs: 8,
#   domainSize: 128
# }

# %% [markdown]
# ### bifxml format file

# %%
diag=gum.loadID("res/diag.bifxml")
gnb.showInfluenceDiagram(diag)

# %%
diag
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x564d700acf60) Influence Diagram{
#   chance: 5,
#   utility: 2,
#   decision: 4,
#   arcs: 12,
#   domainSize: 512
# }

# %% [markdown]
# ### the hard way :-)

# %%
F=diag.addChanceNode(gum.LabelizedVariable("F","F",2))
diag.addArc(diag.idFromName("decisionVar1"),F)

U=diag.addUtilityNode(gum.LabelizedVariable("U","U",1))
diag.addArc(diag.idFromName("decisionVar3"),U)
diag.addArc(diag.idFromName("F"),U)
gnb.showInfluenceDiagram(diag)

# %%
diag.cpt(F)[{'decisionVar1':0}]=[0.9,0.1]
diag.cpt(F)[{'decisionVar1':1}]=[0.3,0.7]

diag.utility(U)[{'F':0,'decisionVar3':0}]=2
diag.utility(U)[{'F':0,'decisionVar3':1}]=4
diag.utility(U)[{'F':1}]=[[0],[5]]

# %% [markdown]
# ## Optimization in an influence diagram (actually LIMID)

# %%
oil=gum.loadID("res/OilWildcatter.bifxml")
gnb.flow.row(oil,gnb.getInference(oil))
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="335pt" height="296pt" viewBox="0.00 0.00 335.20 295.78">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 291.78)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="black" cx="131.11" cy="-181.18" rx="63.75" ry="22.38"/>
# <text text-anchor="middle" x="131.11" y="-176.5" font-family="Times,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="black" points="165.31,-119.33 96.91,-119.33 96.91,-87.68 165.31,-87.68 165.31,-119.33"/>
# <text text-anchor="middle" x="131.11" y="-98.83" font-family="Times,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="132.11,-158.7 132.06,-157.38 132.01,-156.04 131.97,-154.68 131.92,-153.31 131.87,-151.92 131.82,-150.52 131.77,-149.11 131.72,-147.69 131.67,-146.27 131.62,-144.84 131.56,-143.4 131.51,-141.97 131.46,-140.53 131.41,-139.1 131.36,-137.67 131.31,-136.25 131.26,-134.84 131.21,-133.43 131.16,-132.04 131.11,-130.66 131.11,-130.66 131.06,-132.04 131.01,-133.43 130.96,-134.84 130.91,-136.25 130.86,-137.67 130.81,-139.1 130.76,-140.53 130.71,-141.97 130.66,-143.4 130.6,-144.84 130.55,-146.27 130.5,-147.69 130.45,-149.11 130.4,-150.52 130.35,-151.92 130.3,-153.31 130.25,-154.68 130.2,-156.04 130.16,-157.38 130.11,-158.7 132.11,-158.7"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="134.61,-132.79 131.11,-122.79 127.61,-132.79 134.61,-132.79"/>
# </g>
# <!-- OilContents -->
# <g id="node2" class="node">
# <title>OilContents</title>
# <ellipse fill="#808080" stroke="black" cx="70.11" cy="-265.4" rx="70.11" ry="22.38"/>
# <text text-anchor="middle" x="70.11" y="-260.72" font-family="Times,serif" font-size="14.00" fill="white">OilContents</text>
# </g>
# <!-- OilContents&#45;&gt;TestResult -->
# <g id="edge6" class="edge">
# <title>OilContents-&gt;TestResult</title>
# <path fill="none" stroke="black" d="M85.82,-243.22C92.86,-233.73 101.3,-222.36 108.96,-212.03"/>
# <polygon fill="black" stroke="black" points="112.31,-214.4 115.45,-204.28 106.68,-210.22 112.31,-214.4"/>
# </g>
# <!-- Reward -->
# <g id="node6" class="node">
# <title>Reward</title>
# <polygon fill="#50508a" stroke="black" points="141.57,-25.84 113.34,-51.68 56.88,-51.68 28.65,-25.84 56.88,0 113.34,0 141.57,-25.84"/>
# <text text-anchor="middle" x="85.11" y="-21.17" font-family="Times,serif" font-size="14.00" fill="white">Reward</text>
# </g>
# <!-- OilContents&#45;&gt;Reward -->
# <g id="edge7" class="edge">
# <title>OilContents-&gt;Reward</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="
dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.7.2, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style

# %%
# a function to show results on decision nodes T and D
def show_decisions(ie):
    gnb.flow.row(ie.optimalDecision("Testing"),
                   ie.optimalDecision("Drilling"),
                   f"$${ie.MEU()['mean']:5.3f}\\ (stdev : {math.sqrt(ie.MEU()['variance']):5.3f})$$",
                   captions=["Strategy for T",
                             "Strategy for D",
                             "MEU and its standard deviation"])
    gnb.flow.row(ie.posterior("Testing"),ie.posteriorUtility("Testing"),
                   ie.posterior("Drilling"),ie.posteriorUtility("Drilling"),
                  captions=["Final decision for Testing","Final reward for Testing",
                            "Final decision for Drilling","Final reward for Drilling"])

ie=gum.ShaferShenoyLIMIDInference(oil) 

display(HTML("<h2>Inference in the LIMID optimizing the decisions nodes</h2>"))
ie.makeInference()
show_decisions(ie)
# Out:
# <h2>Inference in the LIMID optimizing the decisions nodes</h2>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# </table><br><center><small><em>Strategy for T</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>Drilling</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>TestResult</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>closed</center></th><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>open</center></th><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>diffuse</center></th><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td></tr>
# </table><br><center><small><em>Strategy for D</em></small></center></div><div class="floating-box">$$22.500\ (stdev : 87.457)$$<br><center><small><em>MEU and its standard deviation</em></small></center></div>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# </table><br><center><small><em>Final decision for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;'>22.5000</td><td style='text-align:right;'>20.0000</td></tr>
# </table><br><center><small><em>Final reward for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#b3ca64;text-align:right;'>0.5900</td><td style='color:black;background-color:#cab364;text-align:right;'>0.4100</td></tr>
# </table><br><center><small><em>Final decision for Drilling</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;'>45.0847</td><td style='text-align:right;'>-10.0000</td></tr>
# </table><br><center><small><em>Final reward for Drilling</em></small></center></div>

# %% [markdown]
# ## Graphical inference with evidence and targets (developped nodes)

# %%
gnb.sideBySide(oil,
               gnb.getInference(oil,evs={'TestResult':'closed'}),
               gnb.getInference(oil,evs={'TestResult':'open'}),
               gnb.getInference(oil,evs={'TestResult':'diffuse'}),
               oil,
               gnb.getInference(oil,evs={'OilContents':'Dry'}),
               gnb.getInference(oil,evs={'OilContents':'Wet'}),
               gnb.getInference(oil,evs={'OilContents':'Soaking'}),
               ncols=4)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="335pt" height="296pt" viewBox="0.00 0.00 335.20 295.78">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 291.78)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="black" cx="131.11" cy="-181.18" rx="63.75" ry="22.38"/>
# <text text-anchor="middle" x="131.11" y="-176.5" font-family="Times,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="black" points="165.31,-119.33 96.91,-119.33 96.91,-87.68 165.31,-87.68 165.31,-119.33"/>
# <text text-anchor="middle" x="131.11" y="-98.83" font-family="Times,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="132.11,-158.7 132.06,-157.38 132.01,-156.04 131.97,-154.68 131.92,-153.31 131.87,-151.92 131.82,-150.52 131.77,-149.11 131.72,-147.69 131.67,-146.27 131.62,-144.84 131.56,-143.4 131.51,-141.97 131.46,-140.53 131.41,-139.1 131.36,-137.67 131.31,-136.25 131.26,-134.84 131.21,-133.43 131.16,-132.04 131.11,-130.66 131.11,-130.66 131.06,-132.04 131.01,-133.43 130.96,-134.84 130.91,-136.25 130.86,-137.67 130.81,-139.1 130.76,-140.53 130.71,-141.97 130.66,-143.4 130.6,-144.84 130.55,-146.27 130.5,-147.69 130.45,-149.11 130.4,-150.52 130.35,-151.92 130.3,-153.31 130.25,-154.68 130.2,-156.04 130.16,-157.38 130.11,-158.7 132.11,-158.7"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="134.61,-132.79 131.11,-122.79 127.61,-132.79 134.61,-132.79"/>
# </g>
# <!-- OilContents -->
# <g id="node2" class="node">
# <title>OilContents</title>
# <ellipse fill="#808080" stroke="black" cx="70.11" cy="-265.4" rx="70.11" ry="22.38"/>
# <text text-anchor="middle" x="70.11" y="-260.72" font-family="Times,serif" font-size="14.00" fill="white">OilContents</text>
# </g>
# <!-- OilContents&#45;&gt;TestResult -->
# <g id="edge6" class="edge">
# <title>OilContents-&gt;TestResult</title>
# <path fill="none" stroke="black" d="

# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 344.84)">
# <title>structs</title>
# <text text-anchor="middle" x="222.79" y="-25.2" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">MEU 77.50 (stdev=104.73)</text>
# <text text-anchor="middle" x="222.79" y="-7.95" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.84ms</text>
# <!-- Testing -->
# <g id="node1" class="node">
# <title>Testing</title>
# <polygon fill="none" stroke="#000000" points="175.9,-335.84 37.9,-335.84 37.9,-293.84 175.9,-293.84 175.9,-335.84"/>
# <svg viewBox="0 0 181.554687 53.538125" width="138px" height="42px" preserveAspectRatio="xMinYMin meet" x="37.8973" y="-335.836"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2023-07-26T09:30:05.501264</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.7.2, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*

# %% [markdown]
# ## Soft evidence on chance node

# %%
gnb.showInference(oil,evs={'OilContents':[0.7,0.5,0.8]})

# %% [markdown]
# ## Forced decision

# %%
gnb.showInference(oil,evs={'Drilling':'Yes'})

# %% [markdown]
# ## LIMID versus Influence Diagram
#
# The default inference for influence diagram actually an inference for LIMIDs. In order to use it for classical (and solvable) influence diagram, do not forget to add the sequence of decision nodes using `addNoForgettingAssumption`.

# %%
infdiag=gum.fastID("Chance->*Decision1->Chance2->$Utility<-Chance3<-*Decision2<-Chance->Utility")
infdiag
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x564d705757d0) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 2,
#   arcs: 7,
#   domainSize: 32
# }

# %%
ie=gum.ShaferShenoyLIMIDInference(infdiag)
try:
    ie.makeInference()
except gum.GumException as e:
    print(e)
# Out:
# [pyAgrum] Fatal error: This LIMID/Influence Diagram is not solvable.

# %%
ie.addNoForgettingAssumption(["Decision1","Decision2"])
gnb.sideBySide(ie.reducedLIMID(),ie.junctionTree(),gnb.getInference(infdiag,engine=ie))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="262pt" height="357pt" viewBox="0.00 0.00 261.62 356.50">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 352.5)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <ellipse fill="#808080" stroke="black" cx="200.67" cy="-326.12" rx="47.31" ry="22.38"/>
# <text text-anchor="middle" x="200.67" y="-321.45" font-family="Times,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="#9a5050" stroke="black" points="172.74,-267.74 88.59,-267.74 88.59,-236.09 172.74,-236.09 172.74,-267.74"/>
# <text text-anchor="middle" x="130.67" y="-247.24" font-family="Times,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="182.26,-304.7 180.87,-303.33 179.45,-301.93 178.01,-300.52 176.55,-299.08 175.07,-297.63 173.58,-296.16 172.07,-294.68 170.56,-293.19 169.03,-291.69 167.51,-290.19 165.98,-288.69 164.45,-287.19 162.92,-285.68 161.4,-284.19 159.88,-282.7 158.38,-281.22 156.89,-279.75 155.41,-278.3 153.95,-276.86 152.51,-275.45 152.51,-275.45 153.88,-276.93 155.27,-278.43 156.68,-279.96 158.1,-281.49 159.53,-283.04 160.97,-284.6 162.42,-286.17 163.87,-287.74 165.33,-289.32 166.78,-290.89 168.24,-292.47 169.69,-294.04 171.13,-295.6 172.56,-297.15 173.98,-298.68 175.39,-300.21 176.78,-301.71 178.15,-303.19 179.5,-304.65 180.82,-306.09 182.26,-304.7"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="156.58,-274.56 147.11,-269.81 151.56,-279.43 156.58,-274.56"/>
# </g>
# <!-- Decision2 -->
# <g id="node5" class="node">
# <title>Decision2</title>
# <polygon fill="#9a5050" stroke="black" points="220.74,-200.09 136.59,-200.09 136.59,-168.44 220.74,-168.44 220.74,-200.09"/>
# <text text-anchor="middle" x="178.67" y="-179.59" font-family="Times,serif" font-size="14.00" fill="white">Decision2</text>
# </g>
# <!-- Chance&#45;&gt;Decision2 -->
# <g id="edge3" class="edge">
# <title>Chance-&gt;Decision2</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="198.27,-303.42 197.62,-299.59 196.94,-295.54 196.23,-291.29 195.48,-286.88 194.72,-282.31 193.93,-277.62 193.12,-272.83 192.3,-267.96 191.47,-263.02 190.63,-258.05 189.79,-253.07 188.96,-248.1 188.13,-243.16 187.3,-238.27 186.49,-233.46 185.7,-228.75 184.93,-224.16 184.18,-219.72 183.46,-215.44 182.77,-211.36 182.77,-211.36 183.37,-215.46 184,-219.75 184.65,-224.2 185.33,-228.81 186.02,-233.53 186.73,-238.36 187.44,-243.26 188.17,-248.22 188.9,-253.21 189.63,-258.21 190.36,-263.2 191.08,-268.15 191.8,-273.04 192.5,-277.85 193.19,-282.55 193.86,-287.13 194.51,-291.56 195.13,-295.82 195.73,-299.89 196.29,-303.73 198.27,-303.42"/>
# <polygon fill="black" stroke="black" stroke-width="2" points

# <!-- Chance&#45;Chance2&#45;Decision1&#45;Decision2+Chance&#45;Chance2&#45;Chance3&#45;Decision2 -->
# <g id="node3" class="node">
# <title>Chance-Chance2-Decision1-Decision2+Chance-Chance2-Chance3-Decision2</title>
# <polygon fill="palegreen" stroke="#4a4a4a" points="192.26,-84.63 80.63,-84.63 80.63,-72 192.26,-72 192.26,-84.63"/>
# <text text-anchor="middle" x="136.45" y="-75.59" font-family="Times,serif" font-size="8.00">Chance,Chance2,Decision2</text>
# </g>
# <!-- Chanc

# %% [markdown]
# ## Customizing visualization of the results
#
# Using `pyAgrum.config`, it is possible to adapt the graphical representations for Influence Diagram (see the notebook 99-Tools_configForPyAgrum.ipynb).

# %%
gum.config.reset()
gnb.showInference(infdiag,engine=ie,size="7!")

# %% [markdown]
# Many visual options can be changed when displaing an inference (especially for influence diagrams)

# %%
# do not show inference time
gum.config["notebook","show_inference_time"]=False
# more digits for probabilities
gum.config["notebook","histogram_horizontal_visible_digits"]=3

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# specificic for influence diagram :
# more digits for utilities
gum.config["influenceDiagram","utility_visible_digits"]=5
# disabling stdev for utility and MEU
gum.config["influenceDiagram","utility_show_stdev"]=False
# showing loss (=-utility) and mEL (minimum Expected Loss) instead of MEU
gum.config["influenceDiagram","utility_show_loss"]=True

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# visual changes for influence diagram and inference
gum.config.reset()
gum.config['notebook','graph_rankdir']='LR'
gnb.sideBySide(infdiag,gnb.getInference(infdiag,engine=ie,targets=["Decision1","Chance3"]))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="432pt" height="117pt" viewBox="0.00 0.00 432.00 116.84">
# <g id="graph0" class="graph" transform="scale(0.86344 0.86344) rotate(0) translate(4 131.32)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <ellipse fill="#808080" stroke="black" cx="47.31" cy="-41.94" rx="47.31" ry="22.38"/>
# <text text-anchor="middle" x="47.31" y="-37.27" font-family="Times,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="#9a5050" stroke="black" points="214.76,-113.77 130.61,-113.77 130.61,-82.12 214.76,-82.12 214.76,-113.77"/>
# <text text-anchor="middle" x="172.69" y="-93.27" font-family="Times,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="81.93,-58.3 84,-59.19 86.1,-60.09 88.23,-61.01 90.39,-61.93 92.57,-62.87 94.77,-63.81 96.99,-64.76 99.22,-65.72 101.47,-66.69 103.72,-67.65 105.98,-68.62 108.25,-69.6 110.52,-70.57 112.79,-71.55 115.05,-72.52 117.31,-73.49 119.56,-74.45 121.8,-75.41 124.03,-76.37 126.23,-77.31 126.23,-77.31 124.07,-76.28 121.88,-75.23 119.69,-74.18 117.48,-73.12 115.26,-72.06 113.04,-70.99 110.81,-69.93 108.59,-68.86 106.36,-67.79 104.14,-66.73 101.93,-65.67 99.72,-64.61 97.53,-63.56 95.36,-62.52 93.2,-61.48 91.06,-60.46 88.94,-59.45 86.85,-58.44 84.79,-57.46 82.76,-56.48 81.93,-58.3"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="123.48,-79.82 134.03,-80.76 126.37,-73.44 123.48,-79.82"/>
# </g>
# <!-- Decision2 -->
# <g id="node5" class="node">
# <title>Decision2</title>
# <polygon fill="#9a5050" stroke="black" points="214.76,-57.77 130.61,-57.77 130.61,-26.12 214.76,-26.12 214.76,-57.77"/>
# <text text-anchor="middle" x="172.69" y="-37.27" font-family="Times,serif" font-size="14.00" fill="white">Decision2</text>
# </g>
# <!-- Chance&#45;&gt;Decision2 -->
# <g id="edge3" class="edge">
# <title>Chance-&gt;Decision2</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="94.95,-42.94 96.15,-42.89 97.35,-42.85 98.56,-42.8 99.77,-42.75 100.99,-42.7 102.21,-42.65 103.43,-42.6 104.66,-42.55 105.88,-42.5 107.11,-42.45 108.34,-42.4 109.57,-42.35 110.8,-42.29 112.03,-42.24 113.25,-42.19 114.48,-42.14 115.71,-42.09 116.93,-42.04 118.15,-41.99 119.37,-41.94 119.37,
18.718125  z " style="fill: #ffffff"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 56.571875 46.438125

# %%
# more visual changes for influence diagram and inference
gum.config.reset()

#shape (https://graphviz.org/doc/info/shapes.html)
gum.config["influenceDiagram","chance_shape"] = "cylinder"
gum.config["influenceDiagram","utility_shape"] = "star"
gum.config["influenceDiagram","decision_shape"] = "box3d"

#colors
gum.config["influenceDiagram","default_chance_bgcolor"] = "green"
gum.config["influenceDiagram","default_utility_bgcolor"] = "MediumVioletRed"
gum.config["influenceDiagram","default_decision_bgcolor"] = "DarkSalmon"

gum.config["influenceDiagram","utility_show_stdev"]=False

gnb.sideBySide(infdiag,gnb.getInference(infdiag,engine=ie,targets=["Decision1","Chance3"]))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="231pt" height="384pt" viewBox="0.00 0.00 230.81 384.45">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 380.45)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <path fill="green" stroke="black" d="M177.52,-372.5C177.52,-374.68 162.53,-376.45 144.07,-376.45 125.62,-376.45 110.62,-374.68 110.62,-372.5 110.62,-372.5 110.62,-336.89 110.62,-336.89 110.62,-334.71 125.62,-332.94 144.07,-332.94 162.53,-332.94 177.52,-334.71 177.52,-336.89 177.52,-336.89 177.52,-372.5 177.52,-372.5"/>
# <path fill="none" stroke="black" d="M177.52,-372.5C177.52,-370.32 162.53,-368.54 144.07,-368.54 125.62,-368.54 110.62,-370.32 110.62,-372.5"/>
# <text text-anchor="middle" x="144.07" y="-350.02" font-family="Times,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="DarkSalmon" stroke="black" points="84.15,-296.94 3.52,-296.94 0,-293.42 0,-265.29 80.63,-265.29 84.15,-268.8 84.15,-296.94"/>
# <polyline fill="none" stroke="black" points="80.63,-293.42 0,-293.42"/>
# <polyline fill="none" stroke="black" points="80.63,-293.42 80.63,-265.29"/>
# <polyline fill="none" stroke="black" points="80.63,-293.42 84.15,-296.94"/>
# <text text-anchor="middle" x="42.08" y="-276.44" font-family="Times,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="116.24,-332.94 114.19,-331.56 112.12,-330.16 110.01,-328.74 107.87,-327.3 105.7,-325.84 103.52,-324.37 101.32,-322.89 99.11,-321.4 96.89,-319.9 94.66,-318.4 92.43,-316.9 90.2,-315.39 87.97,-313.9 85.76,-312.4 83.55,-310.92 81.37,-309.45 79.2,-307.99 77.06,-306.54 74.94,-305.12 72.86,-303.72 72.86,-303.72 74.89,-305.2 76.95,-306.7 79.03,-308.23 81.14,-309.77 83.27,-311.32 85.41,-312.89 87.57,-314.47 89.74,-316.05 91.91,-317.63 94.08,-319.22 96.25,-320.81 98.41,-322.39 100.57,-323.96 102.71,-325.53 104.83,-327.08 106.94,-328.62 109.02,-330.14 111.08,-331.64 113.1,-333.12 115.09,-334.57 116.24,-332.94"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="76.06,-301.29 65.87,-298.41 72.04,-307.02 76.06,-301.29"/>
# </g>
# <!-- Decision2 -->
# <g id="node5" class="node">
# <title>Decision2</title>
# <polygon fill="DarkSalmon" stroke="black" points="186.15,-296.94 105.52,-296.94 102,-293.42 102,-265.29 182.63,-265.29 186.15,-268.8 186.15,-296.94"/>
# <polyline fill="none" stroke="black" points="182.63,-293.42 102,-293.42"/>
# <polyline fill="none" stroke="black" points="182.63,-293.42 182.63,-265.29"/>
# <polyline fill="none" stroke="black" points="182.63,-293.42 186.15,-296.94"/>
# <text text-anchor="middle" x="144.07" y="-276.44" font-family="Times,serif" font-size="14.00" fill="white">Decision2</text>
# </g>
# <!-- Chance&#45;&gt;Decision2 -->
# <g id="edge3" class="edge">
# <title>Chance-&gt;Decision2</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points