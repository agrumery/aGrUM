# %% [markdown]
# # Influence diagram

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
import os

# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt
from IPython.display import display,HTML

import math

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %% [markdown]
# ## Build a Influence Diagram
#
# ### fast build with string

# %%
gum.fastID("A->*B->$C<-D<-*E->*G->H->*I<-D")
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x562111e0a500) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 4,
#   arcs: 8,
#   domainSize: 128
# }

# %% [markdown]
# ### bifxml format file

# %%
diag=gum.loadID("res/diag.bifxml")
gnb.showInfluenceDiagram(diag)

# %%
diag
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x562112b4fa70) Influence Diagram{
#   chance: 5,
#   utility: 2,
#   decision: 4,
#   arcs: 12,
#   domainSize: 512
# }

# %% [markdown]
# ### the hard way :-)

# %%
F=diag.addChanceNode(gum.LabelizedVariable("F","F",2))
diag.addArc(diag.idFromName("decisionVar1"),F)

U=diag.addUtilityNode(gum.LabelizedVariable("U","U",1))
diag.addArc(diag.idFromName("decisionVar3"),U)
diag.addArc(diag.idFromName("F"),U)
gnb.showInfluenceDiagram(diag)

# %%
diag.cpt(F)[{'decisionVar1':0}]=[0.9,0.1]
diag.cpt(F)[{'decisionVar1':1}]=[0.3,0.7]

diag.utility(U)[{'F':0,'decisionVar3':0}]=2
diag.utility(U)[{'F':0,'decisionVar3':1}]=4
diag.utility(U)[{'F':1}]=[[0],[5]]

# %% [markdown]
# ## Optimization in an influence diagram (actually LIMID)

# %%
oil=gum.loadID("res/OilWildcatter.bifxml")
gnb.flow.row(oil,gnb.getInference(oil))
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="335pt" height="281pt" viewBox="0.00 0.00 335.38 280.73">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 276.73)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="black" cx="131" cy="-172.04" rx="63.78" ry="20.51"/>
# <text text-anchor="middle" x="131" y="-168.34" font-family="Times,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="black" points="165.5,-112.36 96.5,-112.36 96.5,-83.36 165.5,-83.36 165.5,-112.36"/>
# <text text-anchor="middle" x="131" y="-94.16" font-family="Times,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="132,-151.31 131.96,-150.02 131.91,-148.7 131.86,-147.36 131.81,-146 131.76,-144.63 131.71,-143.25 131.66,-141.85 131.61,-140.45 131.56,-139.03 131.51,-137.61 131.46,-136.19 131.41,-134.77 131.36,-133.34 131.31,-131.92 131.25,-130.5 131.2,-129.09 131.15,-127.69 131.1,-126.3 131.05,-124.91 131,-123.55 131,-123.55 130.95,-124.91 130.9,-126.3 130.85,-127.69 130.8,-129.09 130.75,-130.5 130.7,-131.92 130.65,-133.34 130.6,-134.77 130.55,-136.19 130.5,-137.61 130.45,-139.03 130.39,-140.45 130.34,-141.85 130.29,-143.25 130.24,-144.63 130.19,-146 130.15,-147.36 130.1,-148.7 130.05,-150.02 130,-151.31 132,-151.31"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="134.5,-125.84 131,-115.84 127.5,-125.84 134.5,-125.84"/>
# </g>
# <!-- OilContents -->
# <g id="node2" class="node">
# <title>OilContents</title>
# <ellipse fill="#808080" stroke="black" cx="70" cy="-252.22" rx="70.01" ry="20.51"/>
# <text text-anchor="middle" x="70" y="-248.52" font-family="Times,serif" font-size="14.00" fill="white">OilContents</text>
# </g>
# <!-- OilContents&#45;&gt;TestResult -->
# <g id="edge6" class="edge">
# <title>OilContents-&gt;TestResult</title>
# <path fill="none" stroke="black" d="M85.08,-231.89C92.34,-222.59 101.18,-211.26 109.16,-201.03"/>
# <polygon fill="black" stroke="black" points="112.5,-203.45 115.89,-193.41 106.98,-199.14 112.5,-203.45"/>
# </g>
# <!-- Reward -->
# <g id="node6" class="node">
# <title>Reward</title>
# <polygon fill="#50508a" stroke="black" points="141.18,-23.68 113.09,-47.54 56.92,-47.54 28.83,-23.68 56.92,0.18 113.09,0.18 141.18,-23.68"/>
# <text text-anchor="middle" x="85" y="-19.98" font-family="Times,serif" font-size="14.00" fill="white">Reward</text>
# </g>
# <!-- OilContents&#45;&gt;Reward -->
# <g id="edge7" class="edge">
# <title>OilContents-&gt;Reward</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="
> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2023-05-09T09:54:49.874246</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.7.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="

# %%
# a function to show results on decision nodes T and D
def show_decisions(ie):
    gnb.flow.row(ie.optimalDecision("Testing"),
                   ie.optimalDecision("Drilling"),
                   f"$${ie.MEU()['mean']:5.3f}\\ (stdev : {math.sqrt(ie.MEU()['variance']):5.3f})$$",
                   captions=["Strategy for T",
                             "Strategy for D",
                             "MEU and its standard deviation>"])
    gnb.flow.row(ie.posterior("Testing"),ie.posteriorUtility("Testing"),
                   ie.posterior("Drilling"),ie.posteriorUtility("Drilling"),
                  captions=["Final decision for Testing","Final reward for Testing",
                            "Final decision for Drilling","Final reward for Drilling"])

ie=gum.ShaferShenoyLIMIDInference(oil) 

display(HTML("<h2>Inference in the LIMID optimizing the decisions nodes</h2>"))
ie.makeInference()
show_decisions(ie)
# Out:
# <h2>Inference in the LIMID optimizing the decisions nodes</h2>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# </table><br><center><small><em>Strategy for T</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>Drilling</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>TestResult</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>closed</center></th><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>open</center></th><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>diffuse</center></th><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td></tr>
# </table><br><center><small><em>Strategy for D</em></small></center></div><div class="floating-box">$$22.500\ (stdev : 87.457)$$<br><center><small><em>MEU and its standard deviation></em></small></center></div>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# </table><br><center><small><em>Final decision for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;'>22.5000</td><td style='text-align:right;'>20.0000</td></tr>
# </table><br><center><small><em>Final reward for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#b3ca64;text-align:right;'>0.5900</td><td style='color:black;background-color:#cab364;text-align:right;'>0.4100</td></tr>
# </table><br><center><small><em>Final decision for Drilling</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;'>45.0847</td><td style='text-align:right;'>-10.0000</td></tr>
# </table><br><center><small><em>Final reward for Drilling</em></small></center></div>

# %% [markdown]
# ## Graphical inference with evidence and targets (developped nodes)

# %%
gnb.sideBySide(oil,
               gnb.getInference(oil,evs={'TestResult':'closed'}),
               gnb.getInference(oil,evs={'TestResult':'open'}),
               gnb.getInference(oil,evs={'TestResult':'diffuse'}),
               oil,
               gnb.getInference(oil,evs={'OilContents':'Dry'}),
               gnb.getInference(oil,evs={'OilContents':'Wet'}),
               gnb.getInference(oil,evs={'OilContents':'Soaking'}),
               ncols=4)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="335pt" height="281pt" viewBox="0.00 0.00 335.38 280.73">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 276.73)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="black" cx="131" cy="-172.04" rx="63.78" ry="20.51"/>
# <text text-anchor="middle" x="131" y="-168.34" font-family="Times,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="black" points="165.5,-112.36 96.5,-112.36 96.5,-83.36 165.5,-83.36 165.5,-112.36"/>
# <text text-anchor="middle" x="131" y="-94.16" font-family="Times,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="132,-151.31 131.96,-150.02 131.91,-148.7 131.86,-147.36 131.81,-146 131.76,-144.63 131.71,-143.25 131.66,-141.85 131.61,-140.45 131.56,-139.03 131.51,-137.61 131.46,-136.19 131.41,-134.77 131.36,-133.34 131.31,-131.92 131.25,-130.5 131.2,-129.09 131.15,-127.69 131.1,-126.3 131.05,-124.91 131,-123.55 131,-123.55 130.95,-124.91 130.9,-126.3 130.85,-127.69 130.8,-129.09 130.75,-130.5 130.7,-131.92 130.65,-133.34 130.6,-134.77 130.55,-136.19 130.5,-137.61 130.45,-139.03 130.39,-140.45 130.34,-141.85 130.29,-143.25 130.24,-144.63 130.19,-146 130.15,-147.36 130.1,-148.7 130.05,-150.02 130,-151.31 132,-151.31"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="134.5,-125.84 131,-115.84 127.5,-125.84 134.5,-125.84"/>
# </g>
# <!-- OilContents -->
# <g id="node2" class="node">
# <title>OilContents</title>
# <ellipse fill="#808080" stroke="black" cx="70" cy="-252.22" rx="70.01" ry="20.51"/>
# <text text-anchor="middle" x="70" y="-248.52" font-family="Times,serif" font-size="14.00" fill="white">OilContents</text>
# </g>
# <!-- OilContents&#45;&gt;TestResult -->
# <g id="edge6" class="edge">
# <title>OilContents-&gt;TestResult</title>
# <path fill="none" stroke="black" d="M85.08,-231.89C92.34,-222.59 101.18,-211.26 109.16,-201.03"/>
# <polygon fill="black" stroke="black" points="112.5,-203.45 115.89,-193.41 106.98,-199.14 112.5,-203.45"/>
# </g>
# <!-- Reward -->
# <g id="node6" class="node">
# <title>Reward</title>
# <polygon fill="#50508a" stroke="black" points="141.18,-23.68 113.09,-47.54 56.92,-47.54 28.83,-23.68 56.92,0.18 113.09,0.18 141.18,-23.68"/>
# <text text-anchor="middle" x="85" y="-19.98" font-family="Times,serif" font-size="14.00" fill="white">Reward</text>
# </g>
# <!-- OilContents&#45;&gt;Reward -->
# <g id="edge7" class="edge">
# <title>OilContents-&gt;Reward</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M64.63,-231.35C62.07,-220.84 59.28,-207.67 58,-195.71 52.87,-147.7 64.81,-92.61 74.42,-58.22"/>
# <polygon fill="black" stroke="black" points="78.01,-59.4 77.43,-48.82 71.28,-57.45 78.01,-59.4"/>
# </g>
# <!-- Testing -->
# <g id="node3" class="node">
# <title>Testing</title>
# <polygon fill="#9a5050" stroke="black" points="256.5,-266.72 189.5,-266.72 189.5,-237.72 256.5,-237.72 256.5,-266.72"/>
# <text text-anchor="middle" x="223" y="-248.52" font-family="Times,serif" font-size="14.00" fill="white">Testing</text>
# </g>
# <!-- Testing&#45;&gt;TestResult -->
# <g id="edge2" class="edge">
# <title>Testing-&gt;TestResult</title>
# <path fill="none" stroke="black" d="M206.56,-237.24C193.91,-226.49 176.09,-211.36 160.94,-198.48"/>
# <polygon fill="black" stroke="black" points="163.73,-195.41 153.84,-191.6 159.2,-200.74 163.73,-195.41"/>
# </g>
# <!-- Testing&#45;&gt;Drilling -->
# <g id="edge1" class="edge">
# <title>Testing-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points
dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.7.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap

# %% [markdown]
# ## Soft evidence on chance node

# %%
gnb.showInference(oil,evs={'OilContents':[0.7,0.5,0.8]})

# %% [markdown]
# ## Forced decision

# %%
gnb.showInference(oil,evs={'Drilling':'Yes'})

# %% [markdown]
# ## LIMID versus Influence Diagram
#
# The default inference for influence diagram actually an inference for LIMIDs. In order to use it for classical (and solvable) influence diagram, do not forget to add the sequence of decision nodes using `addNoForgettingAssumption`.

# %%
infdiag=gum.fastID("Chance->*Decision1->Chance2->$Utility<-Chance3<-*Decision2<-Chance->Utility")
infdiag
# Out:
# (pyAgrum.InfluenceDiagram<double>@0x562112cd11c0) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 2,
#   arcs: 7,
#   domainSize: 32
# }

# %%
ie=gum.ShaferShenoyLIMIDInference(infdiag)
try:
    ie.makeInference()
except gum.GumException as e:
    print(e)
# Out:
# [pyAgrum] Fatal error: This LIMID/Influence Diagram is not solvable.

# %%
ie.addNoForgettingAssumption(["Decision1","Decision2"])
gnb.sideBySide(ie.reducedLIMID(),ie.junctionTree(),gnb.getInference(infdiag,engine=ie))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="261pt" height="339pt" viewBox="0.00 0.00 261.26 339.38">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 335.38)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <ellipse fill="#808080" stroke="black" cx="200.74" cy="-310.88" rx="47.25" ry="20.51"/>
# <text text-anchor="middle" x="200.74" y="-307.18" font-family="Times,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="#9a5050" stroke="black" points="172.74,-254.37 88.74,-254.37 88.74,-225.37 172.74,-225.37 172.74,-254.37"/>
# <text text-anchor="middle" x="130.74" y="-236.17" font-family="Times,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="183.05,-291.03 181.62,-289.68 180.16,-288.31 178.67,-286.91 177.16,-285.49 175.63,-284.06 174.08,-282.6 172.52,-281.14 170.95,-279.66 169.37,-278.17 167.79,-276.68 166.2,-275.19 164.61,-273.69 163.02,-272.2 161.44,-270.71 159.87,-269.23 158.31,-267.77 156.76,-266.31 155.22,-264.87 153.71,-263.45 152.22,-262.04 152.22,-262.04 153.64,-263.51 155.09,-265.01 156.55,-266.52 158.03,-268.05 159.52,-269.59 161.02,-271.14 162.53,-272.7 164.04,-274.26 165.56,-275.83 167.08,-277.4 168.59,-278.96 170.1,-280.52 171.6,-282.07 173.09,-283.61 174.56,-285.14 176.02,-286.65 177.46,-288.13 178.88,-289.6 180.28,-291.04 181.65,-292.46 183.05,-291.03"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="156.16,-261.05 146.59,-256.52 151.25,-266.03 156.16,-261.05"/>
# </g>
# <!-- Decision2 -->
# <g id="node5" class="node">
# <title>Decision2</title>
# <polygon fill="#9a5050" stroke="black" points="220.74,-189.37 136.74,-189.37 136.74,-160.37 220.74,-160.37 220.74,-189.37"/>
# <text text-anchor="middle" x="178.74" y="-171.17" font-family="Times,serif" font-size="14.00" fill="white">Decision2</text>
# </g>
# <!-- Chance&#45;&gt;Decision2 -->
# <g id="edge3" class="edge">
# <title>Chance-&gt;Decision2</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="198.48,-289.94 197.83,-286.25 197.15,-282.34 196.43,-278.23 195.67,-273.94 194.9,-269.51 194.09,-264.94 193.27,-260.27 192.44,-255.52 191.6,-250.7 190.74,-245.85 189.89,-240.98 189.04,-236.13 188.19,-231.3 187.35,-226.53 186.53,-221.83 185.72,-217.24 184.94,-212.77 184.18,-208.44 183.45,-204.28 182.75,-200.32 182.75,-200.32 183.36,-204.3 184,-208.47 184.66,-212.81 185.35,-217.3 186.06,-221.91 186.78,-226.62 187.51,-231.41 188.25,-236.25 188.99,-241.13 189.74,-246.01 190.49,-250.88 191.22,-255.72 191.95,-260.49 192.67,-265.18 193.37,-269.76 194.05,-274.21 194.71,-278.51 195.34,-282.63 195.94,-286.56 196.51,-290.26 198.48,-289.94"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="186.07,-200.89 180.99,-191.59 179.16,-202.03 186.07,-200.89"/>
# </g>
# <!-- Utility -->
# <g id="node6" class="node">
# <title>Utility</title>
# <polygon fill
title>
# <polygon fill="palegreen" stroke="#4a4a4a" points="187.36,-83 76.36,-83 76.36,-72 187.36,-72 187.36,-83"/>
# <text text-anchor="middle" x="131.86" y="-75.6" font-family="Times,serif" font-size="8.00">Chance,Chance2,Decision2</text>
# </g>
# <!-- Chance&#4

# %% [markdown]
# ## Customizing visualization of the results
#
# Using `pyAgrum.config`, it is possible to adapt the graphical representations for Influence Diagram (see [99-Tools_configForPyAgrum.ipynb](configForPyAgrum.ipynb.html) ).

# %%
gum.config.reset()
gnb.showInference(infdiag,engine=ie,size="7!")

# %% [markdown]
# Many visual options can be changed when displaing an inference (especially for influence diagrams)

# %%
# do not show inference time
gum.config["notebook","show_inference_time"]=False
# more digits for probabilities
gum.config["notebook","histogram_horizontal_visible_digits"]=3

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# specificic for influence diagram :
# more digits for utilities
gum.config["influenceDiagram","utility_visible_digits"]=5
# disabling stdev for utility and MEU
gum.config["influenceDiagram","utility_show_stdev"]=False
# showing loss (=-utility) and mEL (minimum Expected Loss) instead of MEU
gum.config["influenceDiagram","utility_show_loss"]=True

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# more visual changes for influence diagram and inference
gum.config.reset()

#shape (https://graphviz.org/doc/info/shapes.html)
gum.config["influenceDiagram","chance_shape"] = "cylinder"
gum.config["influenceDiagram","utility_shape"] = "star"
gum.config["influenceDiagram","decision_shape"] = "box3d"

#colors
gum.config["influenceDiagram","default_chance_bgcolor"] = "green"
gum.config["influenceDiagram","default_utility_bgcolor"] = "MediumVioletRed"
gum.config["influenceDiagram","default_decision_bgcolor"] = "DarkSalmon"

gum.config["influenceDiagram","utility_show_stdev"]=False

gnb.sideBySide(infdiag,gnb.getInference(infdiag,engine=ie,targets=["Decision1","Chance3"]))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="231pt" height="374pt" viewBox="0.00 0.00 230.54 374.14">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 370.14)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <path fill="green" stroke="black" d="M177.5,-362.47C177.5,-364.46 162.48,-366.08 144,-366.08 125.52,-366.08 110.5,-364.46 110.5,-362.47 110.5,-362.47 110.5,-329.94 110.5,-329.94 110.5,-327.95 125.52,-326.33 144,-326.33 162.48,-326.33 177.5,-327.95 177.5,-329.94 177.5,-329.94 177.5,-362.47 177.5,-362.47"/>
# <path fill="none" stroke="black" d="M177.5,-362.47C177.5,-360.47 162.48,-358.85 144,-358.85 125.52,-358.85 110.5,-360.47 110.5,-362.47"/>
# <text text-anchor="middle" x="144" y="-342.51" font-family="Times,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="DarkSalmon" stroke="black" points="84,-290.27 3.22,-290.27 0,-287.05 0,-261.27 80.78,-261.27 84,-264.49 84,-290.27"/>
# <polyline fill="none" stroke="black" points="80.78,-287.05 0,-287.05"/>
# <polyline fill="none" stroke="black" points="80.78,-287.05 80.78,-261.27"/>
# <polyline fill="none" stroke="black" points="80.78,-287.05 84,-290.27"/>
# <text text-anchor="middle" x="42" y="-272.07" font-family="Times,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points
&gt;Utility</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M168.13,-326.49C178.49,-316.92 189.48,-304.32 195,-290.27 218.89,-229.43 188.24,-154.32 165.17,-111.02"/>
# <polygon fill="black" stroke="black" points="167.82,-109.59 159.94,-102.51 161.69,-112.96 167.82,-109.59"/>
# </g>
# <!-- Chance2 -->
# <g id="node2" class="node">
# <title>Chance2</title>
# <path fill="green" stroke="black" d="M84,-221.59C84,-223.59 66.97,-225.21 46,-225.21 25.03,-225.21 8,-223.59 8,-221.59 8,-221.59 8,-189.07 8,-189.07 8,-187.08 25.03,-185.46 46,-185.46 66.97,-185.46 84,-187.08 84,-189.07 84,-189.07 84,-221.59 84,-221.59"/>
# <path fill="none" stroke="black" d="M84,-221.59C84,-219.6 66.97,-217.98 46,-217.98 25.03,-217.98 8,-219.6 8,-221.59"/>
# <text text-anchor="middle" x="46" y="-201.63" font-family="Times,serif" font-size="14.00" fill="white">Chance2</text>
# </g>
# <!-- Chance2&#45;&gt;Utility -->
# <g id="edge5" class="edge">
# <title>Chance2-&gt;Utility</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M60.67,-185.07C76.46,-164.35 101.8,-131.08 120.4,-106.67"/>
# <polygon fill="black" stroke="black" points="123.64,-109.2 126.92,-99.12 118.07,-104.95 123.64,-109.2"/>
# </g>
# <!-- Chance3 -->
# <g id="node3" class="node">
# <title>Chance3</title>
# <path fill="green" stroke="black" d="M182,-221.59C182,-223.59 164.97,-225.21 144,-225.21 123.03,-225.21 106,-223.59 106,-221.59 106,-221.59 106,-189.07 106,-189.07 106,-187.08 123.03,-185.46 144,-185.46 164.97,-185.46 182,-187.08 182,-189.07 182,-189.07 182,-221.59 182,-221.59"/>
# <path fill="none" stroke="black" d="M182,-221.59C182,-219.6 164.97,-217.98 144,-217.98 123.03,-217.98 106,-219.6 106,-221.59"/>
# <text text-anchor="middle" x="144" y="-201.63" font-family="Times,serif" font-size="14.00" fill="white">Chance3</text>
# </g>
# <!-- Chance3&#45;&gt;Utility -->
# <g id="edge6" class="edge">
# <title>Chance3-&gt;Utility</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M144,-185.07C144,-178.35 144,-170.3 144,-161.66"/>
# <polygon fill="black" stroke="black" points="147.5,-161.88 144,-151.88 140.5,-161.88 147.5,-161.88"/>
# </g>
# <!-- Decision1&#45;&gt;Chance2 -->
# <g id="edge4" class="edge">
# <title>Decision1-&gt;Chance2</title>
# <path fill="none" stroke="black" d="M42.81,-260.92C43.22,-253.86 43.74,-244.98 44.24,-236.44"/>
# <polygon fill="black" stroke="black" points="47.78,-236.79 44.87,-226.61 40.8,-236.38 47.78,-236.79"/>
# </g>
# <!-- Decision2&#45;&gt;Chance3 -->
# <g id="edge7" class="edge">
# <title>Decision2-&gt;Chance3</title>
# <path fill="none" stroke="black" d="M144,-260.92C144,-253.86 144,-244.98 144,-236.44"/>
# <polygon fill="black" stroke="black" points="147.5,-236.61 144,-226.61 140.5,-236.61 147.5,-236.61"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="327pt" height="474pt" viewBox="0.00 0.00 327.00 474.06">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 470.06)">
# <title>structs</title>
# <text text-anchor="middle" x="159.5" y="-22.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">MEU 14.91</text>
# <text text-anchor="middle" x="159.5" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.33ms</text>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <path fill="green" stroke="#000000" d="M186.5,-463.09C186.5,-464.83
