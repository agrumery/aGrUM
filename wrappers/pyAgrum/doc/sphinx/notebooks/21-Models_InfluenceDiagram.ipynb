# %% [markdown]
# # Influence diagram

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
import os

# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt
from IPython.display import display,HTML

import math

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %% [markdown]
# ## Build a influencediagram
#
# ### fast build with string

# %%
gum.fastID("A->*B->$C<-D<-*E->*G->H->*I<-D")
# Out:
# (pyAgrum.InfluenceDiagram<double>@00000208A7A1F640) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 4,
#   arcs: 8,
#   domainSize: 128
# }

# %% [markdown]
# ### bifxml format file

# %%
diag=gum.loadID("res/diag.bifxml")
gnb.showInfluenceDiagram(diag)

# %%
diag
# Out:
# (pyAgrum.InfluenceDiagram<double>@00000208A7A20870) Influence Diagram{
#   chance: 5,
#   utility: 2,
#   decision: 4,
#   arcs: 12,
#   domainSize: 512
# }

# %% [markdown]
# ### the hard way :-)

# %%
F=diag.addChanceNode(gum.LabelizedVariable("F","F",2))
diag.addArc(diag.idFromName("decisionVar1"),F)

U=diag.addUtilityNode(gum.LabelizedVariable("U","U",1))
diag.addArc(diag.idFromName("decisionVar3"),U)
diag.addArc(diag.idFromName("F"),U)
gnb.showInfluenceDiagram(diag)

# %%
diag.cpt(F)[{'decisionVar1':0}]=[0.9,0.1]
diag.cpt(F)[{'decisionVar1':1}]=[0.3,0.7]

diag.utility(U)[{'F':0,'decisionVar3':0}]=2
diag.utility(U)[{'F':0,'decisionVar3':1}]=4
diag.utility(U)[{'F':1}]=[[0],[5]]

# %% [markdown]
# ## Optimization in an influence diagram (actually LIMID)

# %%
oil=gum.loadID("res/OilWildcatter.bifxml")
gnb.flow.row(oil,gnb.getInference(oil))
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="295pt" height="281pt" viewBox="0.00 0.00 294.57 280.73">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 276.73)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="black" cx="109.28" cy="-172.04" rx="53.07" ry="20.51"/>
# <text text-anchor="middle" x="109.28" y="-168.34" font-family="Times New Roman,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="black" points="136.28,-112.36 82.28,-112.36 82.28,-83.36 136.28,-83.36 136.28,-112.36"/>
# <text text-anchor="middle" x="109.28" y="-94.16" font-family="Times New Roman,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="110.28,-151.31 110.23,-150.04 110.18,-148.76 110.13,-147.45 110.08,-146.13 110.04,-144.79 109.99,-143.43 109.94,-142.07 109.88,-140.7 109.83,-139.32 109.78,-137.93 109.73,-136.54 109.68,-135.15 109.63,-133.76 109.58,-132.36 109.53,-130.98 109.48,-129.59 109.43,-128.22 109.38,-126.85 109.33,-125.5 109.28,-124.15 109.28,-124.15 109.23,-125.5 109.18,-126.85 109.13,-128.22 109.08,-129.59 109.02,-130.98 108.97,-132.36 108.92,-133.76 108.87,-135.15 108.82,-136.54 108.77,-137.93 108.72,-139.32 108.67,-140.7 108.62,-142.07 108.57,-143.43 108.52,-144.79 108.47,-146.13 108.42,-147.45 108.37,-148.76 108.32,-150.04 108.28,-151.31 110.28,-151.31"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="112.78,-125.86 109.28,-115.86 105.78,-125.86 112.78,-125.86"/>
# </g>
# <!-- OilContents -->
# <g id="node2" class="node">
# <title>OilContents</title>
# <ellipse fill="#808080" stroke="black" cx="57.28" cy="-252.22" rx="57.05" ry="20.51"/>
# <text text-anchor="middle" x="57.28" y="-248.52" font-family="Times New Roman,serif" font-size="14.00" fill="white">OilContents</text>
# </g>
# <!-- OilContents&#45;&gt;TestResult -->
# <g id="edge6" class="edge">
# <title>OilContents-&gt;TestResult</title>
# <path fill="none" stroke="black" d="M70.13,-231.89C76.13,-222.87 83.4,-211.94 90.03,-201.97"/>
# <polygon fill="black" stroke="black" points="92.93,-203.94 95.55,-193.67 87.1,-200.06 92.93,-203.94"/>
# </g>
# <!-- Reward -->
# <g id="node6" class="node">
# <title>Reward</title>
# <polygon fill="#50508a" stroke
div><div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="493pt" height="347pt" viewBox="0.00 0.00 492.90 347.36">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 343.36)">
# <title>structs</title>
# <text text-anchor="middle" x="242.45" y="-22.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">MEU 22.50 (stdev=87.46)</text>
# <text text-anchor="middle" x="242.45" y="-7.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.00ms</text>
# <!-- Testing -->
# <g id="node1" class="node">
# <title>Testing</title>
# <polygon fill="none" stroke="#000000" points="189.14,-334.36 51.14,-334.36 51.14,-292.36 189.14,-292.36 189.14,-334.36"/>
# <svg viewBox="0 0 181.554687 53.538125" width="138px" height="42px" preserveAspectRatio="xMinYMin meet" x="51.1392" y="-334.357"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2022-11-11T19:34:41.219713</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.6.2, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </

# %%
# a function to show results on decision nodes T and D
def show_decisions(ie):
    gnb.flow.row(ie.optimalDecision("Testing"),
                   ie.optimalDecision("Drilling"),
                   f"$${ie.MEU()['mean']:5.3f}\\ (stdev : {math.sqrt(ie.MEU()['variance']):5.3f})$$",
                   captions=["Strategy for T",
                             "Strategy for D",
                             "MEU and its standard deviation>"])
    gnb.flow.row(ie.posterior("Testing"),ie.posteriorUtility("Testing"),
                   ie.posterior("Drilling"),ie.posteriorUtility("Drilling"),
                  captions=["Final decision for Testing","Final reward for Testing",
                            "Final decision for Drilling","Final reward for Drilling"])

ie=gum.ShaferShenoyLIMIDInference(oil) 

display(HTML("<h2>Inference in the LIMID optimizing the decisions nodes</h2>"))
ie.makeInference()
show_decisions(ie)
# Out:
# <h2>Inference in the LIMID optimizing the decisions nodes</h2>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# </table><br><center><small><em>Strategy for T</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>Drilling</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>TestResult</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>closed</center></th><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>open</center></th><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>diffuse</center></th><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td></tr>
# </table><br><center><small><em>Strategy for D</em></small></center></div><div class="floating-box">$$22.500\ (stdev : 87.457)$$<br><center><small><em>MEU and its standard deviation></em></small></center></div>
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;'>0.0000</td></tr>
# </table><br><center><small><em>Final decision for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Testing</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;'>22.5000</td><td style='text-align:right;'>20.0000</td></tr>
# </table><br><center><small><em>Final reward for Testing</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='color:black;background-color:#b3ca64;text-align:right;'>0.5900</td><td style='color:black;background-color:#cab364;text-align:right;'>0.4100</td></tr>
# </table><br><center><small><em>Final decision for Drilling</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Drilling</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th></tr>
# <tr><td style='text-align:right;'>45.0847</td><td style='text-align:right;'>-10.0000</td></tr>
# </table><br><center><small><em>Final reward for Drilling</em></small></center></div>

# %% [markdown]
# ## Graphical inference with evidence and targets (developped nodes)

# %%
gnb.sideBySide(oil,
               gnb.getInference(oil,evs={'TestResult':'closed'}),
               gnb.getInference(oil,evs={'TestResult':'open'}),
               gnb.getInference(oil,evs={'TestResult':'diffuse'}),
               oil,
               gnb.getInference(oil,evs={'OilContents':'Dry'}),
               gnb.getInference(oil,evs={'OilContents':'Wet'}),
               gnb.getInference(oil,evs={'OilContents':'Soaking'}),
               ncols=4)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="295pt" height="281pt" viewBox="0.00 0.00 294.57 280.73">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 276.73)">
# <title>G</title>
# <!-- TestResult -->
# <g id="node1" class="node">
# <title>TestResult</title>
# <ellipse fill="#808080" stroke="black" cx="109.28" cy="-172.04" rx="53.07" ry="20.51"/>
# <text text-anchor="middle" x="109.28" y="-168.34" font-family="Times New Roman,serif" font-size="14.00" fill="white">TestResult</text>
# </g>
# <!-- Drilling -->
# <g id="node4" class="node">
# <title>Drilling</title>
# <polygon fill="#9a5050" stroke="black" points="136.28,-112.36 82.28,-112.36 82.28,-83.36 136.28,-83.36 136.28,-112.36"/>
# <text text-anchor="middle" x="109.28" y="-94.16" font-family="Times New Roman,serif" font-size="14.00" fill="white">Drilling</text>
# </g>
# <!-- TestResult&#45;&gt;Drilling -->
# <g id="edge5" class="edge">
# <title>TestResult-&gt;Drilling</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points
/>
# <polygon fill="black" stroke="black" stroke-width="2" points="146.78,-117.27 136.58,-114.4 142.77,-123 146.78,-117.27"/>
# </g>
# <!-- Cost -->
# <g id="node5" class="node">
# <title>Cost</title>
# <polygon fill="#50508a" stroke="black" points="286.36,-172.04 269.32,-195.89 235.23,-195.89 218.19,-172.04 235.23,-148.18 269.32,-148.18 286.36,-172.04"/>
# <text text-anchor="middle" x="252.28" y="-168.34" font-family="Times New Roman,serif" font-size="14.00" fill="white">Cost</text>
# </g>
# <!-- Testing&#45;&gt;Cost -->
# <g id="edge3" class="edge">
# <title>Testing-&gt;Cost</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M201.36,-237.24C208.62,-228.09 218.4,-215.76 227.44,-204.35"/>
# <polygon fill="black" stroke="black" points="230.07,-206.67 233.54,-196.66 224.59,-202.32 230.07,-206.67"/>
# </g>
# <!-- Drilling&#45;&gt;Reward -->
# <g id="edge4" class="edge">
# <title>Drilling-&gt;Reward</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M101.37,-82.94C97.28,-75.74 92.09,-66.61 87.05,-57.73"/>
# <polygon fill="black" stroke="black" points="90.21,-56.21 82.23,-49.24 84.12,-59.67 90.21,-56.21"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="496pt" height="347pt" viewBox="0.00 0.00 495.61 347.36">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 343.36)">
# <title>structs</title>
# <text text-anchor="middle" x="243.8" y="-22.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">MEU 77.50 (stdev=104.73)</text>
# <text text-anchor="middle" x="243.8" y="-7.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">Inference in   2.00ms</text>
# <!-- Testing -->
# <g id="node1" class="node">
# <title>Testing</title>
# <polygon fill="none" stroke="#000000" points="189.13,-334.36 51.13,-334.36 51.13,-292.36 189.13,-292.36 189.13,-334.36"/>
# <svg viewBox="0 0 181.554687 53.538125" width="138px" height="42px" preserveAspectRatio="xMinYMin meet" x="51.1347" y="-334.357"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2022-11-11T19:34:42.108240</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.6.2, https://matplotlib.org/</dc:title>
#      </cc:Agen

# %% [markdown]
# ## Soft evidence on chance node

# %%
gnb.showInference(oil,evs={'OilContents':[0.7,0.5,0.8]})

# %% [markdown]
# ## Forced decision

# %%
gnb.showInference(oil,evs={'Drilling':'Yes'})

# %% [markdown]
# ## LIMID versus Influence Diagram
#
# The default inference for influence diagram actually an inference for LIMIDs. In order to use it for classical (and solvable) influence diagram, do not forget to add the sequence of decision nodes using `addNoForgettingAssumption`.

# %%
infdiag=gum.fastID("Chance->*Decision1->Chance2->$Utility<-Chance3<-*Decision2<-Chance->Utility")
infdiag
# Out:
# (pyAgrum.InfluenceDiagram<double>@00000208A7E19550) Influence Diagram{
#   chance: 3,
#   utility: 1,
#   decision: 2,
#   arcs: 7,
#   domainSize: 32
# }

# %%
ie=gum.ShaferShenoyLIMIDInference(infdiag)
try:
    ie.makeInference()
except gum.GumException as e:
    print(e)
# Out:
# [pyAgrum] Fatal error: This LIMID/Influence Diagram is not solvable.

# %%
ie.addNoForgettingAssumption(["Decision1","Decision2"])
gnb.sideBySide(ie.reducedLIMID(),ie.junctionTree(),gnb.getInference(infdiag,engine=ie))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="224pt" height="339pt" viewBox="0.00 0.00 224.04 339.38">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 335.38)">
# <title>G</title>
# <!-- Chance -->
# <g id="node1" class="node">
# <title>Chance</title>
# <ellipse fill="#808080" stroke="black" cx="168.55" cy="-310.88" rx="40.11" ry="20.51"/>
# <text text-anchor="middle" x="168.55" y="-307.18" font-family="Times New Roman,serif" font-size="14.00" fill="white">Chance</text>
# </g>
# <!-- Decision1 -->
# <g id="node4" class="node">
# <title>Decision1</title>
# <polygon fill="#9a5050" stroke="black" points="140.55,-254.37 70.55,-254.37 70.55,-225.37 140.55,-225.37 140.55,-254.37"/>
# <text text-anchor="middle" x="105.55" y="-236.17" font-family="Times New Roman,serif" font-size="14.00" fill="white">Decision1</text>
# </g>
# <!-- Chance&#45;&gt;Decision1 -->
# <g id="edge1" class="edge">
# <title>Chance-&gt;Decision1</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points
&gt;Decision2</title>
# <polygon fill="black" stroke="none" stroke-width="2" stroke-dasharray="1,5" points="116.56,-225.48 117.37,-224.3 118.19,-223.09 119.04,-221.86 119.9,-220.6 120.77,-219.32 121.66,-218.03 122.55,-216.71 123.46,-215.38 124.38,-214.04 125.31,-212.68 126.24,-211.32 127.17,-209.95 128.11,-208.58 129.05,-207.21 129.98,-205.84 130.92,-204.47 131.85,-203.1 132.78,-201.75 133.7,-200.4 134.61,-199.06 134.61,-199.06 133.62,-200.34 132.62,-201.63 131.6,-202.92 130.59,-204.23 129.57,-205.54 128.55,-206.85 127.53,-208.16 126.5,-209.47 125.49,-210.78 124.47,-212.08 123.46,-213.37 122.47,-214.65 121.48,-215.92 120.5,-217.18 119.53,-218.42 118.58,-219.64 117.64,-220.84 116.72,-222.02 115.83,-223.17 114.95,-224.3 116.56,-225.48"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="136.51,-202.4 139.58,-192.26 130.86,-198.27 136.51,-202.4"/>
# </g>
# <!-- Decision2&#45;&gt;Chance3 -->
# <g id="edge8" class="edge">
# <title>Decision2-&gt;Chance3</title>
# <path fill="none" stroke="black" d="M151.55,-159.9C151.55,-153.05 151.55,-144.5 151.55,-136.2"/>
# <polygon fill="black" stroke="black" points="155.05,-136.34 151.55,-126.34 148.05,-136.34 155.05,-136.34"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="220pt" height="163pt" viewBox="0.00 0.00 219.92 163.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 159)">
# <title>InfluenceDiagram</title>
# <!-- Chance&#45;Chance2&#45;Decision1&#45;Decision2 -->
# <g id="node1" class="node">
# <title>Chance-Chance2-Decision1-Decision2</title>
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="105.96" cy="-137" rx="105.92" ry="18"/>
# <text text-anchor="middle" x="105.96" y="-134.5" font-family="Times New Roman,serif" font-size="10.00">(0):Chance,Chance2,Decision1,Decision2</text>
# </g>
# <!-- Chance&#45;Chance2&#45;Decision1&#45;Decision2+Chance&#45;Chance2&#45;Chance3&#45;Decision2 -->
# <g id="node3" class="node">
# <title>Chance-Chance2-Decision1-Decision2+Chance-Chance2-Chance3-Decision2</title>
# <polygon fill="palegreen" stroke="#4a4a4a" points="154.46,-83 57.46,-83 57.46,-72 154.46,-72 154.46,-83"/>
# <text text-anchor="middle" x="105.96" y="-75.6" font-family="Times New Roman,serif" fon

# %% [markdown]
# ## Customizing visualization of the results
#
# Using `pyAgrum.config`, it is possible to adapt the graphical representations for Influence Diagram (see [99-Tools_configForPyAgrum.ipynb](configForPyAgrum.ipynb.html) ).

# %%
gum.config.reset()
gnb.showInference(infdiag,engine=ie,size="7!")

# %% [markdown]
# Many visual options can be changed when displaing an inference (especially for influence diagrams)

# %%
# do not show inference time
gum.config["notebook","show_inference_time"]=False
# more digits for probabilities
gum.config["notebook","histogram_horizontal_visible_digits"]=3

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# specificic for influence diagram :
# more digits for utilities
gum.config["influenceDiagram","utility_visible_digits"]=5
# disabling stdev for utility and MEU
gum.config["influenceDiagram","utility_show_stdev"]=False
# showing loss (=-utility) and mEL (minimum Expected Loss) instead of MEU
gum.config["influenceDiagram","utility_show_loss"]=True

gnb.showInference(infdiag,engine=ie,size="7!")

# %%
# more visual changes for influence diagram and inference
gum.config.reset()

#shape (https://graphviz.org/doc/info/shapes.html)
gum.config["influenceDiagram","chance_shape"] = "cylinder"
gum.config["influenceDiagram","utility_shape"] = "star"
gum.config["influenceDiagram","decision_shape"] = "box3d"

#colors
gum.config["influenceDiagram","default_chance_bgcolor"] = "green"
gum.config["influenceDiagram","default_utility_bgcolor"] = "MediumVioletRed"
gum.config["influenceDiagram","default_decision_bgcolor"] = "DarkSalmon"

gum.config["influenceDiagram","utility_show_stdev"]=False

gnb.sideBySide(infdiag,gnb.getInference(infdiag,engine=ie,targets=["Decision1","Chance3"]))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width