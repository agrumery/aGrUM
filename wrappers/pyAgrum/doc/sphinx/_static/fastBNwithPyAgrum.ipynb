# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

import pyAgrum.causal as csl
import pyAgrum.causal.notebook as cslnb

# %%
bn=gum.fastBN("A->B;C->B->D",3)
gnb.sideBySide(bn,
               bn.cpt("B"),
               gnb.getJunctionTree(bn),
               gnb.getInference(bn),
               captions=['a BN','a CPT : $P(B|A,C)$','a Junction Tree','an inference'])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="134pt" height="188pt" viewBox="0.00 0.00 134.00 188.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- A -->
# <g id="node1" class="node">
# <title>A</title>
# <g id="a_node1"><a xlink:title="(0) A">
# <ellipse fill="#404040" stroke="black" cx="27" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">A</text>
# </a>
# </g>
# </g>
# <!-- B -->
# <g id="node2" class="node">
# <title>B</title>
# <g id="a_node2"><a xlink:title="(1) B">
# <ellipse fill="#404040" stroke="black" cx="63" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">B</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge1" class="edge">
# <title>A-&gt;B</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path fill="none" stroke="#4a4a4a" d="M35.35,-144.76C39.71,-136.28 45.15,-125.71 50.04,-116.2"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="53.23,-117.64 54.7,-107.15 47.01,-114.44 53.23,-117.64"/>
# </a>
# </g>
# </g>
# <!-- D -->
# <g id="node4" class="node">
# <title>D</title>
# <g id="a_node4"><a xlink:title="(3) D">
# <ellipse fill="#404040" stroke="black" cx="63" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">D</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&gt;D -->
# <g id="edge2" class="edge">
# <title>B-&gt;D</title>
# <g id="a_edge2"><a xlink:title="(1, 3) : ">
# <path fill="none" stroke="#4a4a4a" d="M63,-71.7C63,-63.98 63,-54.71 63,-46.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="66.5,-46.1 63,-36.1 59.5,-46.1 66.5,-46.1"/>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node3" class="node">
# <title>C</title>
# <g id="a_node3"><a xlink:title="(2) C">
# <ellipse fill="#404040" stroke="black" cx="99" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">C</text>
# </a>
# </g>
# </g>
# <!-- C&#45;&gt;B -->
# <g id="edge3" class="edge">
# <title>C-&gt;B</title>
# <g id="a_edge3"><a xlink:title="(2, 1) : ">
# <path fill="none" stroke="#4a4a4a" d="M90.65,-144.76C86.29,-136.28 80.85,-125.71 75.96,-116.2"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="78.99,-114.44 71.3,-107.15 72.77,-117.64 78.99,-114.44"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='2'></th><th colspan='3' style='border:1px solid black;color:black;background-color:#808080;'><center>B</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>C</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>A</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>2</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#ceaf64;text-align:right;'>0.3777</td><td style='color:black;background-color:#e09d64;text-align:right;'>0.2394</td><td style='color:black;background-color:#cdb064;text-align:right;'>0.3828</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#bebf64;text-align:right;'>0.5045</td><td style='color:black;background-color:#ec9164;text-align:right;'>0.1455</td><td style='color:black;background-color:#d2ab64;text-align:right;'>0.3499</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>2</center></th><td style='color:black;background-color:#e69764;text-align:right;'>0.1902</td><td style='color:black;background-color:#dca164;text-align:right;'>0.2699</td><td style='color:black;background-color:#b9c464;text-align:right;'>0.5398</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#e09d64;text-align:right;'>0.2354</td><td style='color:black;background-color:#c6b764;text-align:right;'>0.4377</td><td style='color:black;background-color:#d5a864;text-align:right;'>0.3270</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#bac364;text-align:right;'>0.5313</td><td style='color:black;background-color:#cfae64;text-align:right;'>0.3695</td><td style='color:black;background-color:#f28b64;text-align:right;'>0.0991</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>2</center></th><td style='color:black;background-color:#ee8f64;text-align:right;'>0.1253</td><td style='color:black;background-color:#b5c864;text-align:right;'>0.5724</td><td style='color:black;background-color:#d8a564;text-align:right;'>0.3023</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'><center>2</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#daa364;text-align:right;'>0.2883</td><td style='color:black;background-color:#f48964;text-align:right;'>0.0806</td><td style='color:black;background-color:#aecf64;text-align:right;'>0.6311</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#cab364;text-align:right;'>0.4122</td><td style='color:black;background-color:#f18c64;text-align:right;'>0.1077</td><td style='color:black;background-color:#c1bc64;text-align:right;'>0.4801</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>2</center></th><td style='color:black;background-color:#9fde64;text-align:right;'>0.7462</td><td style='color:black;background-color:#e49964;text-align:right;'>0.2097</td><td style='color:black;background-color:#f98464;text-align:right;'>0.0441</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="62pt" height="163pt" viewBox="0.00 0.00 62.00 163.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 159)">
# <title>BayesNet</title>
# <!-- B&#45;D -->
# <g id="node1" class="node">
# <title>B-D</title>
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="27" cy="-137" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-134.5" font-family="Times New Roman,serif" font-size="10.00">B D</text>
# </g>
# <!-- B&#45;D+A&#45;B&#45;C -->
# <g id="node3" class="node">
# <title>B-D+A-B-C</title>
# <polygon fill="palegreen" stroke="#4a4a4a" points="31,-83 23,-83 23,-72 31,-72 31,-83"/>
# <text text-anchor="middle" x="27" y="-75.6" font-family="Times New Roman,serif" font-size="8.00">B</text>
# </g>
# <!-- B&#45;D&#45;&#45;B&#45;D+A&#45;B&#45;C -->
# <g id="edge1" class="edge">
# <title>B-D--B-D+A-B-C</title>
# <path fill="none" stroke="#4a4a4a" d="M27,-118.75C27,-106.57 27,-91.11 27,-83.37"/>
# </g>
# <!-- A&#45;B&#45;C -->
# <g id="node2" class="node">
# <title>A-B-C</title>
# <ell

# %%
model=gum.fastID("*c<-*a->b<-c->$d;b->$d",3)

gnb.sideBySide(model,
               model.utility("d"),
               gnb.getInference(model),
               captions=['an Influence Diagram','a utility : $U(d|b,c)$','an inference'])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="117pt" height="262pt" viewBox="0.00 0.00 117.00 262.37">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 258.37)">
# <title>G</title>
# <!-- b -->
# <g id="node1" class="node">
# <title>b</title>
# <ellipse fill="#808080" stroke="black" cx="27" cy="-103.86" rx="27" ry="20.51"/>
# <text text-anchor="middle" x="27" y="-100.16" font-family="Times New Roman,serif" font-size="14.00" fill="white">b</text>
# </g>
# <!-- d -->
# <g id="node4" class="node">
# <title>d</title>
# <polygon fill="#50508a" stroke="black" points="81,-23.68 67.5,-47.54 40.5,-47.54 27,-23.68 40.5,0.18 67.5,0.18 81,-23.68"/>
# <text text-anchor="middle" x="54" y="-19.98" font-family="Times New Roman,serif" font-size="14.00" fill="white">d</text>
# </g>
# <!-- b&#45;&gt;d -->
# <g id="edge5" class="edge">
# <title>b-&gt;d</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M33.54,-83.94C36.31,-75.9 39.62,-66.31 42.77,-57.2"/>
# <polygon fill="black" stroke="black" points="46.12,-58.21 46.08,-47.61 39.51,-55.92 46.12,-58.21"/>
# </g>
# <!-- c -->
# <g id="node2" class="node">
# <title>c</title>
# <polygon fill="#9a5050" stroke="black" points="109,-189.37 55,-189.37 55,-160.37 109,-160.37 109,-189.37"/>
# <text text-anchor="middle" x="82" y="-171.17" font-family="Times New Roman,serif" font-size="14.00" fill="white">c</text>
# </g>
# <!-- c&#45;&gt;b -->
# <g id="edge1" class="edge">
# <title>c-&gt;b</title>
# <path fill="none" stroke="black" d="M71.13,-160.24C64.22,-151.56 55.05,-140.06 46.87,-129.79"/>
# <polygon fill="black" stroke="black" points="49.54,-127.53 40.57,-121.89 44.07,-131.89 49.54,-127.53"/>
# </g>
# <!-- c&#45;&gt;d -->
# <g id="edge2" class="edge">
# <title>c-&gt;d</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M79.47,-160.37C75.13,-137.26 66.17,-89.52 60.12,-57.28"/>
# <polygon fill="black" stroke="black" points="63.55,-56.6 58.27,-47.42 56.67,-57.89 63.55,-56.6"/>
# </g>
# <!-- a -->
# <g id="node3" class="node">
# <title>a</title>
# <polygon fill="#9a5050" stroke="black" points="81,-254.37 27,-254.37 27,-225.37 81,-225.37 81,-254.37"/>
# <text text-anchor="middle" x="54" y="-236.17" font-family="Times New Roman,serif" font-size="14.00" fill="white">a</text>
# </g>
# <!-- a&#45;&gt;b -->
# <g id="edge4" class="edge">
# <title>a-&gt;b</title>
# <path fill="none" stroke="black" d="M51.21,-225.03C46.94,-203.8 38.65,-162.7 32.98,-134.54"/>
# <polygon fill="black" stroke="black" points="36.35,-133.55 30.94,-124.44 29.49,-134.93 36.35,-133.55"/>
# </g>
# <!-- a&#45;&gt;c -->
# <g id="edge3" class="edge">
# <title>a-&gt;c</title>
# <polygon fill="black" stroke="transparent" stroke-width="2" stroke-dasharray="1,5" points="60.99,-225.61 61.47,-224.42 61.96,-223.21 62.46,-221.96 62.97,-220.7 63.49,-219.41 64.02,-218.09 64.56,-216.77 65.1,-215.42 65.65,-214.06 66.2,-212.69 66.75,-211.32 67.31,-209.93 67.87,-208.54 68.43,-207.15 68.99,-205.77 69.55,-204.38 70.11,-203 70.66,-201.62 71.21,-200.26 71.76,-198.91 71.76,-198.91 71.12,-200.22 70.48,-201.54 69.83,-202.87 69.18,-204.21 68.52,-205.56 67.87,-206.9 67.21,-208.25 66.56,-209.6 65.9,-210.94 65.25,-212.28 64.61,-213.6 63.97,-214.92 63.33,-216.22 62.71,-217.51 62.09,-218.78 61.48,-220.03 60.88,-221.26 60.29,-222.47 59.72,-223.64 59.16,-224.79 60.99,-225.61"/>
# <polygon fill="black" stroke="black" stroke-width="2" points="75.07,-200.07 75.94,-189.51 68.68,-197.23 75.07,-200.07"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='2'></th><th colspan='1' style='border:1px solid black;color:black;background-color:#808080;'><center>d</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>b</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>c</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>-0.3836</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>4.2567</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>2</center></th><td style='text-align:right;'>26.5780</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>6.2374</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>36.3576</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>2</center></th><td style='text-align:right;'>36.8200</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'><center>2</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>-6.3958</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>31.8073</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>2</center></th><td style='text-align:right;'>17.2866</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="225pt" height="357pt" viewBox="0.00 0.00 225.00 357.36">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 353.36)">
# <title>structs</title>
# <text text-anchor="middle" x="108.5" y="-22.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">MEU 30.00 (stdev=5.26)</text>
# <text text-anchor="middle" x="108.5" y="-7.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.00ms</text>
# <!-- c -->
# <g id="node1" class="node">
# <title>c</title>
# <polygon fill="none" stroke="#000000" points="217,-261.36 91,-261.36 91,-209.36 217,-209.36 217,-261.36"/>
# <svg viewBox="0 0 165.409375 66.588125" width="126px" height="52px" preserveAspectRatio="xMinYMin meet" x="91" y="-261.357"> <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-02-28T23:34:23.932616</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.3.4, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.588125  L 165.409375 66.588125  L 165.409375 0  L 0 0  z " style="fill:#9a5050;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 50.209375 59.488125  L 161.809375 59.488125  L 161.809375 18.718125  L 50.209375 18.718125  z " style="fill:#ffffff;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p8e7468e7ea)" d="M 50.209375 59.488125  L 161.809375 59.488125  L 161.809375 47.839554  L 50.209375 47.839554  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p8e7468e7ea)" d="M 50.209375 44.927411  L 50.209375 44.927

# %%
model=gum.fastMN("a-b-c;b-c-d",3)

gnb.sideBySide(model,
               model.factor(['a','b','c']),
               gnb.getInference(model),
               captions=[' Markov Net (as factor graph)','a factor : $\phi(a,b,c)$','an inference'])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="197pt" height="100pt" viewBox="0.00 0.00 196.80 100.03">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 96.03)">
# <title>G</title>
# <!-- b -->
# <g id="node1" class="node">
# <title>b</title>
# <g id="a_node1"><a xlink:title="(1) b">
# <polygon fill="coral" stroke="black" points="88.48,-89.17 74.48,-89.17 74.48,-68.17 88.48,-68.17 88.48,-89.17"/>
# <text text-anchor="middle" x="81.48" y="-74.97" font-family="Times New Roman,serif" font-size="14.00">b</text>
# </a>
# </g>
# </g>
# <!-- d -->
# <g id="node2" class="node">
# <title>d</title>
# <g id="a_node2"><a xlink:title="(3) d">
# <polygon fill="coral" stroke="black" points="14,-21 0,-21 0,0 14,0 14,-21"/>
# <text text-anchor="middle" x="7" y="-6.8" font-family="Times New Roman,serif" font-size="14.00">d</text>
# </a>
# </g>
# </g>
# <!-- c -->
# <g id="node3" class="node">
# <title>c</title>
# <g id="a_node3"><a xlink:title="(2) c">
# <polygon fill="coral" stroke="black" points="115.26,-21.57 102.26,-21.57 102.26,-0.57 115.26,-0.57 115.26,-21.57"/>
# <text text-anchor="middle" x="108.76" y="-7.37" font-family="Times New Roman,serif" font-size="14.00">c</text>
# </a>
# </g>
# </g>
# <!-- a -->
# <g id="node4" class="node">
# <title>a</title>
# <g id="a_node4"><a xlink:title="(0) a">
# <polygon fill="coral" stroke="black" points="188.8,-92.03 175.8,-92.03 175.8,-71.03 188.8,-71.03 188.8,-92.03"/>
# <text text-anchor="middle" x="182.3" y="-77.83" font-family="Times New Roman,serif" font-size="14.00">a</text>
# </a>
# </g>
# </g>
# <!-- f0#1#2 -->
# <g id="node5" class="node">
# <title>f0#1#2</title>
# <ellipse fill="burlywood" stroke="black" cx="134.13" cy="-60.55" rx="3.6" ry="3.6"/>
# </g>
# <!-- f0#1#2&#45;&#45;b -->
# <g id="edge2" class="edge">
# <title>f0#1#2--b</title>
# <path fill="none" stroke="#4a4a4a" d="M130.68,-61.74C122.16,-64.67 100.05,-72.28 88.59,-76.22"/>
# </g>
# <!-- f0#1#2&#45;&#45;c -->
# <g id="edge3" class="edge">
# <title>f0#1#2--c</title>
# <path fill="none" stroke="#4a4a4a" d="M132.47,-57.3C128.85,-50.25 120.14,-33.26 114.35,-21.96"/>
# </g>
# <!-- f0#1#2&#45;&#45;a -->
# <g id="edge1" class="edge">
# <title>f0#1#2--a</title>
# <path fill="none" stroke="#4a4a4a" d="M137.59,-62.06C145.53,-65.52 165.15,-74.06 175.56,-78.6"/>
# </g>
# <!-- f1#2#3 -->
# <g id="node6" class="node">
# <title>f1#2#3</title>
# <ellipse fill="burlywood" stroke="black" cx="56.14" cy="-29.09" rx="3.6" ry="3.6"/>
# </g>
# <!-- f1#2#3&#45;&#45;b -->
# <g id="edge4" class="edge">
# <title>f1#2#3--b</title>
# <path fill="none" stroke="#4a4a4a" d="M57.8,-32.34C61.41,-39.41 70.11,-56.43 75.9,-67.76"/>
# </g>
# <!-- f1#2#3&#45;&#45;d -->
# <g id="edge6" class="edge">
# <title>f1#2#3--d</title>
# <path fill="none" stroke="#4a4a4a" d="M52.6,-27.75C44.59,-24.72 24.92,-17.28 14.22,-13.23"/>
# </g>
# <!-- f1#2#3&#45;&#45;c -->
# <g id="edge5" class="edge">
# <title>f1#2#3--c</title>
# <path fill="none" stroke="#4a4a4a" d="M59.59,-27.91C68.19,-24.96 90.68,-17.26 102.02,-13.38"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='2'></th><th colspan='3' style='border:1px solid black;color:black;background-color:#808080;'><center>a</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>c</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>b</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>2</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.3663</td><td style='text-align:right;'>0.6926</td><td style='text-align:right;'>0.9410</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.2406</td><td style='text-align:right;'>0.5294</td><td style='text-align:right;'>0.6345</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>2</center></th><td style='text-align:right;'>0.3003</td><td style='text-align:right;'>0.1713</td><td style='text-align:right;'>0.0174</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.4099</td><td style='text-align:right;'>0.0156</td><td style='text-align:right;'>0.6221</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.7128</td><td style='text-align:right;'>0.6671</td><td style='text-align:right;'>0.7551</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>2</center></th><td style='text-align:right;'>0.2469</td><td style='text-align:right;'>0.1774</td><td style='text-align:right;'>0.6485</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'><center>2</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.5075</td><td style='text-align:right;'>0.4339</td><td style='text-align:right;'>0.6849</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.7194</td><td style='text-align:right;'>0.1183</td><td style='text-align:right;'>0.3202</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>2</center></th><td style='text-align:right;'>0.3010</td><td style='text-align:right;'>0.7512</td><td style='text-align:right;'>0.2668</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="203pt" height="336pt" viewBox="0.00 0.00 202.67 336.14">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 332.14)">
# <title>G</title>
# <text text-anchor="middle" x="97.33" y="-7.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">Inference in   1.00ms</text>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="151.26,-85 50.26,-85 50.26,-23 151.26,-23 151.26,-85"/>
# <svg viewBox="0 0 132.1625 80.0255" width="101px" height="62px" preserveAspectRatio="xMinYMin meet" x="50.2633" y="-85"> <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-02-28T23:34:24.479990</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.3.4, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 80.0255  L 132.1625 80.0255  L 132.1625 0  L 0 0  z " style="fill:#e0e0e0;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 72.9255  L 128.5625 72.9255  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fi

# %%
bn=gum.fastBN("A->B;C->B->D",3)
d = csl.CausalModel(bn, [("lat1", ["A","D"])])
cslnb.showCausalImpact(d,"D","A",values={"A":0})
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="161pt" height="228pt" viewBox="0.00 0.00 161.00 227.60">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 223.6)">
# <title>G</title>
# <!-- lat1 -->
# <g id="node1" class="node">
# <title>lat1</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="90" cy="-217.8" rx="1.8" ry="1.8"/>
# </g>
# <!-- A -->
# <g id="node2" class="node">
# <title>A</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">A</text>
# </g>
# <!-- lat1&#45;&gt;A -->
# <g id="edge2" class="edge">
# <title>lat1-&gt;A</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="M88.91,-215.87C84.34,-211.97 66.33,-196.59 50.91,-183.42"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="53.04,-180.63 43.16,-176.8 48.49,-185.96 53.04,-180.63"/>
# </g>
# <!-- D -->
# <g id="node5" class="node">
# <title>D</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="126" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="126" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">D</text>
# </g>
# <!-- lat1&#45;&gt;D -->
# <g id="edge4" class="edge">
# <title>lat1-&gt;D</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="M91.48,-216.18C98.13,-213.28 125.32,-200.43 135,-180 155.56,-136.63 144.54,-79.14 135.03,-45.9"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="138.28,-44.56 132.03,-36 131.58,-46.59 138.28,-44.56"/>
# </g>
# <!-- B -->
# <g id="node3" class="node">
# <title>B</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="99" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">B</text>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge1" class="edge">
# <title>A-&gt;B</title>
# <path fill="none" stroke="#4a4a4a" d="M40.87,-146.12C51.05,-136.22 64.83,-122.83 76.33,-111.64"/>
# <path fill="none" stroke="#4a4a4a" d="M42.27,-147.55C52.45,-137.65 66.22,-124.26 77.73,-113.08"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="79.47,-114.87 84.2,-105.38 74.59,-109.85 79.47,-114.87"/>
# </g>
# <!-- B&#45;&gt;D -->
# <g id="edge5" class="edge">
# <title>B-&gt;D</title>
# <path fill="none" stroke="#4a4a4a" d="M104.47,-72.05C107.58,-63.98 111.4,-54.07 114.9,-44.99"/>
# <path fill="none" stroke="#4a4a4a" d="M106.33,-72.77C109.45,-64.7 113.27,-54.79 116.77,-45.71"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="119.13,-46.55 119.46,-35.96 112.6,-44.03 119.13,-46.55"/>
# </g>
# <!-- C -->
# <g id="node4" class="node">
# <title>C</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="99" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">C</text>
# </g>
# <!-- C&#45;&gt;B -->
# <g id="edge3" class="edge">
# <title>C-&gt;B</title>
# <path fill="none" stroke="#4a4a4a" d="M98,-143.7C98,-135.98 98,-126.71 98,-118.11"/>
# <path fill="none" stroke="#4a4a4a" d="M100,-143.7C100,-135.98 100,-126.71 100,-118.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.5,-118.1 99,-108.1 95.5,-118.1 102.5,-118.1"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style="">$$\begin{equation}P( D \mid \hookrightarrow\mkern-6.5muA) = \sum_{B}{P\left(B\mid A\right) \cdot \left(\sum_{A'}{P\left(D\mid A',B\right) \cdot P\left(A'\right)}\right)}\end{equation}$$</div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'><th colspan='3'><center>D</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>2</center></th></tr>
# <tr><td style='color:black;background-color:#bbc264;text-align:right;'>0.5282</td><td style='color:black;background-color:#e09d64;text-align:right;'>0.2408</td><td style='color:black;background-color:#e19c64;text-align:right;'>0.2309</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Causal Model</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Explanation : frontdoor ['B'] found.</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Impact : $P( D \mid \hookrightarrow\mkern-6.5muA=0)$</small></div></td></tr></table>
