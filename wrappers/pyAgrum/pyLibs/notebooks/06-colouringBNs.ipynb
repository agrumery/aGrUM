# %% [markdown]
# <a href="http://agrum.org" target="blank"><img src="http://agrum.gitlab.io/theme/img/logoAgrum.png" align="left" style="height:100px"/></a><a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This pyAgrum's notebook is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.

# %%
from pylab import *
import matplotlib.pyplot as plt

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
gnb.forDarkTheme()

bn=gum.fastBN("a->b->c->d;b->e->d->f;g->c")
gnb.sideBySide(bn,gnb.getInference(bn))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="332pt" viewBox="0.00 0.00 134.00 332.00" width="134pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- a -->
# <g class="node" id="node1">
# <title>a</title>
# <g id="a_node1"><a xlink:title="(0) a">
# <ellipse cx="99" cy="-306" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-301.8">a</text>
# </a>
# </g>
# </g>
# <!-- b -->
# <g class="node" id="node2">
# <title>b</title>
# <g id="a_node2"><a xlink:title="(1) b">
# <ellipse cx="99" cy="-234" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-229.8">b</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g class="edge" id="edge1">
# <title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M99,-287.8314C99,-280.131 99,-270.9743 99,-262.4166" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="102.5001,-262.4132 99,-252.4133 95.5001,-262.4133 102.5001,-262.4132" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- c -->
# <g class="node" id="node3">
# <title>c</title>
# <g id="a_node3"><a xlink:title="(2) c">
# <ellipse cx="27" cy="-162" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-157.8">c</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g class="edge" id="edge2">
# <title>b-&gt;c</title>
# <g id="a_edge2"><a xlink:title="(1, 2) : ">
# <path d="M83.7307,-218.7307C73.803,-208.803 60.6847,-195.6847 49.5637,-184.5637" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="51.7933,-181.8436 42.2473,-177.2473 46.8436,-186.7933 51.7933,-181.8436" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g class="node" id="node5">
# <title>e</title>
# <g id="a_node5"><a xlink:title="(4) e">
# <ellipse cx="99" cy="-162" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-157.8">e</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g class="edge" id="edge3">
# <title>b-&gt;e</title>
# <g id="a_edge3"><a xlink:title="(1, 4) : ">
# <path d="M99,-215.8314C99,-208.131 99,-198.9743 99,-190.4166" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="102.5001,-190.4132 99,-180.4133 95.5001,-190.4133 102.5001,-190.4132" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g class="node" id="node4">
# <title>d</title>
# <g id="a_node4"><a xlink:title="(3) d">
# <ellipse cx="63" cy="-90" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-85.8">d</text>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g class="edge" id="edge5">
# <title>c-&gt;d</title>
# <g id="a_edge5"><a xlink:title="(2, 3) : ">
# <path d="M35.7146,-144.5708C39.9597,-136.0807 45.1536,-125.6929 49.8663,-116.2674" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="53.024,-117.7782 54.3657,-107.2687 46.763,-114.6477 53.024,-117.7782" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- f -->
# <g class="node" id="node6">
# <title>f</title>
# <g id="a_node6"><a xlink:title="(5) f">
# <ellipse cx="63" cy="-18" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-13.8">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g class="edge" id="edge7">
# <title>d-&gt;f</title>
# <g id="a_edge7"><a xlink:title="(3, 5) : ">
# <path d="M63,-71.8314C63,-64.131 63,-54.9743 63,-46.4166" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="66.5001,-46.4132 63,-36.4133 59.5001,-46.4133 66.5001,-46.4132" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g class="edge" id="edge6">
# <title>e-&gt;d</title>
# <g id="a_edge6"><a xlink:title="(4, 3) : ">
# <path d="M90.2854,-144.5708C86.0403,-136.0807 80.8464,-125.6929 76.1337,-116.2674" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="79.237,-114.6477 71.6343,-107.2687 72.976,-117.7782 79.237,-114.6477" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- g -->
# <g class="node" id="node7">
# <title>g</title>
# <g id="a_node7"><a xlink:title="(6) g">
# <ellipse cx="27" cy="-234" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-229.8">g</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g class="edge" id="edge4">
# <title>g-&gt;c</title>
# <g id="a_edge4"><a xlink:title="(6, 2) : ">
# <path d="M27,-215.8314C27,-208.131 27,-198.9743 27,-190.4166" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="30.5001,-190.4132 27,-180.4133 23.5001,-190.4133 30.5001,-190.4132" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="434pt" viewBox="0.00 0.00 228.00 434.00" width="228pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 430)">
# <title>structs</title>
# <text fill="#aaaaaa" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="110" y="-6.8">Inference in   2.18ms</text>
# <!-- a -->
# <g class="node" id="node1">
# <title>a</title>
# <polygon fill="#ffffff" points="220,-426 119,-426 119,-374 220,-374 220,-426" stroke="#000000"/>
# <svg height="52px" preserveAspectRatio="xMinYMin meet" viewBox="0 0 132.1625 66.4355" width="101px" x="119" y="-426"> <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.4355  L 132.1625 66.4355  L 132.1625 0  L 0 0  z " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 59.3355  L 128.5625 59.3355  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:none;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p15efef9f4f)" d="M 16.9625 59.3355  L 61.089954 59.3355  L 61.089954 47.2555  L 16.9625 47.2555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p15efef9f4f)" d="M 16.9625 44.2355  L 84.435046 44.2355  L 84.435046 32.1555  L 16.9625 32.1555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p15efef9f4f)" d="M 16.9625 59.3355  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="mde255e023e" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#mde255e023e" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p15efef9f4f)" d="M 72.7625 59.3355  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#mde255e023e" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p15efef9f4f)" d="M 128.5625 59.3355  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="128.5625" xlink:href="#mde255e023e" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path d="M 0 0  L -3.5 0  " id="m02a71e12ae" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>

# %%
def nodevalue(n):
    return 0.5 if n in "aeiou" else 0.7
def arcvalue(a):
    return (10-a[0])*a[1]
def arcvalue2(a):
    return (a[0]+a[1]+5)/22
gnb.showBN(bn,
           nodeColor={n:nodevalue(n) for n in bn.names()},
           arcWidth={a:arcvalue(a) for a in bn.arcs()},
           arcColor={a:arcvalue2(a) for a in bn.arcs()})

# %%
gnb.showInference(bn,
           targets={"a","g","f","b"},
           evs={'e':0},
           nodeColor={n:nodevalue(n) for n in bn.names()},
           arcWidth={a:arcvalue(a) for a in bn.arcs()})

# %%
gnb.sideBySide(gnb.getBN(bn,
                         nodeColor={n:nodevalue(n) for n in bn.names()},
                         arcWidth={a:arcvalue(a) for a in bn.arcs()}),
               gnb.getInference(bn,
                                nodeColor={n:nodevalue(n) for n in bn.names()},
                                arcWidth={a:arcvalue(a) for a in bn.arcs()})
              )
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="332pt" viewBox="0.00 0.00 134.00 332.00" width="134pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- a -->
# <g class="node" id="node1">
# <title>a</title>
# <g id="a_node1"><a xlink:title="(0) a : 0.50000">
# <ellipse cx="99" cy="-306" fill="#fed9a6" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-301.8">a</text>
# </a>
# </g>
# </g>
# <!-- b -->
# <g class="node" id="node2">
# <title>b</title>
# <g id="a_node2"><a xlink:title="(1) b : 0.70000">
# <ellipse cx="99" cy="-234" fill="#e5d8bd" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-229.8">b</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g class="edge" id="edge1">
# <title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : 10">
# <path d="M99,-287.8314C99,-280.131 99,-270.9743 99,-262.4166" fill="none" stroke="#aaaaaa" stroke-width=".4571"/>
# <polygon fill="#aaaaaa" points="102.5001,-262.4132 99,-252.4133 95.5001,-262.4133 102.5001,-262.4132" stroke="#aaaaaa" stroke-width=".4571"/>
# </a>
# </g>
# </g>
# <!-- c -->
# <g class="node" id="node3">
# <title>c</title>
# <g id="a_node3"><a xlink:title="(2) c : 0.70000">
# <ellipse cx="27" cy="-162" fill="#e5d8bd" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-157.8">c</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g class="edge" id="edge2">
# <title>b-&gt;c</title>
# <g id="a_edge2"><a xlink:title="(1, 2) : 18">
# <path d="M83.7307,-218.7307C73.803,-208.803 60.6847,-195.6847 49.5637,-184.5637" fill="none" stroke="#aaaaaa" stroke-width="1.8857"/>
# <polygon fill="#aaaaaa" points="51.7933,-181.8436 42.2473,-177.2473 46.8436,-186.7933 51.7933,-181.8436" stroke="#aaaaaa" stroke-width="1.8857"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g class="node" id="node5">
# <title>e</title>
# <g id="a_node5"><a xlink:title="(4) e : 0.50000">
# <ellipse cx="99" cy="-162" fill="#fed9a6" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-157.8">e</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g class="edge" id="edge3">
# <title>b-&gt;e</title>
# <g id="a_edge3"><a xlink:title="(1, 4) : 36">
# <path d="M99,-215.8314C99,-208.131 99,-198.9743 99,-190.4166" fill="none" stroke="#aaaaaa" stroke-width="5.1"/>
# <polygon fill="#aaaaaa" points="103.4626,-190.4132 99,-180.4133 94.5376,-190.4133 103.4626,-190.4132" stroke="#aaaaaa" stroke-width="5.1"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g class="node" id="node4">
# <title>d</title>
# <g id="a_node4"><a xlink:title="(3) d : 0.70000">
# <ellipse cx="63" cy="-90" fill="#e5d8bd" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-85.8">d</text>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g class="edge" id="edge5">
# <title>c-&gt;d</title>
# <g id="a_edge5"><a xlink:title="(2, 3) : 24">
# <path d="M35.7146,-144.5708C39.9597,-136.0807 45.1536,-125.6929 49.8663,-116.2674" fill="none" stroke="#aaaaaa" stroke-width="2.9571"/>
# <polygon fill="#aaaaaa" points="53.024,-117.7782 54.3657,-107.2687 46.763,-114.6477 53.024,-117.7782" stroke="#aaaaaa" stroke-width="2.9571"/>
# </a>
# </g>
# </g>
# <!-- f -->
# <g class="node" id="node6">
# <title>f</title>
# <g id="a_node6"><a xlink:title="(5) f : 0.70000">
# <ellipse cx="63" cy="-18" fill="#e5d8bd" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-13.8">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g class="edge" id="edge7">
# <title>d-&gt;f</title>
# <g id="a_edge7"><a xlink:title="(3, 5) : 35">
# <path d="M63,-71.8314C63,-64.131 63,-54.9743 63,-46.4166" fill="none" stroke="#aaaaaa" stroke-width="4.9214"/>
# <polygon fill="#aaaaaa" points="67.3063,-46.4132 63,-36.4133 58.6938,-46.4133 67.3063,-46.4132" stroke="#aaaaaa" stroke-width="4.9214"/>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g class="edge" id="edge6">
# <title>e-&gt;d</title>
# <g id="a_edge6"><a xlink:title="(4, 3) : 18">
# <path d="M90.2854,-144.5708C86.0403,-136.0807 80.8464,-125.6929 76.1337,-116.2674" fill="none" stroke="#aaaaaa" stroke-width="1.8857"/>
# <polygon fill="#aaaaaa" points="79.237,-114.6477 71.6343,-107.2687 72.976,-117.7782 79.237,-114.6477" stroke="#aaaaaa" stroke-width="1.8857"/>
# </a>
# </g>
# </g>
# <!-- g -->
# <g class="node" id="node7">
# <title>g</title>
# <g id="a_node7"><a xlink:title="(6) g : 0.70000">
# <ellipse cx="27" cy="-234" fill="#e5d8bd" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-229.8">g</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g class="edge" id="edge4">
# <title>g-&gt;c</title>
# <g id="a_edge4"><a xlink:title="(6, 2) : 8">
# <path d="M27,-215.8314C27,-208.131 27,-198.9743 27,-190.4166" fill="none" stroke="#aaaaaa" stroke-width=".1"/>
# <polygon fill="#aaaaaa" points="30.5001,-190.4132 27,-180.4133 23.5001,-190.4133 30.5001,-190.4132" stroke="#aaaaaa" stroke-width=".1"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="434pt" viewBox="0.00 0.00 228.00 434.00" width="228pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 430)">
# <title>structs</title>
# <text fill="#aaaaaa" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="110" y="-6.8">Inference in   1.06ms</text>
# <!-- a -->
# <g class="node" id="node1">
# <title>a</title>
# <polygon fill="#fed9a6" points="220,-426 119,-426 119,-374 220,-374 220,-426" stroke="#000000"/>
# <svg height="52px" preserveAspectRatio="xMinYMin meet" viewBox="0 0 132.1625 66.4355" width="101px" x="119" y="-426"> <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.4355  L 132.1625 66.4355  L 132.1625 0  L 0 0  z " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 59.3355  L 128.5625 59.3355  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:none;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#pd2d35c8e82)" d="M 16.9625 59.3355  L 61.089954 59.3355  L 61.089954 47.2555  L 16.9625 47.2555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#pd2d35c8e82)" d="M 16.9625 44.2355  L 84.435046 44.2355  L 84.435046 32.1555  L 16.9625 32.1555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pd2d35c8e82)" d="M 16.9625 59.3355  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="ma793141498" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#ma793141498" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#pd2d35c8e82)" d="M 72.7625 59.3355  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#ma793141498" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#pd2d35c8e82)" d="M 128.5625 59.3355  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g

# %%
import matplotlib.pyplot as plt
mycmap=plt.get_cmap('Reds')
formyarcs=plt.get_cmap('winter')
gnb.sideBySide(gnb.getBN(bn,
                         nodeColor={n:nodevalue(n) for n in bn.names()},
                         arcColor={a:arcvalue2(a) for a in bn.arcs()},
                         cmap=mycmap,
                         cmapArc=formyarcs),
               gnb.getInference(bn,
                                nodeColor={n:nodevalue(n) for n in bn.names()},
                                arcColor={a:arcvalue2(a) for a in bn.arcs()},
                                arcWidth={a:arcvalue(a) for a in bn.arcs()},
                                cmap=mycmap,
                                cmapArc=formyarcs)
              )
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="332pt" viewBox="0.00 0.00 134.00 332.00" width="134pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- a -->
# <g class="node" id="node1">
# <title>a</title>
# <g id="a_node1"><a xlink:title="(0) a : 0.50000">
# <ellipse cx="99" cy="-306" fill="#fb6949" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-301.8">a</text>
# </a>
# </g>
# </g>
# <!-- b -->
# <g class="node" id="node2">
# <title>b</title>
# <g id="a_node2"><a xlink:title="(1) b : 0.70000">
# <ellipse cx="99" cy="-234" fill="#d92522" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-229.8">b</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g class="edge" id="edge1">
# <title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M99,-287.8314C99,-280.131 99,-270.9743 99,-262.4166" fill="none" stroke="#0045dd"/>
# <polygon fill="#0045dd" points="102.5001,-262.4132 99,-252.4133 95.5001,-262.4133 102.5001,-262.4132" stroke="#0045dd"/>
# </a>
# </g>
# </g>
# <!-- c -->
# <g class="node" id="node3">
# <title>c</title>
# <g id="a_node3"><a xlink:title="(2) c : 0.70000">
# <ellipse cx="27" cy="-162" fill="#d92522" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-157.8">c</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g class="edge" id="edge2">
# <title>b-&gt;c</title>
# <g id="a_edge2"><a xlink:title="(1, 2) : ">
# <path d="M83.7307,-218.7307C73.803,-208.803 60.6847,-195.6847 49.5637,-184.5637" fill="none" stroke="#005dd1"/>
# <polygon fill="#005dd1" points="51.7933,-181.8436 42.2473,-177.2473 46.8436,-186.7933 51.7933,-181.8436" stroke="#005dd1"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g class="node" id="node5">
# <title>e</title>
# <g id="a_node5"><a xlink:title="(4) e : 0.50000">
# <ellipse cx="99" cy="-162" fill="#fb6949" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-157.8">e</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g class="edge" id="edge3">
# <title>b-&gt;e</title>
# <g id="a_edge3"><a xlink:title="(1, 4) : ">
# <path d="M99,-215.8314C99,-208.131 99,-198.9743 99,-190.4166" fill="none" stroke="#0074c5"/>
# <polygon fill="#0074c5" points="102.5001,-190.4132 99,-180.4133 95.5001,-190.4133 102.5001,-190.4132" stroke="#0074c5"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g class="node" id="node4">
# <title>d</title>
# <g id="a_node4"><a xlink:title="(3) d : 0.70000">
# <ellipse cx="63" cy="-90" fill="#d92522" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-85.8">d</text>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g class="edge" id="edge5">
# <title>c-&gt;d</title>
# <g id="a_edge5"><a xlink:title="(2, 3) : ">
# <path d="M35.7146,-144.5708C39.9597,-136.0807 45.1536,-125.6929 49.8663,-116.2674" fill="none" stroke="#0074c5"/>
# <polygon fill="#0074c5" points="53.024,-117.7782 54.3657,-107.2687 46.763,-114.6477 53.024,-117.7782" stroke="#0074c5"/>
# </a>
# </g>
# </g>
# <!-- f -->
# <g class="node" id="node6">
# <title>f</title>
# <g id="a_node6"><a xlink:title="(5) f : 0.70000">
# <ellipse cx="63" cy="-18" fill="#d92522" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-13.8">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g class="edge" id="edge7">
# <title>d-&gt;f</title>
# <g id="a_edge7"><a xlink:title="(3, 5) : ">
# <path d="M63,-71.8314C63,-64.131 63,-54.9743 63,-46.4166" fill="none" stroke="#0097b4"/>
# <polygon fill="#0097b4" points="66.5001,-46.4132 63,-36.4133 59.5001,-46.4133 66.5001,-46.4132" stroke="#0097b4"/>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g class="edge" id="edge6">
# <title>e-&gt;d</title>
# <g id="a_edge6"><a xlink:title="(4, 3) : ">
# <path d="M90.2854,-144.5708C86.0403,-136.0807 80.8464,-125.6929 76.1337,-116.2674" fill="none" stroke="#008bba"/>
# <polygon fill="#008bba" points="79.237,-114.6477 71.6343,-107.2687 72.976,-117.7782 79.237,-114.6477" stroke="#008bba"/>
# </a>
# </g>
# </g>
# <!-- g -->
# <g class="node" id="node7">
# <title>g</title>
# <g id="a_node7"><a xlink:title="(6) g : 0.70000">
# <ellipse cx="27" cy="-234" fill="#d92522" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-229.8">g</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g class="edge" id="edge4">
# <title>g-&gt;c</title>
# <g id="a_edge4"><a xlink:title="(6, 2) : ">
# <path d="M27,-215.8314C27,-208.131 27,-198.9743 27,-190.4166" fill="none" stroke="#0097b4"/>
# <polygon fill="#0097b4" points="30.5001,-190.4132 27,-180.4133 23.5001,-190.4133 30.5001,-190.4132" stroke="#0097b4"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="434pt" viewBox="0.00 0.00 228.00 434.00" width="228pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 430)">
# <title>structs</title>
# <text fill="#aaaaaa" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="110" y="-6.8">Inference in   1.19ms</text>
# <!-- a -->
# <g class="node" id="node1">
# <title>a</title>
# <polygon fill="#fb6949" points="220,-426 119,-426 119,-374 220,-374 220,-426" stroke="#000000"/>
# <svg height="52px" preserveAspectRatio="xMinYMin meet" viewBox="0 0 132.1625 66.4355" width="101px" x="119" y="-426"> <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.4355  L 132.1625 66.4355  L 132.1625 0  L 0 0  z " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 59.3355  L 128.5625 59.3355  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:none;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p00ebc3555e)" d="M 16.9625 59.3355  L 61.089954 59.3355  L 61.089954 47.2555  L 16.9625 47.2555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p00ebc3555e)" d="M 16.9625 44.2355  L 84.435046 44.2355  L 84.435046 32.1555  L 16.9625 32.1555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p00ebc3555e)" d="M 16.9625 59.3355  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="m66702fb2f1" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m66702fb2f1" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p00ebc3555e)" d="M 72.7625 59.3355  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#m66702fb2f1" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p00ebc3555e)" d="M 128.5625 59.3355  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="128.5625" xlink:href="#m66702fb2f1" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path d="M 0 0  L -3.5 0  " id="m77715666
