# %% [markdown]
# <a href="http://agrum.org" target="blank"><img src="http://agrum.gitlab.io/theme/img/logoAgrum.png" align="left" style="height:100px"/></a><a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This pyAgrum's notebook is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.

# %%
from pylab import *
import matplotlib.pyplot as plt

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
gnb.forDarkTheme()

bn=gum.fastBN("a->b->c->d;b->e->d->f;g->c")
gnb.sideBySide(bn,gnb.getInference(bn))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="134pt" height="332pt" viewBox="0.00 0.00 134.00 332.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <g id="a_node1"><a xlink:title="(0) a">
# <ellipse fill="#404040" stroke="black" cx="99" cy="-306" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-302.3" font-family="Times,serif" font-size="14.00" fill="white">a</text>
# </a>
# </g>
# </g>
# <!-- b -->
# <g id="node2" class="node">
# <title>b</title>
# <g id="a_node2"><a xlink:title="(1) b">
# <ellipse fill="#404040" stroke="black" cx="99" cy="-234" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-230.3" font-family="Times,serif" font-size="14.00" fill="white">b</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g id="edge1" class="edge">
# <title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path fill="none" stroke="#aaaaaa" d="M99,-287.7C99,-279.98 99,-270.71 99,-262.11"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" points="102.5,-262.1 99,-252.1 95.5,-262.1 102.5,-262.1"/>
# </a>
# </g>
# </g>
# <!-- c -->
# <g id="node3" class="node">
# <title>c</title>
# <g id="a_node3"><a xlink:title="(2) c">
# <ellipse fill="#404040" stroke="black" cx="27" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">c</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g id="edge3" class="edge">
# <title>b-&gt;c</title>
# <g id="a_edge3"><a xlink:title="(1, 2) : ">
# <path fill="none" stroke="#aaaaaa" d="M84.43,-218.83C74.25,-208.94 60.48,-195.55 48.97,-184.36"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" points="51.41,-181.85 41.8,-177.38 46.53,-186.87 51.41,-181.85"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g id="node5" class="node">
# <title>e</title>
# <g id="a_node5"><a xlink:title="(4) e">
# <ellipse fill="#404040" stroke="black" cx="99" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">e</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g id="edge5" class="edge">
# <title>b-&gt;e</title>
# <g id="a_edge5"><a xlink:title="(1, 4) : ">
# <path fill="none" stroke="#aaaaaa" d="M99,-215.7C99,-207.98 99,-198.71 99,-190.11"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" points="102.5,-190.1 99,-180.1 95.5,-190.1 102.5,-190.1"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g id="node4" class="node">
# <title>d</title>
# <g id="a_node4"><a xlink:title="(3) d">
# <ellipse fill="#404040" stroke="black" cx="63" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">d</text>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g id="edge6" class="edge">
# <title>c-&gt;d</title>
# <g id="a_edge6"><a xlink:title="(2, 3) : ">
# <path fill="none" stroke="#aaaaaa" d="M35.35,-144.76C39.71,-136.28 45.15,-125.71 50.04,-116.2"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" points="53.23,-117.64 54.7,-107.15 47.01,-114.44 53.23,-117.64"/>
# </a>
# </g>
# </g>
# <!-- f -->
# <g id="node6" class="node">
# <title>f</title>
# <g id="a_node6"><a xlink:title="(5) f">
# <ellipse fill="#404040" stroke="black" cx="63" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g id="edge7" class="edge">
# <title>d-&gt;f</title>
# <g id="a_edge7"><a xlink:title="(3, 5) : ">
# <path fill="none" stroke="#aaaaaa" d="M63,-71.7C63,-63.98 63,-54.71 63,-46.11"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" points="66.5,-46.1 63,-36.1 59.5,-46.1 66.5,-46.1"/>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g id="edge4" class="edge">
# <title>e-&gt;d</title>
# <g id="a_edge4"><a xlink:title="(4, 3) : ">
# <path fill="none" stroke="#aaaaaa" d="M90.65,-144.76C86.29,-136.28 80.85,-125.71 75.96,-116.2"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" points="78.99,-114.44 71.3,-107.15 72.77,-117.64 78.99,-114.44"/>
# </a>
# </g>
# </g>
# <!-- g -->
# <g id="node7" class="node">
# <title>g</title>
# <g id="a_node7"><a xlink:title="(6) g">
# <ellipse fill="#404040" stroke="black" cx="27" cy="-234" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-230.3" font-family="Times,serif" font-size="14.00" fill="white">g</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g id="edge2" class="edge">
# <title>g-&gt;c</title>
# <g id="a_edge2"><a xlink:title="(6, 2) : ">
# <path fill="none" stroke="#aaaaaa" d="M27,-215.7C27,-207.98 27,-198.71 27,-190.11"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" points="30.5,-190.1 27,-180.1 23.5,-190.1 30.5,-190.1"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="228pt" height="435pt" viewBox="0.00 0.00 228.00 435.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 431)">
# <title>structs</title>
# <text text-anchor="middle" x="110" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#aaaaaa">Inference in   0.83ms</text>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <polygon fill="white" stroke="#000000" points="220,-427 119,-427 119,-375 220,-375 220,-427"/>
# <svg viewBox="0 0 132.1625 66.4355" width="101px" height="52px" preserveAspectRatio="xMinYMin meet" x="119" y="-427"> <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.4355  L 132.1625 66.4355  L 132.1625 0  L 0 0  z " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 59.3355  L 128.5625 59.3355  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:none;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p704da233d1)" d="M 16.9625 59.3355  L 85.974379 59.3355  L 85.974379 47.2555  L 16.9625 47.2555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p704da233d1)" d="M 16.9625 44.2355  L 59.550621 44.2355  L 59.550621 32.1555  L 16.9625 32.1555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p704da233d1)" d="M 16.9625 59.3355  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="mfa4f3a6519" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#mfa4f3a6519" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p704da233d1)" d="M 72.7625 59.3355  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#mfa4f3a6519" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p704da233d1)" d="M 128.5625 59.3355  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="128.5625" xlink:href="#mfa4f3a6519" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path d="M 0 0  L -3.5 0  " id="mbd77299dd8" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#mbd77299dd8" y="53.2955"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 1 -->
#       <defs>
#        <path d="M 12.40625 8.296875  L 28.515625 8.296875  L

# %%
def nodevalue(n):
    return 0.5 if n in "aeiou" else 0.7
def arcvalue(a):
    return (10-a[0])*a[1]
def arcvalue2(a):
    return (a[0]+a[1]+5)/22
gnb.showBN(bn,
           nodeColor={n:nodevalue(n) for n in bn.names()},
           arcWidth={a:arcvalue(a) for a in bn.arcs()},
           arcColor={a:arcvalue2(a) for a in bn.arcs()})

# %%
gnb.showInference(bn,
           targets={"a","g","f","b"},
           evs={'e':0},
           nodeColor={n:nodevalue(n) for n in bn.names()},
           arcWidth={a:arcvalue(a) for a in bn.arcs()})

# %%
gnb.sideBySide(gnb.getBN(bn,
                         nodeColor={n:nodevalue(n) for n in bn.names()},
                         arcWidth={a:arcvalue(a) for a in bn.arcs()}),
               gnb.getInference(bn,
                                nodeColor={n:nodevalue(n) for n in bn.names()},
                                arcWidth={a:arcvalue(a) for a in bn.arcs()})
              )
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="134pt" height="332pt" viewBox="0.00 0.00 134.00 332.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <g id="a_node1"><a xlink:title="(0) a : 0.50000">
# <ellipse fill="#fed9a6" stroke="black" cx="99" cy="-306" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-302.3" font-family="Times,serif" font-size="14.00" fill="#000000">a</text>
# </a>
# </g>
# </g>
# <!-- b -->
# <g id="node2" class="node">
# <title>b</title>
# <g id="a_node2"><a xlink:title="(1) b : 0.70000">
# <ellipse fill="#e5d8bd" stroke="black" cx="99" cy="-234" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-230.3" font-family="Times,serif" font-size="14.00" fill="#000000">b</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g id="edge1" class="edge">
# <title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : 10">
# <path fill="none" stroke="#aaaaaa" stroke-width="0.46" d="M99,-287.7C99,-279.98 99,-270.71 99,-262.11"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" stroke-width="0.46" points="102.5,-262.1 99,-252.1 95.5,-262.1 102.5,-262.1"/>
# </a>
# </g>
# </g>
# <!-- c -->
# <g id="node3" class="node">
# <title>c</title>
# <g id="a_node3"><a xlink:title="(2) c : 0.70000">
# <ellipse fill="#e5d8bd" stroke="black" cx="27" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-158.3" font-family="Times,serif" font-size="14.00" fill="#000000">c</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g id="edge3" class="edge">
# <title>b-&gt;c</title>
# <g id="a_edge3"><a xlink:title="(1, 2) : 18">
# <path fill="none" stroke="#aaaaaa" stroke-width="1.89" d="M84.43,-218.83C74.25,-208.94 60.48,-195.55 48.97,-184.36"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" stroke-width="1.89" points="51.41,-181.85 41.8,-177.38 46.53,-186.87 51.41,-181.85"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g id="node5" class="node">
# <title>e</title>
# <g id="a_node5"><a xlink:title="(4) e : 0.50000">
# <ellipse fill="#fed9a6" stroke="black" cx="99" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-158.3" font-family="Times,serif" font-size="14.00" fill="#000000">e</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g id="edge5" class="edge">
# <title>b-&gt;e</title>
# <g id="a_edge5"><a xlink:title="(1, 4) : 36">
# <path fill="none" stroke="#aaaaaa" stroke-width="5.1" d="M99,-215.7C99,-207.98 99,-198.71 99,-190.11"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" stroke-width="5.1" points="103.46,-190.1 99,-180.1 94.54,-190.1 103.46,-190.1"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g id="node4" class="node">
# <title>d</title>
# <g id="a_node4"><a xlink:title="(3) d : 0.70000">
# <ellipse fill="#e5d8bd" stroke="black" cx="63" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-86.3" font-family="Times,serif" font-size="14.00" fill="#000000">d</text>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g id="edge6" class="edge">
# <title>c-&gt;d</title>
# <g id="a_edge6"><a xlink:title="(2, 3) : 24">
# <path fill="none" stroke="#aaaaaa" stroke-width="2.96" d="M35.35,-144.76C39.71,-136.28 45.15,-125.71 50.04,-116.2"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" stroke-width="2.96" points="53.23,-117.64 54.7,-107.15 47.01,-114.44 53.23,-117.64"/>
# </a>
# </g>
# </g>
# <!-- f -->
# <g id="node6" class="node">
# <title>f</title>
# <g id="a_node6"><a xlink:title="(5) f : 0.70000">
# <ellipse fill="#e5d8bd" stroke="black" cx="63" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-14.3" font-family="Times,serif" font-size="14.00" fill="#000000">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g id="edge7" class="edge">
# <title>d-&gt;f</title>
# <g id="a_edge7"><a xlink:title="(3, 5) : 35">
# <path fill="none" stroke="#aaaaaa" stroke-width="4.92" d="M63,-71.7C63,-63.98 63,-54.71 63,-46.11"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" stroke-width="4.92" points="67.31,-46.1 63,-36.1 58.69,-46.1 67.31,-46.1"/>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g id="edge4" class="edge">
# <title>e-&gt;d</title>
# <g id="a_edge4"><a xlink:title="(4, 3) : 18">
# <path fill="none" stroke="#aaaaaa" stroke-width="1.89" d="M90.65,-144.76C86.29,-136.28 80.85,-125.71 75.96,-116.2"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" stroke-width="1.89" points="78.99,-114.44 71.3,-107.15 72.77,-117.64 78.99,-114.44"/>
# </a>
# </g>
# </g>
# <!-- g -->
# <g id="node7" class="node">
# <title>g</title>
# <g id="a_node7"><a xlink:title="(6) g : 0.70000">
# <ellipse fill="#e5d8bd" stroke="black" cx="27" cy="-234" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-230.3" font-family="Times,serif" font-size="14.00" fill="#000000">g</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g id="edge2" class="edge">
# <title>g-&gt;c</title>
# <g id="a_edge2"><a xlink:title="(6, 2) : 8">
# <path fill="none" stroke="#aaaaaa" stroke-width="0.1" d="M27,-215.7C27,-207.98 27,-198.71 27,-190.11"/>
# <polygon fill="#aaaaaa" stroke="#aaaaaa" stroke-width="0.1" points="30.5,-190.1 27,-180.1 23.5,-190.1 30.5,-190.1"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="228pt" height="435pt" viewBox="0.00 0.00 228.00 435.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 431)">
# <title>structs</title>
# <text text-anchor="middle" x="110" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#aaaaaa">Inference in   1.43ms</text>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <polygon fill="#fed9a6" stroke="#000000" points="220,-427 119,-427 119,-375 220,-375 220,-427"/>
# <svg viewBox="0 0 132.1625 66.4355" width="101px" height="52px" preserveAspectRatio="xMinYMin meet" x="119" y="-427"> <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.4355  L 132.1625 66.4355  L 132.1625 0  L 0 0  z " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 59.3355  L 128.5625 59.3355  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:none;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p006e9fe0e5)" d="M 16.9625 59.3355  L 85.974379 59.3355  L 85.974379 47.2555  L 16.9625 47.2555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p006e9fe0e5)" d="M 16.9625 44.2355  L 59.550621 44.2355  L 59.550621 32.1555  L 16.9625 32.1555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p006e9fe0e5)" d="M 16.9625 59.3355  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="mbd78298441" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#mbd78298441" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p006e9fe0e5)" d="M 72.7625 59.3355  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#mbd78298441" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p006e9fe0e5)" d="M 128.5625 59.3355  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="128.5625" xlink:href="#mbd78298441" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="

# %%
import matplotlib.pyplot as plt
mycmap=plt.get_cmap('Reds')
formyarcs=plt.get_cmap('winter')
gnb.sideBySide(gnb.getBN(bn,
                         nodeColor={n:nodevalue(n) for n in bn.names()},
                         arcColor={a:arcvalue2(a) for a in bn.arcs()},
                         cmap=mycmap,
                         cmapArc=formyarcs),
               gnb.getInference(bn,
                                nodeColor={n:nodevalue(n) for n in bn.names()},
                                arcColor={a:arcvalue2(a) for a in bn.arcs()},
                                arcWidth={a:arcvalue(a) for a in bn.arcs()},
                                cmap=mycmap,
                                cmapArc=formyarcs)
              )
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="134pt" height="332pt" viewBox="0.00 0.00 134.00 332.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <g id="a_node1"><a xlink:title="(0) a : 0.50000">
# <ellipse fill="#fb6949" stroke="black" cx="99" cy="-306" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-302.3" font-family="Times,serif" font-size="14.00" fill="#000000">a</text>
# </a>
# </g>
# </g>
# <!-- b -->
# <g id="node2" class="node">
# <title>b</title>
# <g id="a_node2"><a xlink:title="(1) b : 0.70000">
# <ellipse fill="#d92522" stroke="black" cx="99" cy="-234" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-230.3" font-family="Times,serif" font-size="14.00" fill="#000000">b</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g id="edge1" class="edge">
# <title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path fill="none" stroke="#0045dd" d="M99,-287.7C99,-279.98 99,-270.71 99,-262.11"/>
# <polygon fill="#0045dd" stroke="#0045dd" points="102.5,-262.1 99,-252.1 95.5,-262.1 102.5,-262.1"/>
# </a>
# </g>
# </g>
# <!-- c -->
# <g id="node3" class="node">
# <title>c</title>
# <g id="a_node3"><a xlink:title="(2) c : 0.70000">
# <ellipse fill="#d92522" stroke="black" cx="27" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-158.3" font-family="Times,serif" font-size="14.00" fill="#000000">c</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g id="edge3" class="edge">
# <title>b-&gt;c</title>
# <g id="a_edge3"><a xlink:title="(1, 2) : ">
# <path fill="none" stroke="#005dd1" d="M84.43,-218.83C74.25,-208.94 60.48,-195.55 48.97,-184.36"/>
# <polygon fill="#005dd1" stroke="#005dd1" points="51.41,-181.85 41.8,-177.38 46.53,-186.87 51.41,-181.85"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g id="node5" class="node">
# <title>e</title>
# <g id="a_node5"><a xlink:title="(4) e : 0.50000">
# <ellipse fill="#fb6949" stroke="black" cx="99" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-158.3" font-family="Times,serif" font-size="14.00" fill="#000000">e</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g id="edge5" class="edge">
# <title>b-&gt;e</title>
# <g id="a_edge5"><a xlink:title="(1, 4) : ">
# <path fill="none" stroke="#0074c5" d="M99,-215.7C99,-207.98 99,-198.71 99,-190.11"/>
# <polygon fill="#0074c5" stroke="#0074c5" points="102.5,-190.1 99,-180.1 95.5,-190.1 102.5,-190.1"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g id="node4" class="node">
# <title>d</title>
# <g id="a_node4"><a xlink:title="(3) d : 0.70000">
# <ellipse fill="#d92522" stroke="black" cx="63" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-86.3" font-family="Times,serif" font-size="14.00" fill="#000000">d</text>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g id="edge6" class="edge">
# <title>c-&gt;d</title>
# <g id="a_edge6"><a xlink:title="(2, 3) : ">
# <path fill="none" stroke="#0074c5" d="M35.35,-144.76C39.71,-136.28 45.15,-125.71 50.04,-116.2"/>
# <polygon fill="#0074c5" stroke="#0074c5" points="53.23,-117.64 54.7,-107.15 47.01,-114.44 53.23,-117.64"/>
# </a>
# </g>
# </g>
# <!-- f -->
# <g id="node6" class="node">
# <title>f</title>
# <g id="a_node6"><a xlink:title="(5) f : 0.70000">
# <ellipse fill="#d92522" stroke="black" cx="63" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-14.3" font-family="Times,serif" font-size="14.00" fill="#000000">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g id="edge7" class="edge">
# <title>d-&gt;f</title>
# <g id="a_edge7"><a xlink:title="(3, 5) : ">
# <path fill="none" stroke="#0097b4" d="M63,-71.7C63,-63.98 63,-54.71 63,-46.11"/>
# <polygon fill="#0097b4" stroke="#0097b4" points="66.5,-46.1 63,-36.1 59.5,-46.1 66.5,-46.1"/>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g id="edge4" class="edge">
# <title>e-&gt;d</title>
# <g id="a_edge4"><a xlink:title="(4, 3) : ">
# <path fill="none" stroke="#008bba" d="M90.65,-144.76C86.29,-136.28 80.85,-125.71 75.96,-116.2"/>
# <polygon fill="#008bba" stroke="#008bba" points="78.99,-114.44 71.3,-107.15 72.77,-117.64 78.99,-114.44"/>
# </a>
# </g>
# </g>
# <!-- g -->
# <g id="node7" class="node">
# <title>g</title>
# <g id="a_node7"><a xlink:title="(6) g : 0.70000">
# <ellipse fill="#d92522" stroke="black" cx="27" cy="-234" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-230.3" font-family="Times,serif" font-size="14.00" fill="#000000">g</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g id="edge2" class="edge">
# <title>g-&gt;c</title>
# <g id="a_edge2"><a xlink:title="(6, 2) : ">
# <path fill="none" stroke="#0097b4" d="M27,-215.7C27,-207.98 27,-198.71 27,-190.11"/>
# <polygon fill="#0097b4" stroke="#0097b4" points="30.5,-190.1 27,-180.1 23.5,-190.1 30.5,-190.1"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="228pt" height="435pt" viewBox="0.00 0.00 228.00 435.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 431)">
# <title>structs</title>
# <text text-anchor="middle" x="110" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#aaaaaa">Inference in   1.60ms</text>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <polygon fill="#fb6949" stroke="#000000" points="220,-427 119,-427 119,-375 220,-375 220,-427"/>
# <svg viewBox="0 0 132.1625 66.4355" width="101px" height="52px" preserveAspectRatio="xMinYMin meet" x="119" y="-427"> <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.4355  L 132.1625 66.4355  L 132.1625 0  L 0 0  z " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 59.3355  L 128.5625 59.3355  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:none;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p63a2ae91a7)" d="M 16.9625 59.3355  L 85.974379 59.3355  L 85.974379 47.2555  L 16.9625 47.2555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p63a2ae91a7)" d="M 16.9625 44.2355  L 59.550621 44.2355  L 59.550621 32.1555  L 16.9625 32.1555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p63a2ae91a7)" d="M 16.9625 59.3355  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="mbf97f63fee" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#mbf97f63fee" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p63a2ae91a7)" d="M 72.7625 59.3355  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#mbf97f63fee" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p63a2ae91a7)" d="M 128.5625 59.3355  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="128.5625" xlink:href="#mbf97f63fee" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path d="M 0 0  L -3.5 0  " id="m5fa04d73f4" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m5fa04d73f4" y="53.2955"/>
#       </g>
#      </g>
#      <g id="text_1">
