# %% [markdown]
# <a href="http://agrum.org" target="blank"><img src="http://agrum.gitlab.io/theme/img/logoAgrum.png" align="left" style="height:100px"/></a><a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This pyAgrum's notebook is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.

# %%
import sys
import os

import numpy as np

import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %matplotlib inline
from pyAgrum.lib.bn2roc import showROC
from pyAgrum.lib.bn2roc import showPR
from pyAgrum.lib.bn2roc import showROC_PR

SIZE_LEARN=10000
SIZE_VALID=2000

# %%
bn=gum.loadBN("res/alarm.dsl")
bn
# Out:
# (pyAgrum.BayesNet<double>@0x5627a32d9000) BN{nodes: 37, arcs: 46, domainSize: 10^16.2389, dim: 752}

# %%
gum.generateSample(bn,SIZE_LEARN,"out/learn.csv",show_progress=True,with_labels=True)
gum.generateSample(bn,SIZE_VALID,"out/train.csv",show_progress=True,with_labels=True)
# Out:
# out/learn.csv: 100%|███████████████████████████████████████|
# Log2-Likelihood : -151516.20188151585
# out/train.csv: 100%|███████████████████████████████████████|
# Log2-Likelihood : -30379.62983044579
# -30379.62983044579

# %% [markdown]
# # Learning a BN from learn.csv

# %%
# Learning a BN from the database
learner=gum.BNLearner("out/train.csv")

bn2=learner.useMIIC().learnBN()
currentTime=learner.currentTime()

# %%
gnb.flow.add(gnb.getBN(bn2,size="9"),f"Learned with {SIZE_LEARN} lines in {currentTime:.3f}s")
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="648pt" height="551pt" viewBox="0.00 0.00 648.00 550.80">
# <g id="graph0" class="graph" transform="scale(0.658847 0.658847) rotate(0) translate(4 832)">
# <title>G</title>
# <!-- MINVOL -->
# <g id="node1" class="node">
# <title>MINVOL</title>
# <g id="a_node1"><a xlink:title="(14) MINVOL">
# <ellipse fill="#404040" stroke="black" cx="455.49" cy="-522" rx="50.89" ry="18"/>
# <text text-anchor="middle" x="455.49" y="-518.3" font-family="Times,serif" font-size="14.00" fill="white">MINVOL</text>
# </a>
# </g>
# </g>
# <!-- PCWP -->
# <g id="node2" class="node">
# <title>PCWP</title>
# <g id="a_node2"><a xlink:title="(19) PCWP">
# <ellipse fill="#404040" stroke="black" cx="699.49" cy="-378" rx="39.79" ry="18"/>
# <text text-anchor="middle" x="699.49" y="-374.3" font-family="Times,serif" font-size="14.00" fill="white">PCWP</text>
# </a>
# </g>
# </g>
# <!-- LVEDVOLUME -->
# <g id="node4" class="node">
# <title>LVEDVOLUME</title>
# <g id="a_node4"><a xlink:title="(6) LVEDVOLUME">
# <ellipse fill="#404040" stroke="black" cx="715.49" cy="-306" rx="79.09" ry="18"/>
# <text text-anchor="middle" x="715.49" y="-302.3" font-family="Times,serif" font-size="14.00" fill="white">LVEDVOLUME</text>
# </a>
# </g>
# </g>
# <!-- PCWP&#45;&gt;LVEDVOLUME -->
# <g id="edge5" class="edge">
# <title>PCWP-&gt;LVEDVOLUME</title>
# <g id="a_edge5"><a xlink:title="(19, 6) : ">
# <path fill="none" stroke="#4a4a4a" d="M703.37,-360.05C705.15,-352.26 707.31,-342.82 709.3,-334.08"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="712.73,-334.8 711.55,-324.28 705.9,-333.24 712.73,-334.8"/>
# </a>
# </g>
# </g>
# <!-- STROKEVOLUME -->
# <g id="node3" class="node">
# <title>STROKEVOLUME</title>
# <g id="a_node3"><a xlink:title="(3) STROKEVOLUME">
# <ellipse fill="#404040" stroke="black" cx="606.49" cy="-162" rx="93.68" ry="18"/>
# <text text-anchor="middle" x="606.49" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">STROKEVOLUME</text>
# </a>
# </g>
# </g>
# <!-- CO -->
# <g id="node29" class="node">
# <title>CO</title>
# <g id="a_node29"><a xlink:title="(22) CO">
# <ellipse fill="#404040" stroke="black" cx="514.49" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="514.49" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">CO</text>
# </a>
# </g>
# </g>
# <!-- STROKEVOLUME&#45;&gt;CO -->
# <g id="edge11" class="edge">
# <title>STROKEVOLUME-&gt;CO</title>
# <g id="a_edge11"><a xlink:title="(3, 22) : ">
# <path fill="none" stroke="#4a4a4a" d="M584.69,-144.41C571.23,-134.17 553.89,-120.98 539.82,-110.27"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="541.62,-107.24 531.54,-103.97 537.38,-112.81 541.62,-107.24"/>
# </a>
# </g>
# </g>
# <!-- HYPOVOLEMIA -->
# <g id="node23" class="node">
# <title>HYPOVOLEMIA</title>
# <g id="a_node23"><a xlink:title="(21) HYPOVOLEMIA">
# <ellipse fill="#404040" stroke="black" cx="717.49" cy="-234" rx="83.39" ry="18"/>
# <text text-anchor="middle" x="717.49" y="-230.3" font-family="Times,serif" font-size="14.00" fill="white">HYPOVOLEMIA</text>
# </a>
# </g>
# </g>
# <!-- LVEDVOLUME&#45;&gt;HYPOVOLEMIA -->
# <g id="edge1" class="edge">
# <title>LVEDVOLUME-&gt;HYPOVOLEMIA</title>
# <g id="a_edge1"><a xlink:title="(6, 21) : ">
# <path fill="none" stroke="#4a4a4a" d="M715.99,-287.7C716.21,-279.98 716.47,-270.71 716.72,-262.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="720.22,-262.2 717,-252.1 713.22,-262 720.22,-262.2"/>
# </a>
# </g>
# </g>
# <!-- FIO2 -->
# <g id="node5" class="node">
# <title>FIO2</title>
# <g id="a_node5"><a xlink:title="(5) FIO2">
# <ellipse fill="#404040" stroke="black" cx="307.49" cy="-522" rx="33.6" ry="18"/>
# <text text-anchor="middle" x="307.49" y="-518.3" font-family="Times,serif" font-size="14.00" fill="white">FIO2</text>
# </a>
# </g>
# </g>
# <!-- PVSAT -->
# <g id="node6" class="node">
# <title>PVSAT</title>
# <g id="a_node6"><a xlink:title="(16) PVSAT">
# <ellipse fill="#404040" stroke="black" cx="307.49" cy="-450" rx="41.69" ry="18"/>
# <text text-anchor="middle" x="307.49" y="-446.3" font-family="Times,serif" font-size="14.00" fill="white">PVSAT</text>
# </a>
# </g>
# </g>
# <!-- FIO2&#45;&gt;PVSAT -->
# <g id="edge6" class="edge">
# <title>FIO2-&gt;PVSAT</title>
# <g id="a_edge6"><a xlink:title="(5, 16) : ">
# <path fill="none" stroke="#4a4a4a" d="M307.49,-503.7C307.49,-495.98 307.49,-486.71 307.49,-478.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="310.99,-478.1 307.49,-468.1 303.99,-478.1 310.99,-478.1"/>
# </a>
# </g>
# </g>
# <!-- SAO2 -->
# <g id="node14" class="node">
# <title>SAO2</title>
# <g id="a_node14"><a xlink:title="(30) SAO2">
# <ellipse fill="#404040" stroke="black" cx="268.49" cy="-306" rx="36.29" ry="18"/>
# <text text-anchor="middle" x="268.49" y="-302.3" font-family="Times,serif" font-size="14.00" fill="white">SAO2</text>
# </a>
# </g>
# </g>
# <!-- PVSAT&#45;&gt;SAO2 -->
# <g id="edge31" class="edge">
# <title>PVSAT-&gt;SAO2</title>
# <g id="a_edge31"><a xlink:title="(16, 30) : ">
# <path fill="none" stroke="#4a4a4a" d="M302.79,-431.87C296.11,-407.56 283.82,-362.82 275.91,-334.01"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="279.24,-332.91 273.21,-324.19 272.49,-334.76 279.24,-332.91"/>
# </a>
# </g>
# </g>
# <!-- INSUFFANESTH -->
# <g id="node7" class="node">
# <title>INSUFFANESTH</title>
# <g id="a_node7"><a xlink:title="(1) INSUFFANESTH">
# <ellipse fill="#404040" stroke="black" cx="886.49" cy="-810" rx="89.08" ry="18"/>
# <text text-anchor="middle" x="886.49" y="-806.3" font-family="Times,serif" font-size="14.00" fill="white">INSUFFANESTH</text>
# </a>
# </g>
# </g>
# <!-- VENTMACH -->
# <g id="node8" class="node">
# <title>VENTMACH</title>
# <g id="a_node8"><a xlink:title="(4) VENTMACH">
# <ellipse fill="#404040" stroke="black" cx="709.49" cy="-738" rx="67.69" ry="18"/>
# <text text-anchor="middle" x="709.49" y="-734.3" font-family="Times,serif" font-size="14.00" fill="white">VENTMACH</text>
# </a>
# </g>
# </g>
# <!-- VENTTUBE -->
# <g id="node32" class="node">
# <title>VENTTUBE</title>
# <g id="a_node32"><a xlink:title="(31) VENTTUBE">
# <ellipse fill="#404040" stroke="black" cx="790.49" cy="-666" rx="65.79" ry="18"/>
# <text text-anchor="middle" x="790.49" y="-662.3" font-family="Times,serif" font-size="14.00" fill="white">VENTTUBE</text>
# </a>
# </g>
# </g>
# <!-- VENTMACH&#45;&gt;VENTTUBE -->
# <g id="edge38" class="edge">
# <title>VENTMACH-&gt;VENTTUBE</title>
# <g id="a_edge38"><a xlink:title="(4, 31) : ">
# <path fill="none" stroke="#4a4a4a" d="M728.69,-720.41C739.18,-711.34 752.34,-699.97 763.81,-690.06"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="766.16,-692.66 771.44,-683.47 761.58,-687.36 766.16,-692.66"/>
# </a>
# </g>
# </g>
# <!-- LVFAILURE -->
# <g id="node9" class="node">
# <title>LVFAILURE</title>
# <g id="a_node9"><a xlink:title="(0) LVFAILURE">
# <ellipse fill="#404040" stroke="black" cx="578.49" cy="-378" rx="63.89" ry="18"/>
# <text text-anchor="middle" x="578.49" y="-374.3" font-family="Times,serif" font-size="14.00" fill="white">LVFAILURE</text>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;STROKEVOLUME -->
# <g id="edge36" class="edge">
# <title>LVFAILURE-&gt;STROKEVOLUME</title>
# <g id="a_edge36"><a xlink:title="(0, 3) : ">
# <path fill="none" stroke="#4a4a4a" d="M581.63,-359.85C583.47,-349.49 585.77,-336.01 587.49,-324 594.23,-277.2 600.3,-222.48 603.69,-190.4"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="607.17,-190.74 604.73,-180.43 600.21,-190.01 607.17,-190.74"/>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;LVEDVOLUME -->
# <g id="edge39" class="edge">
# <title>LVFAILURE-&gt;LVEDVOLUME</title>
# <g id="a_edge39"><a xlink:title="(0, 6) : ">
# <path fill="none" stroke="#4a4a4a" d="M607.88,-361.98C627.7,-351.86 654.07,-338.38 675.76,-327.3"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="677.41,-330.39 684.73,-322.72 674.23,-324.15 677.41,-330.39"/>
# </a>
# </g>
# </g>
# <!-- ARTCO2 -->
# <g id="node10" class="node">
# <title>ARTCO2</title>
# <g id="a_node10"><a xlink:title="(35) ARTCO2">
# <ellipse fill="#404040" stro

# %%
import pyAgrum.lib.bn_vs_bn as bnvsbn
gnb.flow.add(gnb.getBNDiff(bn,bn2,size="8!"),"Diff with MIIC")
gnb.flow.add(bnvsbn.graphDiffLegend())
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="576pt" height="319pt" viewBox="0.00 0.00 576.00 319.35">
# <g id="graph0" class="graph" transform="scale(0.417997 0.417997) rotate(0) translate(4 760)">
# <title>G</title>
# <!-- KINKEDTUBE -->
# <g id="node1" class="node">
# <title>KINKEDTUBE</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="311.54" cy="-594" rx="77.19" ry="18"/>
# <text text-anchor="middle" x="311.54" y="-590.3" font-family="Times,serif" font-size="14.00">KINKEDTUBE</text>
# </g>
# <!-- VENTLUNG -->
# <g id="node23" class="node">
# <title>VENTLUNG</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="347.54" cy="-522" rx="65.79" ry="18"/>
# <text text-anchor="middle" x="347.54" y="-518.3" font-family="Times,serif" font-size="14.00">VENTLUNG</text>
# </g>
# <!-- KINKEDTUBE&#45;&gt;VENTLUNG -->
# <g id="edge38" class="edge">
# <title>KINKEDTUBE-&gt;VENTLUNG</title>
# <path fill="none" stroke="grey" d="M320.63,-575.83C324.71,-567.67 329.61,-557.87 334.1,-548.88"/>
# <polygon fill="grey" stroke="grey" points="337.25,-550.42 338.59,-539.91 330.98,-547.29 337.25,-550.42"/>
# </g>
# <!-- PRESS -->
# <g id="node25" class="node">
# <title>PRESS</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="220.54" cy="-522" rx="42.79" ry="18"/>
# <text text-anchor="middle" x="220.54" y="-518.3" font-family="Times,serif" font-size="14.00">PRESS</text>
# </g>
# <!-- KINKEDTUBE&#45;&gt;PRESS -->
# <g id="edge51" class="edge">
# <title>KINKEDTUBE-&gt;PRESS</title>
# <path fill="none" stroke="red" stroke-dasharray="5,2" d="M289.52,-576.57C277.23,-566.85 261.8,-554.65 248.66,-544.24"/>
# <polygon fill="red" stroke="red" points="250.83,-541.5 240.81,-538.04 246.48,-546.99 250.83,-541.5"/>
# </g>
# <!-- HYPOVOLEMIA -->
# <g id="node2" class="node">
# <title>HYPOVOLEMIA</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="987.55" cy="-234" rx="83.39" ry="18"/>
# <text text-anchor="middle" x="987.55" y="-230.3" font-family="Times,serif" font-size="14.00">HYPOVOLEMIA</text>
# </g>
# <!-- STROKEVOLUME -->
# <g id="node14" class="node">
# <title>STROKEVOLUME</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="974.52" cy="-162" rx="93.68" ry="18"/>
# <text text-anchor="middle" x="974.52" y="-158.3" font-family="Times,serif" font-size="14.00">STROKEVOLUME</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;STROKEVOLUME -->
# <g id="edge49" class="edge">
# <title>HYPOVOLEMIA-&gt;STROKEVOLUME</title>
# <path fill="none" stroke="grey" d="M984.26,-215.83C982.87,-208.13 981.21,-198.97 979.66,-190.42"/>
# <polygon fill="grey" stroke="grey" points="983.08,-189.63 977.85,-180.41 976.19,-190.88 983.08,-189.63"/>
# </g>
# <!-- LVEDVOLUME -->
# <g id="node16" class="node">
# <title>LVEDVOLUME</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="1165.54" cy="-162" rx="79.09" ry="18"/>
# <text text-anchor="middle" x="1165.54" y="-158.3" font-family="Times,serif" font-size="14.00">LVEDVOLUME</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;LVEDVOLUME -->
# <!-- INTUBATION -->
# <g id="node3" class="node">
# <title>INTUBATION</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="479.54" cy="-594" rx="72.59" ry="18"/>
# <text text-anchor="middle" x="479.54" y="-590.3" font-family="Times,serif" font-size="14.00">INTUBATION</text>
# </g>
# <!-- SHUNT -->
# <g id="node19" class="node">
# <title>SHUNT</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="620.55" cy="-522" rx="46.29" ry="18"/>
# <text text-anchor="middle" x="620.55" y="-518.3" font-family="Times,serif" font-size="14.00">SHUNT</text>
# </g>
# <!-- INTUBATION&#45;&gt;SHUNT -->
# <g id="edge50" class="edge">
# <title>INTUBATION-&gt;SHUNT</title>
# <path fill="none" stroke="grey" d="M511.54,-577.66C532.87,-566.77 560.98,-552.42 583.31,-541.01"/>
# <polygon fill="grey" stroke="grey" points="585.18,-543.99 592.49,-536.32 582,-537.75 585.18,-543.99"/>
# </g>
# <!-- INTUBATION&#45;&gt;VENTLUNG -->
# <g id="edge40" class="edge">
# <title>INTUBATION-&gt;VENTLUNG</title>
# <path fill="none" stroke="red" stroke-dasharray="5,2" d="M449.26,-577.48C430.51,-567.26 406.27,-554.03 386.15,-543.06"/>
# <polygon fill="red" stroke="red" points="387.69,-539.91 377.23,-538.19 384.33,-546.05 387.69,-539.91"/>
# </g>
# <!-- MINVOL -->
# <g id="node24" class="node">
# <title>MINVOL</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="351.55" cy="-450" rx="50.89" ry="18"/>
# <text text-anchor="middle" x="351.55" y="-446.3" font-family="Times,serif" font-size="14.00">MINVOL</text>
# </g>
# <!-- INTUBATION&#45;&gt;MINVOL -->
# <g id="edge22" class="edge">
# <title>INTUBATION-&gt;MINVOL</title>
# <path fill="none" stroke="red" stroke-dasharray="5,2" d="M463.85,-576.34C441.27,-550.94 399.52,-503.97 373.78,-475.01"/>
# <polygon fill="red" stroke="red" points="376.23,-472.5 366.97,-467.35 371,-477.15 376.23,-472.5"/>
# </g>
# <!-- INTUBATION&#45;&gt;PRESS -->
# <g id="edge53" class="edge">
# <title>INTUBATION-&gt;PRESS</title>
# <path fill="none" stroke="grey" d="M431.13,-580.54C383.93,-567.42 312.69,-547.62 266.39,-534.75"/>
# <polygon fill="grey" stroke="grey" points="267.19,-531.34 256.62,-532.03 265.32,-538.08 267.19,-531.34"/>
# </g>
# <!-- VENTALV -->
# <g id="node26" class="node">
# <title>VENTALV</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="474.54" cy="-450" rx="54.69" ry="18"/>
# <text text-anchor="middle" x="474.54" y="-446.3" font-family="Times,serif" font-size="14.00">VENTALV</text>
# </g>
# <!-- INTUBATION&#45;&gt;VENTALV -->
# <!-- MINVOLSET -->
# <g id="node4" class="node">
# <title>MINVOLSET</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="69.54" cy="-738" rx="69.59" ry="18"/>
# <text text-anchor="middle" x="69.54" y="-734.3" font-family="Times,serif" font-size="14.00">MINVOLSET</text>
# </g>
# <!-- VENTMACH -->
# <g id="node17" class="node">
# <title>VENTMACH</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="69.54" cy="-666" rx="67.69" ry="18"/>
# <text text-anchor="middle" x="69.54" y="-662.3" font-family="Times,serif" font-size="14.00">VENTMACH</text>
# </g>
# <!-- MINVOLSET&#45;&gt;VENTMACH -->
# <g id="edge7" class="edge">
# <title>MINVOLSET-&gt;VENTMACH</title>
# <path fill="none" stroke="grey" d="M69.54,-719.83C69.54,-712.13 69.54,-702.97 69.54,-694.42"/>
# <polygon fill="grey" stroke="grey" points="73.04,-694.41 69.54,-684.41 66.04,-694.41 73.04,-694.41"/>
# </g>
# <!-- PULMEMBOLUS -->
# <g id="node5" class="node">
# <title>PULMEMBOLUS</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="695.54" cy="-594" rx="89.08" ry="18"/>
# <text text-anchor="middle" x="695.54" y="-590.3" font-family="Times,serif" font-size="14.00">PULMEMBOLUS</text>
# </g>
# <!-- PAP -->
# <g id="node13" class="node">
# <title>PAP</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="713.54" cy="-522" rx="28.7" ry="18"/>
# <text text-anchor="middle" x="713.54" y="-518.3" font-family="Times,serif" font-size="14.00">PAP</text>
# </g>
# <!-- PULMEMBOLUS&#45;&gt;PAP -->
# <g id="edge5" class="edge">
# <title>PULMEMBOLUS-&gt;PAP</title>
# <path fill="none" stroke="grey" d="M700.08,-575.83C702.06,-567.93 704.42,-558.49 706.61,-549.74"/>
# <polygon fill="grey" stroke="grey" points="710.03,-550.46 709.06,-539.91 703.24,-548.77 710.03,-550.46"/>
# </g>
# <!-- PULMEMBOLUS&#45;&gt;SHUNT -->
# <!-- INSUFFANESTH -->
# <g id="node6" class="node">
# <title>INSUFFANESTH</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="715.54" cy="-306" rx="89.08" ry="18"/>
# <text text-anchor="middle" x="715.54" y="-302.3" font-family="Times,serif" font-size="14.00">INSUFFANESTH</text>
# </g>
# <!-- CATECHOL -->
# <g id="node31" class="node">
# <title>CATECHOL</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="591.54" cy="-234" rx="63.89" ry="18"/>
# <text text-anchor="middle" x="591.54" y="-230.3" font-family="Times,serif" font-size="14.00">CATECHOL</text>
# </g>
# <!-- INSUFFANESTH&#45;&gt;CATECHOL -->
# <g id="edge36" class="edge">
# <title>INSUFFANESTH-&gt;CATECHOL</title>
# <path fill="none" stroke="red" stroke-dasharray="5,2" d="M686.16,-288.94C668.8,-278.86 646.68,-266.01 628.19,-255.28"/>
# <polygon fill="red" stroke="red"

# %%
bn3=learner.useGreedyHillClimbing().useNMLCorrection().useScoreBDeu().learnBN()
gnb.flow.add(gnb.getBNDiff(bn,bn3,size="8!"),"Diff with GHC/NMD/BDEU")
gnb.flow.add(bnvsbn.graphDiffLegend())
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="576pt" height="319pt" viewBox="0.00 0.00 576.00 319.35">
# <g id="graph0" class="graph" transform="scale(0.417997 0.417997) rotate(0) translate(4 760)">
# <title>G</title>
# <!-- KINKEDTUBE -->
# <g id="node1" class="node">
# <title>KINKEDTUBE</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="311.54" cy="-594" rx="77.19" ry="18"/>
# <text text-anchor="middle" x="311.54" y="-590.3" font-family="Times,serif" font-size="14.00">KINKEDTUBE</text>
# </g>
# <!-- VENTLUNG -->
# <g id="node23" class="node">
# <title>VENTLUNG</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="347.54" cy="-522" rx="65.79" ry="18"/>
# <text text-anchor="middle" x="347.54" y="-518.3" font-family="Times,serif" font-size="14.00">VENTLUNG</text>
# </g>
# <!-- KINKEDTUBE&#45;&gt;VENTLUNG -->
# <!-- PRESS -->
# <g id="node25" class="node">
# <title>PRESS</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="220.54" cy="-522" rx="42.79" ry="18"/>
# <text text-anchor="middle" x="220.54" y="-518.3" font-family="Times,serif" font-size="14.00">PRESS</text>
# </g>
# <!-- KINKEDTUBE&#45;&gt;PRESS -->
# <g id="edge61" class="edge">
# <title>KINKEDTUBE-&gt;PRESS</title>
# <path fill="none" stroke="grey" d="M289.52,-576.57C277.23,-566.85 261.8,-554.65 248.66,-544.24"/>
# <polygon fill="grey" stroke="grey" points="250.83,-541.5 240.81,-538.04 246.48,-546.99 250.83,-541.5"/>
# </g>
# <!-- HYPOVOLEMIA -->
# <g id="node2" class="node">
# <title>HYPOVOLEMIA</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="987.55" cy="-234" rx="83.39" ry="18"/>
# <text text-anchor="middle" x="987.55" y="-230.3" font-family="Times,serif" font-size="14.00">HYPOVOLEMIA</text>
# </g>
# <!-- STROKEVOLUME -->
# <g id="node14" class="node">
# <title>STROKEVOLUME</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="974.52" cy="-162" rx="93.68" ry="18"/>
# <text text-anchor="middle" x="974.52" y="-158.3" font-family="Times,serif" font-size="14.00">STROKEVOLUME</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;STROKEVOLUME -->
# <g id="edge59" class="edge">
# <title>HYPOVOLEMIA-&gt;STROKEVOLUME</title>
# <path fill="none" stroke="grey" d="M984.26,-215.83C982.87,-208.13 981.21,-198.97 979.66,-190.42"/>
# <polygon fill="grey" stroke="grey" points="983.08,-189.63 977.85,-180.41 976.19,-190.88 983.08,-189.63"/>
# </g>
# <!-- LVEDVOLUME -->
# <g id="node16" class="node">
# <title>LVEDVOLUME</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="1165.54" cy="-162" rx="79.09" ry="18"/>
# <text text-anchor="middle" x="1165.54" y="-158.3" font-family="Times,serif" font-size="14.00">LVEDVOLUME</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;LVEDVOLUME -->
# <g id="edge23" class="edge">
# <title>HYPOVOLEMIA-&gt;LVEDVOLUME</title>
# <path fill="none" stroke="grey" d="M1027.05,-218.02C1053.64,-207.26 1088.88,-193.01 1117.15,-181.57"/>
# <polygon fill="grey" stroke="grey" points="1118.49,-184.81 1126.45,-177.81 1115.87,-178.32 1118.49,-184.81"/>
# </g>
# <!-- INTUBATION -->
# <g id="node3" class="node">
# <title>INTUBATION</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="479.54" cy="-594" rx="72.59" ry="18"/>
# <text text-anchor="middle" x="479.54" y="-590.3" font-family="Times,serif" font-size="14.00">INTUBATION</text>
# </g>
# <!-- SHUNT -->
# <g id="node19" class="node">
# <title>SHUNT</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="620.55" cy="-522" rx="46.29" ry="18"/>
# <text text-anchor="middle" x="620.55" y="-518.3" font-family="Times,serif" font-size="14.00">SHUNT</text>
# </g>
# <!-- INTUBATION&#45;&gt;SHUNT -->
# <g id="edge60" class="edge">
# <title>INTUBATION-&gt;SHUNT</title>
# <path fill="none" stroke="grey" d="M511.54,-577.66C532.87,-566.77 560.98,-552.42 583.31,-541.01"/>
# <polygon fill="grey" stroke="grey" points="585.18,-543.99 592.49,-536.32 582,-537.75 585.18,-543.99"/>
# </g>
# <!-- INTUBATION&#45;&gt;VENTLUNG -->
# <!-- MINVOL -->
# <g id="node24" class="node">
# <title>MINVOL</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="351.55" cy="-450" rx="50.89" ry="18"/>
# <text text-anchor="middle" x="351.55" y="-446.3" font-family="Times,serif" font-size="14.00">MINVOL</text>
# </g>
# <!-- INTUBATION&#45;&gt;MINVOL -->
# <g id="edge24" class="edge">
# <title>INTUBATION-&gt;MINVOL</title>
# <path fill="none" stroke="grey" d="M463.85,-576.34C441.27,-550.94 399.52,-503.97 373.78,-475.01"/>
# <polygon fill="grey" stroke="grey" points="376.23,-472.5 366.97,-467.35 371,-477.15 376.23,-472.5"/>
# </g>
# <!-- INTUBATION&#45;&gt;PRESS -->
# <g id="edge64" class="edge">
# <title>INTUBATION-&gt;PRESS</title>
# <path fill="none" stroke="grey" d="M431.13,-580.54C383.93,-567.42 312.69,-547.62 266.39,-534.75"/>
# <polygon fill="grey" stroke="grey" points="267.19,-531.34 256.62,-532.03 265.32,-538.08 267.19,-531.34"/>
# </g>
# <!-- VENTALV -->
# <g id="node26" class="node">
# <title>VENTALV</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="474.54" cy="-450" rx="54.69" ry="18"/>
# <text text-anchor="middle" x="474.54" y="-446.3" font-family="Times,serif" font-size="14.00">VENTALV</text>
# </g>
# <!-- INTUBATION&#45;&gt;VENTALV -->
# <!-- MINVOLSET -->
# <g id="node4" class="node">
# <title>MINVOLSET</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="69.54" cy="-738" rx="69.59" ry="18"/>
# <text text-anchor="middle" x="69.54" y="-734.3" font-family="Times,serif" font-size="14.00">MINVOLSET</text>
# </g>
# <!-- VENTMACH -->
# <g id="node17" class="node">
# <title>VENTMACH</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="69.54" cy="-666" rx="67.69" ry="18"/>
# <text text-anchor="middle" x="69.54" y="-662.3" font-family="Times,serif" font-size="14.00">VENTMACH</text>
# </g>
# <!-- MINVOLSET&#45;&gt;VENTMACH -->
# <!-- PULMEMBOLUS -->
# <g id="node5" class="node">
# <title>PULMEMBOLUS</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="695.54" cy="-594" rx="89.08" ry="18"/>
# <text text-anchor="middle" x="695.54" y="-590.3" font-family="Times,serif" font-size="14.00">PULMEMBOLUS</text>
# </g>
# <!-- DISCONNECT -->
# <g id="node11" class="node">
# <title>DISCONNECT</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="232.55" cy="-666" rx="77.19" ry="18"/>
# <text text-anchor="middle" x="232.55" y="-662.3" font-family="Times,serif" font-size="14.00">DISCONNECT</text>
# </g>
# <!-- PULMEMBOLUS&#45;&gt;DISCONNECT -->
# <g id="edge73" class="edge">
# <title>PULMEMBOLUS-&gt;DISCONNECT</title>
# <path fill="none" stroke="purple" stroke-dasharray="5,2" d="M624.72,-605.01C538.82,-618.37 394.7,-640.78 307.14,-654.4"/>
# <polygon fill="purple" stroke="purple" points="306.36,-650.98 297.01,-655.97 307.43,-657.9 306.36,-650.98"/>
# </g>
# <!-- PAP -->
# <g id="node13" class="node">
# <title>PAP</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="713.54" cy="-522" rx="28.7" ry="18"/>
# <text text-anchor="middle" x="713.54" y="-518.3" font-family="Times,serif" font-size="14.00">PAP</text>
# </g>
# <!-- PULMEMBOLUS&#45;&gt;PAP -->
# <g id="edge5" class="edge">
# <title>PULMEMBOLUS-&gt;PAP</title>
# <path fill="none" stroke="grey" d="M700.08,-575.83C702.06,-567.93 704.42,-558.49 706.61,-549.74"/>
# <polygon fill="grey" stroke="grey" points="710.03,-550.46 709.06,-539.91 703.24,-548.77 710.03,-550.46"/>
# </g>
# <!-- PULMEMBOLUS&#45;&gt;SHUNT -->
# <g id="edge14" class="edge">
# <title>PULMEMBOLUS-&gt;SHUNT</title>
# <path fill="none" stroke="grey" d="M677,-576.2C667.53,-567.11 655.87,-555.91 645.61,-546.06"/>
# <polygon fill="grey" stroke="grey" points="647.74,-543.25 638.1,-538.85 642.89,-548.3 647.74,-543.25"/>
# </g>
# <!-- INSUFFANESTH -->
# <g id="node6" class="node">
# <title>INSUFFANESTH</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="715.54" cy="-306" rx="89.08" ry="18"/>
# <text text-anchor="middle" x="715.54" y="-302.3" font-family="Times,serif" font-size="14.00">INSUFFANESTH</text>
# </g>
# <!-- CATECHOL -->
# <g id="node31" class="node">
# <title>CATECHOL</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="591.54" cy="-234" rx="63.89" ry="18"/>
# <text text-anchor="middle" x="591.54" y="-230.3" font-family="Times,serif" font-s

# %%
bn4=learner.useGreedyHillClimbing().useNMLCorrection().useScoreBDeu().setInitialDAG(bn2.dag()).learnBN()
gnb.flow.add(gnb.getBNDiff(bn,bn4,size="8!"),"Diff with GHC/NMD/BDEU with intial DAG from MIIC")
gnb.flow.add(bnvsbn.graphDiffLegend())
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="576pt" height="319pt" viewBox="0.00 0.00 576.00 319.35">
# <g id="graph0" class="graph" transform="scale(0.417997 0.417997) rotate(0) translate(4 760)">
# <title>G</title>
# <!-- KINKEDTUBE -->
# <g id="node1" class="node">
# <title>KINKEDTUBE</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="311.54" cy="-594" rx="77.19" ry="18"/>
# <text text-anchor="middle" x="311.54" y="-590.3" font-family="Times,serif" font-size="14.00">KINKEDTUBE</text>
# </g>
# <!-- VENTLUNG -->
# <g id="node23" class="node">
# <title>VENTLUNG</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="347.54" cy="-522" rx="65.79" ry="18"/>
# <text text-anchor="middle" x="347.54" y="-518.3" font-family="Times,serif" font-size="14.00">VENTLUNG</text>
# </g>
# <!-- KINKEDTUBE&#45;&gt;VENTLUNG -->
# <g id="edge36" class="edge">
# <title>KINKEDTUBE-&gt;VENTLUNG</title>
# <path fill="none" stroke="grey" d="M320.63,-575.83C324.71,-567.67 329.61,-557.87 334.1,-548.88"/>
# <polygon fill="grey" stroke="grey" points="337.25,-550.42 338.59,-539.91 330.98,-547.29 337.25,-550.42"/>
# </g>
# <!-- PRESS -->
# <g id="node25" class="node">
# <title>PRESS</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="220.54" cy="-522" rx="42.79" ry="18"/>
# <text text-anchor="middle" x="220.54" y="-518.3" font-family="Times,serif" font-size="14.00">PRESS</text>
# </g>
# <!-- KINKEDTUBE&#45;&gt;PRESS -->
# <g id="edge48" class="edge">
# <title>KINKEDTUBE-&gt;PRESS</title>
# <path fill="none" stroke="grey" d="M289.52,-576.57C277.23,-566.85 261.8,-554.65 248.66,-544.24"/>
# <polygon fill="grey" stroke="grey" points="250.83,-541.5 240.81,-538.04 246.48,-546.99 250.83,-541.5"/>
# </g>
# <!-- HYPOVOLEMIA -->
# <g id="node2" class="node">
# <title>HYPOVOLEMIA</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="987.55" cy="-234" rx="83.39" ry="18"/>
# <text text-anchor="middle" x="987.55" y="-230.3" font-family="Times,serif" font-size="14.00">HYPOVOLEMIA</text>
# </g>
# <!-- STROKEVOLUME -->
# <g id="node14" class="node">
# <title>STROKEVOLUME</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="974.52" cy="-162" rx="93.68" ry="18"/>
# <text text-anchor="middle" x="974.52" y="-158.3" font-family="Times,serif" font-size="14.00">STROKEVOLUME</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;STROKEVOLUME -->
# <g id="edge46" class="edge">
# <title>HYPOVOLEMIA-&gt;STROKEVOLUME</title>
# <path fill="none" stroke="grey" d="M984.26,-215.83C982.87,-208.13 981.21,-198.97 979.66,-190.42"/>
# <polygon fill="grey" stroke="grey" points="983.08,-189.63 977.85,-180.41 976.19,-190.88 983.08,-189.63"/>
# </g>
# <!-- LVEDVOLUME -->
# <g id="node16" class="node">
# <title>LVEDVOLUME</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="1165.54" cy="-162" rx="79.09" ry="18"/>
# <text text-anchor="middle" x="1165.54" y="-158.3" font-family="Times,serif" font-size="14.00">LVEDVOLUME</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;LVEDVOLUME -->
# <!-- INTUBATION -->
# <g id="node3" class="node">
# <title>INTUBATION</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="479.54" cy="-594" rx="72.59" ry="18"/>
# <text text-anchor="middle" x="479.54" y="-590.3" font-family="Times,serif" font-size="14.00">INTUBATION</text>
# </g>
# <!-- SHUNT -->
# <g id="node19" class="node">
# <title>SHUNT</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="620.55" cy="-522" rx="46.29" ry="18"/>
# <text text-anchor="middle" x="620.55" y="-518.3" font-family="Times,serif" font-size="14.00">SHUNT</text>
# </g>
# <!-- INTUBATION&#45;&gt;SHUNT -->
# <g id="edge47" class="edge">
# <title>INTUBATION-&gt;SHUNT</title>
# <path fill="none" stroke="grey" d="M511.54,-577.66C532.87,-566.77 560.98,-552.42 583.31,-541.01"/>
# <polygon fill="grey" stroke="grey" points="585.18,-543.99 592.49,-536.32 582,-537.75 585.18,-543.99"/>
# </g>
# <!-- INTUBATION&#45;&gt;VENTLUNG -->
# <g id="edge38" class="edge">
# <title>INTUBATION-&gt;VENTLUNG</title>
# <path fill="none" stroke="grey" d="M449.26,-577.48C430.51,-567.26 406.27,-554.03 386.15,-543.06"/>
# <polygon fill="grey" stroke="grey" points="387.69,-539.91 377.23,-538.19 384.33,-546.05 387.69,-539.91"/>
# </g>
# <!-- MINVOL -->
# <g id="node24" class="node">
# <title>MINVOL</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="351.55" cy="-450" rx="50.89" ry="18"/>
# <text text-anchor="middle" x="351.55" y="-446.3" font-family="Times,serif" font-size="14.00">MINVOL</text>
# </g>
# <!-- INTUBATION&#45;&gt;MINVOL -->
# <g id="edge21" class="edge">
# <title>INTUBATION-&gt;MINVOL</title>
# <path fill="none" stroke="grey" d="M463.85,-576.34C441.27,-550.94 399.52,-503.97 373.78,-475.01"/>
# <polygon fill="grey" stroke="grey" points="376.23,-472.5 366.97,-467.35 371,-477.15 376.23,-472.5"/>
# </g>
# <!-- INTUBATION&#45;&gt;PRESS -->
# <g id="edge50" class="edge">
# <title>INTUBATION-&gt;PRESS</title>
# <path fill="none" stroke="grey" d="M431.13,-580.54C383.93,-567.42 312.69,-547.62 266.39,-534.75"/>
# <polygon fill="grey" stroke="grey" points="267.19,-531.34 256.62,-532.03 265.32,-538.08 267.19,-531.34"/>
# </g>
# <!-- VENTALV -->
# <g id="node26" class="node">
# <title>VENTALV</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="474.54" cy="-450" rx="54.69" ry="18"/>
# <text text-anchor="middle" x="474.54" y="-446.3" font-family="Times,serif" font-size="14.00">VENTALV</text>
# </g>
# <!-- INTUBATION&#45;&gt;VENTALV -->
# <g id="edge39" class="edge">
# <title>INTUBATION-&gt;VENTALV</title>
# <path fill="none" stroke="grey" d="M478.91,-575.76C478.06,-551.2 476.53,-507.25 475.53,-478.35"/>
# <polygon fill="grey" stroke="grey" points="479.02,-477.96 475.17,-468.09 472.02,-478.21 479.02,-477.96"/>
# </g>
# <!-- MINVOLSET -->
# <g id="node4" class="node">
# <title>MINVOLSET</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="69.54" cy="-738" rx="69.59" ry="18"/>
# <text text-anchor="middle" x="69.54" y="-734.3" font-family="Times,serif" font-size="14.00">MINVOLSET</text>
# </g>
# <!-- VENTMACH -->
# <g id="node17" class="node">
# <title>VENTMACH</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="69.54" cy="-666" rx="67.69" ry="18"/>
# <text text-anchor="middle" x="69.54" y="-662.3" font-family="Times,serif" font-size="14.00">VENTMACH</text>
# </g>
# <!-- MINVOLSET&#45;&gt;VENTMACH -->
# <!-- PULMEMBOLUS -->
# <g id="node5" class="node">
# <title>PULMEMBOLUS</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="695.54" cy="-594" rx="89.08" ry="18"/>
# <text text-anchor="middle" x="695.54" y="-590.3" font-family="Times,serif" font-size="14.00">PULMEMBOLUS</text>
# </g>
# <!-- PAP -->
# <g id="node13" class="node">
# <title>PAP</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="713.54" cy="-522" rx="28.7" ry="18"/>
# <text text-anchor="middle" x="713.54" y="-518.3" font-family="Times,serif" font-size="14.00">PAP</text>
# </g>
# <!-- PULMEMBOLUS&#45;&gt;PAP -->
# <g id="edge4" class="edge">
# <title>PULMEMBOLUS-&gt;PAP</title>
# <path fill="none" stroke="grey" d="M700.08,-575.83C702.06,-567.93 704.42,-558.49 706.61,-549.74"/>
# <polygon fill="grey" stroke="grey" points="710.03,-550.46 709.06,-539.91 703.24,-548.77 710.03,-550.46"/>
# </g>
# <!-- PULMEMBOLUS&#45;&gt;SHUNT -->
# <g id="edge11" class="edge">
# <title>PULMEMBOLUS-&gt;SHUNT</title>
# <path fill="none" stroke="grey" d="M677,-576.2C667.53,-567.11 655.87,-555.91 645.61,-546.06"/>
# <polygon fill="grey" stroke="grey" points="647.74,-543.25 638.1,-538.85 642.89,-548.3 647.74,-543.25"/>
# </g>
# <!-- INSUFFANESTH -->
# <g id="node6" class="node">
# <title>INSUFFANESTH</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="715.54" cy="-306" rx="89.08" ry="18"/>
# <text text-anchor="middle" x="715.54" y="-302.3" font-family="Times,serif" font-size="14.00">INSUFFANESTH</text>
# </g>
# <!-- CATECHOL -->
# <g id="node31" class="node">
# <title>CATECHOL</title>
# <ellipse fill="grey" stroke="#4a4a4a" cx="591.54" cy="-234" rx="63.89" ry="18"/>
# <text text-anchor="middle" x="591.54" y="-230.3" font-family="Times,serif" font-size="14.00">CATECHOL</text>
# </g>
# <!-- INSUFFANESTH&#45;&gt;CATECHOL -->
# <g id

# %%
print(bn2.names())
# Out:
# {'MINVOL', 'PCWP', 'STROKEVOLUME', 'LVEDVOLUME', 'FIO2', 'PVSAT', 'INSUFFANESTH', 'VENTMACH', 'LVFAILURE', 'ARTCO2', 'BP', 'KINKEDTUBE', 'HRSAT', 'SAO2', 'HISTORY', 'ERRLOWOUTPUT', 'ERRCAUTER', 'PRESS', 'EXPCO2', 'HRBP', 'MINVOLSET', 'DISCONNECT', 'HYPOVOLEMIA', 'SHUNT', 'VENTALV', 'PAP', 'VENTLUNG', 'ANAPHYLAXIS', 'CO', 'CATECHOL', 'HREKG', 'VENTTUBE', 'HR', 'INTUBATION', 'PULMEMBOLUS', 'CVP', 'TPR'}

# %%
gnb.showInference(bn2,evs={},size="14")

# %% [markdown]
# # Two classifiers from the learned BN

# %%
print(bn2.variableFromName("HRSAT"))
print(bn2.variableFromName("INTUBATION"))
# Out:
# HRSAT:Labelized(<HIGH,LOW,NORMAL>)
# INTUBATION:Labelized(<ESOPHAGEAL,NORMAL,ONESIDED>)

# %%
showROC(bn2,"out/train.csv",'HRSAT','LOW',show_progress=False)
showROC(bn2,"out/train.csv",'HRSAT','NORMAL',show_progress=False)
showROC(bn2,"out/train.csv",'HRSAT','HIGH',show_progress=False);

# %%
showROC(bn2,"out/train.csv",'INTUBATION',"ESOPHAGEAL",show_progress=False);

# %%
showPR(bn2,"out/train.csv",'HRSAT','LOW',show_progress=False);

# %%
showPR(bn2,"out/train.csv",'INTUBATION',"ESOPHAGEAL",show_progress=False);

# %%
showROC_PR(bn2,"out/train.csv",'HRSAT','LOW',show_progress=False);

# %%
showROC_PR(bn2,"out/train.csv",'INTUBATION',"ESOPHAGEAL",show_progress=False);
