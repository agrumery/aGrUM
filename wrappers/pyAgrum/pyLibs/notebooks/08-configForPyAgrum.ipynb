# %% [markdown]
# # `gum.config` is the configuration object for pyAgrum

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
print("="*35)
print(gum.config)
print("="*35)
# Out:
# ===================================
# [notebook]
#   potential_visible_digits = 4
#   potential_parent_values = merge
#   graph_format = svg
#   default_graph_size = 5
#   default_arc_color = #AAAAAA
#   default_node_cmap = summer
#   default_arc_cmap = BuGn
#   default_node_bgcolor = #404040
#   default_node_fgcolor = white
#   evidence_bgcolor = green
#   evidence_fgcolor = black
# [dynamicBN]
#   default_graph_size = 6
# [influenceDiagram]
#   default_graph_size = 6
#   default_chance_bgcolor = #504A50
#   default_chance_fgcolor = white
#   default_chance_shape = ellipse
#   default_utility_bgcolor = #4A5050
#   default_utility_fgcolor = white
#   default_utility_shape = diamond
#   default_decision_bgcolor = #50504A
#   default_decision_fgcolor = white
#   default_decision_shape = box
# [causal]
#   show_latent_names = False
#   latex_do_prefix = \hookrightarrow\mkern-6.5mu
#   latex_do_suffix =
#   default_graph_size = 2.5
#   default_node_bgcolor = #404040
#   default_node_fgcolor = white
#   default_latent_bgcolor = #A08080
#   default_latent_fgcolor = black
# ===================================

# %% [markdown]
# ### As far as it can be done with Python, `gum.config` is a singleton

# %%
cfg2=gum.PyAgrumConfiguration("")
print(id(cfg2))
print(id(gum.config))
# Out:
# 140250480927824
# 140250480927824

# %% [markdown]
# ### The configuration is a mix between the defaults (which exactly define the possible `section` and `property`) and a file `pyagrum.ini` (if present in the current folder) that contains only the changed properties.
#
# `section` and `key` are case insensitive.

# %%
# !cat pyagrum.ini
# Out:
# [notebook]
#   default_arc_color = #AAAAAA
#   evidence_bgcolor = green

# %% [markdown]
# ### `config` constantly keeps track of the differences between defaults and actual values :

# %%
gum.config.diff()
# Out:
# [notebook]
#   default_arc_color = #AAAAAA
#   evidence_bgcolor = green

# %%
gum.config
# Out:
# [notebook]
#   default_arc_color = #AAAAAA
#   evidence_bgcolor = green

# %% [markdown]
# ## Accessors
#
# ### Getter

# %%
print(gum.config) # __str__ shows all the properties (__repr__ shows only the diff)
# Out:
# [notebook]
#   potential_visible_digits = 4
#   potential_parent_values = merge
#   graph_format = svg
#   default_graph_size = 5
#   default_arc_color = #AAAAAA
#   default_node_cmap = summer
#   default_arc_cmap = BuGn
#   default_node_bgcolor = #404040
#   default_node_fgcolor = white
#   evidence_bgcolor = green
#   evidence_fgcolor = black
# [dynamicBN]
#   default_graph_size = 6
# [influenceDiagram]
#   default_graph_size = 6
#   default_chance_bgcolor = #504A50
#   default_chance_fgcolor = white
#   default_chance_shape = ellipse
#   default_utility_bgcolor = #4A5050
#   default_utility_fgcolor = white
#   default_utility_shape = diamond
#   default_decision_bgcolor = #50504A
#   default_decision_fgcolor = white
#   default_decision_shape = box
# [causal]
#   show_latent_names = False
#   latex_do_prefix = \hookrightarrow\mkern-6.5mu
#   latex_do_suffix =
#   default_graph_size = 2.5
#   default_node_bgcolor = #404040
#   default_node_fgcolor = white
#   default_latent_bgcolor = #A08080
#   default_latent_fgcolor = black

# %%
gum.config["notebook","evidence_bgcolor"]
# Out:
# 'green'

# %% [markdown]
# ### Setter

# %%
gum.config["notebook","evidence_bgcolor"]="papayawhip"
gum.config["causal","default_graph_size"]=1.9

# %%
gum.config # once again, only the diff with defaults
# Out:
# [notebook]
#   default_arc_color = #AAAAAA
#   evidence_bgcolor = papayawhip
# [causal]
#   default_graph_size = 1.9

# %% [markdown]
# ### The structure `section.key` is fixed by default and readonly : one can only change the value of an existing property

# %%
try:
    gum.config["AAA","OOO"]=1
except SyntaxError as e:
    print("Syntax error : {}".format(e.msg))
# Out:
# Syntax error : You can not add section 'AAA' in pyAgrum configuration

# %%
try:
    gum.config["causal","OOO"]=1
except SyntaxError as e:
    print("Syntax error : {}".format(e.msg))
# Out:
# Syntax error : You can not add option 'causal,OOO' in pyAgrum configuration

# %% [markdown]
# ### All the properties are stored as string !

# %%
gum.config["notebook","default_graph_size"]
# Out:
# '5'

# %%
gum.config["notebook","default_graph_size"]=10
gum.config["notebook","default_graph_size"]
# Out:
# '10'

# %% [markdown]
# ### Reset the configuration and reload configuration

# %%
gum.config.reset() # back to defaults
gum.config # no diff => shows all the properties
# Out:
# # no customized property
# [notebook]
#   potential_visible_digits = 4
#   potential_parent_values = merge
#   graph_format = svg
#   default_graph_size = 5
#   default_arc_color = #4A4A4A
#   default_node_cmap = summer
#   default_arc_cmap = BuGn
#   default_node_bgcolor = #404040
#   default_node_fgcolor = white
#   evidence_bgcolor = sandybrown
#   evidence_fgcolor = black
# [dynamicBN]
#   default_graph_size = 6
# [influenceDiagram]
#   default_graph_size = 6
#   default_chance_bgcolor = #504A50
#   default_chance_fgcolor = white
#   default_chance_shape = ellipse
#   default_utility_bgcolor = #4A5050
#   default_utility_fgcolor = white
#   default_utility_shape = diamond
#   default_decision_bgcolor = #50504A
#   default_decision_fgcolor = white
#   default_decision_shape = box
# [causal]
#   show_latent_names = False
#   latex_do_prefix = \hookrightarrow\mkern-6.5mu
#   latex_do_suffix =
#   default_graph_size = 2.5
#   default_node_bgcolor = #404040
#   default_node_fgcolor = white
#   default_latent_bgcolor = #A08080
#   default_latent_fgcolor = black

# %%
try:
    gum.config.load() # reload pyagrum.ini
except FileNotFoundError:
    pass # no pyagrum.ini in the folder
gum.config
# Out:
# [notebook]
#   default_arc_color = #AAAAAA
#   evidence_bgcolor = green

# %% [markdown]
# # Using configuration

# %%
bn=gum.fastBN("D->C<-A->B[4];A->E")
bn.cpt("B")
# Out:
# (gum::Potential<double>@0x562e49e8f9b0) <B:0|A:0> :: 0.218537 /<B:1|A:0> :: 0.145353 /<B:2|A:0> :: 0.30569 /<B:3|A:0> :: 0.33042 /<B:0|A:1> :: 0.527302 /<B:1|A:1> :: 0.0330707 /<B:2|A:1> :: 0.109349 /<B:3|A:1> :: 0.330278

# %%
gum.config["notebook","potential_visible_digits"]=1
bn.cpt("B")
# Out:
# (gum::Potential<double>@0x562e49e8f9b0) <B:0|A:0> :: 0.218537 /<B:1|A:0> :: 0.145353 /<B:2|A:0> :: 0.30569 /<B:3|A:0> :: 0.33042 /<B:0|A:1> :: 0.527302 /<B:1|A:1> :: 0.0330707 /<B:2|A:1> :: 0.109349 /<B:3|A:1> :: 0.330278

# %%
gnb.sideBySide(bn,gnb.getInference(bn,evs={"A":1},targets={"B"}))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="116pt" viewBox="0.00 0.00 206.00 116.00" width="206pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 112)">
# <title>G</title>
# <!-- D -->
# <g class="node" id="node1">
# <title>D</title>
# <g id="a_node1"><a xlink:title="(0) D">
# <ellipse cx="27" cy="-90" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-86.3">D</text>
# </a>
# </g>
# </g>
# <!-- C -->
# <g class="node" id="node2">
# <title>C</title>
# <g id="a_node2"><a xlink:title="(1) C">
# <ellipse cx="27" cy="-18" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-14.3">C</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&gt;C -->
# <g class="edge" id="edge1">
# <title>D-&gt;C</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M27,-71.8314C27,-64.131 27,-54.9743 27,-46.4166" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="30.5001,-46.4132 27,-36.4133 23.5001,-46.4133 30.5001,-46.4132" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g class="node" id="node3">
# <title>A</title>
# <g id="a_node3"><a xlink:title="(2) A">
# <ellipse cx="99" cy="-90" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">A</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;C -->
# <g class="edge" id="edge4">
# <title>A-&gt;C</title>
# <g id="a_edge4"><a xlink:title="(2, 1) : ">
# <path d="M83.7307,-74.7307C73.803,-64.803 60.6847,-51.6847 49.5637,-40.5637" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="51.7933,-37.8436 42.2473,-33.2473 46.8436,-42.7933 51.7933,-37.8436" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- B -->
# <g class="node" id="node4">
# <title>B</title>
# <g id="a_node4"><a xlink:title="(3) B">
# <ellipse cx="99" cy="-18" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-14.3">B</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g class="edge" id="edge2">
# <title>A-&gt;B</title>
# <g id="a_edge2"><a xlink:title="(2, 3) : ">
# <path d="M99,-71.8314C99,-64.131 99,-54.9743 99,-46.4166" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="102.5001,-46.4132 99,-36.4133 95.5001,-46.4133 102.5001,-46.4132" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- E -->
# <g class="node" id="node5">
# <title>E</title>
# <g id="a_node5"><a xlink:title="(4) E">
# <ellipse cx="171" cy="-18" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-14.3">E</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;E -->
# <g class="edge" id="edge3">
# <title>A-&gt;E</title>
# <g id="a_edge3"><a xlink:title="(2, 4) : ">
# <path d="M114.2693,-74.7307C124.197,-64.803 137.3153,-51.6847 148.4363,-40.5637" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="151.1564,-42.7933 155.7527,-33.2473 146.2067,-37.8436 151.1564,-42.7933" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="175pt" viewBox="0.00 0.00 254.00 175.00" width="254pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 171)">
# <title>structs</title>
# <text fill="#aaaaaa" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="123" y="-7.8">Inference in   0.56ms</text>
# <!-- D -->
# <g class="node" id="node1">
# <title>D</title>
# <ellipse cx="27" cy="-149" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-145.3">D</text>
# </g>
# <!-- C -->
# <g class="node" id="node2">
# <title>C</title>
# <ellipse cx="27" cy="-59" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-55.3">C</text>
# </g>
# <!-- D&#45;&gt;C -->
# <g class="edge" id="edge1">
# <title>D-&gt;C</title>
# <g id="a_edge1"><a xlink:title="(0, 1):">
# <path d="M27,-130.7872C27,-118.3443 27,-101.6053 27,-87.4211" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="30.5001,-87.1857 27,-77.1858 23.5001,-87.1858 30.5001,-87.1857" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g class="node" id="node3">
# <title>A</title>
# <ellipse cx="123" cy="-149" fill="#00ff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="123" y="-145.3">A</text>
# </g>
# <!-- A&#45;&gt;C -->
# <g class="edge" id="edge4">
# <title>A-&gt;C</title>
# <g id="a_edge4"><a xlink:title="(2, 1):">
# <path d="M106.4907,-134.5604C94.3183,-123.8133 77.4366,-108.6967 63,-95 58.4814,-90.713 53.7227,-86.0583 49.1984,-81.5633" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="51.4316,-78.8463 41.8894,-74.2421 46.4777,-83.7919 51.4316,-78.8463" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- B -->
# <g class="node" id="node4">
# <title>B</title>
# <polygon fill="#ffffff" points="173.5,-95 72.5,-95 72.5,-23 173.5,-23 173.5,-95" stroke="#000000"/>
# <svg height="72px" preserveAspectRatio="xMinYMin meet" viewBox="0 0 132.1625 93.6155" width="101px" x="72.5" y="-95"> <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 93.6155  L 132.1625 93.6155  L 132.1625 0  L 0 0  z " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 86.5155  L 128.5625 86.5155  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:none;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p70a4922bf0)" d="M 16.9625 84.044591  L 53.821552 84.044591  L 53.821552 73.640763  L 16.9625 73.640763  z " style="fill:#1f77b4;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p70a4922bf0)" d="M 16.9625 71.039806  L 29.165817 71.039806  L 29.165817 60.635978  L 16.9625 60.635978  z " style="fill:#1f77b4;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#p70a4922bf0)" d="M 16.9625 58.035022  L 20.653193 58.035022  L 20.653193 47.631194  L 16.9625 47.631194  z " style="fill:#1f77b4;"/>
#    </g>
#    <g id="patch_6">
#     <path clip-path="url(#p70a4922bf0)" d="M 16.9625 45.030237  L 75.809438 45.030237  L 75.809438 34.626409  L 16.9625 34.626409  z " style="fill:#1f77b4;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p70a4922bf0)" d="M 16.9625 86.5155  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="mac55403ae6" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#mac55403ae6" y="86.5155"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p70a4922bf0)" d="M 72.7625 86.5155  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#mac55403ae6" y="86.5155"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p70a4922bf0)" d="M 128.5625 86.5155  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="128.5625" xlink:href="#mac55403ae6" y="86.5155"/>
#       </g>
#      </g>
#     </g>

# %%
gum.config["notebook","evidence_bgcolor"]="green"
gum.config["notebook","default_node_bgcolor"]="yellow"
gum.config["notebook","default_node_fgcolor"]="red"
gnb.sideBySide(bn,gnb.getInference(bn,evs={"A":1},targets={"B"}))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="116pt" viewBox="0.00 0.00 206.00 116.00" width="206pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 112)">
# <title>G</title>
# <!-- D -->
# <g class="node" id="node1">
# <title>D</title>
# <g id="a_node1"><a xlink:title="(0) D">
# <ellipse cx="27" cy="-90" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-86.3">D</text>
# </a>
# </g>
# </g>
# <!-- C -->
# <g class="node" id="node2">
# <title>C</title>
# <g id="a_node2"><a xlink:title="(1) C">
# <ellipse cx="27" cy="-18" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-14.3">C</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&gt;C -->
# <g class="edge" id="edge1">
# <title>D-&gt;C</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M27,-71.8314C27,-64.131 27,-54.9743 27,-46.4166" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="30.5001,-46.4132 27,-36.4133 23.5001,-46.4133 30.5001,-46.4132" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g class="node" id="node3">
# <title>A</title>
# <g id="a_node3"><a xlink:title="(2) A">
# <ellipse cx="99" cy="-90" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">A</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;C -->
# <g class="edge" id="edge4">
# <title>A-&gt;C</title>
# <g id="a_edge4"><a xlink:title="(2, 1) : ">
# <path d="M83.7307,-74.7307C73.803,-64.803 60.6847,-51.6847 49.5637,-40.5637" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="51.7933,-37.8436 42.2473,-33.2473 46.8436,-42.7933 51.7933,-37.8436" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- B -->
# <g class="node" id="node4">
# <title>B</title>
# <g id="a_node4"><a xlink:title="(3) B">
# <ellipse cx="99" cy="-18" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-14.3">B</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g class="edge" id="edge2">
# <title>A-&gt;B</title>
# <g id="a_edge2"><a xlink:title="(2, 3) : ">
# <path d="M99,-71.8314C99,-64.131 99,-54.9743 99,-46.4166" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="102.5001,-46.4132 99,-36.4133 95.5001,-46.4133 102.5001,-46.4132" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- E -->
# <g class="node" id="node5">
# <title>E</title>
# <g id="a_node5"><a xlink:title="(4) E">
# <ellipse cx="171" cy="-18" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-14.3">E</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;E -->
# <g class="edge" id="edge3">
# <title>A-&gt;E</title>
# <g id="a_edge3"><a xlink:title="(2, 4) : ">
# <path d="M114.2693,-74.7307C124.197,-64.803 137.3153,-51.6847 148.4363,-40.5637" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="151.1564,-42.7933 155.7527,-33.2473 146.2067,-37.8436 151.1564,-42.7933" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="175pt" viewBox="0.00 0.00 254.00 175.00" width="254pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 171)">
# <title>structs</title>
# <text fill="#aaaaaa" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="123" y="-7.8">Inference in   0.85ms</text>
# <!-- D -->
# <g class="node" id="node1">
# <title>D</title>
# <ellipse cx="27" cy="-149" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-145.3">D</text>
# </g>
# <!-- C -->
# <g class="node" id="node2">
# <title>C</title>
# <ellipse cx="27" cy="-59" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-55.3">C</text>
# </g>
# <!-- D&#45;&gt;C -->
# <g class="edge" id="edge1">
# <title>D-&gt;C</title>
# <g id="a_edge1"><a xlink:title="(0, 1):">
# <path d="M27,-130.7872C27,-118.3443 27,-101.6053 27,-87.4211" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="30.5001,-87.1857 27,-77.1858 23.5001,-87.1858 30.5001,-87.1857" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g class="node" id="node3">
# <title>A</title>
# <ellipse cx="123" cy="-149" fill="#00ff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="123" y="-145.3">A</text>
# </g>
# <!-- A&#45;&gt;C -->
# <g class="edge" id="edge4">
# <title>A-&gt;C</title>
# <g id="a_edge4"><a xlink:title="(2, 1):">
# <path d="M106.4907,-134.5604C94.3183,-123.8133 77.4366,-108.6967 63,-95 58.4814,-90.713 53.7227,-86.0583 49.1984,-81.5633" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="51.4316,-78.8463 41.8894,-74.2421 46.4777,-83.7919 51.4316,-78.8463" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- B -->
# <g class="node" id="node4">
# <title>B</title>
# <polygon fill="#ffffff" points="173.5,-95 72.5,-95 72.5,-23 173.5,-23 173.5,-95" stroke="#000000"/>
# <svg height="72px" preserveAspectRatio="xMinYMin meet" viewBox="0 0 132.1625 93.6155" width="101px" x="72.5" y="-95"> <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 93.6155  L 132.1625 93.6155  L 132.1625 0  L 0 0  z " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 86.5155  L 128.5625 86.5155  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:none;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p79f0552d13)" d="M 16.9625 84.044591  L 53.821552 84.044591  L 53.821552 73.640763  L 16.9625 73.640763  z " style="fill:#1f77b4;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p79f0552d13)" d="M 16.9625 71.039806  L 29.165817 71.039806  L 29.165817 60.635978  L 16.9625 60.635978  z " style="fill:#1f77b4;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#p79f0552d13)" d="M 16.9625 58.035022  L 20.653193 58.035022  L 20.653193 47.631194  L 16.9625 47.631194  z " style="fill:#1f77b4;"/>
#    </g>
#    <g id="patch_6">
#     <path clip-path="url(#p79f0552d13)" d="M 16.9625 45.030237  L 75.809438 45.030237  L 75.809438 34.626409  L 16.9625 34.626409  z " style="fill:#1f77b4;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p79f0552d13)" d="M 16.9625 86.5155  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="maf07d82bf2" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#maf07d82bf2" y="86.5155"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p79f0552d13)" d="M 72.7625 86.5155  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#maf07d82bf2" y="86.5155"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p79f0552d13)" d="M 128.5625 86.5155  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="128.5625" xlink:href="#maf07d82bf2" y="86.5155"/>
#       </g>
#      </g>
#     </g>

# %%
gum.config["notebook","default_graph_size"]=1
gnb.sideBySide(bn,gnb.getInference(bn,evs={"A":1},targets={"B"}))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="41pt" viewBox="0.00 0.00 72.00 40.54" width="72pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(.3495 .3495) rotate(0) translate(4 112)">
# <title>G</title>
# <!-- D -->
# <g class="node" id="node1">
# <title>D</title>
# <g id="a_node1"><a xlink:title="(0) D">
# <ellipse cx="27" cy="-90" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-86.3">D</text>
# </a>
# </g>
# </g>
# <!-- C -->
# <g class="node" id="node2">
# <title>C</title>
# <g id="a_node2"><a xlink:title="(1) C">
# <ellipse cx="27" cy="-18" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-14.3">C</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&gt;C -->
# <g class="edge" id="edge1">
# <title>D-&gt;C</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M27,-71.8314C27,-64.131 27,-54.9743 27,-46.4166" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="30.5001,-46.4132 27,-36.4133 23.5001,-46.4133 30.5001,-46.4132" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g class="node" id="node3">
# <title>A</title>
# <g id="a_node3"><a xlink:title="(2) A">
# <ellipse cx="99" cy="-90" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">A</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;C -->
# <g class="edge" id="edge4">
# <title>A-&gt;C</title>
# <g id="a_edge4"><a xlink:title="(2, 1) : ">
# <path d="M83.7307,-74.7307C73.803,-64.803 60.6847,-51.6847 49.5637,-40.5637" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="51.7933,-37.8436 42.2473,-33.2473 46.8436,-42.7933 51.7933,-37.8436" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- B -->
# <g class="node" id="node4">
# <title>B</title>
# <g id="a_node4"><a xlink:title="(3) B">
# <ellipse cx="99" cy="-18" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-14.3">B</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g class="edge" id="edge2">
# <title>A-&gt;B</title>
# <g id="a_edge2"><a xlink:title="(2, 3) : ">
# <path d="M99,-71.8314C99,-64.131 99,-54.9743 99,-46.4166" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="102.5001,-46.4132 99,-36.4133 95.5001,-46.4133 102.5001,-46.4132" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- E -->
# <g class="node" id="node5">
# <title>E</title>
# <g id="a_node5"><a xlink:title="(4) E">
# <ellipse cx="171" cy="-18" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-14.3">E</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;E -->
# <g class="edge" id="edge3">
# <title>A-&gt;E</title>
# <g id="a_edge3"><a xlink:title="(2, 4) : ">
# <path d="M114.2693,-74.7307C124.197,-64.803 137.3153,-51.6847 148.4363,-40.5637" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="151.1564,-42.7933 155.7527,-33.2473 146.2067,-37.8436 151.1564,-42.7933" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="50pt" viewBox="0.00 0.00 72.00 49.61" width="72pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(.2835 .2835) rotate(0) translate(4 171)">
# <title>structs</title>
# <text fill="#aaaaaa" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="123" y="-7.8">Inference in   0.73ms</text>
# <!-- D -->
# <g class="node" id="node1">
# <title>D</title>
# <ellipse cx="27" cy="-149" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-145.3">D</text>
# </g>
# <!-- C -->
# <g class="node" id="node2">
# <title>C</title>
# <ellipse cx="27" cy="-59" fill="#ffff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ff0000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-55.3">C</text>
# </g>
# <!-- D&#45;&gt;C -->
# <g class="edge" id="edge1">
# <title>D-&gt;C</title>
# <g id="a_edge1"><a xlink:title="(0, 1):">
# <path d="M27,-130.7872C27,-118.3443 27,-101.6053 27,-87.4211" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="30.5001,-87.1857 27,-77.1858 23.5001,-87.1858 30.5001,-87.1857" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g class="node" id="node3">
# <title>A</title>
# <ellipse cx="123" cy="-149" fill="#00ff00" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="123" y="-145.3">A</text>
# </g>
# <!-- A&#45;&gt;C -->
# <g class="edge" id="edge4">
# <title>A-&gt;C</title>
# <g id="a_edge4"><a xlink:title="(2, 1):">
# <path d="M106.4907,-134.5604C94.3183,-123.8133 77.4366,-108.6967 63,-95 58.4814,-90.713 53.7227,-86.0583 49.1984,-81.5633" fill="none" stroke="#aaaaaa"/>
# <polygon fill="#aaaaaa" points="51.4316,-78.8463 41.8894,-74.2421 46.4777,-83.7919 51.4316,-78.8463" stroke="#aaaaaa"/>
# </a>
# </g>
# </g>
# <!-- B -->
# <g class="node" id="node4">
# <title>B</title>
# <polygon fill="#ffffff" points="173.5,-95 72.5,-95 72.5,-23 173.5,-23 173.5,-95" stroke="#000000"/>
# <svg height="72px" preserveAspectRatio="xMinYMin meet" viewBox="0 0 132.1625 93.6155" width="101px" x="72.5" y="-95"> <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 93.6155  L 132.1625 93.6155  L 132.1625 0  L 0 0  z " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 86.5155  L 128.5625 86.5155  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:none;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p9631933827)" d="M 16.9625 84.044591  L 53.821552 84.044591  L 53.821552 73.640763  L 16.9625 73.640763  z " style="fill:#1f77b4;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p9631933827)" d="M 16.9625 71.039806  L 29.165817 71.039806  L 29.165817 60.635978  L 16.9625 60.635978  z " style="fill:#1f77b4;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#p9631933827)" d="M 16.9625 58.035022  L 20.653193 58.035022  L 20.653193 47.631194  L 16.9625 47.631194  z " style="fill:#1f77b4;"/>
#    </g>
#    <g id="patch_6">
#     <path clip-path="url(#p9631933827)" d="M 16.9625 45.030237  L 75.809438 45.030237  L 75.809438 34.626409  L 16.9625 34.626409  z " style="fill:#1f77b4;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p9631933827)" d="M 16.9625 86.5155  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="me1e5bb9145" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#me1e5bb9145" y="86.5155"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p9631933827)" d="M 72.7625 86.5155  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#me1e5bb9145" y="86.5155"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p9631933827)" d="M 128.5625 86.5155  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="128.5625" xlink:href="#me1e5bb9145" y="86.5155"/>
#       </g>
#      </g>

# %% [markdown]
# # find a specific property

# %%
gum.config
# Out:
# [notebook]
#   potential_visible_digits = 1
#   default_graph_size = 1
#   default_arc_color = #AAAAAA
#   default_node_bgcolor = yellow
#   default_node_fgcolor = red
#   evidence_bgcolor = green

# %%
#find anything containing arc
gum.config.grep("arc")
# Out:
# [notebook]
#   default_arc_color = #AAAAAA
#   default_arc_cmap = BuGn
# [dynamicBN]
#
# [influenceDiagram]
#
# [causal]

# %%
#find anything containing default
gum.config.grep("default")
# Out:
# [notebook]
#   default_graph_size = 1
#   default_arc_color = #AAAAAA
#   default_node_cmap = summer
#   default_arc_cmap = BuGn
#   default_node_bgcolor = yellow
#   default_node_fgcolor = red
# [dynamicBN]
#   default_graph_size = 6
# [influenceDiagram]
#   default_graph_size = 6
#   default_chance_bgcolor = #504A50
#   default_chance_fgcolor = white
#   default_chance_shape = ellipse
#   default_utility_bgcolor = #4A5050
#   default_utility_fgcolor = white
#   default_utility_shape = diamond
#   default_decision_bgcolor = #50504A
#   default_decision_fgcolor = white
#   default_decision_shape = box
# [causal]
#   default_graph_size = 2.5
#   default_node_bgcolor = #404040
#   default_node_fgcolor = white
#   default_latent_bgcolor = #A08080
#   default_latent_fgcolor = black

# %%
# find anything containing theme
# if a section contains the search, all its properties are shown
gum.config.grep("caus")
# Out:
# [causal]
#   show_latent_names = False
#   latex_do_prefix = \hookrightarrow\mkern-6.5mu
#   latex_do_suffix =
#   default_graph_size = 2.5
#   default_node_bgcolor = #404040
#   default_node_fgcolor = white
#   default_latent_bgcolor = #A08080
#   default_latent_fgcolor = black

# %% [markdown]
# # Saving current configuration in `pyagrum.ini`

# %%
gum.config.reset()
gum.config['notebook','default_arc_color'] = "#AAAAAA"
gum.config['notebook','evidence_bgcolor'] = "green"
gum.config.save()

# %%
# !cat pyagrum.ini
# Out:
# [notebook]
#   default_arc_color = #AAAAAA
#   evidence_bgcolor = green

# %%
from configparser import ConfigParser
c=ConfigParser()

gum.config['notebook','default_arc_color'] = "#AAAAAA"
gum.config['notebook','evidence_bgcolor'] = "green"
c.read_string(gum.config.__repr__())

# %%
[section for section in c.sections() if len(c[section])>0]
# Out:
# ['notebook']

# %%
gum.config.__repr__()
# Out:
# '[notebook]\n  default_arc_color = #AAAAAA\n  evidence_bgcolor = green'
