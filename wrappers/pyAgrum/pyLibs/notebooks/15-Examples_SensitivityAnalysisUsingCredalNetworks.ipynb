# %% [markdown]
# <a href="http://agrum.org" target="blank"><img src="http://agrum.gitlab.io/theme/img/logoAgrum.png" align="left" style="height:100px"/></a><a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This pyAgrum's notebook is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.

# %% [markdown]
# # Sensitivity analysis for Bayesian networks using credal networks
#
# There are several sensitivity analysis frameworks for Bayesian networks. A fairly efficient method is certainly to use credal networks to do this analysis.
#
# ## Creating a Bayesian network

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %%
bn=gum.fastBN("A->B->C<-D->E->F<-B")
gnb.flow.row(bn,gnb.getInference(bn))
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="162pt" height="188pt" viewBox="0.00 0.00 162.00 188.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- B -->
# <g id="node1" class="node">
# <title>B</title>
# <g id="a_node1"><a xlink:title="(1) B">
# <ellipse fill="#404040" stroke="black" cx="127" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="127" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">B</text>
# </a>
# </g>
# </g>
# <!-- F -->
# <g id="node5" class="node">
# <title>F</title>
# <g id="a_node5"><a xlink:title="(5) F">
# <ellipse fill="#404040" stroke="black" cx="113" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="113" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">F</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&gt;F -->
# <g id="edge4" class="edge">
# <title>B-&gt;F</title>
# <g id="a_edge4"><a xlink:title="(1, 5) : ">
# <path fill="none" stroke="#4a4a4a" d="M123.61,-72.05C122.07,-64.35 120.21,-55.03 118.47,-46.36"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="121.85,-45.39 116.46,-36.28 114.98,-46.77 121.85,-45.39"/>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node6" class="node">
# <title>C</title>
# <g id="a_node6"><a xlink:title="(2) C">
# <ellipse fill="#404040" stroke="black" cx="27" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">C</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&gt;C -->
# <g id="edge2" class="edge">
# <title>B-&gt;C</title>
# <g id="a_edge2"><a xlink:title="(1, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M109.12,-76.49C93.72,-65.7 71.26,-49.98 53.72,-37.7"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="55.26,-34.51 45.06,-31.64 51.25,-40.24 55.26,-34.51"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g id="node2" class="node">
# <title>A</title>
# <g id="a_node2"><a xlink:title="(0) A">
# <ellipse fill="#404040" stroke="black" cx="127" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="127" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">A</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge1" class="edge">
# <title>A-&gt;B</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path fill="none" stroke="#4a4a4a" d="M127,-143.7C127,-135.98 127,-126.71 127,-118.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="130.5,-118.1 127,-108.1 123.5,-118.1 130.5,-118.1"/>
# </a>
# </g>
# </g>
# <!-- E -->
# <g id="node3" class="node">
# <title>E</title>
# <g id="a_node3"><a xlink:title="(4) E">
# <ellipse fill="#404040" stroke="black" cx="55" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="55" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">E</text>
# </a>
# </g>
# </g>
# <!-- E&#45;&gt;F -->
# <g id="edge5" class="edge">
# <title>E-&gt;F</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path fill="none" stroke="#4a4a4a" d="M67.59,-73.81C75.26,-64.55 85.23,-52.52 93.86,-42.09"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="96.75,-44.09 100.44,-34.16 91.36,-39.63 96.75,-44.09"/>
# </a>
# </g>
# </g>
# <!-- D -->
# <g id="node4" class="node">
# <title>D</title>
# <g id="a_node4"><a xlink:title="(3) D">
# <ellipse fill="#404040" stroke="black" cx="27" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">D</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&gt;E -->
# <g id="edge3" class="edge">
# <title>D-&gt;E</title>
# <g id="a_edge3"><a xlink:title="(3, 4) : ">
# <path fill="none" stroke="#4a4a4a" d="M33.64,-144.41C36.91,-136.22 40.94,-126.14 44.62,-116.95"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="47.95,-118.05 48.41,-107.47 41.45,-115.45 47.95,-118.05"/>
# </a>
# </g>
# </g>
# <!-- D&#45;&gt;C -->
# <g id="edge6" class="edge">
# <title>D-&gt;C</title>
# <g id="a_edge6"><a xlink:title="(3, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M23.75,-143.89C21.95,-133.54 19.91,-120.06 19,-108 17.8,-92.04 17.8,-87.96 19,-72 19.64,-63.52 20.84,-54.34 22.12,-46.04"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="25.58,-46.55 23.75,-36.11 18.68,-45.41 25.58,-46.55"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div><div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="267pt" height="256pt" viewBox="0.00 0.00 267.00 256.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 252)">
# <title>structs</title>
# <text text-anchor="middle" x="129.5" y="-7.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">Inference in   2.00ms</text>
# <!-- A -->
# <g id="node1" class="node">
# <title>A</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="259,-248 158,-248 158,-197 259,-197 259,-248"/>
# <svg viewBox="0 0 132.1625 66.4355" width="101px" height="51px" preserveAspectRatio="xMinYMin meet" x="158" y="-248"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2022-02-20T00:13:41.027098</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.5.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.4355  L 132.1625 66.4355  L 132.1625 0  L 0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 59.3355  L 128.5625 59.3355  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill: #ffffff"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 16.9625 59.3355  L 112.98346 59.3355  L 112.98346 47.2555  L 16.9625 47.2555  z " clip-path="url(#p4f6aa13b46)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="patch_4">
#     <path d="M 16.9625 44.2355  L 32.54154 44.2355  L 32.54154 32.1555  L 16.9625 32.1555  z " clip-path="url(#p4f6aa13b46)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path d="M 16.9625 59.3355  L 16.9625 32.1555  " clip-path="url(#p4f6aa13b46)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path id="m388ea3091d" d="M 0 0  L 0 3.5  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#m388ea3091d" x="16.9625" y="59.3355" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path d="M 72.7625 59.3355  L 72.7625 32.1555  " clip-path="url(#p4f6aa13b46)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use xlink:href="#m388ea3091d" x="72.7625" y="59.3355" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path d="M 128.5625 59.3355  L 128.5625 32.1555  " clip-path="url(#p4f6aa13b46)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use xlink:href="#m388ea3091d" x="128.5625" y="59.3355" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path id="m8af938c619" d="M 0 0  L -3.5 0  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#m8af938c619" x="16.9625" y="53.2955" style="stroke: #000000; strok

# %% [markdown]
# ## Building a credal network from a BN
#
# It is easy to build a credal network from a Bayesian network by indicating the 'noise' on each parameter.

# %%
cr=gum.CredalNet(bn,bn)
gnb.show(cr)
cr.bnToCredal(beta=1e-10,oneNet=False)
cr.computeBinaryCPTMinMax()
print(cr)
# Out:
# A:Range([0,1])
# <> : [[0.182055 , 0.817945] , [0.132709 , 0.867291]]
#
# B:Range([0,1])
# <A:0> : [[0.814242 , 0.185758] , [0.814241 , 0.185759]]
# <A:1> : [[0.360802 , 0.639198] , [0.359964 , 0.640036]]
#
# C:Range([0,1])
# <B:0|D:0> : [[0.187328 , 0.812672] , [0.15419 , 0.84581]]
# <B:1|D:0> : [[0.507362 , 0.492638] , [0.507283 , 0.492717]]
# <B:0|D:1> : [[0.425391 , 0.574609] , [0.425104 , 0.574896]]
# <B:1|D:1> : [[0.184355 , 0.815645] , [0.112276 , 0.887724]]
#
# D:Range([0,1])
# <> : [[0.984151 , 0.0158492]]
#
# E:Range([0,1])
# <D:0> : [[0.18389 , 0.81611] , [0.143465 , 0.856535]]
# <D:1> : [[0.635584 , 0.364416] , [0.635572 , 0.364428]]
#
# F:Range([0,1])
# <E:0|B:0> : [[0.688333 , 0.311667] , [0.688327 , 0.311673]]
# <E:1|B:0> : [[0.242911 , 0.757089] , [0.235478 , 0.764522]]
# <E:0|B:1> : [[0.350608 , 0.649392] , [0.34961 , 0.65039]]
# <E:1|B:1> : [[0.529391 , 0.470609] , [0.529335 , 0.470665]]

# %% [markdown]
# ## Testing difference hypothesis about the global precision on the parameters
#
# We can therefore easily conduct a sensitivity analysis based on an assumption of error on all the parameters of the network.

# %%
def showNoisy(bn,beta):
  cr=gum.CredalNet(bn,bn)
  cr.bnToCredal(beta=beta,oneNet=False)
  cr.computeBinaryCPTMinMax()
  ielbp=gum.CNLoopyPropagation(cr)  
  return gnb.getInference(cr,engine=ielbp)

# %%
for eps in [1,1e-3,1e-5,1e-8,1e-10]:
  gnb.flow.add_html(showNoisy(bn,eps),caption=f"noise={eps}")
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="267pt" height="226pt" viewBox="0.00 0.00 267.00 226.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 222)">
# <title>structs</title>
# <text text-anchor="middle" x="129.5" y="-7.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">Inference in   3.00ms</text>
# <!-- A -->
# <g id="node1" class="node">
# <title>A</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="259,-218 158,-218 158,-177 259,-177 259,-218"/>
# <svg viewBox="0 0 132.1625 52.998125" width="101px" height="41px" preserveAspectRatio="xMinYMin meet" x="158" y="-218"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2022-02-20T00:13:41.965072</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.5.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 52.998125  L 132.1625 52.998125  L 132.1625 0  L 0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 45.898125  L 128.5625 45.898125  L 128.5625 18.718125  L 16.9625 18.718125  z " style="fill: #ffffff"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 16.9625 45.898125  L 128.5625 45.898125  L 128.5625 33.818125  L 16.9625 33.818125  z " clip-path="url(#pc136efe646)" style="fill: #bbffaa"/>
#    </g>
#    <g id="patch_4">
#     <path d="M 16.9625 30.798125  L 128.5625 30.798125  L 128.5625 18.718125  L 16.9625 18.718125  z " clip-path="url(#pc136efe646)" style="fill: #bbffaa"/>
#    </g>
#    <g id="patch_5">
#     <path d="M 16.9625 45.898125  L 16.9625 45.898125  L 16.9625 33.818125  L 16.9625 33.818125  z " clip-path="url(#pc136efe646)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="patch_6">
#     <path d="M