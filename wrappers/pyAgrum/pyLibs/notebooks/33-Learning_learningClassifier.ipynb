# %% [markdown]
# <a href="http://agrum.org" target="blank"><img src="http://agrum.gitlab.io/theme/img/logoAgrum.png" align="left" style="height:100px"/></a><a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This pyAgrum's notebook is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.

# %%
import sys
import os

import numpy as np

import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %matplotlib inline
from pyAgrum.lib.bn2roc import showROC
from pyAgrum.lib.bn2roc import showPR
from pyAgrum.lib.bn2roc import showROC_PR

SIZE_LEARN=10000
SIZE_VALID=2000

# %%
bn=gum.loadBN("res/alarm.dsl")
bn
# Out:
# (pyAgrum.BayesNet<double>@0000024E8254E230) BN{nodes: 37, arcs: 46, domainSize: 10^16.2389, dim: 752}

# %%
gum.generateSample(bn,SIZE_LEARN,"out/learn.csv",show_progress=True,with_labels=True)
gum.generateSample(bn,SIZE_VALID,"out/train.csv",show_progress=True,with_labels=True)
# Out:
# out/learn.csv: 100%|███████████████████████████████████████|
# Log2-Likelihood : -151908.94471571845
# out/train.csv: 100%|███████████████████████████████████████|
# Log2-Likelihood : -30284.61373965278
# -30284.61373965278

# %% [markdown]
# # Learning a BN from learn.csv

# %%
# Learning a BN from the database
learner=gum.BNLearner("out/train.csv")

bn2=learner.useMIIC().learnBN()
currentTime=learner.currentTime()

# %%
gnb.flow.add(gnb.getBN(bn2,size="9"),f"Learned with {SIZE_LEARN} lines in {currentTime:.3f}s")
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="648pt" height="479pt" viewBox="0.00 0.00 648.00 479.48">
# <g id="graph0" class="graph" transform="scale(0.53 0.53) rotate(0) translate(4 904)">
# <title>G</title>
# <!-- HISTORY -->
# <g id="node1" class="node">
# <title>HISTORY</title>
# <g id="a_node1"><a xlink:title="(15) HISTORY">
# <ellipse fill="#404040" stroke="black" cx="119.14" cy="-306" rx="50.89" ry="18"/>
# <text text-anchor="middle" x="119.14" y="-302.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">HISTORY</text>
# </a>
# </g>
# </g>
# <!-- LVFAILURE -->
# <g id="node6" class="node">
# <title>LVFAILURE</title>
# <g id="a_node6"><a xlink:title="(3) LVFAILURE">
# <ellipse fill="#404040" stroke="black" cx="119.14" cy="-234" rx="60.39" ry="18"/>
# <text text-anchor="middle" x="119.14" y="-230.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">LVFAILURE</text>
# </a>
# </g>
# </g>
# <!-- HISTORY&#45;&gt;LVFAILURE -->
# <g id="edge39" class="edge">
# <title>HISTORY-&gt;LVFAILURE</title>
# <g id="a_edge39"><a xlink:title="(15, 3) : ">
# <path fill="none" stroke="#4a4a4a" d="M119.14,-287.7C119.14,-279.98 119.14,-270.71 119.14,-262.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="122.64,-262.1 119.14,-252.1 115.64,-262.1 122.64,-262.1"/>
# </a>
# </g>
# </g>
# <!-- CATECHOL -->
# <g id="node2" class="node">
# <title>CATECHOL</title>
# <g id="a_node2"><a xlink:title="(5) CATECHOL">
# <ellipse fill="#404040" stroke="black" cx="734.14" cy="-234" rx="59.59" ry="18"/>
# <text text-anchor="middle" x="734.14" y="-230.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">CATECHOL</text>
# </a>
# </g>
# </g>
# <!-- HR -->
# <g id="node5" class="node">
# <title>HR</title>
# <g id="a_node5"><a xlink:title="(6) HR">
# <ellipse fill="#404040" stroke="black" cx="734.14" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="734.14" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">HR</text>
# </a>
# </g>
# </g>
# <!-- CATECHOL&#45;&gt;HR -->
# <g id="edge18" class="edge">
# <title>CATECHOL-&gt;HR</title>
# <g id="a_edge18"><a xlink:title="(5, 6) : ">
# <path fill="none" stroke="#4a4a4a" d="M734.14,-215.7C734.14,-207.98 734.14,-198.71 734.14,-190.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="737.64,-190.1 734.14,-180.1 730.64,-190.1 737.64,-190.1"/>
# </a>
# </g>
# </g>
# <!-- ERRLOWOUTPUT -->
# <g id="node3" class="node">
# <title>ERRLOWOUTPUT</title>
# <g id="a_node3"><a xlink:title="(10) ERRLOWOUTPUT">
# <ellipse fill="#404040" stroke="black" cx="603.14" cy="-162" rx="86.38" ry="18"/>
# <text text-anchor="middle" x="603.14" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">ERRLOWOUTPUT</text>
# </a>
# </g>
# </g>
# <!-- HRBP -->
# <g id="node4" class="node">
# <title>HRBP</title>
# <g id="a_node4"><a xlink:title="(34) HRBP">
# <ellipse fill="#404040" stroke="black" cx="630.14" cy="-90" rx="34.39" ry="18"/>
# <text text-anchor="middle" x="630.14" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">HRBP</text>
# </a>
# </g>
# </g>
# <!-- ERRLOWOUTPUT&#45;&gt;HRBP -->
# <g id="edge1" class="edge">
# <title>ERRLOWOUTPUT-&gt;HRBP</title>
# <g id="a_edge1"><a xlink:title="(10, 34) : ">
# <path fill="none" stroke="#4a4a4a" d="M609.82,-143.7C612.86,-135.81 616.53,-126.3 619.9,-117.55"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="623.21,-118.69 623.55,-108.1 616.68,-116.17 623.21,-118.69"/>
# </a>
# </g>
# </g>
# <!-- HR&#45;&gt;HRBP -->
# <g id="edge36" class="edge">
# <title>HR-&gt;HRBP</title>
# <g id="a_edge36"><a xlink:title="(6, 34) : ">
# <path fill="none" stroke="#4a4a4a" d="M715.55,-148.49C699.78,-137.87 676.91,-122.48 658.81,-110.29"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="660.6,-107.28 650.35,-104.6 656.69,-113.09 660.6,-107.28"/>
# </a>
# </g>
# </g>
# <!-- HREKG -->
# <g id="node14" class="node">
# <title>HREKG</title>
# <g id="a_node14"><a xlink:title="(17) HREKG">
# <ellipse fill="#404040" stroke="black" cx="796.14" cy="-18" rx="42.49" ry="18"/>
# <text text-anchor="middle" x="796.14" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">HREKG</text>
# </a>
# </g>
# </g>
# <!-- HR&#45;&gt;HREKG -->
# <g id="edge15" class="edge">
# <title>HR-&gt;HREKG</title>
# <g id="a_edge15"><a xlink:title="(6, 17) : ">
# <path fill="none" stroke="#4a4a4a" d="M733.41,-143.72C733.31,-125.11 735.13,-95.08 746.14,-72 751.68,-60.4 760.69,-49.67 769.55,-40.93"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="771.95,-43.48 776.88,-34.09 767.18,-38.36 771.95,-43.48"/>
# </a>
# </g>
# </g>
# <!-- CO -->
# <g id="node33" class="node">
# <title>CO</title>
# <g id="a_node33"><a xlink:title="(1) CO">
# <ellipse fill="#404040" stroke="black" cx="413.14" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="413.14" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">CO</text>
# </a>
# </g>
# </g>
# <!-- HR&#45;&gt;CO -->
# <g id="edge28" class="edge">
# <title>HR-&gt;CO</title>
# <g id="a_edge28"><a xlink:title="(6, 1) : ">
# <path fill="none" stroke="#4a4a4a" d="M713.57,-150.18C708.62,-147.88 703.27,-145.66 698.14,-144 611.31,-115.94 504.51,-101.04 449.59,-94.74"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="449.96,-91.26 439.64,-93.62 449.19,-98.21 449.96,-91.26"/>
# </a>
# </g>
# </g>
# <!-- HRSAT -->
# <g id="node36" class="node">
# <title>HRSAT</title>
# <g id="a_node36"><a xlink:title="(30) HRSAT">
# <ellipse fill="#404040" stroke="black" cx="796.14" cy="-90" rx="40.89" ry="18"/>
# <text text-anchor="middle" x="796.14" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">HRSAT</text>
# </a>
# </g>
# </g>
# <!-- HR&#45;&gt;HRSAT -->
# <g id="edge6" class="edge">
# <title>HR-&gt;HRSAT</title>
# <g id="a_edge6"><a xlink:title="(6, 30) : ">
# <path fill="none" stroke="#4a4a4a" d="M747.29,-146.15C755.34,-137.07 765.81,-125.24 775,-114.87"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="777.7,-117.1 781.71,-107.29 772.46,-112.46 777.7,-117.1"/>
# </a>
# </g>
# </g>
# <!-- STROKEVOLUME -->
# <g id="node12" class="node">
# <title>STROKEVOLUME</title>
# <g id="a_node12"><a xlink:title="(14) STROKEVOLUME">
# <ellipse fill="#404040" stroke="black" cx="413.14" cy="-162" rx="85.29" ry="18"/>
# <text text-anchor="middle" x="413.14" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">STROKEVOLUME</text>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;STROKEVOLUME -->
# <g id="edge35" class="edge">
# <title>LVFAILURE-&gt;STROKEVOLUME</title>
# <g id="a_edge35"><a xlink:title="(3, 14) : ">
# <path fill="none" stroke="#4a4a4a" d="M164.76,-222.14C214.21,-210.37 293.5,-191.49 349.16,-178.23"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="350.01,-181.63 358.92,-175.91 348.38,-174.82 350.01,-181.63"/>
# </a>
# </g>
# </g>
# <!-- LVEDVOLUME -->
# <g id="node29" class="node">
# <title>LVEDVOLUME</title>
# <g id="a_node29"><a xlink:title="(9) LVEDVOLUME">
# <ellipse fill="#404040" stroke="black" cx="72.14" cy="-162" rx="72.29" ry="18"/>
# <text text-anchor="middle" x="72.14" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">LVEDVOLUME</text>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;LVEDVOLUME -->
# <g id="edge17" class="edge">
# <title>LVFAILURE-&gt;LVEDVOLUME</title>
# <g id="a_edge17"><a xlink:title="(3, 9) : ">
# <path fill="none" stroke="#4a4a4a" d="M107.77,-216.05C102.17,-207.71 95.3,-197.49 89.1,-188.25"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="91.9,-186.14 83.42,-179.79 86.08,-190.04 91.9,-186.14"/>
# </a>
# </g>
# </g>
# <!-- HYPOVOLEMIA -->
# <g id="node7" class="node">
# <title>HYPOVOLEMIA</title>
# <g id="a_node7"><a xlink:title="(31) HYPOVOLEMIA">
# <ellipse fill="#404040" stroke="black" cx="320.14" cy="-234" rx="76.89" ry="18"/>
# <text text-anchor="middle" x="320.14" y="-230.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">HYPOVOLEMIA</text>
# </a>
# </g>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;STROKEVOLUME -->
# <g id

# %%
import pyAgrum.lib.bn_vs_bn as bnvsbn
gnb.flow.add(gnb.getBNDiff(bn,bn2,size="8!"),"Diff with MIIC")
gnb.flow.add(bnvsbn.graphDiffLegend())
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="576pt" height="467pt" viewBox="0.00 0.00 576.00 467.16">
# <g id="graph0" class="graph" transform="scale(0.61 0.61) rotate(0) translate(4 760)">
# <title>G</title>
# <!-- KINKEDTUBE -->
# <g id="node1" class="node">
# <title>KINKEDTUBE</title>
# <ellipse fill="lightgrey" stroke="black" cx="321.09" cy="-594" rx="67.69" ry="18"/>
# <text text-anchor="middle" x="321.09" y="-590.3" font-family="Times New Roman,serif" font-size="14.00">KINKEDTUBE</text>
# </g>
# <!-- VENTLUNG -->
# <g id="node23" class="node">
# <title>VENTLUNG</title>
# <ellipse fill="lightgrey" stroke="black" cx="386.09" cy="-522" rx="59.59" ry="18"/>
# <text text-anchor="middle" x="386.09" y="-518.3" font-family="Times New Roman,serif" font-size="14.00">VENTLUNG</text>
# </g>
# <!-- KINKEDTUBE&#45;&gt;VENTLUNG -->
# <g id="edge34" class="edge">
# <title>KINKEDTUBE-&gt;VENTLUNG</title>
# <path fill="none" stroke="grey" d="M337.16,-576.2C345.03,-567.48 354.65,-556.83 363.27,-547.28"/>
# <polygon fill="grey" stroke="grey" points="366.11,-549.36 370.21,-539.59 360.91,-544.67 366.11,-549.36"/>
# </g>
# <!-- PRESS -->
# <g id="node25" class="node">
# <title>PRESS</title>
# <ellipse fill="lightgrey" stroke="black" cx="502.09" cy="-522" rx="38.19" ry="18"/>
# <text text-anchor="middle" x="502.09" y="-518.3" font-family="Times New Roman,serif" font-size="14.00">PRESS</text>
# </g>
# <!-- KINKEDTUBE&#45;&gt;PRESS -->
# <g id="edge47" class="edge">
# <title>KINKEDTUBE-&gt;PRESS</title>
# <path fill="none" stroke="grey" d="M359.03,-578.91C389.62,-566.74 432.47,-549.7 463.28,-537.44"/>
# <polygon fill="grey" stroke="grey" points="464.84,-540.59 472.83,-533.64 462.25,-534.08 464.84,-540.59"/>
# </g>
# <!-- HYPOVOLEMIA -->
# <g id="node2" class="node">
# <title>HYPOVOLEMIA</title>
# <ellipse fill="lightgrey" stroke="black" cx="155.1" cy="-234" rx="76.89" ry="18"/>
# <text text-anchor="middle" x="155.1" y="-230.3" font-family="Times New Roman,serif" font-size="14.00">HYPOVOLEMIA</text>
# </g>
# <!-- STROKEVOLUME -->
# <g id="node14" class="node">
# <title>STROKEVOLUME</title>
# <ellipse fill="lightgrey" stroke="black" cx="317.1" cy="-162" rx="85.29" ry="18"/>
# <text text-anchor="middle" x="317.1" y="-158.3" font-family="Times New Roman,serif" font-size="14.00">STROKEVOLUME</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;STROKEVOLUME -->
# <g id="edge45" class="edge">
# <title>HYPOVOLEMIA-&gt;STROKEVOLUME</title>
# <path fill="none" stroke="grey" d="M191.05,-218.02C214.61,-207.55 245.62,-193.77 270.98,-182.49"/>
# <polygon fill="grey" stroke="grey" points="272.68,-185.57 280.4,-178.31 269.84,-179.17 272.68,-185.57"/>
# </g>
# <!-- LVEDVOLUME -->
# <g id="node16" class="node">
# <title>LVEDVOLUME</title>
# <ellipse fill="lightgrey" stroke="black" cx="142.09" cy="-162" rx="72.29" ry="18"/>
# <text text-anchor="middle" x="142.09" y="-158.3" font-family="Times New Roman,serif" font-size="14.00">LVEDVOLUME</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;LVEDVOLUME -->
# <g id="edge18" class="edge">
# <title>HYPOVOLEMIA-&gt;LVEDVOLUME</title>
# <path fill="none" stroke="grey" d="M151.81,-215.83C150.42,-208.13 148.77,-198.97 147.22,-190.42"/>
# <polygon fill="grey" stroke="grey" points="150.64,-189.63 145.42,-180.41 143.75,-190.88 150.64,-189.63"/>
# </g>
# <!-- INTUBATION -->
# <g id="node3" class="node">
# <title>INTUBATION</title>
# <ellipse fill="lightgrey" stroke="black" cx="606.1" cy="-594" rx="66.09" ry="18"/>
# <text text-anchor="middle" x="606.1" y="-590.3" font-family="Times New Roman,serif" font-size="14.00">INTUBATION</text>
# </g>
# <!-- SHUNT -->
# <g id="node19" class="node">
# <title>SHUNT</title>
# <ellipse fill="lightgrey" stroke="black" cx="706.1" cy="-522" rx="40.89" ry="18"/>
# <text text-anchor="middle" x="706.1" y="-518.3" font-family="Times New Roman,serif" font-size="14.00">SHUNT</text>
# </g>
# <!-- INTUBATION&#45;&gt;SHUNT -->
# <g id="edge46" class="edge">
# <title>INTUBATION-&gt;SHUNT</title>
# <path fill="none" stroke="grey" d="M629.54,-577.12C643.44,-567.11 661.19,-554.33 676.11,-543.59"/>
# <polygon fill="grey" stroke="grey" points="678.44,-546.23 684.51,-537.55 674.35,-540.55 678.44,-546.23"/>
# </g>
# <!-- INTUBATION&#45;&gt;VENTLUNG -->
# <g id="edge36" class="edge">
# <title>INTUBATION-&gt;VENTLUNG</title>
# <path fill="none" stroke="red" stroke-dasharray="5,2" d="M563.68,-580.12C527.46,-568.26 475.28,-551.19 436.85,-538.61"/>
# <polygon fill="red" stroke="red" points="437.49,-535.14 426.89,-535.35 435.31,-541.79 437.49,-535.14"/>
# </g>
# <!-- MINVOL -->
# <g id="node24" class="node">
# <title>MINVOL</title>
# <ellipse fill="lightgrey" stroke="black" cx="433.09" cy="-450" rx="46.29" ry="18"/>
# <text text-anchor="middle" x="433.09" y="-446.3" font-family="Times New Roman,serif" font-size="14.00">MINVOL</text>
# </g>
# <!-- INTUBATION&#45;&gt;MINVOL -->
# <g id="edge19" class="edge">
# <title>INTUBATION-&gt;MINVOL</title>
# <path fill="none" stroke="red" stroke-dasharray="5,2" d="M592.97,-576.1C578.87,-557.64 555.11,-528.72 530.34,-508.14 512.14,-493.02 489.57,-479.27 470.75,-468.94"/>
# <polygon fill="red" stroke="red" points="472.32,-465.81 461.85,-464.15 469,-471.97 472.32,-465.81"/>
# </g>
# <!-- INTUBATION&#45;&gt;PRESS -->
# <g id="edge49" class="edge">
# <title>INTUBATION-&gt;PRESS</title>
# <path fill="none" stroke="grey" d="M581.71,-577.12C566.92,-566.88 547.93,-553.73 532.2,-542.84"/>
# <polygon fill="grey" stroke="grey" points="534.06,-539.88 523.85,-537.06 530.08,-545.63 534.06,-539.88"/>
# </g>
# <!-- VENTALV -->
# <g id="node26" class="node">
# <title>VENTALV</title>
# <ellipse fill="lightgrey" stroke="black" cx="550.09" cy="-450" rx="52.79" ry="18"/>
# <text text-anchor="middle" x="550.09" y="-446.3" font-family="Times New Roman,serif" font-size="14.00">VENTALV</text>
# </g>
# <!-- INTUBATION&#45;&gt;VENTALV -->
# <!-- MINVOLSET -->
# <g id="node4" class="node">
# <title>MINVOLSET</title>
# <ellipse fill="lightgrey" stroke="black" cx="538.09" cy="-738" rx="63.09" ry="18"/>
# <text text-anchor="middle" x="538.09" y="-734.3" font-family="Times New Roman,serif" font-size="14.00">MINVOLSET</text>
# </g>
# <!-- VENTMACH -->
# <g id="node17" class="node">
# <title>VENTMACH</title>
# <ellipse fill="lightgrey" stroke="black" cx="538.09" cy="-666" rx="61.99" ry="18"/>
# <text text-anchor="middle" x="538.09" y="-662.3" font-family="Times New Roman,serif" font-size="14.00">VENTMACH</text>
# </g>
# <!-- MINVOLSET&#45;&gt;VENTMACH -->
# <g id="edge6" class="edge">
# <title>MINVOLSET-&gt;VENTMACH</title>
# <path fill="none" stroke="grey" d="M538.09,-719.83C538.09,-712.13 538.09,-702.97 538.09,-694.42"/>
# <polygon fill="grey" stroke="grey" points="541.59,-694.41 538.09,-684.41 534.59,-694.41 541.59,-694.41"/>
# </g>
# <!-- PULMEMBOLUS -->
# <g id="node5" class="node">
# <title>PULMEMBOLUS</title>
# <ellipse fill="lightgrey" stroke="black" cx="785.09" cy="-594" rx="78.79" ry="18"/>
# <text text-anchor="middle" x="785.09" y="-590.3" font-family="Times New Roman,serif" font-size="14.00">PULMEMBOLUS</text>
# </g>
# <!-- PAP -->
# <g id="node13" class="node">
# <title>PAP</title>
# <ellipse fill="lightgrey" stroke="black" cx="793.08" cy="-522" rx="27.9" ry="18"/>
# <text text-anchor="middle" x="793.08" y="-518.3" font-family="Times New Roman,serif" font-size="14.00">PAP</text>
# </g>
# <!-- PULMEMBOLUS&#45;&gt;PAP -->
# <g id="edge4" class="edge">
# <title>PULMEMBOLUS-&gt;PAP</title>
# <path fill="none" stroke="grey" d="M787.1,-575.83C787.96,-568.13 788.98,-558.97 789.93,-550.42"/>
# <polygon fill="grey" stroke="grey" points="793.41,-550.74 791.04,-540.41 786.45,-549.97 793.41,-550.74"/>
# </g>
# <!-- PULMEMBOLUS&#45;&gt;SHUNT -->
# <!-- INSUFFANESTH -->
# <g id="node6" class="node">
# <title>INSUFFANESTH</title>
# <ellipse fill="lightgrey" stroke="black" cx="500.09" cy="-306" rx="77.99" ry="18"/>
# <text text-anchor="middle" x="500.09" y="-302.3" font-family="Times New Roman,serif" font-size="14.00">INSUFFANESTH</text>
# </g>
# <!-- CATECHOL -->
# <g id="node3

# %%
bn3=learner.useGreedyHillClimbing().useNMLCorrection().useScoreBDeu().learnBN()
gnb.flow.add(gnb.getBNDiff(bn,bn3,size="8!"),"Diff with GHC/NMD/BDEU")
gnb.flow.add(bnvsbn.graphDiffLegend())
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="576pt" height="467pt" viewBox="0.00 0.00 576.00 467.16">
# <g id="graph0" class="graph" transform="scale(0.61 0.61) rotate(0) translate(4 760)">
# <title>G</title>
# <!-- KINKEDTUBE -->
# <g id="node1" class="node">
# <title>KINKEDTUBE</title>
# <ellipse fill="lightgrey" stroke="black" cx="321.09" cy="-594" rx="67.69" ry="18"/>
# <text text-anchor="middle" x="321.09" y="-590.3" font-family="Times New Roman,serif" font-size="14.00">KINKEDTUBE</text>
# </g>
# <!-- VENTLUNG -->
# <g id="node23" class="node">
# <title>VENTLUNG</title>
# <ellipse fill="lightgrey" stroke="black" cx="386.09" cy="-522" rx="59.59" ry="18"/>
# <text text-anchor="middle" x="386.09" y="-518.3" font-family="Times New Roman,serif" font-size="14.00">VENTLUNG</text>
# </g>
# <!-- KINKEDTUBE&#45;&gt;VENTLUNG -->
# <!-- PRESS -->
# <g id="node25" class="node">
# <title>PRESS</title>
# <ellipse fill="lightgrey" stroke="black" cx="502.09" cy="-522" rx="38.19" ry="18"/>
# <text text-anchor="middle" x="502.09" y="-518.3" font-family="Times New Roman,serif" font-size="14.00">PRESS</text>
# </g>
# <!-- KINKEDTUBE&#45;&gt;PRESS -->
# <g id="edge60" class="edge">
# <title>KINKEDTUBE-&gt;PRESS</title>
# <path fill="none" stroke="grey" d="M359.03,-578.91C389.62,-566.74 432.47,-549.7 463.28,-537.44"/>
# <polygon fill="grey" stroke="grey" points="464.84,-540.59 472.83,-533.64 462.25,-534.08 464.84,-540.59"/>
# </g>
# <!-- HYPOVOLEMIA -->
# <g id="node2" class="node">
# <title>HYPOVOLEMIA</title>
# <ellipse fill="lightgrey" stroke="black" cx="155.1" cy="-234" rx="76.89" ry="18"/>
# <text text-anchor="middle" x="155.1" y="-230.3" font-family="Times New Roman,serif" font-size="14.00">HYPOVOLEMIA</text>
# </g>
# <!-- STROKEVOLUME -->
# <g id="node14" class="node">
# <title>STROKEVOLUME</title>
# <ellipse fill="lightgrey" stroke="black" cx="317.1" cy="-162" rx="85.29" ry="18"/>
# <text text-anchor="middle" x="317.1" y="-158.3" font-family="Times New Roman,serif" font-size="14.00">STROKEVOLUME</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;STROKEVOLUME -->
# <!-- LVEDVOLUME -->
# <g id="node16" class="node">
# <title>LVEDVOLUME</title>
# <ellipse fill="lightgrey" stroke="black" cx="142.09" cy="-162" rx="72.29" ry="18"/>
# <text text-anchor="middle" x="142.09" y="-158.3" font-family="Times New Roman,serif" font-size="14.00">LVEDVOLUME</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;LVEDVOLUME -->
# <g id="edge22" class="edge">
# <title>HYPOVOLEMIA-&gt;LVEDVOLUME</title>
# <path fill="none" stroke="grey" d="M151.81,-215.83C150.42,-208.13 148.77,-198.97 147.22,-190.42"/>
# <polygon fill="grey" stroke="grey" points="150.64,-189.63 145.42,-180.41 143.75,-190.88 150.64,-189.63"/>
# </g>
# <!-- HISTORY -->
# <g id="node20" class="node">
# <title>HISTORY</title>
# <ellipse fill="lightgrey" stroke="black" cx="471.1" cy="-162" rx="50.89" ry="18"/>
# <text text-anchor="middle" x="471.1" y="-158.3" font-family="Times New Roman,serif" font-size="14.00">HISTORY</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;HISTORY -->
# <g id="edge72" class="edge">
# <title>HYPOVOLEMIA-&gt;HISTORY</title>
# <path fill="none" stroke="purple" stroke-dasharray="5,2" d="M210.14,-221.46C268.69,-208.12 360.65,-187.16 418.32,-174.02"/>
# <polygon fill="purple" stroke="purple" points="419.35,-177.38 428.32,-171.75 417.8,-170.55 419.35,-177.38"/>
# </g>
# <!-- INTUBATION -->
# <g id="node3" class="node">
# <title>INTUBATION</title>
# <ellipse fill="lightgrey" stroke="black" cx="606.1" cy="-594" rx="66.09" ry="18"/>
# <text text-anchor="middle" x="606.1" y="-590.3" font-family="Times New Roman,serif" font-size="14.00">INTUBATION</text>
# </g>
# <!-- SHUNT -->
# <g id="node19" class="node">
# <title>SHUNT</title>
# <ellipse fill="lightgrey" stroke="black" cx="706.1" cy="-522" rx="40.89" ry="18"/>
# <text text-anchor="middle" x="706.1" y="-518.3" font-family="Times New Roman,serif" font-size="14.00">SHUNT</text>
# </g>
# <!-- INTUBATION&#45;&gt;SHUNT -->
# <g id="edge59" class="edge">
# <title>INTUBATION-&gt;SHUNT</title>
# <path fill="none" stroke="grey" d="M629.54,-577.12C643.44,-567.11 661.19,-554.33 676.11,-543.59"/>
# <polygon fill="grey" stroke="grey" points="678.44,-546.23 684.51,-537.55 674.35,-540.55 678.44,-546.23"/>
# </g>
# <!-- VENTTUBE -->
# <g id="node21" class="node">
# <title>VENTTUBE</title>
# <ellipse fill="lightgrey" stroke="black" cx="464.09" cy="-594" rx="57.69" ry="18"/>
# <text text-anchor="middle" x="464.09" y="-590.3" font-family="Times New Roman,serif" font-size="14.00">VENTTUBE</text>
# </g>
# <!-- INTUBATION&#45;&gt;VENTTUBE -->
# <g id="edge69" class="edge">
# <title>INTUBATION-&gt;VENTTUBE</title>
# <path fill="none" stroke="purple" stroke-dasharray="5,2" d="M539.67,-594C537.17,-594 534.66,-594 532.17,-594"/>
# <polygon fill="purple" stroke="purple" points="531.95,-590.5 521.95,-594 531.95,-597.5 531.95,-590.5"/>
# </g>
# <!-- INTUBATION&#45;&gt;VENTLUNG -->
# <!-- MINVOL -->
# <g id="node24" class="node">
# <title>MINVOL</title>
# <ellipse fill="lightgrey" stroke="black" cx="433.09" cy="-450" rx="46.29" ry="18"/>
# <text text-anchor="middle" x="433.09" y="-446.3" font-family="Times New Roman,serif" font-size="14.00">MINVOL</text>
# </g>
# <!-- INTUBATION&#45;&gt;MINVOL -->
# <g id="edge23" class="edge">
# <title>INTUBATION-&gt;MINVOL</title>
# <path fill="none" stroke="grey" d="M592.97,-576.1C578.87,-557.64 555.11,-528.72 530.34,-508.14 512.14,-493.02 489.57,-479.27 470.75,-468.94"/>
# <polygon fill="grey" stroke="grey" points="472.32,-465.81 461.85,-464.15 469,-471.97 472.32,-465.81"/>
# </g>
# <!-- INTUBATION&#45;&gt;PRESS -->
# <g id="edge62" class="edge">
# <title>INTUBATION-&gt;PRESS</title>
# <path fill="none" stroke="grey" d="M581.71,-577.12C566.92,-566.88 547.93,-553.73 532.2,-542.84"/>
# <polygon fill="grey" stroke="grey" points="534.06,-539.88 523.85,-537.06 530.08,-545.63 534.06,-539.88"/>
# </g>
# <!-- VENTALV -->
# <g id="node26" class="node">
# <title>VENTALV</title>
# <ellipse fill="lightgrey" stroke="black" cx="550.09" cy="-450" rx="52.79" ry="18"/>
# <text text-anchor="middle" x="550.09" y="-446.3" font-family="Times New Roman,serif" font-size="14.00">VENTALV</text>
# </g>
# <!-- INTUBATION&#45;&gt;VENTALV -->
# <!-- MINVOLSET -->
# <g id="node4" class="node">
# <title>MINVOLSET</title>
# <ellipse fill="lightgrey" stroke="black" cx="538.09" cy="-738" rx="63.09" ry="18"/>
# <text text-anchor="middle" x="538.09" y="-734.3" font-family="Times New Roman,serif" font-size="14.00">MINVOLSET</text>
# </g>
# <!-- VENTMACH -->
# <g id="node17" class="node">
# <title>VENTMACH</title>
# <ellipse fill="lightgrey" stroke="black" cx="538.09" cy="-666" rx="61.99" ry="18"/>
# <text text-anchor="middle" x="538.09" y="-662.3" font-family="Times New Roman,serif" font-size="14.00">VENTMACH</text>
# </g>
# <!-- MINVOLSET&#45;&gt;VENTMACH -->
# <!-- PULMEMBOLUS -->
# <g id="node5" class="node">
# <title>PULMEMBOLUS</title>
# <ellipse fill="lightgrey" stroke="black" cx="785.09" cy="-594" rx="78.79" ry="18"/>
# <text text-anchor="middle" x="785.09" y="-590.3" font-family="Times New Roman,serif" font-size="14.00">PULMEMBOLUS</text>
# </g>
# <!-- PAP -->
# <g id="node13" class="node">
# <title>PAP</title>
# <ellipse fill="lightgrey" stroke="black" cx="793.08" cy="-522" rx="27.9" ry="18"/>
# <text text-anchor="middle" x="793.08" y="-518.3" font-family="Times New Roman,serif" font-size="14.00">PAP</text>
# </g>
# <!-- PULMEMBOLUS&#45;&gt;PAP -->
# <g id="edge5" class="edge">
# <title>PULMEMBOLUS-&gt;PAP</title>
# <path fill="none" stroke="grey" d="M787.1,-575.83C787.96,-568.13 788.98,-558.97 789.93,-550.42"/>
# <polygon fill="grey" stroke="grey" points="793.41,-550.74 791.04,-540.41 786.45,-549.97 793.41,-550.74"/>
# </g>
# <!-- PULMEMBOLUS&#45;&gt;SHUNT -->
# <g id="edge13" class="edge">
# <title>PULMEMBOLUS-&gt;SHUNT</title>
# <path fill="none" stroke="grey" d="M765.56,-576.2C755.34,-566.89 742.7,-555.36 731.7,-545.34"/>
# <polygon fill="grey" stroke="grey" points="733.8,-542.51 724.05,-538.36 729.08,-547.69 73

# %%
bn4=learner.useGreedyHillClimbing().useNMLCorrection().useScoreBDeu().setInitialDAG(bn2.dag()).learnBN()
gnb.flow.add(gnb.getBNDiff(bn,bn4,size="8!"),"Diff with GHC/NMD/BDEU with intial DAG from MIIC")
gnb.flow.add(bnvsbn.graphDiffLegend())
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="576pt" height="467pt" viewBox="0.00 0.00 576.00 467.16">
# <g id="graph0" class="graph" transform="scale(0.61 0.61) rotate(0) translate(4 760)">
# <title>G</title>
# <!-- KINKEDTUBE -->
# <g id="node1" class="node">
# <title>KINKEDTUBE</title>
# <ellipse fill="lightgrey" stroke="black" cx="321.09" cy="-594" rx="67.69" ry="18"/>
# <text text-anchor="middle" x="321.09" y="-590.3" font-family="Times New Roman,serif" font-size="14.00">KINKEDTUBE</text>
# </g>
# <!-- VENTLUNG -->
# <g id="node23" class="node">
# <title>VENTLUNG</title>
# <ellipse fill="lightgrey" stroke="black" cx="386.09" cy="-522" rx="59.59" ry="18"/>
# <text text-anchor="middle" x="386.09" y="-518.3" font-family="Times New Roman,serif" font-size="14.00">VENTLUNG</text>
# </g>
# <!-- KINKEDTUBE&#45;&gt;VENTLUNG -->
# <g id="edge35" class="edge">
# <title>KINKEDTUBE-&gt;VENTLUNG</title>
# <path fill="none" stroke="grey" d="M337.16,-576.2C345.03,-567.48 354.65,-556.83 363.27,-547.28"/>
# <polygon fill="grey" stroke="grey" points="366.11,-549.36 370.21,-539.59 360.91,-544.67 366.11,-549.36"/>
# </g>
# <!-- PRESS -->
# <g id="node25" class="node">
# <title>PRESS</title>
# <ellipse fill="lightgrey" stroke="black" cx="502.09" cy="-522" rx="38.19" ry="18"/>
# <text text-anchor="middle" x="502.09" y="-518.3" font-family="Times New Roman,serif" font-size="14.00">PRESS</text>
# </g>
# <!-- KINKEDTUBE&#45;&gt;PRESS -->
# <g id="edge49" class="edge">
# <title>KINKEDTUBE-&gt;PRESS</title>
# <path fill="none" stroke="grey" d="M359.03,-578.91C389.62,-566.74 432.47,-549.7 463.28,-537.44"/>
# <polygon fill="grey" stroke="grey" points="464.84,-540.59 472.83,-533.64 462.25,-534.08 464.84,-540.59"/>
# </g>
# <!-- HYPOVOLEMIA -->
# <g id="node2" class="node">
# <title>HYPOVOLEMIA</title>
# <ellipse fill="lightgrey" stroke="black" cx="155.1" cy="-234" rx="76.89" ry="18"/>
# <text text-anchor="middle" x="155.1" y="-230.3" font-family="Times New Roman,serif" font-size="14.00">HYPOVOLEMIA</text>
# </g>
# <!-- LVFAILURE -->
# <g id="node10" class="node">
# <title>LVFAILURE</title>
# <ellipse fill="lightgrey" stroke="black" cx="317.1" cy="-234" rx="60.39" ry="18"/>
# <text text-anchor="middle" x="317.1" y="-230.3" font-family="Times New Roman,serif" font-size="14.00">LVFAILURE</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;LVFAILURE -->
# <g id="edge53" class="edge">
# <title>HYPOVOLEMIA-&gt;LVFAILURE</title>
# <path fill="none" stroke="purple" stroke-dasharray="5,2" d="M231.83,-234C236.55,-234 241.3,-234 246,-234"/>
# <polygon fill="purple" stroke="purple" points="246.2,-237.5 256.2,-234 246.2,-230.5 246.2,-237.5"/>
# </g>
# <!-- STROKEVOLUME -->
# <g id="node14" class="node">
# <title>STROKEVOLUME</title>
# <ellipse fill="lightgrey" stroke="black" cx="317.1" cy="-162" rx="85.29" ry="18"/>
# <text text-anchor="middle" x="317.1" y="-158.3" font-family="Times New Roman,serif" font-size="14.00">STROKEVOLUME</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;STROKEVOLUME -->
# <g id="edge47" class="edge">
# <title>HYPOVOLEMIA-&gt;STROKEVOLUME</title>
# <path fill="none" stroke="grey" d="M191.05,-218.02C214.61,-207.55 245.62,-193.77 270.98,-182.49"/>
# <polygon fill="grey" stroke="grey" points="272.68,-185.57 280.4,-178.31 269.84,-179.17 272.68,-185.57"/>
# </g>
# <!-- LVEDVOLUME -->
# <g id="node16" class="node">
# <title>LVEDVOLUME</title>
# <ellipse fill="lightgrey" stroke="black" cx="142.09" cy="-162" rx="72.29" ry="18"/>
# <text text-anchor="middle" x="142.09" y="-158.3" font-family="Times New Roman,serif" font-size="14.00">LVEDVOLUME</text>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;LVEDVOLUME -->
# <g id="edge18" class="edge">
# <title>HYPOVOLEMIA-&gt;LVEDVOLUME</title>
# <path fill="none" stroke="grey" d="M151.81,-215.83C150.42,-208.13 148.77,-198.97 147.22,-190.42"/>
# <polygon fill="grey" stroke="grey" points="150.64,-189.63 145.42,-180.41 143.75,-190.88 150.64,-189.63"/>
# </g>
# <!-- INTUBATION -->
# <g id="node3" class="node">
# <title>INTUBATION</title>
# <ellipse fill="lightgrey" stroke="black" cx="606.1" cy="-594" rx="66.09" ry="18"/>
# <text text-anchor="middle" x="606.1" y="-590.3" font-family="Times New Roman,serif" font-size="14.00">INTUBATION</text>
# </g>
# <!-- SHUNT -->
# <g id="node19" class="node">
# <title>SHUNT</title>
# <ellipse fill="lightgrey" stroke="black" cx="706.1" cy="-522" rx="40.89" ry="18"/>
# <text text-anchor="middle" x="706.1" y="-518.3" font-family="Times New Roman,serif" font-size="14.00">SHUNT</text>
# </g>
# <!-- INTUBATION&#45;&gt;SHUNT -->
# <g id="edge48" class="edge">
# <title>INTUBATION-&gt;SHUNT</title>
# <path fill="none" stroke="grey" d="M629.54,-577.12C643.44,-567.11 661.19,-554.33 676.11,-543.59"/>
# <polygon fill="grey" stroke="grey" points="678.44,-546.23 684.51,-537.55 674.35,-540.55 678.44,-546.23"/>
# </g>
# <!-- INTUBATION&#45;&gt;VENTLUNG -->
# <!-- MINVOL -->
# <g id="node24" class="node">
# <title>MINVOL</title>
# <ellipse fill="lightgrey" stroke="black" cx="433.09" cy="-450" rx="46.29" ry="18"/>
# <text text-anchor="middle" x="433.09" y="-446.3" font-family="Times New Roman,serif" font-size="14.00">MINVOL</text>
# </g>
# <!-- INTUBATION&#45;&gt;MINVOL -->
# <!-- INTUBATION&#45;&gt;PRESS -->
# <g id="edge51" class="edge">
# <title>INTUBATION-&gt;PRESS</title>
# <path fill="none" stroke="grey" d="M581.71,-577.12C566.92,-566.88 547.93,-553.73 532.2,-542.84"/>
# <polygon fill="grey" stroke="grey" points="534.06,-539.88 523.85,-537.06 530.08,-545.63 534.06,-539.88"/>
# </g>
# <!-- VENTALV -->
# <g id="node26" class="node">
# <title>VENTALV</title>
# <ellipse fill="lightgrey" stroke="black" cx="550.09" cy="-450" rx="52.79" ry="18"/>
# <text text-anchor="middle" x="550.09" y="-446.3" font-family="Times New Roman,serif" font-size="14.00">VENTALV</text>
# </g>
# <!-- INTUBATION&#45;&gt;VENTALV -->
# <!-- MINVOLSET -->
# <g id="node4" class="node">
# <title>MINVOLSET</title>
# <ellipse fill="lightgrey" stroke="black" cx="538.09" cy="-738" rx="63.09" ry="18"/>
# <text text-anchor="middle" x="538.09" y="-734.3" font-family="Times New Roman,serif" font-size="14.00">MINVOLSET</text>
# </g>
# <!-- MINVOLSET&#45;&gt;INTUBATION -->
# <g id="edge54" class="edge">
# <title>MINVOLSET-&gt;INTUBATION</title>
# <path fill="none" stroke="purple" stroke-dasharray="5,2" d="M559.2,-720.88C573.88,-707.61 592.38,-687.85 601.44,-666.02 607.08,-652.41 608.52,-636.11 608.43,-622.46"/>
# <polygon fill="purple" stroke="purple" points="611.92,-622.06 608.08,-612.19 604.92,-622.3 611.92,-622.06"/>
# </g>
# <!-- VENTMACH -->
# <g id="node17" class="node">
# <title>VENTMACH</title>
# <ellipse fill="lightgrey" stroke="black" cx="538.09" cy="-666" rx="61.99" ry="18"/>
# <text text-anchor="middle" x="538.09" y="-662.3" font-family="Times New Roman,serif" font-size="14.00">VENTMACH</text>
# </g>
# <!-- MINVOLSET&#45;&gt;VENTMACH -->
# <g id="edge6" class="edge">
# <title>MINVOLSET-&gt;VENTMACH</title>
# <path fill="none" stroke="grey" d="M538.09,-719.83C538.09,-712.13 538.09,-702.97 538.09,-694.42"/>
# <polygon fill="grey" stroke="grey" points="541.59,-694.41 538.09,-684.41 534.59,-694.41 541.59,-694.41"/>
# </g>
# <!-- PULMEMBOLUS -->
# <g id="node5" class="node">
# <title>PULMEMBOLUS</title>
# <ellipse fill="lightgrey" stroke="black" cx="785.09" cy="-594" rx="78.79" ry="18"/>
# <text text-anchor="middle" x="785.09" y="-590.3" font-family="Times New Roman,serif" font-size="14.00">PULMEMBOLUS</text>
# </g>
# <!-- PAP -->
# <g id="node13" class="node">
# <title>PAP</title>
# <ellipse fill="lightgrey" stroke="black" cx="793.08" cy="-522" rx="27.9" ry="18"/>
# <text text-anchor="middle" x="793.08" y="-518.3" font-family="Times New Roman,serif" font-size="14.00">PAP</text>
# </g>
# <!-- PULMEMBOLUS&#45;&gt;PAP -->
# <g id="edge4" class="edge">
# <title>PULMEMBOLUS-&gt;PAP</title>
# <path fill="none" stroke="grey" d="M787.1,-575.83C787.96,-568.13 788.98,-558.97 789.93,-550.42"/>
# <polygon fill="grey" stroke="grey" points="793.41,-550.74 791.04,-540.41 786.45,-549.97 793.41,-550.74"/>
# </g>

# %%
print(bn2.names())
# Out:
# {'HISTORY', 'CATECHOL', 'ERRLOWOUTPUT', 'HRBP', 'HR', 'LVFAILURE', 'HYPOVOLEMIA', 'PCWP', 'TPR', 'FIO2', 'MINVOLSET', 'STROKEVOLUME', 'PULMEMBOLUS', 'HREKG', 'PRESS', 'BP', 'ERRCAUTER', 'PAP', 'DISCONNECT', 'KINKEDTUBE', 'SHUNT', 'ARTCO2', 'INTUBATION', 'VENTMACH', 'MINVOL', 'EXPCO2', 'CVP', 'INSUFFANESTH', 'LVEDVOLUME', 'SAO2', 'ANAPHYLAXIS', 'PVSAT', 'CO', 'VENTALV', 'VENTLUNG', 'HRSAT', 'VENTTUBE'}

# %%
gnb.showInference(bn2,evs={},size="14")

# %% [markdown]
# # Two classifiers from the learned BN

# %%
print(bn2.variableFromName("HRSAT"))
print(bn2.variableFromName("INTUBATION"))
# Out:
# HRSAT:Labelized(<HIGH,LOW,NORMAL>)
# INTUBATION:Labelized(<ESOPHAGEAL,NORMAL,ONESIDED>)

# %%
showROC(bn2,"out/train.csv",'HRSAT','LOW',show_progress=False)
showROC(bn2,"out/train.csv",'HRSAT','LOW',show_progress=False)
showROC(bn2,"out/train.csv",'HRSAT','LOW',show_progress=False);

# %%
showROC(bn2,"out/train.csv",'INTUBATION',"ESOPHAGEAL",show_progress=False);

# %%
showPR(bn2,"out/train.csv",'HRSAT','LOW',show_progress=False);

# %%
showPR(bn2,"out/train.csv",'INTUBATION',"ESOPHAGEAL",show_progress=False);

# %%
showROC_PR(bn2,"out/train.csv",'HRSAT','LOW',show_progress=False);

# %%
showROC_PR(bn2,"out/train.csv",'INTUBATION',"ESOPHAGEAL",show_progress=False);
