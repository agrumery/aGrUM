# %% [markdown]
# <a href="http://agrum.org" target="blank"><img src="http://agrum.gitlab.io/theme/img/logoAgrum.png" align="left" style="height:100px"/></a><a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This pyAgrum's notebook is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.

# %%
import os

# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
gnb.configuration()
# Out:
# <table><tr><th>Library</th><th>Version</th></tr><tr><td>OS</td><td>posix [linux]</td></tr><tr><td>Python</td><td>3.10.4 (main, Mar 23 2022, 23:05:40) [GCC 11.2.0]</td></tr><tr><td>IPython</td><td>8.3.0</td></tr><tr><td>Matplotlib</td><td>3.5.2</td></tr><tr><td>Numpy</td><td>1.21.6</td></tr><tr><td>pyDot</td><td>1.4.2</td></tr><tr><td>pyAgrum</td><td>1.1.0</td></tr></table><div align='right'><small>Fri May 13 09:54:57 2022 CEST</small></div>

# %% [markdown]
# # Credal Net from BN

# %%
bn=gum.fastBN("A->B[3]->C<-D<-A->E->F")
bn_min=gum.BayesNet(bn)
bn_max=gum.BayesNet(bn)
for n in bn.nodes():
  x=0.4*min(bn.cpt(n).min(),1-bn.cpt(n).max())
  bn_min.cpt(n).translate(-x)
  bn_max.cpt(n).translate(x)
    
cn=gum.CredalNet(bn_min,bn_max)
cn.intervalToCredal()

gnb.flow.row(bn,bn.cpt("B"),cn,bn_min.cpt("B"),bn_max.cpt("B"),captions=["Bayes Net","CPT","Credal Net","CPTmin","CPTmax"])
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="206pt" height="188pt" viewBox="0.00 0.00 206.00 188.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- B -->
# <g id="node1" class="node">
# <title>B</title>
# <g id="a_node1"><a xlink:title="(1) B">
# <ellipse fill="#404040" stroke="black" cx="27" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">B</text>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node4" class="node">
# <title>C</title>
# <g id="a_node4"><a xlink:title="(2) C">
# <ellipse fill="#404040" stroke="black" cx="63" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">C</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&gt;C -->
# <g id="edge2" class="edge">
# <title>B-&gt;C</title>
# <g id="a_edge2"><a xlink:title="(1, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M35.35,-72.76C39.71,-64.28 45.15,-53.71 50.04,-44.2"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="53.23,-45.64 54.7,-35.15 47.01,-42.44 53.23,-45.64"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g id="node2" class="node">
# <title>A</title>
# <g id="a_node2"><a xlink:title="(0) A">
# <ellipse fill="#404040" stroke="black" cx="99" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">A</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge1" class="edge">
# <title>A-&gt;B</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path fill="none" stroke="#4a4a4a" d="M84.43,-146.83C74.25,-136.94 60.48,-123.55 48.97,-112.36"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="51.41,-109.85 41.8,-105.38 46.53,-114.87 51.41,-109.85"/>
# </a>
# </g>
# </g>
# <!-- E -->
# <g id="node5" class="node">
# <title>E</title>
# <g id="a_node5"><a xlink:title="(4) E">
# <ellipse fill="#404040" stroke="black" cx="171" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="171" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">E</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;E -->
# <g id="edge3" class="edge">
# <title>A-&gt;E</title>
# <g id="a_edge3"><a xlink:title="(0, 4) : ">
# <path fill="none" stroke="#4a4a4a" d="M113.57,-146.83C123.75,-136.94 137.52,-123.55 149.03,-112.36"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="151.47,-114.87 156.2,-105.38 146.59,-109.85 151.47,-114.87"/>
# </a>
# </g>
# </g>
# <!-- D -->
# <g id="node6" class="node">
# <title>D</title>
# <g id="a_node6"><a xlink:title="(3) D">
# <ellipse fill="#404040" stroke="black" cx="99" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">D</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;D -->
# <g id="edge4" class="edge">
# <title>A-&gt;D</title>
# <g id="a_edge4"><a xlink:title="(0, 3) : ">
# <path fill="none" stroke="#4a4a4a" d="M99,-143.7C99,-135.98 99,-126.71 99,-118.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.5,-118.1 99,-108.1 95.5,-118.1 102.5,-118.1"/>
# </a>
# </g>
# </g>
# <!-- F -->
# <g id="node3" class="node">
# <title>F</title>
# <g id="a_node3"><a xlink:title="(5) F">
# <ellipse fill="#404040" stroke="black" cx="171" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="171" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">F</text>
# </a>
# </g>
# </g>
# <!-- E&#45;&gt;F -->
# <g id="edge5" class="edge">
# <title>E-&gt;F</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path fill="none" stroke="#4a4a4a" d="M171,-71.7C171,-63.98 171,-54.71 171,-46.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="174.5,-46.1 171,-36.1 167.5,-46.1 174.5,-46.1"/>
# </a>
# </g>
# </g>
# <!-- D&#45;&gt;C -->
# <g id="edge6" class="edge">
# <title>D-&gt;C</title>
# <g id="a_edge6"><a xlink:title="(3, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M90.65,-72.76C86.29,-64.28 80.85,-53.71 75.96,-44.2"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="78.99,-42.44 71.3,-35.15 72.77,-45.64 78.99,-42.44"/>
# </a>
# </g>
# </g>
# </g>
# </svg><br><center><small><em>Bayes Net</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='3' style='border:1px solid black;color:black;background-color:#808080;'><center>B</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>A</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>2</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#acd164;text-align:right;'>0.6467</td><td style='color:black;background-color:#ec9164;text-align:right;'>0.1475</td><td style='color:black;background-color:#e49964;text-align:right;'>0.2057</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#d6a764;text-align:right;'>0.3166</td><td style='color:black;background-color:#f18c64;text-align:right;'>0.1090</td><td style='color:black;background-color:#b5c864;text-align:right;'>0.5744</td></tr>
# </table><br><center><small><em>CPT</em></small></center></div><div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="206pt" height="188pt" viewBox="0.00 0.00 206.00 188.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- B -->
# <g id="node1" class="node">
# <title>B</title>
# <g id="a_node1"><a xlink:title="(1) B">
# <polygon fill="#404040" stroke="black" points="54,-85.99 48.65,-101.22 27,-108 5.35,-101.22 0,-85.99 14.98,-73.78 39.02,-73.78 54,-85.99"/>
# <text text-anchor="middle" x="27" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">B</text>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node4" class="node">
# <title>C</title>
# <g id="a_node4"><a xlink:title="(2) C">
# <polygon fill="#404040" stroke="black" points="90,-13.99 84.65,-29.22 63,-36 41.35,-29.22 36,-13.99 50.98,-1.78 75.02,-1.78 90,-13.99"/>
# <text text-anchor="middle" x="63" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">C</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&gt;C -->
# <g id="edge2" class="edge">
# <title>B-&gt;C</title>
# <g id="a_edge2"><a xlink:title="(1, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M34.99,-73.46C39.57,-64.55 45.43,-53.17 50.6,-43.12"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="53.82,-44.51 55.28,-34.01 47.59,-41.3 53.82,-44.51"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g id="node2" class="node">
# <title>A</title>
# <g id="a_node2"><a xlink:title="(0) A">
# <polygon fill="#404040" stroke="black" points="126,-157.99 120.65,-173.22 99,-180 77.35,-173.22 72,-157.99 86.98,-145.78 111.02,-145.78 126,-157.99"/>
# <text text-anchor="middle" x="99" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">A</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge1" class="edge">
# <title>A-&gt;B</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path fill="none" stroke="#4a4a4a" d="M84.78,-147.17C74.29,-136.97 59.85,-122.93 48.03,-111.44"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="50.32,-108.79 40.71,-104.33 45.44,-113.81 50.32,-108.79"/>
# </a>
# </g>
# </g>
# <!-- E -->
# <g id="node5" class="node">
# <title>E</title>
# <g id="a_node5"><a xlink:title="(4) E">
# <polygon fill="#404040" stroke="black" points="198,-85.99 192.65,-101.22 171,-108 149.35,-101.22 144,-85.99 158.98,-73.

# %% [markdown]
# #### We can use LBP on CN (L2U) only for binary credal networks (here B is not binary). We then propose the classical binarization (but warn the user that this leads to approximation in the inference)

# %%
cn2=gum.CredalNet(bn_min,bn_max)
cn2.intervalToCredal()
cn2.approximatedBinarization()
cn2.computeBinaryCPTMinMax()

gnb.flow.row(cn,cn2,captions=["Credal net","Binarized credal net"])
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="206pt" height="188pt" viewBox="0.00 0.00 206.00 188.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- B -->
# <g id="node1" class="node">
# <title>B</title>
# <g id="a_node1"><a xlink:title="(1) B">
# <polygon fill="#404040" stroke="black" points="54,-85.99 48.65,-101.22 27,-108 5.35,-101.22 0,-85.99 14.98,-73.78 39.02,-73.78 54,-85.99"/>
# <text text-anchor="middle" x="27" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">B</text>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node4" class="node">
# <title>C</title>
# <g id="a_node4"><a xlink:title="(2) C">
# <polygon fill="#404040" stroke="black" points="90,-13.99 84.65,-29.22 63,-36 41.35,-29.22 36,-13.99 50.98,-1.78 75.02,-1.78 90,-13.99"/>
# <text text-anchor="middle" x="63" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">C</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&gt;C -->
# <g id="edge2" class="edge">
# <title>B-&gt;C</title>
# <g id="a_edge2"><a xlink:title="(1, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M34.99,-73.46C39.57,-64.55 45.43,-53.17 50.6,-43.12"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="53.82,-44.51 55.28,-34.01 47.59,-41.3 53.82,-44.51"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g id="node2" class="node">
# <title>A</title>
# <g id="a_node2"><a xlink:title="(0) A">
# <polygon fill="#404040" stroke="black" points="126,-157.99 120.65,-173.22 99,-180 77.35,-173.22 72,-157.99 86.98,-145.78 111.02,-145.78 126,-157.99"/>
# <text text-anchor="middle" x="99" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">A</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge1" class="edge">
# <title>A-&gt;B</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path fill="none" stroke="#4a4a4a" d="M84.78,-147.17C74.29,-136.97 59.85,-122.93 48.03,-111.44"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="50.32,-108.79 40.71,-104.33 45.44,-113.81 50.32,-108.79"/>
# </a>
# </g>
# </g>
# <!-- E -->
# <g id="node5" class="node">
# <title>E</title>
# <g id="a_node5"><a xlink:title="(4) E">
# <polygon fill="#404040" stroke="black" points="198,-85.99 192.65,-101.22 171,-108 149.35,-101.22 144,-85.99 158.98,-73.78 183.02,-73.78 198,-85.99"/>
# <text text-anchor="middle" x="171" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">E</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;E -->
# <g id="edge3" class="edge">
# <title>A-&gt;E</title>
# <g id="a_edge3"><a xlink:title="(0, 4) : ">
# <path fill="none" stroke="#4a4a4a" d="M113.22,-147.17C123.71,-136.97 138.15,-122.93 149.97,-111.44"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="152.56,-113.81 157.29,-104.33 147.68,-108.79 152.56,-113.81"/>
# </a>
# </g>
# </g>
# <!-- D -->
# <g id="node6" class="node">
# <title>D</title>
# <g id="a_node6"><a xlink:title="(3) D">
# <polygon fill="#404040" stroke="black" points="126,-85.99 120.65,-101.22 99,-108 77.35,-101.22 72,-85.99 86.98,-73.78 111.02,-73.78 126,-85.99"/>
# <text text-anchor="middle" x="99" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">D</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;D -->
# <g id="edge4" class="edge">
# <title>A-&gt;D</title>
# <g id="a_edge4"><a xlink:title="(0, 3) : ">
# <path fill="none" stroke="#4a4a4a" d="M99,-145.46C99,-137.59 99,-127.79 99,-118.68"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.5,-118.46 99,-108.46 95.5,-118.46 102.5,-118.46"/>
# </a>
# </g>
# </g>
# <!-- F -->
# <g id="node3" class="node">
# <title>F</title>
# <g id="a_node3"><a xlink:title="(5) F">
# <polygon fill="#404040" stroke="black" points="198,-13.99 192.65,-29.22 171,-36 149.35,-29.22 144,-13.99 158.98,-1.78 183.02,-1.78 198,-13.99"/>
# <text text-anchor="middle" x="171" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">F</text>
# </a>
# </g>
# </g>
# <!-- E&#45;&gt;F -->
# <g id="edge5" class="edge">
# <title>E-&gt;F</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path fill="none" stroke="#4a4a4a" d="M171,-73.46C171,-65.59 171,-55.79 171,-46.68"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="174.5,-46.46 171,-36.46 167.5,-46.46 174.5,-46.46"/>
# </a>
# </g>
# </g>
# <!-- D&#45;&gt;C -->
# <g id="edge6" class="edge">
# <title>D-&gt;C</title>
# <g id="a_edge6"><a xlink:title="(3, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M91.01,-73.46C86.43,-64.55 80.57,-53.17 75.4,-43.12"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="78.41,-41.3 70.72,-34.01 72.18,-44.51 78.41,-41.3"/>
# </a>
# </g>
# </g>
# </g>
# </svg><br><center><small><em>Credal net</em></small></center></div><div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="360pt" height="226pt" viewBox="0.00 0.00 360.00 226.44">
# <g id="graph0" class="graph" transform="scale(0.870937 0.870937) rotate(0) translate(4 256)">
# <title>G</title>
# <!-- B&#45;v0 -->
# <g id="node1" class="node">
# <title>B-v0</title>
# <g id="a_node1"><a xlink:title="(7) B-v0">
# <polygon fill="#404040" stroke="black" points="70.54,-13.99 63.57,-29.22 35.35,-36 7.12,-29.22 0.15,-13.99 19.68,-1.78 51.01,-1.78 70.54,-13.99"/>
# <text text-anchor="middle" x="35.35" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">B-v0</text>
# </a>
# </g>
# </g>
# <!-- B&#45;b1 -->
# <g id="node2" class="node">
# <title>B-b1</title>
# <g id="a_node2"><a xlink:title="(2) B-b1">
# <polygon fill="#404040" stroke="black" points="147.49,-85.99 140.33,-101.22 111.35,-108 82.37,-101.22 75.21,-85.99 95.26,-73.78 127.43,-73.78 147.49,-85.99"/>
# <text text-anchor="middle" x="111.35" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">B-b1</text>
# </a>
# </g>
# </g>
# <!-- B&#45;b1&#45;&gt;B&#45;v0 -->
# <g id="edge4" class="edge">
# <title>B-b1-&gt;B-v0</title>
# <g id="a_edge4"><a xlink:title="(2, 7) : ">
# <path fill="none" stroke="#4a4a4a" d="M94.86,-73.81C83.97,-63.78 69.57,-50.52 57.66,-39.55"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="59.99,-36.94 50.26,-32.74 55.25,-42.09 59.99,-36.94"/>
# </a>
# </g>
# </g>
# <!-- B&#45;v1 -->
# <g id="node4" class="node">
# <title>B-v1</title>
# <g id="a_node4"><a xlink:title="(8) B-v1">
# <polygon fill="#404040" stroke="black" points="248.54,-13.99 241.57,-29.22 213.35,-36 185.12,-29.22 178.15,-13.99 197.68,-1.78 229.01,-1.78 248.54,-13.99"/>
# <text text-anchor="middle" x="213.35" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">B-v1</text>
# </a>
# </g>
# </g>
# <!-- B&#45;b1&#45;&gt;B&#45;v1 -->
# <g id="edge15" class="edge">
# <title>B-b1-&gt;B-v1</title>
# <g id="a_edge15"><a xlink:title="(2, 8) : ">
# <path fill="none" stroke="#4a4a4a" d="M131.01,-75.5C146.69,-64.74 168.82,-49.56 186.18,-37.64"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="188.51,-40.29 194.77,-31.75 184.55,-34.52 188.51,-40.29"/>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node7" class="node">
# <title>C</title>
# <g id="a_node7"><a xlink:title="(3) C">
# <polygon fill="#404040" stroke="black" points="320.35,-13.99 315,-29.22 293.35,-36 271.7,-29.22 266.35,-13.99 281.33,-1.78 305.36,-1.78 320.35,-13.99"/>
# <text text-anchor="middle" x="293.35" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">C</text>
# </a>
# </g>
# </g>
# <!-- B&#45;b1&#45;&gt;C -->
# <g id="edge7" class="edge">
# <title>B-b1-&gt;C</title>
# <g id="a_edge7"><a xlink:title="(2, 3) : ">
# <path fill="none" stroke="#4a4a4a" d="M138.01,-80.16C167.5,-70.18 216.28,-53.11 257.35,-36 259.17,-35.24 261.03,-34.44 262.9,-33.62"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="264.52,-36.73 272.17,-29.4 261.62,-30.35 264.52,-36.73"/>
# </a>
# </g>
# </g>
# <!-- B&#45;v2 -->
# <g id="node9" class="node">
# <title>B-v2</title>
# <g id="a_node9"><a xlink:title="(9) B-v2">
# <polygon fill="#404040" stroke="black" points="159.54,-13.99 152.57,-29.22 124.35,-36 96.12,-29.22 89.15,-13.99 108.68,-1.78 140.01,-1.78 159.54,-13.99"/>
# <text text-anchor="middle" x="124.35" y="-14.3" font-family=

# %% [markdown]
# Here, $B$ becomes
# - $B$-b$i$ : the $i$-th bit of B
# - instrumental $B$-v$k$ : the indicator variable for each modality $k$ of $B$

# %%
ie_mc=gum.CNMonteCarloSampling(cn)
ie2_lbp=gum.CNLoopyPropagation(cn2)
ie2_mc=gum.CNMonteCarloSampling(cn2)

# %%
gnb.sideBySide(gnb.getInference(cn,engine=ie_mc),
               gnb.getInference(cn2,engine=ie2_mc),
               gnb.getInference(cn2,engine=ie2_lbp))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="347pt" height="237pt" viewBox="0.00 0.00 347.00 237.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 233)">
# <title>structs</title>
# <text text-anchor="middle" x="169.5" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in 60006.58ms</text>
# <!-- A -->
# <g id="node1" class="node">
# <title>A</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="220,-229 119,-229 119,-188 220,-188 220,-229"/>
# <svg viewBox="0 0 132.1625 52.998125" width="101px" height="41px" preserveAspectRatio="xMinYMin meet" x="119" y="-229"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2022-05-13T09:55:57.545562</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.5.2, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 52.998125  L 132.1625 52.998125  L 132.1625 0  L 0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 45.898125  L 128.5625 45.898125  L 128.5625 18.718125  L 16.9625 18.718125  z " style="fill: #ffffff"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 16.9625 45.898125  L 119.215003 45.898125  L 119.215003 33.818125  L 16.9625 33.818125  z " clip-path="url(#pf55a47cf37)" style="fill: #bbffaa"/>
#    </g>
#    <g id="patch_4">
#     <path d="M 16.9625 30.798125  L 38.773056 30.798125  L 38.773056 18.718125  L 16.9625 18.718125  z " clip-path="url(#pf55a47cf37)" style="fill: #bbffaa"/>
#    </g>
#    <g id="patch_5">
#     <path d="M 16.9625 45.898125  L 106.751944 45.898125  L 106.751944 33.818125  L 16.9625 33.818125  z " clip-path="url(#pf55a47cf37)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="patch_6">
#     <path d="M 16.9625 30.798125  L 26.309997 30.798125  L 26.309997 18.718125  L 16.9625 18.718125  z " clip-path="url(#pf55a47cf37)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path d="M 16.9625 45.898125  L 16.9625 18.718125  " clip-path="url(#pf55a47cf37)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path id="mccee563914" d="M 0 0  L 0 3.5  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#mccee563914" x="16.9625" y="45.898125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path d="M 72.7625 45.898125  L 72.7625 18.718125  " clip-path="url(#pf55a47cf37)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use xlink:href="#mccee563914" x="72.7625" y="45.898125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path d="M 128.5625 45.898125  L 128.5625 18.718125  " clip-path="url(#pf55a47cf37)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use xlink:href="#mccee563914" x="128.5625" y="45.898125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path id="m8abd0ea1fc" d="M 0 0  L -3.5 0  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#m8abd0ea1fc" x="16.9625" y="39.858125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 1 -->
#       <g transform="translate(3.6 43.657344)scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-31" d="M 794 531  L 1825 531  L 1825 4091  L 703 3866  L 703 4441  L 1819 4666  L 2450 4666  L 2450 531  L 3481 531  L 3481 0  L 794 0  L 794 531  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-31"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_2">
#      <g id="line2d_8">
#       <g>
#        <use xlink:href="#m8abd0ea1fc" x="16.9625" y="24.758125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 0 -->
#       <g transform="translate(3.6 28.557344)scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-30" d="M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="patch_7">
#     <path d="M 16.9625 45.898125  L 16.9625 18.718125  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="patch_8">
#     <path d="M 128.5625 45.898125  L 128.5625 18.718125  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="patch_9">
#     <path d="M 16.9625 45.898125  L 128.5625 45.898125  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="patch_10">
#     <path d="M 16.9625 18.718125  L 128.5625 18.718125  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id
# <A:1> : [[0.272995 , 0.108987 , 0.618018] , [0.272995 , 0.152582 , 0.574423] , [0.316589 , 0.152582 , 0.530829] , [0.360184 , 0.108987 , 0.530829] , [0.31659 , 0.0653924 , 0.618018] , [0.360184 , 0.0653924 , 0.574424]]
#
# C:Range([0,1])
# <B:0|D:0> : [[0.500982 , 0.499018] , [0.513663 , 0.486337]]
# <B:1|D:0> : [[0.418886 , 0.581114] , [0.431566 , 0.568434]]
# <B:2|D:0> : [[0.114657 , 0.885343] , [0.127336 , 0.872664]]
# <B:0|D:1> : [[0.977811 , 0.0221893] , [0.990491 , 0.00950872]]
# <B:1|D:1> : [[0.143169 , 0.856831] , [0.155849 , 0.844151]]
# <B:2|D:1> : [[0.62924 , 0.37076] , [0.641919 , 0.358081]]
#
# D:Range([0,1])
# <A:0> : [[0.593434 , 0.406566] , [0.783228 , 0.216772]]
# <A:1> : [[0.142344 , 0.857656] , [0.332139 , 0.667861]]
#
# E:Range([0,1])
# <A:0> : [[0.209976 , 0.790024] , [0.489943 , 0.510057]]
# <A:1> : [[0.389381 , 0.610619] , [0.669348 , 0.330652]]
#
# F:Range([0,1])
# <E:0> : [[0.251754 , 0.748246] , [0.479112 , 0.520888]]
# <E:1> : [[0.602119 , 0.397881] , [0.82948 , 0.17052]]

# %% [markdown]
# ## Credal Net from bif files

# %%
cn=gum.CredalNet("res/cn/2Umin.bif","res/cn/2Umax.bif")
cn.intervalToCredal()

# %%
gnb.showCN(cn,"2")

# %%
ie=gum.CNMonteCarloSampling(cn)
ie.insertEvidenceFile("res/cn/L2U.evi")

# %%
ie.setRepetitiveInd(False)
ie.setMaxTime(1)
ie.setMaxIter(1000)

ie.makeInference()

# %%
gnb.flow.row(cn,gnb.getInference(cn,targets={"A","H","L","D"},engine=ie,evs={"L":[0,1],"G":[1,0]}))
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="278pt" height="260pt" viewBox="0.00 0.00 278.00 260.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 256)">
# <title>G</title>
# <!-- B -->
# <g id="node1" class="node">
# <title>B</title>
# <g id="a_node1"><a xlink:title="(1) B">
# <polygon fill="#404040" stroke="black" points="54,-229.99 48.65,-245.22 27,-252 5.35,-245.22 0,-229.99 14.98,-217.78 39.02,-217.78 54,-229.99"/>
# <text text-anchor="middle" x="27" y="-230.3" font-family="Times,serif" font-size="14.00" fill="white">B</text>
# </a>
# </g>
# </g>
# <!-- E -->
# <g id="node7" class="node">
# <title>E</title>
# <g id="a_node7"><a xlink:title="(4) E">
# <polygon fill="#404040" stroke="black" points="126,-157.99 120.65,-173.22 99,-180 77.35,-173.22 72,-157.99 86.98,-145.78 111.02,-145.78 126,-157.99"/>
# <text text-anchor="middle" x="99" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">E</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&gt;E -->
# <g id="edge3" class="edge">
# <title>B-&gt;E</title>
# <g id="a_edge3"><a xlink:title="(1, 4) : ">
# <path fill="none" stroke="#4a4a4a" d="M41.22,-219.17C51.71,-208.97 66.15,-194.93 77.97,-183.44"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="80.56,-185.81 85.29,-176.33 75.68,-180.79 80.56,-185.81"/>
# </a>
# </g>
# </g>
# <!-- H -->
# <g id="node2" class="node">
# <title>H</title>
# <g id="a_node2"><a xlink:title="(7) H">
# <polygon fill="#404040" stroke="black" points="162,-85.99 156.65,-101.22 135,-108 113.35,-101.22 108,-85.99 122.98,-73.78 147.02,-73.78 162,-85.99"/>
# <text text-anchor="middle" x="135" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">H</text>
# </a>
# </g>
# </g>
# <!-- L -->
# <g id="node3" class="node">
# <title>L</title>
# <g id="a_node3"><a xlink:title="(8) L">
# <polygon fill="#404040" stroke="black" points="162,-13.99 156.65,-29.22 135,-36 113.35,-29.22 108,-13.99 122.98,-1.78 147.02,-1.78 162,-13.99"/>
# <text text-anchor="middle" x="135" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">L</text>
# </a>
# </g>
# </g>
# <!-- H&#45;&gt;L -->
# <g id="edge4" class="edge">
# <title>H-&gt;L</title>
# <g id="a_edge4"><a xlink:title="(7, 8) : ">
# <path fill="none" stroke="#4a4a4a" d="M135,-73.46C135,-65.59 135,-55.79 135,-46.68"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="138.5,-46.46 135,-36.46 131.5,-46.46 138.5,-46.46"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g id="node4" class="node">
# <title>A</title>
# <g id="a_node4"><a xlink:title="(0) A">
# <polygon fill="#404040" stroke="black" points="126,-229.99 120.65,-245.22 99,-252 77.35,-245.22 72,-229.99 86.98,-217.78 111.02,-217.78 126,-229.99"/>
# <text text-anchor="middle" x="99" y="-230.3" font-family="Times,serif" font-size="14.00" fill="white">A</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;E -->
# <g id="edge1" class="edge">
# <title>A-&gt;E</title>
# <g id="a_edge1"><a xlink:title="(0, 4) : ">
# <path fill="none" stroke="#4a4a4a" d="M99,-217.46C99,-209.59 99,-199.79 99,-190.68"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.5,-190.46 99,-180.46 95.5,-190.46 102.5,-190.46"/>
# </a>
# </g>
# </g>
# <!-- F -->
# <g id="node5" class="node">
# <title>F</title>
# <g id="a_node5"><a xlink:title="(5) F">
# <polygon fill="#404040" stroke="black" points="198,-157.99 192.65,-173.22 171,-180 149.35,-173.22 144,-157.99 158.98,-145.78 183.02,-145.78 198,-157.99"/>
# <text text-anchor="middle" x="171" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">F</text>
# </a>
# </g>
# </g>
# <!-- F&#45;&gt;H -->
# <g id="edge2" class="edge">
# <title>F-&gt;H</title>
# <g id="a_edge2"><a xlink:title="(5, 7) : ">
# <path fill="none" stroke="#4a4a4a" d="M163.01,-145.46C158.43,-136.55 152.57,-125.17 147.4,-115.12"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="150.41,-113.3 142.72,-106.01 144.18,-116.51 150.41,-113.3"/>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node6" class="node">
# <title>C</title>
# <g id="a_node6"><a xlink:title="(2) C">
# <polygon fill="#404040" stroke="black" points="198,-229.99 192.65,-245.22 171,-252 149.35,-245.22 144,-229.99 158.98,-217.78 183.02,-217.78 198,-229.99"/>
# <text text-anchor="middle" x="171" y="-230.3" font-family="Times,serif" font-size="14.00" fill="white">C</text>
# </a>
# </g>
# </g>
# <!-- C&#45;&gt;F -->
# <g id="edge6" class="edge">
# <title>C-&gt;F</title>
# <g id="a_edge6"><a xlink:title="(2, 5) : ">
# <path fill="none" stroke="#4a4a4a" d="M171,-217.46C171,-209.59 171,-199.79 171,-190.68"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="174.5,-190.46 171,-180.46 167.5,-190.46 174.5,-190.46"/>
# </a>
# </g>
# </g>
# <!-- E&#45;&gt;H -->
# <g id="edge7" class="edge">
# <title>E-&gt;H</title>
# <g id="a_edge7"><a xlink:title="(4, 7) : ">
# <path fill="none" stroke="#4a4a4a" d="M106.99,-145.46C111.57,-136.55 117.43,-125.17 122.6,-115.12"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="125.82,-116.51 127.28,-106.01 119.59,-113.3 125.82,-116.51"/>
# </a>
# </g>
# </g>
# <!-- D -->
# <g id="node8" class="node">
# <title>D</title>
# <g id="a_node8"><a xlink:title="(3) D">
# <polygon fill="#404040" stroke="black" points="270,-229.99 264.65,-245.22 243,-252 221.35,-245.22 216,-229.99 230.98,-217.78 255.02,-217.78 270,-229.99"/>
# <text text-anchor="middle" x="243" y="-230.3" font-family="Times,serif" font-size="14.00" fill="white">D</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&gt;F -->
# <g id="edge8" class="edge">
# <title>D-&gt;F</title>
# <g id="a_edge8"><a xlink:title="(3, 5) : ">
# <path fill="none" stroke="#4a4a4a" d="M228.78,-219.17C218.29,-208.97 203.85,-194.93 192.03,-183.44"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="194.32,-180.79 184.71,-176.33 189.44,-185.81 194.32,-180.79"/>
# </a>
# </g>
# </g>
# <!-- G -->
# <g id="node9" class="node">
# <title>G</title>
# <g id="a_node9"><a xlink:title="(6) G">
# <polygon fill="#404040" stroke="black" points="270,-157.99 264.65,-173.22 243,-180 221.35,-173.22 216,-157.99 230.98,-145.78 255.02,-145.78 270,-157.99"/>
# <text text-anchor="middle" x="243" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">G</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&gt;G -->
# <g id="edge5" class="edge">
# <title>D-&gt;G</title>
# <g id="a_edge5"><a xlink:title="(3, 6) : ">
# <path fill="none" stroke="#4a4a4a" d="M243,-217.46C243,-209.59 243,-199.79 243,-190.68"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="246.5,-190.46 243,-180.46 239.5,-190.46 246.5,-190.46"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div><div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="373pt" height="298pt" viewBox="0.00 0.00 373.00 298.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 294)">
# <title>structs</title>
# <text text-anchor="middle" x="182.5" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in 1402.86ms</text>
# <!-- A -->
# <g id="node1" class="node">
# <title>A</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="101,-290 0,-290 0,-249 101,-249 101,-290"/>
# <svg viewBox="0 0 132.1625 52.998125" width="101px" height="41px" preserveAspectRatio="xMinYMin meet" x="0" y="-290"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2022-05-13T09:57:02.356543</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.5.2, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 52.998125  L 132.1625 52.998125  L 132.1625 0  L 0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="p

# %% [markdown]
# # Comparing inference in credal networks

# %%
import pyAgrum as gum

def showDiffInference(model,mc,lbp):
    for i in model.current_bn().nodes():
        a,b=mc.marginalMin(i)[:]
        c,d=mc.marginalMax(i)[:]
        
        e,f=lbp.marginalMin(i)[:]
        g,h=lbp.marginalMax(i)[:]
        
        plt.scatter([a,b,c,d],[e,f,g,h])
        

cn=gum.CredalNet("res/cn/2Umin.bif","res/cn/2Umax.bif")
cn.intervalToCredal()

# %% [markdown]
# #### The two inference give quite the same result

# %%
ie_mc=gum.CNMonteCarloSampling(cn)
ie_mc.makeInference()

cn.computeBinaryCPTMinMax()
ie_lbp=gum.CNLoopyPropagation(cn)
ie_lbp.makeInference()

showDiffInference(cn,ie_mc,ie_lbp)

# %% [markdown]
# #### but not when evidence are inserted

# %%
ie_mc=gum.CNMonteCarloSampling(cn)
ie_mc.insertEvidenceFile("res/cn/L2U.evi")
ie_mc.makeInference()

ie_lbp=gum.CNLoopyPropagation(cn)
ie_lbp.insertEvidenceFile("res/cn/L2U.evi")
ie_lbp.makeInference()

showDiffInference(cn,ie_mc,ie_lbp)

# %% [markdown]
# ## Dynamical Credal Net

# %%
cn=gum.CredalNet("res/cn/bn_c_8.bif","res/cn/den_c_8.bif")
cn.bnToCredal(0.8,False)

# %%
ie=gum.CNMonteCarloSampling(cn)
ie.insertModalsFile("res/cn/modalities.modal")

ie.setRepetitiveInd(True)
ie.setMaxTime(5)
ie.setMaxIter(1000)

ie.makeInference()

# %%
print(ie.dynamicExpMax("temp"))
# Out:
# (14.203404647522472, 11.669951317919612, 12.10019505553209, 11.99476087981647, 11.964516312727358, 11.941414476248845, 11.94838537443891, 11.945414782442136, 11.946445491630861)

# %%
fig=figure()
ax=fig.add_subplot(111)
ax.fill_between(range(9),ie.dynamicExpMax("temp"),ie.dynamicExpMin("temp"))

# %%
ie=gum.CNMonteCarloSampling(cn)
ie.insertModalsFile("res/cn/modalities.modal")

ie.setRepetitiveInd(False)
ie.setMaxTime(5)
ie.setMaxIter(1000)

ie.makeInference()
print(ie.messageApproximationScheme())
# Out:
# stopped with timeout=5

# %%
fig=figure()
ax=fig.add_subplot(111)
ax.fill_between(range(9),ie.dynamicExpMax("temp"),ie.dynamicExpMin("temp"))

# %%
ie=gum.CNMonteCarloSampling(cn)
ie.insertModalsFile("res/cn/modalities.modal")

ie.setRepetitiveInd(False)
ie.setMaxTime(5)
ie.setMaxIter(5000)

gnb.animApproximationScheme(ie)
ie.makeInference()

# %%
fig=figure()
ax=fig.add_subplot(111)
ax.fill_between(range(9),ie.dynamicExpMax("temp"),ie.dynamicExpMin("temp"));
