# %% [markdown]
# <a href="http://agrum.org" target="blank"><img src="http://agrum.gitlab.io/theme/img/logoAgrum.png" align="left" style="height:100px"/></a><a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This pyAgrum's notebook is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.

# %%
# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt

import os

# %% [markdown]
# Initialisation
# ==============
#
# * importing pyAgrum
# * importing pyAgrum.lib tools
# * loading a BN

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
gnb.configuration()
# Out:
# <table width='100%'><tr><th>Library</th><th>Version</th></tr><tr><td>OS</td><td>nt [win32]</td></tr><tr><td>Python</td><td>3.9.2 (tags/v3.9.2:1a79785, Feb 19 2021, 13:44:55) [MSC v.1928 64 bit (AMD64)]</td></tr><tr><td>IPython</td><td>7.22.0</td></tr><tr><td>MatPlotLib</td><td>3.4.1</td></tr><tr><td>Numpy</td><td>1.20.2</td></tr><tr><td>pyAgrum</td><td>0.19.3.9</td></tr></table><div align='right'><small>Fri Apr 02 22:21:11 2021 Paris, Madrid (heure d’été)</small></div>

# %%
bn=gum.loadBN(os.path.join("res","alarm.dsl"))
gnb.showBN(bn,size='10')

# %% [markdown]
# Visualisation and inspection
# ============================

# %%
print(bn.variableFromName('SHUNT'))
# Out:
# SHUNT<NORMAL,HIGH>

# %%
print(bn.cpt(bn.idFromName('SHUNT')))
# Out:
#              ||  SHUNT            |
# PULMEM|INTUBA||NORMAL   |HIGH     |
# ------|------||---------|---------|
# TRUE  |NORMAL|| 0.1000  | 0.9000  |
# FALSE |NORMAL|| 0.9500  | 0.0500  |
# TRUE  |ESOPHA|| 0.1000  | 0.9000  |
# FALSE |ESOPHA|| 0.9500  | 0.0500  |
# TRUE  |ONESID|| 0.0100  | 0.9900  |
# FALSE |ONESID|| 0.0500  | 0.9500  |

# %%
gnb.showPotential(bn.cpt(bn.idFromName('SHUNT')),digits=3)
# Out:
# <table style="border:1px solid black;"><tr><th colspan='2'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>SHUNT</center></th></tr><tr><th style='border:1px solid black;color:black;background-color:#808080'><center>INTUBATION</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PULMEMBOLUS</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>NORMAL</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>HIGH</center></th></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>NORMAL</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>TRUE</center></th><td style='color:black;background-color:#f28b64;text-align:right;'>0.100</td><td style='color:black;background-color:#8bf264;text-align:right;'>0.900</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>FALSE</center></th><td style='color:black;background-color:#85f864;text-align:right;'>0.950</td><td style='color:black;background-color:#f88564;text-align:right;'>0.050</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>ESOPHAGEAL</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>TRUE</center></th><td style='color:black;background-color:#f28b64;text-align:right;'>0.100</td><td style='color:black;background-color:#8bf264;text-align:right;'>0.900</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>FALSE</center></th><td style='color:black;background-color:#85f864;text-align:right;'>0.950</td><td style='color:black;background-color:#f88564;text-align:right;'>0.050</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>ONESIDED</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>TRUE</center></th><td style='color:black;background-color:#fd8064;text-align:right;'>0.010</td><td style='color:black;background-color:#80fd64;text-align:right;'>0.990</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>FALSE</center></th><td style='color:black;background-color:#f88564;text-align:right;'>0.050</td><td style='color:black;background-color:#85f864;text-align:right;'>0.950</td></tr></table>

# %% [markdown]
# Results of inference
# ====================
#
# It is easy to look at result of inference

# %%
gnb.showPosterior(bn,{'SHUNT':'HIGH'},'PRESS')

# %%
gnb.showPosterior(bn,{'MINVOLSET':'NORMAL'},'VENTALV')

# %% [markdown]
# Overall results

# %%
gnb.showInference(bn,size="10")

# %% [markdown]
# What is the impact of observed variables (SHUNT and VENTALV for instance) on another on (PRESS) ?

# %%
ie=gum.LazyPropagation(bn)
ie.evidenceImpact('PRESS',['SHUNT','VENTALV'])
# Out:
# (gum::Potential<double>@000001CFFB39E270)
#              ||  PRESS                                |
# VENTAL|SHUNT ||ZERO     |LOW      |NORMAL   |HIGH     |
# ------|------||---------|---------|---------|---------|
# ZERO  |NORMAL|| 0.0569  | 0.2669  | 0.2005  | 0.4757  |
# LOW   |NORMAL|| 0.0208  | 0.2515  | 0.0553  | 0.6724  |
# NORMAL|NORMAL|| 0.0769  | 0.3267  | 0.1772  | 0.4192  |
# HIGH  |NORMAL|| 0.0501  | 0.1633  | 0.2796  | 0.5071  |
# ZERO  |HIGH  || 0.0589  | 0.2726  | 0.1997  | 0.4688  |
# LOW   |HIGH  || 0.0318  | 0.2237  | 0.0521  | 0.6924  |
# NORMAL|HIGH  || 0.1735  | 0.5839  | 0.1402  | 0.1024  |
# HIGH  |HIGH  || 0.0711  | 0.2347  | 0.2533  | 0.4410  |

# %% [markdown]
# Using inference as a function
# ====================
#
# It is also easy to use inference as a routine in more complex procedures.

# %%
import time
r=range(0,100,2)
xs=[x/100.0 for x in r]

tf=time.time()
ys=[gum.getPosterior(bn,{'MINVOLSET':[0,x/100.0,0.5]},'VENTALV').tolist() 
        for x in r]
delta=time.time()-tf

p=plot(xs,ys)
legend(p,[bn.variableFromName('VENTALV').label(i) 
          for i in range(bn.variableFromName('VENTALV').domainSize())],loc=7);
title('VENTALV (100 inferences in %d ms)'%delta);
ylabel('posterior Probability');
xlabel('Evidence on MINVOLSET : [0,x,0.5]')
plt.show()

# %% [markdown]
# Another example : python gives access to a large set of tools. Here the value for the equality of two probabilities of a posterior is easely computed.

# %%
x=[p/100.0 for p in range(0,100)]

tf=time.time()
y=[gum.getPosterior(bn,{'HRBP':[1.0-p/100.0,1.0-p/100.0,p/100.0]},'TPR').tolist() 
   for p in range(0,100)]
delta=time.time()-tf

p=plot(x,y)
title('HRBP (100 inferences in %d ms)'%delta);
v=bn.variableFromName('TPR');
legend([v.label(i) for i in range(v.domainSize())],loc='best');
np1=(transpose(y)[0]>transpose(y)[2]).argmin()
text(x[np1]-0.05,y[np1][0]+0.005,str(x[np1]),bbox=dict(facecolor='red', alpha=0.1))
plt.show()

# %% [markdown]
# BN as a classifier
# ================

# %% [markdown]
# Generation of databases
# -----------------------
#
# Using the CSV format for the database:

# %%
gum.generateCSV(bn,os.path.join("out","test.csv"),1000,with_labels=True)
# Out:
# -14670.812086397971

# %%
from pyAgrum.lib._utils import oslike
oslike.head(os.path.join("out",'test.csv'))
# Out:
# MINVOL,EXPCO2,PVSAT,FIO2,ERRLOWOUTPUT,HREKG,CATECHOL,SHUNT,VENTLUNG,ERRCAUTER,INSUFFANESTH,CO,PAP,INTUBATION,LVFAILURE,VENTALV,MINVOLSET,HYPOVOLEMIA,HISTORY,ANAPHYLAXIS,PULMEMBOLUS,HRSAT,KINKEDTUBE,ARTCO2,STROKEVOLUME,PCWP,VENTTUBE,CVP,HRBP,TPR,DISCONNECT,HR,VENTMACH,SAO2,LVEDVOLUME,BP,PRESS
# ZERO,LOW,LOW,NORMAL,FALSE,HIGH,HIGH,NORMAL,ZERO,FALSE,TRUE,HIGH,NORMAL,NORMAL,FALSE,ZERO,NORMAL,FALSE,FALSE,FALSE,FALSE,HIGH,FALSE,HIGH,NORMAL,NORMAL,LOW,NORMAL,HIGH,NORMAL,FALSE,HIGH,NORMAL,LOW,NORMAL,HIGH,LOW
# ZERO,LOW,LOW,NORMAL,FALSE,HIGH,HIGH,NORMAL,ZERO,FALSE,FALSE,HIGH,NORMAL,NORMAL,FALSE,ZERO,LOW,FALSE,FALSE,FALSE,FALSE,HIGH,FALSE,HIGH,NORMAL,NORMAL,ZERO,LOW,HIGH,HIGH,FALSE,HIGH,LOW,LOW,NORMAL,HIGH,ZERO
# LOW,HIGH,NORMAL,NORMAL,FALSE,HIGH,HIGH,NORMAL,HIGH,FALSE,FALSE,HIGH,NORMAL,NORMAL,FALSE,LOW,NORMAL,TRUE,FALSE,FALSE,FALSE,HIGH,TRUE,HIGH,LOW,HIGH,LOW,NORMAL,HIGH,NORMAL,FALSE,HIGH,NORMAL,LOW,HIGH,HIGH,HIGH
# ZERO,LOW,LOW,NORMAL,FALSE,HIGH,HIGH,NORMAL,ZERO,FALSE,FALSE,HIGH,NORMAL,NORMAL,FALSE,ZERO,NORMAL,FALSE,FALSE,FALSE,FALSE,HIGH,FALSE,HIGH,NORMAL,NORMAL,LOW,NORMAL,HIGH,NORMAL,FALSE,HIGH,NORMAL,LOW,NORMAL,HIGH,HIGH
# ZERO,LOW,LOW,NORMAL,TRUE,LOW,HIGH,NORMAL,ZERO,TRUE,FALSE,HIGH,NORMAL,NORMAL,FALSE,ZERO,NORMAL,FALSE,FALSE,FALSE,FALSE,HIGH,FALSE,HIGH,NORMAL,NORMAL,LOW,NORMAL,LOW,NORMAL,FALSE,HIGH,NORMAL,LOW,NORMAL,NORMAL,LOW
# ZERO,LOW,LOW,NORMAL,FALSE,HIGH,HIGH,NORMAL,ZERO,FALSE,FALSE,HIGH,NORMAL,NORMAL,FALSE,ZERO,NORMAL,FALSE,FALSE,FALSE,FALSE,HIGH,FALSE,HIGH,HIGH,NORMAL,ZERO,NORMAL,HIGH,NORMAL,TRUE,HIGH,NORMAL,LOW,NORMAL,HIGH,LOW
# ZERO,LOW,LOW,NORMAL,FALSE,HIGH,HIGH,NORMAL,ZERO,FALSE,FALSE,HIGH,NORMAL,NORMAL,FALSE,ZERO,NORMAL,FALSE,FALSE,FALSE,FALSE,HIGH,FALSE,HIGH,NORMAL,NORMAL,LOW,NORMAL,HIGH,HIGH,FALSE,HIGH,NORMAL,LOW,NORMAL,HIGH,NORMAL
# ZERO,LOW,LOW,LOW,FALSE,LOW,HIGH,NORMAL,ZERO,FALSE,TRUE,LOW,NORMAL,NORMAL,TRUE,ZERO,NORMAL,TRUE,TRUE,FALSE,FALSE,LOW,FALSE,HIGH,LOW,LOW,LOW,LOW,LOW,NORMAL,FALSE,NORMAL,NORMAL,LOW,LOW,LOW,HIGH
# ZERO,LOW,LOW,NORMAL,FALSE,HIGH,HIGH,NORMAL,ZERO,FALSE,FALSE,HIGH,NORMAL,NORMAL,FALSE,ZERO,NORMAL,FALSE,FALSE,FALSE,FALSE,HIGH,FALSE,HIGH,NORMAL,NORMAL,LOW,NORMAL,HIGH,HIGH,FALSE,HIGH,NORMAL,LOW,NORMAL,HIGH,NORMAL

# %% [markdown]
# BN as a classifier
# ------------------
#
# (because of the use of from-bn-generated csv files, quite good ROC curves are expected)

# %%
from pyAgrum.lib.bn2roc import showROC_PR

showROC_PR(bn,os.path.join("out","test.csv"),
        target='CATECHOL',label='HIGH',  # class and label 
        show_progress=True,show_fig=True,with_labels=True)
# Out:
#  out\test.csv : [ ############################################################ ] 100%
# (0.9739732402559628, 0.8384562795999999, 0.9987377693155188, 0.34813415895)

# %% [markdown]
# Using another class variable

# %%
showROC_PR(bn,os.path.join("out","test.csv"),'SAO2','HIGH',show_progress=True)
# Out:
#  out\test.csv : [ ############################################################ ] 100%
# (0.2741632513661203,
#  0.010294167391823879,
#  0.021381973925438075,
#  0.012257517612538345)

# %% [markdown]
# # Fast prototyping for BNs

# %%
bn1=gum.fastBN("a->b;a->c;b->c;c->d",3)

gnb.sideBySide(*[gnb.getInference(bn1,evs={'c':val},targets={'a','c','d'}) for val in range(3)],
              captions=["<pre>Inference given that c={}</pre>".format(val) for val in range(3)])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="142pt" height="360pt" viewBox="0.00 0.00 141.61 360.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 357)">
# <title>structs</title>
# <text text-anchor="middle" x="67" y="-7.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.00ms</text>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="119.25,-353 18.25,-353 18.25,-291 119.25,-291 119.25,-353"/>
# <svg viewBox="0 0 132.1625 80.0255" width="101px" height="62px" preserveAspectRatio="xMinYMin meet" x="18.25" y="-353"> <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-04-02T22:21:18.614940</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.4.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 80.0255  L 132.1625 80.0255  L 132.1625 0  L 0 0  z " style="fill:#e0e0e0;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 72.9255  L 128.5625 72.9255  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:#ffffff;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p0f6ce4146c)" d="M 16.9625 72.9255  L 46.505563 72.9255  L 46.505563 61.276929  L 16.9625 61.276929  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p0f6ce4146c)" d="M 16.9625 58.364786  L 63.001542 58.364786  L 63.001542 46.716214  L 16.9625 46.716214  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#p0f6ce4146c)" d="M 16.9625 43.804071  L 52.980395 43.804071  L 52.980395 32.1555  L 16.9625 32.1555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p0f6ce4146c)" d="M 16.9625 72.9255  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="m2b449cf261" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m2b449cf261" y="72.9255"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p0f6ce4146c)" d="M 72.7625 72.9255  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#m2b449cf261" y="72.9255"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p0f6ce4146c)" d="M 128.5625 72.9255  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="128.5625" xlink:href="#m2b449cf261" y="72.9255"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path d="M 0 0  L -3.5 0  " id="m1570b2b61c" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m1570b2b61c" y="67.101214"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 2 -->
#       <g transform="translate(3.6 70.900433)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 1228 531  L 3431 531  L 3431 0  L 469 0  L 469 531  Q 828 903 1448 1529  Q 2069 2156 2228 2338  Q 2531 2678 2651 2914  Q 2772 3150 2772 3378  Q 2772 3750 2511 3984  Q 2250 4219 1831 4219  Q 1534 4219 1204 4116  Q 875 4013 500 3803  L 500 4441  Q 881 4594 1212 4672  Q 1544 4750 1819 4750  Q 2544 4750 2975 4387  Q 3406 4025 3406 3419  Q 3406 3131 3298 2873  Q 3191 2616 2906 2266  Q 2828 2175 2409 1742  Q 1991 1309 1228 531  z " id="DejaVuSans-32" transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-32"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_2">
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m1570b2b61c" y="52.5405"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 1 -->
#       <g transform="translate(3.6 56.339719)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 794 531  L 1825 531  L 1825 4091  L 703 3866  L 703 4441  L 1819 4666  L 2450 4666  L 2450 531  L 3481 531  L 3481 0  L 794 0  L 794 531  z " id="DejaVuSans-31" transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-31"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_3">
#      <g id="line2d_9">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m1570b2b61c" y="37.979786"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 0 -->
#       <g transform="translate(3.6 41.779004)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z " id="DejaVuSans-30" transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="patch_6">
#     <path d="M 16.9625 72.9255  L 16.9625 32.1555  " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="patch_7">
#     <path d="M 128.5625 72.9255  L 128.5625 32.1555  " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="patch_8">
#     <path d="M 16.9625 72.9255  L 128.5625 72.9255  " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="patch_9">
#     <path d="M 16.9625 32.1555  L 128.5625 32.1555  " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="text_4">
#     <!-- 0.26 -->
#     <g transform="translate(106.296875 70.845813)scale(0.1 -0.1)">
#      <defs>
#       <path d="M 684 794  L 1344 794  L 1344 0  L 684 0  L 684 794  z " id="DejaVuSans-2e" transform="scale(0.015625)"/>
#       <path d="M 2113 2584  Q 1688 2584 1439 2293  Q 1191 2003 1191 1497  Q 1191 994 1439 701  Q 1688 409 2113 409  Q 2538 409 2786 701  Q 3034 994 3034 1497  Q 3034 2003 2786 2293  Q 2538 2584 2113 2584  z M 3366 4563  L 3366 3988  Q 3128 4100 2886 4159  Q 2644 4219 2406 4219  Q 1781 4219 1451 3797  Q 1122 3375 1075 2522  Q 1259 2794 1537 2939  Q 1816 3084 2150 3084  Q 2853 3084 3261 2657  Q 3669 2231 3669 1497  Q 3669 778 3244 343  Q 2819 -91 2113 -91  Q 1303 -91 875 529  Q 447 1150 447 2328  Q 447 3434 972 4092  Q 1497 4750 2381 4750  Q 2619 4750 2861 4703  Q 3103 4656 3366 4563  z " id="DejaVuSans-36" transform="scale(0.015625)"/>
#      </defs>
#      <use xlink:href="#DejaVuSans-30"/>
#      <use x="63.623047" xlink:href="#DejaVuSans-2e"/>
#      <use x="95.410156" xlink:href="#DejaVuSans-32"/>
#      <use x="159.033203" xlink:href="#DejaVuSans-36"/>
#     </g>
#    </g>
#    <g id="text_5">
#     <!-- 0.41 -->
#     <g transform="translate(106.296875 56.285098)sca

# %%
print(gum.getPosterior(bn1,evs={'c':0},target='c'))
print(gum.getPosterior(bn1,evs={'c':0},target='a'))
# Out:
#   c                          |
# 0        |1        |2        |
# ---------|---------|---------|
#  1.0000  | 0.0000  | 0.0000  |
#
#
#   a                          |
# 0        |1        |2        |
# ---------|---------|---------|
#  0.3227  | 0.4125  | 0.2647  |

# %% [markdown]
# # Joint posterior, impact of multiple evidence

# %%
bn=gum.fastBN("a->b->c->d;b->e->d->f;g->c")
gnb.sideBySide(bn,gnb.getInference(bn))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="134pt" height="332pt" viewBox="0.00 0.00 134.00 332.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- g -->
# <g id="node1" class="node">
# <title>g</title>
# <g id="a_node1"><a xlink:title="(6) g">
# <ellipse fill="#404040" stroke="black" cx="27" cy="-234" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-230.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">g</text>
# </a>
# </g>
# </g>
# <!-- c -->
# <g id="node6" class="node">
# <title>c</title>
# <g id="a_node6"><a xlink:title="(2) c">
# <ellipse fill="#404040" stroke="black" cx="27" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">c</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g id="edge2" class="edge">
# <title>g-&gt;c</title>
# <g id="a_edge2"><a xlink:title="(6, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M27,-215.7C27,-207.98 27,-198.71 27,-190.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="30.5,-190.1 27,-180.1 23.5,-190.1 30.5,-190.1"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g id="node2" class="node">
# <title>d</title>
# <g id="a_node2"><a xlink:title="(3) d">
# <ellipse fill="#404040" stroke="black" cx="63" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">d</text>
# </a>
# </g>
# </g>
# <!-- f -->
# <g id="node3" class="node">
# <title>f</title>
# <g id="a_node3"><a xlink:title="(5) f">
# <ellipse fill="#404040" stroke="black" cx="63" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g id="edge7" class="edge">
# <title>d-&gt;f</title>
# <g id="a_edge7"><a xlink:title="(3, 5) : ">
# <path fill="none" stroke="#4a4a4a" d="M63,-71.7C63,-63.98 63,-54.71 63,-46.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="66.5,-46.1 63,-36.1 59.5,-46.1 66.5,-46.1"/>
# </a>
# </g>
# </g>
# <!-- b -->
# <g id="node4" class="node">
# <title>b</title>
# <g id="a_node4"><a xlink:title="(1) b">
# <ellipse fill="#404040" stroke="black" cx="99" cy="-234" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-230.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">b</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g id="edge3" class="edge">
# <title>b-&gt;c</title>
# <g id="a_edge3"><a xlink:title="(1, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M84.43,-218.83C74.25,-208.94 60.48,-195.55 48.97,-184.36"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="51.41,-181.85 41.8,-177.38 46.53,-186.87 51.41,-181.85"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g id="node7" class="node">
# <title>e</title>
# <g id="a_node7"><a xlink:title="(4) e">
# <ellipse fill="#404040" stroke="black" cx="99" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">e</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g id="edge5" class="edge">
# <title>b-&gt;e</title>
# <g id="a_edge5"><a xlink:title="(1, 4) : ">
# <path fill="none" stroke="#4a4a4a" d="M99,-215.7C99,-207.98 99,-198.71 99,-190.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.5,-190.1 99,-180.1 95.5,-190.1 102.5,-190.1"/>
# </a>
# </g>
# </g>
# <!-- a -->
# <g id="node5" class="node">
# <title>a</title>
# <g id="a_node5"><a xlink:title="(0) a">
# <ellipse fill="#404040" stroke="black" cx="99" cy="-306" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-302.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">a</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g id="edge1" class="edge">
# <title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path fill="none" stroke="#4a4a4a" d="M99,-287.7C99,-279.98 99,-270.71 99,-262.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.5,-262.1 99,-252.1 95.5,-262.1 102.5,-262.1"/>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g id="edge6" class="edge">
# <title>c-&gt;d</title>
# <g id="a_edge6"><a xlink:title="(2, 3) : ">
# <path fill="none" stroke="#4a4a4a" d="M35.35,-144.76C39.71,-136.28 45.15,-125.71 50.04,-116.2"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="53.23,-117.64 54.7,-107.15 47.01,-114.44 53.23,-117.64"/>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g id="edge4" class="edge">
# <title>e-&gt;d</title>
# <g id="a_edge4"><a xlink:title="(4, 3) : ">
# <path fill="none" stroke="#4a4a4a" d="M90.65,-144.76C86.29,-136.28 80.85,-125.71 75.96,-116.2"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="78.99,-114.44 71.3,-107.15 72.77,-117.64 78.99,-114.44"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="189pt" height="360pt" viewBox="0.00 0.00 188.69 360.00">
# <g id="graph0" class="graph" transform="scale(0.83 0.83) rotate(0) translate(4 431)">
# <title>structs</title>
# <text text-anchor="middle" x="110" y="-7.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.00ms</text>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="220,-427 119,-427 119,-375 220,-375 220,-427"/>
# <svg viewBox="0 0 132.1625 66.4355" width="101px" height="52px" preserveAspectRatio="xMinYMin meet" x="119" y="-427"> <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-04-02T22:21:19.770934</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.4.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.4355  L 132.1625 66.4355  L 132.1625 0  L 0 0  z " style="fill:#e0e0e0;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 59.3355  L 128.5625 59.3355  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:#ffffff;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#pe43101c01a)" d="M 16.9625 59.3355  L 59.51033 59.3355  L 59.51033 47.2555  L 16.9625 47.2555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#pe43101c01a)" d="M 16.9625 44.2355  L 86.01467 44.2355  L 86.01467 32.1555  L 16.9625 32.1555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pe43101c01a)" d="M 16.9625 59.3355  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="m947d56a173" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m947d56a173" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#pe43101c01a)" d="M 72.7625 59.3355  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#m947d56a173" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#pe43101c01a)" d="M 128.5625 59.3355  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d

# %%
ie=gum.LazyPropagation(bn)
ie.addJointTarget({"e","f","g"})
ie.makeInference()
gnb.sideBySide(ie.jointPosterior({"e","f","g"}),ie.jointPosterior({"e","g"}),
               captions=["Joint posterior $P(e,f,g)$","Joint posterior $P(e,f)$"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='2'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>g</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>f</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#f28b64;text-align:right;'>0.0963</td><td style='color:black;background-color:#f48964;text-align:right;'>0.0795</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#fa8364;text-align:right;'>0.0333</td><td style='color:black;background-color:#f78664;text-align:right;'>0.0554</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#e89564;text-align:right;'>0.1796</td><td style='color:black;background-color:#e39a64;text-align:right;'>0.2149</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#e89564;text-align:right;'>0.1746</td><td style='color:black;background-color:#e99464;text-align:right;'>0.1664</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='1'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>g</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#dba264;text-align:right;'>0.2759</td><td style='color:black;background-color:#d9a464;text-align:right;'>0.2943</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#e49964;text-align:right;'>0.2079</td><td style='color:black;background-color:#e29b64;text-align:right;'>0.2218</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Joint posterior $P(e,f,g)$</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Joint posterior $P(e,f)$</small></div></td></tr></table>

# %%
gnb.sideBySide(ie.evidenceImpact("a",["e","f"]),ie.evidenceImpact("a",["d","e","f"]),
              captions=["$\\forall e,f, P(a|e,f)$",
                        "$\\forall d,e,f, P(a|d,e,f)=P(a|d,e)$ using d-separation"]
                        )
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='2'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>a</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>f</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#afce64;text-align:right;'>0.6175</td><td style='color:black;background-color:#ceaf64;text-align:right;'>0.3825</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#afce64;text-align:right;'>0.6228</td><td style='color:black;background-color:#ceaf64;text-align:right;'>0.3772</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#b4c964;text-align:right;'>0.5856</td><td style='color:black;background-color:#c9b464;text-align:right;'>0.4144</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#aad364;text-align:right;'>0.6567</td><td style='color:black;background-color:#d3aa64;text-align:right;'>0.3433</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='2'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>a</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>d</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#afce64;text-align:right;'>0.6241</td><td style='color:black;background-color:#ceaf64;text-align:right;'>0.3759</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#bac364;text-align:right;'>0.5345</td><td style='color:black;background-color:#c3ba64;text-align:right;'>0.4655</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#b1cc64;text-align:right;'>0.6088</td><td style='color:black;background-color:#ccb164;text-align:right;'>0.3912</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#a8d564;text-align:right;'>0.6757</td><td style='color:black;background-color:#d5a864;text-align:right;'>0.3243</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>$\forall e,f, P(a|e,f)$</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>$\forall d,e,f, P(a|d,e,f)=P(a|d,e)$ using d-separation</small></div></td></tr></table>

# %%
gnb.sideBySide(ie.evidenceJointImpact(["a","b"],["e","f"]),ie.evidenceJointImpact(["a","b"],["d","e","f"]),
              captions=["$\\forall e,f, P(a,b|e,f)$",
                        "$\\forall d,e,f, P(a,b|d,e,f)=P(a,b|d,e)$ using d-separation"]
                        )
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='3'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>b</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>f</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>a</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.5839</td><td style='text-align:right;'>0.0337</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.1641</td><td style='text-align:right;'>0.2184</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.5903</td><td style='text-align:right;'>0.0326</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.1659</td><td style='text-align:right;'>0.2113</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.5453</td><td style='text-align:right;'>0.0402</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.1533</td><td style='text-align:right;'>0.2612</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.6311</td><td style='text-align:right;'>0.0256</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.1774</td><td style='text-align:right;'>0.1659</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='3'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>b</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>d</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>a</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.5918</td><td style='text-align:right;'>0.0323</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.1663</td><td style='text-align:right;'>0.2096</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.4837</td><td style='text-align:right;'>0.0508</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.1360</td><td style='text-align:right;'>0.3295</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.5733</td><td style='text-align:right;'>0.0355</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.1611</td><td style='text-align:right;'>0.2301</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.6540</td><td style='text-align:right;'>0.0217</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.1838</td><td style='text-align:right;'>0.1405</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>$\forall e,f, P(a,b|e,f)$</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>$\forall d,e,f, P(a,b|d,e,f)=P(a,b|d,e)$ using d-separation</small></div></td></tr></table>
