# %% [markdown]
# <a href="http://agrum.org" target="blank"><img src="http://agrum.gitlab.io/theme/img/logoAgrum.png" align="left" style="height:100px"/></a><a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This pyAgrum's notebook is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.

# %%
# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt

import os

# %% [markdown]
# Initialisation
# ==============
#
# * importing pyAgrum
# * importing pyAgrum.lib tools
# * loading a BN

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
gnb.configuration()
# Out:
# <table width='100%'><tr><th>Library</th><th>Version</th></tr><tr><td>OS</td><td>nt [win32]</td></tr><tr><td>Python</td><td>3.9.1 (tags/v3.9.1:1e5d33e, Dec  7 2020, 17:08:21) [MSC v.1927 64 bit (AMD64)]</td></tr><tr><td>IPython</td><td>7.19.0</td></tr><tr><td>MatPlotLib</td><td>3.3.3</td></tr><tr><td>Numpy</td><td>1.19.3</td></tr><tr><td>pyAgrum</td><td>0.18.2.9</td></tr></table><div align='right'><small>Sun Jan 03 20:42:00 2021 Paris, Madrid</small></div>

# %%
bn=gum.loadBN(os.path.join("res","alarm.dsl"))
gnb.showBN(bn,size='10')

# %% [markdown]
# Visualisation and inspection
# ============================

# %%
print(bn.variableFromName('SHUNT'))
# Out:
# SHUNT<NORMAL,HIGH>

# %%
print(bn.cpt(bn.idFromName('SHUNT')))
# Out:
#              ||  SHUNT            |
# PULMEM|INTUBA||NORMAL   |HIGH     |
# ------|------||---------|---------|
# TRUE  |NORMAL|| 0.1000  | 0.9000  |
# FALSE |NORMAL|| 0.9500  | 0.0500  |
# TRUE  |ESOPHA|| 0.1000  | 0.9000  |
# FALSE |ESOPHA|| 0.9500  | 0.0500  |
# TRUE  |ONESID|| 0.0100  | 0.9900  |
# FALSE |ONESID|| 0.0500  | 0.9500  |

# %%
gnb.showPotential(bn.cpt(bn.idFromName('SHUNT')),digits=3)
# Out:
# <table style="border:1px solid black;"><tr><th colspan='2'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>SHUNT</center></th></tr><tr><th style='border:1px solid black;color:black;background-color:#808080'><center>INTUBATION</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PULMEMBOLUS</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>NORMAL</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>HIGH</center></th></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>NORMAL</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>TRUE</center></th><td style='color:black;background-color:#f28b64;text-align:right;'>0.100</td><td style='color:black;background-color:#8bf264;text-align:right;'>0.900</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>FALSE</center></th><td style='color:black;background-color:#85f864;text-align:right;'>0.950</td><td style='color:black;background-color:#f88564;text-align:right;'>0.050</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>ESOPHAGEAL</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>TRUE</center></th><td style='color:black;background-color:#f28b64;text-align:right;'>0.100</td><td style='color:black;background-color:#8bf264;text-align:right;'>0.900</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>FALSE</center></th><td style='color:black;background-color:#85f864;text-align:right;'>0.950</td><td style='color:black;background-color:#f88564;text-align:right;'>0.050</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>ONESIDED</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>TRUE</center></th><td style='color:black;background-color:#fd8064;text-align:right;'>0.010</td><td style='color:black;background-color:#80fd64;text-align:right;'>0.990</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>FALSE</center></th><td style='color:black;background-color:#f88564;text-align:right;'>0.050</td><td style='color:black;background-color:#85f864;text-align:right;'>0.950</td></tr></table>

# %% [markdown]
# Results of inference
# ====================
#
# It is easy to look at result of inference

# %%
gnb.showPosterior(bn,{'SHUNT':'HIGH'},'PRESS')

# %%
gnb.showPosterior(bn,{'MINVOLSET':'NORMAL'},'VENTALV')

# %% [markdown]
# Overall results

# %%
gnb.showInference(bn,size="10")

# %% [markdown]
# What is the impact of observed variables (SHUNT and VENTALV for instance) on another on (PRESS) ?

# %%
ie=gum.LazyPropagation(bn)
ie.evidenceImpact('PRESS',['SHUNT','VENTALV'])
# Out:
# (gum::Potential<double>@000002CB032A9420)
#              ||  PRESS                                |
# VENTAL|SHUNT ||ZERO     |LOW      |NORMAL   |HIGH     |
# ------|------||---------|---------|---------|---------|
# ZERO  |NORMAL|| 0.0569  | 0.2669  | 0.2005  | 0.4757  |
# LOW   |NORMAL|| 0.0208  | 0.2515  | 0.0553  | 0.6724  |
# NORMAL|NORMAL|| 0.0769  | 0.3267  | 0.1772  | 0.4192  |
# HIGH  |NORMAL|| 0.0501  | 0.1633  | 0.2796  | 0.5071  |
# ZERO  |HIGH  || 0.0589  | 0.2726  | 0.1997  | 0.4688  |
# LOW   |HIGH  || 0.0318  | 0.2237  | 0.0521  | 0.6924  |
# NORMAL|HIGH  || 0.1735  | 0.5839  | 0.1402  | 0.1024  |
# HIGH  |HIGH  || 0.0711  | 0.2347  | 0.2533  | 0.4410  |

# %% [markdown]
# Using inference as a function
# ====================
#
# It is also easy to use inference as a routine in more complex procedures.

# %%
import time
r=range(0,100,2)
xs=[x/100.0 for x in r]

tf=time.time()
ys=[gum.getPosterior(bn,{'MINVOLSET':[0,x/100.0,0.5]},'VENTALV').tolist() 
        for x in r]
delta=time.time()-tf

p=plot(xs,ys)
legend(p,[bn.variableFromName('VENTALV').label(i) 
          for i in range(bn.variableFromName('VENTALV').domainSize())],loc=7);
title('VENTALV (100 inferences in %d ms)'%delta);
ylabel('posterior Probability');
xlabel('Evidence on MINVOLSET : [0,x,0.5]')
plt.show()

# %% [markdown]
# Another example : python gives access to a large set of tools. Here the value for the equality of two probabilities of a posterior is easely computed.

# %%
x=[p/100.0 for p in range(0,100)]

tf=time.time()
y=[gum.getPosterior(bn,{'HRBP':[1.0-p/100.0,1.0-p/100.0,p/100.0]},'TPR').tolist() 
   for p in range(0,100)]
delta=time.time()-tf

p=plot(x,y)
title('HRBP (100 inferences in %d ms)'%delta);
v=bn.variableFromName('TPR');
legend([v.label(i) for i in range(v.domainSize())],loc='best');
np1=(transpose(y)[0]>transpose(y)[2]).argmin()
text(x[np1]-0.05,y[np1][0]+0.005,str(x[np1]),bbox=dict(facecolor='red', alpha=0.1))
plt.show()

# %% [markdown]
# BN as a classifier
# ================

# %% [markdown]
# Generation of databases
# -----------------------
#
# Using the CSV format for the database:

# %%
gum.generateCSV(bn,os.path.join("out","test.csv"),1000,with_labels=True)
# Out:
# -15115.7773056975

# %%
from pyAgrum.lib._utils import oslike
oslike.head(os.path.join("out",'test.csv'))
# Out:
# ERRCAUTER,HRSAT,VENTMACH,HRBP,SHUNT,PVSAT,PCWP,SAO2,STROKEVOLUME,EXPCO2,VENTALV,HYPOVOLEMIA,HR,HISTORY,FIO2,CO,VENTTUBE,ERRLOWOUTPUT,KINKEDTUBE,PULMEMBOLUS,CATECHOL,TPR,ARTCO2,LVFAILURE,MINVOLSET,LVEDVOLUME,PRESS,CVP,MINVOL,VENTLUNG,DISCONNECT,ANAPHYLAXIS,INSUFFANESTH,PAP,INTUBATION,HREKG,BP
# FALSE,LOW,NORMAL,LOW,NORMAL,HIGH,HIGH,NORMAL,LOW,NORMAL,HIGH,TRUE,NORMAL,FALSE,NORMAL,LOW,LOW,FALSE,FALSE,FALSE,NORMAL,NORMAL,LOW,FALSE,NORMAL,HIGH,NORMAL,HIGH,LOW,NORMAL,FALSE,FALSE,TRUE,NORMAL,NORMAL,HIGH,LOW
# FALSE,HIGH,NORMAL,HIGH,NORMAL,LOW,NORMAL,LOW,NORMAL,LOW,ZERO,FALSE,HIGH,FALSE,NORMAL,HIGH,LOW,FALSE,FALSE,FALSE,HIGH,NORMAL,HIGH,FALSE,NORMAL,NORMAL,HIGH,NORMAL,ZERO,ZERO,FALSE,FALSE,FALSE,LOW,NORMAL,HIGH,NORMAL
# FALSE,HIGH,NORMAL,HIGH,NORMAL,LOW,NORMAL,LOW,NORMAL,LOW,ZERO,FALSE,HIGH,FALSE,NORMAL,HIGH,LOW,FALSE,FALSE,FALSE,HIGH,HIGH,HIGH,FALSE,NORMAL,NORMAL,HIGH,NORMAL,ZERO,ZERO,FALSE,FALSE,FALSE,NORMAL,NORMAL,HIGH,HIGH
# FALSE,LOW,NORMAL,LOW,NORMAL,LOW,HIGH,LOW,LOW,LOW,ZERO,TRUE,NORMAL,FALSE,NORMAL,LOW,LOW,FALSE,FALSE,FALSE,HIGH,NORMAL,HIGH,FALSE,NORMAL,HIGH,LOW,NORMAL,ZERO,ZERO,FALSE,FALSE,FALSE,NORMAL,NORMAL,NORMAL,LOW
# FALSE,HIGH,HIGH,HIGH,NORMAL,HIGH,HIGH,NORMAL,NORMAL,NORMAL,HIGH,FALSE,HIGH,FALSE,NORMAL,HIGH,NORMAL,FALSE,FALSE,FALSE,HIGH,HIGH,LOW,FALSE,HIGH,NORMAL,HIGH,NORMAL,LOW,NORMAL,TRUE,FALSE,FALSE,NORMAL,NORMAL,HIGH,HIGH
# FALSE,HIGH,NORMAL,HIGH,NORMAL,LOW,NORMAL,LOW,NORMAL,NORMAL,LOW,FALSE,HIGH,FALSE,LOW,HIGH,LOW,FALSE,FALSE,FALSE,HIGH,NORMAL,HIGH,FALSE,NORMAL,NORMAL,LOW,NORMAL,LOW,LOW,FALSE,FALSE,FALSE,HIGH,ESOPHAGEAL,HIGH,NORMAL
# FALSE,HIGH,NORMAL,HIGH,NORMAL,LOW,NORMAL,LOW,NORMAL,LOW,ZERO,FALSE,HIGH,FALSE,NORMAL,HIGH,LOW,FALSE,FALSE,FALSE,HIGH,NORMAL,HIGH,FALSE,NORMAL,NORMAL,NORMAL,NORMAL,ZERO,ZERO,FALSE,FALSE,FALSE,LOW,NORMAL,LOW,HIGH
# FALSE,LOW,NORMAL,LOW,NORMAL,HIGH,HIGH,NORMAL,LOW,LOW,HIGH,TRUE,NORMAL,TRUE,NORMAL,LOW,NORMAL,FALSE,FALSE,FALSE,HIGH,HIGH,LOW,TRUE,NORMAL,LOW,HIGH,LOW,ZERO,NORMAL,FALSE,FALSE,FALSE,NORMAL,NORMAL,NORMAL,LOW
# TRUE,NORMAL,NORMAL,HIGH,NORMAL,HIGH,NORMAL,NORMAL,NORMAL,NORMAL,HIGH,FALSE,HIGH,FALSE,NORMAL,HIGH,NORMAL,FALSE,FALSE,FALSE,HIGH,HIGH,LOW,FALSE,NORMAL,NORMAL,HIGH,NORMAL,ZERO,NORMAL,FALSE,FALSE,FALSE,NORMAL,NORMAL,LOW,HIGH

# %% [markdown]
# BN as a classifier
# ------------------
#
# (because of the use of from-bn-generated csv files, quite good ROC curves are expected)

# %%
from pyAgrum.lib.bn2roc import showROC_PR

showROC_PR(bn,os.path.join("out","test.csv"),
        variable='CATECHOL',label='HIGH',  # class and label 
        show_progress=True,show_fig=True,with_labels=True)
# Out:
#  out\test.csv : [ ############################################################ ] 100%
# (0.9522577896786758, 0.9300899828, 0.9972840596752425, 0.3378378368)

# %% [markdown]
# Using another class variable

# %%
showROC_PR(bn,os.path.join("out","test.csv"),'SAO2','HIGH',show_progress=True)
# Out:
#  out\test.csv : [ ############################################################ ] 100%
# (0.9644387755102041, 0.0055727553, 0.6864861495719445, 0.41220621535)

# %% [markdown]
# # Fast prototyping for BNs

# %%
bn1=gum.fastBN("a->b;a->c;b->c;c->d",3)

gnb.sideBySide(*[gnb.getInference(bn1,evs={'c':val},targets={'a','c','d'}) for val in range(3)],
              captions=["<pre>Inference given that c={}</pre>".format(val) for val in range(3)])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="142pt" height="360pt" viewBox="0.00 0.00 141.61 360.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 357)">
# <title>structs</title>
# <text text-anchor="middle" x="67" y="-7.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">Inference in   1.01ms</text>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="119.25,-353 18.25,-353 18.25,-291 119.25,-291 119.25,-353"/>
# <svg viewBox="0 0 132.1625 80.0255" width="101px" height="62px" preserveAspectRatio="xMinYMin meet" x="18.25" y="-353"> <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-01-03T20:42:07.287613</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.3.3, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 80.0255  L 132.1625 80.0255  L 132.1625 0  L 0 0  z " style="fill:#e0e0e0;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 72.9255  L 128.5625 72.9255  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:#ffffff;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#paa884245e1)" d="M 16.9625 72.9255  L 62.994297 72.9255  L 62.994297 61.276929  L 16.9625 61.276929  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#paa884245e1)" d="M 16.9625 58.364786  L 34.574018 58.364786  L 34.574018 46.716214  L 16.9625 46.716214  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_5">
#     <path clip-path="url(#paa884245e1)" d="M 16.9625 43.804071  L 64.919185 43.804071  L 64.919185 32.1555  L 16.9625 32.1555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#paa884245e1)" d="M 16.9625 72.9255  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="m86be2e2445" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m86be2e2445" y="72.9255"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#paa884245e1)" d="M 72.7625 72.9255  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#m86be2e2445" y="72.9255"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#paa884245e1)" d="M 128.5625 72.9255  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="128.5625" xlink:href="#m86be2e2445" y="72.9255"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path d="M 0 0  L -3.5 0  " id="m06f1c38f86" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m06f1c38f86" y="67.101214"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 2 -->
#       <g transform="translate(3.6 70.900433)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 19.1875 8.296875  L 53.609375 8.296875  L 53.609375 0  L 7.328125 0  L 7.328125 8.296875  Q 12.9375 14.109375 22.625 23.890625  Q 32.328125 33.6875 34.8125 36.53125  Q 39.546875 41.84375 41.421875 45.53125  Q 43.3125 49.21875 43.3125 52.78125  Q 43.3125 58.59375 39.234375 62.25  Q 35.15625 65.921875 28.609375 65.921875  Q 23.96875 65.921875 18.8125 64.3125  Q 13.671875 62.703125 7.8125 59.421875  L 7.8125 69.390625  Q 13.765625 71.78125 18.9375 73  Q 24.125 74.21875 28.421875 74.21875  Q 39.75 74.21875 46.484375 68.546875  Q 53.21875 62.890625 53.21875 53.421875  Q 53.21875 48.921875 51.53125 44.890625  Q 49.859375 40.875 45.40625 35.40625  Q 44.1875 33.984375 37.640625 27.21875  Q 31.109375 20.453125 19.1875 8.296875  z " id="DejaVuSans-50"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-50"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_2">
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m06f1c38f86" y="52.5405"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 1 -->
#       <g transform="translate(3.6 56.339719)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 12.40625 8.296875  L 28.515625 8.296875  L 28.515625 63.921875  L 10.984375 60.40625  L 10.984375 69.390625  L 28.421875 72.90625  L 38.28125 72.90625  L 38.28125 8.296875  L 54.390625 8.296875  L 54.390625 0  L 12.40625 0  z " id="DejaVuSans-49"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-49"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_3">
#      <g id="line2d_9">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m06f1c38f86" y="37.979786"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 0 -->
#       <g transform="translate(3.6 41.779004)scale(0.1 -0.1)">
#        <defs>
#         <path d="M 31.78125 66.40625  Q 24.171875 66.40625 20.328125 58.90625  Q 16.5 51.421875 16.5 36.375  Q 16.5 21.390625 20.328125 13.890625  Q 24.171875 6.390625 31.78125 6.390625  Q 39.453125 6.390625 43.28125 13.890625  Q 47.125 21.390625 47.125 36.375  Q 47.125 51.421875 43.28125 58.90625  Q 39.453125 66.40625 31.78125 66.40625  z M 31.78125 74.21875  Q 44.046875 74.21875 50.515625 64.515625  Q 56.984375 54.828125 56.984375 36.375  Q 56.984375 17.96875 50.515625 8.265625  Q 44.046875 -1.421875 31.78125 -1.421875  Q 19.53125 -1.421875 13.0625 8.265625  Q 6.59375 17.96875 6.59375 36.375  Q 6.59375 54.828125 13.0625 64.515625  Q 19.53125 74.21875 31.78125 74.21875  z " id="DejaVuSans-48"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-48"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="patch_6">
#     <path d="M 16.9625 72.9255  L 16.9625 32.1555  " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="patch_7">
#     <path d="M 128.5625 72.9255  L 128.5625 32.1555  " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="patch_8">
#     <path d="M 16.9625 72.9255  L 128.5625 72.9255  " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="patch_9">
#     <path d="M 16.9625 32.1555  L 128.5625 32.1555  " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="text_4">
#     <!-- 41.25% -->
#     <g transform="translate(90.432812 70.845813)scale(0.1 -0.1)">
#      <defs>
#       <path d="M 37.796875 64.3125  L 12.890625 25.390625  L 37.796875 25.390625  z M 35.203125 72.90625  L 47.609375 72.90625  L 47.609375 25.390625  L 58.015625 25.390625  L 58.015625 17.1875  L 47.609375 17.1875  L 47.609375 0  L 37.796875 0  L 37.796875 17.1875  L 4.890625 17.1875  L 4.890625 26.703125  z " id="DejaVuSans-52"/>
#       <path d="M 10.6875 12.40625  L 21 12.40625  L 21 0  L 10.6875 0  z " id="DejaVuSans-46"/>
#       <path d="M 10.796875 72.90625  L 49.515625 72.90625  L 49.5156

# %%
print(gum.getPosterior(bn1,evs={'c':0},target='c'))
print(gum.getPosterior(bn1,evs={'c':0},target='a'))
# Out:
#   c                          |
# 0        |1        |2        |
# ---------|---------|---------|
#  1.0000  | 0.0000  | 0.0000  |
#
#
#   a                          |
# 0        |1        |2        |
# ---------|---------|---------|
#  0.4297  | 0.1578  | 0.4125  |

# %% [markdown]
# # Joint posterior, impact of multiple evidence

# %%
bn=gum.fastBN("a->b->c->d;b->e->d->f;g->c")
gnb.sideBySide(bn,gnb.getInference(bn))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="134pt" height="332pt" viewBox="0.00 0.00 134.00 332.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <g id="a_node1"><a xlink:title="(0) a">
# <ellipse fill="#404040" stroke="black" cx="99" cy="-306" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-302.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">a</text>
# </a>
# </g>
# </g>
# <!-- b -->
# <g id="node2" class="node">
# <title>b</title>
# <g id="a_node2"><a xlink:title="(1) b">
# <ellipse fill="#404040" stroke="black" cx="99" cy="-234" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-230.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">b</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g id="edge1" class="edge">
# <title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path fill="none" stroke="#4a4a4a" d="M99,-287.7C99,-279.98 99,-270.71 99,-262.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.5,-262.1 99,-252.1 95.5,-262.1 102.5,-262.1"/>
# </a>
# </g>
# </g>
# <!-- c -->
# <g id="node3" class="node">
# <title>c</title>
# <g id="a_node3"><a xlink:title="(2) c">
# <ellipse fill="#404040" stroke="black" cx="27" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">c</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g id="edge3" class="edge">
# <title>b-&gt;c</title>
# <g id="a_edge3"><a xlink:title="(1, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M84.43,-218.83C74.25,-208.94 60.48,-195.55 48.97,-184.36"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="51.41,-181.85 41.8,-177.38 46.53,-186.87 51.41,-181.85"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g id="node5" class="node">
# <title>e</title>
# <g id="a_node5"><a xlink:title="(4) e">
# <ellipse fill="#404040" stroke="black" cx="99" cy="-162" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">e</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g id="edge5" class="edge">
# <title>b-&gt;e</title>
# <g id="a_edge5"><a xlink:title="(1, 4) : ">
# <path fill="none" stroke="#4a4a4a" d="M99,-215.7C99,-207.98 99,-198.71 99,-190.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.5,-190.1 99,-180.1 95.5,-190.1 102.5,-190.1"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g id="node4" class="node">
# <title>d</title>
# <g id="a_node4"><a xlink:title="(3) d">
# <ellipse fill="#404040" stroke="black" cx="63" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">d</text>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g id="edge6" class="edge">
# <title>c-&gt;d</title>
# <g id="a_edge6"><a xlink:title="(2, 3) : ">
# <path fill="none" stroke="#4a4a4a" d="M35.35,-144.76C39.71,-136.28 45.15,-125.71 50.04,-116.2"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="53.23,-117.64 54.7,-107.15 47.01,-114.44 53.23,-117.64"/>
# </a>
# </g>
# </g>
# <!-- f -->
# <g id="node6" class="node">
# <title>f</title>
# <g id="a_node6"><a xlink:title="(5) f">
# <ellipse fill="#404040" stroke="black" cx="63" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g id="edge7" class="edge">
# <title>d-&gt;f</title>
# <g id="a_edge7"><a xlink:title="(3, 5) : ">
# <path fill="none" stroke="#4a4a4a" d="M63,-71.7C63,-63.98 63,-54.71 63,-46.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="66.5,-46.1 63,-36.1 59.5,-46.1 66.5,-46.1"/>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g id="edge4" class="edge">
# <title>e-&gt;d</title>
# <g id="a_edge4"><a xlink:title="(4, 3) : ">
# <path fill="none" stroke="#4a4a4a" d="M90.65,-144.76C86.29,-136.28 80.85,-125.71 75.96,-116.2"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="78.99,-114.44 71.3,-107.15 72.77,-117.64 78.99,-114.44"/>
# </a>
# </g>
# </g>
# <!-- g -->
# <g id="node7" class="node">
# <title>g</title>
# <g id="a_node7"><a xlink:title="(6) g">
# <ellipse fill="#404040" stroke="black" cx="27" cy="-234" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-230.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">g</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g id="edge2" class="edge">
# <title>g-&gt;c</title>
# <g id="a_edge2"><a xlink:title="(6, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M27,-215.7C27,-207.98 27,-198.71 27,-190.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="30.5,-190.1 27,-180.1 23.5,-190.1 30.5,-190.1"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="189pt" height="360pt" viewBox="0.00 0.00 188.69 360.00">
# <g id="graph0" class="graph" transform="scale(0.83 0.83) rotate(0) translate(4 431)">
# <title>structs</title>
# <text text-anchor="middle" x="110" y="-7.8" font-family="Times New Roman,serif" font-size="14.00" fill="#4a4a4a">Inference in   1.00ms</text>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="220,-427 119,-427 119,-375 220,-375 220,-427"/>
# <svg viewBox="0 0 132.1625 66.4355" width="101px" height="52px" preserveAspectRatio="xMinYMin meet" x="119" y="-427"> <metadata>
#   <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2021-01-03T20:42:08.742607</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.3.3, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.4355  L 132.1625 66.4355  L 132.1625 0  L 0 0  z " style="fill:#e0e0e0;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 59.3355  L 128.5625 59.3355  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:#ffffff;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#pc4f53cf9ce)" d="M 16.9625 59.3355  L 44.471925 59.3355  L 44.471925 47.2555  L 16.9625 47.2555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#pc4f53cf9ce)" d="M 16.9625 44.2355  L 101.053075 44.2355  L 101.053075 32.1555  L 16.9625 32.1555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pc4f53cf9ce)" d="M 16.9625 59.3355  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="m84dea674a2" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m84dea674a2" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#pc4f53cf9ce)" d="M 72.7625 59.3355  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#m84dea674a2" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#pc4f53cf9ce)" d="M 128.5625 59.3355  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="

# %%
ie=gum.LazyPropagation(bn)
ie.addJointTarget({"e","f","g"})
ie.makeInference()
gnb.sideBySide(ie.jointPosterior({"e","f","g"}),ie.jointPosterior({"e","g"}),
               captions=["Joint posterior $P(e,f,g)$","Joint posterior $P(e,f)$"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='2'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>g</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>f</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#fd8064;text-align:right;'>0.0119</td><td style='color:black;background-color:#f98464;text-align:right;'>0.0420</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#f58864;text-align:right;'>0.0762</td><td style='color:black;background-color:#dda064;text-align:right;'>0.2655</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#fc8164;text-align:right;'>0.0181</td><td style='color:black;background-color:#f78664;text-align:right;'>0.0610</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#ef8e64;text-align:right;'>0.1190</td><td style='color:black;background-color:#cab364;text-align:right;'>0.4063</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='1'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>g</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#fb8264;text-align:right;'>0.0299</td><td style='color:black;background-color:#f18c64;text-align:right;'>0.1030</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#e69764;text-align:right;'>0.1952</td><td style='color:black;background-color:#a9d464;text-align:right;'>0.6719</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Joint posterior $P(e,f,g)$</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Joint posterior $P(e,f)$</small></div></td></tr></table>

# %%
gnb.sideBySide(ie.evidenceImpact("a",["e","f"]),ie.evidenceImpact("a",["d","e","f"]),
              captions=["$\\forall e,f, P(a|e,f)$",
                        "$\\forall d,e,f, P(a|d,e,f)=P(a|d,e)$ using d-separation"]
                        )
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='2'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>a</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>f</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#98e564;text-align:right;'>0.8030</td><td style='color:black;background-color:#e59864;text-align:right;'>0.1970</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#9fde64;text-align:right;'>0.7466</td><td style='color:black;background-color:#de9f64;text-align:right;'>0.2534</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#98e564;text-align:right;'>0.8020</td><td style='color:black;background-color:#e59864;text-align:right;'>0.1980</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#9fde64;text-align:right;'>0.7456</td><td style='color:black;background-color:#de9f64;text-align:right;'>0.2544</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='2'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>a</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>d</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#98e564;text-align:right;'>0.8044</td><td style='color:black;background-color:#e59864;text-align:right;'>0.1956</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#98e564;text-align:right;'>0.7978</td><td style='color:black;background-color:#e59864;text-align:right;'>0.2022</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#9fde64;text-align:right;'>0.7484</td><td style='color:black;background-color:#de9f64;text-align:right;'>0.2516</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#a0dd64;text-align:right;'>0.7420</td><td style='color:black;background-color:#dda064;text-align:right;'>0.2580</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>$\forall e,f, P(a|e,f)$</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>$\forall d,e,f, P(a|d,e,f)=P(a|d,e)$ using d-separation</small></div></td></tr></table>

# %%
gnb.sideBySide(ie.evidenceJointImpact(["a","b"],["e","f"]),ie.evidenceJointImpact(["a","b"],["d","e","f"]),
              captions=["$\\forall e,f, P(a,b|e,f)$",
                        "$\\forall d,e,f, P(a,b|d,e,f)=P(a,b|d,e)$ using d-separation"]
                        )
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='3'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>b</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>f</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>a</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.7512</td><td style='text-align:right;'>0.0518</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.1770</td><td style='text-align:right;'>0.0200</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.2319</td><td style='text-align:right;'>0.5147</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.0547</td><td style='text-align:right;'>0.1987</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.7420</td><td style='text-align:right;'>0.0600</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.1748</td><td style='text-align:right;'>0.0232</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.2222</td><td style='text-align:right;'>0.5234</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.0524</td><td style='text-align:right;'>0.2021</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='3'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>b</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>d</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>a</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.7644</td><td style='text-align:right;'>0.0401</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.1801</td><td style='text-align:right;'>0.0155</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.7035</td><td style='text-align:right;'>0.0944</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.1658</td><td style='text-align:right;'>0.0364</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.2477</td><td style='text-align:right;'>0.5007</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.0584</td><td style='text-align:right;'>0.1933</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;'>0.1894</td><td style='text-align:right;'>0.5527</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;'>0.0446</td><td style='text-align:right;'>0.2134</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>$\forall e,f, P(a,b|e,f)$</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>$\forall d,e,f, P(a,b|d,e,f)=P(a,b|d,e)$ using d-separation</small></div></td></tr></table>
