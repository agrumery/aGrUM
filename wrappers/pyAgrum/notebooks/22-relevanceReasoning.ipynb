# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

import time
# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt

# %% [markdown]
# # multiple inference
#
# In the well known 'alarm' BN, how to analyze the influence on 'VENTALV' of a soft evidence on 'MINVOLSET' ?

# %%
bn=gum.loadBN("/home/phw/Clouds/spiderOak/LIP6/BayesNetRepository/alarm.bif")
gnb.showBN(bn,size="6")
# Out:
# <svg height="323pt" viewBox="0.00 0.00 432.00 322.52" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.422147 0.422147) rotate(0) translate(4 760)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-760 1019.34,-760 1019.34,4 -4,4" stroke="none"/>
# <!-- HISTORY -->
# <g class="node" id="node1"><title>HISTORY</title>
# <g id="a_node1"><a xlink:title="(0) HISTORY">
# <ellipse cx="48.7457" cy="-162" fill="#444444" rx="48.9926" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="48.7457" y="-158.3">HISTORY</text>
# </a>
# </g>
# </g>
# <!-- CVP -->
# <g class="node" id="node2"><title>CVP</title>
# <g id="a_node2"><a xlink:title="(1) CVP">
# <ellipse cx="147.746" cy="-90" fill="#444444" rx="27.8951" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="147.746" y="-86.3">CVP</text>
# </a>
# </g>
# </g>
# <!-- PCWP -->
# <g class="node" id="node3"><title>PCWP</title>
# <g id="a_node3"><a xlink:title="(2) PCWP">
# <ellipse cx="228.746" cy="-90" fill="#444444" rx="35.194" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="228.746" y="-86.3">PCWP</text>
# </a>
# </g>
# </g>
# <!-- HYPOVOLEMIA -->
# <g class="node" id="node4"><title>HYPOVOLEMIA</title>
# <g id="a_node4"><a xlink:title="(3) HYPOVOLEMIA">
# <ellipse cx="350.746" cy="-234" fill="#444444" rx="75.2868" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="350.746" y="-230.3">HYPOVOLEMIA</text>
# </a>
# </g>
# </g>
# <!-- LVEDVOLUME -->
# <g class="node" id="node5"><title>LVEDVOLUME</title>
# <g id="a_node5"><a xlink:title="(4) LVEDVOLUME">
# <ellipse cx="187.746" cy="-162" fill="#444444" rx="72.2875" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="187.746" y="-158.3">LVEDVOLUME</text>
# </a>
# </g>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;LVEDVOLUME -->
# <g class="edge" id="edge1"><title>HYPOVOLEMIA-&gt;LVEDVOLUME</title>
# <g id="a_edge1"><a xlink:title="(3, 4) : ">
# <path d="M315.778,-217.983C291.201,-207.429 258.133,-193.228 231.76,-181.902" fill="none" stroke="black"/>
# <polygon fill="black" points="232.945,-178.602 222.375,-177.872 230.183,-185.034 232.945,-178.602" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- STROKEVOLUME -->
# <g class="node" id="node7"><title>STROKEVOLUME</title>
# <g id="a_node7"><a xlink:title="(6) STROKEVOLUME">
# <ellipse cx="360.746" cy="-162" fill="#444444" rx="83.3857" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="360.746" y="-158.3">STROKEVOLUME</text>
# </a>
# </g>
# </g>
# <!-- HYPOVOLEMIA&#45;&gt;STROKEVOLUME -->
# <g class="edge" id="edge15"><title>HYPOVOLEMIA-&gt;STROKEVOLUME</title>
# <g id="a_edge15"><a xlink:title="(3, 6) : ">
# <path d="M353.218,-215.697C354.32,-207.983 355.644,-198.712 356.872,-190.112" fill="none" stroke="black"/>
# <polygon fill="black" points="360.353,-190.499 358.302,-180.104 353.423,-189.509 360.353,-190.499" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- LVEDVOLUME&#45;&gt;CVP -->
# <g class="edge" id="edge29"><title>LVEDVOLUME-&gt;CVP</title>
# <g id="a_edge29"><a xlink:title="(4, 1) : ">
# <path d="M178.063,-144.055C173.277,-135.679 167.405,-125.404 162.108,-116.134" fill="none" stroke="black"/>
# <polygon fill="black" points="165.064,-114.253 157.064,-107.307 158.987,-117.726 165.064,-114.253" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- LVEDVOLUME&#45;&gt;PCWP -->
# <g class="edge" id="edge46"><title>LVEDVOLUME-&gt;PCWP</title>
# <g id="a_edge46"><a xlink:title="(4, 2) : ">
# <path d="M197.671,-144.055C202.505,-135.801 208.421,-125.701 213.788,-116.538" fill="none" stroke="black"/>
# <polygon fill="black" points="216.878,-118.187 218.912,-107.789 210.838,-114.649 216.878,-118.187" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- LVFAILURE -->
# <g class="node" id="node6"><title>LVFAILURE</title>
# <g id="a_node6"><a xlink:title="(5) LVFAILURE">
# <ellipse cx="187.746" cy="-234" fill="#444444" rx="59.5901" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="187.746" y="-230.3">LVFAILURE</text>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;HISTORY -->
# <g class="edge" id="edge40"><title>LVFAILURE-&gt;HISTORY</title>
# <g id="a_edge40"><a xlink:title="(5, 0) : ">
# <path d="M158.267,-218.155C136.975,-207.432 108.079,-192.88 85.3149,-181.416" fill="none" stroke="black"/>
# <polygon fill="black" points="86.7963,-178.243 76.2907,-176.872 83.6478,-184.495 86.7963,-178.243" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;LVEDVOLUME -->
# <g class="edge" id="edge33"><title>LVFAILURE-&gt;LVEDVOLUME</title>
# <g id="a_edge33"><a xlink:title="(5, 4) : ">
# <path d="M187.746,-215.697C187.746,-207.983 187.746,-198.712 187.746,-190.112" fill="none" stroke="black"/>
# <polygon fill="black" points="191.246,-190.104 187.746,-180.104 184.246,-190.104 191.246,-190.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- LVFAILURE&#45;&gt;STROKEVOLUME -->
# <g class="edge" id="edge10"><title>LVFAILURE-&gt;STROKEVOLUME</title>
# <g id="a_edge10"><a xlink:title="(5, 6) : ">
# <path d="M221.925,-219.17C248.201,-208.538 284.794,-193.732 313.813,-181.99" fill="none" stroke="black"/>
# <polygon fill="black" points="315.382,-185.131 323.339,-178.136 312.756,-178.642 315.382,-185.131" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- CO -->
# <g class="node" id="node36"><title>CO</title>
# <g id="a_node36"><a xlink:title="(35) CO">
# <ellipse cx="416.746" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="416.746" y="-86.3">CO</text>
# </a>
# </g>
# </g>
# <!-- STROKEVOLUME&#45;&gt;CO -->
# <g class="edge" id="edge35"><title>STROKEVOLUME-&gt;CO</title>
# <g id="a_edge35"><a xlink:title="(6, 35) : ">
# <path d="M374.302,-144.055C381.412,-135.167 390.233,-124.14 397.989,-114.446" fill="none" stroke="black"/>
# <polygon fill="black" points="400.947,-116.352 404.461,-106.356 395.481,-111.979 400.947,-116.352" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- ERRLOWOUTPUT -->
# <g class="node" id="node8"><title>ERRLOWOUTPUT</title>
# <g id="a_node8"><a xlink:title="(7) ERRLOWOUTPUT">
# <ellipse cx="582.746" cy="-162" fill="#444444" rx="83.3857" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="582.746" y="-158.3">ERRLOWOUTPUT</text>
# </a>
# </g>
# </g>
# <!-- HRBP -->
# <g class="node" id="node9"><title>HRBP</title>
# <g id="a_node9"><a xlink:title="(8) HRBP">
# <ellipse cx="600.746" cy="-90" fill="#444444" rx="33.5952" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="600.746" y="-86.3">HRBP</text>
# </a>
# </g>
# </g>
# <!-- ERRLOWOUTPUT&#45;&gt;HRBP -->
# <g class="edge" id="edge16"><title>ERRLOWOUTPUT-&gt;HRBP</title>
# <g id="a_edge16"><a xlink:title="(7, 8) : ">
# <path d="M587.195,-143.697C589.2,-135.898 591.615,-126.509 593.847,-117.829" fill="none" stroke="black"/>
# <polygon fill="black" points="597.247,-118.661 596.347,-108.104 590.467,-116.918 597.247,-118.661" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- HREKG -->
# <g class="node" id="node10"><title>HREKG</title>
# <g id="a_node10"><a xlink:title="(9) HREKG">
# <ellipse cx="712.746" cy="-90" fill="#444444" rx="40.8928" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="712.746" y="-86.3">HREKG</text>
# </a>
# </g>
# </g>
# <!-- ERRCAUTER -->
# <g class="node" id="node11"><title>ERRCAUTER</title>
# <g id="a_node11"><a xlink:title="(10) ERRCAUTER">
# <ellipse cx="818.746" cy="-162" fill="#444444" rx="63.0888" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="818.746" y="-158.3">ERRCAUTER</text>
# </a>
# </g>
# </g>
# <!-- ERRCAUTER&#45;&gt;HREKG -->
# <g class="edge" id="edge34"><title>ERRCAUTER-&gt;HREKG</title>
# <g id="a_edge34"><a xlink:title="

# %% [markdown]
# We propose to draw the plot of the posterior of 'VENTALV' for the evidence : $$\forall x \in [0,1], e_{MINVOLSET}=[0,x,0.5]$$
#
# To do so, we perform a large number of inference and plot the posteriors.

# %%
K=5000
r=range(0,K)
xs=[x/K for x in r]

def getPlot(xs,ys,K,duration):
    p=plot(xs,ys)
    legend(p,[bn.variableFromName('VENTALV').label(i) 
              for i in range(bn.variableFromName('VENTALV').domainSize())],loc=7);
    title('VENTALV ({} inferences in {} s)'.format(K,duration));
    ylabel('posterior Probability');
    xlabel('Evidence on MINVOLSET : [0,x,0.5]');

# %% [markdown]
# ## first try :classical lazy inference

# %%
tf=time.time()
ys=[]
for x in r:
    ie=gum.LazyPropagation(bn)
    ie.addEvidence('MINVOLSET',[0,x/K,0.5])
    ie.makeInference()
    ys.append(ie.posterior('VENTALV').tolist())
delta1=time.time()-tf
getPlot(xs,ys,K,delta1)

# %% [markdown]
# ## second try : classical variable elimination
#
# One can note that we just need one posterior. This is a case where VariableElimination should give best results.

# %%
tf=time.time()
ys=[]
for x in r:
    ie=gum.VariableElimination(bn)
    ie.addEvidence('MINVOLSET',[0,x/K,0.5])
    ie.makeInference()
    ys.append(ie.posterior('VENTALV').tolist())
delta2=time.time()-tf
getPlot(xs,ys,K,delta2)

# %% [markdown]
# pyAgrum give us a function `gum.getPosterior` to do this same job more easily.

# %%
tf=time.time()
ys=[gum.getPosterior(bn,{'MINVOLSET':[0,x/K,0.5]},'VENTALV').tolist() 
        for x in r]
getPlot(xs,ys,K,time.time()-tf)

# %% [markdown]
# ## last try : optimized Lazy propagation : relevance reasoning and incremental inference
#
# Optimized inference in aGrUM can use the targets and the evidence to optimize the computations. This is called **relevance reasonning**.
#
# Moreover, if the values of the evidence change but not the structure of the query (same nodes as target, same nodes as hard evidence, same nodes as soft evidence), inference in aGrUM may re-use some of the computations from a query to another. This is called **incremental inference**.

# %%
tf=time.time()
ie=gum.VariableElimination(bn)
ie.addEvidence('MINVOLSET',[1,1,1])
ie.addTarget('VENTALV')
ys=[]
for x in r:
    ie.chgEvidence('MINVOLSET',[0,x/K,0.5])
    ie.makeInference()
    ys.append(ie.posterior('VENTALV').tolist())
delta3=time.time()-tf
getPlot(xs,ys,K,delta3)

# %%
print("Mean duration of a lazy propagation            : {:5.3f}ms".format(1000*delta1/K))
print("Mean duration of a variable elimination        : {:5.3f}ms".format(1000*delta2/K))
print("Mean duration of an optimized lazy propagation : {:5.3f}ms".format(1000*delta3/K))
# Out:
# Mean duration of a lazy propagation            : 27.202ms
# Mean duration of a variable elimination        : 3.407ms
# Mean duration of an optimized lazy propagation : 3.150ms

# %% [markdown]
# # How it works

# %%
bn=gum.fastBN("Y->X->T1;Z2->X;Z1->X;Z1->T1;Z1->Z3->T2")
ie=gum.LazyPropagation(bn)

gnb.sideBySide(bn,
               bn.cpt("X"),
               gnb.getJunctionTree(bn),
               captions=["BN","potential","Junction Tree"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="none"/>
# <!-- Y -->
# <g class="node" id="node1"><title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-158.3">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2"><title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1"><title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M41.5703,-146.834C51.7499,-136.938 65.5239,-123.546 77.0306,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="79.4741,-114.865 84.2043,-105.385 74.5945,-109.846 79.4741,-114.865" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3"><title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-14.3">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6"><title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.599,-72.055C105.746,-64.1446 108.353,-54.5398 110.756,-45.6879" fill="none" stroke="black"/>
# <polygon fill="black" points="114.201,-46.3567 113.443,-35.789 107.446,-44.523 114.201,-46.3567" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4"><title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-158.3">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3"><title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.697C99,-135.983 99,-126.712 99,-118.112" fill="none" stroke="black"/>
# <polygon fill="black" points="102.5,-118.104 99,-108.104 95.5001,-118.104 102.5,-118.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5"><title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-158.3">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4"><title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M156.43,-146.834C146.25,-136.938 132.476,-123.546 120.969,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="123.405,-109.846 113.796,-105.385 118.526,-114.865 123.405,-109.846" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7"><title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.816,-144.433C155.73,-120.088 138.679,-74.4035 127.854,-45.4019" fill="none" stroke="black"/>
# <polygon fill="black" points="131.084,-44.0466 124.308,-35.9017 124.526,-46.4944 131.084,-44.0466" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6"><title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-86.3">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5"><title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M179.813,-144.765C184.418,-136.283 190.155,-125.714 195.321,-116.197" fill="none" stroke="black"/>
# <polygon fill="black" points="198.539,-117.606 200.234,-107.147 192.387,-114.266 198.539,-117.606" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7"><title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-14.3">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2"><title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.6966C209,-63.9827 209,-54.7125 209,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="212.5,-46.1043 209,-36.1043 205.5,-46.1044 212.5,-46.1043" stroke="black"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table>
# <tr><th colspan='3'></th><th colspan='2' style='background-color:#AAAAAA'><center>X</center></th></tr>
# <tr><th style='background-color:#AAAAAA'><center>Y</center></th><th style='background-color:#AAAAAA'><center>Z2</center></th><th style='background-color:#AAAAAA'><center>Z1</center></th><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='background-color:#BBBBBB;' rowspan = '4'><center>0</center></th><td style='background-color:#8bf264;text-align:right;'>0.9006</td><td style='background-color:#f28b64;text-align:right;'>0.0994</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>1</center></th><td style='background-color:#de9f64;text-align:right;'>0.2550</td><td style='background-color:#9fde64;text-align:right;'>0.7450</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><td style='background-color:#88f564;text-align:right;'>0.9289</td><td style='background-color:#f58864;text-align:right;'>0.0711</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>1</center></th><td style='background-color:#95e864;text-align:right;'>0.8266</td><td style='background-color:#e89564;text-align:right;'>0.1734</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='background-color:#BBBBBB;' rowspan = '4'><center>1</center></th><td style='background-color:#b9c464;text-align:right;'>0.5410</td><td style='background-color:#c4b964;text-align:right;'>0.4590</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>1</center></th><td style='background-color:#b6c764;text-align:right;'>0.5697</td><td style='background-color:#c7b664;text-align:right;'>0.4303</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><td style='background-color:#c0bd64;text-align:right;'>0.4881</td><td style='background-color:#bdc064;text-align:right;'>0.5119</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>1</center></th><td style='background-color:#c5b864;text-align:right;'>0.4468</td><td style='background-color:#b8c564;text-align:right;'>0.5532</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>potential</small></div></td><td style="border-top:hidden;border-bottom:hidde

# %% [markdown]
# <h3>aGrUM/pyAgrum use as much as possible techniques of relevance reasonning to reduce the complexity of the inference.</h3>

# %%
ie.setEvidence({"X":0})
gnb.sideBySide(ie,gnb.getDot(ie.joinTree().toDotWithNames(bn)),
               captions=["","Join tree optimized for hard evidence on X"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="none"/>
# <!-- Y -->
# <g class="node" id="node1"><title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-158.3">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2"><title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1"><title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M41.5703,-146.834C51.7499,-136.938 65.5239,-123.546 77.0306,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="79.4741,-114.865 84.2043,-105.385 74.5945,-109.846 79.4741,-114.865" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3"><title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-14.3">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6"><title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.599,-72.055C105.746,-64.1446 108.353,-54.5398 110.756,-45.6879" fill="none" stroke="black"/>
# <polygon fill="black" points="114.201,-46.3567 113.443,-35.789 107.446,-44.523 114.201,-46.3567" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4"><title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-158.3">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3"><title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.697C99,-135.983 99,-126.712 99,-118.112" fill="none" stroke="black"/>
# <polygon fill="black" points="102.5,-118.104 99,-108.104 95.5001,-118.104 102.5,-118.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5"><title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-158.3">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4"><title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M156.43,-146.834C146.25,-136.938 132.476,-123.546 120.969,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="123.405,-109.846 113.796,-105.385 118.526,-114.865 123.405,-109.846" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7"><title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.816,-144.433C155.73,-120.088 138.679,-74.4035 127.854,-45.4019" fill="none" stroke="black"/>
# <polygon fill="black" points="131.084,-44.0466 124.308,-35.9017 124.526,-46.4944 131.084,-44.0466" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6"><title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-86.3">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5"><title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M179.813,-144.765C184.418,-136.283 190.155,-125.714 195.321,-116.197" fill="none" stroke="black"/>
# <polygon fill="black" points="198.539,-117.606 200.234,-107.147 192.387,-114.266 198.539,-117.606" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7"><title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-14.3">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2"><title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.6966C209,-63.9827 209,-54.7125 209,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="212.5,-46.1043 209,-36.1043 205.5,-46.1044 212.5,-46.1043" stroke="black"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><div align="left"><ul><li><b>hard evidence</b><br/>X</li></ul></div></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Lazy Propagation on this BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Evidence and targets</small></div></td></tr></table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small></small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Join tree optimized for hard evidence on X</small></div></td></tr></table>

# %%
ie.updateEvidence({"X":[0.1,0.9]})
gnb.sideBySide(ie,gnb.getDot(ie.joinTree().toDotWithNames(bn)),
               captions=["","Join tree optimized for soft evidence on X"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="none"/>
# <!-- Y -->
# <g class="node" id="node1"><title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-158.3">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2"><title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1"><title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M41.5703,-146.834C51.7499,-136.938 65.5239,-123.546 77.0306,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="79.4741,-114.865 84.2043,-105.385 74.5945,-109.846 79.4741,-114.865" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3"><title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-14.3">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6"><title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.599,-72.055C105.746,-64.1446 108.353,-54.5398 110.756,-45.6879" fill="none" stroke="black"/>
# <polygon fill="black" points="114.201,-46.3567 113.443,-35.789 107.446,-44.523 114.201,-46.3567" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4"><title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-158.3">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3"><title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.697C99,-135.983 99,-126.712 99,-118.112" fill="none" stroke="black"/>
# <polygon fill="black" points="102.5,-118.104 99,-108.104 95.5001,-118.104 102.5,-118.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5"><title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-158.3">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4"><title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M156.43,-146.834C146.25,-136.938 132.476,-123.546 120.969,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="123.405,-109.846 113.796,-105.385 118.526,-114.865 123.405,-109.846" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7"><title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.816,-144.433C155.73,-120.088 138.679,-74.4035 127.854,-45.4019" fill="none" stroke="black"/>
# <polygon fill="black" points="131.084,-44.0466 124.308,-35.9017 124.526,-46.4944 131.084,-44.0466" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6"><title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-86.3">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5"><title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M179.813,-144.765C184.418,-136.283 190.155,-125.714 195.321,-116.197" fill="none" stroke="black"/>
# <polygon fill="black" points="198.539,-117.606 200.234,-107.147 192.387,-114.266 198.539,-117.606" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7"><title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-14.3">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2"><title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.6966C209,-63.9827 209,-54.7125 209,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="212.5,-46.1043 209,-36.1043 205.5,-46.1044 212.5,-46.1043" stroke="black"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><div align="left"><ul><li><b>soft evidence</b><br/>X</li></ul></div></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Lazy Propagation on this BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Evidence and targets</small></div></td></tr></table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small></small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Join tree optimized for soft evidence on X</small></div></td></tr></table>

# %%
ie.updateEvidence({"Y":0,"X":0,3:[0.1,0.9],"Z1":[0.4,0.6]})
gnb.sideBySide(ie,gnb.getDot(ie.joinTree().toDotWithNames(bn)),
               captions=["","Join tree optimized for hard evidence on X and Y, soft on Z2 and Z1"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="none"/>
# <!-- Y -->
# <g class="node" id="node1"><title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-158.3">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2"><title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1"><title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M41.5703,-146.834C51.7499,-136.938 65.5239,-123.546 77.0306,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="79.4741,-114.865 84.2043,-105.385 74.5945,-109.846 79.4741,-114.865" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3"><title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-14.3">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6"><title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.599,-72.055C105.746,-64.1446 108.353,-54.5398 110.756,-45.6879" fill="none" stroke="black"/>
# <polygon fill="black" points="114.201,-46.3567 113.443,-35.789 107.446,-44.523 114.201,-46.3567" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4"><title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-158.3">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3"><title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.697C99,-135.983 99,-126.712 99,-118.112" fill="none" stroke="black"/>
# <polygon fill="black" points="102.5,-118.104 99,-108.104 95.5001,-118.104 102.5,-118.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5"><title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-158.3">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4"><title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M156.43,-146.834C146.25,-136.938 132.476,-123.546 120.969,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="123.405,-109.846 113.796,-105.385 118.526,-114.865 123.405,-109.846" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7"><title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.816,-144.433C155.73,-120.088 138.679,-74.4035 127.854,-45.4019" fill="none" stroke="black"/>
# <polygon fill="black" points="131.084,-44.0466 124.308,-35.9017 124.526,-46.4944 131.084,-44.0466" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6"><title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-86.3">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5"><title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M179.813,-144.765C184.418,-136.283 190.155,-125.714 195.321,-116.197" fill="none" stroke="black"/>
# <polygon fill="black" points="198.539,-117.606 200.234,-107.147 192.387,-114.266 198.539,-117.606" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7"><title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-14.3">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2"><title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.6966C209,-63.9827 209,-54.7125 209,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="212.5,-46.1043 209,-36.1043 205.5,-46.1044 212.5,-46.1043" stroke="black"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><div align="left"><ul><li><b>hard evidence</b><br/>Y, X</li><li><b>soft evidence</b><br/>Z2, Z1</li></ul></div></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Lazy Propagation on this BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Evidence and targets</small></div></td></tr></table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small></small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Join tree optimized for hard evidence on X and Y, soft on Z2 and Z1</small></div></td></tr></table>

# %%
ie.setEvidence({"X":0})
ie.setTargets({"T1","Z1"})
gnb.sideBySide(ie,gnb.getDot(ie.joinTree().toDotWithNames(bn)),
               captions=["","Join tree optimized for hard evidence on X and targets T1,Z1"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="none"/>
# <!-- Y -->
# <g class="node" id="node1"><title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-158.3">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2"><title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1"><title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M41.5703,-146.834C51.7499,-136.938 65.5239,-123.546 77.0306,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="79.4741,-114.865 84.2043,-105.385 74.5945,-109.846 79.4741,-114.865" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3"><title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-14.3">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6"><title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.599,-72.055C105.746,-64.1446 108.353,-54.5398 110.756,-45.6879" fill="none" stroke="black"/>
# <polygon fill="black" points="114.201,-46.3567 113.443,-35.789 107.446,-44.523 114.201,-46.3567" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4"><title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-158.3">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3"><title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.697C99,-135.983 99,-126.712 99,-118.112" fill="none" stroke="black"/>
# <polygon fill="black" points="102.5,-118.104 99,-108.104 95.5001,-118.104 102.5,-118.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5"><title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-158.3">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4"><title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M156.43,-146.834C146.25,-136.938 132.476,-123.546 120.969,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="123.405,-109.846 113.796,-105.385 118.526,-114.865 123.405,-109.846" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7"><title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.816,-144.433C155.73,-120.088 138.679,-74.4035 127.854,-45.4019" fill="none" stroke="black"/>
# <polygon fill="black" points="131.084,-44.0466 124.308,-35.9017 124.526,-46.4944 131.084,-44.0466" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6"><title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-86.3">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5"><title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M179.813,-144.765C184.418,-136.283 190.155,-125.714 195.321,-116.197" fill="none" stroke="black"/>
# <polygon fill="black" points="198.539,-117.606 200.234,-107.147 192.387,-114.266 198.539,-117.606" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7"><title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-14.3">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2"><title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.6966C209,-63.9827 209,-54.7125 209,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="212.5,-46.1043 209,-36.1043 205.5,-46.1044 212.5,-46.1043" stroke="black"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><div align="left"><ul><li><b>hard evidence</b><br/>X</li><li><b>target(s)</b><br/>T1, Z1</li></ul></div></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Lazy Propagation on this BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Evidence and targets</small></div></td></tr></table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small></small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Join tree optimized for hard evidence on X and targets T1,Z1</small></div></td></tr></table>

# %%
ie.updateEvidence({"Y":0,"X":0,3:[0.1,0.9],"Z1":[0.4,0.6]})
ie.addJointTarget(["Z2","Z1","T1"])

gnb.sideBySide(ie,
               gnb.getDot(ie.joinTree().toDotWithNames(bn)),
               captions=["","Join tree optimized for hard evidence on X and targets T1,Z1"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="none"/>
# <!-- Y -->
# <g class="node" id="node1"><title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-158.3">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2"><title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1"><title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M41.5703,-146.834C51.7499,-136.938 65.5239,-123.546 77.0306,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="79.4741,-114.865 84.2043,-105.385 74.5945,-109.846 79.4741,-114.865" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3"><title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-14.3">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6"><title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.599,-72.055C105.746,-64.1446 108.353,-54.5398 110.756,-45.6879" fill="none" stroke="black"/>
# <polygon fill="black" points="114.201,-46.3567 113.443,-35.789 107.446,-44.523 114.201,-46.3567" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4"><title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-158.3">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3"><title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.697C99,-135.983 99,-126.712 99,-118.112" fill="none" stroke="black"/>
# <polygon fill="black" points="102.5,-118.104 99,-108.104 95.5001,-118.104 102.5,-118.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5"><title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-158.3">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4"><title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M156.43,-146.834C146.25,-136.938 132.476,-123.546 120.969,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="123.405,-109.846 113.796,-105.385 118.526,-114.865 123.405,-109.846" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7"><title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.816,-144.433C155.73,-120.088 138.679,-74.4035 127.854,-45.4019" fill="none" stroke="black"/>
# <polygon fill="black" points="131.084,-44.0466 124.308,-35.9017 124.526,-46.4944 131.084,-44.0466" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6"><title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-86.3">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5"><title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M179.813,-144.765C184.418,-136.283 190.155,-125.714 195.321,-116.197" fill="none" stroke="black"/>
# <polygon fill="black" points="198.539,-117.606 200.234,-107.147 192.387,-114.266 198.539,-117.606" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7"><title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-14.3">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2"><title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.6966C209,-63.9827 209,-54.7125 209,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="212.5,-46.1043 209,-36.1043 205.5,-46.1044 212.5,-46.1043" stroke="black"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><div align="left"><ul><li><b>hard evidence</b><br/>Y, X</li><li><b>soft evidence</b><br/>Z2, Z1</li><li><b>target(s)</b><br/>T1, Z1</li><li><b>Joint target(s)</b><br/>[Z2, Z1, T1]</li></ul></div></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Lazy Propagation on this BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Evidence and targets</small></div></td></tr></table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small></small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Join tree optimized for hard evidence on X and targets T1,Z1</small></div></td></tr></table>

# %%
ie.makeInference()
ie.jointPosterior(["Z2","Z1","T1"])
# Out:
# <pyAgrum.pyAgrum.Potential_double; proxy of <Swig Object of type 'gum::Potential< double > *' at 0x7ff0b87fd960> >

# %%
ie.jointPosterior(["Z2","Z1"])
# Out:
# <pyAgrum.pyAgrum.Potential_double; proxy of <Swig Object of type 'gum::Potential< double > *' at 0x7ff0b87fdc90> >

# %%
# this will not work 
# ie.jointPosterior(["Z3","Z1"])
# UndefinedElement:  no joint target containing {4,5}could be found

# %%
ie.addJointTarget(["Z2","Z1"])
gnb.sideBySide(ie,
               gnb.getDot(ie.joinTree().toDotWithNames(bn)),
              captions=['','JoinTree'])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="188pt" viewBox="0.00 0.00 244.00 188.00" width="244pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-184 240,-184 240,4 -4,4" stroke="none"/>
# <!-- Y -->
# <g class="node" id="node1"><title>Y</title>
# <g id="a_node1"><a xlink:title="(0) Y">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-158.3">Y</text>
# </a>
# </g>
# </g>
# <!-- X -->
# <g class="node" id="node2"><title>X</title>
# <g id="a_node2"><a xlink:title="(1) X">
# <ellipse cx="99" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">X</text>
# </a>
# </g>
# </g>
# <!-- Y&#45;&gt;X -->
# <g class="edge" id="edge1"><title>Y-&gt;X</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M41.5703,-146.834C51.7499,-136.938 65.5239,-123.546 77.0306,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="79.4741,-114.865 84.2043,-105.385 74.5945,-109.846 79.4741,-114.865" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T1 -->
# <g class="node" id="node3"><title>T1</title>
# <g id="a_node3"><a xlink:title="(2) T1">
# <ellipse cx="118" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="118" y="-14.3">T1</text>
# </a>
# </g>
# </g>
# <!-- X&#45;&gt;T1 -->
# <g class="edge" id="edge6"><title>X-&gt;T1</title>
# <g id="a_edge6"><a xlink:title="(1, 2) : ">
# <path d="M103.599,-72.055C105.746,-64.1446 108.353,-54.5398 110.756,-45.6879" fill="none" stroke="black"/>
# <polygon fill="black" points="114.201,-46.3567 113.443,-35.789 107.446,-44.523 114.201,-46.3567" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z2 -->
# <g class="node" id="node4"><title>Z2</title>
# <g id="a_node4"><a xlink:title="(3) Z2">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-158.3">Z2</text>
# </a>
# </g>
# </g>
# <!-- Z2&#45;&gt;X -->
# <g class="edge" id="edge3"><title>Z2-&gt;X</title>
# <g id="a_edge3"><a xlink:title="(3, 1) : ">
# <path d="M99,-143.697C99,-135.983 99,-126.712 99,-118.112" fill="none" stroke="black"/>
# <polygon fill="black" points="102.5,-118.104 99,-108.104 95.5001,-118.104 102.5,-118.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1 -->
# <g class="node" id="node5"><title>Z1</title>
# <g id="a_node5"><a xlink:title="(4) Z1">
# <ellipse cx="171" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="171" y="-158.3">Z1</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;X -->
# <g class="edge" id="edge4"><title>Z1-&gt;X</title>
# <g id="a_edge4"><a xlink:title="(4, 1) : ">
# <path d="M156.43,-146.834C146.25,-136.938 132.476,-123.546 120.969,-112.359" fill="none" stroke="black"/>
# <polygon fill="black" points="123.405,-109.846 113.796,-105.385 118.526,-114.865 123.405,-109.846" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;T1 -->
# <g class="edge" id="edge7"><title>Z1-&gt;T1</title>
# <g id="a_edge7"><a xlink:title="(4, 2) : ">
# <path d="M164.816,-144.433C155.73,-120.088 138.679,-74.4035 127.854,-45.4019" fill="none" stroke="black"/>
# <polygon fill="black" points="131.084,-44.0466 124.308,-35.9017 124.526,-46.4944 131.084,-44.0466" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- Z3 -->
# <g class="node" id="node6"><title>Z3</title>
# <g id="a_node6"><a xlink:title="(5) Z3">
# <ellipse cx="209" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-86.3">Z3</text>
# </a>
# </g>
# </g>
# <!-- Z1&#45;&gt;Z3 -->
# <g class="edge" id="edge5"><title>Z1-&gt;Z3</title>
# <g id="a_edge5"><a xlink:title="(4, 5) : ">
# <path d="M179.813,-144.765C184.418,-136.283 190.155,-125.714 195.321,-116.197" fill="none" stroke="black"/>
# <polygon fill="black" points="198.539,-117.606 200.234,-107.147 192.387,-114.266 198.539,-117.606" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- T2 -->
# <g class="node" id="node7"><title>T2</title>
# <g id="a_node7"><a xlink:title="(6) T2">
# <ellipse cx="209" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-14.3">T2</text>
# </a>
# </g>
# </g>
# <!-- Z3&#45;&gt;T2 -->
# <g class="edge" id="edge2"><title>Z3-&gt;T2</title>
# <g id="a_edge2"><a xlink:title="(5, 6) : ">
# <path d="M209,-71.6966C209,-63.9827 209,-54.7125 209,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="212.5,-46.1043 209,-36.1043 205.5,-46.1044 212.5,-46.1043" stroke="black"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><div align="left"><ul><li><b>hard evidence</b><br/>Y, X</li><li><b>soft evidence</b><br/>Z2, Z1</li><li><b>target(s)</b><br/>T1, Z1</li><li><b>Joint target(s)</b><br/>[Z2, Z1, T1]</li></ul></div></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Lazy Propagation on this BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Evidence and targets</small></div></td></tr></table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small></small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>JoinTree</small></div></td></tr></table>
