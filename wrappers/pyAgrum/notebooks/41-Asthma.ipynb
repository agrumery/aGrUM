# %% [markdown]
# <a href="http://agrum.org" target="blank"><img src="http://agrum.gitlab.io/theme/img/logoAgrum.png" align="left" style="height:100px"/></a><a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br /><span xmlns:dct="http://purl.org/dc/terms/" href="http://purl.org/dc/dcmitype/Dataset" property="dct:title" rel="dct:type">This pyAgrum's notebook</span> is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.

# %%
#from pylab import *
import matplotlib.pyplot as plt

# import the computation tools of aGrUM
import pyAgrum as gum

# import the graphical display functions
import pyAgrum.lib.notebook as gnb

# %%
# load the "asthme" Bayesian network
bn=gum.loadBN('res/asthma.bif')

# %%
# display the Bayesian network
gnb.showBN(bn,size='7',format='png',nodeColor={n:0.9 for n in bn.names()},cmap=plt.get_cmap('Blues'))

# %%
# display the conditional probability table of asthme given pollution
gnb.showPotential(bn.cpt(bn.idFromName('asthma')),digits=4)
# Out:
# <table><tr><th colspan='1'></th><th colspan='2' style='background-color:#AAAAAA'><center>asthma</center></th></tr><tr><th style='background-color:#AAAAAA'><center>pollution</center></th><th style='background-color:#BBBBBB'><center>crisis</center></th><th style='background-color:#BBBBBB'><center>no_crisis</center></th></tr><tr><th style='background-color:#BBBBBB'><center>1</center></th><td style='background-color:#f28b64;text-align:right;'>0.1000</td><td style='background-color:#8bf264;text-align:right;'>0.9000</td></tr><tr><th style='background-color:#BBBBBB'><center>2</center></th><td style='background-color:#e39a64;text-align:right;'>0.2113</td><td style='background-color:#9ae364;text-align:right;'>0.7887</td></tr><tr><th style='background-color:#BBBBBB'><center>3</center></th><td style='background-color:#e59864;text-align:right;'>0.1972</td><td style='background-color:#98e564;text-align:right;'>0.8028</td></tr><tr><th style='background-color:#BBBBBB'><center>4</center></th><td style='background-color:#daa364;text-align:right;'>0.2824</td><td style='background-color:#a3da64;text-align:right;'>0.7176</td></tr><tr><th style='background-color:#BBBBBB'><center>5</center></th><td style='background-color:#c2bb64;text-align:right;'>0.4746</td><td style='background-color:#bbc264;text-align:right;'>0.5254</td></tr><tr><th style='background-color:#BBBBBB'><center>6</center></th><td style='background-color:#bcc164;text-align:right;'>0.5230</td><td style='background-color:#c1bc64;text-align:right;'>0.4770</td></tr><tr><th style='background-color:#BBBBBB'><center>7</center></th><td style='background-color:#add064;text-align:right;'>0.6341</td><td style='background-color:#d0ad64;text-align:right;'>0.3659</td></tr><tr><th style='background-color:#BBBBBB'><center>8</center></th><td style='background-color:#95e864;text-align:right;'>0.8257</td><td style='background-color:#e89564;text-align:right;'>0.1743</td></tr><tr><th style='background-color:#BBBBBB'><center>9</center></th><td style='background-color:#91ec64;text-align:right;'>0.8537</td><td style='background-color:#ec9164;text-align:right;'>0.1463</td></tr><tr><th style='background-color:#BBBBBB'><center>10</center></th><td style='background-color:#8af364;text-align:right;'>0.9091</td><td style='background-color:#f38a64;text-align:right;'>0.0909</td></tr></table>

# %%
# display the probability distribution of Variable "trafic"
gnb.showPosterior (bn, {}, "traffic" )

# %%
# display the probability distribution of Variable "pollution"
gnb.showPosterior ( bn, {}, "pollution")

# %%
# display the distribution somewhat differently
gum.getPosterior ( bn, {}, "pollution")
# Out:
# (gum::Potential<double>@0x55f2654ef2f0) <pollution:1> :: 0 /<pollution:2> :: 0.0355395 /<pollution:3> :: 0.423343 /<pollution:4> :: 0.278755 /<pollution:5> :: 0.147469 /<pollution:6> :: 0.0628773 /<pollution:7> :: 0.0164284 /<pollution:8> :: 0.0218519 /<pollution:9> :: 0.00822278 /<pollution:10> :: 0.00551375

# %%
# more interesting: display the posterior distribution of "asthme"
# given that we observed that heure=8 and meteo=nuageux
gnb.showPosterior (bn, {'hour' : 8, 'weather' : 'cloudy'}, "asthma" )

# %%
# show the posterior distributions of all the variables given that
# we observed that heure=8 and meteo=nuageux.
# the tables in beige represent the observations
gnb.showInference(bn,size="7",evs={'hour' : 8, 'weather' : 'cloudy'})

# %%
gnb.showInference(bn,size="7",evs={'hour': 7, 'accident' : 'yes'})
