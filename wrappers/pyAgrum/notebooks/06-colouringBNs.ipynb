# %%
# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

bn=gum.fastBN("a->b->c->d;b->e->d->f;g->c")
gnb.sideBySide(bn,gnb.getInference(bn))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="288pt" viewBox="0.00 0.00 116.24 288.00" width="116pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.86747 0.86747) rotate(0) translate(4 328)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-328 130,-328 130,4 -4,4" stroke="none"/>
# <!-- a -->
# <g class="node" id="node1"><title>a</title>
# <g id="a_node1"><a xlink:title="(0) a">
# <ellipse cx="99" cy="-306" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-302.3">a</text>
# </a>
# </g>
# </g>
# <!-- b -->
# <g class="node" id="node2"><title>b</title>
# <g id="a_node2"><a xlink:title="(1) b">
# <ellipse cx="99" cy="-234" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-230.3">b</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g class="edge" id="edge1"><title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M99,-287.697C99,-279.983 99,-270.712 99,-262.112" fill="none" stroke="black"/>
# <polygon fill="black" points="102.5,-262.104 99,-252.104 95.5001,-262.104 102.5,-262.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- c -->
# <g class="node" id="node3"><title>c</title>
# <g id="a_node3"><a xlink:title="(2) c">
# <ellipse cx="27" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-158.3">c</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g class="edge" id="edge7"><title>b-&gt;c</title>
# <g id="a_edge7"><a xlink:title="(1, 2) : ">
# <path d="M84.4297,-218.834C74.2501,-208.938 60.4761,-195.546 48.9694,-184.359" fill="none" stroke="black"/>
# <polygon fill="black" points="51.4055,-181.846 41.7957,-177.385 46.5259,-186.865 51.4055,-181.846" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g class="node" id="node5"><title>e</title>
# <g id="a_node5"><a xlink:title="(4) e">
# <ellipse cx="99" cy="-162" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-158.3">e</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g class="edge" id="edge2"><title>b-&gt;e</title>
# <g id="a_edge2"><a xlink:title="(1, 4) : ">
# <path d="M99,-215.697C99,-207.983 99,-198.712 99,-190.112" fill="none" stroke="black"/>
# <polygon fill="black" points="102.5,-190.104 99,-180.104 95.5001,-190.104 102.5,-190.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g class="node" id="node4"><title>d</title>
# <g id="a_node4"><a xlink:title="(3) d">
# <ellipse cx="63" cy="-90" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-86.3">d</text>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g class="edge" id="edge5"><title>c-&gt;d</title>
# <g id="a_edge5"><a xlink:title="(2, 3) : ">
# <path d="M35.3496,-144.765C39.7115,-136.283 45.1469,-125.714 50.0413,-116.197" fill="none" stroke="black"/>
# <polygon fill="black" points="53.2346,-117.641 54.6957,-107.147 47.0096,-114.439 53.2346,-117.641" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- f -->
# <g class="node" id="node6"><title>f</title>
# <g id="a_node6"><a xlink:title="(5) f">
# <ellipse cx="63" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-14.3">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g class="edge" id="edge4"><title>d-&gt;f</title>
# <g id="a_edge4"><a xlink:title="(3, 5) : ">
# <path d="M63,-71.6966C63,-63.9827 63,-54.7125 63,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="66.5001,-46.1043 63,-36.1043 59.5001,-46.1044 66.5001,-46.1043" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g class="edge" id="edge3"><title>e-&gt;d</title>
# <g id="a_edge3"><a xlink:title="(4, 3) : ">
# <path d="M90.6504,-144.765C86.2885,-136.283 80.8531,-125.714 75.9587,-116.197" fill="none" stroke="black"/>
# <polygon fill="black" points="78.9904,-114.439 71.3043,-107.147 72.7654,-117.641 78.9904,-114.439" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- g -->
# <g class="node" id="node7"><title>g</title>
# <g id="a_node7"><a xlink:title="(6) g">
# <ellipse cx="27" cy="-234" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-230.3">g</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g class="edge" id="edge6"><title>g-&gt;c</title>
# <g id="a_edge6"><a xlink:title="(6, 2) : ">
# <path d="M27,-215.697C27,-207.983 27,-198.712 27,-190.112" fill="none" stroke="black"/>
# <polygon fill="black" points="30.5001,-190.104 27,-180.104 23.5001,-190.104 30.5001,-190.104" stroke="black"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="...

# %%
def value(n):
    return 0.5 if n in "aeiou" else 0.7
def arcvalue(a):
    return (10-a[0])*a[1]
gnb.showBN(bn,
           vals={n:value(n) for n in bn.names()},
           arcvals={a:arcvalue(a) for a in bn.arcs()})
# Out:
# <svg height="288pt" viewBox="0.00 0.00 116.24 288.00" width="116pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.86747 0.86747) rotate(0) translate(4 328)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-328 130,-328 130,4 -4,4" stroke="none"/>
# <!-- a -->
# <g class="node" id="node1"><title>a</title>
# <g id="a_node1"><a xlink:title="(0) a : 0.50000">
# <ellipse cx="99" cy="-306" fill="#80c066" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-302.3">a</text>
# </a>
# </g>
# </g>
# <!-- b -->
# <g class="node" id="node2"><title>b</title>
# <g id="a_node2"><a xlink:title="(1) b : 0.70000">
# <ellipse cx="99" cy="-234" fill="#b3d966" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-230.3">b</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g class="edge" id="edge1"><title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : 10">
# <path d="M99,-287.697C99,-279.983 99,-270.712 99,-262.112" fill="none" stroke="black" stroke-width="0.457143"/>
# <polygon fill="black" points="102.5,-262.104 99,-252.104 95.5001,-262.104 102.5,-262.104" stroke="black" stroke-width="0.457143"/>
# </a>
# </g>
# </g>
# <!-- c -->
# <g class="node" id="node3"><title>c</title>
# <g id="a_node3"><a xlink:title="(2) c : 0.70000">
# <ellipse cx="27" cy="-162" fill="#b3d966" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-158.3">c</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g class="edge" id="edge7"><title>b-&gt;c</title>
# <g id="a_edge7"><a xlink:title="(1, 2) : 18">
# <path d="M84.4297,-218.834C74.2501,-208.938 60.4761,-195.546 48.9694,-184.359" fill="none" stroke="black" stroke-width="1.88571"/>
# <polygon fill="black" points="51.4055,-181.846 41.7957,-177.385 46.5259,-186.865 51.4055,-181.846" stroke="black" stroke-width="1.88571"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g class="node" id="node5"><title>e</title>
# <g id="a_node5"><a xlink:title="(4) e : 0.50000">
# <ellipse cx="99" cy="-162" fill="#80c066" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-158.3">e</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g class="edge" id="edge2"><title>b-&gt;e</title>
# <g id="a_edge2"><a xlink:title="(1, 4) : 36">
# <path d="M99,-215.697C99,-207.983 99,-198.712 99,-190.112" fill="none" stroke="black" stroke-width="5.1"/>
# <polygon fill="black" points="103.463,-190.104 99,-180.104 94.5376,-190.104 103.463,-190.104" stroke="black" stroke-width="5.1"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g class="node" id="node4"><title>d</title>
# <g id="a_node4"><a xlink:title="(3) d : 0.70000">
# <ellipse cx="63" cy="-90" fill="#b3d966" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-86.3">d</text>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g class="edge" id="edge5"><title>c-&gt;d</title>
# <g id="a_edge5"><a xlink:title="(2, 3) : 24">
# <path d="M35.3496,-144.765C39.7115,-136.283 45.1469,-125.714 50.0413,-116.197" fill="none" stroke="black" stroke-width="2.95714"/>
# <polygon fill="black" points="53.2346,-117.641 54.6957,-107.147 47.0096,-114.439 53.2346,-117.641" stroke="black" stroke-width="2.95714"/>
# </a>
# </g>
# </g>
# <!-- f -->
# <g class="node" id="node6"><title>f</title>
# <g id="a_node6"><a xlink:title="(5) f : 0.70000">
# <ellipse cx="63" cy="-18" fill="#b3d966" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-14.3">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g class="edge" id="edge4"><title>d-&gt;f</title>
# <g id="a_edge4"><a xlink:title="(3, 5) : 35">
# <path d="M63,-71.6966C63,-63.9827 63,-54.7125 63,-46.1124" fill="none" stroke="black" stroke-width="4.92143"/>
# <polygon fill="black" points="67.3063,-46.1043 63,-36.1043 58.6938,-46.1044 67.3063,-46.1043" stroke="black" stroke-width="4.92143"/>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g class="edge" id="edge3"><title>e-&gt;d</title>
# <g id="a_edge3"><a xlink:title="(4, 3) : 18">
# <path d="M90.6504,-144.765C86.2885,-136.283 80.8531,-125.714 75.9587,-116.197" fill="none" stroke="black" stroke-width="1.88571"/>
# <polygon fill="black" points="78.9904,-114.439 71.3043,-107.147 72.7654,-117.641 78.9904,-114.439" stroke="black" stroke-width="1.88571"/>
# </a>
# </g>
# </g>
# <!-- g -->
# <g class="node" id="node7"><title>g</title>
# <g id="a_node7"><a xlink:title="(6) g : 0.70000">
# <ellipse cx="27" cy="-234" fill="#b3d966" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-230.3">g</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g class="edge" id="edge6"><title>g-&gt;c</title>
# <g id="a_edge6"><a xlink:title="(6, 2) : 8">
# <path d="M27,-215.697C27,-207.983 27,-198.712 27,-190.112" fill="none" stroke="black" stroke-width="0.1"/>
# <polygon fill="black" points="30.5001,-190.104 27,-180.104 23.5001,-190.104 30.5001,-190.104" stroke="black" stroke-width="0.1"/>
# </a>
# </g>
# </g>
# </g>
# </svg>

# %%
gnb.showInference(bn,
           targets={"a","g","f"},
           vals={n:value(n) for n in bn.names()},
           arcvals={a:arcvalue(a) for a in bn.arcs()})

# %%
gnb.sideBySide(gnb.getBN(bn,
                         vals={n:value(n) for n in bn.names()},
                         arcvals={a:arcvalue(a) for a in bn.arcs()}),
               gnb.getInference(bn,
                                vals={n:value(n) for n in bn.names()},
                                arcvals={a:arcvalue(a) for a in bn.arcs()})
              )
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="288pt" viewBox="0.00 0.00 116.24 288.00" width="116pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.86747 0.86747) rotate(0) translate(4 328)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-328 130,-328 130,4 -4,4" stroke="none"/>
# <!-- a -->
# <g class="node" id="node1"><title>a</title>
# <g id="a_node1"><a xlink:title="(0) a : 0.50000">
# <ellipse cx="99" cy="-306" fill="#80c066" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-302.3">a</text>
# </a>
# </g>
# </g>
# <!-- b -->
# <g class="node" id="node2"><title>b</title>
# <g id="a_node2"><a xlink:title="(1) b : 0.70000">
# <ellipse cx="99" cy="-234" fill="#b3d966" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-230.3">b</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g class="edge" id="edge1"><title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : 10">
# <path d="M99,-287.697C99,-279.983 99,-270.712 99,-262.112" fill="none" stroke="black" stroke-width="0.457143"/>
# <polygon fill="black" points="102.5,-262.104 99,-252.104 95.5001,-262.104 102.5,-262.104" stroke="black" stroke-width="0.457143"/>
# </a>
# </g>
# </g>
# <!-- c -->
# <g class="node" id="node3"><title>c</title>
# <g id="a_node3"><a xlink:title="(2) c : 0.70000">
# <ellipse cx="27" cy="-162" fill="#b3d966" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-158.3">c</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g class="edge" id="edge7"><title>b-&gt;c</title>
# <g id="a_edge7"><a xlink:title="(1, 2) : 18">
# <path d="M84.4297,-218.834C74.2501,-208.938 60.4761,-195.546 48.9694,-184.359" fill="none" stroke="black" stroke-width="1.88571"/>
# <polygon fill="black" points="51.4055,-181.846 41.7957,-177.385 46.5259,-186.865 51.4055,-181.846" stroke="black" stroke-width="1.88571"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g class="node" id="node5"><title>e</title>
# <g id="a_node5"><a xlink:title="(4) e : 0.50000">
# <ellipse cx="99" cy="-162" fill="#80c066" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-158.3">e</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g class="edge" id="edge2"><title>b-&gt;e</title>
# <g id="a_edge2"><a xlink:title="(1, 4) : 36">
# <path d="M99,-215.697C99,-207.983 99,-198.712 99,-190.112" fill="none" stroke="black" stroke-width="5.1"/>
# <polygon fill="black" points="103.463,-190.104 99,-180.104 94.5376,-190.104 103.463,-190.104" stroke="black" stroke-width="5.1"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g class="node" id="node4"><title>d</title>
# <g id="a_node4"><a xlink:title="(3) d : 0.70000">
# <ellipse cx="63" cy="-90" fill="#b3d966" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-86.3">d</text>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g class="edge" id="edge5"><title>c-&gt;d</title>
# <g id="a_edge5"><a xlink:title="(2, 3) : 24">
# <path d="M35.3496,-144.765C39.7115,-136.283 45.1469,-125.714 50.0413,-116.197" fill="none" stroke="black" stroke-width="2.95714"/>
# <polygon fill="black" points="53.2346,-117.641 54.6957,-107.147 47.0096,-114.439 53.2346,-117.641" stroke="black" stroke-width="2.95714"/>
# </a>
# </g>
# </g>
# <!-- f -->
# <g class="node" id="node6"><title>f</title>
# <g id="a_node6"><a xlink:title="(5) f : 0.70000">
# <ellipse cx="63" cy="-18" fill="#b3d966" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-14.3">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g class="edge" id="edge4"><title>d-&gt;f</title>
# <g id="a_edge4"><a xlink:title="(3, 5) : 35">
# <path d="M63,-71.6966C63,-63.9827 63,-54.7125 63,-46.1124" fill="none" stroke="black" stroke-width="4.92143"/>
# <polygon fill="black" points="67.3063,-46.1043 63,-36.1043 58.6938,-46.1044 67.3063,-46.1043" stroke="black" stroke-width="4.92143"/>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g class="edge" id="edge3"><title>e-&gt;d</title>
# <g id="a_edge3"><a xlink:title="(4, 3) : 18">
# <path d="M90.6504,-144.765C86.2885,-136.283 80.8531,-125.714 75.9587,-116.197" fill="none" stroke="black" stroke-width="1.88571"/>
# <polygon fill="black" points="78.9904,-114.439 71.3043,-107.147 72.7654,-117.641 78.9904,-114.439" stroke="black" stroke-width="1.88571"/>
# </a>
# </g>
# </g>
# <!-- g -->
# <g class="node" id="node7"><title>g</title>
# <g id="a_node7"><a xlink:title="(6) g : 0.70000">
# <ellipse cx="27" cy="-234" fill="#b3d966" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-230.3">g</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g class="edge" id="edge6"><title>g-&gt;c</title>
# <g id="a_edge6"><a xlink:title="(6, 2) : 8">
# <path d="M27,-215.697C27,-207.983 27,-198.712 27,-190.112" fill="none" stroke="black" stroke-width="0.1"/>
# <polygon fill="black" points="30.5001,-190.104 27,-180.104 23.5001,-190.104 30.5001,-190.104" stroke="black" stroke-width="0.1"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="...

# %%
import matplotlib.pyplot as plt
mycmap=plt.get_cmap('Pastel1')
gnb.sideBySide(gnb.getBN(bn,
                         vals={n:value(n) for n in bn.names()},
                         arcvals={a:arcvalue(a) for a in bn.arcs()},
                         cmap=mycmap),
               gnb.getInference(bn,
                                vals={n:value(n) for n in bn.names()},
                                arcvals={a:arcvalue(a) for a in bn.arcs()},
                                cmap=mycmap)
              )
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="288pt" viewBox="0.00 0.00 116.24 288.00" width="116pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.86747 0.86747) rotate(0) translate(4 328)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-328 130,-328 130,4 -4,4" stroke="none"/>
# <!-- a -->
# <g class="node" id="node1"><title>a</title>
# <g id="a_node1"><a xlink:title="(0) a : 0.50000">
# <ellipse cx="99" cy="-306" fill="#fed9a6" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-302.3">a</text>
# </a>
# </g>
# </g>
# <!-- b -->
# <g class="node" id="node2"><title>b</title>
# <g id="a_node2"><a xlink:title="(1) b : 0.70000">
# <ellipse cx="99" cy="-234" fill="#e5d8bd" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-230.3">b</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g class="edge" id="edge1"><title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : 10">
# <path d="M99,-287.697C99,-279.983 99,-270.712 99,-262.112" fill="none" stroke="black" stroke-width="0.457143"/>
# <polygon fill="black" points="102.5,-262.104 99,-252.104 95.5001,-262.104 102.5,-262.104" stroke="black" stroke-width="0.457143"/>
# </a>
# </g>
# </g>
# <!-- c -->
# <g class="node" id="node3"><title>c</title>
# <g id="a_node3"><a xlink:title="(2) c : 0.70000">
# <ellipse cx="27" cy="-162" fill="#e5d8bd" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-158.3">c</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g class="edge" id="edge7"><title>b-&gt;c</title>
# <g id="a_edge7"><a xlink:title="(1, 2) : 18">
# <path d="M84.4297,-218.834C74.2501,-208.938 60.4761,-195.546 48.9694,-184.359" fill="none" stroke="black" stroke-width="1.88571"/>
# <polygon fill="black" points="51.4055,-181.846 41.7957,-177.385 46.5259,-186.865 51.4055,-181.846" stroke="black" stroke-width="1.88571"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g class="node" id="node5"><title>e</title>
# <g id="a_node5"><a xlink:title="(4) e : 0.50000">
# <ellipse cx="99" cy="-162" fill="#fed9a6" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-158.3">e</text>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g class="edge" id="edge2"><title>b-&gt;e</title>
# <g id="a_edge2"><a xlink:title="(1, 4) : 36">
# <path d="M99,-215.697C99,-207.983 99,-198.712 99,-190.112" fill="none" stroke="black" stroke-width="5.1"/>
# <polygon fill="black" points="103.463,-190.104 99,-180.104 94.5376,-190.104 103.463,-190.104" stroke="black" stroke-width="5.1"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g class="node" id="node4"><title>d</title>
# <g id="a_node4"><a xlink:title="(3) d : 0.70000">
# <ellipse cx="63" cy="-90" fill="#e5d8bd" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-86.3">d</text>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g class="edge" id="edge5"><title>c-&gt;d</title>
# <g id="a_edge5"><a xlink:title="(2, 3) : 24">
# <path d="M35.3496,-144.765C39.7115,-136.283 45.1469,-125.714 50.0413,-116.197" fill="none" stroke="black" stroke-width="2.95714"/>
# <polygon fill="black" points="53.2346,-117.641 54.6957,-107.147 47.0096,-114.439 53.2346,-117.641" stroke="black" stroke-width="2.95714"/>
# </a>
# </g>
# </g>
# <!-- f -->
# <g class="node" id="node6"><title>f</title>
# <g id="a_node6"><a xlink:title="(5) f : 0.70000">
# <ellipse cx="63" cy="-18" fill="#e5d8bd" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-14.3">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g class="edge" id="edge4"><title>d-&gt;f</title>
# <g id="a_edge4"><a xlink:title="(3, 5) : 35">
# <path d="M63,-71.6966C63,-63.9827 63,-54.7125 63,-46.1124" fill="none" stroke="black" stroke-width="4.92143"/>
# <polygon fill="black" points="67.3063,-46.1043 63,-36.1043 58.6938,-46.1044 67.3063,-46.1043" stroke="black" stroke-width="4.92143"/>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g class="edge" id="edge3"><title>e-&gt;d</title>
# <g id="a_edge3"><a xlink:title="(4, 3) : 18">
# <path d="M90.6504,-144.765C86.2885,-136.283 80.8531,-125.714 75.9587,-116.197" fill="none" stroke="black" stroke-width="1.88571"/>
# <polygon fill="black" points="78.9904,-114.439 71.3043,-107.147 72.7654,-117.641 78.9904,-114.439" stroke="black" stroke-width="1.88571"/>
# </a>
# </g>
# </g>
# <!-- g -->
# <g class="node" id="node7"><title>g</title>
# <g id="a_node7"><a xlink:title="(6) g : 0.70000">
# <ellipse cx="27" cy="-234" fill="#e5d8bd" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-230.3">g</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g class="edge" id="edge6"><title>g-&gt;c</title>
# <g id="a_edge6"><a xlink:title="(6, 2) : 8">
# <path d="M27,-215.697C27,-207.983 27,-198.712 27,-190.112" fill="none" stroke="black" stroke-width="0.1"/>
# <polygon fill="black" points="30.5001,-190.104 27,-180.104 23.5001,-190.104 30.5001,-190.104" stroke="black" stroke-width="0.1"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="...
