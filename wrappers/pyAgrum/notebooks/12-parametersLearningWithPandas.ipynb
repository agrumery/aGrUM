# %%
# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt

import os

# %% [markdown]
# Initialisation
# ==============
#
# * importing pyAgrum
# * importing pyAgrum.lib tools
# * loading a BN

# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %% [markdown]
# ## Loading two BNs

# %%
bn=gum.loadBN(os.path.join("res","asia.bif"))
bn2=gum.loadBN(os.path.join("res","asia.bif"))

gnb.sideBySide(bn,bn2,
               captions=['First bn','Second bn'])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="217pt" viewBox="0.00 0.00 288.00 216.99" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.834565 0.834565) rotate(0) translate(4 256)">
# <title>G</title>
# <!-- visit_to_Asia? -->
# <g class="node" id="node1"><title>visit_to_Asia?</title>
# <g id="a_node1"><a xlink:title="(0) visit_to_Asia?">
# <ellipse cx="62.3945" cy="-234" fill="#444444" rx="62.2891" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="62.3945" y="-230.3">visit_to_Asia?</text>
# </a>
# </g>
# </g>
# <!-- tuberculosis? -->
# <g class="node" id="node2"><title>tuberculosis?</title>
# <g id="a_node2"><a xlink:title="(1) tuberculosis?">
# <ellipse cx="62.3945" cy="-162" fill="#444444" rx="58.4896" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="62.3945" y="-158.3">tuberculosis?</text>
# </a>
# </g>
# </g>
# <!-- visit_to_Asia?&#45;&gt;tuberculosis? -->
# <g class="edge" id="edge1"><title>visit_to_Asia?-&gt;tuberculosis?</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M62.3945,-215.697C62.3945,-207.983 62.3945,-198.712 62.3945,-190.112" fill="none" stroke="black"/>
# <polygon fill="black" points="65.8946,-190.104 62.3945,-180.104 58.8946,-190.104 65.8946,-190.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer? -->
# <g class="node" id="node3"><title>tuberculos_or_cancer?</title>
# <g id="a_node3"><a xlink:title="(2) tuberculos_or_cancer?">
# <ellipse cx="124.394" cy="-90" fill="#444444" rx="93.6835" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="124.394" y="-86.3">tuberculos_or_cancer?</text>
# </a>
# </g>
# </g>
# <!-- tuberculosis?&#45;&gt;tuberculos_or_cancer? -->
# <g class="edge" id="edge3"><title>tuberculosis?-&gt;tuberculos_or_cancer?</title>
# <g id="a_edge3"><a xlink:title="(1, 2) : ">
# <path d="M77.0876,-144.411C84.697,-135.82 94.139,-125.159 102.582,-115.627" fill="none" stroke="black"/>
# <polygon fill="black" points="105.366,-117.763 109.376,-107.956 100.126,-113.121 105.366,-117.763" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- positive_XraY? -->
# <g class="node" id="node4"><title>positive_XraY?</title>
# <g id="a_node4"><a xlink:title="(3) positive_XraY?">
# <ellipse cx="124.394" cy="-18" fill="#444444" rx="67.6881" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="124.394" y="-14.3">positive_XraY?</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer?&#45;&gt;positive_XraY? -->
# <g class="edge" id="edge7"><title>tuberculos_or_cancer?-&gt;positive_XraY?</title>
# <g id="a_edge7"><a xlink:title="(2, 3) : ">
# <path d="M124.394,-71.6966C124.394,-63.9827 124.394,-54.7125 124.394,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="127.895,-46.1043 124.394,-36.1043 120.895,-46.1044 127.895,-46.1043" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- dyspnoea? -->
# <g class="node" id="node8"><title>dyspnoea?</title>
# <g id="a_node8"><a xlink:title="(7) dyspnoea?">
# <ellipse cx="273.394" cy="-18" fill="#444444" rx="50.0912" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="273.394" y="-14.3">dyspnoea?</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer?&#45;&gt;dyspnoea? -->
# <g class="edge" id="edge2"><title>tuberculos_or_cancer?-&gt;dyspnoea?</title>
# <g id="a_edge2"><a xlink:title="(2, 7) : ">
# <path d="M158.205,-73.1159C181.096,-62.3615 211.381,-48.1336 235.153,-36.9658" fill="none" stroke="black"/>
# <polygon fill="black" points="236.68,-40.1154 244.243,-32.6954 233.704,-33.7798 236.68,-40.1154" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer? -->
# <g class="node" id="node5"><title>lung_cancer?</title>
# <g id="a_node5"><a xlink:title="(4) lung_cancer?">
# <ellipse cx="198.394" cy="-162" fill="#444444" rx="59.5901" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="198.394" y="-158.3">lung_cancer?</text>
# </a>
# </g>
# </g>
# <!-- lung_cancer?&#45;&gt;tuberculos_or_cancer? -->
# <g class="edge" id="edge8"><title>lung_cancer?-&gt;tuberculos_or_cancer?</title>
# <g id="a_edge8"><a xlink:title="(4, 2) : ">
# <path d="M180.857,-144.411C171.526,-135.583 159.884,-124.572 149.601,-114.844" fill="none" stroke="black"/>
# <polygon fill="black" points="151.732,-112.042 142.062,-107.713 146.921,-117.127 151.732,-112.042" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- smoking? -->
# <g class="node" id="node6"><title>smoking?</title>
# <g id="a_node6"><a xlink:title="(5) smoking?">
# <ellipse cx="242.394" cy="-234" fill="#444444" rx="46.5926" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="242.394" y="-230.3">smoking?</text>
# </a>
# </g>
# </g>
# <!-- smoking?&#45;&gt;lung_cancer? -->
# <g class="edge" id="edge4"><title>smoking?-&gt;lung_cancer?</title>
# <g id="a_edge4"><a xlink:title="(5, 4) : ">
# <path d="M231.967,-216.411C226.729,-208.077 220.267,-197.797 214.416,-188.488" fill="none" stroke="black"/>
# <polygon fill="black" points="217.338,-186.56 209.053,-179.956 211.411,-190.285 217.338,-186.56" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- bronchitis? -->
# <g class="node" id="node7"><title>bronchitis?</title>
# <g id="a_node7"><a xlink:title="(6) bronchitis?">
# <ellipse cx="286.394" cy="-90" fill="#444444" rx="50.8918" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="286.394" y="-86.3">bronchitis?</text>
# </a>
# </g>
# </g>
# <!-- smoking?&#45;&gt;bronchitis? -->
# <g class="edge" id="edge6"><title>smoking?-&gt;bronchitis?</title>
# <g id="a_edge6"><a xlink:title="(5, 6) : ">
# <path d="M251.527,-216.228C256.784,-206.003 263.165,-192.531 267.394,-180 274.247,-159.698 279.172,-135.928 282.288,-118.063" fill="none" stroke="black"/>
# <polygon fill="black" points="285.766,-118.481 283.955,-108.042 278.861,-117.332 285.766,-118.481" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- bronchitis?&#45;&gt;dyspnoea? -->
# <g class="edge" id="edge5"><title>bronchitis?-&gt;dyspnoea?</title>
# <g id="a_edge5"><a xlink:title="(6, 7) : ">
# <path d="M283.181,-71.6966C281.748,-63.9827 280.027,-54.7125 278.43,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="281.838,-45.2971 276.571,-36.1043 274.956,-46.5753 281.838,-45.2971" stroke="black"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="217pt" viewBox="0.00 0.00 288.00 216.99" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.834565 0.834565) rotate(0) translate(4 256)">
# <title>G</title>
# <!-- visit_to_Asia? -->
# <g class="node" id="node1"><title>visit_to_Asia?</title>
# <g id="a_node1"><a xlink:title="(0) visit_to_Asia?">
# <ellipse cx="62.3945" cy="-234" fill="#444444" rx="62.2891" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="62.3945" y="-230.3">visit_to_Asia?</text>
# </a>
# </g>
# </g>
# <!-- tuberculosis? -->
# <g class="node" id="node2"><title>tuberculosis?</title>
# <g id="a_node2"><a xlink:title="(1) tuberculosis?">
# <ellipse cx="62.3945" cy="-162" fill="#444444" rx="58.4896" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="62.3945" y="-158.3">tuberculosis?</text>
# </a>
# </g>
# </g>
# <!-- visit_to_Asia?&#45;&gt;tuberculosis? -->
# <g class="edge" id="edge1"><title>visit_to_Asia?-&gt;tuberculosis?</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path d="M62.3945,-215.697C62.3945,-207.983 62.3945,-198.712 62.3945,-190.112" fill="none" stroke="black"/>
# <polygon fill="black" points="65.8946,-190.104 62.3945,-180.104 58.8946,-190.104 65.8946,-1

# %% [markdown]
# ## Randomizing the parameters

# %%
bn.generateCPTs()
bn2.generateCPTs()

# %% [markdown]
# ## Direct comparison of parameters

# %%
from IPython.display import HTML

gnb.sideBySide(bn.cpt(3),
               bn2.cpt(3),
               captions=['<h3>cpt of node 3 in first bn</h3>','<h3>same cpt in second bn</h3>'])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table>
# <tr><th colspan='1'></th><th colspan='2' style='background-color:#AAAAAA'><center>positive_XraY?</center></th></tr>
# <tr><th style='background-color:#AAAAAA'><center>tuberculos_or_cancer?</center></th><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='background-color:#BBBBBB'><center>0</center></th><td style='background-color:#94e964;text-align:right;'>0.8319</td><td style='background-color:#e99464;text-align:right;'>0.1681</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>1</center></th><td style='background-color:#bbc264;text-align:right;'>0.5292</td><td style='background-color:#c2bb64;text-align:right;'>0.4708</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table>
# <tr><th colspan='1'></th><th colspan='2' style='background-color:#AAAAAA'><center>positive_XraY?</center></th></tr>
# <tr><th style='background-color:#AAAAAA'><center>tuberculos_or_cancer?</center></th><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='background-color:#BBBBBB'><center>0</center></th><td style='background-color:#e59864;text-align:right;'>0.1982</td><td style='background-color:#98e564;text-align:right;'>0.8018</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>1</center></th><td style='background-color:#d8a564;text-align:right;'>0.3035</td><td style='background-color:#a5d864;text-align:right;'>0.6965</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small><h3>cpt of node 3 in first bn</h3></small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small><h3>same cpt in second bn</h3></small></div></td></tr></table>

# %% [markdown]
# ## Exact KL-divergence

# %% [markdown]
# Since the BN is not too big, BruteForceKL can be computed ...

# %%
g1=gum.BruteForceKL(bn,bn2)
before_learning=g1.compute()
print(before_learning['klPQ'])
# Out:
# 5.034863674577392

# %% [markdown]
# Just to be sure that the distance between a BN and itself is 0 :

# %%
g0=gum.BruteForceKL(bn,bn)
print(g0.compute()['klPQ'])
# Out:
# 0.0

# %% [markdown]
# ## Generate a database from the original BN

# %%
gum.generateCSV(bn,os.path.join("out","test.csv"),10000,True)
# Out:
#  out/test.csv : [ ############################################################ ] 100%ut/test.csv : [ ######################################################       ] 90%
# Log2-Likelihood : -71515.27347363044
# -71515.27347363044

# %% [markdown]
# ## Using pandas for _counting

# %%
import pandas
df=pandas.read_csv(os.path.join("out","test.csv"))
df
# Out:
#       tuberculosis?  bronchitis?  dyspnoea?  tuberculos_or_cancer?  \
# 0                 0            0          0                      1
# 1                 1            1          0                      1
# 2                 1            1          1                      1
# 3                 1            1          1                      0
# 4                 1            1          1                      0
# 5                 0            0          1                      1
# 6                 1            1          1                      1
# 7                 1            1          0                      1
# 8                 1            1          1                      0
# 9                 1            0          0                      1
# 10                0            1          0                      1
# 11                1            1          1                      0
# 12                1            1          0                      1
# 13                0            0          0                      1
# 14                1            0          0                      1
# 15                0            1          1                      0
# 16                0            0          0                      1
# 17                1            0          1                      0
# 18                1            1          1                      0
# 19                1            0          1                      1
# 20                1            0          1                      1
# 21                1            0          0                      0
# 22                0            0          1                      1
# 23                1            0          0                      1
# 24                1            1          1                      0
# 25                0            1          0                      1
# 26                0            0          0                      1
# 27                1            1          1                      0
# 28                0            1          0                      1
# 29                1            0          0                      0
# ...             ...          ...        ...                    ...
# 9970              1            1          1                      0
# 9971              1            0          0                      1
# 9972              1            1          0                      1
# 9973              1            1          0                      1
# 9974              1            0          0                      0
# 9975              1            0          0                      1
# 9976              1            1          0                      1
# 9977              0            1          0                      1
# 9978              0            1          1                      1
# 9979              0            0          1                      1
# 9980              1            0          0                      1
# 9981              1            0          0                      1
# 9982              1            0          1                      0
# 9983              0            0          0                      0
# 9984              1            0          1                      1
# 9985              0            0          1                      1
# 9986              0            1          1                      0
# 9987              1            0          1                      0
# 9988              1            1          1                      0
# 9989              1            1          1                      0
# 9990              0            1          1                      0
# 9991              1            1          1                      0
# 9992              1            0          0                      0
# 9993              1            1          0                      1
# 9994              1            1          1                      0
# 9995              0            1          1                      1
# 9996              1            1          1                      1
# 9997              0            1          1                      1
# 9998              1            0          0                      1
# 9999              1            0          1                      0
#
#       lung_cancer?  smoking?  visit_to_Asia?  positive_XraY?
# 0                0         1               0               0
# 1                1         1               0               1
# 2                0         1               0               1
# 3                0         1               0               0
# 4                1         1               1               0
# 5                0         1               1               1
# 6                0         0               0               1
# 7                1         1               1               0
# 8                1         0               0               0
# 9                0         0               0               0
# 10               0         1               1               1
# 11               1         1               0               0
# 12               0         0               0               0
# 13               1         1               1               1
# 14               0         1               1               1
# 15               1         1               0               0
# 16               1         0               0               0
# 17               1         0               1               0
# 18               1         0               0               0
# 19               1         1               0               0
# 20               1         1               1               1
# 21               1         0               0               0
# 22               1         1               0               1
# 23               1         1               0               1
# 24               0         0               0               1
# 25               1         1               1               0
# 26               1         1               1               0
# 27               0         1               1               0
# 28               0         1               0               0
# 29               1         0               1               0
# ...            ...       ...             ...             ...
# 9970             1         0               1               0
# 9971             0         0               0               0
# 9972             0         0               0               1
# 9973             0         1               1               0
# 9974             1         1               0               0
# 9975             1         0               1               1
# 9976             1         1               0               0
# 9977             1         1               0               1
# 9978             1         1               1               1
# 9979             1         1               0               1
# 9980             0         1               0               1
# 9981             1         0               0               1
# 9982             1         1               0               0
# 9983             1         1               0               1
# 9984             0         1               1               0
# 9985             0         1               1               1
# 9986             1         0               1               0
# 9987             1         1               0               1
# 9988             1         1               0               0
# 9989             1         0               1               0
# 9990             1         1               1               0
# 9991             1         1               0               0
# 9992             0         0               0               0
# 9993             1         0               1               0
# 9994             1         1               0               0
# 9995             1         0               0               1
# 9996             1         0               0               0
# 9997             1         1               0               1
# 9998             0         0               1               1
# 9999             1         1               0               0
#
# [10000 rows x 8 columns]

# %% [markdown]
# We use the crosstab function in pandas

# %%
c=pandas.crosstab(df['dyspnoea?'],[df['tuberculos_or_cancer?'],df['bronchitis?']])
c
# Out:
# tuberculos_or_cancer?     0           1
# bronchitis?               0     1     0     1
# dyspnoea?
# 0                       658    40  1556  1667
# 1                      1771  2602   728   978

# %% [markdown]
# Playing with numpy reshaping, we retrieve the good form for the CPT from the pandas cross-table

# %%
gnb.sideBySide('<pre>'+str(np.array((c/c.sum().apply(np.float32)).transpose()).reshape(2,2,2))+'</pre>',
               bn.cpt(bn.idFromName('dyspnoea?')),
               captions=["<h3>Learned parameters in crosstab","<h3>Original parameters in bn</h3>"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><pre>[[[0.27089337 0.72910663]
#   [0.01514005 0.98485995]]
#
#  [[0.68126095 0.31873905]
#   [0.63024575 0.36975425]]]</pre></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table>
# <tr><th colspan='2'></th><th colspan='2' style='background-color:#AAAAAA'><center>dyspnoea?</center></th></tr>
# <tr><th style='background-color:#AAAAAA'><center>bronchitis?</center></th><th style='background-color:#AAAAAA'><center>tuberculos_or_cancer?</center></th><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><td style='background-color:#dba264;text-align:right;'>0.2800</td><td style='background-color:#a2db64;text-align:right;'>0.7200</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>1</center></th><td style='background-color:#fc8164;text-align:right;'>0.0168</td><td style='background-color:#81fc64;text-align:right;'>0.9832</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><td style='background-color:#a7d664;text-align:right;'>0.6819</td><td style='background-color:#d6a764;text-align:right;'>0.3181</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>1</center></th><td style='background-color:#afce64;text-align:right;'>0.6245</td><td style='background-color:#ceaf64;text-align:right;'>0.3755</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small><h3>Learned parameters in crosstab</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small><h3>Original parameters in bn</h3></small></div></td></tr></table>

# %% [markdown]
# ## A global method for estimating Bayesian Network parameters from CSV file using PANDAS

# %%
def computeCPTfromDF(bn,df,name):
    """
    Compute the CPT of variable "name" in the BN bn from the database df
    """
    id=bn.idFromName(name)
    domains=[bn.variableFromName(name).domainSize() 
             for name in bn.cpt(id).var_names]

    parents=list(bn.cpt(id).var_names)
    parents.pop()

    c=pandas.crosstab(df[name],[df[parent] for parent in parents])

    s=c.sum()
    
    # if c is monodimensionnal then s will be a float and not a Series 
    if type(s)==pandas.core.series.Series:
        s=s.apply(np.float32)
    else:
        s=float(s)
    
    bn.cpt(id)[:]=np.array((c/s).transpose()).reshape(*domains)
    
def ParametersLearning(bn,df):
    """
    Compute the CPTs of every varaible in the BN bn from the database df
    """
    for name in bn.names():
        computeCPTfromDF(bn,df,name)

# %%
ParametersLearning(bn2,df)

# %% [markdown]
# KL has decreased a lot (if everything's OK)

# %%
g1=gum.BruteForceKL(bn,bn2)
print("BEFORE LEARNING")
print(before_learning['klPQ'])
print
print("AFTER LEARNING")
print(g1.compute()['klPQ'])
# Out:
# BEFORE LEARNING
# 5.034863674577392
# AFTER LEARNING
# 0.0010000272182900069

# %% [markdown]
# And CPTs should be close

# %%
gnb.sideBySide(bn.cpt(3),
               bn2.cpt(3),
               captions=["<h3>Original BN","<h3>learned BN</h3>"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table>
# <tr><th colspan='1'></th><th colspan='2' style='background-color:#AAAAAA'><center>positive_XraY?</center></th></tr>
# <tr><th style='background-color:#AAAAAA'><center>tuberculos_or_cancer?</center></th><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='background-color:#BBBBBB'><center>0</center></th><td style='background-color:#94e964;text-align:right;'>0.8319</td><td style='background-color:#e99464;text-align:right;'>0.1681</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>1</center></th><td style='background-color:#bbc264;text-align:right;'>0.5292</td><td style='background-color:#c2bb64;text-align:right;'>0.4708</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table>
# <tr><th colspan='1'></th><th colspan='2' style='background-color:#AAAAAA'><center>positive_XraY?</center></th></tr>
# <tr><th style='background-color:#AAAAAA'><center>tuberculos_or_cancer?</center></th><th style='background-color:#BBBBBB'><center>0</center></th><th style='background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='background-color:#BBBBBB'><center>0</center></th><td style='background-color:#94e964;text-align:right;'>0.8334</td><td style='background-color:#e99464;text-align:right;'>0.1666</td></tr>
# <tr><th style='background-color:#BBBBBB'><center>1</center></th><td style='background-color:#bac364;text-align:right;'>0.5338</td><td style='background-color:#c3ba64;text-align:right;'>0.4662</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small><h3>Original BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small><h3>learned BN</h3></small></div></td></tr></table>

# %% [markdown]
# ## Influence of the size of the database on the quality of learned parameters

# %% [markdown]
# What is the effect of increasing the size of the database on the KL ? We expect that the KL decreases to 0.

# %%
res=[]
for i in range(200,10001,50):
    ParametersLearning(bn2,df[:i])
    g1=gum.BruteForceKL(bn,bn2)
    res.append(g1.compute()['klPQ'])
fig=figure(figsize=(10,6))
ax  = fig.add_subplot(1, 1, 1)
ax.plot(range(200,10001,50),res)
ax.set_xlabel("size of the database")
ax.set_ylabel("KL")
t=ax.set_title("klPQ(bn,learnedBN(x))")
