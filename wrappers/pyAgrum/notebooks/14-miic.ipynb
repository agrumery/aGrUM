# %%
# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt

import os

import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %%
bn=gum.loadBN(os.path.join("res","asia.bif"))
bn
# Out:
# (gum::BayesNet<double>@0x337a810) BN{nodes: 8, arcs: 8, domainSize: 256, parameters: 36, compression ratio: 85% }

# %%
gum.generateCSV(bn,os.path.join("out","sample_asia.csv"),100000,True)
# Out:
#  out/sample_asia.csv : [ ##################################################### ] 100%ut/sample_asia.csv : [ #############################################         ] 84%out/sample_asia.csv : [ ####################################################  ] 98%
# Log2-Likelihood : -322593.73685743735
# -322593.73685743735

# %%
learner=gum.BNLearner(os.path.join("out","sample_asia.csv"))
learner.use3off2()
learner.useNML()
ge3off2=learner.learnMixedStructure()

# %%
learner=gum.BNLearner(os.path.join("out","sample_asia.csv"))
learner.useGreedyHillClimbing()
bnHC=learner.learnBN()
geHC=gum.EssentialGraph(bnHC)

# %%
learner=gum.BNLearner(os.path.join("out","sample_asia.csv"))
learner.useLocalSearchWithTabuList()
bnTL=learner.learnBN()
geTL=gum.EssentialGraph(bnTL)

# %%
gnb.sideBySide(ge3off2,bnHC,geHC,bnTL,geTL)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="..."/></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><svg height="238pt" viewBox="0.00 0.00 288.00 238.25" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.916359 0.916359) rotate(0) translate(4 256)">
# <title>G</title>
# <!-- bronchitis? -->
# <g class="node" id="node1"><title>bronchitis?</title>
# <g id="a_node1"><a xlink:title="(0) bronchitis?">
# <ellipse cx="255.592" cy="-90" fill="#444444" rx="50.8918" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="255.592" y="-86.3">bronchitis?</text>
# </a>
# </g>
# </g>
# <!-- dyspnoea? -->
# <g class="node" id="node4"><title>dyspnoea?</title>
# <g id="a_node4"><a xlink:title="(3) dyspnoea?">
# <ellipse cx="242.592" cy="-18" fill="#444444" rx="50.0912" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="242.592" y="-14.3">dyspnoea?</text>
# </a>
# </g>
# </g>
# <!-- bronchitis?&#45;&gt;dyspnoea? -->
# <g class="edge" id="edge6"><title>bronchitis?-&gt;dyspnoea?</title>
# <g id="a_edge6"><a xlink:title="(0, 3) : ">
# <path d="M252.378,-71.6966C250.946,-63.9827 249.224,-54.7125 247.627,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="251.035,-45.2971 245.768,-36.1043 244.153,-46.5753 251.035,-45.2971" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- positive_XraY? -->
# <g class="node" id="node2"><title>positive_XraY?</title>
# <g id="a_node2"><a xlink:title="(1) positive_XraY?">
# <ellipse cx="93.5917" cy="-18" fill="#444444" rx="67.6881" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="93.5917" y="-14.3">positive_XraY?</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer? -->
# <g class="node" id="node3"><title>tuberculos_or_cancer?</title>
# <g id="a_node3"><a xlink:title="(2) tuberculos_or_cancer?">
# <ellipse cx="93.5917" cy="-90" fill="#444444" rx="93.6835" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="93.5917" y="-86.3">tuberculos_or_cancer?</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer?&#45;&gt;positive_XraY? -->
# <g class="edge" id="edge2"><title>tuberculos_or_cancer?-&gt;positive_XraY?</title>
# <g id="a_edge2"><a xlink:title="(2, 1) : ">
# <path d="M93.5917,-71.6966C93.5917,-63.9827 93.5917,-54.7125 93.5917,-46.1124" fill="none" stroke="black"/>
# <polygon fill="black" points="97.0918,-46.1043 93.5917,-36.1043 90.0918,-46.1044 97.0918,-46.1043" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer?&#45;&gt;dyspnoea? -->
# <g class="edge" id="edge5"><title>tuberculos_or_cancer?-&gt;dyspnoea?</title>
# <g id="a_edge5"><a xlink:title="(2, 3) : ">
# <path d="M127.402,-73.1159C150.294,-62.3615 180.579,-48.1336 204.35,-36.9658" fill="none" stroke="black"/>
# <polygon fill="black" points="205.877,-40.1154 213.44,-32.6954 202.901,-33.7798 205.877,-40.1154" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- smoking? -->
# <g class="node" id="node5"><title>smoking?</title>
# <g id="a_node5"><a xlink:title="(4) smoking?">
# <ellipse cx="254.592" cy="-162" fill="#444444" rx="46.5926" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="254.592" y="-158.3">smoking?</text>
# </a>
# </g>
# </g>
# <!-- smoking?&#45;&gt;bronchitis? -->
# <g class="edge" id="edge8"><title>smoking?-&gt;bronchitis?</title>
# <g id="a_edge8"><a xlink:title="(4, 0) : ">
# <path d="M254.839,-143.697C254.949,-135.983 255.082,-126.712 255.204,-118.112" fill="none" stroke="black"/>
# <polygon fill="black" points="258.704,-118.153 255.347,-108.104 251.705,-118.053 258.704,-118.153" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- visit_to_Asia? -->
# <g class="node" id="node6"><title>visit_to_Asia?</title>
# <g id="a_node6"><a xlink:title="(5) visit_to_Asia?">
# <ellipse cx="93.5917" cy="-234" fill="#444444" rx="62.2891" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="93.5917" y="-230.3">visit_to_Asia?</text>
# </a>
# </g>
# </g>
# <!-- tuberculosis? -->
# <g class="node" id="node7"><title>tuberculosis?</title>
# <g id="a_node7"><a xlink:title="(6) tuberculosis?">
# <ellipse cx="93.5917" cy="-162" fill="#444444" rx="58.4896" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="93.5917" y="-158.3">tuberculosis?</text>
# </a>
# </g>
# </g>
# <!-- visit_to_Asia?&#45;&gt;tuberculosis? -->
# <g class="edge" id="edge1"><title>visit_to_Asia?-&gt;tuberculosis?</title>
# <g id="a_edge1"><a xlink:title="(5, 6) : ">
# <path d="M93.5917,-215.697C93.5917,-207.983 93.5917,-198.712 93.5917,-190.112" fill="none" stroke="black"/>
# <polygon fill="black" points="97.0918,-190.104 93.5917,-180.104 90.0918,-190.104 97.0918,-190.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- tuberculosis?&#45;&gt;tuberculos_or_cancer? -->
# <g class="edge" id="edge4"><title>tuberculosis?-&gt;tuberculos_or_cancer?</title>
# <g id="a_edge4"><a xlink:title="(6, 2) : ">
# <path d="M93.5917,-143.697C93.5917,-135.983 93.5917,-126.712 93.5917,-118.112" fill="none" stroke="black"/>
# <polygon fill="black" points="97.0918,-118.104 93.5917,-108.104 90.0918,-118.104 97.0918,-118.104" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer? -->
# <g class="node" id="node8"><title>lung_cancer?</title>
# <g id="a_node8"><a xlink:title="(7) lung_cancer?">
# <ellipse cx="243.592" cy="-234" fill="#444444" rx="59.5901" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="243.592" y="-230.3">lung_cancer?</text>
# </a>
# </g>
# </g>
# <!-- lung_cancer?&#45;&gt;tuberculos_or_cancer? -->
# <g class="edge" id="edge7"><title>lung_cancer?-&gt;tuberculos_or_cancer?</title>
# <g id="a_edge7"><a xlink:title="(7, 2) : ">
# <path d="M229.301,-216.215C213.294,-197.771 186.223,-167.629 160.592,-144 149.272,-133.565 136.116,-122.878 124.475,-113.86" fill="none" stroke="black"/>
# <polygon fill="black" points="126.382,-110.912 116.313,-107.615 122.128,-116.471 126.382,-110.912" stroke="black"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer?&#45;&gt;smoking? -->
# <g class="edge" id="edge3"><title>lung_cancer?-&gt;smoking?</title>
# <g id="a_edge3"><a xlink:title="(7, 4) : ">
# <path d="M246.311,-215.697C247.523,-207.983 248.98,-198.712 250.331,-190.112" fill="none" stroke="black"/>
# <polygon fill="black" points="253.809,-190.526 251.904,-180.104 246.894,-189.44 253.809,-190.526" stroke="black"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="...

# %%
learner=gum.BNLearner(os.path.join("out","sample_asia.csv"))
learner.use3off2()
ge3off2=learner.learnMixedStructure()

# %%
ge3off2
# Out:
# (gum::MixedGraph@0x3904f60) {0,1,2,3,4,5,6,7} , {7->2,2->3,6->2,0->3,2->1} , {4--7,5--6,0--4}
