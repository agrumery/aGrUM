# %% [markdown]
# # Parameter learning with Pandas
#
# This notebook uses pandas to learn the parameters.
#
# However **<font color="red"><big>the simplest way to learn parameters is to use `BNLearner` :-)</big></font>**.
#
# Moreover, you will be able to add priors, etc (see <A href="BNLearning.html">learning BN</A>).

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)

# %%
# %matplotlib inline
from pylab import *
import matplotlib.pyplot as plt

import os

# %% [markdown]
# ## Importing pyAgrum

# %%
import pyagrum as gum
import pyagrum.lib.notebook as gnb

# %% [markdown]
# ## Loading two BNs

# %%
bn=gum.loadBN("res/asia.bif")
bn2=gum.loadBN("res/asia.bif")

gnb.sideBySide(bn,bn2,
               captions=['First bn','Second bn'])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="329pt" height="260pt" viewBox="0.00 0.00 328.82 260.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 256)">
# <title>G</title>
# <!-- tuberculosis -->
# <g id="node1" class="node">
# <title>tuberculosis</title>
# <g id="a_node1"><a xlink:title="(1) tuberculosis">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="260.77" cy="-162" rx="55.45" ry="18"/>
# <text text-anchor="middle" x="260.77" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">tuberculosis</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer -->
# <g id="node4" class="node">
# <title>tuberculos_or_cancer</title>
# <g id="a_node4"><a xlink:title="(2) tuberculos_or_cancer">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="203.77" cy="-90" rx="90.25" ry="18"/>
# <text text-anchor="middle" x="203.77" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">tuberculos_or_cancer</text>
# </a>
# </g>
# </g>
# <!-- tuberculosis&#45;&gt;tuberculos_or_cancer -->
# <g id="edge2" class="edge">
# <title>tuberculosis-&gt;tuberculos_or_cancer</title>
# <g id="a_edge2"><a xlink:title="1 → 2">
# <path fill="none" stroke="#4a4a4a" d="M247.26,-144.41C240.54,-136.16 232.28,-126.01 224.76,-116.78"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="227.56,-114.67 218.53,-109.13 222.13,-119.09 227.56,-114.67"/>
# </a>
# </g>
# </g>
# <!-- positive_XraY -->
# <g id="node2" class="node">
# <title>positive_XraY</title>
# <g id="a_node2"><a xlink:title="(3) positive_XraY">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="203.77" cy="-18" rx="65.17" ry="18"/>
# <text text-anchor="middle" x="203.77" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">positive_XraY</text>
# </a>
# </g>
# </g>
# <!-- smoking -->
# <g id="node3" class="node">
# <title>smoking</title>
# <g id="a_node3"><a xlink:title="(5) smoking">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="89.77" cy="-234" rx="43.16" ry="18"/>
# <text text-anchor="middle" x="89.77" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">smoking</text>
# </a>
# </g>
# </g>
# <!-- bronchitis -->
# <g id="node5" class="node">
# <title>bronchitis</title>
# <g id="a_node5"><a xlink:title="(6) bronchitis">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="47.77" cy="-90" rx="47.77" ry="18"/>
# <text text-anchor="middle" x="47.77" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">bronchitis</text>
# </a>
# </g>
# </g>
# <!-- smoking&#45;&gt;bronchitis -->
# <g id="edge8" class="edge">
# <title>smoking-&gt;bronchitis</title>
# <g id="a_edge8"><a xlink:title="5 → 6">
# <path fill="none" stroke="#4a4a4a" d="M81.43,-216.15C76.61,-205.89 70.75,-192.42 66.77,-180 60.43,-160.19 55.58,-137.23 52.37,-119.59"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="55.84,-119.07 50.68,-109.82 48.94,-120.27 55.84,-119.07"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer -->
# <g id="node8" class="node">
# <title>lung_cancer</title>
# <g id="a_node8"><a xlink:title="(4) lung_cancer">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="131.77" cy="-162" rx="55.96" ry="18"/>
# <text text-anchor="middle" x="131.77" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">lung_cancer</text>
# </a>
# </g>
# </g>
# <!-- smoking&#45;&gt;lung_cancer -->
# <g id="edge4" class="edge">
# <title>smoking-&gt;lung_cancer</title>
# <g id="a_edge4"><a xlink:title="5 → 4">
# <path fill="none" stroke="#4a4a4a" d="M99.94,-216.05C104.73,-208.06 110.57,-198.33 115.93,-189.4"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="118.77,-191.46 120.92,-181.09 112.77,-187.86 118.77,-191.46"/>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer&#45;&gt;positive_XraY -->
# <g id="edge6" class="edge">
# <title>tuberculos_or_cancer-&gt;positive_XraY</title>
# <g id="a_edge6"><a xlink:title="2 → 3">
# <path fill="none" stroke="#4a4a4a" d="M203.77,-71.7C203.77,-64.41 203.77,-55.73 203.77,-47.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="207.27,-47.62 203.77,-37.62 200.27,-47.62 207.27,-47.62"/>
# </a>
# </g>
# </g>
# <!-- dyspnoea -->
# <g id="node7" class="node">
# <title>dyspnoea</title>
# <g id="a_node7"><a xlink:title="(7) dyspnoea">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="61.77" cy="-18" rx="45.72" ry="18"/>
# <text text-anchor="middle" x="61.77" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">dyspnoea</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer&#45;&gt;dyspnoea -->
# <g id="edge3" class="edge">
# <title>tuberculos_or_cancer-&gt;dyspnoea</title>
# <g id="a_edge3"><a xlink:title="2 → 7">
# <path fill="none" stroke="#4a4a4a" d="M170.83,-72.76C149.47,-62.24 121.59,-48.49 99.36,-37.53"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="101.15,-34.51 90.63,-33.23 98.05,-40.79 101.15,-34.51"/>
# </a>
# </g>
# </g>
# <!-- bronchitis&#45;&gt;dyspnoea -->
# <g id="edge7" class="edge">
# <title>bronchitis-&gt;dyspnoea</title>
# <g id="a_edge7"><a xlink:title="6 → 7">
# <path fill="none" stroke="#4a4a4a" d="M51.23,-71.7C52.7,-64.32 54.46,-55.52 56.12,-47.25"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="59.52,-48.08 58.05,-37.59 52.66,-46.71 59.52,-48.08"/>
# </a>
# </g>
# </g>
# <!-- visit_to_Asia -->
# <g id="node6" class="node">
# <title>visit_to_Asia</title>
# <g id="a_node6"><a xlink:title="(0) visit_to_Asia">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="260.77" cy="-234" rx="60.05" ry="18"/>
# <text text-anchor="middle" x="260.77" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">visit_to_Asia</text>
# </a>
# </g>
# </g>
# <!-- visit_to_Asia&#45;&gt;tuberculosis -->
# <g id="edge1" class="edge">
# <title>visit_to_Asia-&gt;tuberculosis</title>
# <g id="a_edge1"><a xlink:title="0 → 1">
# <path fill="none" stroke="#4a4a4a" d="M260.77,-215.7C260.77,-208.41 260.77,-199.73 260.77,-191.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="264.27,-191.62 260.77,-181.62 257.27,-191.62 264.27,-191.62"/>
# </a>
# </g>
# </g>
# <!-- lung_cancer&#45;&gt;tuberculos_or_cancer -->
# <g id="edge5" class="edge">
# <title>lung_cancer-&gt;tuberculos_or_cancer</title>
# <g id="a_edge5"><a xlink:title="4 → 2">
# <path fill="none" stroke="#4a4a4a" d="M148.83,-144.41C157.58,-135.91 168.41,-125.37 178.14,-115.91"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="180.51,-118.49 185.24,-109.01 175.63,-113.47 180.51,-118.49"/>
# </a>
# </g>
# </g>
# </g>
# </svg><br><small><i>First bn</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="329pt" height="260pt" viewBox="0.00 0.00 328.82 260.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 256)">
# <title>G</title>
# <!-- tuberculosis -->
# <g id="node1" class="node">
# <title>tuberculosis</title>
# <g id="a_node1"><a xlink:title="(1) tuberculosis">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="260.77" cy="-162" rx="55.45" ry="18"/>
# <text text-anchor="middle" x="260.77" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">tuberculosis</text>
# </a>
# </g>
# </g>
# <!-- tuberculos_or_cancer -->
# <g id="node4" class="node">
# <title>tuberculos_or_cancer</title>
# <g id="a_node4"><a xlink:title="(2) tuberculos_or_cancer">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="203.77" cy="-90" rx="90.25" ry="18"/>
# <text text-anchor="middle" x="203.77" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">tuberculos_or_cancer</text>
# </a>
# </g>
# </g>
# <!-- tuberculosis&#45;&gt;tuberculos_or_cancer -->
# <g id="edge2" class="edge">
# <title>tuberculosis-&gt;tuberculos_or_cancer</title>
# <g id="a_edge2"><a xlink:title="1 → 2">
# <path fill="none" stroke="#4a4a4a" d="M247.26,-144.41C240.54,-136.16 232.28,-126.01 224.76,-116.78"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="227.56,-114.67 218.53,-109.13 222.13,-119.09 227.56,-114.67"/>
# </a>
# </g>
# </g>
# <!-- positive_XraY -->
# <g id="node2" class="node">
# <title>positive_XraY</tit

# %% [markdown]
# ## Randomizing the parameters

# %%
bn.generateCPTs()
bn2.generateCPTs()

# %% [markdown]
# ## Direct comparison of parameters

# %%
from IPython.display import HTML

gnb.sideBySide(bn.cpt(3),
               bn2.cpt(3),
               captions=['<h3>cpt of node 3 in first bn</h3>','<h3>same cpt in second bn</h3>'])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>positive_XraY</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>tuberculos_or_cancer</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#99e464;text-align:right;padding: 3px;'>0.7964</td><td style='color:black;background-color:#e49964;text-align:right;padding: 3px;'>0.2036</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#c1bc64;text-align:right;padding: 3px;'>0.4766</td><td style='color:black;background-color:#bcc164;text-align:right;padding: 3px;'>0.5234</td></tr>
# </table><br><small><i><h3>cpt of node 3 in first bn</h3></i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>positive_XraY</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>tuberculos_or_cancer</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#bbc264;text-align:right;padding: 3px;'>0.5289</td><td style='color:black;background-color:#c2bb64;text-align:right;padding: 3px;'>0.4711</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#82fb64;text-align:right;padding: 3px;'>0.9737</td><td style='color:black;background-color:#fb8264;text-align:right;padding: 3px;'>0.0263</td></tr>
# </table><br><small><i><h3>same cpt in second bn</h3></i></small></div></td></tr></table>

# %% [markdown]
# ## Exact KL-divergence

# %% [markdown]
# Since the BN is not too big, BruteForceKL can be computed ...

# %%
g1=gum.ExactBNdistance(bn,bn2)
before_learning=g1.compute()
print(f"klPQ computed : {before_learning['klPQ']}")
# Out:
# klPQ computed : 3.5890604269977544

# %% [markdown]
# Just to be sure that the distance between a BN and itself is 0 :

# %%
g0=gum.ExactBNdistance(bn,bn)
print(g0.compute()['klPQ'])
# Out:
# 0.0

# %% [markdown]
# ## Generate a database from the original BN

# %%
gum.generateSample(bn,10000,"out/test.csv",True)
# Out:
# out/test.csv:   0%|                                        |
# out/test.csv: 100%|████████████████████████████████████████|
# Log2-Likelihood : -69473.53917155035
# -69473.53917155035

# %% [markdown]
# ## Using pandas for _counting
#
# As an exercise, we will use pandas to learn the parameters.

# %%
# using bn as a template for the specification of variables in test.csv
learner=gum.BNLearner("out/test.csv",bn)
bn3=learner.learnParameters(bn.dag())

#the same but we add a Laplace adjustment (smoothing) as a Prior
learner=gum.BNLearner("out/test.csv",bn)
learner.useSmoothingPrior(1000) # a count C is replaced by C+1000
bn4=learner.learnParameters(bn.dag())

after_pyAgrum_learning=gum.ExactBNdistance(bn,bn3).compute()
after_pyAgrum_learning_with_smoothing=gum.ExactBNdistance(bn,bn4).compute()
print("without prior:{}".format(after_pyAgrum_learning['klPQ']))
print("with prior smooting(1000):{}".format(after_pyAgrum_learning_with_smoothing['klPQ']))
# Out:
# without prior:0.0012720451633336399
# with prior smooting(1000):0.14250138472640594

# %% [markdown]
# ### Now, let's try to learn the parameters with pandas

# %%
import pandas

# %%
# We directly generate samples in a DataFrame
df,_=gum.generateSample(bn,10000,None,True)
# Out:
#   0%|                                                      |
# 100%|██████████████████████████████████████████████████████|
# Log2-Likelihood : -69448.36808187414

# %%
df.head()
# Out:
#   smoking tuberculos_or_cancer positive_XraY visit_to_Asia dyspnoea  \
# 0       1                    0             1             0        1
# 1       0                    0             0             0        1
# 2       1                    0             0             1        1
# 3       1                    0             0             0        0
# 4       1                    0             0             0        0
#
#   tuberculosis lung_cancer bronchitis
# 0            1           1          1
# 1            1           1          0
# 2            1           0          1
# 3            0           0          1
# 4            1           0          1

# %% [markdown]
# We use the crosstab function in pandas

# %%
c=pandas.crosstab(df['dyspnoea'],[df['tuberculos_or_cancer'],df['bronchitis']])
c
# Out:
# tuberculos_or_cancer     0           1
# bronchitis               0     1     0     1
# dyspnoea
# 0                     1220  2213   314  1022
# 1                     1380  1704  1015  1132

# %% [markdown]
# Playing with numpy reshaping, we retrieve the good form for the CPT from the pandas cross-table

# %%
gnb.sideBySide('<pre>'+str(np.array((c/c.sum().apply(np.float32)).transpose()).reshape(2,2,2))+'</pre>',
               bn.cpt('dyspnoea'),
               captions=["<h3>Learned parameters in crosstab","<h3>Original parameters in bn</h3>"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><pre>[[[0.46923077 0.53076923]
#   [0.56497319 0.43502681]]
#
#  [[0.23626787 0.76373213]
#   [0.47446611 0.52553389]]]</pre><br><small><i><h3>Learned parameters in crosstab</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>dyspnoea</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>bronchitis</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>tuberculos_or_cancer</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#c2bb64;text-align:right;padding: 3px;'>0.4727</td><td style='color:black;background-color:#bbc264;text-align:right;padding: 3px;'>0.5273</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#de9f64;text-align:right;padding: 3px;'>0.2533</td><td style='color:black;background-color:#9fde64;text-align:right;padding: 3px;'>0.7467</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#b7c664;text-align:right;padding: 3px;'>0.5548</td><td style='color:black;background-color:#c6b764;text-align:right;padding: 3px;'>0.4452</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#c1bc64;text-align:right;padding: 3px;'>0.4818</td><td style='color:black;background-color:#bcc164;text-align:right;padding: 3px;'>0.5182</td></tr>
# </table><br><small><i><h3>Original parameters in bn</h3></i></small></div></td></tr></table>

# %% [markdown]
# ## A global method for estimating Bayesian network parameters from CSV file using PANDAS

# %%
def computeCPTfromDF(bn,df,name):
    """
    Compute the CPT of variable "name" in the BN bn from the database df
    """
    id=bn.idFromName(name)
    parents=list(reversed(bn.cpt(id).names))
    domains=[bn[name].domainSize()
             for name in parents]
    parents.pop()

    if (len(parents)>0):
        c=pandas.crosstab(df[name],[df[parent] for parent in parents])
        s=c/c.sum().apply(np.float32)
    else:
        s=df[name].value_counts(normalize=True)

    bn.cpt(id)[:]=np.array((s).transpose()).reshape(*domains)

def ParametersLearning(bn,df):
    """
    Compute the CPTs of every varaible in the BN bn from the database df
    """
    for name in bn.names():
        computeCPTfromDF(bn,df,name)

# %%
ParametersLearning(bn2,df)

# %% [markdown]
# KL has decreased a lot (if everything's OK)

# %%
g1=gum.ExactBNdistance(bn,bn2)
print("BEFORE LEARNING")
print(before_learning['klPQ'])
print
print("AFTER LEARNING")
print(g1.compute()['klPQ'])
# Out:
# BEFORE LEARNING
# 3.5890604269977544
# AFTER LEARNING
# 1.1115179736893932

# %% [markdown]
# And CPTs should be close

# %%
gnb.sideBySide(bn.cpt(3),
               bn2.cpt(3),
               captions=["<h3>Original BN","<h3>learned BN</h3>"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>positive_XraY</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>tuberculos_or_cancer</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#99e464;text-align:right;padding: 3px;'>0.7964</td><td style='color:black;background-color:#e49964;text-align:right;padding: 3px;'>0.2036</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#c1bc64;text-align:right;padding: 3px;'>0.4766</td><td style='color:black;background-color:#bcc164;text-align:right;padding: 3px;'>0.5234</td></tr>
# </table><br><small><i><h3>Original BN</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>positive_XraY</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>tuberculos_or_cancer</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#99e464;text-align:right;padding: 3px;'>0.7958</td><td style='color:black;background-color:#e49964;text-align:right;padding: 3px;'>0.2042</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#c0bd64;text-align:right;padding: 3px;'>0.4872</td><td style='color:black;background-color:#bdc064;text-align:right;padding: 3px;'>0.5128</td></tr>
# </table><br><small><i><h3>learned BN</h3></i></small></div></td></tr></table>

# %% [markdown]
# ## Influence of the size of the database on the quality of learned parameters

# %% [markdown]
# What is the effect of increasing the size of the database on the KL ? We expect that the KL decreases to 0.

# %%
res=[]
for i in range(200,10001,50):
    ParametersLearning(bn2,df[:i])
    g1=gum.ExactBNdistance(bn,bn2)
    res.append(g1.compute()['klPQ'])
fig=figure(figsize=(10,6))
ax  = fig.add_subplot(1, 1, 1)
ax.plot(range(200,10001,50),res)
ax.set_xlabel("size of the database")
ax.set_ylabel("KL")
ax.set_title("klPQ(bn,learnedBN(x))");
