# %% [markdown]
# # Multinomial Simpson Paradox
#
# this notebook shows a model for a multinomial Simpson paradox.

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://pyagrum.gitlab.io) |[ ![interactive online version](images/atbinder.svg)](https://mybinder.org/v2/gl/agrumery%2FaGrUM/forBinder?urlpath=%2Fdoc%2Ftree%2Fwrappers%2Fpyagrum%2Fdoc%2Fsphinx%2Fnotebooks%2F63-Causality_MultinomialSimpsonParadox.ipynb)

# %%
import pandas as pd

import pyagrum as gum
import pyagrum.lib.notebook as gnb

# %% [markdown]
# ### Building the models

# %%
# building a model including a Simpson's paradox
import scipy.stats as stats

bn = gum.fastBN("A[0,90]->B[0:40:200]<-C[0,5]->A")

bn.cpt("C").fillFromDistribution(stats.uniform, loc=0, scale=5)
bn.cpt("A").fillFromDistribution(stats.uniform, loc="C*12", scale=30)
bn.cpt("B").fillFromDistribution(stats.norm, loc="5+C*4-int(A/8)", scale=3);

# %% [markdown]
# **As a site note** we are dealing here with quite large models already :

# %%
bn.memoryFootprint()
# Out:
# 878016

# %%
help(bn.memoryFootprint)
# Out:
# Help on method memoryFootprint in module pyagrum.pyagrum:
#
# memoryFootprint() -> int method of pyagrum.pyagrum.BayesNet instance
#     Returns the memory footprint in bytes of the Bayesian network.
#
#     Returns
#     -------
#     int
#       the memory footprint in bytes of the Bayesian network

# %%
#  generating a CSV, taking this model as the causal one.
gum.generateSample(bn, 400, "out/sample.csv", with_labels=False)
df = pd.read_csv("out/sample.csv")
df.plot.scatter(x="A", y="B", c="C", colormap="tab20");

# %%
cm = gum.CausalModel(bn)
_, p, _ = gum.causalImpact(cm, on="B", doing="A")

# %%
# building an Markov-equivalent model, generating a CSV, taking this model as the causal one.
bn2 = gum.BayesNet(bn)
bn2.reverseArc("C", "A")
bn2
# Out:
# (pyagrum.BayesNet@0x811881800) BN{nodes: 3, arcs: 3, domainSize: 109200, dim: 109199, mem: 858Ko 104o}

# %%
gum.generateSample(bn2, 400, "out/sample2.csv", with_labels=False)
df2 = pd.read_csv("out/sample2.csv")

cm2 = gum.CausalModel(bn2)
_, p2, _ = gum.causalImpact(cm2, on="B", doing="A")

# %% [markdown]
# ### The observationnal model and its paradoxal structure (exactly the same with the second Markov-equivalent model)

# %%
gnb.flow.row(
  gnb.getBN(bn),
  df.plot.scatter(x="A", y="B"),
  df.plot.scatter(x="A", y="B", c="C", colormap="tab20"),
  captions=["the observationnal model", "the trend is increasing", "the trend is decreasing for any value for C !"],
)
gnb.flow.row(
  gnb.getBN(bn2),
  df2.plot.scatter(x="A", y="B"),
  df2.plot.scatter(x="A", y="B", c="C", colormap="tab20"),
  captions=["the Markov-equivalent model", "the trend is increasing", "the trend is decreasing for any value for C !"],
)
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="89pt" height="188pt" viewBox="0.00 0.00 89.00 188.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- A -->
# <g id="node1" class="node">
# <title>A</title>
# <g id="a_node1"><a xlink:title="(0) A">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="54" cy="-162" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="54" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">A</text>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node2" class="node">
# <title>C</title>
# <g id="a_node2"><a xlink:title="(2) C">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-90" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="27" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">C</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;C -->
# <g id="edge2" class="edge">
# <title>A-&gt;C</title>
# <g id="a_edge2"><a xlink:title="0 → 2">
# <path fill="none" stroke="#4a4a4a" d="M47.46,-144.05C44.48,-136.32 40.87,-126.96 37.52,-118.27"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="40.88,-117.27 34.02,-109.2 34.35,-119.79 40.88,-117.27"/>
# </a>
# </g>
# </g>
# <!-- B -->
# <g id="node3" class="node">
# <title>B</title>
# <g id="a_node3"><a xlink:title="(1) B">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="54" cy="-18" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="54" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">B</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge1" class="edge">
# <title>A-&gt;B</title>
# <g id="a_edge1"><a xlink:title="0 → 1">
# <path fill="none" stroke="#4a4a4a" d="M57.65,-143.91C59.68,-133.57 61.98,-120.09 63,-108 64.34,-92.06 64.34,-87.94 63,-72 62.32,-63.97 61.08,-55.33 59.73,-47.4"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="63.17,-46.79 57.93,-37.58 56.29,-48.05 63.17,-46.79"/>
# </a>
# </g>
# </g>
# <!-- C&#45;&gt;B -->
# <g id="edge3" class="edge">
# <title>C-&gt;B</title>
# <g id="a_edge3"><a xlink:title="2 → 1">
# <path fill="none" stroke="#4a4a4a" d="M33.54,-72.05C36.52,-64.32 40.13,-54.96 43.48,-46.27"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="46.65,-47.79 46.98,-37.2 40.12,-45.27 46.65,-47.79"/>
# </a>
# </g>
# </g>
# </g>
# </svg><br><center><small><em>the Markov-equivalent model</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>the trend is increasing</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>the trend is decreasing for any value for C !</em></small></center></div>

# %% [markdown]
# ### The paradox is revealed in the trend of the inferred means : the means are increasing with the value of $A$ **except for any value of $C$** ...

# %%
gum.config["notebook", "histogram_epsilon"] = 0.001
gum.config["notebook", "histogram_discretized_scale"] = 0.4

# %%
for a in [10, 20, 30]:
  gnb.flow.add_html(gnb.getPosterior(bn, target="B", evs={"A": a}), f"$P(B|A={a})$")
gnb.flow.new_line()
for a in [10, 20, 30]:
  gnb.flow.add_html(gnb.getPosterior(bn, target="B", evs={"A": a, "C": 0}), f"P(B | $A={a},C=0)$")
gnb.flow.new_line()
for a in [10, 20, 30]:
  gnb.flow.add_html(gnb.getPosterior(bn, target="B", evs={"A": a, "C": 2}), f"P(B | $A={a},C=2$)")
gnb.flow.new_line()
for a in [10, 20, 30]:
  gnb.flow.add_html(gnb.getPosterior(bn, target="B", evs={"A": a, "C": 4}), f"P(B | $A={a},C=4$)")
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>$P(B|A=10)$</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>$P(B|A=20)$</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>$P(B|A=30)$</em></small></center></div><br/><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>P(B | $A=10,C=0)$</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>P(B | $A=20,C=0)$</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>P(B | $A=30,C=0)$</em></small></center></div><br/><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>P(B | $A=10,C=2$)</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>P(B | $A=20,C=2$)</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>P(B | $A=30,C=2$)</em></small></center></div><br/><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>P(B | $A=10,C=4$)</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>P(B | $A=20,C=4$)</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>P(B | $A=30,C=4$)</em></small></center></div>

# %% [markdown]
# ### Now that the paradoxal structure is understood and the paradox is revealed, will we choose to observe $C$ (or not) before deciding to increase or decrease $A$ (with the goal to maximize $B$) ?
#
# Of course, it depends on the causal structure of the problem !

# %% [markdown]
# ### If $C$ is cause for $A$, observing $C$ really gives a new information about $B$.

# %%
gnb.flow.add_html(gnb.getCausalModel(cm), "the first causal model")
gnb.flow.new_line()
for v in [10, 20, 30]:
  gnb.flow.add_html(gnb.getProba(p.extract({"A": v})), f"Doing $A={v}$")
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="85pt" height="180pt" viewBox="0.00 0.00 85.00 180.00">
# <g id="graph0" class="graph" transform="scale(0.957447 0.957447) rotate(0) translate(4 184)">
# <!-- A -->
# <g id="node1" class="node">
# <title>A</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-90" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="27" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">A</text>
# </g>
# <!-- B -->
# <g id="node2" class="node">
# <title>B</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="54" cy="-18" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="54" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">B</text>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge1" class="edge">
# <title>A-&gt;B</title>
# <path fill="none" stroke="#4a4a4a" d="M32.6,-71.7C35.59,-63.96 39.2,-54.6 42.55,-45.91"/>
# <path fill="none" stroke="#4a4a4a" d="M34.47,-72.41C37.45,-64.68 41.06,-55.32 44.42,-46.63"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="46.65,-47.79 46.98,-37.2 40.12,-45.27 46.65,-47.79"/>
# </g>
# <!-- C -->
# <g id="node3" class="node">
# <title>C</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="54" cy="-162" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="54" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">C</text>
# </g>
# <!-- C&#45;&gt;A -->
# <g id="edge3" class="edge">
# <title>C-&gt;A</title>
# <path fill="none" stroke="#4a4a4a" d="M46.53,-144.41C43.55,-136.68 39.94,-127.32 36.58,-118.63"/>
# <path fill="none" stroke="#4a4a4a" d="M48.4,-143.7C45.41,-135.96 41.8,-126.6 38.45,-117.91"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="40.88,-117.27 34.02,-109.2 34.35,-119.79 40.88,-117.27"/>
# </g>
# <!-- C&#45;&gt;B -->
# <g id="edge2" class="edge">
# <title>C-&gt;B</title>
# <path fill="none" stroke="#4a4a4a" d="M56.67,-143.72C58.69,-133.4 61,-119.92 62,-107.92 63.34,-92.06 63.34,-87.94 62,-72.08 61.33,-64.11 60.09,-55.47 58.74,-47.57"/>
# <path fill="none" stroke="#4a4a4a" d="M58.64,-144.1C60.66,-133.74 62.97,-120.26 64,-108.08 65.34,-92.06 65.34,-87.94 64,-71.92 63.31,-63.83 62.07,-55.19 60.71,-47.24"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="63.17,-46.79 57.93,-37.58 56.29,-48.05 63.17,-46.79"/>
# </g>
# </g>
# </svg><br><center><small><em>the first causal model</em></small></center></div><br/><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>Doing $A=10$</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>Doing $A=20$</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>Doing $A=30$</em></small></center></div>

# %% [markdown]
# ### if $A$ is cause for $C$, observing $C$ may lead to misinterpretations about the causal role of $A$.

# %%
gnb.flow.add_html(gnb.getCausalModel(cm2), "the second causal model")
gnb.flow.new_line()
for v in [10, 20, 30]:
  gnb.flow.add_html(gnb.getProba(p2.extract({"A": v})), f"Doing $A={v}$")
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="86pt" height="180pt" viewBox="0.00 0.00 86.00 180.00">
# <g id="graph0" class="graph" transform="scale(0.957447 0.957447) rotate(0) translate(4 184)">
# <!-- A -->
# <g id="node1" class="node">
# <title>A</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-162" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="27" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">A</text>
# </g>
# <!-- B -->
# <g id="node2" class="node">
# <title>B</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-18" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="27" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">B</text>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge1" class="edge">
# <title>A-&gt;B</title>
# <path fill="none" stroke="#4a4a4a" d="M22.77,-144.06C20.97,-133.69 18.92,-120.21 18,-108.07 16.8,-92.04 16.8,-87.96 18,-71.93 18.61,-63.86 19.71,-55.23 20.92,-47.28"/>
# <path fill="none" stroke="#4a4a4a" d="M24.74,-143.72C22.94,-133.39 20.89,-119.91 20,-107.93 18.8,-92.04 18.8,-87.96 20,-72.07 20.59,-64.12 21.7,-55.48 22.9,-47.58"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="25.35,-48.04 23.51,-37.61 18.45,-46.91 25.35,-48.04"/>
# </g>
# <!-- C -->
# <g id="node3" class="node">
# <title>C</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="55" cy="-90" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="55" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">C</text>
# </g>
# <!-- A&#45;&gt;C -->
# <g id="edge2" class="edge">
# <title>A-&gt;C</title>
# <path fill="none" stroke="#4a4a4a" d="M32.71,-144.04C35.85,-136.19 39.67,-126.62 43.22,-117.76"/>
# <path fill="none" stroke="#4a4a4a" d="M34.56,-144.78C37.7,-136.94 41.53,-127.37 45.08,-118.5"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="47.39,-119.46 47.85,-108.88 40.89,-116.86 47.39,-119.46"/>
# </g>
# <!-- C&#45;&gt;B -->
# <g id="edge3" class="edge">
# <title>C-&gt;B</title>
# <path fill="none" stroke="#4a4a4a" d="M47.44,-72.78C44.3,-64.94 40.47,-55.37 36.92,-46.5"/>
# <path fill="none" stroke="#4a4a4a" d="M49.29,-72.04C46.15,-64.19 42.33,-54.62 38.78,-45.76"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="41.11,-44.86 34.15,-36.88 34.61,-47.46 41.11,-44.86"/>
# </g>
# </g>
# </svg><br><center><small><em>the second causal model</em></small></center></div><br/><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>Doing $A=10$</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>Doing $A=20$</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>Doing $A=30$</em></small></center></div>
