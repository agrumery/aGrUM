# %% [markdown]
# # Where is my Bag ? (p115)

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://agrum.org) |[ ![interactive online version](images/atbinder.svg)](https://agrum.gitlab.io/extra/agrum_at_binder.html)
#
# Authors: <b>Aymen Merrouche</b> and Pierre-Henri Wuillemin.
#
# **This notebook follows the example from "The Book Of Why" (Pearl, 2018) chapter 3 page115**

# %%
import pyagrum as gum
import pyagrum.lib.notebook as gnb
import pyagrum.causal as csl
import pyagrum.causal.notebook as cslnb
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# >After making a stopover, a passenger is waiting for his luggage. What are the chances that his luggage wasn't properly routed and got lost?
# The appearance of his luggage on the carousel has two causes, its presence on the plane (if not, then there are no chances for him to recover it) and the time he spent waiting in front of the carousel. (The more he waits, the more his chances of seeing his luggage increase.)

# %% [markdown]
# ## causal graph for the Bag problem
# The corresponding causal diagram is the following:

# %%
ab = gum.fastBN("Elapsed time[11]->Bag on Carousel<-Bag on Plane")
ab
# Out:
# (pyagrum.BayesNet@0x13bd7ce00) BN{nodes: 3, arcs: 2, domainSize: 44, dim: 33, mem: 456o}

# %%
# We fill the CPTs
ab.cpt("Bag on Plane").fillWith(1).normalize()
ab.cpt("Elapsed time").fillWith(1).normalize()
ab.cpt("Bag on Carousel").fillWith([1.0, 0.0] * 11 + [1 - i / 20 if i % 2 == 0 else (i - 1) / 20 for i in range(22)])
# Out:
# (pyagrum.Tensor@0x6000008912a0)
#              ||  Bag on Carousel  |
# Elapse|Bag on||0        |1        |
# ------|------||---------|---------|
# 0     |0     || 1.0000  | 0.0000  |
# 1     |0     || 1.0000  | 0.0000  |
# 2     |0     || 1.0000  | 0.0000  |
# 3     |0     || 1.0000  | 0.0000  |
# 4     |0     || 1.0000  | 0.0000  |
# 5     |0     || 1.0000  | 0.0000  |
# [...10 more line(s) ...]
# 5     |1     || 0.5000  | 0.5000  |
# 6     |1     || 0.4000  | 0.6000  |
# 7     |1     || 0.3000  | 0.7000  |
# 8     |1     || 0.2000  | 0.8000  |
# 9     |1     || 0.1000  | 0.9000  |
# 10    |1     || 0.0000  | 1.0000  |

# %%
gnb.sideBySide(
  ab,
  ab.cpt("Bag on Plane"),
  ab.cpt("Elapsed time"),
  captions=["the BN", "marginal for $BagOnPlane$", "marginal for $Elapsed time$"],
)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="266pt" height="116pt" viewBox="0.00 0.00 266.10 116.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 112)">
# <title>G</title>
# <!-- Bag on Carousel -->
# <g id="node1" class="node">
# <title>Bag on Carousel</title>
# <g id="a_node1"><a xlink:title="(1) Bag on Carousel">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="129.56" cy="-18" rx="72.85" ry="18"/>
# <text text-anchor="middle" x="129.56" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">Bag on Carousel</text>
# </a>
# </g>
# </g>
# <!-- Bag on Plane -->
# <g id="node2" class="node">
# <title>Bag on Plane</title>
# <g id="a_node2"><a xlink:title="(2) Bag on Plane">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="60.56" cy="-90" rx="60.56" ry="18"/>
# <text text-anchor="middle" x="60.56" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">Bag on Plane</text>
# </a>
# </g>
# </g>
# <!-- Bag on Plane&#45;&gt;Bag on Carousel -->
# <g id="edge2" class="edge">
# <title>Bag on Plane-&gt;Bag on Carousel</title>
# <g id="a_edge2"><a xlink:title="2 → 1">
# <path fill="none" stroke="#4a4a4a" d="M76.92,-72.41C85.3,-63.91 95.68,-53.37 105.01,-43.91"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="107.26,-46.61 111.79,-37.03 102.27,-41.7 107.26,-46.61"/>
# </a>
# </g>
# </g>
# <!-- Elapsed time -->
# <g id="node3" class="node">
# <title>Elapsed time</title>
# <g id="a_node3"><a xlink:title="(0) Elapsed time">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="198.56" cy="-90" rx="59.54" ry="18"/>
# <text text-anchor="middle" x="198.56" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">Elapsed time</text>
# </a>
# </g>
# </g>
# <!-- Elapsed time&#45;&gt;Bag on Carousel -->
# <g id="edge1" class="edge">
# <title>Elapsed time-&gt;Bag on Carousel</title>
# <g id="a_edge1"><a xlink:title="0 → 1">
# <path fill="none" stroke="#4a4a4a" d="M182.21,-72.41C173.83,-63.91 163.45,-53.37 154.12,-43.91"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="156.85,-41.7 147.34,-37.03 151.87,-46.61 156.85,-41.7"/>
# </a>
# </g>
# </g>
# </g>
# </svg><br><small><i>the BN</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Bag on Plane</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#bfbf64;text-align:right;padding: 3px;'>0.5000</td><td style='color:black;background-color:#bfbf64;text-align:right;padding: 3px;'>0.5000</td></tr>
# </table><br><small><i>marginal for $BagOnPlane$</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='11'><center>Elapsed time</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>2</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>3</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>4</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>5</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>6</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>7</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>8</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>9</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>10</center></th></tr>
# <tr><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0909</td><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0909</td><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0909</td><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0909</td><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0909</td><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0909</td><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0909</td><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0909</td><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0909</td><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0909</td><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0909</td></tr>
# </table><br><small><i>marginal for $Elapsed time$</i></small></div></td></tr></table>

# %% [markdown]
# **It is obvious that:**
#
# * If the bag is on the plane, you will receive it within the 10 minutes:
# $$P(BagOnCarousel = True \mid ElapsedTime = 10,BagOnPlane = True) = 1$$

# %%
# Knowing that 'Bag on Plane':1 and 'Elapsed time': 10
gnb.showInference(ab, targets={"Bag on Carousel"}, evs={"Bag on Plane": 1, "Elapsed time": 10})

# %% [markdown]
# * If the bag is not on the plane in the first place, there are no chances of receiving it :
# $$P(BagOnCarousel = False \mid BagOnplane = False) = 1$$

# %%
# Knowing that 'Bag on Plane':0
gnb.showInference(ab, targets={"Bag on Carousel"}, evs={"Bag on Plane": 0})

# %% [markdown]
# ## First inference
#
# If $x$ minutes have passed and I still haven't gotten my bag, what is the probability that it was on the plane (that I will eventually receive it)?

# %% [markdown]
# > We are interested in probability: $$P(Bag On plane = true \mid ElapsedTime = x,BagOnCarousel = False)$$
# In other words, you are waiting by the carousel at the airport, $x$ minutes have passed and you still haven't received your bag what's the probability that you'll eventually receive it ?. We're looking for the probability that you'll eventually receive your bag (i.e. your bag being on the plane as we saw above.) given that $x$ minutes have passed.

# %%
# inference engine : LazyPropagation
ie1 = gum.LazyPropagation(ab)
ie1.setEvidence({"Elapsed time": 0, "Bag on Carousel": 0})
time = {}
# For every value of elapsed time
for t in range(0, 11):
  # We get the probability of eventually receiving the bag
  ie1.chgEvidence("Elapsed time", t)
  ie1.makeInference()
  time[t] = ie1.posterior("Bag on Plane")[1]
# time is a dictionary : for x in [0,10] {x minutes : P(Bag On plane = true | ElapsedTime = x minutes,BagOnCarousel = False)}

# %% [markdown]
# ### The curve of Abandoning Hope:

# %%
# plot style
sns.set_style("darkgrid")
# labels size
plt.rc("xtick", labelsize=6)
plt.rc("ytick", labelsize=6)
# figure size
plt.figure(figsize=(12, 4))
plt.xlabel('Time Elapsed "min"', fontsize=12)
plt.ylabel("Probability that your bag is on plane", fontsize=10)
# title
plt.title("Probability of seeing your bag on the carousel given that x minutes have passed", fontsize=12)
plt.bar(time.keys(), time.values())
plt.show()

# %% [markdown]
# > After waiting half of the total time, don't panic, <b>There is still a probability of 33% that you will receive your luggage. (with a 50% probability, in the beginning, $\implies$ you should only lose one-third of your hope)</b> !
# $$P(Bag On plane = True \mid ElapsedTime = 5,BagOnCarousel = False) = 0.33$$

# %%
gnb.showPosterior(ab, target="Bag on Plane", evs={"Elapsed time": 5, "Bag on Carousel": 0})

# %% [markdown]
# ## Concerning Colliders :

# %% [markdown]
# In the junction $BagOnPlane \rightarrow BagOnCarousel \leftarrow ElpasedTime$, the node $BagOnCarousel$ is called a collider  (where two or more arrowheads meet). This junction is not an open path $\implies$ no back-door paths between "Bag On Plane" and "Elapsed Time". We don't need to account for "Bag On Carousel" to assess the causal effect of "Bag On plane" on "Elapsed Time". The two variables "Time Elapsed" and "Bag On plane" are <b>d-separate</b>, they are independent, however, they both are causes of "Bag On Carousel" <br>
# ### Assesing causal effect of "Bag on Plane"
#
# We don't need to account for anything to assess the causal effect of "Bag On plane" on "Elapsed Time" :

# %% [markdown]
# <img src="images/figure_3_5.png" width="500">

# %%
abModele = csl.CausalModel(ab, [("l", ("Elapsed time", "Bag on Plane"))])
cslnb.showCausalImpact(abModele, "Elapsed time", doing="Bag on Plane", values={})
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="180pt" height="105pt" viewBox="0.00 0.00 180.00 105.25">
# <g id="graph0" class="graph" transform="scale(0.676426 0.676426) rotate(0) translate(4 151.6)">
# <title>G</title>
# <!-- l -->
# <g id="node1" class="node">
# <title>l</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="128.54" cy="-145.8" rx="1.8" ry="1.8"/>
# </g>
# <!-- Elapsed time -->
# <g id="node2" class="node">
# <title>Elapsed time</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="59.54" cy="-90" rx="59.54" ry="18"/>
# <text text-anchor="middle" x="59.54" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">Elapsed time</text>
# </g>
# <!-- l&#45;&gt;Elapsed time -->
# <g id="edge4" class="edge">
# <title>l-&gt;Elapsed time</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="M127.34,-143.87C122.66,-140.22 105.07,-126.5 88.98,-113.95"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="91.52,-111.49 81.48,-108.1 87.21,-117.01 91.52,-111.49"/>
# </g>
# <!-- Bag on Plane -->
# <g id="node4" class="node">
# <title>Bag on Plane</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="197.54" cy="-90" rx="60.56" ry="18"/>
# <text text-anchor="middle" x="197.54" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">Bag on Plane</text>
# </g>
# <!-- l&#45;&gt;Bag on Plane -->
# <g id="edge2" class="edge">
# <title>l-&gt;Bag on Plane</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="M129.74,-143.87C134.42,-140.22 152.01,-126.5 168.1,-113.95"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="169.87,-117.01 175.6,-108.1 165.57,-111.49 169.87,-117.01"/>
# </g>
# <!-- Bag on Carousel -->
# <g id="node3" class="node">
# <title>Bag on Carousel</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="128.54" cy="-18" rx="72.85" ry="18"/>
# <text text-anchor="middle" x="128.54" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">Bag on Carousel</text>
# </g>
# <!-- Elapsed time&#45;&gt;Bag on Carousel -->
# <g id="edge1" class="edge">
# <title>Elapsed time-&gt;Bag on Carousel</title>
# <path fill="none" stroke="#4a4a4a" d="M75.18,-71.71C83.56,-63.2 93.95,-52.67 103.27,-43.21"/>
# <path fill="none" stroke="#4a4a4a" d="M76.6,-73.11C84.99,-64.61 95.37,-54.07 104.69,-44.62"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="106.24,-46.61 110.76,-37.03 101.25,-41.7 106.24,-46.61"/>
# </g>
# <!-- Bag on Plane&#45;&gt;Bag on Carousel -->
# <g id="edge3" class="edge">
# <title>Bag on Plane-&gt;Bag on Carousel</title>
# <path fill="none" stroke="#4a4a4a" d="M180.48,-73.11C172.09,-64.61 161.71,-54.07 152.39,-44.62"/>
# <path fill="none" stroke="#4a4a4a" d="M181.9,-71.71C173.52,-63.2 163.13,-52.67 153.81,-43.21"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="155.83,-41.7 146.32,-37.03 150.84,-46.61 155.83,-41.7"/>
# </g>
# </g>
# </svg><br><center><small><em>Causal Model</em></small></center></div><div class="floating-box">$$\begin{equation*}P( Elapsed time \mid \text{do}(Bag on Plane)) = P\left(Elapsed time\right)\end{equation*}$$<br><center><small><em>Explanation : No causal effect of X on Y, because they are d-separated (conditioning on the observed variables if any).</em></small></center></div><div class="floating-box"><img src="data:image/png;base64,...
# "><br><center><small><em>Impact</em></small></center></div>

# %% [markdown]
# ### Collider bias!
# Although a little bit counter-intuitive, conditioning on "Bag On Carousel" will make the two variables dependent! <b>Adjusting for a collider increases bias </b>
# > If the bag is not on the carousel and 9 minutes have passed, then it is more likely that the bag is not on the plane.

# %% [markdown]
# > To illustrate collider bias, we will assess the causal effect of "Elapsed Time" on "Bag On Plane" when we don't adjust for collider "Bag On Carousel" and when we adjust for it. (for example, look only in the case where "Bag on Carousel" = 0)

# %% [markdown]
# ### Without adjusting for collider "Bag On Carousel"

# %%
abModele = csl.CausalModel(ab, [("l", ("Elapsed time", "Bag on Plane"))])
cslnb.showCausalImpact(abModele, on={"Bag on Plane"}, doing={"Elapsed time"}, values={"Elapsed time": 9})
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="180pt" height="105pt" viewBox="0.00 0.00 180.00 105.25">
# <g id="graph0" class="graph" transform="scale(0.676426 0.676426) rotate(0) translate(4 151.6)">
# <title>G</title>
# <!-- l -->
# <g id="node1" class="node">
# <title>l</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="128.54" cy="-145.8" rx="1.8" ry="1.8"/>
# </g>
# <!-- Elapsed time -->
# <g id="node2" class="node">
# <title>Elapsed time</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="59.54" cy="-90" rx="59.54" ry="18"/>
# <text text-anchor="middle" x="59.54" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">Elapsed time</text>
# </g>
# <!-- l&#45;&gt;Elapsed time -->
# <g id="edge4" class="edge">
# <title>l-&gt;Elapsed time</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="M127.34,-143.87C122.66,-140.22 105.07,-126.5 88.98,-113.95"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="91.52,-111.49 81.48,-108.1 87.21,-117.01 91.52,-111.49"/>
# </g>
# <!-- Bag on Plane -->
# <g id="node4" class="node">
# <title>Bag on Plane</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="197.54" cy="-90" rx="60.56" ry="18"/>
# <text text-anchor="middle" x="197.54" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">Bag on Plane</text>
# </g>
# <!-- l&#45;&gt;Bag on Plane -->
# <g id="edge2" class="edge">
# <title>l-&gt;Bag on Plane</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="M129.74,-143.87C134.42,-140.22 152.01,-126.5 168.1,-113.95"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="169.87,-117.01 175.6,-108.1 165.57,-111.49 169.87,-117.01"/>
# </g>
# <!-- Bag on Carousel -->
# <g id="node3" class="node">
# <title>Bag on Carousel</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="128.54" cy="-18" rx="72.85" ry="18"/>
# <text text-anchor="middle" x="128.54" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">Bag on Carousel</text>
# </g>
# <!-- Elapsed time&#45;&gt;Bag on Carousel -->
# <g id="edge1" class="edge">
# <title>Elapsed time-&gt;Bag on Carousel</title>
# <path fill="none" stroke="#4a4a4a" d="M75.18,-71.71C83.56,-63.2 93.95,-52.67 103.27,-43.21"/>
# <path fill="none" stroke="#4a4a4a" d="M76.6,-73.11C84.99,-64.61 95.37,-54.07 104.69,-44.62"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="106.24,-46.61 110.76,-37.03 101.25,-41.7 106.24,-46.61"/>
# </g>
# <!-- Bag on Plane&#45;&gt;Bag on Carousel -->
# <g id="edge3" class="edge">
# <title>Bag on Plane-&gt;Bag on Carousel</title>
# <path fill="none" stroke="#4a4a4a" d="M180.48,-73.11C172.09,-64.61 161.71,-54.07 152.39,-44.62"/>
# <path fill="none" stroke="#4a4a4a" d="M181.9,-71.71C173.52,-63.2 163.13,-52.67 153.81,-43.21"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="155.83,-41.7 146.32,-37.03 150.84,-46.61 155.83,-41.7"/>
# </g>
# </g>
# </svg><br><center><small><em>Causal Model</em></small></center></div><div class="floating-box">$$\begin{equation*}P( Bag on Plane \mid \text{do}(Elapsed time)) = P\left(Bag on Plane\right)\end{equation*}$$<br><center><small><em>Explanation : No causal effect of X on Y, because they are d-separated (conditioning on the observed variables if any).</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Bag on Plane</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#bfbf64;text-align:right;padding: 3px;'>0.5000</td><td style='color:black;background-color:#bfbf64;text-align:right;padding: 3px;'>0.5000</td></tr>
# </table><br><center><small><em>Impact</em></small></center></div>

# %% [markdown]
# > The two variables are independent.

# %% [markdown]
# ### When adjusting for collider "Bag On Carousel"

# %% [markdown]
# <b> If we observe that the bag is not on the carousel (Bag On Carousel = 0), the more time passes the more likely the luggage is not on the plane. </b>

# %%
abModele = csl.CausalModel(ab, [("l", ("Elapsed time", "Bag on Plane"))])
cslnb.showCausalImpact(
  abModele,
  on={"Bag on Plane"},
  doing={"Elapsed time"},
  knowing={"Bag on Carousel"},
  values={"Elapsed time": 7, "Bag on Carousel": 0},
)
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="180pt" height="105pt" viewBox="0.00 0.00 180.00 105.25">
# <g id="graph0" class="graph" transform="scale(0.676426 0.676426) rotate(0) translate(4 151.6)">
# <title>G</title>
# <!-- l -->
# <g id="node1" class="node">
# <title>l</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="128.54" cy="-145.8" rx="1.8" ry="1.8"/>
# </g>
# <!-- Elapsed time -->
# <g id="node2" class="node">
# <title>Elapsed time</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="59.54" cy="-90" rx="59.54" ry="18"/>
# <text text-anchor="middle" x="59.54" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">Elapsed time</text>
# </g>
# <!-- l&#45;&gt;Elapsed time -->
# <g id="edge4" class="edge">
# <title>l-&gt;Elapsed time</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="M127.34,-143.87C122.66,-140.22 105.07,-126.5 88.98,-113.95"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="91.52,-111.49 81.48,-108.1 87.21,-117.01 91.52,-111.49"/>
# </g>
# <!-- Bag on Plane -->
# <g id="node4" class="node">
# <title>Bag on Plane</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="197.54" cy="-90" rx="60.56" ry="18"/>
# <text text-anchor="middle" x="197.54" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">Bag on Plane</text>
# </g>
# <!-- l&#45;&gt;Bag on Plane -->
# <g id="edge2" class="edge">
# <title>l-&gt;Bag on Plane</title>
# <path fill="none" stroke="#4a4a4a" stroke-dasharray="5,2" d="M129.74,-143.87C134.42,-140.22 152.01,-126.5 168.1,-113.95"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="169.87,-117.01 175.6,-108.1 165.57,-111.49 169.87,-117.01"/>
# </g>
# <!-- Bag on Carousel -->
# <g id="node3" class="node">
# <title>Bag on Carousel</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="128.54" cy="-18" rx="72.85" ry="18"/>
# <text text-anchor="middle" x="128.54" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">Bag on Carousel</text>
# </g>
# <!-- Elapsed time&#45;&gt;Bag on Carousel -->
# <g id="edge1" class="edge">
# <title>Elapsed time-&gt;Bag on Carousel</title>
# <path fill="none" stroke="#4a4a4a" d="M75.18,-71.71C83.56,-63.2 93.95,-52.67 103.27,-43.21"/>
# <path fill="none" stroke="#4a4a4a" d="M76.6,-73.11C84.99,-64.61 95.37,-54.07 104.69,-44.62"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="106.24,-46.61 110.76,-37.03 101.25,-41.7 106.24,-46.61"/>
# </g>
# <!-- Bag on Plane&#45;&gt;Bag on Carousel -->
# <g id="edge3" class="edge">
# <title>Bag on Plane-&gt;Bag on Carousel</title>
# <path fill="none" stroke="#4a4a4a" d="M180.48,-73.11C172.09,-64.61 161.71,-54.07 152.39,-44.62"/>
# <path fill="none" stroke="#4a4a4a" d="M181.9,-71.71C173.52,-63.2 163.13,-52.67 153.81,-43.21"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="155.83,-41.7 146.32,-37.03 150.84,-46.61 155.83,-41.7"/>
# </g>
# </g>
# </svg><br><center><small><em>Causal Model</em></small></center></div><div class="floating-box">$$\begin{equation*}P( Bag on Plane \mid \text{do}(Elapsed time), Bag on Carousel) =  \frac {P\left(Bag on Plane\right) \cdot P\left(Bag on Carousel\mid Bag on Plane,Elapsed time\right)}{\sum_{Bag on Plane'}{P\left(Bag on Plane'\right) \cdot P\left(Bag on Carousel\mid Bag on Plane',Elapsed time\right)}}\end{equation*}$$<br><center><small><em>Explanation : Do-calculus computations</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>Bag on Plane</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#9ce164;text-align:right;padding: 3px;'>0.7692</td><td style='color:black;background-color:#e19c64;text-align:right;padding: 3px;'>0.2308</td></tr>
# </table><br><center><small><em>Impact</em></small></center></div>

# %% [markdown]
# > The two variables become dependent.
# #### Effect of "Elapsed Time" on "Bag on Plane"
#
# We can draw a curve of the effect of "Elapsed Time" on "Bag on Plane" when adjusting for "Bag On Carousel" (=0) :

# %%
formula, impact, explanation = csl.causalImpact(
  abModele, on={"Bag on Plane"}, doing={"Elapsed time"}, knowing={"Bag on Carousel"}
)
formula
# Out:
# $$P( Bag on Plane \mid \text{do}(Elapsed time), Bag on Carousel) =  \frac {P\left(Bag on Plane\right) \cdot P\left(Bag on Carousel\mid Bag on Plane,Elapsed time\right)}{\sum_{Bag on Plane'}{P\left(Bag on Plane'\right) \cdot P\left(Bag on Carousel\mid Bag on Plane',Elapsed time\right)}}$$

# %% [markdown]
# > As we saw previously, if you still didn't receive your bag, the more you wait the more likely your bag is not on the plane.

# %%
# style du plot
sns.set_style("darkgrid")
# taille des lables
plt.rc("xtick", labelsize=6)
plt.rc("ytick", labelsize=6)
# taille de la figure
plt.figure(figsize=(12, 4))
plt.xlabel('Time Elapsed "min"', fontsize=12)
plt.ylabel("Probability that your bag is not on the plane", fontsize=10)
# titre
plt.title(
  "Probability of not having your bag on the plane given that x minutes have passed and that you still didn't receive it",
  fontsize=12,
)
plt.bar(range(11), impact.extract({"Bag on Carousel": 0, "Bag on Plane": 0}).tolist())
plt.show()
