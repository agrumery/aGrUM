# %% [markdown]
# # Markov random fields (a.k.a. Markov Networks)

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://pyagrum.gitlab.io) |[ ![interactive online version](images/atbinder.svg)](https://mybinder.org/v2/gl/agrumery%2FaGrUM/forBinder?urlpath=%2Fdoc%2Ftree%2Fwrappers%2Fpyagrum%2Fdoc%2Fsphinx%2Fnotebooks%2F23-Models_MarkovRandomField.ipynb)

# %%
import pyagrum.markov_random_field as gum
import pyagrum.lib.notebook as gnb
import pyagrum.lib.mrf2graph as m2g

# %% [markdown]
# ## building a Markov random field

# %%
gum.config.reset()  # back to default
gum.config["notebook", "default_markovrandomfield_view"] = "graph"
mn = gum.fastMRF("A--B--C;C--D;B--E--F;F--D--G;H--J;E--A;J")
mn
# Out:
# (pyagrum.MarkovRandomField@0x7522cdcf00) MRF{nodes: 9, edges: 12, domainSize: 512, dim: 38}

# %% [markdown]
# Using `pyagrum.config`, it is possible to adapt the graphical representations for Markov random field (see the notebook 99-Tools_configForPyAgrum.ipynb).

# %%
gum.config.reset()  # back to default
gum.config["factorgraph", "edge_length"] = "0.4"
gnb.showMRF(mn)

# %%
gum.config.reset()  # back to default
print("Default view for Markov random field: " + gum.config["notebook", "default_markovrandomfield_view"])
gum.config["notebook", "default_markovrandomfield_view"] = "graph"
print("modified to: " + gum.config["notebook", "default_markovrandomfield_view"])
mn
# Out:
# Default view for Markov random field: factorgraph
# modified to: graph
# (pyagrum.MarkovRandomField@0x7522cdcf00) MRF{nodes: 9, edges: 12, domainSize: 512, dim: 38}

# %%
gnb.sideBySide(gnb.getMRF(mn, view="graph", size="5"), gnb.getMRF(mn, view="factorgraph", size="5"))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="202pt" height="360pt" viewBox="0.00 0.00 202.00 360.00">
# <g id="graph0" class="graph" transform="scale(0.891089 0.891089) rotate(0) translate(4 400)">
# <title>G</title>
# <!-- G -->
# <g id="node1" class="node">
# <title>G</title>
# <g id="a_node1"><a xlink:title="(6) G">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="109" cy="-18" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="109" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">G</text>
# </a>
# </g>
# </g>
# <!-- D -->
# <g id="node2" class="node">
# <title>D</title>
# <g id="a_node2"><a xlink:title="(3) D">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="137" cy="-162" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="137" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">D</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&#45;G -->
# <g id="edge11" class="edge">
# <title>D--G</title>
# <g id="a_edge11"><a xlink:title="3 — 6">
# <path fill="none" stroke="#4a4a4a" d="M133.62,-143.87C128.24,-116.58 117.78,-63.52 112.39,-36.19"/>
# </a>
# </g>
# </g>
# <!-- F -->
# <g id="node3" class="node">
# <title>F</title>
# <g id="a_node3"><a xlink:title="(5) F">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="82" cy="-90" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="82" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">F</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&#45;F -->
# <g id="edge12" class="edge">
# <title>D--F</title>
# <g id="a_edge12"><a xlink:title="3 — 5">
# <path fill="none" stroke="#4a4a4a" d="M124.79,-145.46C115.68,-133.86 103.28,-118.08 94.17,-106.49"/>
# </a>
# </g>
# </g>
# <!-- F&#45;&#45;G -->
# <g id="edge9" class="edge">
# <title>F--G</title>
# <g id="a_edge9"><a xlink:title="5 — 6">
# <path fill="none" stroke="#4a4a4a" d="M88.54,-72.05C92.78,-61.05 98.29,-46.76 102.52,-35.79"/>
# </a>
# </g>
# </g>
# <!-- B -->
# <g id="node4" class="node">
# <title>B</title>
# <g id="a_node4"><a xlink:title="(1) B">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="82" cy="-306" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="82" y="-300.95" font-family="Times,serif" font-size="14.00" fill="white">B</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&#45;F -->
# <g id="edge4" class="edge">
# <title>B--F</title>
# <g id="a_edge4"><a xlink:title="1 — 5">
# <path fill="none" stroke="#4a4a4a" d="M82,-287.85C82,-247.78 82,-148.38 82,-108.23"/>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node5" class="node">
# <title>C</title>
# <g id="a_node5"><a xlink:title="(2) C">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="137" cy="-234" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="137" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">C</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&#45;C -->
# <g id="edge2" class="edge">
# <title>B--C</title>
# <g id="a_edge2"><a xlink:title="1 — 2">
# <path fill="none" stroke="#4a4a4a" d="M94.21,-289.46C103.32,-277.86 115.72,-262.08 124.83,-250.49"/>
# </a>
# </g>
# </g>
# <!-- E -->
# <g id="node7" class="node">
# <title>E</title>
# <g id="a_node7"><a xlink:title="(4) E">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-234" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="27" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">E</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&#45;E -->
# <g id="edge5" class="edge">
# <title>B--E</title>
# <g id="a_edge5"><a xlink:title="1 — 4">
# <path fill="none" stroke="#4a4a4a" d="M69.79,-289.46C60.68,-277.86 48.28,-262.08 39.17,-250.49"/>
# </a>
# </g>
# </g>
# <!-- C&#45;&#45;D -->
# <g id="edge6" class="edge">
# <title>C--D</title>
# <g id="a_edge6"><a xlink:title="2 — 3">
# <path fill="none" stroke="#4a4a4a" d="M137,-215.7C137,-204.85 137,-190.92 137,-180.1"/>
# </a>
# </g>
# </g>
# <!-- H -->
# <g id="node6" class="node">
# <title>H</title>
# <g id="a_node6"><a xlink:title="(7) H">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="192" cy="-378" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="192" y="-372.95" font-family="Times,serif" font-size="14.00" fill="white">H</text>
# </a>
# </g>
# </g>
# <!-- J -->
# <g id="node9" class="node">
# <title>J</title>
# <g id="a_node9"><a xlink:title="(8) J">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="192" cy="-306" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="192" y="-300.95" font-family="Times,serif" font-size="14.00" fill="white">J</text>
# </a>
# </g>
# </g>
# <!-- H&#45;&#45;J -->
# <g id="edge10" class="edge">
# <title>H--J</title>
# <g id="a_edge10"><a xlink:title="7 — 8">
# <path fill="none" stroke="#4a4a4a" d="M192,-359.7C192,-348.85 192,-334.92 192,-324.1"/>
# </a>
# </g>
# </g>
# <!-- E&#45;&#45;F -->
# <g id="edge7" class="edge">
# <title>E--F</title>
# <g id="a_edge7"><a xlink:title="4 — 5">
# <path fill="none" stroke="#4a4a4a" d="M33.53,-216.15C44.11,-188.82 64.9,-135.14 75.48,-107.82"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g id="node8" class="node">
# <title>A</title>
# <g id="a_node8"><a xlink:title="(0) A">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="82" cy="-378" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="82" y="-372.95" font-family="Times,serif" font-size="14.00" fill="white">A</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&#45;B -->
# <g id="edge1" class="edge">
# <title>A--B</title>
# <g id="a_edge1"><a xlink:title="0 — 1">
# <path fill="none" stroke="#4a4a4a" d="M82,-359.7C82,-348.85 82,-334.92 82,-324.1"/>
# </a>
# </g>
# </g>
# <!-- A&#45;&#45;C -->
# <g id="edge8" class="edge">
# <title>A--C</title>
# <g id="a_edge8"><a xlink:title="0 — 2">
# <path fill="none" stroke="#4a4a4a" d="M94.75,-361.7C102.56,-351.59 112.15,-337.71 118,-324 128.11,-300.31 133.05,-270.71 135.3,-252.33"/>
# </a>
# </g>
# </g>
# <!-- A&#45;&#45;E -->
# <g id="edge3" class="edge">
# <title>A--E</title>
# <g id="a_edge3"><a xlink:title="0 — 4">
# <path fill="none" stroke="#4a4a4a" d="M69.25,-361.7C61.44,-351.59 51.85,-337.71 46,-324 35.89,-300.31 30.95,-270.71 28.7,-252.33"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="293pt" height="360pt" viewBox="0.00 0.00 293.00 360.00">
# <g id="graph0" class="graph" transform="scale(0.887444 0.887444) rotate(0) translate(4 401.66)">
# <title>G</title>
# <!-- G -->
# <g id="node1" class="node">
# <title>G</title>
# <g id="a_node1"><a xlink:title="(6) G">
# <polygon fill="coral" stroke="#4a4a4a" points="139.47,-22.26 123.96,-22.26 123.96,0 139.47,0 139.47,-22.26"/>
# <text xml:space="preserve" text-anchor="middle" x="131.71" y="-6.08" font-family="Times,serif" font-size="14.00">G</text>
# </a>
# </g>
# </g>
# <!-- D -->
# <g id="node2" class="node">
# <title>D</title>
# <g id="a_node2"><a xlink:title="(3) D">
# <polygon fill="coral" stroke="#4a4a4a" points="189.22,-106.3 173.71,-106.3 173.71,-84.04 189.22,-84.04 189.22,-106.3"/>
# <text xml:space="preserve" text-anchor="middle" x="181.47" y="-90.12" font-family="Times,serif" font-size="14.00">D</text>
# </a>
# </g>
# </g>
# <!-- F -->
# <g id="node3" class="node">
# <title>F</title>
# <g id="a_node3"><a xlink:title="(5) F">
# <polygon fill="coral" stroke="#4a4a4a" points="81.76,-101.03 68.5,-101.03 68.5,-78.77 81.76,-78.77 81.76,-101.03"/>
# <text xml:space="preserve" text-anchor="middle" x="75.13" y="-84.85" font-family="Times,serif" font-size="14.00">F</text>
# </a>
# </g>
# </g>
# <!-- B -->
# <g id="node4" class="node">
# <title>B</title>
# <g id="a_node4"><a xlink:title="(1) B">
# <polygon fill="coral" stroke="#4a4a4a" points="95.23,-194.22 80.47,-194.22 80.47,-171.96 95.23,-171.96 95.23,-194.22"/>
# <text xml:space="preserve" text-anchor="middle" x="87.85" y="-178.04" font-family="Times,serif" font-size="14.00">B</text>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node5" class="node">
# <title>C</title>
# <g id="a_node5"><a xlink:title="(2) C">
# <polygon fill="coral" s

# %%
gnb.showMRF(mn)
print(mn)
# Out:
# MRF{nodes: 9, edges: 12, domainSize: 512, dim: 38}

# %% [markdown]
# ## Accessors for Markov random fields

# %%
print(f"nodes       : {mn.nodes()}")
print(f"node names  : {mn.names()}")
print(f"edges       : {mn.edges()}")
print(f"components  : {mn.connectedComponents()}")
print(f"factors     : {mn.factors()}")
print(f"factor(C,D) : {mn.factor({2, 3})}")
print(f"factor(C,D) : {mn.factor({'C', 'D'})}")
# Out:
# nodes       : {0, 1, 2, 3, 4, 5, 6, 7, 8}
# node names  : {'G', 'D', 'F', 'B', 'C', 'H', 'E', 'A', 'J'}
# edges       : {(0, 1), (1, 2), (0, 4), (1, 5), (1, 4), (2, 3), (4, 5), (0, 2), (5, 6), (7, 8), (3, 6), (3, 5)}
# components  : {3: 0, 8: 1, 1: 0, 6: 0, 4: 0, 7: 1, 0: 0, 2: 0, 5: 0}
# factors     : [{0, 1, 2}, {2, 3}, {8, 7}, {1, 4, 5}, {3, 5, 6}, {0, 4}, {8}]
# factor(C,D) :
#       ║  C                │
# D     ║0        │1        │
# ──────║─────────│─────────│
# 0     ║ 0.0873  │ 0.8666  │
# 1     ║ 0.2404  │ 0.8527  │
#
# factor(C,D) :
#       ║  C                │
# D     ║0        │1        │
# ──────║─────────│─────────│
# 0     ║ 0.0873  │ 0.8666  │
# 1     ║ 0.2404  │ 0.8527  │

# %%
try:
  mn.factor({0, 1})
except gum.GumException as e:
  print(e)
try:
  mn.factor({"A", "B"})
except gum.GumException as e:
  print(e)
# Out:
# [pyAgrum] Object not found: No element with the key <{1,0}>
# [pyAgrum] Object not found: No element with the key <{1,0}>

# %% [markdown]
# ## Manipulating factors

# %%
mn.factor({"A", "B", "C"})
# Out:
# (pyagrum.Tensor@0x75220ec480)
#              ║  A                │
# B     │C     ║0        │1        │
# ──────│──────║─────────│─────────│
# 0     │0     ║ 0.0273  │ 0.9621  │
# 1     │0     ║ 0.7435  │ 0.1808  │
# 0     │1     ║ 0.6688  │ 0.6904  │
# 1     │1     ║ 0.4763  │ 0.1269  │

# %%
mn.factor({"A", "B", "C"})[{"B": 0}]
# Out:
# array([[0.02726654, 0.96214382],
#        [0.66877648, 0.69036741]])

# %%
mn.factor({"A", "B", "C"})[{"B": 0}] = [[1, 2], [3, 4]]
mn.factor({"A", "B", "C"})
# Out:
# (pyagrum.Tensor@0x75220ec480)
#              ║  A                │
# B     │C     ║0        │1        │
# ──────│──────║─────────│─────────│
# 0     │0     ║ 1.0000  │ 2.0000  │
# 1     │0     ║ 0.7435  │ 0.1808  │
# 0     │1     ║ 3.0000  │ 4.0000  │
# 1     │1     ║ 0.4763  │ 0.1269  │

# %% [markdown]
# ## Customizing graphical representation

# %%
gum.config.reset()  # back to default
gum.config["factorgraph", "edge_length"] = "0.5"

maxnei = max([len(mn.neighbours(n)) for n in mn.nodes()])
nodemap = {n: len(mn.neighbours(mn.idFromName(n))) / maxnei for n in mn.names()}

facmax = max([len(f) for f in mn.factors()])
fgma = lambda factor: (1 + len(factor) ** 2) / (1 + facmax * facmax)

gnb.flow.row(
  gnb.getGraph(m2g.MRF2UGdot(mn)),
  gnb.getGraph(m2g.MRF2UGdot(mn, nodeColor=nodemap)),
  gnb.getGraph(m2g.MRF2FactorGraphdot(mn)),
  gnb.getGraph(m2g.MRF2FactorGraphdot(mn, factorColor=fgma, nodeColor=nodemap)),
  captions=[
    "Markov random field",
    "MarkovRandomField with colored node w.r.t number of neighbours",
    "MarkovRandomField as factor graph",
    "MRF with colored factor w.r.t to the size of scope",
  ],
)
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="202pt" height="360pt" viewBox="0.00 0.00 202.00 360.00">
# <g id="graph0" class="graph" transform="scale(0.891089 0.891089) rotate(0) translate(4 400)">
# <title>G</title>
# <!-- G -->
# <g id="node1" class="node">
# <title>G</title>
# <g id="a_node1"><a xlink:title="(6) G">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="109" cy="-18" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="109" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">G</text>
# </a>
# </g>
# </g>
# <!-- D -->
# <g id="node2" class="node">
# <title>D</title>
# <g id="a_node2"><a xlink:title="(3) D">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="137" cy="-162" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="137" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">D</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&#45;G -->
# <g id="edge11" class="edge">
# <title>D--G</title>
# <g id="a_edge11"><a xlink:title="3 — 6">
# <path fill="none" stroke="#4a4a4a" d="M133.62,-143.87C128.24,-116.58 117.78,-63.52 112.39,-36.19"/>
# </a>
# </g>
# </g>
# <!-- F -->
# <g id="node3" class="node">
# <title>F</title>
# <g id="a_node3"><a xlink:title="(5) F">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="82" cy="-90" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="82" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">F</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&#45;F -->
# <g id="edge12" class="edge">
# <title>D--F</title>
# <g id="a_edge12"><a xlink:title="3 — 5">
# <path fill="none" stroke="#4a4a4a" d="M124.79,-145.46C115.68,-133.86 103.28,-118.08 94.17,-106.49"/>
# </a>
# </g>
# </g>
# <!-- F&#45;&#45;G -->
# <g id="edge9" class="edge">
# <title>F--G</title>
# <g id="a_edge9"><a xlink:title="5 — 6">
# <path fill="none" stroke="#4a4a4a" d="M88.54,-72.05C92.78,-61.05 98.29,-46.76 102.52,-35.79"/>
# </a>
# </g>
# </g>
# <!-- B -->
# <g id="node4" class="node">
# <title>B</title>
# <g id="a_node4"><a xlink:title="(1) B">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="82" cy="-306" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="82" y="-300.95" font-family="Times,serif" font-size="14.00" fill="white">B</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&#45;F -->
# <g id="edge4" class="edge">
# <title>B--F</title>
# <g id="a_edge4"><a xlink:title="1 — 5">
# <path fill="none" stroke="#4a4a4a" d="M82,-287.85C82,-247.78 82,-148.38 82,-108.23"/>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node5" class="node">
# <title>C</title>
# <g id="a_node5"><a xlink:title="(2) C">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="137" cy="-234" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="137" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">C</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&#45;C -->
# <g id="edge2" class="edge">
# <title>B--C</title>
# <g id="a_edge2"><a xlink:title="1 — 2">
# <path fill="none" stroke="#4a4a4a" d="M94.21,-289.46C103.32,-277.86 115.72,-262.08 124.83,-250.49"/>
# </a>
# </g>
# </g>
# <!-- E -->
# <g id="node7" class="node">
# <title>E</title>
# <g id="a_node7"><a xlink:title="(4) E">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-234" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="27" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">E</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&#45;E -->
# <g id="edge5" class="edge">
# <title>B--E</title>
# <g id="a_edge5"><a xlink:title="1 — 4">
# <path fill="none" stroke="#4a4a4a" d="M69.79,-289.46C60.68,-277.86 48.28,-262.08 39.17,-250.49"/>
# </a>
# </g>
# </g>
# <!-- C&#45;&#45;D -->
# <g id="edge6" class="edge">
# <title>C--D</title>
# <g id="a_edge6"><a xlink:title="2 — 3">
# <path fill="none" stroke="#4a4a4a" d="M137,-215.7C137,-204.85 137,-190.92 137,-180.1"/>
# </a>
# </g>
# </g>
# <!-- H -->
# <g id="node6" class="node">
# <title>H</title>
# <g id="a_node6"><a xlink:title="(7) H">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="192" cy="-378" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="192" y="-372.95" font-family="Times,serif" font-size="14.00" fill="white">H</text>
# </a>
# </g>
# </g>
# <!-- J -->
# <g id="node9" class="node">
# <title>J</title>
# <g id="a_node9"><a xlink:title="(8) J">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="192" cy="-306" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="192" y="-300.95" font-family="Times,serif" font-size="14.00" fill="white">J</text>
# </a>
# </g>
# </g>
# <!-- H&#45;&#45;J -->
# <g id="edge10" class="edge">
# <title>H--J</title>
# <g id="a_edge10"><a xlink:title="7 — 8">
# <path fill="none" stroke="#4a4a4a" d="M192,-359.7C192,-348.85 192,-334.92 192,-324.1"/>
# </a>
# </g>
# </g>
# <!-- E&#45;&#45;F -->
# <g id="edge7" class="edge">
# <title>E--F</title>
# <g id="a_edge7"><a xlink:title="4 — 5">
# <path fill="none" stroke="#4a4a4a" d="M33.53,-216.15C44.11,-188.82 64.9,-135.14 75.48,-107.82"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g id="node8" class="node">
# <title>A</title>
# <g id="a_node8"><a xlink:title="(0) A">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="82" cy="-378" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="82" y="-372.95" font-family="Times,serif" font-size="14.00" fill="white">A</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&#45;B -->
# <g id="edge1" class="edge">
# <title>A--B</title>
# <g id="a_edge1"><a xlink:title="0 — 1">
# <path fill="none" stroke="#4a4a4a" d="M82,-359.7C82,-348.85 82,-334.92 82,-324.1"/>
# </a>
# </g>
# </g>
# <!-- A&#45;&#45;C -->
# <g id="edge8" class="edge">
# <title>A--C</title>
# <g id="a_edge8"><a xlink:title="0 — 2">
# <path fill="none" stroke="#4a4a4a" d="M94.75,-361.7C102.56,-351.59 112.15,-337.71 118,-324 128.11,-300.31 133.05,-270.71 135.3,-252.33"/>
# </a>
# </g>
# </g>
# <!-- A&#45;&#45;E -->
# <g id="edge3" class="edge">
# <title>A--E</title>
# <g id="a_edge3"><a xlink:title="0 — 4">
# <path fill="none" stroke="#4a4a4a" d="M69.25,-361.7C61.44,-351.59 51.85,-337.71 46,-324 35.89,-300.31 30.95,-270.71 28.7,-252.33"/>
# </a>
# </g>
# </g>
# </g>
# </svg><br><center><small><em>Markov random field</em></small></center></div><div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="202pt" height="360pt" viewBox="0.00 0.00 202.00 360.00">
# <g id="graph0" class="graph" transform="scale(0.891089 0.891089) rotate(0) translate(4 400)">
# <title>G</title>
# <!-- G -->
# <g id="node1" class="node">
# <title>G</title>
# <g id="a_node1"><a xlink:title="(6) G : 0.50000">
# <ellipse fill="#fed9a6" stroke="#4a4a4a" cx="109" cy="-18" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="109" y="-12.95" font-family="Times,serif" font-size="14.00">G</text>
# </a>
# </g>
# </g>
# <!-- D -->
# <g id="node2" class="node">
# <title>D</title>
# <g id="a_node2"><a xlink:title="(3) D : 0.75000">
# <ellipse fill="#e5d8bd" stroke="#4a4a4a" cx="137" cy="-162" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="137" y="-156.95" font-family="Times,serif" font-size="14.00">D</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&#45;G -->
# <g id="edge11" class="edge">
# <title>D--G</title>
# <g id="a_edge11"><a xlink:title="3 — 6">
# <path fill="none" stroke="#4a4a4a" d="M133.62,-143.87C128.24,-116.58 117.78,-63.52 112.39,-36.19"/>
# </a>
# </g>
# </g>
# <!-- F -->
# <g id="node3" class="node">
# <title>F</title>
# <g id="a_node3"><a xlink:title="(5) F : 1.00000">
# <ellipse fill="#aaffff" stroke="#4a4a4a" cx="82" cy="-90" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="82" y="-84.95" font-family="Times,serif" font-size="14.00">F</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&#45;F -->
# <g id="edge12" class="edge">
# <title>D--F</title>
# <g id="a_edge12"><a xlink:title="3 — 5">
# <path fill="none" stroke="#4a4a4a" d="M124.79,-145.46C115.68,-133.86 103.28,-118.08 94.17,-106.49"/>
# </a>
# </g>
# </g>
# <!-- F&#45;&#45;G -->
# <g id="edge9" class="edge">
# <title>F--G</title>
# <g id="a_edge9"><a xlink:title=

# %% [markdown]
# ## from BayesNet to MarkovRandomField

# %%
bn = gum.fastBN("A->B<-C->D->E->F<-B<-G;A->H->I;C->J<-K<-L")
mn = gum.MarkovRandomField.fromBN(bn)
gnb.flow.row(
  bn, gnb.getGraph(m2g.MRF2UGdot(mn)), captions=["a Bayesian network", "the corresponding Markov random field"]
)
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="278pt" height="332pt" viewBox="0.00 0.00 278.00 332.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- G -->
# <g id="node1" class="node">
# <title>G</title>
# <g id="a_node1"><a xlink:title="(6) G">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="171" cy="-234" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="171" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">G</text>
# </a>
# </g>
# </g>
# <!-- B -->
# <g id="node4" class="node">
# <title>B</title>
# <g id="a_node4"><a xlink:title="(1) B">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="171" cy="-162" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="171" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">B</text>
# </a>
# </g>
# </g>
# <!-- G&#45;&gt;B -->
# <g id="edge7" class="edge">
# <title>G-&gt;B</title>
# <g id="a_edge7"><a xlink:title="6 → 1">
# <path fill="none" stroke="#4a4a4a" d="M171,-215.7C171,-208.41 171,-199.73 171,-191.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="174.5,-191.62 171,-181.62 167.5,-191.62 174.5,-191.62"/>
# </a>
# </g>
# </g>
# <!-- D -->
# <g id="node2" class="node">
# <title>D</title>
# <g id="a_node2"><a xlink:title="(3) D">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="99" cy="-162" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="99" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">D</text>
# </a>
# </g>
# </g>
# <!-- E -->
# <g id="node9" class="node">
# <title>E</title>
# <g id="a_node9"><a xlink:title="(4) E">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="103" cy="-90" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="103" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">E</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&gt;E -->
# <g id="edge4" class="edge">
# <title>D-&gt;E</title>
# <g id="a_edge4"><a xlink:title="3 → 4">
# <path fill="none" stroke="#4a4a4a" d="M99.99,-143.7C100.41,-136.41 100.9,-127.73 101.37,-119.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="104.86,-119.8 101.94,-109.62 97.87,-119.4 104.86,-119.8"/>
# </a>
# </g>
# </g>
# <!-- F -->
# <g id="node3" class="node">
# <title>F</title>
# <g id="a_node3"><a xlink:title="(5) F">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="134" cy="-18" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="134" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">F</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&gt;F -->
# <g id="edge5" class="edge">
# <title>B-&gt;F</title>
# <g id="a_edge5"><a xlink:title="1 → 5">
# <path fill="none" stroke="#4a4a4a" d="M166.54,-143.87C160.29,-119.88 148.85,-75.99 141.34,-47.16"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="144.77,-46.45 138.86,-37.65 138,-48.21 144.77,-46.45"/>
# </a>
# </g>
# </g>
# <!-- I -->
# <g id="node5" class="node">
# <title>I</title>
# <g id="a_node5"><a xlink:title="(8) I">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="243" cy="-90" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="243" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">I</text>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node6" class="node">
# <title>C</title>
# <g id="a_node6"><a xlink:title="(2) C">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="99" cy="-234" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="99" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">C</text>
# </a>
# </g>
# </g>
# <!-- C&#45;&gt;D -->
# <g id="edge8" class="edge">
# <title>C-&gt;D</title>
# <g id="a_edge8"><a xlink:title="2 → 3">
# <path fill="none" stroke="#4a4a4a" d="M99,-215.7C99,-208.41 99,-199.73 99,-191.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.5,-191.62 99,-181.62 95.5,-191.62 102.5,-191.62"/>
# </a>
# </g>
# </g>
# <!-- C&#45;&gt;B -->
# <g id="edge3" class="edge">
# <title>C-&gt;B</title>
# <g id="a_edge3"><a xlink:title="2 → 1">
# <path fill="none" stroke="#4a4a4a" d="M113.92,-218.5C123.77,-208.92 136.86,-196.19 148.03,-185.34"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="150.29,-188.02 155.02,-178.54 145.41,-183 150.29,-188.02"/>
# </a>
# </g>
# </g>
# <!-- J -->
# <g id="node12" class="node">
# <title>J</title>
# <g id="a_node12"><a xlink:title="(9) J">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-162" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="27" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">J</text>
# </a>
# </g>
# </g>
# <!-- C&#45;&gt;J -->
# <g id="edge9" class="edge">
# <title>C-&gt;J</title>
# <g id="a_edge9"><a xlink:title="2 → 9">
# <path fill="none" stroke="#4a4a4a" d="M84.08,-218.5C74.23,-208.92 61.14,-196.19 49.97,-185.34"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="52.59,-183 42.98,-178.54 47.71,-188.02 52.59,-183"/>
# </a>
# </g>
# </g>
# <!-- H -->
# <g id="node7" class="node">
# <title>H</title>
# <g id="a_node7"><a xlink:title="(7) H">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="243" cy="-162" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="243" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">H</text>
# </a>
# </g>
# </g>
# <!-- H&#45;&gt;I -->
# <g id="edge12" class="edge">
# <title>H-&gt;I</title>
# <g id="a_edge12"><a xlink:title="7 → 8">
# <path fill="none" stroke="#4a4a4a" d="M243,-143.7C243,-136.41 243,-127.73 243,-119.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="246.5,-119.62 243,-109.62 239.5,-119.62 246.5,-119.62"/>
# </a>
# </g>
# </g>
# <!-- L -->
# <g id="node8" class="node">
# <title>L</title>
# <g id="a_node8"><a xlink:title="(11) L">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-306" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="27" y="-300.95" font-family="Times,serif" font-size="14.00" fill="white">L</text>
# </a>
# </g>
# </g>
# <!-- K -->
# <g id="node11" class="node">
# <title>K</title>
# <g id="a_node11"><a xlink:title="(10) K">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-234" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="27" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">K</text>
# </a>
# </g>
# </g>
# <!-- L&#45;&gt;K -->
# <g id="edge6" class="edge">
# <title>L-&gt;K</title>
# <g id="a_edge6"><a xlink:title="11 → 10">
# <path fill="none" stroke="#4a4a4a" d="M27,-287.7C27,-280.41 27,-271.73 27,-263.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="30.5,-263.62 27,-253.62 23.5,-263.62 30.5,-263.62"/>
# </a>
# </g>
# </g>
# <!-- E&#45;&gt;F -->
# <g id="edge10" class="edge">
# <title>E-&gt;F</title>
# <g id="a_edge10"><a xlink:title="4 → 5">
# <path fill="none" stroke="#4a4a4a" d="M110.35,-72.41C113.86,-64.48 118.15,-54.78 122.12,-45.84"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="125.24,-47.41 126.09,-36.85 118.84,-44.58 125.24,-47.41"/>
# </a>
# </g>
# </g>
# <!-- A -->
# <g id="node10" class="node">
# <title>A</title>
# <g id="a_node10"><a xlink:title="(0) A">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="243" cy="-234" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="243" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">A</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge1" class="edge">
# <title>A-&gt;B</title>
# <g id="a_edge1"><a xlink:title="0 → 1">
# <path fill="none" stroke="#4a4a4a" d="M228.08,-218.5C218.23,-208.92 205.14,-196.19 193.97,-185.34"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="196.59,-183 186.98,-178.54 191.71,-188.02 196.59,-183"/>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;H -->
# <g id="edge2" class="edge">
# <title>A-&gt;H</title>
# <g id="a_edge2"><a xlink:title="0 → 7">
# <path fill="none" stroke="#4a4a4a" d="M243,-215.7C243,-208.41 243,-199.73 243,-191.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="246.5,-191.62 243,-181.62 239.5,-191.62 246.5,-191.62"/>
# </a>
# </g>
# </g>
# <!-- K&#45;&gt;J -->
# <g id="edge

# %%
# The corresponding factor graph
m2g.MRF2FactorGraphdot(mn)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="355pt" height="342pt" viewBox="0.00 0.00 355.00 342.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 337.57)">
# <title>G</title>
# <!-- G -->
# <g id="node1" class="node">
# <title>G</title>
# <g id="a_node1"><a xlink:title="(6) G">
# <polygon fill="coral" stroke="#4a4a4a" points="270.75,-200.69 255.24,-200.69 255.24,-178.43 270.75,-178.43 270.75,-200.69"/>
# <text xml:space="preserve" text-anchor="middle" x="263" y="-184.51" font-family="Times,serif" font-size="14.00">G</text>
# </a>
# </g>
# </g>
# <!-- D -->
# <g id="node2" class="node">
# <title>D</title>
# <g id="a_node2"><a xlink:title="(3) D">
# <polygon fill="coral" stroke="#4a4a4a" points="240.27,-326.64 224.76,-326.64 224.76,-304.38 240.27,-304.38 240.27,-326.64"/>
# <text xml:space="preserve" text-anchor="middle" x="232.51" y="-310.46" font-family="Times,serif" font-size="14.00">D</text>
# </a>
# </g>
# </g>
# <!-- F -->
# <g id="node3" class="node">
# <title>F</title>
# <g id="a_node3"><a xlink:title="(5) F">
# <polygon fill="coral" stroke="#4a4a4a" points="347.21,-270.12 333.95,-270.12 333.95,-247.86 347.21,-247.86 347.21,-270.12"/>
# <text xml:space="preserve" text-anchor="middle" x="340.58" y="-253.94" font-family="Times,serif" font-size="14.00">F</text>
# </a>
# </g>
# </g>
# <!-- B -->
# <g id="node4" class="node">
# <title>B</title>
# <g id="a_node4"><a xlink:title="(1) B">
# <polygon fill="coral" stroke="#4a4a4a" points="273.07,-244.96 258.31,-244.96 258.31,-222.7 273.07,-222.7 273.07,-244.96"/>
# <text xml:space="preserve" text-anchor="middle" x="265.69" y="-228.78" font-family="Times,serif" font-size="14.00">B</text>
# </a>
# </g>
# </g>
# <!-- I -->
# <g id="node5" class="node">
# <title>I</title>
# <g id="a_node5"><a xlink:title="(8) I">
# <polygon fill="coral" stroke="#4a4a4a" points="255.28,-22.26 245.02,-22.26 245.02,0 255.28,0 255.28,-22.26"/>
# <text xml:space="preserve" text-anchor="middle" x="250.15" y="-6.08" font-family="Times,serif" font-size="14.00">I</text>
# </a>
# </g>
# </g>
# <!-- C -->
# <g id="node6" class="node">
# <title>C</title>
# <g id="a_node6"><a xlink:title="(2) C">
# <polygon fill="coral" stroke="#4a4a4a" points="203.02,-251.07 188.26,-251.07 188.26,-228.81 203.02,-228.81 203.02,-251.07"/>
# <text xml:space="preserve" text-anchor="middle" x="195.64" y="-234.89" font-family="Times,serif" font-size="14.00">C</text>
# </a>
# </g>
# </g>
# <!-- H -->
# <g id="node7" class="node">
# <title>H</title>
# <g id="a_node7"><a xlink:title="(7) H">
# <polygon fill="coral" stroke="#4a4a4a" points="245.13,-95.54 229.62,-95.54 229.62,-73.28 245.13,-73.28 245.13,-95.54"/>
# <text xml:space="preserve" text-anchor="middle" x="237.37" y="-79.36" font-family="Times,serif" font-size="14.00">H</text>
# </a>
# </g>
# </g>
# <!-- L -->
# <g id="node8" class="node">
# <title>L</title>
# <g id="a_node8"><a xlink:title="(11) L">
# <polygon fill="coral" stroke="#4a4a4a" points="44.75,-280.59 30.74,-280.59 30.74,-258.33 44.75,-258.33 44.75,-280.59"/>
# <text xml:space="preserve" text-anchor="middle" x="37.75" y="-264.41" font-family="Times,serif" font-size="14.00">L</text>
# </a>
# </g>
# </g>
# <!-- E -->
# <g id="node9" class="node">
# <title>E</title>
# <g id="a_node9"><a xlink:title="(4) E">
# <polygon fill="coral" stroke="#4a4a4a" points="308.33,-314.19 294.32,-314.19 294.32,-291.93 308.33,-291.93 308.33,-314.19"/>
# <text xml:space="preserve" text-anchor="middle" x="301.33" y="-298.01" font-family="Times,serif" font-size="14.00">E</text>
# </a>
# </g>
# </g>
# <!-- A -->
# <g id="node10" class="node">
# <title>A</title>
# <g id="a_node10"><a xlink:title="(0) A">
# <polygon fill="coral" stroke="#4a4a4a" points="227.1,-174.9 211.59,-174.9 211.59,-152.64 227.1,-152.64 227.1,-174.9"/>
# <text xml:space="preserve" text-anchor="middle" x="219.35" y="-158.72" font-family="Times,serif" font-size="14.00">A</text>
# </a>
# </g>
# </g>
# <!-- K -->
# <g id="node11" class="node">
# <title>K</title>
# <g id="a_node11"><a xlink:title="(10) K">
# <polygon fill="coral" stroke="#4a4a4a" points="119.86,-263.92 104.35,-263.92 104.35,-241.66 119.86,-241.66 119.86,-263.92"/>
# <text xml:space="preserve" text-anchor="middle" x="112.1" y="-247.74" font-family="Times,serif" font-size="14.00">K</text>
# </a>
# </g>
# </g>
# <!-- J -->
# <g id="node12" class="node">
# <title>J</title>
# <g id="a_node12"><a xlink:title="(9) J">
# <polygon fill="coral" stroke="#4a4a4a" points="150.33,-307.6 139.32,-307.6 139.32,-285.34 150.33,-285.34 150.33,-307.6"/>
# <text xml:space="preserve" text-anchor="middle" x="144.83" y="-291.42" font-family="Times,serif" font-size="14.00">J</text>
# </a>
# </g>
# </g>
# <!-- f0#1#2#6 -->
# <g id="node13" class="node">
# <title>f0#1#2#6</title>
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="229.09" cy="-208.32" rx="3.6" ry="3.6"/>
# </g>
# <!-- f0#1#2#6&#45;&#45;G -->
# <g id="edge4" class="edge">
# <title>f0#1#2#6--G</title>
# <path fill="none" stroke="#4a4a4a" d="M232.47,-206.45C237.63,-203.6 247.63,-198.07 254.78,-194.11"/>
# </g>
# <!-- f0#1#2#6&#45;&#45;B -->
# <g id="edge2" class="edge">
# <title>f0#1#2#6--B</title>
# <path fill="none" stroke="#4a4a4a" d="M231.96,-210.32C237.49,-214.17 249.78,-222.74 257.89,-228.39"/>
# </g>
# <!-- f0#1#2#6&#45;&#45;C -->
# <g id="edge3" class="edge">
# <title>f0#1#2#6--C</title>
# <path fill="none" stroke="#4a4a4a" d="M226.47,-210.8C221.54,-215.46 210.73,-225.68 203.32,-232.69"/>
# </g>
# <!-- f0#1#2#6&#45;&#45;A -->
# <g id="edge1" class="edge">
# <title>f0#1#2#6--A</title>
# <path fill="none" stroke="#4a4a4a" d="M228.26,-204.52C226.86,-198.12 223.98,-184.95 221.87,-175.31"/>
# </g>
# <!-- f2#3 -->
# <g id="node14" class="node">
# <title>f2#3</title>
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="210.8" cy="-279.48" rx="3.6" ry="3.6"/>
# </g>
# <!-- f2#3&#45;&#45;D -->
# <g id="edge6" class="edge">
# <title>f2#3--D</title>
# <path fill="none" stroke="#4a4a4a" d="M212.81,-282.8C215.7,-287.61 221.2,-296.74 225.66,-304.13"/>
# </g>
# <!-- f2#3&#45;&#45;C -->
# <g id="edge5" class="edge">
# <title>f2#3--C</title>
# <path fill="none" stroke="#4a4a4a" d="M209.4,-275.83C207.29,-270.32 203.2,-259.66 200.03,-251.38"/>
# </g>
# <!-- f3#4 -->
# <g id="node15" class="node">
# <title>f3#4</title>
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="270.7" cy="-329.97" rx="3.6" ry="3.6"/>
# </g>
# <!-- f3#4&#45;&#45;D -->
# <g id="edge7" class="edge">
# <title>f3#4--D</title>
# <path fill="none" stroke="#4a4a4a" d="M266.9,-328.53C260.79,-326.21 248.64,-321.61 240.54,-318.55"/>
# </g>
# <!-- f3#4&#45;&#45;E -->
# <g id="edge8" class="edge">
# <title>f3#4--E</title>
# <path fill="none" stroke="#4a4a4a" d="M273.53,-327.48C278.15,-323.43 287.46,-315.25 294.03,-309.47"/>
# </g>
# <!-- f0#7 -->
# <g id="node16" class="node">
# <title>f0#7</title>
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="231.98" cy="-123.25" rx="3.6" ry="3.6"/>
# </g>
# <!-- f0#7&#45;&#45;H -->
# <g id="edge10" class="edge">
# <title>f0#7--H</title>
# <path fill="none" stroke="#4a4a4a" d="M232.52,-119.38C233.27,-113.94 234.69,-103.77 235.79,-95.8"/>
# </g>
# <!-- f0#7&#45;&#45;A -->
# <g id="edge9" class="edge">
# <title>f0#7--A</title>
# <path fill="none" stroke="#4a4a4a" d="M230.82,-126.99C229.03,-132.71 225.55,-143.87 222.89,-152.4"/>
# </g>
# <!-- f7#8 -->
# <g id="node17" class="node">
# <title>f7#8</title>
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="242.21" cy="-47.12" rx="3.6" ry="3.6"/>
# </g>
# <!-- f7#8&#45;&#45;I -->
# <g id="edge11" class="edge">
# <title>f7#8--I</title>
# <path fill="none" stroke="#4a4a4a" d="M243.06,-43.27C244.13,-38.41 246.03,-29.83 247.59,-22.76"/>
# </g>
# <!-- f7#8&#45;&#45;H -->
# <g id="edge12" class="edge">
# <title>f7#8--H</title>
# <path fill="none" stroke="#4a4a4a" d="M241.69,-51.11C241.02,-56.3 239.82,-65.57 238.85,-73.01"/>
# </g>
# <!-- f2#9#10 -->
# <g id="node18" class="node">
# <title>f2#9#10</title>
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="153.73" cy="-256.94" rx="3.6" ry="3.6"/>
# </g>
# <!-- f2#9#10&#45;&#45;C -->
# <g id="edge14" class="edge">
# <title>f2#9#10--C</title>
# <path fill="none" stroke="#4a4a4a" d="M157.3,-255.49C164.03,-252.76 178.73,-246.8 187.85,-243.1"/>
# </g>
# <!-- f2#9#10&#45;&#45;K -->
# <g id="edge15" class="edge">
# <title>f2#9#10--K</title>
# <path fill="none" stroke="#4a4a4a" d="M14

# %% [markdown]
# ## Inference in Markov random field

# %%
bn = gum.fastBN("A->B<-C->D->E->F<-B<-G;A->H->I;C->J<-K<-L")
iebn = gum.LazyPropagation(bn)

mn = gum.MarkovRandomField.fromBN(bn)
iemn = gum.ShaferShenoyMRFInference(mn)
iemn.setEvidence({"A": 1, "F": [0.4, 0.8]})
iemn.makeInference()
iemn.posterior("B")
# Out:
# (pyagrum.Tensor@0x7522c5f1a0)
#   B                │
# 0        │1        │
# ─────────│─────────│
#  0.4437  │ 0.5563  │

# %%
def affAGC(evs):
  gnb.sideBySide(
    gnb.getSideBySide(
      gum.getPosterior(bn, target="A", evs=evs),
      gum.getPosterior(bn, target="G", evs=evs),
      gum.getPosterior(bn, target="C", evs=evs),
    ),
    gnb.getSideBySide(
      gum.getPosterior(mn, target="A", evs=evs),
      gum.getPosterior(mn, target="G", evs=evs),
      gum.getPosterior(mn, target="C", evs=evs),
    ),
    captions=[
      "Inference in the Bayesian network bn with evidence " + str(evs),
      "Inference in the Markov random field mn with evidence " + str(evs),
    ],
  )


print(
  "Inference for both the corresponding models in BayesNet and Markov Random Field worlds when the MRF comes from a BN"
)
affAGC({})
print("C has no impact on A and G")
affAGC({"C": 1})

print("But if B is observed")
affAGC({"B": 1})
print("C has an impact on A and G")
affAGC({"B": 1, "C": 0})
# Out:
# Inference for both the corresponding models in BayesNet and Markov Random Field worlds when the MRF comes from a BN
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#d0ad64;text-align:right;padding: 3px;'>0.3639</td><td style='color:black;background-color:#add064;text-align:right;padding: 3px;'>0.6361</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>G</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#c7b664;text-align:right;padding: 3px;'>0.4320</td><td style='color:black;background-color:#b6c764;text-align:right;padding: 3px;'>0.5680</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>C</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#b4c964;text-align:right;padding: 3px;'>0.5847</td><td style='color:black;background-color:#c9b464;text-align:right;padding: 3px;'>0.4153</td></tr>
# </table></div></td></tr></table><br><small><i>Inference in the Bayesian network bn with evidence {}</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#d0ad64;text-align:right;padding: 3px;'>0.3639</td><td style='color:black;background-color:#add064;text-align:right;padding: 3px;'>0.6361</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>G</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#c7b664;text-align:right;padding: 3px;'>0.4320</td><td style='color:black;background-color:#b6c764;text-align:right;padding: 3px;'>0.5680</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>C</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#b4c964;text-align:right;padding: 3px;'>0.5847</td><td style='color:black;background-color:#c9b464;text-align:right;padding: 3px;'>0.4153</td></tr>
# </table></div></td></tr></table><br><small><i>Inference in the Markov random field mn with evidence {}</i></small></div></td></tr></table>
# C has no impact on A and G
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#d0ad64;text-align:right;padding: 3px;'>0.3639</td><td style='color:black;background-color:#add064;text-align:right;padding: 3px;'>0.6361</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>G</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#c7b664;text-align:right;padding: 3px;'>0.4320</td><td style='color:black;background-color:#b6c764;text-align:right;padding: 3px;'>0.5680</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>C</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td></tr>
# </table></div></td></tr></table><br><small><i>Inference in the Bayesian network bn with evidence {'C': 1}</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#d0ad64;text-align:right;padding: 3px;'>0.3639</td><td style='color:black;background-color:#add064;text-align:right;padding: 3px;'>0.6361</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>G</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#c7b664;text-align:right;padding: 3px;'>0.4320</td><td style='color:black;background-color:#b6c764;text-align:right;padding: 3px;'>0.5680</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>C</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td></tr>
# </table></div></td></tr></table><br><small><i>Inference in the Markov random field mn with evidence {'C': 1}</i></small></div></td></tr></table>
# But if B is observed
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#cbb264;text-align:right;padding: 3px;'>0.4015</td><td style='color:black;background-color:#b2cb64;text-align:right;padding: 3px;'>0.5985</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>G</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#d4a964;text-align:right;padding: 3px;'>0.3350</td><td style='color:black;background-color:#a9d464;text-align:right;padding: 3px;'>0.6650</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>C</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#aad364;text-align:right;padding: 3px;'>0.6608</td><td style='color:black;background-color:#d3aa64;text-align:right;padding: 3px;'>0.3392</td></tr>
# </table></div></td></tr></table><br><small><i>Inference in the Bayesian network bn with evidence {'B': 1}</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#cbb264;text-align:right;padding: 3px;'>0.4015</td><td style='color:black;background-color:#b2cb64;text-align:right;padding: 3px;'>0.5985</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>G</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#d4a964;text-align:right;padding: 3px;'>0.3350</td><td style='color:black;background-color:#a9d464;text-align:right;padding: 3px;'>0.6650</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>C</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#aad364;text-align:right;padding: 3px;'>0.6608</td><td style='color:black;background-color:#d3aa64;text-align:right;padding: 3px;'>0.3392</td></tr>
# </table></div></td></tr></table><br><small><i>Inference in the Markov random field mn with evidence {'B': 1}</i></small></div></td></tr></table>
# C has an impact on A and G
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#cbb264;text-align:right;padding: 3px;'>0.4031</td><td style='color:black;background-color:#b2cb64;text-align:right;padding: 3px;'>0.5969</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>G</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#d6a764;text-align:right;padding: 3px;'>0.3197</td><td style='color:black;background-color:#a7d664;text-align:right;padding: 3px;'>0.6803</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>C</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td></tr>
# </table></div></td></tr></table><br><small><i>Inference in the Bayesian network bn with evidence {'B': 1, 'C': 0}</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#cbb264;text-align:right;padding: 3px;'>0.4031</td><td style='color:black;background-color:#b2cb64;text-align:right;padding: 3px;'>0.5969</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>G</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#d6a764;text-align:right;padding: 3px;'>0.3197</td><td style='color:black;background-color:#a7d664;text-align:right;padding: 3px;'>0.6803</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>C</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td></tr>
# </table></div></td></tr></table><br><small><i>Inference in the Markov random field mn with evidence {'B': 1, 'C': 0}</i></small></div></td></tr></table>

# %%
mn.generateFactors()
print("But with more general factors")
affAGC({})
print("C has impact on A and G even without knowing B")
affAGC({"C": 1})
# Out:
# But with more general factors
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#d0ad64;text-align:right;padding: 3px;'>0.3639</td><td style='color:black;background-color:#add064;text-align:right;padding: 3px;'>0.6361</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>G</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#c7b664;text-align:right;padding: 3px;'>0.4320</td><td style='color:black;background-color:#b6c764;text-align:right;padding: 3px;'>0.5680</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>C</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#b4c964;text-align:right;padding: 3px;'>0.5847</td><td style='color:black;background-color:#c9b464;text-align:right;padding: 3px;'>0.4153</td></tr>
# </table></div></td></tr></table><br><small><i>Inference in the Bayesian network bn with evidence {}</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#f18c64;text-align:right;padding: 3px;'>0.1091</td><td style='color:black;background-color:#8cf164;text-align:right;padding: 3px;'>0.8909</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>G</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#86f764;text-align:right;padding: 3px;'>0.9452</td><td style='color:black;background-color:#f78664;text-align:right;padding: 3px;'>0.0548</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>C</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#ec9164;text-align:right;padding: 3px;'>0.1408</td><td style='color:black;background-color:#91ec64;text-align:right;padding: 3px;'>0.8592</td></tr>
# </table></div></td></tr></table><br><small><i>Inference in the Markov random field mn with evidence {}</i></small></div></td></tr></table>
# C has impact on A and G even without knowing B
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#d0ad64;text-align:right;padding: 3px;'>0.3639</td><td style='color:black;background-color:#add064;text-align:right;padding: 3px;'>0.6361</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>G</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#c7b664;text-align:right;padding: 3px;'>0.4320</td><td style='color:black;background-color:#b6c764;text-align:right;padding: 3px;'>0.5680</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>C</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td></tr>
# </table></div></td></tr></table><br><small><i>Inference in the Bayesian network bn with evidence {'C': 1}</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0863</td><td style='color:black;background-color:#8af364;text-align:right;padding: 3px;'>0.9137</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>G</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#84f964;text-align:right;padding: 3px;'>0.9541</td><td style='color:black;background-color:#f98464;text-align:right;padding: 3px;'>0.0459</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>C</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td></tr>
# </table></div></td></tr></table><br><small><i>Inference in the Markov random field mn with evidence {'C': 1}</i></small></div></td></tr></table>

# %% [markdown]
# ## Graphical inference in Markov random field

# %%
bn = gum.fastBN("A->B<-C->D->E->F<-B<-G;A->H->I;C->J<-K<-L")
mn = gum.MarkovRandomField.fromBN(bn)

gnb.sideBySide(
  gnb.getJunctionTree(bn),
  gnb.getJunctionTree(mn),
  captions=["Junction tree for the BN", "Junction tree for the induced MN"],
)
gnb.sideBySide(
  gnb.getJunctionTreeMap(bn, size="3!"),
  gnb.getJunctionTreeMap(mn, size="3!"),
  captions=["Map of the junction tree for the BN", "Map of the junction tree for the induced MN"],
)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="334pt" height="421pt" viewBox="0.00 0.00 334.00 421.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 417.25)">
# <!-- (0) 7&#45;8 -->
# <g id="node1" class="node">
# <title>(0) 7-8</title>
# <g id="a_node1"><a xlink:title="size : 2&#10;7&#10;8">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="27" cy="-269.5" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="27" y="-264.45" font-family="Times,serif" font-size="14.00">H I</text>
# </a>
# </g>
# </g>
# <!-- (0) 7&#45;8^(4) 0&#45;7 -->
# <g id="node11" class="node">
# <title>(0) 7-8^(4) 0-7</title>
# <g id="a_node11"><a xlink:title="size : 1&#10;7">
# <polygon fill="palegreen" stroke="#4a4a4a" points="51,-215.5 29,-215.5 29,-197.75 51,-197.75 51,-215.5"/>
# <text xml:space="preserve" text-anchor="middle" x="40" y="-203.9" font-family="Times,serif" font-size="8.00">H</text>
# </a>
# </g>
# </g>
# <!-- (0) 7&#45;8&#45;&#45;(0) 7&#45;8^(4) 0&#45;7 -->
# <g id="edge5" class="edge">
# <title>(0) 7-8--(0) 7-8^(4) 0-7</title>
# <path fill="none" stroke="#4a4a4a" d="M30.69,-251.22C33.18,-239.55 36.36,-224.68 38.28,-215.67"/>
# </g>
# <!-- (1) 10&#45;11 -->
# <g id="node2" class="node">
# <title>(1) 10-11</title>
# <g id="a_node2"><a xlink:title="size : 2&#10;10&#10;11">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="294" cy="-395.25" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="294" y="-390.2" font-family="Times,serif" font-size="14.00">K L</text>
# </a>
# </g>
# </g>
# <!-- (1) 10&#45;11^(3) 2&#45;9&#45;10 -->
# <g id="node10" class="node">
# <title>(1) 10-11^(3) 2-9-10</title>
# <g id="a_node10"><a xlink:title="size : 1&#10;10">
# <polygon fill="palegreen" stroke="#4a4a4a" points="305,-341.25 283,-341.25 283,-323.5 305,-323.5 305,-341.25"/>
# <text xml:space="preserve" text-anchor="middle" x="294" y="-329.65" font-family="Times,serif" font-size="8.00">K</text>
# </a>
# </g>
# </g>
# <!-- (1) 10&#45;11&#45;&#45;(1) 10&#45;11^(3) 2&#45;9&#45;10 -->
# <g id="edge3" class="edge">
# <title>(1) 10-11--(1) 10-11^(3) 2-9-10</title>
# <path fill="none" stroke="#4a4a4a" d="M294,-376.97C294,-365.3 294,-350.43 294,-341.42"/>
# </g>
# <!-- (2) 0&#45;1&#45;2&#45;6 -->
# <g id="node3" class="node">
# <title>(2) 0-1-2-6</title>
# <g id="a_node3"><a xlink:title="size : 4&#10;0&#10;1&#10;2&#10;6">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="116" cy="-269.5" rx="43.67" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="116" y="-264.45" font-family="Times,serif" font-size="14.00">A B C G</text>
# </a>
# </g>
# </g>
# <!-- (2) 0&#45;1&#45;2&#45;6^(8) 1&#45;2&#45;4 -->
# <g id="node13" class="node">
# <title>(2) 0-1-2-6^(8) 1-2-4</title>
# <g id="a_node13"><a xlink:title="size : 2&#10;1&#10;2">
# <polygon fill="palegreen" stroke="#4a4a4a" points="176.38,-215.5 147.62,-215.5 147.62,-197.75 176.38,-197.75 176.38,-215.5"/>
# <text xml:space="preserve" text-anchor="middle" x="162" y="-203.9" font-family="Times,serif" font-size="8.00">B C</text>
# </a>
# </g>
# </g>
# <!-- (2) 0&#45;1&#45;2&#45;6&#45;&#45;(2) 0&#45;1&#45;2&#45;6^(8) 1&#45;2&#45;4 -->
# <g id="edge9" class="edge">
# <title>(2) 0-1-2-6--(2) 0-1-2-6^(8) 1-2-4</title>
# <path fill="none" stroke="#4a4a4a" d="M128.57,-251.87C137.4,-240.18 148.84,-225.05 155.78,-215.85"/>
# </g>
# <!-- (2) 0&#45;1&#45;2&#45;6^(4) 0&#45;7 -->
# <g id="node14" class="node">
# <title>(2) 0-1-2-6^(4) 0-7</title>
# <g id="a_node14"><a xlink:title="size : 1&#10;0">
# <polygon fill="palegreen" stroke="#4a4a4a" points="115,-215.5 93,-215.5 93,-197.75 115,-197.75 115,-215.5"/>
# <text xml:space="preserve" text-anchor="middle" x="104" y="-203.9" font-family="Times,serif" font-size="8.00">A</text>
# </a>
# </g>
# </g>
# <!-- (2) 0&#45;1&#45;2&#45;6&#45;&#45;(2) 0&#45;1&#45;2&#45;6^(4) 0&#45;7 -->
# <g id="edge11" class="edge">
# <title>(2) 0-1-2-6--(2) 0-1-2-6^(4) 0-7</title>
# <path fill="none" stroke="#4a4a4a" d="M112.59,-251.22C110.29,-239.55 107.36,-224.68 105.59,-215.67"/>
# </g>
# <!-- (3) 2&#45;9&#45;10 -->
# <g id="node4" class="node">
# <title>(3) 2-9-10</title>
# <g id="a_node4"><a xlink:title="size : 3&#10;2&#10;9&#10;10">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="294" cy="-269.5" rx="32.41" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="294" y="-264.45" font-family="Times,serif" font-size="14.00">C J K</text>
# </a>
# </g>
# </g>
# <!-- (3) 2&#45;9&#45;10^(8) 1&#45;2&#45;4 -->
# <g id="node15" class="node">
# <title>(3) 2-9-10^(8) 1-2-4</title>
# <g id="a_node15"><a xlink:title="size : 1&#10;2">
# <polygon fill="palegreen" stroke="#4a4a4a" points="284.62,-215.5 263.38,-215.5 263.38,-197.75 284.62,-197.75 284.62,-215.5"/>
# <text xml:space="preserve" text-anchor="middle" x="274" y="-203.9" font-family="Times,serif" font-size="8.00">C</text>
# </a>
# </g>
# </g>
# <!-- (3) 2&#45;9&#45;10&#45;&#45;(3) 2&#45;9&#45;10^(8) 1&#45;2&#45;4 -->
# <g id="edge13" class="edge">
# <title>(3) 2-9-10--(3) 2-9-10^(8) 1-2-4</title>
# <path fill="none" stroke="#4a4a4a" d="M288.43,-251.54C284.59,-239.86 279.66,-224.86 276.67,-215.76"/>
# </g>
# <!-- (4) 0&#45;7 -->
# <g id="node5" class="node">
# <title>(4) 0-7</title>
# <g id="a_node5"><a xlink:title="size : 2&#10;0&#10;7">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="72" cy="-143.75" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="72" y="-138.7" font-family="Times,serif" font-size="14.00">A H</text>
# </a>
# </g>
# </g>
# <!-- (6) 1&#45;4&#45;5 -->
# <g id="node6" class="node">
# <title>(6) 1-4-5</title>
# <g id="a_node6"><a xlink:title="size : 3&#10;1&#10;4&#10;5">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="211" cy="-269.5" rx="32.93" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="211" y="-264.45" font-family="Times,serif" font-size="14.00">B E F</text>
# </a>
# </g>
# </g>
# <!-- (6) 1&#45;4&#45;5^(8) 1&#45;2&#45;4 -->
# <g id="node12" class="node">
# <title>(6) 1-4-5^(8) 1-2-4</title>
# <g id="a_node12"><a xlink:title="size : 2&#10;1&#10;4">
# <polygon fill="palegreen" stroke="#4a4a4a" points="225.38,-215.5 196.62,-215.5 196.62,-197.75 225.38,-197.75 225.38,-215.5"/>
# <text xml:space="preserve" text-anchor="middle" x="211" y="-203.9" font-family="Times,serif" font-size="8.00">B E</text>
# </a>
# </g>
# </g>
# <!-- (6) 1&#45;4&#45;5&#45;&#45;(6) 1&#45;4&#45;5^(8) 1&#45;2&#45;4 -->
# <g id="edge7" class="edge">
# <title>(6) 1-4-5--(6) 1-4-5^(8) 1-2-4</title>
# <path fill="none" stroke="#4a4a4a" d="M211,-251.22C211,-239.55 211,-224.68 211,-215.67"/>
# </g>
# <!-- (8) 1&#45;2&#45;4 -->
# <g id="node7" class="node">
# <title>(8) 1-2-4</title>
# <g id="a_node7"><a xlink:title="size : 3&#10;1&#10;2&#10;4">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="211" cy="-143.75" rx="33.95" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="211" y="-138.7" font-family="Times,serif" font-size="14.00">B C E</text>
# </a>
# </g>
# </g>
# <!-- (8) 1&#45;2&#45;4^(9) 2&#45;3&#45;4 -->
# <g id="node9" class="node">
# <title>(8) 1-2-4^(9) 2-3-4</title>
# <g id="a_node9"><a xlink:title="size : 2&#10;2&#10;4">
# <polygon fill="palegreen" stroke="#4a4a4a" points="225.38,-89.75 196.62,-89.75 196.62,-72 225.38,-72 225.38,-89.75"/>
# <text xml:space="preserve" text-anchor="middle" x="211" y="-78.15" font-family="Times,serif" font-size="8.00">C E</text>
# </a>
# </g>
# </g>
# <!-- (8) 1&#45;2&#45;4&#45;&#45;(8) 1&#45;2&#45;4^(9) 2&#45;3&#45;4 -->
# <g id="edge1" class="edge">
# <title>(8) 1-2-4--(8) 1-2-4^(9) 2-3-4</title>
# <path fill="none" stroke="#4a4a4a" d="M211,-125.47C211,-113.8 211,-98.93 211,-89.92"/>
# </g>
# <!-- (9) 2&#45;3&#45;4 -->
# <g id="node8" class="node">
# <title>(9) 2-3-4</title>
# <g id="a_node8"><a xlink:title="size : 3&#10;2&#10;3&#10;4">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="211" cy="-18" rx="34.46" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="211" y="-12.95" font-family="Times,serif" font-size="14.00">C D E</text>
# </a>
# </g>
# </g>
# <!-- (8) 1&#45;2&#45;4^(9) 2&#45;3&#45;4&#45;&#45;(9) 2&#45;3
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="161pt" height="216pt" viewBox="0.00 0.00 161.00 216.00">
# <g id="graph0" class="graph" transform="scale(0.325848 0.325848) rotate(0) translate(4 658.89)">
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <g id="a_node1"><a xlink:title="size : 2&#10;7&#10;8">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="21.6" cy="-21.6" rx="21.6" ry="21.6"/>
# </a>
# </g>
# </g>
# <!-- 0~4 -->
# <g id="node11" class="node">
# <title>0~4</title>
# <g id="a_node11"><a xlink:title="size : 1&#10;7">
# <polygon fill="palegreen" stroke="#4a4a4a" points="82.62,-70.13 75.42,-70.13 75.42,-62.93 82.62,-62.93 82.62,-70.13"/>
# </a>
# </g>
# </g>
# <!-- 0&#45;&#45;0~4 -->
# <g id="edge5" class="edge">
# <title>0--0~4</title>
# <path fill="none" stroke="#4a4a4a" d="M38.83,-35.08C51.51,-45 67.78,-57.73 75.12,-63.47"/>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <g id="a_node2"><a xlink:title="size : 2&#10;10&#10;11">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="463.5" cy="-633.29" rx="21.6" ry="21.6"/>
# </a>
# </g>
# </g>
# <!-- 1~3 -->
# <g id="node10" class="node">
# <title>1~3</title>
# <g id="a_node10"><a xlink:title="size : 1&#10;10">
# <polygon fill="palegreen" stroke="#4a4a4a" points="421.14,-579.92 413.94,-579.92 413.94,-572.72 421.14,-572.72 421.14,-579.92"/>
# </a>
# </g>
# </g>
# <!-- 1&#45;&#45;1~3 -->
# <g id="edge3" class="edge">
# <title>1--1~3</title>
# <path fill="none" stroke="#4a4a4a" d="M449.71,-616.19C439.56,-603.61 426.54,-587.47 420.66,-580.19"/>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <g id="a_node3"><a xlink:title="size : 4&#10;0&#10;1&#10;2&#10;6">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="208.68" cy="-245.1" rx="43.2" ry="43.2"/>
# </a>
# </g>
# </g>
# <!-- 2~8 -->
# <g id="node13" class="node">
# <title>2~8</title>
# <g id="a_node13"><a xlink:title="size : 2&#10;1&#10;2">
# <polygon fill="palegreen" stroke="#4a4a4a" points="256.3,-317.8 241.9,-317.8 241.9,-303.4 256.3,-303.4 256.3,-317.8"/>
# </a>
# </g>
# </g>
# <!-- 2&#45;&#45;2~8 -->
# <g id="edge9" class="edge">
# <title>2--2~8</title>
# <path fill="none" stroke="#4a4a4a" d="M231.49,-282.06C236.5,-290.18 241.3,-297.96 244.62,-303.33"/>
# </g>
# <!-- 2~4 -->
# <g id="node14" class="node">
# <title>2~4</title>
# <g id="a_node14"><a xlink:title="size : 1&#10;0">
# <polygon fill="palegreen" stroke="#4a4a4a" points="173.06,-185.3 165.86,-185.3 165.86,-178.1 173.06,-178.1 173.06,-185.3"/>
# </a>
# </g>
# </g>
# <!-- 2&#45;&#45;2~4 -->
# <g id="edge11" class="edge">
# <title>2--2~4</title>
# <path fill="none" stroke="#4a4a4a" d="M185.86,-208.22C180.2,-199.07 174.91,-190.51 171.93,-185.7"/>
# </g>
# <!-- 3 -->
# <g id="node4" class="node">
# <title>3</title>
# <g id="a_node4"><a xlink:title="size : 3&#10;2&#10;9&#10;10">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="377.06" cy="-513.88" rx="32.4" ry="32.4"/>
# </a>
# </g>
# </g>
# <!-- 3~8 -->
# <g id="node15" class="node">
# <title>3~8</title>
# <g id="a_node15"><a xlink:title="size : 1&#10;2">
# <polygon fill="palegreen" stroke="#4a4a4a" points="340.22,-451.83 333.02,-451.83 333.02,-444.63 340.22,-444.63 340.22,-451.83"/>
# </a>
# </g>
# </g>
# <!-- 3&#45;&#45;3~8 -->
# <g id="edge13" class="edge">
# <title>3--3~8</title>
# <path fill="none" stroke="#4a4a4a" d="M359.91,-486.04C351.81,-472.9 343.05,-458.67 338.96,-452.04"/>
# </g>
# <!-- 4 -->
# <g id="node5" class="node">
# <title>4</title>
# <g id="a_node5"><a xlink:title="size : 2&#10;0&#10;7">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="126.95" cy="-121.72" rx="21.6" ry="21.6"/>
# </a>
# </g>
# </g>
# <!-- 6 -->
# <g id="node6" class="node">
# <title>6</title>
# <g id="a_node6"><a xlink:title="size : 3&#10;1&#10;4&#10;5">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="160.97" cy="-477.67" rx="32.4" ry="32.4"/>
# </a>
# </g>
# </g>
# <!-- 6~8 -->
# <g id="node12" class="node">
# <title>6~8</title>
# <g id="a_node12"><a xlink:title="size : 2&#10;1&#10;4">
# <polygon fill="palegreen" stroke="#4a4a4a" points="230.49,-435.78 216.09,-435.78 216.09,-421.38 230.49,-421.38 230.49,-435.78"/>
# </a>
# </g>
# </g>
# <!-- 6&#45;&#45;6~8 -->
# <g id="edge7" class="edge">
# <title>6--6~8</title>
# <path fill="none" stroke="#4a4a4a" d="M186.68,-457.42C197.14,-449.18 208.45,-440.27 215.69,-434.57"/>
# </g>
# <!-- 8 -->
# <g id="node7" class="node">
# <title>8</title>
# <g id="a_node7"><a xlink:title="size : 3&#10;1&#10;2&#10;4">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="293.04" cy="-379.59" rx="32.4" ry="32.4"/>
# </a>
# </g>
# </g>
# <!-- 8~9 -->
# <g id="node9" class="node">
# <title>8~9</title>
# <g id="a_node9"><a xlink:title="size : 2&#10;2&#10;4">
# <polygon fill="palegreen" stroke="#4a4a4a" points="374.08,-344.17 359.68,-344.17 359.68,-329.77 374.08,-329.77 374.08,-344.17"/>
# </a>
# </g>
# </g>
# <!-- 8&#45;&#45;8~9 -->
# <g id="edge1" class="edge">
# <title>8--8~9</title>
# <path fill="none" stroke="#4a4a4a" d="M321.38,-363.23C335.04,-355.35 350.37,-346.5 359.29,-341.35"/>
# </g>
# <!-- 9 -->
# <g id="node8" class="node">
# <title>9</title>
# <g id="a_node8"><a xlink:title="size : 3&#10;2&#10;3&#10;4">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="437.3" cy="-300.46" rx="32.4" ry="32.4"/>
# </a>
# </g>
# </g>
# <!-- 8~9&#45;&#45;9 -->
# <g id="edge2" class="edge">
# <title>8~9--9</title>
# <path fill="none" stroke="#4a4a4a" d="M374.41,-333.06C382.5,-328.87 395.86,-321.94 408.18,-315.55"/>
# </g>
# <!-- 1~3&#45;&#45;3 -->
# <g id="edge4" class="edge">
# <title>1~3--3</title>
# <path fill="none" stroke="#4a4a4a" d="M414.88,-572.22C410.77,-565.87 402.51,-553.14 394.76,-541.19"/>
# </g>
# <!-- 0~4&#45;&#45;4 -->
# <g id="edge6" class="edge">
# <title>0~4--4</title>
# <path fill="none" stroke="#4a4a4a" d="M82.47,-70.5C88.73,-77.71 102.32,-93.36 112.84,-105.47"/>
# </g>
# <!-- 6~8&#45;&#45;8 -->
# <g id="edge8" class="edge">
# <title>6~8--8</title>
# <path fill="none" stroke="#4a4a4a" d="M230.76,-423.34C239.19,-417.41 253.4,-407.43 266.12,-398.5"/>
# </g>
# <!-- 2~8&#45;&#45;8 -->
# <g id="edge10" class="edge">
# <title>2~8--8</title>
# <path fill="none" stroke="#4a4a4a" d="M253.97,-318.25C259.16,-326.39 267.66,-339.74 275.42,-351.92"/>
# </g>
# <!-- 2~4&#45;&#45;4 -->
# <g id="edge12" class="edge">
# <title>2~4--4</title>
# <path fill="none" stroke="#4a4a4a" d="M166.67,-177.76C161.28,-170.15 149.11,-152.99 139.66,-139.65"/>
# </g>
# <!-- 3~8&#45;&#45;8 -->
# <g id="edge14" class="edge">
# <title>3~8--8</title>
# <path fill="none" stroke="#4a4a4a" d="M334.02,-444.14C329.44,-436.93 319.56,-421.37 310.65,-407.34"/>
# </g>
# </g>
# </svg><br><small><i>Map of the junction tree for the BN</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="161pt" height="216pt" viewBox="0.00 0.00 161.00 216.00">
# <g id="graph0" class="graph" transform="scale(0.325848 0.325848) rotate(0) translate(4 658.89)">
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <g id="a_node1"><a xlink:title="size : 2&#10;7&#10;8">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="21.6" cy="-21.6" rx="21.6" ry="21.6"/>
# </a>
# </g>
# </g>
# <!-- 0~4 -->
# <g id="node11" class="node">
# <title>0~4</title>
# <g id="a_node11"><a xlink:title="size : 1&#10;7">
# <polygon fill="palegreen" stroke="#4a4a4a" points="82.62,-70.13 75.42,-70.13 75.42,-62.93 82.62,-62.93 82.62,-70.13"/>
# </a>
# </g>
# </g>
# <!-- 0&#45;&#45;0~4 -->
# <g id="edge5" class="edge">
# <title>0--0~4</title>
# <path fill="none" stroke="#4a4a4a" d="M38.83,-35.08C51.51,-45 67.78,-57.73 75.12,-63.47"/>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <g id="a_node2"><a xlink:title="size : 2&#10;10&#10;11">
# <ellipse fill="burlywood" stroke="#4a4a4a" cx="463.5" cy="-633.29" rx="21.6" ry="21.6"/>
# </a>
# </g>
# </g>
# <!-- 1~3 -->
# <g id="node10" class="node">
# <title>1~3</title>
# <g id="a_node10"><a xlink:title="size : 1&#10;10">
# <polygon fill="palegreen" stroke="#4a4a4a" points="421.14,-579.92 413.94,-579.92 413.94,-572

# %%
gnb.showInference(bn, evs={"D": 1, "H": 0})

# %%
gum.config.reset()
gnb.showInference(mn, size="8", evs={"D": 1, "H": 0})

# %%
gum.config["factorgraph", "edge_length_inference"] = "1.1"
gnb.showInference(mn, size="11", evs={"D": 1, "H": 0})

# %%
gum.config["notebook", "default_markovrandomfield_view"] = "graph"
gnb.showInference(mn, size="8", evs={"D": 1, "H": 0})
