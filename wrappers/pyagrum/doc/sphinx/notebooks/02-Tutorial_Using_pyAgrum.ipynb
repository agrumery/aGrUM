# %% [markdown]
# # Using pyAgrum

# %% [markdown]
# | | | |
# |-|-|-|
# |[ ![Creative Commons License](images/cc4.png)](http://creativecommons.org/licenses/by-nc/4.0/) |[ ![aGrUM](images/logoAgrum.png)](https://pyagrum.gitlab.io) |[ ![interactive online version](images/atbinder.svg)](https://mybinder.org/v2/gl/agrumery%2FaGrUM/forBinder?urlpath=%2Fdoc%2Ftree%2Fwrappers%2Fpyagrum%2Fdoc%2Fsphinx%2Fnotebooks%2F02-Tutorial_Using_pyAgrum.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Initialisation
#
# * importing pyAgrum
# * importing pyagrum.lib tools
# * loading a BN

# %%
import pyagrum as gum
import pyagrum.lib.notebook as gnb

gnb.configuration()
# Out:
# <table><tr><th>Library</th><th>Version</th></tr><tr><td>OS</td><td>posix [darwin]</td></tr><tr><td>Python</td><td>3.14.7 (main, Aug  5 2026, 10:29:49) [Clang 21.0.0 (clang-2100.1.1.101)]</td></tr><tr><td>IPython</td><td>9.17.1</td></tr><tr><td>Matplotlib</td><td>3.11.2</td></tr><tr><td>Numpy</td><td>2.5.3</td></tr><tr><td>pyDot</td><td>4.0.1</td></tr><tr><td>pyAgrum</td><td>3.2.0</td></tr></table><div align='right'><small>Mon Sep 21 17:38:57 2026 CEST</small></div>

# %%
bn = gum.loadBN("res/alarm.dsl")
gnb.showBN(bn, size="9")

# %% [markdown]
# ## Visualisation and inspection

# %%
print(bn["SHUNT"])
# Out:
# SHUNT:Labelized({NORMAL|HIGH})

# %%
print(bn.cpt(bn.idFromName("SHUNT")))
# Out:
#              ║  SHUNT            │
# PULMEM│INTUBA║NORMAL   │HIGH     │
# ──────│──────║─────────│─────────│
# TRUE  │NORMAL║ 0.1000  │ 0.9000  │
# FALSE │NORMAL║ 0.9500  │ 0.0500  │
# TRUE  │ESOPHA║ 0.1000  │ 0.9000  │
# FALSE │ESOPHA║ 0.9500  │ 0.0500  │
# TRUE  │ONESID║ 0.0100  │ 0.9900  │
# FALSE │ONESID║ 0.0500  │ 0.9500  │

# %%
gnb.showTensor(bn.cpt(bn.idFromName("SHUNT")), digits=3)
# Out:
# <table style="border:1px solid black;border-collapse: collapse;"><tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>SHUNT</center>
#       </th></tr><tr><th style='border:1px solid black;color:black;background-color:#808080'><center>INTUBATION</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PULMEMBOLUS</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>NORMAL</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>HIGH</center></th></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>NORMAL</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>TRUE</center></th><td style='color:black;background-color:#f28b64;text-align:right;padding: 3px;'>0.100</td><td style='color:black;background-color:#8bf264;text-align:right;padding: 3px;'>0.900</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>FALSE</center></th><td style='color:black;background-color:#85f864;text-align:right;padding: 3px;'>0.950</td><td style='color:black;background-color:#f88564;text-align:right;padding: 3px;'>0.050</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ESOPHAGEAL</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>TRUE</center></th><td style='color:black;background-color:#f28b64;text-align:right;padding: 3px;'>0.100</td><td style='color:black;background-color:#8bf264;text-align:right;padding: 3px;'>0.900</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>FALSE</center></th><td style='color:black;background-color:#85f864;text-align:right;padding: 3px;'>0.950</td><td style='color:black;background-color:#f88564;text-align:right;padding: 3px;'>0.050</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>ONESIDED</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>TRUE</center></th><td style='color:black;background-color:#fd8064;text-align:right;padding: 3px;'>0.010</td><td style='color:black;background-color:#80fd64;text-align:right;padding: 3px;'>0.990</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>FALSE</center></th><td style='color:black;background-color:#f88564;text-align:right;padding: 3px;'>0.050</td><td style='color:black;background-color:#85f864;text-align:right;padding: 3px;'>0.950</td></tr></table>

# %% [markdown]
# ## Results of inference
#
# It is easy to look at result of inference

# %%
gnb.showPosterior(bn, {"SHUNT": "HIGH"}, "PRESS")
# Out:
# <img src="data:image/png;base64,...
# ">

# %%
gnb.showPosterior(bn, {"MINVOLSET": "NORMAL"}, "VENTALV")
# Out:
# <img src="data:image/png;base64,...
# ">

# %% [markdown]
# Overall results

# %%
gnb.showInference(bn, size="10")

# %% [markdown]
# What is the impact of observed variables (SHUNT and VENTALV for instance) on another on (PRESS) ?

# %%
ie = gum.LazyPropagation(bn)
ie.evidenceImpact("PRESS", ["SHUNT", "VENTALV"])
# Out:
# (pyagrum.Tensor@0x7a9feb46c0)
#              ║  PRESS                                │
# VENTAL│SHUNT ║ZERO     │LOW      │NORMAL   │HIGH     │
# ──────│──────║─────────│─────────│─────────│─────────│
# ZERO  │NORMAL║ 0.0569  │ 0.2669  │ 0.2005  │ 0.4757  │
# LOW   │NORMAL║ 0.0208  │ 0.2515  │ 0.0553  │ 0.6724  │
# NORMAL│NORMAL║ 0.0769  │ 0.3267  │ 0.1772  │ 0.4192  │
# HIGH  │NORMAL║ 0.0501  │ 0.1633  │ 0.2796  │ 0.5071  │
# ZERO  │HIGH  ║ 0.0589  │ 0.2726  │ 0.1997  │ 0.4688  │
# LOW   │HIGH  ║ 0.0318  │ 0.2237  │ 0.0521  │ 0.6924  │
# NORMAL│HIGH  ║ 0.1735  │ 0.5839  │ 0.1402  │ 0.1024  │
# HIGH  │HIGH  ║ 0.0711  │ 0.2347  │ 0.2533  │ 0.4410  │

# %% [markdown]
# ## Using inference as a function
#
# It is also easy to use inference as a routine in more complex procedures.

# %%
import time

r = range(0, 100)
xs = [x / 100.0 for x in r]

tf = time.time()
ys = [gum.getPosterior(bn, evs={"MINVOLSET": [0, x / 100.0, 0.5]}, target="VENTALV").tolist() for x in r]
delta = time.time() - tf

plt.plot(xs, ys)
plt.legend([bn["VENTALV"].label(i) for i in range(bn["VENTALV"].domainSize())], loc=7)
plt.title("VENTALV (100 inferences in %d ms)" % delta)
plt.ylabel("posterior Probability")
plt.xlabel("Evidence on MINVOLSET : [0,x,0.5]")
plt.show()

# %% [markdown]
# Another example : python gives access to a large set of tools. Here the value for the equality of two probabilities of a posterior is easely computed.

# %%
x = [p / 100.0 for p in range(0, 100)]

tf = time.time()
y = [
  gum.getPosterior(bn, evs={"HRBP": [1.0 - p / 100.0, 1.0 - p / 100.0, p / 100.0]}, target="TPR").tolist()
  for p in range(0, 100)
]
delta = time.time() - tf

plt.plot(x, y)
plt.title("HRBP (100 inferences in %d ms)" % delta)
v = bn["TPR"]
plt.legend([v.label(i) for i in range(v.domainSize())], loc="best")
np1 = (np.transpose(y)[0] > np.transpose(y)[2]).argmin()
plt.text(x[np1] - 0.05, y[np1][0] + 0.005, str(x[np1]), bbox=dict(facecolor="red", alpha=0.05))
plt.show()

# %% [markdown]
# ## BN as a classifier

# %% [markdown]
# ### Generation of databases
#
# Using the CSV format for the database:

# %%
print(
  f"The log2-likelihood of the generated base : {gum.generateSample(bn, 1000, 'out/test.csv', with_labels=True):.2f}"
)
# Out:
# The log2-likelihood of the generated base : -15306.03

# %%
with open("out/test.csv", "r") as src:
  for _ in range(10):
    print(src.readline(), end="")
# Out:
# PRESS,CATECHOL,PVSAT,DISCONNECT,SHUNT,PCWP,ANAPHYLAXIS,MINVOLSET,ARTCO2,HISTORY,HREKG,HRBP,SAO2,ERRLOWOUTPUT,EXPCO2,HYPOVOLEMIA,HRSAT,VENTALV,CVP,ERRCAUTER,MINVOL,INTUBATION,CO,STROKEVOLUME,BP,VENTLUNG,TPR,LVFAILURE,INSUFFANESTH,PAP,PULMEMBOLUS,FIO2,VENTMACH,LVEDVOLUME,KINKEDTUBE,HR,VENTTUBE
# NORMAL,HIGH,LOW,FALSE,NORMAL,LOW,FALSE,NORMAL,HIGH,TRUE,HIGH,HIGH,LOW,FALSE,LOW,TRUE,HIGH,ZERO,LOW,FALSE,ZERO,NORMAL,NORMAL,LOW,NORMAL,ZERO,NORMAL,TRUE,FALSE,NORMAL,FALSE,NORMAL,NORMAL,LOW,FALSE,HIGH,LOW
# NORMAL,HIGH,LOW,FALSE,NORMAL,HIGH,TRUE,NORMAL,HIGH,FALSE,HIGH,HIGH,LOW,FALSE,LOW,TRUE,HIGH,ZERO,NORMAL,FALSE,ZERO,NORMAL,NORMAL,LOW,NORMAL,ZERO,NORMAL,FALSE,FALSE,NORMAL,FALSE,NORMAL,NORMAL,HIGH,FALSE,HIGH,LOW
# HIGH,HIGH,LOW,FALSE,NORMAL,HIGH,FALSE,NORMAL,HIGH,FALSE,HIGH,HIGH,LOW,FALSE,LOW,FALSE,HIGH,ZERO,HIGH,FALSE,ZERO,NORMAL,HIGH,NORMAL,NORMAL,ZERO,NORMAL,FALSE,TRUE,NORMAL,FALSE,NORMAL,NORMAL,HIGH,FALSE,HIGH,LOW
# ZERO,HIGH,LOW,TRUE,NORMAL,LOW,FALSE,NORMAL,HIGH,FALSE,HIGH,LOW,LOW,FALSE,LOW,FALSE,LOW,ZERO,NORMAL,FALSE,ZERO,NORMAL,LOW,NORMAL,LOW,ZERO,NORMAL,FALSE,FALSE,NORMAL,FALSE,NORMAL,NORMAL,NORMAL,TRUE,NORMAL,ZERO
# HIGH,HIGH,HIGH,FALSE,NORMAL,NORMAL,FALSE,NORMAL,LOW,FALSE,HIGH,HIGH,NORMAL,FALSE,NORMAL,FALSE,HIGH,HIGH,NORMAL,FALSE,LOW,NORMAL,NORMAL,NORMAL,LOW,NORMAL,NORMAL,FALSE,FALSE,NORMAL,FALSE,NORMAL,NORMAL,NORMAL,FALSE,HIGH,LOW
# HIGH,HIGH,LOW,FALSE,HIGH,HIGH,FALSE,NORMAL,HIGH,FALSE,HIGH,HIGH,LOW,FALSE,LOW,TRUE,HIGH,ZERO,HIGH,FALSE,ZERO,NORMAL,LOW,LOW,LOW,ZERO,HIGH,FALSE,FALSE,NORMAL,FALSE,NORMAL,NORMAL,HIGH,FALSE,HIGH,LOW
# HIGH,HIGH,LOW,FALSE,NORMAL,NORMAL,FALSE,NORMAL,HIGH,FALSE,HIGH,HIGH,LOW,FALSE,LOW,FALSE,HIGH,ZERO,NORMAL,FALSE,ZERO,NORMAL,HIGH,NORMAL,LOW,ZERO,LOW,FALSE,FALSE,NORMAL,FALSE,NORMAL,NORMAL,NORMAL,FALSE,HIGH,LOW
# NORMAL,HIGH,LOW,FALSE,NORMAL,NORMAL,FALSE,NORMAL,HIGH,FALSE,HIGH,HIGH,LOW,FALSE,LOW,FALSE,HIGH,ZERO,NORMAL,FALSE,ZERO,NORMAL,HIGH,NORMAL,HIGH,ZERO,HIGH,FALSE,FALSE,NORMAL,FALSE,NORMAL,NORMAL,NORMAL,FALSE,HIGH,LOW
# HIGH,HIGH,NORMAL,FALSE,NORMAL,NORMAL,FALSE,NORMAL,HIGH,FALSE,HIGH,HIGH,LOW,FALSE,LOW,FALSE,HIGH,LOW,NORMAL,FALSE,ZERO,NORMAL,HIGH,NORMAL,HIGH,ZERO,HIGH,FALSE,FALSE,NORMAL,FALSE,NORMAL,NORMAL,NORMAL,FALSE,HIGH,LOW

# %% [markdown]
# ### probabilistic classifier using BN
#
# (because of the use of from-bn-generated csv files, quite good ROC curves are expected)

# %%
from pyagrum.lib.bn2roc import showROC_PR

showROC_PR(
  bn,
  "out/test.csv",
  target="CATECHOL",
  label="HIGH",  # class and label
  show_progress=True,
  show_fig=True,
  with_labels=True,
)
# Out:
# out/test.csv:   0%|          |
# out/test.csv: 100%|██████████|
# (np.float64(0.9397100812651),
#  np.float64(0.9300899828),
#  np.float64(0.9946366806555398),
#  np.float64(0.09747101979999999))

# %% [markdown]
# Using another class variable

# %%
showROC_PR(bn, "out/test.csv", "SAO2", "HIGH", show_progress=True)
# Out:
# out/test.csv:   0%|          |
# out/test.csv: 100%|██████████|
# (np.float64(0.3375239197187486),
#  np.float64(0.012257517612538345),
#  np.float64(0.02580906142623325),
#  np.float64(0.012257517612538345))

# %% [markdown]
# ## Fast prototyping for BNs

# %%
bn1 = gum.fastBN("a->b;a->c;b->c;c->d", 3)

gnb.sideBySide(
  *[gnb.getInference(bn1, evs={"c": val}, targets={"a", "c", "d"}) for val in range(3)],
  captions=[f"Inference given that $c={val}$" for val in range(3)],
)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="144pt" height="357pt" viewBox="0.00 0.00 144.00 357.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 352.5)">
# <title>structs</title>
# <text xml:space="preserve" text-anchor="middle" x="68" y="-7.2" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in  21.54ms</text>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="120.25,-348.5 19.25,-348.5 19.25,-284.5 120.25,-284.5 120.25,-348.5"/>
# <svg viewBox="0 0 132.1625 83.000703" width="101px" height="64px" preserveAspectRatio="xMinYMin meet" x="19.25" y="-348.5"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2026-09-21T17:39:02.820731</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.11.2, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 83.000703  L 132.1625 83.000703  L 132.1625 0  L 0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 75.900703  L 128.5625 75.900703  L 128.5625 34.320703  L 16.9625 34.320703  z " style="fill: #ffffff"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 16.9625 75.900703  L 79.281618 75.900703  L 79.281618 64.020703  L 16.9625 64.020703  z " clip-path="url(#p465c8f98d8)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="patch_4">
#     <path d="M 16.9625 61.050703  L 50.518615 61.050703  L 50.518615 49.170703  L 16.9625 49.170703  z " clip-path="url(#p465c8f98d8)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="patch_5">
#     <path d="M 16.9625 46.200703  L 32.687267 46.200703  L 32.687267 34.320703  L 16.9625 34.320703  z " clip-path="url(#p465c8f98d8)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path d="M 16.9625 75.900703  L 16.9625 34.320703  " clip-path="url(#p465c8f98d8)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path id="mdc35db1a5f" d="M 0 0  L 0 3.5  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#mdc35db1a5f" x="16.9625" y="75.900703" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path d="M 72.7625 75.900703  L 72.7625 34.320703  " clip-path="url(#p465c8f98d8)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use xlink:href="#mdc35db1a5f" x="72.7625" y="75.900703" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path d="M 128.5625 75.900703  L 128.5625 34.320703  " clip-path="url(#p465c8f98d8)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use xlink:href="#mdc35db1a5f" x="128.5625" y="75.900703" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path id="m2fb62cb40d" d="M 0 0  L -3.5 0  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#m2fb62cb40d" x="16.9625" y="69.960703" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 2 -->
#       <g transform="translate(3.6 73.759531) scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-15" d="M 1228 531  L 3431 531  L 3431 0  L 469 0  L 469 531  Q 828 903 1448 1529  Q 2069 2156 2228 2338  Q 2531 2678 2651 2914  Q 2772 3150 2772 3378  Q 2772 3750 2511 3984  Q 2250 4219 1831 4219  Q 1534 4219 1204 4116  Q 875 4013 500 3803  L 500 4441  Q 881 4594 1212 4672  Q 1544 4750 1819 4750  Q 2544 4750 2975 4387  Q 3406 4025 3406 3419  Q 3406 3131 3298 2873  Q 3191 2616 2906 2266  Q 2828 2175 2409 1742  Q 1991 1309 1228 531  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-15"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_2">
#      <g id="line2d_8">
#       <g>
#        <use xlink:href="#m2fb62cb40d" x="16.9625" y="55.110703" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 1 -->
#       <g transform="translate(3.6 58.909531) scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-14" d="M 794 531  L 1825 531  L 1825 4091  L 703 3866  L 703 4441  L 1819 4666  L 2450 4666  L 2450 531  L 3481 531  L 3481 0  L 794 0  L 794 531  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-14"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_3">
#      <g id="line2d_9">
#       <g>
#        <use xlink:href="#m2fb62cb40d" x="16.9625" y="40.260703" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 0 -->
#       <g transform="translate(3.6 44.059531) scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-13" d="M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-13"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="patch_6">
#     <path d="M 16.9625 75.900703  L 16.9625 34.320703  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="patch_7">
#     <path d="M 128.5625 75.900703  L 128.5625 34.320703  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="patch_8">
#     <path d="M 16.9625 75.900703  L 128.5625 75.900703  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="patch_9">
#     <path d="M 16.9625 34.320703  L 128.5625 34.320703  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="text_4">
#     <!-- 55.84% -->
#     <g style="opacity: 0.7" transform="translate(90.432812 73.498359) scale(0.1 -0.1)">
#      <defs>
#       <path id="DejaVuSans-18" d="M 691 4666  L 3169 4666  L 3169 4134  L 1269 4134  L 1269 2991  Q 1406 3038 1543 3061  Q 1681 3084 1819 3084  Q 2600 3084 3056 2656  Q 3513 2228 3513 1497  Q 3513 744 3044 326  Q 2575 -91 1722 -91  Q 1428 -91 1123 -41  Q 819 9 494 109  L 494 744  Q 775 591 1075 516  Q 1375 441 1709 441  Q 2250 441 2565 725  Q 2881 1009 2881 1497  Q 2881 1984 2565 2268  Q 2250 2553 1709 2553  Q 1456 2553 1204 2497  Q 953 2441 691 2322  L 691 4666  z " transform="scale(0.015625)"/>
#       <path id="DejaVuSans-11" d="M 684 794  L 1344 794  L 1344 0  L 684 0  L 684 794  z " transform="scale(0.015625)"/>
#       <path id="DejaVuSans-1b" d="M 2034 2216  Q 1584 2216 1326 1975  Q 1069 1734 1069 1313  Q 1069 891 1326 650  Q 1584 409 2034 409  Q 2484 409 2743 651  Q 3003 894 3003 1313  Q 3003 1734 2745 1975  Q 2488 2216 2034 2216  z M 1403 2484  Q

# %%
print(gum.getPosterior(bn1, evs={"c": 0}, target="c"))
print(gum.getPosterior(bn1, evs={"c": 0}, target="d"))

# using pyagrum.lib.notebook's helpers
gnb.flow.row(gum.getPosterior(bn1, evs={"c": 0}, target="c"), gum.getPosterior(bn1, evs={"c": 0}, target="d"))
# Out:
#   c                          │
# 0        │1        │2        │
# ─────────│─────────│─────────│
#  1.0000  │ 0.0000  │ 0.0000  │
#
#
#   d                          │
# 0        │1        │2        │
# ─────────│─────────│─────────│
#  0.0796  │ 0.2674  │ 0.6529  │
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='3'><center>c</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>2</center></th></tr>
# <tr><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.0000</td></tr>
# </table></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='3'><center>d</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>2</center></th></tr>
# <tr><td style='color:black;background-color:#f48964;text-align:right;padding: 3px;'>0.0796</td><td style='color:black;background-color:#dca164;text-align:right;padding: 3px;'>0.2674</td><td style='color:black;background-color:#abd264;text-align:right;padding: 3px;'>0.6529</td></tr>
# </table></div>

# %% [markdown]
# ## Joint posterior, impact of multiple evidence

# %%
bn = gum.fastBN("a->b->c->d;b->e->d->f;g->c")
gnb.sideBySide(bn, gnb.getInference(bn))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="134pt" height="332pt" viewBox="0.00 0.00 134.00 332.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <g id="a_node1"><a xlink:title="(0) a">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="99" cy="-306" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="99" y="-300.95" font-family="Times,serif" font-size="14.00" fill="white">a</text>
# </a>
# </g>
# </g>
# <!-- b -->
# <g id="node6" class="node">
# <title>b</title>
# <g id="a_node6"><a xlink:title="(1) b">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="99" cy="-234" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="99" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">b</text>
# </a>
# </g>
# </g>
# <!-- a&#45;&gt;b -->
# <g id="edge1" class="edge">
# <title>a-&gt;b</title>
# <g id="a_edge1"><a xlink:title="0 → 1">
# <path fill="none" stroke="#4a4a4a" d="M99,-287.7C99,-280.41 99,-271.73 99,-263.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.5,-263.62 99,-253.62 95.5,-263.62 102.5,-263.62"/>
# </a>
# </g>
# </g>
# <!-- g -->
# <g id="node2" class="node">
# <title>g</title>
# <g id="a_node2"><a xlink:title="(6) g">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-234" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="27" y="-228.95" font-family="Times,serif" font-size="14.00" fill="white">g</text>
# </a>
# </g>
# </g>
# <!-- c -->
# <g id="node3" class="node">
# <title>c</title>
# <g id="a_node3"><a xlink:title="(2) c">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-162" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="27" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">c</text>
# </a>
# </g>
# </g>
# <!-- g&#45;&gt;c -->
# <g id="edge2" class="edge">
# <title>g-&gt;c</title>
# <g id="a_edge2"><a xlink:title="6 → 2">
# <path fill="none" stroke="#4a4a4a" d="M27,-215.7C27,-208.41 27,-199.73 27,-191.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="30.5,-191.62 27,-181.62 23.5,-191.62 30.5,-191.62"/>
# </a>
# </g>
# </g>
# <!-- d -->
# <g id="node5" class="node">
# <title>d</title>
# <g id="a_node5"><a xlink:title="(3) d">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="63" cy="-90" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="63" y="-84.95" font-family="Times,serif" font-size="14.00" fill="white">d</text>
# </a>
# </g>
# </g>
# <!-- c&#45;&gt;d -->
# <g id="edge6" class="edge">
# <title>c-&gt;d</title>
# <g id="a_edge6"><a xlink:title="2 → 3">
# <path fill="none" stroke="#4a4a4a" d="M35.35,-144.76C39.58,-136.55 44.81,-126.37 49.58,-117.09"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="52.54,-118.99 54,-108.49 46.32,-115.79 52.54,-118.99"/>
# </a>
# </g>
# </g>
# <!-- e -->
# <g id="node4" class="node">
# <title>e</title>
# <g id="a_node4"><a xlink:title="(4) e">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="99" cy="-162" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="99" y="-156.95" font-family="Times,serif" font-size="14.00" fill="white">e</text>
# </a>
# </g>
# </g>
# <!-- e&#45;&gt;d -->
# <g id="edge4" class="edge">
# <title>e-&gt;d</title>
# <g id="a_edge4"><a xlink:title="4 → 3">
# <path fill="none" stroke="#4a4a4a" d="M90.65,-144.76C86.42,-136.55 81.19,-126.37 76.42,-117.09"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="79.68,-115.79 72,-108.49 73.46,-118.99 79.68,-115.79"/>
# </a>
# </g>
# </g>
# <!-- f -->
# <g id="node7" class="node">
# <title>f</title>
# <g id="a_node7"><a xlink:title="(5) f">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="63" cy="-18" rx="27" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="63" y="-12.95" font-family="Times,serif" font-size="14.00" fill="white">f</text>
# </a>
# </g>
# </g>
# <!-- d&#45;&gt;f -->
# <g id="edge7" class="edge">
# <title>d-&gt;f</title>
# <g id="a_edge7"><a xlink:title="3 → 5">
# <path fill="none" stroke="#4a4a4a" d="M63,-71.7C63,-64.41 63,-55.73 63,-47.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="66.5,-47.62 63,-37.62 59.5,-47.62 66.5,-47.62"/>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;c -->
# <g id="edge3" class="edge">
# <title>b-&gt;c</title>
# <g id="a_edge3"><a xlink:title="1 → 2">
# <path fill="none" stroke="#4a4a4a" d="M84.08,-218.5C74.23,-208.92 61.14,-196.19 49.97,-185.34"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="52.59,-183 42.98,-178.54 47.71,-188.02 52.59,-183"/>
# </a>
# </g>
# </g>
# <!-- b&#45;&gt;e -->
# <g id="edge5" class="edge">
# <title>b-&gt;e</title>
# <g id="a_edge5"><a xlink:title="1 → 4">
# <path fill="none" stroke="#4a4a4a" d="M99,-215.7C99,-208.41 99,-199.73 99,-191.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.5,-191.62 99,-181.62 95.5,-191.62 102.5,-191.62"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="228pt" height="442pt" viewBox="0.00 0.00 228.00 442.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 437.5)">
# <title>structs</title>
# <text xml:space="preserve" text-anchor="middle" x="110" y="-7.2" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.18ms</text>
# <!-- a -->
# <g id="node1" class="node">
# <title>a</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="220,-433.5 119,-433.5 119,-380.5 220,-380.5 220,-433.5"/>
# <svg viewBox="0 0 132.1625 69.140703" width="101px" height="53px" preserveAspectRatio="xMinYMin meet" x="119" y="-433.5"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2026-09-21T17:39:03.936534</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.11.2, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 69.140703  L 132.1625 69.140703  L 132.1625 0  L 0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 62.040703  L 128.5625 62.040703  L 128.5625 34.320703  L 16.9625 34.320703  z " style="fill: #ffffff"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 16.9625 62.040703  L 58.714442 62.040703  L 58.714442 49.720703  L 16.9625 49.720703  z " clip-path="url(#p3b13b090a8)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="patch_4">
#     <path d="M 16.9625 46.640703  L 86.810558 46.640703  L 86.810558 34.320703  L 16.9625 34.320703  z " clip-path="url(#p3b13b090a8)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path d="M 16.9625 62.040703  L 16.9625 34.320703  " clip-path="url(#p3b13b090a8)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path id="m517d0904ad" d="M 0 0  L 0 3.5  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#m517d0904ad" x="16.9625" y="62.040703" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path d="M 72.7625 62.040703  L 72.7625 34.320703  " clip-path="url(#p3b13b090a8)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use xlink:href="#m517d0904ad" x="72.7625" y="62.040703" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>

# %%
ie = gum.LazyPropagation(bn)
ie.addJointTarget({"e", "f", "g"})
ie.makeInference()
gnb.sideBySide(
  ie.jointPosterior({"e", "f", "g"}),
  ie.jointPosterior({"e", "g"}),
  captions=["Joint posterior $P(e,f,g)$", "Joint posterior $P(e,f)$"],
)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>g</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>f</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#f48964;text-align:right;padding: 3px;'>0.0782</td><td style='color:black;background-color:#fb8264;text-align:right;padding: 3px;'>0.0276</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#dda064;text-align:right;padding: 3px;'>0.2655</td><td style='color:black;background-color:#f38a64;text-align:right;padding: 3px;'>0.0935</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#f18c64;text-align:right;padding: 3px;'>0.1083</td><td style='color:black;background-color:#fa8364;text-align:right;padding: 3px;'>0.0356</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#d9a464;text-align:right;padding: 3px;'>0.2951</td><td style='color:black;background-color:#f28b64;text-align:right;padding: 3px;'>0.0962</td></tr>
# </table><br><small><i>Joint posterior $P(e,f,g)$</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>g</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#e79664;text-align:right;padding: 3px;'>0.1865</td><td style='color:black;background-color:#f68764;text-align:right;padding: 3px;'>0.0631</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#b7c664;text-align:right;padding: 3px;'>0.5606</td><td style='color:black;background-color:#e69764;text-align:right;padding: 3px;'>0.1898</td></tr>
# </table><br><small><i>Joint posterior $P(e,f)$</i></small></div></td></tr></table>

# %%
gnb.sideBySide(
  ie.evidenceImpact("a", ["e", "f"]),
  ie.evidenceImpact("a", ["d", "e", "f"]),
  captions=["$\\forall e,f, P(a|e,f)$", "$\\forall d,e,f, P(a|d,e,f)=P(a|d,e)$ using d-separation"],
)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>a</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>f</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#b2cb64;text-align:right;padding: 3px;'>0.5982</td><td style='color:black;background-color:#cbb264;text-align:right;padding: 3px;'>0.4018</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#acd164;text-align:right;padding: 3px;'>0.6459</td><td style='color:black;background-color:#d1ac64;text-align:right;padding: 3px;'>0.3541</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#b3ca64;text-align:right;padding: 3px;'>0.5862</td><td style='color:black;background-color:#cab364;text-align:right;padding: 3px;'>0.4138</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#aecf64;text-align:right;padding: 3px;'>0.6296</td><td style='color:black;background-color:#cfae64;text-align:right;padding: 3px;'>0.3704</td></tr>
# </table><br><small><i>$\forall e,f, P(a|e,f)$</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>a</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>d</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#b6c764;text-align:right;padding: 3px;'>0.5651</td><td style='color:black;background-color:#c7b664;text-align:right;padding: 3px;'>0.4349</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#a9d464;text-align:right;padding: 3px;'>0.6664</td><td style='color:black;background-color:#d4a964;text-align:right;padding: 3px;'>0.3336</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#b6c764;text-align:right;padding: 3px;'>0.5671</td><td style='color:black;background-color:#c7b664;text-align:right;padding: 3px;'>0.4329</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#a7d664;text-align:right;padding: 3px;'>0.6806</td><td style='color:black;background-color:#d6a764;text-align:right;padding: 3px;'>0.3194</td></tr>
# </table><br><small><i>$\forall d,e,f, P(a|d,e,f)=P(a|d,e)$ using d-separation</i></small></div></td></tr></table>

# %%
gnb.sideBySide(
  ie.evidenceJointImpact(["a", "b"], ["e", "f"]),
  ie.evidenceJointImpact(["a", "b"], ["d", "e", "f"]),
  captions=["$\\forall e,f, P(a,b|e,f)$", "$\\forall d,e,f, P(a,b|d,e,f)=P(a,b|d,e)$ using d-separation"],
)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='3'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>b</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>f</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>a</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;padding: 3px;'>0.3527</td><td style='text-align:right;padding: 3px;'>0.2455</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;padding: 3px;'>0.0659</td><td style='text-align:right;padding: 3px;'>0.3359</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;padding: 3px;'>0.4482</td><td style='text-align:right;padding: 3px;'>0.1976</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;padding: 3px;'>0.0837</td><td style='text-align:right;padding: 3px;'>0.2704</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;padding: 3px;'>0.3285</td><td style='text-align:right;padding: 3px;'>0.2577</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;padding: 3px;'>0.0614</td><td style='text-align:right;padding: 3px;'>0.3525</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;padding: 3px;'>0.4156</td><td style='text-align:right;padding: 3px;'>0.2140</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;padding: 3px;'>0.0776</td><td style='text-align:right;padding: 3px;'>0.2928</td></tr>
# </table><br><small><i>$\forall e,f, P(a,b|e,f)$</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='3'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>b</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>e</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>d</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>a</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;padding: 3px;'>0.2863</td><td style='text-align:right;padding: 3px;'>0.2788</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;padding: 3px;'>0.0535</td><td style='text-align:right;padding: 3px;'>0.3815</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;padding: 3px;'>0.4893</td><td style='text-align:right;padding: 3px;'>0.1771</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;padding: 3px;'>0.0914</td><td style='text-align:right;padding: 3px;'>0.2422</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;padding: 3px;'>0.2903</td><td style='text-align:right;padding: 3px;'>0.2768</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;padding: 3px;'>0.0542</td><td style='text-align:right;padding: 3px;'>0.3787</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;padding: 3px;'>0.5178</td><td style='text-align:right;padding: 3px;'>0.1628</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;padding: 3px;'>0.0967</td><td style='text-align:right;padding: 3px;'>0.2227</td></tr>
# </table><br><small><i>$\forall d,e,f, P(a,b|d,e,f)=P(a,b|d,e)$ using d-separation</i></small></div></td></tr></table>

# %% [markdown]
# ## Most Probable Explanation
#
# The Most Probable Explanation (MPE) is a concept commonly used in the field of probabilistic reasoning and Bayesian statistics. It refers to the set of values for the variables in a given probabilistic model that is the most consistent with (that maximizes the likelihood of) the observed evidence. Essentially, it represents the most likely scenario or explanation given the available evidenceand the underlying probabilistic model.

# %%
ie = gum.LazyPropagation(bn)
print(ie.mpe())
# Out:
# <d:1|e:1|c:1|b:0|a:0|g:0|f:0>

# %%
evs = {"e": 0, "g": 0}
ie.setEvidence(evs)
vals = ie.mpeLog2Posterior()
print(
  f"The most probable explanation for observation {evs} is \n - the configuration {vals[0]} \n - for a log probability of {vals[1]:.6f}"
)
# Out:
# The most probable explanation for observation {'e': 0, 'g': 0} is
#  - the configuration <g:0|e:0|d:0|f:1|c:0|b:1|a:1>
#  - for a log probability of -2.579438
